# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from numpy.random import choice
from numpy.linalg import norm

from math import factorial

from itertools import permutations

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE, Isomap
import umap

from tqdm import tqdm
import os

# %%
from numpy.linalg import svd, eigvals
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, homogeneity_completeness_v_measure, confusion_matrix, ConfusionMatrixDisplay

# %%
from skdim.id import *

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import get_cmap

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.style.use('seaborn-whitegrid')
# plt.style.use('default')

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

# %%
from generate_data import generate_lattice_based_task, makeTensorLoaders

# %% [markdown]
# #### Test for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('No GPU, training on CPU')
    device = torch.device('cpu')
else:
    print('GPU found, training on GPU')
    device = torch.device('cuda')
# Out:
# GPU found, training on GPU

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Number of runs

# %%
nRuns = 5

# %% [markdown]
# #### Generate data for runs

# %%
dim = 64
nTot = 2000
latticeDim = 2

fracTrain = 0.8
fracTest = np.round(1-fracTrain,2)

nTrain = int(nTot*fracTrain)
nTest = nTot - nTrain

lenSeq = 4
nRepeats = 2

dimsL = np.array([5,5])
nStates = np.prod(dimsL)

# %%
cnt = 0
lattice_labels = np.zeros((nStates,latticeDim),dtype=int)
for y in range(-2,3):
    for x in range(-2,3):
        lattice_labels[cnt] = (x,y)
        cnt += 1

# %%
def templateMaker(nStates, dim):
    ## Generate template representations (for expected elements)
    template = np.zeros((nStates, dim))
    for ii in range(nStates):
        template[ii] = choice(2, dim, p=[0.75, 0.25])## p=[Pr(0),Pr(1)]
    return template

# %%
template = {}
for cntr in range(nRuns):
    template[cntr] = templateMaker(nStates=nStates,dim=dim)

# %%
repsTrain = {}
yRepsTrain = {}
eTrain = {}
pTrain = {}
surpTrain = {}
allStatesTrain = {}
actionsTrain = {}

# %%
repsTest = {}
yRepsTest = {}
eTest = {}
pTest = {}
surpTest = {}
allStatesTest = {}
actionsTest = {}

# %%
repsTestTemp = {}
yRepsTestTemp = {}
eTestTemp = {}
pTestTemp = {}
surpTestTemp = {}
allStatesTestTemp = {}
actionsTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]),\
    (actionsTrain[cntr],actionsTest[cntr],actionsTestTemp[cntr]) = generate_lattice_based_task(nTot,fracTrain,dim,lenSeq,
                                                                                               lattice_labels=lattice_labels,
                                                                                               latticeDim=latticeDim,
                                                                                               repeats=True, numRepeats=nRepeats,
                                                                                               template=template[cntr])

# %% [markdown]
# #### Create directories to save data and representations

# %%
pp = ## specify path

# %%
npp = {}
pp_npy = {}
pp_pts = {}

# %%
for cntr in range(nRuns):
    
    npp[cntr] = 'lattice-same-pop-'+str(cntr)+'/'
    pp_npy[cntr] = pp+npp[cntr]+'npys-'+str(cntr)+'/'
    pp_pts[cntr] = pp+npp[cntr]+'pts-'+str(cntr)+'/'

    ## uncomment the following lines to create the folders. comment out if already created
    
    # os.mkdir(os.path.join(pp,npp[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_pts[cntr]))

    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr],'Dataset/'))

# %% [markdown]
# #### Save seeds and dataset

# %%
seeds = np.random.randint(1000, size=nRuns)
np.save(pp_npy[cntr]+'seeds',seeds)

# %%
for cntr in range(nRuns):
    ## Template
    np.save(pp_npy[cntr]+'Dataset/template',template[cntr])

    ## Train Data
    np.save(pp_npy[cntr]+'Dataset/repsTrain',repsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTrain',yRepsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTrain',eTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTrain',surpTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTrain',allStatesTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTrain',actionsTrain[cntr])

    ## Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTest',repsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTest',yRepsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTest',eTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTest',surpTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTest',allStatesTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTest',actionsTest[cntr])
    
    ## Temporally violated Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTestTemp',repsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTestTemp',yRepsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTestTemp',eTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTestTemp',surpTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTestTemp',allStatesTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTestTemp',actionsTestTemp[cntr])

# %% [markdown]
# #### Load seeds

# %%
seeds = np.load(pp_npy[cntr]+'seeds.npy')

# %%
seeds
# Out:
# array([732, 590, 605, 785, 149])

# %% [markdown]
# #### Convert data into tensors, etc.

# %%
batch_size = 100 ##100

# %%
pos_seq_idx = np.array([0,0,1,1,2,2])

# %%
train_loader = {}
test_loader = {}
test_temp_loader = {}

# %%
for cntr in range(nRuns):
    train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=True)
    test_loader[cntr] = makeTensorLoaders((repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)
    test_temp_loader[cntr] = makeTensorLoaders((repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),
                                          batch_size,shuffle=False)

# %%
# kk = 3
# print(np.min(allStatesTestTemp[kk]))
# ix = np.where(allStatesTestTemp[kk]==np.min(allStatesTestTemp[kk]))[0]
# print(repsTestTemp[kk][ix])
# print(yRepsTestTemp[kk][ix])

# %% [markdown]
# #### Load architectures, models, etc.

# %%
n_latent = 16 ## make sure it is the same in the architecture file as well
pop_list = [3,3,3] ## make sure it is the same in the architecture file as well

# %%
from architecture_same_pop import microcircuit

# %%
model = {}
optimizer_rec = {}
optimizer_pc = {}

# %%
#specify loss function
reconLoss = nn.MSELoss()

#optimizer learning rate
eta_rec = 0.001
eta_pc = 0.0001

# %%
for cntr in range(nRuns):
    model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,pop_list=pop_list,bsize=batch_size,
                               manual_seed=seeds[cntr],task='lattice')
    model[cntr].to(device)

# %%
for cntr in range(nRuns):
    optimizer_rec[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_rec)
    optimizer_pc[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_pc)

# %% [markdown]
# #### Train and collect activations

# %%
for data, f_target, lastEvent, surpriseBinary in train_loader[0]:
    if train_on_gpu:
        data, f_target = data.float().cuda(), f_target.float().cuda()
    else: data, f_target = data.float(), f_target.float()

# %%
output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[0](data)

# %%
nSteps = data.shape[1]

# %%
n_epochs = 100 ## number of epochs
div = n_epochs//n_epochs ## try ensuring that number used to divide by is a factor of n_epochs

# %%
feedback = True

# %%
def findMSE(output):
    errSq = output**2
    MSE_mat_samples_seq = errSq/np.prod(errSq.shape)
    MSE_samples = torch.mean(MSE_mat_samples_seq,1)
    return MSE_samples

# %%
train_losses = {}
test_losses = {}
temp_losses = {}

train_expected_rec_losses = {}
train_expected_fb_losses = {}

test_expected_rec_losses = {}
test_expected_fb_losses = {}

test_surprise_rec_losses = {}
test_surprise_fb_losses = {}

MSE_mat_full_test = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    train_losses[cntr] = np.zeros(n_epochs+1)
    test_losses[cntr] = np.zeros(n_epochs+1)
    temp_losses[cntr] = np.zeros(n_epochs+1)

    train_loss_min = np.Inf
    best_epoch = 0

    train_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    train_expected_fb_losses[cntr] = np.zeros(n_epochs+1)

    test_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_fb_losses[cntr] = np.zeros(n_epochs+1)
    
    test_surprise_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_surprise_fb_losses[cntr] = np.zeros(n_epochs+1)

    MSE_mat_full_test[cntr] = np.zeros(n_epochs+1)

    for epoch in (range(1,n_epochs+1)):

        train_loss = 0.0

        train_expected_rec_loss = 0.0
        train_expected_fb_loss = 0.0
        
        test_expected_rec_loss = 0.0
        test_expected_fb_loss = 0.0

        temp_rec_loss = 0.0
        temp_fb_loss = 0.0
        
        test_loss = 0.0
        temp_loss = 0.0

        cnt = 0
        
        ## Save model without training
        if epoch == 1:
            
            model[cntr].eval()
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_0.pt') ## Save model before any training
            
            ## Losses at 0th epoch
            for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
                if train_on_gpu:
                    data, f_target = data.float().cuda(), f_target.float().cuda()
                else:
                    data, f_target = data.float(), f_target.float()

                ##define all-sequence targets
                target = f_target

                optimizer_rec[cntr].zero_grad() #clears older gradients
                optimizer_pc[cntr].zero_grad() #clears older gradients
                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

                err_rec = torch.linalg.norm((output_pred-target),dim=2)
                err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
                MSE_samples_rec = findMSE(err_rec)
                MSE_samples_fb = findMSE(err_fb)

                loss = reconLoss(output_pred,target) #calculate the loss for the batch
                train_loss += loss.item()*data.size(0) #update training loss

                train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
                train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
                                    
            ## calculate average loss
            train_loss = train_loss/len(train_loader[cntr].dataset)
            
            ## Training loss at initialization
            train_losses[cntr][0] = train_loss
            train_expected_rec_losses[cntr][0] = train_expected_rec_loss
            train_expected_fb_losses[cntr][0] = train_expected_fb_loss
            
            ## Test losses at initialization
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test

                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)
                
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                # calculate the batch loss
                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
#             print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][0] = test_loss

            test_expected_rec_losses[cntr][0] = test_expected_rec_loss
            test_expected_fb_losses[cntr][0] = test_expected_fb_loss
        
        ## Test temp losses at initialization
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                    
                ##define all-sequence targets
                target_temp = f_target_temp

                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)
                loss_temp = reconLoss(output_pred_temp,target_temp)
                err_temp_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                # calculate the batch loss
                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_temp.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
#             print('Temp Loss: {:.6f}\n'.format(test_loss))

            temp_losses[cntr][0] = temp_loss

            test_surprise_rec_losses[cntr][0] = temp_rec_loss
            test_surprise_fb_losses[cntr][0] = temp_fb_loss

        #train model
        model[cntr].train()
        for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
            if train_on_gpu:
                data, f_target = data.float().cuda(), f_target.float().cuda()
            else:
                data, f_target = data.float(), f_target.float()

            ##define all-sequence targets
            target = f_target

            output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

            err_rec = torch.linalg.norm((output_pred-target),dim=2)
            err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
            MSE_samples_rec = findMSE(err_rec)
            MSE_samples_fb = findMSE(err_fb)
            
            loss = reconLoss(output_pred,target) #calculate the loss for the batch
            train_loss += loss.item()*data.size(0) #update training loss
            fbloss = torch.mean(MSE_samples_fb)

            optimizer_rec[cntr].zero_grad() #clears older gradients
            optimizer_pc[cntr].zero_grad() #clears older gradients
            ######## feedback error updates only higher-cortical area
            if (feedback)&(epoch%2==0):
                for name, param in model[cntr].named_parameters():
                    if ('FF' in name) or ('L23' in name) or ('L4' in name) or ('L56' in name):
                        param.require_grad = False
                fbloss.backward()
                optimizer_pc[cntr].step()
                for name, param in model[cntr].named_parameters():
                    param.require_grad = True
            else:
                loss.backward() #backprop
                optimizer_rec[cntr].step() #update parameters in direction of the -ve gradient  

            train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
            train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
        
        #calculate average loss
        train_loss = train_loss/len(train_loader[cntr].dataset)

        #training/validation stats
        train_losses[cntr][epoch] = train_loss
        train_expected_rec_losses[cntr][epoch] = train_expected_rec_loss
        train_expected_fb_losses[cntr][epoch] = train_expected_fb_loss

        #save model if the training loss decreased
        if train_loss <= train_loss_min:
            print('Epoch: {}, Train Loss Decreased!! ({:.6f}-->{:.6f})'.format(epoch,train_loss_min,train_loss))
            torch.save(model[cntr].state_dict(),pp_pts[cntr]+'predRNN.pt')
            train_loss_min = train_loss
            best_epoch = epoch

        if epoch%div == 0:
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_'+str(epoch)+'.pt')
            
            model[cntr].eval()
            
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test
                
                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)

                # calculate the batch loss
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
            print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][epoch] = test_loss

            test_expected_rec_losses[cntr][epoch] = test_expected_rec_loss
            test_expected_fb_losses[cntr][epoch] = test_expected_fb_loss
            
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                
                ##define all-sequence targets
                target_temp = f_target_temp
                
                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)

                # calculate the batch loss
                err_temp_rec = torch.linalg.norm((output_pred_temp-target_temp),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_temp[0],dim=2)+torch.linalg.norm(feedbackDiffs_temp[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_test.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
            print('Temp Loss: {:.6f}\n'.format(temp_loss))

            temp_losses[cntr][epoch] = temp_loss

            test_surprise_rec_losses[cntr][epoch] = temp_rec_loss
            test_surprise_fb_losses[cntr][epoch] = temp_fb_loss
            
    print('----------------------------------------------------')
            
    outF = open(pp+npp[cntr]+"training-details.txt", "w")
    outF.write('# epochs = ' + str(n_epochs))
    outF.write('\n')
    outF.write('Best epoch = '+str(best_epoch))
    outF.write('\n')
    outF.write('Minimum training loss = ' + str(train_loss_min))
    outF.write('\n')
    outF.write('Total number of samples = ' + str(nTot))
    outF.write('\n')
    outF.write('Number of training samples = ' + str(nTrain))
    outF.write('\n')
    outF.write('Number of testing samples = ' + str(nTest))
    outF.write('\n')
    outF.write('Dimensionality of representations = ' + str(dim))
    outF.write('\n')
    outF.write('Length of sequences = ' + str(lenSeq))
    outF.write('\n')
    outF.close()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1, Train Loss Decreased!! (inf-->0.222948)
# Test Loss: 0.188810
#
# Temp Loss: 0.189892
#
# Epoch: 2, Train Loss Decreased!! (0.222948-->0.188499)
# Test Loss: 0.187981
#
# Temp Loss: 0.188949
#
# Epoch: 3, Train Loss Decreased!! (0.188499-->0.184258)
# Test Loss: 0.182109
#
# Temp Loss: 0.183457
#
# Epoch: 4, Train Loss Decreased!! (0.184258-->0.182416)
# Test Loss: 0.181945
#
# Temp Loss: 0.183343
#
# Epoch: 5, Train Loss Decreased!! (0.182416-->0.181721)
# Test Loss: 0.180976
#
# Temp Loss: 0.182256
#
# Epoch: 6, Train Loss Decreased!! (0.181721-->0.181164)
# Test Loss: 0.180951
#
# Temp Loss: 0.182282
#
# Epoch: 7, Train Loss Decreased!! (0.181164-->0.180965)
# Test Loss: 0.180287
#
# Temp Loss: 0.181700
#
# Epoch: 8, Train Loss Decreased!! (0.180965-->0.180652)
# Test Loss: 0.180250
#
# Temp Loss: 0.181514
#
# Epoch: 9, Train Loss Decreased!! (0.180652-->0.180605)
# Test Loss: 0.179749
#
# Temp Loss: 0.181050
#
# Epoch: 10, Train Loss Decreased!! (0.180605-->0.180086)
# Test Loss: 0.179798
#
# Temp Loss: 0.181009
#
# Epoch: 11, Train Loss Decreased!! (0.180086-->0.179778)
# Test Loss: 0.178892
#
# Temp Loss: 0.180603
#
# Epoch: 12, Train Loss Decreased!! (0.179778-->0.179120)
# Test Loss: 0.178995
#
# Temp Loss: 0.180620
#
# Epoch: 13, Train Loss Decreased!! (0.179120-->0.178584)
# Test Loss: 0.177130
#
# Temp Loss: 0.179930
#
# Epoch: 14, Train Loss Decreased!! (0.178584-->0.177165)
# Test Loss: 0.177013
#
# Temp Loss: 0.179990
#
# Epoch: 15, Train Loss Decreased!! (0.177165-->0.176141)
# Test Loss: 0.174221
#
# Temp Loss: 0.180215
#
# Epoch: 16, Train Loss Decreased!! (0.176141-->0.173985)
# Test Loss: 0.174082
#
# Temp Loss: 0.180145
#
# Epoch: 17, Train Loss Decreased!! (0.173985-->0.172345)
# Test Loss: 0.170298
#
# Temp Loss: 0.183242
#
# Epoch: 18, Train Loss Decreased!! (0.172345-->0.169981)
# Test Loss: 0.170462
#
# Temp Loss: 0.183145
#
# Epoch: 19, Train Loss Decreased!! (0.169981-->0.168479)
# Test Loss: 0.166886
#
# Temp Loss: 0.184344
#
# Epoch: 20, Train Loss Decreased!! (0.168479-->0.166325)
# Test Loss: 0.167029
#
# Temp Loss: 0.184093
#
# Epoch: 21, Train Loss Decreased!! (0.166325-->0.165274)
# Test Loss: 0.164325
#
# Temp Loss: 0.184834
#
# Epoch: 22, Train Loss Decreased!! (0.165274-->0.163834)
# Test Loss: 0.164571
#
# Temp Loss: 0.184976
#
# Epoch: 23, Train Loss Decreased!! (0.163834-->0.162917)
# Test Loss: 0.162043
#
# Temp Loss: 0.186307
#
# Epoch: 24, Train Loss Decreased!! (0.162917-->0.161369)
# Test Loss: 0.162132
#
# Temp Loss: 0.186175
#
# Epoch: 25, Train Loss Decreased!! (0.161369-->0.160243)
# Test Loss: 0.159142
#
# Temp Loss: 0.187570
#
# Epoch: 26, Train Loss Decreased!! (0.160243-->0.158445)
# Test Loss: 0.159346
#
# Temp Loss: 0.187673
#
# Epoch: 27, Train Loss Decreased!! (0.158445-->0.157087)
# Test Loss: 0.155743
#
# Temp Loss: 0.188924
#
# Epoch: 28, Train Loss Decreased!! (0.157087-->0.154637)
# Test Loss: 0.155448
#
# Temp Loss: 0.188472
#
# Epoch: 29, Train Loss Decreased!! (0.154637-->0.152916)
# Test Loss: 0.150978
#
# Temp Loss: 0.190053
#
# Epoch: 30, Train Loss Decreased!! (0.152916-->0.150263)
# Test Loss: 0.151464
#
# Temp Loss: 0.190202
#
# Epoch: 31, Train Loss Decreased!! (0.150263-->0.148413)
# Test Loss: 0.146196
#
# Temp Loss: 0.192191
#
# Epoch: 32, Train Loss Decreased!! (0.148413-->0.145359)
# Test Loss: 0.146585
#
# Temp Loss: 0.192075
#
# Epoch: 33, Train Loss Decreased!! (0.145359-->0.143297)
# Test Loss: 0.140912
#
# Temp Loss: 0.192112
#
# Epoch: 34, Train Loss Decreased!! (0.143297-->0.139935)
# Test Loss: 0.141255
#
# Temp Loss: 0.192055
#
# Epoch: 35, Train Loss Decreased!! (0.139935-->0.137805)
# Test Loss: 0.134653
#
# Temp Loss: 0.192899
#
# Epoch: 36, Train Loss Decreased!! (0.137805-->0.134377)
# Test Loss: 0.135296
#
# Temp Loss: 0.193047
#
# Epoch: 37, Train Loss Decreased!! (0.134377-->0.131954)
# Test Loss: 0.128886
#
# Temp Loss: 0.193726
#
# Epoch: 38, Train Loss Decreased!! (0.131954-->0.128321)
# Test Loss: 0.129379
#
# Temp Loss: 0.194260
#
# Epoch: 39, Train Loss Decreased!! (0.128321-->0.125428)
# Test Loss: 0.122279
#
# Temp Loss: 0.196396
#
# Epoch: 40, Train Loss Decreased!! (0.125428-->0.121766)
# Test Loss: 0.122976
#
# Temp Loss: 0.196958
#
# Epoch: 41, Train Loss Decreased!! (0.121766-->0.118843)
# Test Loss: 0.115524
#
# Temp Loss: 0.196938
#
# Epoch: 42, Train Loss Decreased!! (0.118843-->0.114687)
# Test Loss: 0.116046
#
# Temp Loss: 0.197446
#
# Epoch: 43, Train Loss Decreased!! (0.114687-->0.111758)
# Test Loss: 0.108654
#
# Temp Loss: 0.199785
#
# Epoch: 44, Train Loss Decreased!! (0.111758-->0.107508)
# Test Loss: 0.109002
#
# Temp Loss: 0.200392
#
# Epoch: 45, Train Loss Decreased!! (0.107508-->0.104254)
# Test Loss: 0.100699
#
# Temp Loss: 0.200425
#
# Epoch: 46, Train Loss Decreased!! (0.104254-->0.099585)
# Test Loss: 0.101267
#
# Temp Loss: 0.200823
#
# Epoch: 47, Train Loss Decreased!! (0.099585-->0.095828)
# Test Loss: 0.092245
#
# Temp Loss: 0.202112
#
# Epoch: 48, Train Loss Decreased!! (0.095828-->0.090922)
# Test Loss: 0.092814
#
# Temp Loss: 0.202166
#
# Epoch: 49, Train Loss Decreased!! (0.090922-->0.087017)
# Test Loss: 0.083365
#
# Temp Loss: 0.204316
#
# Epoch: 50, Train Loss Decreased!! (0.087017-->0.081877)
# Test Loss: 0.083826
#
# Temp Loss: 0.204634
#
# Epoch: 51, Train Loss Decreased!! (0.081877-->0.077802)
# Test Loss: 0.073901
#
# Temp Loss: 0.206407
#
# Epoch: 52, Train Loss Decreased!! (0.077802-->0.072558)
# Test Loss: 0.074577
#
# Temp Loss: 0.206442
#
# Epoch: 53, Train Loss Decreased!! (0.072558-->0.068487)
# Test Loss: 0.064929
#
# Temp Loss: 0.207588
#
# Epoch: 54, Train Loss Decreased!! (0.068487-->0.063427)
# Test Loss: 0.065445
#
# Temp Loss: 0.207596
#
# Epoch: 55, Train Loss Decreased!! (0.063427-->0.059374)
# Test Loss: 0.055586
#
# Temp Loss: 0.211323
#
# Epoch: 56, Train Loss Decreased!! (0.059374-->0.054292)
# Test Loss: 0.056122
#
# Temp Loss: 0.210909
#
# Epoch: 57, Train Loss Decreased!! (0.054292-->0.050581)
# Test Loss: 0.047071
#
# Temp Loss: 0.214418
#
# Epoch: 58, Train Loss Decreased!! (0.050581-->0.045979)
# Test Loss: 0.047707
#
# Temp Loss: 0.214010
#
# Epoch: 59, Train Loss Decreased!! (0.045979-->0.042438)
# Test Loss: 0.039167
#
# Temp Loss: 0.217180
#
# Epoch: 60, Train Loss Decreased!! (0.042438-->0.038231)
# Test Loss: 0.039979
#
# Temp Loss: 0.216414
#
# Epoch: 61, Train Loss Decreased!! (0.038231-->0.035260)
# Test Loss: 0.032579
#
# Temp Loss: 0.220692
#
# Epoch: 62, Train Loss Decreased!! (0.035260-->0.031562)
# Test Loss: 0.033025
#
# Temp Loss: 0.220270
#
# Epoch: 63, Train Loss Decreased!! (0.031562-->0.028994)
# Test Loss: 0.026833
#
# Temp Loss: 0.223140
#
# Epoch: 64, Train Loss Decreased!! (0.028994-->0.025910)
# Test Loss: 0.027329
#
# Temp Loss: 0.222603
#
# Epoch: 65, Train Loss Decreased!! (0.025910-->0.023891)
# Test Loss: 0.022160
#
# Temp Loss: 0.226656
#
# Epoch: 66, Train Loss Decreased!! (0.023891-->0.021309)
# Test Loss: 0.022556
#
# Temp Loss: 0.226158
#
# Epoch: 67, Train Loss Decreased!! (0.021309-->0.019551)
# Test Loss: 0.018183
#
# Temp Loss: 0.228501
#
# Epoch: 68, Train Loss Decreased!! (0.019551-->0.017386)
# Test Loss: 0.018772
#
# Temp Loss: 0.228027
#
# Epoch: 69, Train Loss Decreased!! (0.017386-->0.016010)
# Test Loss: 0.015092
#
# Temp Loss: 0.231277
#
# Epoch: 70, Train Loss Decreased!! (0.016010-->0.014412)
# Test Loss: 0.015569
#
# Temp Loss: 0.230866
#
# Epoch: 71, Train Loss Decreased!! (0.014412-->0.013180)
# Test Loss: 0.012505
#
# Temp Loss: 0.233613
#
# Epoch: 72, Train Loss Decreased!! (0.013180-->0.011949)
# Test Loss: 0.013299
#
# Temp Loss: 0.233192
#
# Epoch: 73, Train Loss Decreased!! (0.011949-->0.011092)
# Test Loss: 0.010587
#
# Temp Loss: 0.235242
#
# Epoch: 74, Train Loss Decreased!! (0.011092-->0.010184)
# Test Loss: 0.011303
#
# Temp Loss: 0.234573
#
# Epoch: 75, Train Loss Decreased!! (0.010184-->0.009374)
# Test Loss: 0.009017
#
# Temp Loss: 0.236716
#
# Epoch: 76, Train Loss Decreased!! (0.009374-->0.008707)
# Test Loss: 0.009965
#
# Temp Loss: 0.236112
#
# Epoch: 77, Train Loss Decreased!! (0.008707-->0.008018)
# Test Loss: 0.007676
#
# Temp Loss: 0.237509
#
# Epoch: 78, Train Loss Decreased!! (0.008018-->0.007471)
# Test Loss: 0.008716
#
# Temp Loss: 0.236917
#
# Epoch: 79, Train Loss Decreased!! (0.007471-->0.006940)
# Test Loss: 0.006762
#
# Temp Loss: 0.238044
#
# Epoch: 80, Train Loss Decreased!! (0.006940-->0.006445)
# Test Loss: 0.007684
#
# Temp Loss: 0.237232
#
# Epoch: 81, Train Loss Decreased!! (0.006445-->0.006091)
# Test Loss: 0.005891
#
# Temp Loss: 0.239421
#
# Epoch: 82, Train Loss Decreased!! (0.006091-->0.005765)
# Test Loss: 0.006883
#
# Temp Loss: 0.238522
#
# Epoch: 83, Train Loss Decreased!! (0.005765-->0.005425)
# Test Loss: 0.005179
#
# Temp Loss: 0.239595
#
# Epoch: 84, Train Loss Decreased!! (0.005425-->0.005026)
# Test Loss: 0.006018
#
# Temp Loss: 0.238677
#
# Epoch: 85, Train Loss Decreased!! (0.005026-->0.004737)
# Test Loss: 0.004532
#
# Temp Loss: 0.240100
#
# Epoch: 86, Train Loss Decreased!! (0.004737-->0.004417)
# Test Loss: 0.005498
#
# Temp Loss: 0.239161
#
# Epoch: 87, Train Loss Decreased!! (0.004417-->0.004338)
# Test Loss: 0.004073
#
# Temp Loss: 0.240725
#
# Epoch: 88, Train Loss Decreased!! (0.004338-->0.003939)
# Test Loss: 0.004831
#
# Temp Loss: 0.239588
#
# Epoch: 89, Train Loss Decreased!! (0.003939-->0.003770)
# Test Loss: 0.003648
#
# Temp Loss: 0.241598
#
# Epoch: 90, Train Loss Decreased!! (0.003770-->0.003491)
# Test Loss: 0.004233
#
# Temp Loss: 0.240508
#
# Epoch: 91, Train Loss Decreased!! (0.003491-->0.003316)
# Test Loss: 0.003150
#
# Temp Loss: 0.241280
#
# Epoch: 92, Train Loss Decreased!! (0.003316-->0.003166)
# Test Loss: 0.004077
#
# Temp Loss: 0.240074
#
# Epoch: 93, Train Loss Decreased!! (0.003166-->0.003032)
# Test Loss: 0.002844
#
# Temp Loss: 0.242186
#
# Epoch: 94, Train Loss Decreased!! (0.003032-->0.002830)
# Test Loss: 0.003516
#
# Temp Loss: 0.240932
#
# Epoch: 95, Train Loss Decreased!! (0.002830-->0.002739)
# Test Loss: 0.002560
#
# Temp Loss: 0.241770
#
# Epoch: 96, Train Loss Decreased!! (0.002739-->0.002601)
# Test Loss: 0.003439
#
# Temp Loss: 0.240517
#
# Epoch: 97, Train Loss Decreased!! (0.002601-->0.002526)
# Test Loss: 0.002335
#
# Temp Loss: 0.242226
#
# Epoch: 98, Train Loss Decreased!! (0.002526-->0.002395)
# Test Loss: 0.003176
#
# Temp Loss: 0.240913
#
# Epoch: 99, Train Loss Decreased!! (0.002395-->0.002339)
# Test Loss: 0.002108
#
# Temp Loss: 0.242627
#  20%|██        | 1/5 [00:53<03:35, 53.99s/it]
# Epoch: 100, Train Loss Decreased!! (0.002339-->0.002212)
# Test Loss: 0.003039
#
# Temp Loss: 0.241046
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.221013)
# Test Loss: 0.191559
#
# Temp Loss: 0.191048
#
# Epoch: 2, Train Loss Decreased!! (0.221013-->0.189900)
# Test Loss: 0.190873
#
# Temp Loss: 0.190514
#
# Epoch: 3, Train Loss Decreased!! (0.189900-->0.182640)
# Test Loss: 0.181196
#
# Temp Loss: 0.180858
#
# Epoch: 4, Train Loss Decreased!! (0.182640-->0.179982)
# Test Loss: 0.181115
#
# Temp Loss: 0.180606
#
# Epoch: 5, Train Loss Decreased!! (0.179982-->0.179468)
# Test Loss: 0.179939
#
# Temp Loss: 0.179708
#
# Epoch: 6, Train Loss Decreased!! (0.179468-->0.178910)
# Test Loss: 0.180000
#
# Temp Loss: 0.179660
#
# Epoch: 7, Train Loss Decreased!! (0.178910-->0.178798)
# Test Loss: 0.179694
#
# Temp Loss: 0.179482
#
# Epoch: 8, Train Loss Decreased!! (0.178798-->0.178492)
# Test Loss: 0.179713
#
# Temp Loss: 0.179486
#
# Epoch: 9, Train Loss Decreased!! (0.178492-->0.178300)
# Test Loss: 0.179056
#
# Temp Loss: 0.179009
#
# Epoch: 10, Train Loss Decreased!! (0.178300-->0.177867)
# Test Loss: 0.178995
#
# Temp Loss: 0.179010
#
# Epoch: 11, Train Loss Decreased!! (0.177867-->0.177304)
# Test Loss: 0.177552
#
# Temp Loss: 0.178821
#
# Epoch: 12, Train Loss Decreased!! (0.177304-->0.176322)
# Test Loss: 0.177457
#
# Temp Loss: 0.178891
#
# Epoch: 13, Train Loss Decreased!! (0.176322-->0.175174)
# Test Loss: 0.174903
#
# Temp Loss: 0.179139
#
# Epoch: 14, Train Loss Decreased!! (0.175174-->0.173462)
# Test Loss: 0.174874
#
# Temp Loss: 0.179034
#
# Epoch: 15, Train Loss Decreased!! (0.173462-->0.172196)
# Test Loss: 0.171795
#
# Temp Loss: 0.182867
#
# Epoch: 16, Train Loss Decreased!! (0.172196-->0.170232)
# Test Loss: 0.171735
#
# Temp Loss: 0.182674
#
# Epoch: 17, Train Loss Decreased!! (0.170232-->0.168907)
# Test Loss: 0.168908
#
# Temp Loss: 0.186053
#
# Epoch: 18, Train Loss Decreased!! (0.168907-->0.167073)
# Test Loss: 0.168985
#
# Temp Loss: 0.185628
#
# Epoch: 19, Train Loss Decreased!! (0.167073-->0.165996)
# Test Loss: 0.166527
#
# Temp Loss: 0.188366
#
# Epoch: 20, Train Loss Decreased!! (0.165996-->0.164316)
# Test Loss: 0.166646
#
# Temp Loss: 0.187881
#
# Epoch: 21, Train Loss Decreased!! (0.164316-->0.163540)
# Test Loss: 0.164541
#
# Temp Loss: 0.190120
#
# Epoch: 22, Train Loss Decreased!! (0.163540-->0.161898)
# Test Loss: 0.164464
#
# Temp Loss: 0.189598
#
# Epoch: 23, Train Loss Decreased!! (0.161898-->0.161144)
# Test Loss: 0.162051
#
# Temp Loss: 0.190562
#
# Epoch: 24, Train Loss Decreased!! (0.161144-->0.159287)
# Test Loss: 0.162256
#
# Temp Loss: 0.190267
#
# Epoch: 25, Train Loss Decreased!! (0.159287-->0.158486)
# Test Loss: 0.159870
#
# Temp Loss: 0.191977
#
# Epoch: 26, Train Loss Decreased!! (0.158486-->0.156790)
# Test Loss: 0.159845
#
# Temp Loss: 0.191386
#
# Epoch: 27, Train Loss Decreased!! (0.156790-->0.155641)
# Test Loss: 0.156257
#
# Temp Loss: 0.193040
#
# Epoch: 28, Train Loss Decreased!! (0.155641-->0.153551)
# Test Loss: 0.156967
#
# Temp Loss: 0.192684
#
# Epoch: 29, Train Loss Decreased!! (0.153551-->0.152411)
# Test Loss: 0.152914
#
# Temp Loss: 0.194251
#
# Epoch: 30, Train Loss Decreased!! (0.152411-->0.150093)
# Test Loss: 0.153371
#
# Temp Loss: 0.194124
#
# Epoch: 31, Train Loss Decreased!! (0.150093-->0.148532)
# Test Loss: 0.149286
#
# Temp Loss: 0.195697
#
# Epoch: 32, Train Loss Decreased!! (0.148532-->0.146148)
# Test Loss: 0.149400
#
# Temp Loss: 0.196041
#
# Epoch: 33, Train Loss Decreased!! (0.146148-->0.144088)
# Test Loss: 0.144152
#
# Temp Loss: 0.198357
#
# Epoch: 34, Train Loss Decreased!! (0.144088-->0.140911)
# Test Loss: 0.145002
#
# Temp Loss: 0.198825
#
# Epoch: 35, Train Loss Decreased!! (0.140911-->0.138420)
# Test Loss: 0.138140
#
# Temp Loss: 0.200624
#
# Epoch: 36, Train Loss Decreased!! (0.138420-->0.134962)
# Test Loss: 0.138870
#
# Temp Loss: 0.201172
#
# Epoch: 37, Train Loss Decreased!! (0.134962-->0.132407)
# Test Loss: 0.131709
#
# Temp Loss: 0.202278
#
# Epoch: 38, Train Loss Decreased!! (0.132407-->0.128623)
# Test Loss: 0.132486
#
# Temp Loss: 0.202718
#
# Epoch: 39, Train Loss Decreased!! (0.128623-->0.126289)
# Test Loss: 0.125914
#
# Temp Loss: 0.202622
#
# Epoch: 40, Train Loss Decreased!! (0.126289-->0.122569)
# Test Loss: 0.126631
#
# Temp Loss: 0.203080
#
# Epoch: 41, Train Loss Decreased!! (0.122569-->0.120048)
# Test Loss: 0.120283
#
# Temp Loss: 0.202491
#
# Epoch: 42, Train Loss Decreased!! (0.120048-->0.116365)
# Test Loss: 0.120491
#
# Temp Loss: 0.203308
#
# Epoch: 43, Train Loss Decreased!! (0.116365-->0.113597)
# Test Loss: 0.113309
#
# Temp Loss: 0.203834
#
# Epoch: 44, Train Loss Decreased!! (0.113597-->0.109919)
# Test Loss: 0.113898
#
# Temp Loss: 0.204256
#
# Epoch: 45, Train Loss Decreased!! (0.109919-->0.107203)
# Test Loss: 0.106956
#
# Temp Loss: 0.204455
#
# Epoch: 46, Train Loss Decreased!! (0.107203-->0.103810)
# Test Loss: 0.107497
#
# Temp Loss: 0.204803
#
# Epoch: 47, Train Loss Decreased!! (0.103810-->0.100792)
# Test Loss: 0.100162
#
# Temp Loss: 0.206615
#
# Epoch: 48, Train Loss Decreased!! (0.100792-->0.097224)
# Test Loss: 0.101070
#
# Temp Loss: 0.206836
#
# Epoch: 49, Train Loss Decreased!! (0.097224-->0.094345)
# Test Loss: 0.093828
#
# Temp Loss: 0.207734
#
# Epoch: 50, Train Loss Decreased!! (0.094345-->0.090449)
# Test Loss: 0.094391
#
# Temp Loss: 0.208159
#
# Epoch: 51, Train Loss Decreased!! (0.090449-->0.087820)
# Test Loss: 0.087163
#
# Temp Loss: 0.209295
#
# Epoch: 52, Train Loss Decreased!! (0.087820-->0.083799)
# Test Loss: 0.087560
#
# Temp Loss: 0.209748
#
# Epoch: 53, Train Loss Decreased!! (0.083799-->0.080874)
# Test Loss: 0.079833
#
# Temp Loss: 0.210517
#
# Epoch: 54, Train Loss Decreased!! (0.080874-->0.077207)
# Test Loss: 0.080945
#
# Temp Loss: 0.210851
#
# Epoch: 55, Train Loss Decreased!! (0.077207-->0.074236)
# Test Loss: 0.073319
#
# Temp Loss: 0.213279
#
# Epoch: 56, Train Loss Decreased!! (0.074236-->0.070709)
# Test Loss: 0.074541
#
# Temp Loss: 0.213446
#
# Epoch: 57, Train Loss Decreased!! (0.070709-->0.067723)
# Test Loss: 0.066925
#
# Temp Loss: 0.214191
#
# Epoch: 58, Train Loss Decreased!! (0.067723-->0.064281)
# Test Loss: 0.067871
#
# Temp Loss: 0.214199
#
# Epoch: 59, Train Loss Decreased!! (0.064281-->0.061217)
# Test Loss: 0.060447
#
# Temp Loss: 0.217202
#
# Epoch: 60, Train Loss Decreased!! (0.061217-->0.058059)
# Test Loss: 0.061930
#
# Temp Loss: 0.217268
#
# Epoch: 61, Train Loss Decreased!! (0.058059-->0.054762)
# Test Loss: 0.053689
#
# Temp Loss: 0.218874
#
# Epoch: 62, Train Loss Decreased!! (0.054762-->0.051314)
# Test Loss: 0.054898
#
# Temp Loss: 0.219277
#
# Epoch: 63, Train Loss Decreased!! (0.051314-->0.048290)
# Test Loss: 0.047319
#
# Temp Loss: 0.222267
#
# Epoch: 64, Train Loss Decreased!! (0.048290-->0.045129)
# Test Loss: 0.048824
#
# Temp Loss: 0.222407
#
# Epoch: 65, Train Loss Decreased!! (0.045129-->0.042322)
# Test Loss: 0.041195
#
# Temp Loss: 0.223115
#
# Epoch: 66, Train Loss Decreased!! (0.042322-->0.039478)
# Test Loss: 0.042744
#
# Temp Loss: 0.223126
#
# Epoch: 67, Train Loss Decreased!! (0.039478-->0.036996)
# Test Loss: 0.036116
#
# Temp Loss: 0.225557
#
# Epoch: 68, Train Loss Decreased!! (0.036996-->0.034495)
# Test Loss: 0.037699
#
# Temp Loss: 0.225842
#
# Epoch: 69, Train Loss Decreased!! (0.034495-->0.032124)
# Test Loss: 0.031044
#
# Temp Loss: 0.227262
#
# Epoch: 70, Train Loss Decreased!! (0.032124-->0.029858)
# Test Loss: 0.032907
#
# Temp Loss: 0.227427
#
# Epoch: 71, Train Loss Decreased!! (0.029858-->0.027876)
# Test Loss: 0.026688
#
# Temp Loss: 0.228668
#
# Epoch: 72, Train Loss Decreased!! (0.027876-->0.025630)
# Test Loss: 0.028078
#
# Temp Loss: 0.228797
#
# Epoch: 73, Train Loss Decreased!! (0.025630-->0.023867)
# Test Loss: 0.022962
#
# Temp Loss: 0.229930
#
# Epoch: 74, Train Loss Decreased!! (0.023867-->0.022096)
# Test Loss: 0.024275
#
# Temp Loss: 0.230005
#
# Epoch: 75, Train Loss Decreased!! (0.022096-->0.020559)
# Test Loss: 0.019523
#
# Temp Loss: 0.232034
#
# Epoch: 76, Train Loss Decreased!! (0.020559-->0.018939)
# Test Loss: 0.020870
#
# Temp Loss: 0.232079
#
# Epoch: 77, Train Loss Decreased!! (0.018939-->0.017529)
# Test Loss: 0.016627
#
# Temp Loss: 0.232570
#
# Epoch: 78, Train Loss Decreased!! (0.017529-->0.016157)
# Test Loss: 0.017859
#
# Temp Loss: 0.232377
#
# Epoch: 79, Train Loss Decreased!! (0.016157-->0.014854)
# Test Loss: 0.013678
#
# Temp Loss: 0.233649
#
# Epoch: 80, Train Loss Decreased!! (0.014854-->0.013490)
# Test Loss: 0.015199
#
# Temp Loss: 0.233268
#
# Epoch: 81, Train Loss Decreased!! (0.013490-->0.012587)
# Test Loss: 0.011567
#
# Temp Loss: 0.235173
#
# Epoch: 82, Train Loss Decreased!! (0.012587-->0.011490)
# Test Loss: 0.012941
#
# Temp Loss: 0.234648
#
# Epoch: 83, Train Loss Decreased!! (0.011490-->0.010492)
# Test Loss: 0.009656
#
# Temp Loss: 0.236581
#
# Epoch: 84, Train Loss Decreased!! (0.010492-->0.009503)
# Test Loss: 0.010755
#
# Temp Loss: 0.236258
#
# Epoch: 85, Train Loss Decreased!! (0.009503-->0.008762)
# Test Loss: 0.008045
#
# Temp Loss: 0.237430
#
# Epoch: 86, Train Loss Decreased!! (0.008762-->0.007965)
# Test Loss: 0.009160
#
# Temp Loss: 0.236828
#
# Epoch: 87, Train Loss Decreased!! (0.007965-->0.007350)
# Test Loss: 0.006697
#
# Temp Loss: 0.238292
#
# Epoch: 88, Train Loss Decreased!! (0.007350-->0.006811)
# Test Loss: 0.008206
#
# Temp Loss: 0.237626
#
# Epoch: 89, Train Loss Decreased!! (0.006811-->0.006371)
# Test Loss: 0.005749
#
# Temp Loss: 0.238996
#
# Epoch: 90, Train Loss Decreased!! (0.006371-->0.005917)
# Test Loss: 0.006933
#
# Temp Loss: 0.238476
#
# Epoch: 91, Train Loss Decreased!! (0.005917-->0.005551)
# Test Loss: 0.004844
#
# Temp Loss: 0.240244
#
# Epoch: 92, Train Loss Decreased!! (0.005551-->0.005013)
# Test Loss: 0.006056
#
# Temp Loss: 0.239509
#
# Epoch: 93, Train Loss Decreased!! (0.005013-->0.004759)
# Test Loss: 0.004323
#
# Temp Loss: 0.240820
#
# Epoch: 94, Train Loss Decreased!! (0.004759-->0.004488)
# Test Loss: 0.005534
#
# Temp Loss: 0.240104
#
# Epoch: 95, Train Loss Decreased!! (0.004488-->0.004201)
# Test Loss: 0.003893
#
# Temp Loss: 0.241601
#
# Epoch: 96, Train Loss Decreased!! (0.004201-->0.003989)
# Test Loss: 0.004959
#
# Temp Loss: 0.240771
#
# Epoch: 97, Train Loss Decreased!! (0.003989-->0.003714)
# Test Loss: 0.003409
#
# Temp Loss: 0.242006
#
# Epoch: 98, Train Loss Decreased!! (0.003714-->0.003563)
# Test Loss: 0.004489
#
# Temp Loss: 0.241099
#
# Epoch: 99, Train Loss Decreased!! (0.003563-->0.003347)
# Test Loss: 0.003120
#
# Temp Loss: 0.241836
#  40%|████      | 2/5 [01:45<02:36, 52.33s/it]
# Epoch: 100, Train Loss Decreased!! (0.003347-->0.003316)
# Test Loss: 0.004088
#
# Temp Loss: 0.241012
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.249458)
# Test Loss: 0.210751
#
# Temp Loss: 0.212189
#
# Epoch: 2, Train Loss Decreased!! (0.249458-->0.210546)
# Test Loss: 0.210002
#
# Temp Loss: 0.211577
#
# Epoch: 3, Train Loss Decreased!! (0.210546-->0.198422)
# Test Loss: 0.192767
#
# Temp Loss: 0.193622
#
# Epoch: 4, Train Loss Decreased!! (0.198422-->0.193065)
# Test Loss: 0.192383
#
# Temp Loss: 0.193490
#
# Epoch: 5, Train Loss Decreased!! (0.193065-->0.192621)
# Test Loss: 0.191560
#
# Temp Loss: 0.192581
#
# Epoch: 6, Train Loss Decreased!! (0.192621-->0.192008)
# Test Loss: 0.191508
#
# Temp Loss: 0.192580
#
# Epoch: 7, Train Loss Decreased!! (0.192008-->0.191711)
# Test Loss: 0.190390
#
# Temp Loss: 0.192420
#
# Epoch: 8, Train Loss Decreased!! (0.191711-->0.190949)
# Test Loss: 0.190607
#
# Temp Loss: 0.192443
#
# Epoch: 9, Train Loss Decreased!! (0.190949-->0.189872)
# Test Loss: 0.187523
#
# Temp Loss: 0.194762
#
# Epoch: 10, Train Loss Decreased!! (0.189872-->0.188124)
# Test Loss: 0.187522
#
# Temp Loss: 0.194752
#
# Epoch: 11, Train Loss Decreased!! (0.188124-->0.186357)
# Test Loss: 0.183393
#
# Temp Loss: 0.201192
#
# Epoch: 12, Train Loss Decreased!! (0.186357-->0.183914)
# Test Loss: 0.183671
#
# Temp Loss: 0.200761
#
# Epoch: 13, Train Loss Decreased!! (0.183914-->0.182304)
# Test Loss: 0.180596
#
# Temp Loss: 0.205586
#
# Epoch: 14, Train Loss Decreased!! (0.182304-->0.180694)
# Test Loss: 0.180685
#
# Temp Loss: 0.204678
#
# Epoch: 15, Train Loss Decreased!! (0.180694-->0.179863)
# Test Loss: 0.178798
#
# Temp Loss: 0.206399
#
# Epoch: 16, Train Loss Decreased!! (0.179863-->0.178299)
# Test Loss: 0.178910
#
# Temp Loss: 0.205523
#
# Epoch: 17, Train Loss Decreased!! (0.178299-->0.177026)
# Test Loss: 0.176143
#
# Temp Loss: 0.209386
#
# Epoch: 18, Train Loss Decreased!! (0.177026-->0.175135)
# Test Loss: 0.176099
#
# Temp Loss: 0.208374
#
# Epoch: 19, Train Loss Decreased!! (0.175135-->0.173968)
# Test Loss: 0.172717
#
# Temp Loss: 0.212709
#
# Epoch: 20, Train Loss Decreased!! (0.173968-->0.171688)
# Test Loss: 0.172934
#
# Temp Loss: 0.211933
#
# Epoch: 21, Train Loss Decreased!! (0.171688-->0.170194)
# Test Loss: 0.169600
#
# Temp Loss: 0.215885
#
# Epoch: 22, Train Loss Decreased!! (0.170194-->0.168131)
# Test Loss: 0.169995
#
# Temp Loss: 0.214812
#
# Epoch: 23, Train Loss Decreased!! (0.168131-->0.166751)
# Test Loss: 0.166293
#
# Temp Loss: 0.218044
#
# Epoch: 24, Train Loss Decreased!! (0.166751-->0.164557)
# Test Loss: 0.166553
#
# Temp Loss: 0.216977
#
# Epoch: 25, Train Loss Decreased!! (0.164557-->0.163169)
# Test Loss: 0.162818
#
# Temp Loss: 0.221176
#
# Epoch: 26, Train Loss Decreased!! (0.163169-->0.161067)
# Test Loss: 0.163179
#
# Temp Loss: 0.220179
#
# Epoch: 27, Train Loss Decreased!! (0.161067-->0.159794)
# Test Loss: 0.159257
#
# Temp Loss: 0.219519
#
# Epoch: 28, Train Loss Decreased!! (0.159794-->0.157619)
# Test Loss: 0.159382
#
# Temp Loss: 0.218727
#
# Epoch: 29, Train Loss Decreased!! (0.157619-->0.155786)
# Test Loss: 0.154760
#
# Temp Loss: 0.221035
#
# Epoch: 30, Train Loss Decreased!! (0.155786-->0.153583)
# Test Loss: 0.155854
#
# Temp Loss: 0.220705
#
# Epoch: 31, Train Loss Decreased!! (0.153583-->0.151669)
# Test Loss: 0.150033
#
# Temp Loss: 0.222962
#
# Epoch: 32, Train Loss Decreased!! (0.151669-->0.149165)
# Test Loss: 0.151364
#
# Temp Loss: 0.222528
#
# Epoch: 33, Train Loss Decreased!! (0.149165-->0.146924)
# Test Loss: 0.145160
#
# Temp Loss: 0.224396
#
# Epoch: 34, Train Loss Decreased!! (0.146924-->0.144057)
# Test Loss: 0.146345
#
# Temp Loss: 0.224474
#
# Epoch: 35, Train Loss Decreased!! (0.144057-->0.141691)
# Test Loss: 0.139623
#
# Temp Loss: 0.224545
#
# Epoch: 36, Train Loss Decreased!! (0.141691-->0.138895)
# Test Loss: 0.141856
#
# Temp Loss: 0.224787
#
# Epoch: 37, Train Loss Decreased!! (0.138895-->0.136513)
# Test Loss: 0.133784
#
# Temp Loss: 0.227841
#
# Epoch: 38, Train Loss Decreased!! (0.136513-->0.133767)
# Test Loss: 0.136764
#
# Temp Loss: 0.228197
#
# Epoch: 39, Train Loss Decreased!! (0.133767-->0.131259)
# Test Loss: 0.128572
#
# Temp Loss: 0.229616
#
# Epoch: 40, Train Loss Decreased!! (0.131259-->0.128373)
# Test Loss: 0.131366
#
# Temp Loss: 0.229677
#
# Epoch: 41, Train Loss Decreased!! (0.128373-->0.125860)
# Test Loss: 0.122993
#
# Temp Loss: 0.232904
#
# Epoch: 42, Train Loss Decreased!! (0.125860-->0.122133)
# Test Loss: 0.124636
#
# Temp Loss: 0.232013
#
# Epoch: 43, Train Loss Decreased!! (0.122133-->0.119611)
# Test Loss: 0.116677
#
# Temp Loss: 0.233764
#
# Epoch: 44, Train Loss Decreased!! (0.119611-->0.116085)
# Test Loss: 0.118828
#
# Temp Loss: 0.233421
#
# Epoch: 45, Train Loss Decreased!! (0.116085-->0.113243)
# Test Loss: 0.110251
#
# Temp Loss: 0.233408
#
# Epoch: 46, Train Loss Decreased!! (0.113243-->0.109840)
# Test Loss: 0.112992
#
# Temp Loss: 0.232668
#
# Epoch: 47, Train Loss Decreased!! (0.109840-->0.106510)
# Test Loss: 0.103006
#
# Temp Loss: 0.234546
#
# Epoch: 48, Train Loss Decreased!! (0.106510-->0.102586)
# Test Loss: 0.106259
#
# Temp Loss: 0.233727
#
# Epoch: 49, Train Loss Decreased!! (0.102586-->0.099299)
# Test Loss: 0.095660
#
# Temp Loss: 0.237988
#
# Epoch: 50, Train Loss Decreased!! (0.099299-->0.095117)
# Test Loss: 0.098648
#
# Temp Loss: 0.237495
#
# Epoch: 51, Train Loss Decreased!! (0.095117-->0.091672)
# Test Loss: 0.088288
#
# Temp Loss: 0.239247
#
# Epoch: 52, Train Loss Decreased!! (0.091672-->0.087394)
# Test Loss: 0.091120
#
# Temp Loss: 0.238776
#
# Epoch: 53, Train Loss Decreased!! (0.087394-->0.084176)
# Test Loss: 0.080828
#
# Temp Loss: 0.242972
#
# Epoch: 54, Train Loss Decreased!! (0.084176-->0.080252)
# Test Loss: 0.084157
#
# Temp Loss: 0.242116
#
# Epoch: 55, Train Loss Decreased!! (0.080252-->0.076590)
# Test Loss: 0.073316
#
# Temp Loss: 0.243130
#
# Epoch: 56, Train Loss Decreased!! (0.076590-->0.072898)
# Test Loss: 0.077015
#
# Temp Loss: 0.242257
#
# Epoch: 57, Train Loss Decreased!! (0.072898-->0.069505)
# Test Loss: 0.066314
#
# Temp Loss: 0.244813
#
# Epoch: 58, Train Loss Decreased!! (0.069505-->0.065757)
# Test Loss: 0.069774
#
# Temp Loss: 0.243852
#
# Epoch: 59, Train Loss Decreased!! (0.065757-->0.062562)
# Test Loss: 0.059743
#
# Temp Loss: 0.245530
#
# Epoch: 60, Train Loss Decreased!! (0.062562-->0.059458)
# Test Loss: 0.063829
#
# Temp Loss: 0.244467
#
# Epoch: 61, Train Loss Decreased!! (0.059458-->0.056441)
# Test Loss: 0.053645
#
# Temp Loss: 0.247009
#
# Epoch: 62, Train Loss Decreased!! (0.056441-->0.053210)
# Test Loss: 0.057429
#
# Temp Loss: 0.245899
#
# Epoch: 63, Train Loss Decreased!! (0.053210-->0.050265)
# Test Loss: 0.047487
#
# Temp Loss: 0.247720
#
# Epoch: 64, Train Loss Decreased!! (0.050265-->0.047061)
# Test Loss: 0.049957
#
# Temp Loss: 0.246882
#
# Epoch: 65, Train Loss Decreased!! (0.047061-->0.044353)
# Test Loss: 0.042011
#
# Temp Loss: 0.249524
#
# Epoch: 66, Train Loss Decreased!! (0.044353-->0.042033)
# Test Loss: 0.045370
#
# Temp Loss: 0.248473
#
# Epoch: 67, Train Loss Decreased!! (0.042033-->0.039432)
# Test Loss: 0.036804
#
# Temp Loss: 0.251778
#
# Epoch: 68, Train Loss Decreased!! (0.039432-->0.036765)
# Test Loss: 0.039903
#
# Temp Loss: 0.251211
#
# Epoch: 69, Train Loss Decreased!! (0.036765-->0.034751)
# Test Loss: 0.032736
#
# Temp Loss: 0.252602
#
# Epoch: 70, Train Loss Decreased!! (0.034751-->0.032944)
# Test Loss: 0.036018
#
# Temp Loss: 0.252131
#
# Epoch: 71, Train Loss Decreased!! (0.032944-->0.030983)
# Test Loss: 0.029162
#
# Temp Loss: 0.255283
#
# Epoch: 72, Train Loss Decreased!! (0.030983-->0.029821)
# Test Loss: 0.033168
#
# Temp Loss: 0.255220
#
# Epoch: 73, Train Loss Decreased!! (0.029821-->0.027353)
# Test Loss: 0.024958
#
# Temp Loss: 0.257092
#
# Epoch: 74, Train Loss Decreased!! (0.027353-->0.025239)
# Test Loss: 0.028038
#
# Temp Loss: 0.256910
#
# Epoch: 75, Train Loss Decreased!! (0.025239-->0.023597)
# Test Loss: 0.021566
#
# Temp Loss: 0.257816
#
# Epoch: 76, Train Loss Decreased!! (0.023597-->0.022169)
# Test Loss: 0.025054
#
# Temp Loss: 0.256970
#
# Epoch: 77, Train Loss Decreased!! (0.022169-->0.020599)
# Test Loss: 0.018890
#
# Temp Loss: 0.259224
#
# Epoch: 78, Train Loss Decreased!! (0.020599-->0.019364)
# Test Loss: 0.022267
#
# Temp Loss: 0.259005
#
# Epoch: 79, Train Loss Decreased!! (0.019364-->0.017951)
# Test Loss: 0.016380
#
# Temp Loss: 0.261642
#
# Epoch: 80, Train Loss Decreased!! (0.017951-->0.017076)
# Test Loss: 0.020211
#
# Temp Loss: 0.260684
#
# Epoch: 81, Train Loss Decreased!! (0.017076-->0.015764)
# Test Loss: 0.013971
#
# Temp Loss: 0.261789
#
# Epoch: 82, Train Loss Decreased!! (0.015764-->0.014172)
# Test Loss: 0.016467
#
# Temp Loss: 0.261234
#
# Epoch: 83, Train Loss Decreased!! (0.014172-->0.013139)
# Test Loss: 0.011884
#
# Temp Loss: 0.264407
#
# Epoch: 84, Train Loss Decreased!! (0.013139-->0.011848)
# Test Loss: 0.013918
#
# Temp Loss: 0.263470
#
# Epoch: 85, Train Loss Decreased!! (0.011848-->0.011151)
# Test Loss: 0.009918
#
# Temp Loss: 0.265413
#
# Epoch: 86, Train Loss Decreased!! (0.011151-->0.010237)
# Test Loss: 0.012804
#
# Temp Loss: 0.264150
#
# Epoch: 87, Train Loss Decreased!! (0.010237-->0.009598)
# Test Loss: 0.008491
#
# Temp Loss: 0.266693
#
# Epoch: 88, Train Loss Decreased!! (0.009598-->0.008715)
# Test Loss: 0.011036
#
# Temp Loss: 0.265731
#
# Epoch: 89, Train Loss Decreased!! (0.008715-->0.008452)
# Test Loss: 0.007406
#
# Temp Loss: 0.268749
#
# Epoch: 90, Train Loss Decreased!! (0.008452-->0.007742)
# Test Loss: 0.010037
#
# Temp Loss: 0.266788
#
# Epoch: 91, Train Loss Decreased!! (0.007742-->0.007379)
# Test Loss: 0.006550
#
# Temp Loss: 0.268954
#
# Epoch: 92, Train Loss Decreased!! (0.007379-->0.006791)
# Test Loss: 0.008818
#
# Temp Loss: 0.267627
#
# Epoch: 93, Train Loss Decreased!! (0.006791-->0.006499)
# Test Loss: 0.005586
#
# Temp Loss: 0.271037
#
# Epoch: 94, Train Loss Decreased!! (0.006499-->0.006417)
# Test Loss: 0.009368
#
# Temp Loss: 0.268727
#
# Epoch: 95, Train Loss Decreased!! (0.006417-->0.006215)
# Test Loss: 0.005078
#
# Temp Loss: 0.271156
#
# Epoch: 96, Train Loss Decreased!! (0.006215-->0.005701)
# Test Loss: 0.008290
#
# Temp Loss: 0.269051
#
# Epoch: 97, Train Loss Decreased!! (0.005701-->0.005461)
# Test Loss: 0.004783
#
# Temp Loss: 0.272592
#
# Test Loss: 0.009360
#
# Temp Loss: 0.269349
#
# Test Loss: 0.005009
#
# Temp Loss: 0.273020
#  60%|██████    | 3/5 [02:37<01:44, 52.48s/it]
# Test Loss: 0.009511
#
# Temp Loss: 0.269625
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.220393)
# Test Loss: 0.189166
#
# Temp Loss: 0.189464
#
# Epoch: 2, Train Loss Decreased!! (0.220393-->0.190298)
# Test Loss: 0.188643
#
# Temp Loss: 0.188881
#
# Epoch: 3, Train Loss Decreased!! (0.190298-->0.182585)
# Test Loss: 0.178729
#
# Temp Loss: 0.178642
#
# Epoch: 4, Train Loss Decreased!! (0.182585-->0.179801)
# Test Loss: 0.178657
#
# Temp Loss: 0.178500
#
# Epoch: 5, Train Loss Decreased!! (0.179801-->0.179391)
# Test Loss: 0.177975
#
# Temp Loss: 0.177957
#
# Epoch: 6, Train Loss Decreased!! (0.179391-->0.178924)
# Test Loss: 0.177832
#
# Temp Loss: 0.177862
#
# Epoch: 7, Train Loss Decreased!! (0.178924-->0.178741)
# Test Loss: 0.177110
#
# Temp Loss: 0.177252
#
# Epoch: 8, Train Loss Decreased!! (0.178741-->0.178384)
# Test Loss: 0.177169
#
# Temp Loss: 0.177250
#
# Epoch: 9, Train Loss Decreased!! (0.178384-->0.178043)
# Test Loss: 0.176247
#
# Temp Loss: 0.177162
#
# Epoch: 10, Train Loss Decreased!! (0.178043-->0.177377)
# Test Loss: 0.176268
#
# Temp Loss: 0.176848
#
# Epoch: 11, Train Loss Decreased!! (0.177377-->0.176502)
# Test Loss: 0.174020
#
# Temp Loss: 0.178238
#
# Epoch: 12, Train Loss Decreased!! (0.176502-->0.175359)
# Test Loss: 0.173989
#
# Temp Loss: 0.177998
#
# Epoch: 13, Train Loss Decreased!! (0.175359-->0.174441)
# Test Loss: 0.171911
#
# Temp Loss: 0.178915
#
# Epoch: 14, Train Loss Decreased!! (0.174441-->0.173209)
# Test Loss: 0.172082
#
# Temp Loss: 0.178844
#
# Epoch: 15, Train Loss Decreased!! (0.173209-->0.172383)
# Test Loss: 0.169995
#
# Temp Loss: 0.180499
#
# Epoch: 16, Train Loss Decreased!! (0.172383-->0.171013)
# Test Loss: 0.170134
#
# Temp Loss: 0.180053
#
# Epoch: 17, Train Loss Decreased!! (0.171013-->0.170206)
# Test Loss: 0.167784
#
# Temp Loss: 0.181860
#
# Epoch: 18, Train Loss Decreased!! (0.170206-->0.168752)
# Test Loss: 0.167736
#
# Temp Loss: 0.181375
#
# Epoch: 19, Train Loss Decreased!! (0.168752-->0.167797)
# Test Loss: 0.165447
#
# Temp Loss: 0.183397
#
# Epoch: 20, Train Loss Decreased!! (0.167797-->0.166368)
# Test Loss: 0.165520
#
# Temp Loss: 0.183089
#
# Epoch: 21, Train Loss Decreased!! (0.166368-->0.165676)
# Test Loss: 0.163522
#
# Temp Loss: 0.184783
#
# Epoch: 22, Train Loss Decreased!! (0.165676-->0.164615)
# Test Loss: 0.163829
#
# Temp Loss: 0.184819
#
# Epoch: 23, Train Loss Decreased!! (0.164615-->0.163676)
# Test Loss: 0.161249
#
# Temp Loss: 0.186447
#
# Epoch: 24, Train Loss Decreased!! (0.163676-->0.162131)
# Test Loss: 0.161326
#
# Temp Loss: 0.186300
#
# Epoch: 25, Train Loss Decreased!! (0.162131-->0.161302)
# Test Loss: 0.158883
#
# Temp Loss: 0.187357
#
# Epoch: 26, Train Loss Decreased!! (0.161302-->0.159679)
# Test Loss: 0.158897
#
# Temp Loss: 0.187250
#
# Epoch: 27, Train Loss Decreased!! (0.159679-->0.158675)
# Test Loss: 0.155756
#
# Temp Loss: 0.188752
#
# Epoch: 28, Train Loss Decreased!! (0.158675-->0.156488)
# Test Loss: 0.155897
#
# Temp Loss: 0.188546
#
# Epoch: 29, Train Loss Decreased!! (0.156488-->0.155060)
# Test Loss: 0.151492
#
# Temp Loss: 0.190064
#
# Epoch: 30, Train Loss Decreased!! (0.155060-->0.152434)
# Test Loss: 0.151883
#
# Temp Loss: 0.189668
#
# Epoch: 31, Train Loss Decreased!! (0.152434-->0.150682)
# Test Loss: 0.146423
#
# Temp Loss: 0.190956
#
# Epoch: 32, Train Loss Decreased!! (0.150682-->0.147705)
# Test Loss: 0.147074
#
# Temp Loss: 0.190857
#
# Epoch: 33, Train Loss Decreased!! (0.147705-->0.145583)
# Test Loss: 0.141514
#
# Temp Loss: 0.192684
#
# Epoch: 34, Train Loss Decreased!! (0.145583-->0.142568)
# Test Loss: 0.142282
#
# Temp Loss: 0.192909
#
# Epoch: 35, Train Loss Decreased!! (0.142568-->0.140163)
# Test Loss: 0.135986
#
# Temp Loss: 0.194983
#
# Epoch: 36, Train Loss Decreased!! (0.140163-->0.136852)
# Test Loss: 0.137040
#
# Temp Loss: 0.195143
#
# Epoch: 37, Train Loss Decreased!! (0.136852-->0.134262)
# Test Loss: 0.130598
#
# Temp Loss: 0.197111
#
# Epoch: 38, Train Loss Decreased!! (0.134262-->0.131211)
# Test Loss: 0.131760
#
# Temp Loss: 0.197239
#
# Epoch: 39, Train Loss Decreased!! (0.131211-->0.128706)
# Test Loss: 0.125238
#
# Temp Loss: 0.197792
#
# Epoch: 40, Train Loss Decreased!! (0.128706-->0.125413)
# Test Loss: 0.126147
#
# Temp Loss: 0.198289
#
# Epoch: 41, Train Loss Decreased!! (0.125413-->0.122902)
# Test Loss: 0.119990
#
# Temp Loss: 0.200334
#
# Epoch: 42, Train Loss Decreased!! (0.122902-->0.119989)
# Test Loss: 0.121308
#
# Temp Loss: 0.200240
#
# Epoch: 43, Train Loss Decreased!! (0.119989-->0.117222)
# Test Loss: 0.114064
#
# Temp Loss: 0.201507
#
# Epoch: 44, Train Loss Decreased!! (0.117222-->0.113518)
# Test Loss: 0.114700
#
# Temp Loss: 0.201776
#
# Epoch: 45, Train Loss Decreased!! (0.113518-->0.111156)
# Test Loss: 0.108779
#
# Temp Loss: 0.203046
#
# Epoch: 46, Train Loss Decreased!! (0.111156-->0.107997)
# Test Loss: 0.109270
#
# Temp Loss: 0.203591
#
# Epoch: 47, Train Loss Decreased!! (0.107997-->0.105007)
# Test Loss: 0.102588
#
# Temp Loss: 0.205702
#
# Epoch: 48, Train Loss Decreased!! (0.105007-->0.101485)
# Test Loss: 0.103904
#
# Temp Loss: 0.205263
#
# Epoch: 49, Train Loss Decreased!! (0.101485-->0.098656)
# Test Loss: 0.096459
#
# Temp Loss: 0.208916
#
# Epoch: 50, Train Loss Decreased!! (0.098656-->0.095502)
# Test Loss: 0.098157
#
# Temp Loss: 0.208468
#
# Epoch: 51, Train Loss Decreased!! (0.095502-->0.092726)
# Test Loss: 0.090724
#
# Temp Loss: 0.209445
#
# Epoch: 52, Train Loss Decreased!! (0.092726-->0.089193)
# Test Loss: 0.091899
#
# Temp Loss: 0.208991
#
# Epoch: 53, Train Loss Decreased!! (0.089193-->0.086440)
# Test Loss: 0.084837
#
# Temp Loss: 0.211742
#
# Epoch: 54, Train Loss Decreased!! (0.086440-->0.083056)
# Test Loss: 0.086316
#
# Temp Loss: 0.211226
#
# Epoch: 55, Train Loss Decreased!! (0.083056-->0.080374)
# Test Loss: 0.079535
#
# Temp Loss: 0.212812
#
# Epoch: 56, Train Loss Decreased!! (0.080374-->0.077076)
# Test Loss: 0.080206
#
# Temp Loss: 0.212334
#
# Epoch: 57, Train Loss Decreased!! (0.077076-->0.074372)
# Test Loss: 0.073359
#
# Temp Loss: 0.214904
#
# Epoch: 58, Train Loss Decreased!! (0.074372-->0.070901)
# Test Loss: 0.074415
#
# Temp Loss: 0.214547
#
# Epoch: 59, Train Loss Decreased!! (0.070901-->0.068374)
# Test Loss: 0.068113
#
# Temp Loss: 0.216776
#
# Epoch: 60, Train Loss Decreased!! (0.068374-->0.065294)
# Test Loss: 0.069072
#
# Temp Loss: 0.216228
#
# Epoch: 61, Train Loss Decreased!! (0.065294-->0.062344)
# Test Loss: 0.061581
#
# Temp Loss: 0.218646
#
# Epoch: 62, Train Loss Decreased!! (0.062344-->0.058976)
# Test Loss: 0.063175
#
# Temp Loss: 0.218049
#
# Epoch: 63, Train Loss Decreased!! (0.058976-->0.056393)
# Test Loss: 0.055972
#
# Temp Loss: 0.220064
#
# Epoch: 64, Train Loss Decreased!! (0.056393-->0.053182)
# Test Loss: 0.057493
#
# Temp Loss: 0.218995
#
# Epoch: 65, Train Loss Decreased!! (0.053182-->0.050161)
# Test Loss: 0.049499
#
# Temp Loss: 0.221776
#
# Epoch: 66, Train Loss Decreased!! (0.050161-->0.046630)
# Test Loss: 0.050972
#
# Temp Loss: 0.220942
#
# Epoch: 67, Train Loss Decreased!! (0.046630-->0.044057)
# Test Loss: 0.044013
#
# Temp Loss: 0.223375
#
# Epoch: 68, Train Loss Decreased!! (0.044057-->0.040866)
# Test Loss: 0.045149
#
# Temp Loss: 0.222275
#
# Epoch: 69, Train Loss Decreased!! (0.040866-->0.038491)
# Test Loss: 0.038223
#
# Temp Loss: 0.225879
#
# Epoch: 70, Train Loss Decreased!! (0.038491-->0.035659)
# Test Loss: 0.040136
#
# Temp Loss: 0.224201
#
# Epoch: 71, Train Loss Decreased!! (0.035659-->0.033543)
# Test Loss: 0.033793
#
# Temp Loss: 0.227578
#
# Epoch: 72, Train Loss Decreased!! (0.033543-->0.030994)
# Test Loss: 0.034883
#
# Temp Loss: 0.226025
#
# Epoch: 73, Train Loss Decreased!! (0.030994-->0.029039)
# Test Loss: 0.029368
#
# Temp Loss: 0.229616
#
# Epoch: 74, Train Loss Decreased!! (0.029039-->0.026707)
# Test Loss: 0.030500
#
# Temp Loss: 0.227758
#
# Epoch: 75, Train Loss Decreased!! (0.026707-->0.025282)
# Test Loss: 0.025647
#
# Temp Loss: 0.230728
#
# Epoch: 76, Train Loss Decreased!! (0.025282-->0.023295)
# Test Loss: 0.027048
#
# Temp Loss: 0.228946
#
# Epoch: 77, Train Loss Decreased!! (0.023295-->0.021928)
# Test Loss: 0.022537
#
# Temp Loss: 0.232543
#
# Epoch: 78, Train Loss Decreased!! (0.021928-->0.020444)
# Test Loss: 0.024435
#
# Temp Loss: 0.230251
#
# Epoch: 79, Train Loss Decreased!! (0.020444-->0.019286)
# Test Loss: 0.020069
#
# Temp Loss: 0.234150
#
# Epoch: 80, Train Loss Decreased!! (0.019286-->0.017997)
# Test Loss: 0.021345
#
# Temp Loss: 0.232159
#
# Epoch: 81, Train Loss Decreased!! (0.017997-->0.017033)
# Test Loss: 0.017835
#
# Temp Loss: 0.235354
#
# Epoch: 82, Train Loss Decreased!! (0.017033-->0.015794)
# Test Loss: 0.019464
#
# Temp Loss: 0.233222
#
# Epoch: 83, Train Loss Decreased!! (0.015794-->0.015078)
# Test Loss: 0.015557
#
# Temp Loss: 0.236356
#
# Epoch: 84, Train Loss Decreased!! (0.015078-->0.013783)
# Test Loss: 0.016961
#
# Temp Loss: 0.234273
#
# Epoch: 85, Train Loss Decreased!! (0.013783-->0.013472)
# Test Loss: 0.014115
#
# Temp Loss: 0.237276
#
# Epoch: 86, Train Loss Decreased!! (0.013472-->0.012573)
# Test Loss: 0.015758
#
# Temp Loss: 0.235536
#
# Epoch: 87, Train Loss Decreased!! (0.012573-->0.011926)
# Test Loss: 0.012545
#
# Temp Loss: 0.238579
#
# Epoch: 88, Train Loss Decreased!! (0.011926-->0.011285)
# Test Loss: 0.014261
#
# Temp Loss: 0.236487
#
# Epoch: 89, Train Loss Decreased!! (0.011285-->0.010812)
# Test Loss: 0.011062
#
# Temp Loss: 0.239697
#
# Epoch: 90, Train Loss Decreased!! (0.010812-->0.010225)
# Test Loss: 0.013040
#
# Temp Loss: 0.237041
#
# Epoch: 91, Train Loss Decreased!! (0.010225-->0.009666)
# Test Loss: 0.010017
#
# Temp Loss: 0.240290
#
# Epoch: 92, Train Loss Decreased!! (0.009666-->0.009402)
# Test Loss: 0.012307
#
# Temp Loss: 0.237645
#
# Epoch: 93, Train Loss Decreased!! (0.009402-->0.008974)
# Test Loss: 0.009273
#
# Temp Loss: 0.240110
#
# Epoch: 94, Train Loss Decreased!! (0.008974-->0.008865)
# Test Loss: 0.011646
#
# Temp Loss: 0.237000
#
# Epoch: 95, Train Loss Decreased!! (0.008865-->0.008294)
# Test Loss: 0.008331
#
# Temp Loss: 0.240551
#
# Epoch: 96, Train Loss Decreased!! (0.008294-->0.007851)
# Test Loss: 0.010041
#
# Temp Loss: 0.238081
#
# Epoch: 97, Train Loss Decreased!! (0.007851-->0.007334)
# Test Loss: 0.007522
#
# Temp Loss: 0.241055
#
# Epoch: 98, Train Loss Decreased!! (0.007334-->0.007238)
# Test Loss: 0.009675
#
# Temp Loss: 0.237751
#
# Epoch: 99, Train Loss Decreased!! (0.007238-->0.006958)
# Test Loss: 0.006877
#
# Temp Loss: 0.241344
#  80%|████████  | 4/5 [03:28<00:51, 51.76s/it]
# Epoch: 100, Train Loss Decreased!! (0.006958-->0.006586)
# Test Loss: 0.008753
#
# Temp Loss: 0.238092
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.213889)
# Test Loss: 0.185379
#
# Temp Loss: 0.185412
#
# Epoch: 2, Train Loss Decreased!! (0.213889-->0.185345)
# Test Loss: 0.184733
#
# Temp Loss: 0.184632
#
# Epoch: 3, Train Loss Decreased!! (0.185345-->0.179819)
# Test Loss: 0.177243
#
# Temp Loss: 0.177333
#
# Epoch: 4, Train Loss Decreased!! (0.179819-->0.177735)
# Test Loss: 0.177167
#
# Temp Loss: 0.177194
#
# Epoch: 5, Train Loss Decreased!! (0.177735-->0.177463)
# Test Loss: 0.176123
#
# Temp Loss: 0.176503
#
# Epoch: 6, Train Loss Decreased!! (0.177463-->0.176941)
# Test Loss: 0.176391
#
# Temp Loss: 0.176495
#
# Epoch: 7, Train Loss Decreased!! (0.176941-->0.176709)
# Test Loss: 0.175763
#
# Temp Loss: 0.175823
#
# Epoch: 8, Train Loss Decreased!! (0.176709-->0.176248)
# Test Loss: 0.175758
#
# Temp Loss: 0.175978
#
# Epoch: 9, Train Loss Decreased!! (0.176248-->0.175940)
# Test Loss: 0.174597
#
# Temp Loss: 0.175161
#
# Epoch: 10, Train Loss Decreased!! (0.175940-->0.175033)
# Test Loss: 0.174506
#
# Temp Loss: 0.175393
#
# Epoch: 11, Train Loss Decreased!! (0.175033-->0.174043)
# Test Loss: 0.171975
#
# Temp Loss: 0.175459
#
# Epoch: 12, Train Loss Decreased!! (0.174043-->0.172487)
# Test Loss: 0.172063
#
# Temp Loss: 0.175417
#
# Epoch: 13, Train Loss Decreased!! (0.172487-->0.171091)
# Test Loss: 0.168822
#
# Temp Loss: 0.177531
#
# Epoch: 14, Train Loss Decreased!! (0.171091-->0.169248)
# Test Loss: 0.168866
#
# Temp Loss: 0.177382
#
# Epoch: 15, Train Loss Decreased!! (0.169248-->0.167368)
# Test Loss: 0.165136
#
# Temp Loss: 0.181555
#
# Epoch: 16, Train Loss Decreased!! (0.167368-->0.164981)
# Test Loss: 0.165014
#
# Temp Loss: 0.181444
#
# Epoch: 17, Train Loss Decreased!! (0.164981-->0.163292)
# Test Loss: 0.161198
#
# Temp Loss: 0.185612
#
# Epoch: 18, Train Loss Decreased!! (0.163292-->0.161175)
# Test Loss: 0.161242
#
# Temp Loss: 0.185361
#
# Epoch: 19, Train Loss Decreased!! (0.161175-->0.160041)
# Test Loss: 0.158982
#
# Temp Loss: 0.188447
#
# Epoch: 20, Train Loss Decreased!! (0.160041-->0.158569)
# Test Loss: 0.159054
#
# Temp Loss: 0.187929
#
# Epoch: 21, Train Loss Decreased!! (0.158569-->0.157430)
# Test Loss: 0.155790
#
# Temp Loss: 0.188627
#
# Epoch: 22, Train Loss Decreased!! (0.157430-->0.155683)
# Test Loss: 0.155935
#
# Temp Loss: 0.188385
#
# Epoch: 23, Train Loss Decreased!! (0.155683-->0.154529)
# Test Loss: 0.152249
#
# Temp Loss: 0.191821
#
# Epoch: 24, Train Loss Decreased!! (0.154529-->0.152175)
# Test Loss: 0.152365
#
# Temp Loss: 0.191304
#
# Epoch: 25, Train Loss Decreased!! (0.152175-->0.150852)
# Test Loss: 0.148544
#
# Temp Loss: 0.193749
#
# Epoch: 26, Train Loss Decreased!! (0.150852-->0.148275)
# Test Loss: 0.148453
#
# Temp Loss: 0.193339
#
# Epoch: 27, Train Loss Decreased!! (0.148275-->0.146470)
# Test Loss: 0.143558
#
# Temp Loss: 0.195482
#
# Epoch: 28, Train Loss Decreased!! (0.146470-->0.143502)
# Test Loss: 0.143816
#
# Temp Loss: 0.195378
#
# Epoch: 29, Train Loss Decreased!! (0.143502-->0.141469)
# Test Loss: 0.138671
#
# Temp Loss: 0.195295
#
# Epoch: 30, Train Loss Decreased!! (0.141469-->0.138150)
# Test Loss: 0.138904
#
# Temp Loss: 0.195526
#
# Epoch: 31, Train Loss Decreased!! (0.138150-->0.135943)
# Test Loss: 0.133563
#
# Temp Loss: 0.197015
#
# Epoch: 32, Train Loss Decreased!! (0.135943-->0.132640)
# Test Loss: 0.133697
#
# Temp Loss: 0.197341
#
# Epoch: 33, Train Loss Decreased!! (0.132640-->0.130417)
# Test Loss: 0.128333
#
# Temp Loss: 0.196778
#
# Epoch: 34, Train Loss Decreased!! (0.130417-->0.127507)
# Test Loss: 0.129069
#
# Temp Loss: 0.197463
#
# Epoch: 35, Train Loss Decreased!! (0.127507-->0.125060)
# Test Loss: 0.122453
#
# Temp Loss: 0.198084
#
# Epoch: 36, Train Loss Decreased!! (0.125060-->0.121706)
# Test Loss: 0.123327
#
# Temp Loss: 0.198570
#
# Epoch: 37, Train Loss Decreased!! (0.121706-->0.119285)
# Test Loss: 0.116755
#
# Temp Loss: 0.197798
#
# Epoch: 38, Train Loss Decreased!! (0.119285-->0.115843)
# Test Loss: 0.117246
#
# Temp Loss: 0.197818
#
# Epoch: 39, Train Loss Decreased!! (0.115843-->0.113126)
# Test Loss: 0.110026
#
# Temp Loss: 0.198869
#
# Epoch: 40, Train Loss Decreased!! (0.113126-->0.109453)
# Test Loss: 0.111386
#
# Temp Loss: 0.199258
#
# Epoch: 41, Train Loss Decreased!! (0.109453-->0.106391)
# Test Loss: 0.102940
#
# Temp Loss: 0.201105
#
# Epoch: 42, Train Loss Decreased!! (0.106391-->0.102498)
# Test Loss: 0.104449
#
# Temp Loss: 0.201498
#
# Epoch: 43, Train Loss Decreased!! (0.102498-->0.099002)
# Test Loss: 0.095499
#
# Temp Loss: 0.202795
#
# Epoch: 44, Train Loss Decreased!! (0.099002-->0.095224)
# Test Loss: 0.097519
#
# Temp Loss: 0.202358
#
# Epoch: 45, Train Loss Decreased!! (0.095224-->0.091617)
# Test Loss: 0.088352
#
# Temp Loss: 0.205096
#
# Epoch: 46, Train Loss Decreased!! (0.091617-->0.087547)
# Test Loss: 0.089611
#
# Temp Loss: 0.204628
#
# Epoch: 47, Train Loss Decreased!! (0.087547-->0.084391)
# Test Loss: 0.080958
#
# Temp Loss: 0.208035
#
# Epoch: 48, Train Loss Decreased!! (0.084391-->0.080147)
# Test Loss: 0.082395
#
# Temp Loss: 0.207475
#
# Epoch: 49, Train Loss Decreased!! (0.080147-->0.077299)
# Test Loss: 0.074656
#
# Temp Loss: 0.209908
#
# Epoch: 50, Train Loss Decreased!! (0.077299-->0.073776)
# Test Loss: 0.076554
#
# Temp Loss: 0.209249
#
# Epoch: 51, Train Loss Decreased!! (0.073776-->0.071132)
# Test Loss: 0.068878
#
# Temp Loss: 0.212054
#
# Epoch: 52, Train Loss Decreased!! (0.071132-->0.067743)
# Test Loss: 0.070588
#
# Temp Loss: 0.210960
#
# Epoch: 53, Train Loss Decreased!! (0.067743-->0.064869)
# Test Loss: 0.062173
#
# Temp Loss: 0.213622
#
# Epoch: 54, Train Loss Decreased!! (0.064869-->0.061280)
# Test Loss: 0.063940
#
# Temp Loss: 0.212173
#
# Epoch: 55, Train Loss Decreased!! (0.061280-->0.058356)
# Test Loss: 0.055370
#
# Temp Loss: 0.215217
#
# Epoch: 56, Train Loss Decreased!! (0.058356-->0.054222)
# Test Loss: 0.056648
#
# Temp Loss: 0.214340
#
# Epoch: 57, Train Loss Decreased!! (0.054222-->0.051597)
# Test Loss: 0.048627
#
# Temp Loss: 0.216971
#
# Epoch: 58, Train Loss Decreased!! (0.051597-->0.048233)
# Test Loss: 0.051223
#
# Temp Loss: 0.215555
#
# Epoch: 59, Train Loss Decreased!! (0.048233-->0.045728)
# Test Loss: 0.042789
#
# Temp Loss: 0.218838
#
# Epoch: 60, Train Loss Decreased!! (0.045728-->0.042858)
# Test Loss: 0.046411
#
# Temp Loss: 0.216714
#
# Epoch: 61, Train Loss Decreased!! (0.042858-->0.040094)
# Test Loss: 0.037201
#
# Temp Loss: 0.221534
#
# Epoch: 62, Train Loss Decreased!! (0.040094-->0.037256)
# Test Loss: 0.040547
#
# Temp Loss: 0.219657
#
# Epoch: 63, Train Loss Decreased!! (0.037256-->0.034642)
# Test Loss: 0.032204
#
# Temp Loss: 0.223756
#
# Epoch: 64, Train Loss Decreased!! (0.034642-->0.032134)
# Test Loss: 0.035105
#
# Temp Loss: 0.221936
#
# Epoch: 65, Train Loss Decreased!! (0.032134-->0.029789)
# Test Loss: 0.027594
#
# Temp Loss: 0.226428
#
# Epoch: 66, Train Loss Decreased!! (0.029789-->0.027302)
# Test Loss: 0.029953
#
# Temp Loss: 0.224350
#
# Epoch: 67, Train Loss Decreased!! (0.027302-->0.025413)
# Test Loss: 0.023452
#
# Temp Loss: 0.227928
#
# Epoch: 68, Train Loss Decreased!! (0.025413-->0.022968)
# Test Loss: 0.024871
#
# Temp Loss: 0.226183
#
# Epoch: 69, Train Loss Decreased!! (0.022968-->0.021635)
# Test Loss: 0.019934
#
# Temp Loss: 0.230414
#
# Epoch: 70, Train Loss Decreased!! (0.021635-->0.019514)
# Test Loss: 0.021319
#
# Temp Loss: 0.229181
#
# Epoch: 71, Train Loss Decreased!! (0.019514-->0.018438)
# Test Loss: 0.017020
#
# Temp Loss: 0.231775
#
# Epoch: 72, Train Loss Decreased!! (0.018438-->0.016746)
# Test Loss: 0.018407
#
# Temp Loss: 0.230349
#
# Epoch: 73, Train Loss Decreased!! (0.016746-->0.015822)
# Test Loss: 0.014691
#
# Temp Loss: 0.233589
#
# Epoch: 74, Train Loss Decreased!! (0.015822-->0.014524)
# Test Loss: 0.016353
#
# Temp Loss: 0.231770
#
# Epoch: 75, Train Loss Decreased!! (0.014524-->0.013826)
# Test Loss: 0.012549
#
# Temp Loss: 0.234695
#
# Epoch: 76, Train Loss Decreased!! (0.013826-->0.012497)
# Test Loss: 0.013947
#
# Temp Loss: 0.233528
#
# Epoch: 77, Train Loss Decreased!! (0.012497-->0.011852)
# Test Loss: 0.010914
#
# Temp Loss: 0.236373
#
# Epoch: 78, Train Loss Decreased!! (0.011852-->0.010971)
# Test Loss: 0.012400
#
# Temp Loss: 0.234995
#
# Epoch: 79, Train Loss Decreased!! (0.010971-->0.010337)
# Test Loss: 0.009607
#
# Temp Loss: 0.237011
#
# Epoch: 80, Train Loss Decreased!! (0.010337-->0.009593)
# Test Loss: 0.010846
#
# Temp Loss: 0.235918
#
# Epoch: 81, Train Loss Decreased!! (0.009593-->0.009099)
# Test Loss: 0.008324
#
# Temp Loss: 0.238171
#
# Epoch: 82, Train Loss Decreased!! (0.009099-->0.008586)
# Test Loss: 0.010031
#
# Temp Loss: 0.236761
#
# Epoch: 83, Train Loss Decreased!! (0.008586-->0.008200)
# Test Loss: 0.007490
#
# Temp Loss: 0.238575
#
# Epoch: 84, Train Loss Decreased!! (0.008200-->0.007750)
# Test Loss: 0.008915
#
# Temp Loss: 0.237330
#
# Epoch: 85, Train Loss Decreased!! (0.007750-->0.007338)
# Test Loss: 0.006713
#
# Temp Loss: 0.239894
#
# Epoch: 86, Train Loss Decreased!! (0.007338-->0.006998)
# Test Loss: 0.008129
#
# Temp Loss: 0.238326
#
# Epoch: 87, Train Loss Decreased!! (0.006998-->0.006570)
# Test Loss: 0.006088
#
# Temp Loss: 0.240228
#
# Epoch: 88, Train Loss Decreased!! (0.006570-->0.006400)
# Test Loss: 0.007616
#
# Temp Loss: 0.238622
#
# Epoch: 89, Train Loss Decreased!! (0.006400-->0.006014)
# Test Loss: 0.005506
#
# Temp Loss: 0.240383
#
# Epoch: 90, Train Loss Decreased!! (0.006014-->0.005821)
# Test Loss: 0.006790
#
# Temp Loss: 0.238991
#
# Epoch: 91, Train Loss Decreased!! (0.005821-->0.005409)
# Test Loss: 0.004851
#
# Temp Loss: 0.241222
#
# Epoch: 92, Train Loss Decreased!! (0.005409-->0.005246)
# Test Loss: 0.006128
#
# Temp Loss: 0.239836
#
# Epoch: 93, Train Loss Decreased!! (0.005246-->0.004930)
# Test Loss: 0.004603
#
# Temp Loss: 0.241525
#
# Epoch: 94, Train Loss Decreased!! (0.004930-->0.004818)
# Test Loss: 0.005581
#
# Temp Loss: 0.240306
#
# Epoch: 95, Train Loss Decreased!! (0.004818-->0.004583)
# Test Loss: 0.004112
#
# Temp Loss: 0.241431
#
# Epoch: 96, Train Loss Decreased!! (0.004583-->0.004360)
# Test Loss: 0.005111
#
# Temp Loss: 0.239885
#
# Epoch: 97, Train Loss Decreased!! (0.004360-->0.004220)
# Test Loss: 0.003771
#
# Temp Loss: 0.242040
#
# Epoch: 98, Train Loss Decreased!! (0.004220-->0.003970)
# Test Loss: 0.004666
#
# Temp Loss: 0.240716
#
# Epoch: 99, Train Loss Decreased!! (0.003970-->0.003868)
# Test Loss: 0.003531
#
# Temp Loss: 0.242267
# 100%|██████████| 5/5 [04:18<00:00, 51.77s/it]
# Epoch: 100, Train Loss Decreased!! (0.003868-->0.003703)
# Test Loss: 0.004415
#
# Temp Loss: 0.241000
#
# ----------------------------------------------------

# %%
train_losses_mat = np.zeros((nRuns,n_epochs+1))
test_losses_mat = np.zeros((nRuns,n_epochs+1))
temp_losses_mat = np.zeros((nRuns,n_epochs+1))

train_expected_losses_mat = np.zeros((nRuns,n_epochs+1))

test_expected_losses_mat = np.zeros((nRuns,n_epochs+1))
test_surprise_losses_mat = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    train_losses_mat[cntr] = train_losses[cntr]
    test_losses_mat[cntr] = test_losses[cntr]
    temp_losses_mat[cntr] = temp_losses[cntr]
    
    train_expected_losses_mat[cntr] = train_expected_rec_losses[cntr]
    
    test_expected_losses_mat[cntr] = test_expected_rec_losses[cntr]
    test_surprise_losses_mat[cntr] = test_surprise_rec_losses[cntr]

# %%
train_losses_mean = np.mean(train_losses_mat,axis=0)
test_losses_mean = np.mean(test_losses_mat,axis=0)
temp_losses_mean = np.mean(temp_losses_mat,axis=0)

train_expected_losses_mean = np.mean(train_expected_losses_mat,axis=0)

test_expected_losses_mean = np.mean(test_expected_losses_mat,axis=0)
test_surprise_losses_mean = np.mean(test_surprise_losses_mat,axis=0)

# %%
train_losses_std = np.std(train_losses_mat,axis=0)
test_losses_std = np.std(test_losses_mat,axis=0)
temp_losses_std = np.std(test_losses_mat,axis=0)

train_expected_losses_std = np.std(train_expected_losses_mat,axis=0)

test_expected_losses_std = np.std(test_expected_losses_mat,axis=0)
test_surprise_losses_std = np.std(test_surprise_losses_mat,axis=0)

# %%
train_expected_losses_mean[0] = train_losses_mean[0]

# %%
f = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.errorbar(np.arange(n_epochs+1),train_losses_mean,yerr=train_losses_std)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,2)
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.subplot(2,2,3)
plt.errorbar(np.arange(n_epochs+1),test_losses_mean,yerr=test_losses_std)
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,4)
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
# kk=4
# a = np.unique(allStatesTest[kk][:,0])
# b = np.unique(allStatesTrain[kk][:,0])
# len(np.intersect1d(a,b))

# %% [markdown]
# ### Representational Analyses

# %% [markdown]
# #### RNN Names

# %%
rnn_names = ['L4','L23','L56','H4','H23','H56']

# %%
# analyses_train_loader = {}

# %%
# for cntr in range(nRuns):
#     analyses_train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
#                                            batch_size,shuffle=False)

# %% [markdown]
# #### Pass data and store activations

# %%
def pass_data_store_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        activations_hidden_L23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_L4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_L56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_hidden_H23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_H4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_H56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_out_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
        for e in tqdm(range(n_epochs+1)):

            cnt = 0

            ## Load model
            model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr],task='lattice')
            model[cntr].to(device)
            model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
            model[cntr].eval()

            ## Pass clean samples
            for data, f_target, lastEvent, surpriseBinary in loader[cntr]:

                if train_on_gpu:
                    data, f_targetC = data.float().cuda(), f_target.float().cuda()
                else: data, f_targetC = data.float(), f_target.float()

                target = f_target

                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                ## Collect activations  
                act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                for i in range(batch_size):
                    if i < len(data):
                        label = target.data[i]

                        activations_hidden_L23_np[cntr][e,cnt] = act_hidden_L23[i]
                        activations_hidden_L4_np[cntr][e,cnt] = act_hidden_L4[i]
                        activations_hidden_L56_np[cntr][e,cnt] = act_hidden_L56[i]

                        activations_hidden_H23_np[cntr][e,cnt] = act_hidden_H23[i]
                        activations_hidden_H4_np[cntr][e,cnt] = act_hidden_H4[i]
                        activations_hidden_H56_np[cntr][e,cnt] = act_hidden_H56[i]

                        activations_out_np[cntr][e,cnt] = output_pred[i]

                        cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# (L23_train,L4_train,L56_train,
#  H23_train,H4_train,H56_train,), out_train = pass_data_store_activations(analyses_train_loader, nTrain)

# %%
model[1]
# Out:
# microcircuit(
#   (relu): ReLU()
#   (L4): RNN(116, 48, batch_first=True)
#   (L23): RNN(96, 48, batch_first=True)
#   (L56): RNN(96, 48, batch_first=True)
#   (H4): RNN(96, 48, batch_first=True)
#   (H23): RNN(48, 48, batch_first=True)
#   (H56): RNN(48, 48, batch_first=True)
#   (WFF): Linear(in_features=48, out_features=48, bias=True)
#   (WFBa): Linear(in_features=48, out_features=48, bias=True)
#   (WFBb): Linear(in_features=48, out_features=48, bias=True)
#   (WL423): Linear(in_features=48, out_features=48, bias=True)
#   (WL2356): Linear(in_features=48, out_features=48, bias=True)
#   (WL564): Linear(in_features=48, out_features=48, bias=True)
#   (WH423): Linear(in_features=48, out_features=48, bias=True)
#   (WH2356): Linear(in_features=48, out_features=48, bias=True)
#   (WH564): Linear(in_features=48, out_features=48, bias=True)
#   (opLayer): Linear(in_features=48, out_features=64, bias=True)
# )

# %%
(L23_test,L4_test,L56_test,
 H23_test,H4_test,H56_test), out_test = pass_data_store_activations(test_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:07<00:00, 13.03it/s]
# 100%|██████████| 101/101 [00:07<00:00, 13.13it/s]
# 100%|██████████| 101/101 [00:07<00:00, 13.04it/s]
# 100%|██████████| 101/101 [00:07<00:00, 13.01it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.91it/s]

# %%
(L23_temp,L4_temp,L56_temp,
 H23_temp,H4_temp,H56_temp), out_temp = pass_data_store_activations(test_temp_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:07<00:00, 13.04it/s]
# 100%|██████████| 101/101 [00:07<00:00, 13.04it/s]
# 100%|██████████| 101/101 [00:07<00:00, 13.09it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.73it/s]
# 100%|██████████| 101/101 [00:07<00:00, 13.12it/s]

# %% [markdown]
# #### PCA for RNNs

# %%
def repsPCA(rnnActs):
    nEpochs, nSeqs, nRolls, nNeurons = rnnActs.shape
    pca_dict = {}
    nSamps = nSeqs*nRolls
    dimPCA = min(nNeurons,nSamps)
    repsR_transformed = np.zeros((nEpochs,nSamps,dimPCA))
    
    for ep in tqdm(range(nEpochs)):
        
        reps = rnnActs[ep]
        
        ## reshape
        repsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        for ii in range(nSeqs):
            for jj in range(nRolls):
                repsR[cnt] = reps[ii,jj]
                cnt += 1
        ## PCA
        rnnPCA = PCA()
        repsR_transformed[ep] = rnnPCA.fit_transform(repsR)
        pca_dict[str(ep)] = rnnPCA
        
    return repsR_transformed, pca_dict

# %%
L23pca_train = {}
L4pca_train = {}
L56pca_train = {}

H23pca_train = {}
H4pca_train = {}
H56pca_train = {}

L23pca_test = {}
L4pca_test = {}
L56pca_test = {}

H23pca_test = {}
H4pca_test = {}
H56pca_test = {}

L23pca_temp = {}
L4pca_temp = {}
L56pca_temp = {}

H23pca_temp = {}
H4pca_temp = {}
H56pca_temp = {}

# %%
# for cntr in range(nRuns):
#     L23pca_train[cntr], _ = repsPCA(L23_train[cntr])
#     L4pca_train[cntr], _ = repsPCA(L4_train[cntr])
#     L56pca_train[cntr], _ = repsPCA(L56_train[cntr])

#     H23pca_train[cntr], _ = repsPCA(H23_train[cntr])
#     H4pca_train[cntr], _ = repsPCA(H4_train[cntr])
#     H56pca_train[cntr], _ = repsPCA(H56_train[cntr])

# %%
for cntr in range(nRuns):
    L23pca_test[cntr], _ = repsPCA(L23_test[cntr])
    L4pca_test[cntr], _ = repsPCA(L4_test[cntr])
    L56pca_test[cntr], _ = repsPCA(L56_test[cntr])

    H23pca_test[cntr], _ = repsPCA(H23_test[cntr])
    H4pca_test[cntr], _ = repsPCA(H4_test[cntr])
    H56pca_test[cntr], _ = repsPCA(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 270.77it/s]
# 100%|██████████| 101/101 [00:00<00:00, 280.53it/s]
# 100%|██████████| 101/101 [00:00<00:00, 301.40it/s]
# 100%|██████████| 101/101 [00:00<00:00, 302.30it/s]
# 100%|██████████| 101/101 [00:00<00:00, 303.20it/s]
# 100%|██████████| 101/101 [00:00<00:00, 307.81it/s]
# 100%|██████████| 101/101 [00:00<00:00, 298.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 294.39it/s]
# 100%|██████████| 101/101 [00:00<00:00, 309.22it/s]
# 100%|██████████| 101/101 [00:00<00:00, 305.03it/s]
# 100%|██████████| 101/101 [00:00<00:00, 305.03it/s]
# 100%|██████████| 101/101 [00:00<00:00, 281.31it/s]
# 100%|██████████| 101/101 [00:00<00:00, 309.69it/s]
# 100%|██████████| 101/101 [00:00<00:00, 296.98it/s]
# 100%|██████████| 101/101 [00:00<00:00, 291.84it/s]
# 100%|██████████| 101/101 [00:00<00:00, 314.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 288.52it/s]
# 100%|██████████| 101/101 [00:00<00:00, 310.64it/s]
# 100%|██████████| 101/101 [00:00<00:00, 296.98it/s]
# 100%|██████████| 101/101 [00:00<00:00, 284.46it/s]
# 100%|██████████| 101/101 [00:00<00:00, 315.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 286.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 306.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 298.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 301.40it/s]
# 100%|██████████| 101/101 [00:00<00:00, 303.20it/s]
# 100%|██████████| 101/101 [00:00<00:00, 285.27it/s]
# 100%|██████████| 101/101 [00:00<00:00, 307.81it/s]
# 100%|██████████| 101/101 [00:00<00:00, 295.25it/s]
# 100%|██████████| 101/101 [00:00<00:00, 306.88it/s]

# %%
for cntr in range(nRuns):
    L23pca_temp[cntr], _ = repsPCA(L23_temp[cntr])
    L4pca_temp[cntr], _ = repsPCA(L4_temp[cntr])
    L56pca_temp[cntr], _ = repsPCA(L56_temp[cntr])

    H23pca_temp[cntr], _ = repsPCA(H23_temp[cntr])
    H4pca_temp[cntr], _ = repsPCA(H4_temp[cntr])
    H56pca_temp[cntr], _ = repsPCA(H56_temp[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 273.33it/s]
# 100%|██████████| 101/101 [00:00<00:00, 293.54it/s]
# 100%|██████████| 101/101 [00:00<00:00, 300.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 299.62it/s]
# 100%|██████████| 101/101 [00:00<00:00, 312.56it/s]
# 100%|██████████| 101/101 [00:00<00:00, 296.11it/s]
# 100%|██████████| 101/101 [00:00<00:00, 309.68it/s]
# 100%|██████████| 101/101 [00:00<00:00, 296.98it/s]
# 100%|██████████| 101/101 [00:00<00:00, 292.69it/s]
# 100%|██████████| 101/101 [00:00<00:00, 311.60it/s]
# 100%|██████████| 101/101 [00:00<00:00, 282.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 314.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 304.11it/s]
# 100%|██████████| 101/101 [00:00<00:00, 314.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 281.30it/s]
# 100%|██████████| 101/101 [00:00<00:00, 282.09it/s]
# 100%|██████████| 101/101 [00:00<00:00, 315.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 299.61it/s]
# 100%|██████████| 101/101 [00:00<00:00, 272.96it/s]
# 100%|██████████| 101/101 [00:00<00:00, 297.85it/s]
# 100%|██████████| 101/101 [00:00<00:00, 295.25it/s]
# 100%|██████████| 101/101 [00:00<00:00, 312.56it/s]
# 100%|██████████| 101/101 [00:00<00:00, 295.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 300.51it/s]
# 100%|██████████| 101/101 [00:00<00:00, 298.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 306.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 298.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 290.17it/s]
# 100%|██████████| 101/101 [00:00<00:00, 305.95it/s]
# 100%|██████████| 101/101 [00:00<00:00, 295.25it/s]

# %% [markdown]
# #### Labels, etc.

# %%
allStatesLabelsTrain = {}
allStatesLabelsTest = {}
allStatesLabelsTestTemp = {}

actionsLabelsTrain = {}
actionsLabelsTest = {}
actionsLabelsTestTemp = {}

# %%
def allStatesLabels(allStates,latLabs):
    nSamps, nSeqs, nDim = allStates.shape
    labels = np.zeros((nSamps,nSeqs),dtype=int)
    for ii in range(nSamps):
        for jj in range(nSeqs):
            labels[ii,jj] = np.where((latLabs[:,None] == allStates[ii,jj]).all(-1).any(-1)==1)[0][0]
    return labels

# %%
for cntr in range(nRuns):
#     allStatesLabelsTrain[cntr] = allStatesLabels(allStatesTrain[cntr],lattice_labels)
    allStatesLabelsTest[cntr] = allStatesLabels(allStatesTest[cntr],lattice_labels)
    allStatesLabelsTestTemp[cntr] = allStatesLabels(allStatesTestTemp[cntr],lattice_labels)
    
#     actionsLabelsTrain[cntr] = np.argmax(actionsTrain[cntr],-1)
    actionsLabelsTest[cntr] = np.argmax(actionsTest[cntr],-1)
    actionsLabelsTestTemp[cntr] = np.argmax(actionsTestTemp[cntr],-1)

# %%
# idxs0_train = np.array([6*x for x in range(nTrain)])
# idxs1_train = idxs0_train + 1
# idxs2_train = idxs0_train + 2
# idxs3_train = idxs0_train + 3
# idxs4_train = idxs0_train + 4
# idxs5_train = idxs0_train + 5

# %%
idxs0_test = np.array([6*x for x in range(nTest)])
idxs1_test = idxs0_test + 1
idxs2_test = idxs0_test + 2
idxs3_test = idxs0_test + 3
idxs4_test = idxs0_test + 4
idxs5_test = idxs0_test + 5

# %%
idxs_test_surp = np.sort(np.hstack((idxs4_test,idxs5_test)))

# %%
pos_test = np.tile(np.arange(nSteps),nTest).ravel()

# %% [markdown]
# #### Plots

# %% [markdown]
# #### Coloured by states

# %%
# cnt = 0
# ep = 50
# ix = idxs5_test
# seq = 3 ##0-3
# c = allStatesLabelsTest[cnt][:,seq] + 1
# s = 10#1*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = allStatesTest[cnt][:,seq,xy] + 0.5
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %% [markdown]
# #### Coloured by distance from lattice centre

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %% [markdown]
# #### 3D plot

# %%
# cnt = 1
# ix = idxs0_test
# seq = 0

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# c = np.repeat(c,n_epochs+1,0)
# s = 10#5*c

# sub = 1
# colmap = 'copper'

# Zs = np.repeat(np.arange(n_epochs+1).reshape(-1,1),nTest,1)

# %%
# fig = plt.figure(figsize=(17,12))

# ax = fig.add_subplot(2, 3, 1, projection='3d')
# ax.scatter3D(L4pca_test[cnt][:,ix,0].ravel()[::sub],L4pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 2, projection='3d')
# ax.scatter3D(L23pca_test[cnt][:,ix,0].ravel()[::sub],L23pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 3, projection='3d')
# ax.scatter3D(L56pca_test[cnt][:,ix,0].ravel()[::sub],L56pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 4, projection='3d')
# ax.scatter3D(H4pca_test[cnt][:,ix,0].ravel()[::sub],H4pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 5, projection='3d')
# ax.scatter3D(H23pca_test[cnt][:,ix,0].ravel()[::sub],H23pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 6, projection='3d')
# ax.scatter3D(H56pca_test[cnt][:,ix,0].ravel()[::sub],H56pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# plt.show()

# %% [markdown]
# #### Coloured by actions

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 3 ##0-3
# step = 5
# c = actionsLabelsTest[cnt][:,step] + 1
# s = 5*c
# colmap='Set1'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 2 ##0-3
# step = 5
# c = (actionsLabelsTest[cnt][:,step]%2)*1. + 1
# s = 5*c
# colmap='Dark2'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 2 ##0-3
# step = 5
# c = (actionsLabelsTest[cnt][:,step]>1)*1. + 1
# s = 5*c
# colmap='Dark2'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = 50
# ix = idxs4_test
# seq = 2 ##0-3
# step = 3
# c = allStatesLabelsTest[cnt][:,seq]
# s = 1*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs_surp
# seq = -1 ##0-3
# step = 4
# # c = actionsLabelsTest[cnt][:,step]
# # s = 5*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H5/6')

# %% [markdown]
# #### Supervised Decoding

# %% [markdown]
# #### Position

# %%
def repsDecodeSupervisedPosition(rnnActs,labels,clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    nClasses = 6
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
testPCs = {}
tempPCs = {}

contextPCs_sub = {}

# %%
for cntr in range(nRuns):
    testPCs[cntr] = (L4pca_test[cntr],L23pca_test[cntr],L56pca_test[cntr],
                     H4pca_test[cntr],H23pca_test[cntr],H56pca_test[cntr])
    tempPCs[cntr] = (L4pca_temp[cntr],L23pca_temp[cntr],L56pca_temp[cntr],
                     H4pca_temp[cntr],H23pca_temp[cntr],H56pca_temp[cntr])
    
    for rnnNo in range(len(rnn_names)):
        contextPCs_sub[cntr,rnnNo] = np.hstack((testPCs[cntr][rnnNo][:,idxs_test_surp,:],
                                                tempPCs[cntr][rnnNo][:,idxs_test_surp,:]))

# %%
L4posPC = {}
L23posPC = {}
L56posPC = {}
H4posPC = {}
H23posPC = {}
H56posPC = {}

# %%
dims23 = np.array([1,2,4,8,16,32,64,80])
dims4 = np.array([1,2,4,8,16,32])
dims56 = np.array([1,2,4,8,16,32,64])

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][1][:,:,:d],pos_test)
        H23posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][4][:,:,:d],pos_test)
    
    for d in dims4:
        L4posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][0][:,:,:d],pos_test)
        H4posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][3][:,:,:d],pos_test)
        
    for d in dims56:
        L56posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][2][:,:,:d],pos_test)      
        H56posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][5][:,:,:d],pos_test)
# Out:
# 100%|██████████| 5/5 [05:24<00:00, 64.95s/it]

# %%
preds_L23posPC = {}
preds_L4posPC = {}
preds_L56posPC = {}

preds_H23posPC = {}
preds_H4posPC = {}
preds_H56posPC = {}

# %%
accs_L23posPC = {}
accs_L4posPC = {}
accs_L56posPC = {}

accs_H23posPC = {}
accs_H4posPC = {}
accs_H56posPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23posPC[cntr,d,ep] = np.argmax(L23posPC[cntr,d][ep],axis=-1)
            preds_H23posPC[cntr,d,ep] = np.argmax(H23posPC[cntr,d][ep],axis=-1)
            
            accs_L23posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L23posPC[cntr,d,ep])
            accs_H23posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H23posPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4posPC[cntr,d,ep] = np.argmax(L4posPC[cntr,d][ep],axis=-1)
            preds_H4posPC[cntr,d,ep] = np.argmax(H4posPC[cntr,d][ep],axis=-1)
            
            accs_L4posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L4posPC[cntr,d,ep])
            accs_H4posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H4posPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56posPC[cntr,d,ep] = np.argmax(L56posPC[cntr,d][ep],axis=-1)
            preds_H56posPC[cntr,d,ep] = np.argmax(H56posPC[cntr,d][ep],axis=-1)
            
            accs_L56posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L56posPC[cntr,d,ep])
            accs_H56posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H56posPC[cntr,d,ep])

# %%
tensor_accs_L23posPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4posPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56posPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23posPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4posPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56posPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23posPC[ii,jj,kk] = accs_L23posPC[ii,d,kk]
            tensor_accs_H23posPC[ii,jj,kk] = accs_H23posPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4posPC[ii,jj,kk] = accs_L4posPC[ii,d,kk]
            tensor_accs_H4posPC[ii,jj,kk] = accs_H4posPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56posPC[ii,jj,kk] = accs_L56posPC[ii,d,kk]            
            tensor_accs_H56posPC[ii,jj,kk] = accs_H56posPC[ii,d,kk]

# %%
mean_accs_L4posPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23posPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56posPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4posPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23posPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56posPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4posPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23posPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56posPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4posPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23posPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56posPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23posPC[dd,ep] = np.mean(tensor_accs_L23posPC[:,dd,ep])
        mean_accs_H23posPC[dd,ep] = np.mean(tensor_accs_H23posPC[:,dd,ep])
        
        std_accs_L23posPC[dd,ep] = np.var(tensor_accs_L23posPC[:,dd,ep])
        std_accs_H23posPC[dd,ep] = np.var(tensor_accs_H23posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4posPC[dd,ep] = np.mean(tensor_accs_L4posPC[:,dd,ep])
        mean_accs_H4posPC[dd,ep] = np.mean(tensor_accs_H4posPC[:,dd,ep])
        
        std_accs_L4posPC[dd,ep] = np.var(tensor_accs_L4posPC[:,dd,ep])
        std_accs_H4posPC[dd,ep] = np.var(tensor_accs_H4posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56posPC[dd,ep] = np.mean(tensor_accs_L56posPC[:,dd,ep])
        mean_accs_H56posPC[dd,ep] = np.mean(tensor_accs_H56posPC[:,dd,ep])
        
        std_accs_L56posPC[dd,ep] = np.var(tensor_accs_L56posPC[:,dd,ep])
        std_accs_H56posPC[dd,ep] = np.var(tensor_accs_H56posPC[:,dd,ep])

# %%
ffpos = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Position Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,0],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,0],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,0],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,0],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,0],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,0],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Position Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,1],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,1],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,1],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,1],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,1],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,1],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Position Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,-1],yerr=std_accs_L4posPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,-1],yerr=std_accs_L23posPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,-1],yerr=std_accs_L56posPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,-1],yerr=std_accs_H4posPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,-1],yerr=std_accs_H23posPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,-1],yerr=std_accs_H56posPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
ffpos_epoch = plt.figure(figsize=(15,5))

plt.subplot(231)
plt.title('Position Decoding - 1D')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[0],yerr=std_accs_L4posPC[0],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[0],yerr=std_accs_L23posPC[0],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[0],yerr=std_accs_L56posPC[0],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[0],yerr=std_accs_H4posPC[0],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[0],yerr=std_accs_H23posPC[0],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[0],yerr=std_accs_H56posPC[0],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.subplot(232)
plt.title('Position Decoding - 2D')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[1],yerr=std_accs_L4posPC[1],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[1],yerr=std_accs_L23posPC[1],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[1],yerr=std_accs_L56posPC[1],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[1],yerr=std_accs_H4posPC[1],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[1],yerr=std_accs_H23posPC[1],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[1],yerr=std_accs_H56posPC[1],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.subplot(233)
plt.title('Position Decoding - Full Dim')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[-1],yerr=std_accs_L4posPC[-1],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[-1],yerr=std_accs_L23posPC[-1],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[-1],yerr=std_accs_L56posPC[-1],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[-1],yerr=std_accs_H4posPC[-1],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[-1],yerr=std_accs_H23posPC[-1],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[-1],yerr=std_accs_H56posPC[-1],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
fpos_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4posPC,0),yerr=np.var(mean_accs_L4posPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23posPC,0),yerr=np.var(mean_accs_L23posPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56posPC,0),yerr=np.var(mean_accs_L56posPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4posPC,0),yerr=np.var(mean_accs_H4posPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23posPC,0),yerr=np.var(mean_accs_H23posPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56posPC,0),yerr=np.var(mean_accs_H56posPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Position Decodability across Epochs - Same-Pop')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# #### Image ID and Surprise (only surprise position)

# %%
context_sub_surp = np.array([0]*2*nTest + [1]*2*nTest)

# %%
context_sub_imgIDs = {}
for cntr in range(nRuns):
    context_sub_imgIDs[cntr] = np.hstack((np.repeat(allStatesLabelsTest[cntr][:,2],nRepeats),
                                          np.repeat(allStatesLabelsTestTemp[cntr][:,2],nRepeats)))

# %%
L23imgPC = {}
L4imgPC = {}
L56imgPC = {}

H23imgPC = {}
H4imgPC = {}
H56imgPC = {}

L23surpPC = {}
L4surpPC = {}
L56surpPC = {}

H23surpPC = {}
H4surpPC = {}
H56surpPC = {}

# %%
def repsDecodeSupervisedContext(rnnActs,labels,decodeType='surprise',clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'surprise':
        nClasses = 2
    elif decodeType == 'imageID':
        nClasses = nStates
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        
        L23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][:,:,:d],context_sub_surp,decodeType='surprise')
        H23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][:,:,:d],context_sub_surp,decodeType='surprise')
        
    for d in dims4:
        L4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        
        L4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][:,:,:d],context_sub_surp,decodeType='surprise')
        H4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][:,:,:d],context_sub_surp,decodeType='surprise')
    for d in dims56:

        ## Context Sub, ImageID
        L56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')

        ## Context Sub, Surprise
        L56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][:,:,:d],context_sub_surp,decodeType='surprise')
        H56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][:,:,:d],context_sub_surp,decodeType='surprise')
# Out:
# 100%|██████████| 5/5 [13:58<00:00, 167.63s/it]

# %%
preds_L23imgPC = {}
preds_L4imgPC = {}
preds_L56imgPC = {}

preds_H23imgPC = {}
preds_H4imgPC = {}
preds_H56imgPC = {}

preds_L23surpPC = {}
preds_L4surpPC = {}
preds_L56surpPC = {}

preds_H23surpPC = {}
preds_H4surpPC = {}
preds_H56surpPC = {}

# %%
accs_L23imgPC = {}
accs_L4imgPC = {}
accs_L56imgPC = {}

accs_H23imgPC = {}
accs_H4imgPC = {}
accs_H56imgPC = {}

accs_L23surpPC = {}
accs_L4surpPC = {}
accs_L56surpPC = {}

accs_H23surpPC = {}
accs_H4surpPC = {}
accs_H56surpPC = {}

# %%
for cntr in range(nRuns):
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23imgPC[cntr,d,ep] = np.argmax(L23imgPC[cntr,d][ep],axis=-1)
            preds_H23imgPC[cntr,d,ep] = np.argmax(H23imgPC[cntr,d][ep],axis=-1)
            
            preds_L23surpPC[cntr,d,ep] = np.argmax(L23surpPC[cntr,d][ep],axis=-1)
            preds_H23surpPC[cntr,d,ep] = np.argmax(H23surpPC[cntr,d][ep],axis=-1)
            
            accs_L23imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L23imgPC[cntr,d,ep])
            accs_H23imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H23imgPC[cntr,d,ep])
            
            accs_L23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L23surpPC[cntr,d,ep])
            accs_H23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H23surpPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4imgPC[cntr,d,ep] = np.argmax(L4imgPC[cntr,d][ep],axis=-1)
            preds_H4imgPC[cntr,d,ep] = np.argmax(H4imgPC[cntr,d][ep],axis=-1)
            
            preds_L4surpPC[cntr,d,ep] = np.argmax(L4surpPC[cntr,d][ep],axis=-1)
            preds_H4surpPC[cntr,d,ep] = np.argmax(H4surpPC[cntr,d][ep],axis=-1)
            
            accs_L4imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L4imgPC[cntr,d,ep])
            accs_H4imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H4imgPC[cntr,d,ep])
            
            accs_L4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L4surpPC[cntr,d,ep])
            accs_H4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H4surpPC[cntr,d,ep])
                
        for d in dims56:        
            preds_L56imgPC[cntr,d,ep] = np.argmax(L56imgPC[cntr,d][ep],axis=-1)
            preds_H56imgPC[cntr,d,ep] = np.argmax(H56imgPC[cntr,d][ep],axis=-1)
            
            preds_L56surpPC[cntr,d,ep] = np.argmax(L56surpPC[cntr,d][ep],axis=-1)
            preds_H56surpPC[cntr,d,ep] = np.argmax(H56surpPC[cntr,d][ep],axis=-1)
            
            accs_L56imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L56imgPC[cntr,d,ep])
            accs_H56imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H56imgPC[cntr,d,ep])
            
            accs_L56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L56surpPC[cntr,d,ep])
            accs_H56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H56surpPC[cntr,d,ep])

# %%
tensor_accs_L23imgPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4imgPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56imgPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23imgPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4imgPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56imgPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_L23surpPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4surpPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56surpPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23surpPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4surpPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56surpPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23imgPC[ii,jj,kk] = accs_L23imgPC[ii,d,kk]
            tensor_accs_H23imgPC[ii,jj,kk] = accs_H23imgPC[ii,d,kk]
            
            tensor_accs_L23surpPC[ii,jj,kk] = accs_L23surpPC[ii,d,kk]
            tensor_accs_H23surpPC[ii,jj,kk] = accs_H23surpPC[ii,d,kk]
            
        
        for jj,d in enumerate(dims4):
            tensor_accs_L4imgPC[ii,jj,kk] = accs_L4imgPC[ii,d,kk]
            tensor_accs_H4imgPC[ii,jj,kk] = accs_H4imgPC[ii,d,kk]
            
            tensor_accs_L4surpPC[ii,jj,kk] = accs_L4surpPC[ii,d,kk]
            tensor_accs_H4surpPC[ii,jj,kk] = accs_H4surpPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56imgPC[ii,jj,kk] = accs_L56imgPC[ii,d,kk]
            tensor_accs_H56imgPC[ii,jj,kk] = accs_H56imgPC[ii,d,kk]

            tensor_accs_L56surpPC[ii,jj,kk] = accs_L56surpPC[ii,d,kk]
            tensor_accs_H56surpPC[ii,jj,kk] = accs_H56surpPC[ii,d,kk]

# %%
mean_accs_L4imgPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23imgPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56imgPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4imgPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23imgPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56imgPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_L4surpPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23surpPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56surpPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4surpPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23surpPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56surpPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4imgPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23imgPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56imgPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4imgPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23imgPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56imgPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4surpPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23surpPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56surpPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4surpPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23surpPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56surpPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dims in enumerate(dims23):
        mean_accs_L23imgPC[dd,ep] = np.mean(tensor_accs_L23imgPC[:,dd,ep])
        mean_accs_H23imgPC[dd,ep] = np.mean(tensor_accs_H23imgPC[:,dd,ep])
        
        std_accs_L23imgPC[dd,ep] = np.var(tensor_accs_L23imgPC[:,dd,ep])
        std_accs_H23imgPC[dd,ep] = np.var(tensor_accs_H23imgPC[:,dd,ep])
        
        mean_accs_L23surpPC[dd,ep] = np.mean(tensor_accs_L23surpPC[:,dd,ep])
        mean_accs_H23surpPC[dd,ep] = np.mean(tensor_accs_H23surpPC[:,dd,ep])
        
        std_accs_L23surpPC[dd,ep] = np.var(tensor_accs_L23surpPC[:,dd,ep])
        std_accs_H23surpPC[dd,ep] = np.var(tensor_accs_H23surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims4):
        mean_accs_L4imgPC[dd,ep] = np.mean(tensor_accs_L4imgPC[:,dd,ep])
        mean_accs_H4imgPC[dd,ep] = np.mean(tensor_accs_H4imgPC[:,dd,ep])
        
        std_accs_L4imgPC[dd,ep] = np.var(tensor_accs_L4imgPC[:,dd,ep])
        std_accs_H4imgPC[dd,ep] = np.var(tensor_accs_H4imgPC[:,dd,ep])
        
        mean_accs_L4surpPC[dd,ep] = np.mean(tensor_accs_L4surpPC[:,dd,ep])
        mean_accs_H4surpPC[dd,ep] = np.mean(tensor_accs_H4surpPC[:,dd,ep])
        
        std_accs_L4surpPC[dd,ep] = np.var(tensor_accs_L4surpPC[:,dd,ep])
        std_accs_H4surpPC[dd,ep] = np.var(tensor_accs_H4surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims56):
        mean_accs_L56imgPC[dd,ep] = np.mean(tensor_accs_L56imgPC[:,dd,ep])        
        mean_accs_H56imgPC[dd,ep] = np.mean(tensor_accs_H56imgPC[:,dd,ep])
        
        std_accs_L56imgPC[dd,ep] = np.var(tensor_accs_L56imgPC[:,dd,ep])
        std_accs_H56imgPC[dd,ep] = np.var(tensor_accs_H56imgPC[:,dd,ep])
        
        mean_accs_L56surpPC[dd,ep] = np.mean(tensor_accs_L56surpPC[:,dd,ep])
        mean_accs_H56surpPC[dd,ep] = np.mean(tensor_accs_H56surpPC[:,dd,ep])
        
        std_accs_L56surpPC[dd,ep] = np.var(tensor_accs_L56surpPC[:,dd,ep])        
        std_accs_H56surpPC[dd,ep] = np.var(tensor_accs_H56surpPC[:,dd,ep])

# %%
ffdim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Image ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,0],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,0],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,0],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,0],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,0],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,0],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Image ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,1],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,1],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,1],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,1],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,1],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,1],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Image ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,-1],yerr=std_accs_L4imgPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,-1],yerr=std_accs_L23imgPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,-1],yerr=std_accs_L56imgPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,-1],yerr=std_accs_H4imgPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,-1],yerr=std_accs_H23imgPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,-1],yerr=std_accs_H56imgPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fimg_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4imgPC,0),yerr=np.var(mean_accs_L4imgPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23imgPC,0),yerr=np.var(mean_accs_L23imgPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56imgPC,0),yerr=np.var(mean_accs_L56imgPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4imgPC,0),yerr=np.var(mean_accs_H4imgPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23imgPC,0),yerr=np.var(mean_accs_H23imgPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56imgPC,0),yerr=np.var(mean_accs_H56imgPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Image Decodability across Epochs - Same-Pop')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
ffsurp_dim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Surprise ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,0],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,0],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,0],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,0],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,0],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,0],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(132)
plt.title('Surprise ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,1],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,1],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,1],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,1],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,1],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,1],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(133)
plt.title('Surprise ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,-1],yerr=std_accs_L4surpPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,-1],yerr=std_accs_L23surpPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,-1],yerr=std_accs_L56surpPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,-1],yerr=std_accs_H4surpPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,-1],yerr=std_accs_H23surpPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,-1],yerr=std_accs_H56surpPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fsurp_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4surpPC,0),yerr=np.var(mean_accs_L4surpPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23surpPC,0),yerr=np.var(mean_accs_L23surpPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56surpPC,0),yerr=np.var(mean_accs_L56surpPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4surpPC,0),yerr=np.var(mean_accs_H4surpPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23surpPC,0),yerr=np.var(mean_accs_H23surpPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56surpPC,0),yerr=np.var(mean_accs_H56surpPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Surprise Decodability across Epochs - Same-Pop')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
np.save(pp+'preds_img_temp_L4-same-pop-lattice',preds_L4imgPC)
np.save(pp+'preds_img_temp_L23-same-pop-lattice',preds_L23imgPC)
np.save(pp+'preds_img_temp_L56-same-pop-lattice',preds_L56imgPC)
np.save(pp+'preds_img_temp_H4-same-pop-lattice',preds_H4imgPC)
np.save(pp+'preds_img_temp_H23-same-pop-lattice',preds_H23imgPC)
np.save(pp+'preds_img_temp_H56-same-pop-lattice',preds_H56imgPC)

np.save(pp+'accs_img_temp_L4-same-pop-lattice',accs_L4imgPC)
np.save(pp+'accs_img_temp_L23-same-pop-lattice',accs_L23imgPC)
np.save(pp+'accs_img_temp_L56-same-pop-lattice',accs_L56imgPC)
np.save(pp+'accs_img_temp_H4-same-pop-lattice',accs_H4imgPC)
np.save(pp+'accs_img_temp_H23-same-pop-lattice',accs_H23imgPC)
np.save(pp+'accs_img_temp_H56-same-pop-lattice',accs_H56imgPC)

# %%
np.save(pp+'preds_pos_temp_L4-same-pop-lattice',preds_L4posPC)
np.save(pp+'preds_pos_temp_L23-same-pop-lattice',preds_L23posPC)
np.save(pp+'preds_pos_temp_L56-same-pop-lattice',preds_L56posPC)
np.save(pp+'preds_pos_temp_H4-same-pop-lattice',preds_H4posPC)
np.save(pp+'preds_pos_temp_H23-same-pop-lattice',preds_H23posPC)
np.save(pp+'preds_pos_temp_H56-same-pop-lattice',preds_H56posPC)

np.save(pp+'accs_pos_temp_L4-same-pop-lattice',accs_L4posPC)
np.save(pp+'accs_pos_temp_L23-same-pop-lattice',accs_L23posPC)
np.save(pp+'accs_pos_temp_L56-same-pop-lattice',accs_L56posPC)
np.save(pp+'accs_pos_temp_H4-same-pop-lattice',accs_H4posPC)
np.save(pp+'accs_pos_temp_H23-same-pop-lattice',accs_H23posPC)
np.save(pp+'accs_pos_temp_H56-same-pop-lattice',accs_H56posPC)

# %%
np.save(pp+'preds_surp_temp_L4-same-pop-lattice',preds_L4surpPC)
np.save(pp+'preds_surp_temp_L23-same-pop-lattice',preds_L23surpPC)
np.save(pp+'preds_surp_temp_L56-same-pop-lattice',preds_L56surpPC)
np.save(pp+'preds_surp_temp_H4-same-pop-lattice',preds_H4surpPC)
np.save(pp+'preds_surp_temp_H23-same-pop-lattice',preds_H23surpPC)
np.save(pp+'preds_surp_temp_H56-same-pop-lattice',preds_H56surpPC)

np.save(pp+'accs_surp_temp_L4-same-pop-lattice',accs_L4surpPC)
np.save(pp+'accs_surp_temp_L23-same-pop-lattice',accs_L23surpPC)
np.save(pp+'accs_surp_temp_L56-same-pop-lattice',accs_L56surpPC)
np.save(pp+'accs_surp_temp_H4-same-pop-lattice',accs_H4surpPC)
np.save(pp+'accs_surp_temp_H23-same-pop-lattice',accs_H23surpPC)
np.save(pp+'accs_surp_temp_H56-same-pop-lattice',accs_H56surpPC)

# %% [markdown]
# #### Latent variable decoding

# %%
def repsDecodeSupervisedLatents(rnnActs,labels,decodeType='action',clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'action':
        nClasses = 4
    else:
        nClasses = 5
        
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
L23actPC = {}
L4actPC = {}
L56actPC = {}

H23actPC = {}
H4actPC = {}
H56actPC = {}

L23distPC = {}
L4distPC = {}
L56distPC = {}

H23distPC = {}
H4distPC = {}
H56distPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][1][:,:,:d],actionsLabelsTest[cnt].ravel())
        H23actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][4][:,:,:d],actionsLabelsTest[cnt].ravel())
    
    for d in dims4:
        L4actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][0][:,:,:d],actionsLabelsTest[cnt].ravel())
        H4actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][3][:,:,:d],actionsLabelsTest[cnt].ravel())
        
    for d in dims56:
        L56actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][2][:,:,:d],actionsLabelsTest[cnt].ravel())      
        H56actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][5][:,:,:d],actionsLabelsTest[cnt].ravel())
# Out:
# 100%|██████████| 5/5 [03:33<00:00, 42.76s/it]

# %%
preds_L23actPC = {}
preds_L4actPC = {}
preds_L56actPC = {}

preds_H23actPC = {}
preds_H4actPC = {}
preds_H56actPC = {}

# %%
accs_L23actPC = {}
accs_L4actPC = {}
accs_L56actPC = {}

accs_H23actPC = {}
accs_H4actPC = {}
accs_H56actPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23actPC[cntr,d,ep] = np.argmax(L23actPC[cntr,d][ep],axis=-1)
            preds_H23actPC[cntr,d,ep] = np.argmax(H23actPC[cntr,d][ep],axis=-1)
            
            accs_L23actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L23actPC[cntr,d,ep])
            accs_H23actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H23actPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4actPC[cntr,d,ep] = np.argmax(L4actPC[cntr,d][ep],axis=-1)
            preds_H4actPC[cntr,d,ep] = np.argmax(H4actPC[cntr,d][ep],axis=-1)
            
            accs_L4actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L4actPC[cntr,d,ep])
            accs_H4actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H4actPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56actPC[cntr,d,ep] = np.argmax(L56actPC[cntr,d][ep],axis=-1)
            preds_H56actPC[cntr,d,ep] = np.argmax(H56actPC[cntr,d][ep],axis=-1)
            
            accs_L56actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L56actPC[cntr,d,ep])
            accs_H56actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H56actPC[cntr,d,ep])

# %%
tensor_accs_L23actPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4actPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56actPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23actPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4actPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56actPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23actPC[ii,jj,kk] = accs_L23actPC[ii,d,kk]
            tensor_accs_H23actPC[ii,jj,kk] = accs_H23actPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4actPC[ii,jj,kk] = accs_L4actPC[ii,d,kk]
            tensor_accs_H4actPC[ii,jj,kk] = accs_H4actPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56actPC[ii,jj,kk] = accs_L56actPC[ii,d,kk]            
            tensor_accs_H56actPC[ii,jj,kk] = accs_H56actPC[ii,d,kk]

# %%
mean_accs_L4actPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23actPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56actPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4actPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23actPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56actPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4actPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23actPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56actPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4actPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23actPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56actPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23actPC[dd,ep] = np.mean(tensor_accs_L23actPC[:,dd,ep])
        mean_accs_H23actPC[dd,ep] = np.mean(tensor_accs_H23actPC[:,dd,ep])
        
        std_accs_L23actPC[dd,ep] = np.var(tensor_accs_L23actPC[:,dd,ep])
        std_accs_H23actPC[dd,ep] = np.var(tensor_accs_H23actPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4actPC[dd,ep] = np.mean(tensor_accs_L4actPC[:,dd,ep])
        mean_accs_H4actPC[dd,ep] = np.mean(tensor_accs_H4actPC[:,dd,ep])
        
        std_accs_L4actPC[dd,ep] = np.var(tensor_accs_L4actPC[:,dd,ep])
        std_accs_H4actPC[dd,ep] = np.var(tensor_accs_H4actPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56actPC[dd,ep] = np.mean(tensor_accs_L56actPC[:,dd,ep])
        mean_accs_H56actPC[dd,ep] = np.mean(tensor_accs_H56actPC[:,dd,ep])
        
        std_accs_L56actPC[dd,ep] = np.var(tensor_accs_L56actPC[:,dd,ep])
        std_accs_H56actPC[dd,ep] = np.var(tensor_accs_H56actPC[:,dd,ep])

# %%
ffact = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Action Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,0],yerr=std_accs_L4actPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,0],yerr=std_accs_L23actPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,0],yerr=std_accs_L56actPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,0],yerr=std_accs_H4actPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,0],yerr=std_accs_H23actPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,0],yerr=std_accs_H56actPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Action Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,1],yerr=std_accs_L4actPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,1],yerr=std_accs_L23actPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,1],yerr=std_accs_L56actPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,1],yerr=std_accs_H4actPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,1],yerr=std_accs_H23actPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,1],yerr=std_accs_H56actPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Action Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,-1],yerr=std_accs_L4actPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,-1],yerr=std_accs_L23actPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,-1],yerr=std_accs_L56actPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,-1],yerr=std_accs_H4actPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,-1],yerr=std_accs_H23actPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,-1],yerr=std_accs_H56actPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fact_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4actPC,0),yerr=np.var(mean_accs_L4actPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23actPC,0),yerr=np.var(mean_accs_L23actPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56actPC,0),yerr=np.var(mean_accs_L56actPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4actPC,0),yerr=np.var(mean_accs_H4actPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23actPC,0),yerr=np.var(mean_accs_H23actPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56actPC,0),yerr=np.var(mean_accs_H56actPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Action Decodability across Epochs - Same-Pop')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# #### Temporal accuracies

# %%
labelsTrain = {}
labelsTest = {}
labelsTestTemp = {}

# %%
for cntr in range(nRuns):
#     labelsTrain[cntr] = np.argmax(yRepsTrain[cntr]@template[cntr].T,-1)
    labelsTest[cntr] = np.argmax(yRepsTest[cntr]@template[cntr].T,-1)
    labelsTestTemp[cntr] = np.argmax(yRepsTestTemp[cntr]@template[cntr].T,-1)

# %%
# preds_train = {}
preds_test = {}
preds_temp = {}

# accs_train = np.zeros((nRuns,n_epochs+1))
accs_test = np.zeros((nRuns,n_epochs+1))
accs_temp = np.zeros((nRuns,n_epochs+1))

for cntr in range(nRuns):
#     preds_train[cntr] = np.argmax(np.abs(np.round_(out_train[cntr]))@template[cntr].T,-1)
    preds_test[cntr] = np.argmax(np.abs(np.round_(out_test[cntr]))@template[cntr].T,-1)
    preds_temp[cntr] = np.argmax(np.abs(np.round_(out_temp[cntr]))@template[cntr].T,-1)
    
    for ep in range(n_epochs+1): 
#         accs_train[cntr,ep] = accuracy_score(labelsTrain[cntr].ravel(),preds_train[cntr][ep].ravel())
        accs_test[cntr,ep] = accuracy_score(labelsTest[cntr].ravel(),preds_test[cntr][ep].ravel())
        accs_temp[cntr,ep] = accuracy_score(labelsTestTemp[cntr].ravel(),preds_temp[cntr][ep].ravel())

# %%
# plt.errorbar(np.arange(n_epochs+1),np.mean(accs_train,0),yerr=np.var(accs_train,0),fmt='-',label='Train')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_test,0),yerr=np.var(accs_test,0),fmt='-',label='Test - Clean')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_temp,0),yerr=np.var(accs_temp,0),fmt='-',label='Test - Surprise')
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend()
plt.title('Prediction accuracy in presence of temporal violation')
plt.show()

# %%
np.save(pp+'same-pop-no-violations-accs-lattice',accs_test)
np.save(pp+'same-pop-temporal-violations-accs-lattice',accs_temp)

# %% [markdown]
# ### Spatial violations

# %%
from numpy.random import normal

# %%
noise_stds = np.linspace(0,1,6)

# %%
repsTrainNoisy = {}
repsTestNoisy = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        repsTrainNoisy[cntr,nn] = repsTrain[cntr] + normal(0,noise,repsTrain[cntr].shape)
        repsTestNoisy[cntr,nn] = repsTest[cntr] + normal(0,noise,repsTest[cntr].shape)

# %%
noisy_train_loaders = {}
noisy_test_loaders = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noisy_train_loaders[cntr,nn] = makeTensorLoaders((repsTrainNoisy[cntr,nn],yRepsTrain[cntr],
                                                            eTrain[cntr],surpTrain[cntr]),batch_size,shuffle=False)
        noisy_test_loaders[cntr,nn] = makeTensorLoaders((repsTestNoisy[cntr,nn],yRepsTest[cntr],
                                                            eTest[cntr],surpTest[cntr]),batch_size,shuffle=False)

# %%
nNoise = len(noise_stds)

# %%
def pass_data_store_activations_noisy(loader, nData, 
                                nRuns=nRuns, nNoise=nNoise, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        for nn in range(nNoise):
            activations_hidden_L23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_L4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_L56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_hidden_H23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_H4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_H56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_out_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
            for e in tqdm(range(n_epochs+1)):

                cnt = 0

                ## Load model
                model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr],task='lattice')
                model[cntr].to(device)
                model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
                model[cntr].eval()

                ## Pass clean samples
                for data, f_target, lastEvent, surpriseBinary in loader[cntr,nn]:

                    if train_on_gpu:
                        data, f_targetC = data.float().cuda(), f_target.float().cuda()
                    else: data, f_targetC = data.float(), f_target.float()

                    target = f_target

                    output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                    ## Collect activations  
                    act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                    act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                    act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                    act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                    act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                    act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                    output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                    for i in range(batch_size):
                        if i < len(data):
                            label = target.data[i]

                            activations_hidden_L23_np[cntr,nn][e,cnt] = act_hidden_L23[i]
                            activations_hidden_L4_np[cntr,nn][e,cnt] = act_hidden_L4[i]
                            activations_hidden_L56_np[cntr,nn][e,cnt] = act_hidden_L56[i]

                            activations_hidden_H23_np[cntr,nn][e,cnt] = act_hidden_H23[i]
                            activations_hidden_H4_np[cntr,nn][e,cnt] = act_hidden_H4[i]
                            activations_hidden_H56_np[cntr,nn][e,cnt] = act_hidden_H56[i]

                            activations_out_np[cntr,nn][e,cnt] = output_pred[i]

                            cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# L23_train_noisy = {}
# L4_train_noisy = {}
# L56_train_noisy = {}

# H23_train_noisy = {}
# H4_train_noisy = {}
# H56_train_noisy = {}

# out_train_noisy = {}

# %%
L23_test_noisy = {}
L4_test_noisy = {}
L56_test_noisy = {}

H23_test_noisy = {}
H4_test_noisy = {}
H56_test_noisy = {}

out_test_noisy = {}

# %%
# (L23_train_noisy,L4_train_noisy,L56_train_noisy,
#  H23_train_noisy,H4_train_noisy,H56_train_noisy), out_train_noisy = pass_data_store_activations_noisy(noisy_train_loaders,nTrain)

(L23_test_noisy,L4_test_noisy,L56_test_noisy,
 H23_test_noisy,H4_test_noisy,H56_test_noisy), out_test_noisy = pass_data_store_activations_noisy(noisy_test_loaders,nTest)
# Out:
# 100%|██████████| 101/101 [00:08<00:00, 12.16it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.28it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.20it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.35it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.29it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.26it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.30it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.21it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.28it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.18it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.24it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.26it/s]
# 100%|██████████| 101/101 [00:11<00:00,  8.55it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.18it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.14it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.07it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.20it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.21it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.98it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.07it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.20it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.25it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.23it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.25it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.13it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.27it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.06it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.13it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.10it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.18it/s]

# %%
predsN_train = {}
accsN_train = np.zeros((nRuns,len(noise_stds),n_epochs+1))

predsN_test = {}
accsN_test = np.zeros((nRuns,len(noise_stds),n_epochs+1))

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        predsN_test[cntr,nn] = np.argmax(out_test_noisy[cntr,nn]@template[cntr].T,-1)
        accsN_test[cntr,nn] = np.sum(np.sum(((labelsTest[cntr] - predsN_test[cntr,nn])==0)*1,-1),-1)/(nTest*6)

# %%
name = "Dark2_r"
cmap = get_cmap(name)  # type: matplotlib.colors.ListedColormap
colors = cmap.colors  # type: list

# %%
fpredspat = plt.figure()
for nn, noise in enumerate(noise_stds):
    plt.errorbar(np.arange(n_epochs+1),np.mean(accsN_test[:,nn],0),yerr=np.var(accsN_test[:,nn],0),
                 fmt='-',label=np.round(noise,2),
                 c=colors[nn])
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend(title="Noise sigma",bbox_to_anchor=(1,0.5))
plt.title('Prediction accuracy with spatial noise - Same-Pop Microcircuit')
plt.show()

# %%
np.save(pp+'same-pop-spatial-noisy-accs-lattice',accsN_test)

# %%
#### Dimensionality (linear)
def rnnLinDim(acts):
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    eig_mat = np.zeros((nEpochs,nNeurons))
        
    for ep in tqdm(range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        cov = actsScaled.T@actsScaled
        eig_mat[ep] = eigvals(cov)
        num = np.sum(eig_mat,1)**2
        den = np.sum(eig_mat**2,1) + 1e-17
        PR = num/den
    return PR
L23LinDim = np.zeros((nRuns,n_epochs+1))
L4LinDim = np.zeros((nRuns,n_epochs+1))
L56LinDim = np.zeros((nRuns,n_epochs+1))

H23LinDim = np.zeros((nRuns,n_epochs+1))
H4LinDim = np.zeros((nRuns,n_epochs+1))
H56LinDim = np.zeros((nRuns,n_epochs+1))
for cntr in range(nRuns):
    L23LinDim[cntr] = rnnLinDim(L23_test[cntr])
    L4LinDim[cntr] = rnnLinDim(L4_test[cntr])
    L56LinDim[cntr] = rnnLinDim(L56_test[cntr])

    H23LinDim[cntr] = rnnLinDim(H23_test[cntr])
    H4LinDim[cntr] = rnnLinDim(H4_test[cntr])
    H56LinDim[cntr] = rnnLinDim(H56_test[cntr])
#### Dimensionality (non-linear)
def rnnNonLinDim(acts,nTypes=2,subsample=True,ds=100):
    
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    dims_mat = np.zeros((nEpochs,nTypes))
        
    for ep in (range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        
        if subsample:
            actsScaled = actsScaled[::ds]
        
        dims_mat[ep,0] = MiND_ML().fit(actsScaled).dimension_
#         print(dims_mat[ep,0])
        dims_mat[ep,1] = CorrInt().fit(actsScaled).dimension_
#         print(dims_mat[ep,1])
#         dims_mat[ep,2] = MLE().fit(actsScaled).dimension_
#         print(dims_mat[ep,2])
#         dims_mat[ep,3] = DANCo().fit(actsScaled).dimension_
        
    return np.mean(dims_mat,-1),dims_mat
L23NonLinDim = np.zeros((nRuns,n_epochs+1))
L4NonLinDim = np.zeros((nRuns,n_epochs+1))
L56NonLinDim = np.zeros((nRuns,n_epochs+1))

H23NonLinDim = np.zeros((nRuns,n_epochs+1))
H4NonLinDim = np.zeros((nRuns,n_epochs+1))
H56NonLinDim = np.zeros((nRuns,n_epochs+1))
L23_ND_mat = {}
L4_ND_mat = {}
L56_ND_mat = {}
H23_ND_mat = {}
H4_ND_mat = {}
H56_ND_mat = {}
for cntr in tqdm(range(nRuns)):
    L23NonLinDim[cntr], L23_ND_mat[cntr] = rnnNonLinDim(L23_test[cntr])
    L4NonLinDim[cntr], L4_ND_mat[cntr] = rnnNonLinDim(L4_test[cntr])
    L56NonLinDim[cntr], L56_ND_mat[cntr] = rnnNonLinDim(L56_test[cntr])

    H23NonLinDim[cntr], H23_ND_mat[cntr] = rnnNonLinDim(H23_test[cntr])
    H4NonLinDim[cntr], H4_ND_mat[cntr] = rnnNonLinDim(H4_test[cntr])
    H56NonLinDim[cntr], H56_ND_mat[cntr] = rnnNonLinDim(H56_test[cntr])
L23_NonLineDim_mean = np.mean(L23NonLinDim,0)
L4_NonLineDim_mean = np.mean(L4NonLinDim,0)
L56_NonLineDim_mean = np.mean(L56NonLinDim,0)

H23_NonLineDim_mean = np.mean(H23NonLinDim,0)
H4_NonLineDim_mean = np.mean(H4NonLinDim,0)
H56_NonLineDim_mean = np.mean(H56NonLinDim,0)

L23_NonLineDim_std = np.var(L23NonLinDim,0)
L4_NonLineDim_std = np.var(L4NonLinDim,0)
L56_NonLineDim_std = np.var(L56NonLinDim,0)

H23_NonLineDim_std = np.var(H23NonLinDim,0)
H4_NonLineDim_std = np.var(H4NonLinDim,0)
H56_NonLineDim_std = np.var(H56NonLinDim,0)
L23_dim = np.zeros((nRuns,n_epochs+1))
L4_dim = np.zeros((nRuns,n_epochs+1))
L56_dim = np.zeros((nRuns,n_epochs+1))

H23_dim = np.zeros((nRuns,n_epochs+1))
H4_dim = np.zeros((nRuns,n_epochs+1))
H56_dim = np.zeros((nRuns,n_epochs+1))
for cntr in range(nRuns):
    L23_dim[cntr] = L23LinDim[cntr]/L23NonLinDim[cntr]
    L4_dim[cntr] = L4LinDim[cntr]/L4NonLinDim[cntr]
    L56_dim[cntr] = L56LinDim[cntr]/L56NonLinDim[cntr]
    H23_dim[cntr] = H23LinDim[cntr]/H23NonLinDim[cntr]
    H4_dim[cntr] = H4LinDim[cntr]/H4NonLinDim[cntr]
    H56_dim[cntr] = H56LinDim[cntr]/H56NonLinDim[cntr]
np.save(pp+'L23DG_same-pop_lattice',L23_dim)
np.save(pp+'L4DG_same-pop_lattice',L4_dim)
np.save(pp+'L56DG_same-pop_lattice',L56_dim)
np.save(pp+'H23DG_same-pop_lattice',H23_dim)
np.save(pp+'H4DG_same-pop_lattice',H4_dim)
np.save(pp+'H56DG_same-pop_lattice',H56_dim)
ffTotDim = plt.figure(figsize=(5,5))

plt.subplot(111)

plt.plot(np.arange(n_epochs+1),np.mean(L4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(L4_dim,0)-np.var(L4_dim,0),np.mean(L4_dim,0)+np.var(L4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(L23_dim,0)-np.var(L23_dim,0),np.mean(L23_dim,0)+np.var(L23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(L56_dim,0)-np.var(L56_dim,0),np.mean(L56_dim,0)+np.var(L56_dim,0),alpha=0.5)

plt.plot(np.arange(n_epochs+1),np.mean(H4_dim,0),label='Higher layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(H4_dim,0)-np.var(H4_dim,0),np.mean(H4_dim,0)+np.var(H4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H23_dim,0),label='Higher layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(H23_dim,0)-np.var(H23_dim,0),np.mean(H23_dim,0)+np.var(H23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H56_dim,0),label='Higher layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(H56_dim,0)-np.var(H56_dim,0),np.mean(H56_dim,0)+np.var(H56_dim,0),alpha=0.5)

plt.xlabel('Epochs')
plt.ylabel('Dimensionality Gain')
# plt.ylim(0.9,2.2)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Same-sized Populations')
plt.show()
ffTotDim.savefig('Dimensionality-gain-same-pop-across-learning-lattice.png',dpi=300,bbox_inches='tight')
ffTotDim.savefig('Dimensionality-gain-same-pop-across-learning-lattice.svg',dpi=300,bbox_inches='tight')
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 366.92it/s]
# 100%|██████████| 101/101 [00:00<00:00, 400.28it/s]
# 100%|██████████| 101/101 [00:00<00:00, 391.99it/s]
# 100%|██████████| 101/101 [00:00<00:00, 403.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 410.00it/s]
# 100%|██████████| 101/101 [00:00<00:00, 398.70it/s]
# 100%|██████████| 101/101 [00:00<00:00, 395.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 430.94it/s]
# 100%|██████████| 101/101 [00:00<00:00, 410.00it/s]
# 100%|██████████| 101/101 [00:00<00:00, 406.70it/s]
# 100%|██████████| 101/101 [00:00<00:00, 411.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 397.17it/s]
# 100%|██████████| 101/101 [00:00<00:00, 420.21it/s]
# 100%|██████████| 101/101 [00:00<00:00, 423.70it/s]
# 100%|██████████| 101/101 [00:00<00:00, 401.87it/s]
# 100%|██████████| 101/101 [00:00<00:00, 429.11it/s]
# 100%|██████████| 101/101 [00:00<00:00, 409.95it/s]
# 100%|██████████| 101/101 [00:00<00:00, 405.08it/s]
# 100%|██████████| 101/101 [00:00<00:00, 414.07it/s]
# 100%|██████████| 101/101 [00:00<00:00, 418.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 423.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 423.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 425.45it/s]
# 100%|██████████| 101/101 [00:00<00:00, 403.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 406.71it/s]
# 100%|██████████| 101/101 [00:00<00:00, 400.28it/s]
# 100%|██████████| 101/101 [00:00<00:00, 415.04it/s]
# 100%|██████████| 101/101 [00:00<00:00, 411.56it/s]
# 100%|██████████| 101/101 [00:00<00:00, 442.23it/s]
# 100%|██████████| 101/101 [00:00<00:00, 444.22it/s]
# 100%|██████████| 5/5 [01:55<00:00, 23.10s/it]
