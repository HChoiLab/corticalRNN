# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from numpy.random import choice
from numpy.linalg import norm

from math import factorial

from itertools import permutations

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE, Isomap
import umap

from tqdm import tqdm
import os

# %%
from numpy.linalg import svd, eigvals
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, homogeneity_completeness_v_measure, confusion_matrix, ConfusionMatrixDisplay

# %%
from skdim.id import *

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import get_cmap

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.style.use('seaborn-whitegrid')
# plt.style.use('default')

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

# %%
from generate_data import generate_lattice_based_task, makeTensorLoaders

# %% [markdown]
# #### Test for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('No GPU, training on CPU')
    device = torch.device('cpu')
else:
    print('GPU found, training on GPU')
    device = torch.device('cuda')
# Out:
# GPU found, training on GPU

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Number of runs

# %%
nRuns = 5

# %% [markdown]
# #### Generate data for runs

# %%
dim = 64
nTot = 2000
latticeDim = 2

fracTrain = 0.8
fracTest = np.round(1-fracTrain,2)

nTrain = int(nTot*fracTrain)
nTest = nTot - nTrain

lenSeq = 4
nRepeats = 2

dimsL = np.array([5,5])
nStates = np.prod(dimsL)

# %%
cnt = 0
lattice_labels = np.zeros((nStates,latticeDim),dtype=int)
for y in range(-2,3):
    for x in range(-2,3):
        lattice_labels[cnt] = (x,y)
        cnt += 1

# %%
def templateMaker(nStates, dim):
    ## Generate template representations (for expected elements)
    template = np.zeros((nStates, dim))
    for ii in range(nStates):
        template[ii] = choice(2, dim, p=[0.75, 0.25])## p=[Pr(0),Pr(1)]
    return template

# %%
template = {}
for cntr in range(nRuns):
    template[cntr] = templateMaker(nStates=nStates,dim=dim)

# %%
repsTrain = {}
yRepsTrain = {}
eTrain = {}
pTrain = {}
surpTrain = {}
allStatesTrain = {}
actionsTrain = {}

# %%
repsTest = {}
yRepsTest = {}
eTest = {}
pTest = {}
surpTest = {}
allStatesTest = {}
actionsTest = {}

# %%
repsTestTemp = {}
yRepsTestTemp = {}
eTestTemp = {}
pTestTemp = {}
surpTestTemp = {}
allStatesTestTemp = {}
actionsTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]),\
    (actionsTrain[cntr],actionsTest[cntr],actionsTestTemp[cntr]) = generate_lattice_based_task(nTot,fracTrain,dim,lenSeq,
                                                                                               lattice_labels=lattice_labels,
                                                                                               latticeDim=latticeDim,
                                                                                               repeats=True, numRepeats=nRepeats,
                                                                                               template=template[cntr])

# %% [markdown]
# #### Create directories to save data and representations

# %%
pp = ## specify path

# %%
npp = {}
pp_npy = {}
pp_pts = {}

# %%
for cntr in range(nRuns):
    
    npp[cntr] = 'lattice-bidirectional-fb-'+str(cntr)+'/'
    pp_npy[cntr] = pp+npp[cntr]+'npys-'+str(cntr)+'/'
    pp_pts[cntr] = pp+npp[cntr]+'pts-'+str(cntr)+'/'
    
## uncomment the following lines to create the folders. comment out if already created
    
    # os.mkdir(os.path.join(pp,npp[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_pts[cntr]))

    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr],'Dataset/'))

# %% [markdown]
# #### Save seeds and dataset

# %%
seeds = np.random.randint(1000, size=nRuns)
np.save(pp_npy[cntr]+'seeds',seeds)

# %%
for cntr in range(nRuns):
    ## Template
    np.save(pp_npy[cntr]+'Dataset/template',template[cntr])

    ## Train Data
    np.save(pp_npy[cntr]+'Dataset/repsTrain',repsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTrain',yRepsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTrain',eTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTrain',surpTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTrain',allStatesTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTrain',actionsTrain[cntr])

    ## Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTest',repsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTest',yRepsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTest',eTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTest',surpTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTest',allStatesTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTest',actionsTest[cntr])
    
    ## Temporally violated Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTestTemp',repsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTestTemp',yRepsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTestTemp',eTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTestTemp',surpTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTestTemp',allStatesTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTestTemp',actionsTestTemp[cntr])

# %% [markdown]
# #### Load seeds

# %%
seeds = np.load(pp_npy[cntr]+'seeds.npy')

# %%
seeds
# Out:
# array([766, 804, 783, 157, 124])

# %% [markdown]
# #### Convert data into tensors, etc.

# %%
batch_size = 100 ##100

# %%
pos_seq_idx = np.array([0,0,1,1,2,2])

# %%
train_loader = {}
test_loader = {}
test_temp_loader = {}

# %%
for cntr in range(nRuns):
    train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=True)
    test_loader[cntr] = makeTensorLoaders((repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)
    test_temp_loader[cntr] = makeTensorLoaders((repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),
                                          batch_size,shuffle=False)

# %%
# kk = 3
# print(np.min(allStatesTestTemp[kk]))
# ix = np.where(allStatesTestTemp[kk]==np.min(allStatesTestTemp[kk]))[0]
# print(repsTestTemp[kk][ix])
# print(yRepsTestTemp[kk][ix])

# %% [markdown]
# #### Load architectures, models, etc.

# %%
n_latent = 16 ## make sure it is the same in the architecture file as well
pop_list = [2,5,4] ## make sure it is the same in the architecture file as well

# %%
from architecture_bidirectional_feedback import microcircuit

# %%
model = {}
optimizer_rec = {}
optimizer_pc = {}

# %%
#specify loss function
reconLoss = nn.MSELoss()

#optimizer learning rate
eta_rec = 0.001
eta_pc = 0.0001

# %%
for cntr in range(nRuns):
    model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,pop_list=pop_list,bsize=batch_size,
                               manual_seed=seeds[cntr],task='lattice')
    model[cntr].to(device)

# %%
for cntr in range(nRuns):
    optimizer_rec[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_rec)
    optimizer_pc[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_pc)

# %% [markdown]
# #### Train and collect activations

# %%
for data, f_target, lastEvent, surpriseBinary in train_loader[0]:
    if train_on_gpu:
        data, f_target = data.float().cuda(), f_target.float().cuda()
    else: data, f_target = data.float(), f_target.float()

# %%
output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[0](data)

# %%
nSteps = data.shape[1]

# %%
n_epochs = 100 ## number of epochs
div = n_epochs//n_epochs ## try ensuring that number used to divide by is a factor of n_epochs

# %%
feedback = True

# %%
def findMSE(output):
    errSq = output**2
    MSE_mat_samples_seq = errSq/np.prod(errSq.shape)
    MSE_samples = torch.mean(MSE_mat_samples_seq,1)
    return MSE_samples

# %%
train_losses = {}
test_losses = {}
temp_losses = {}

train_expected_rec_losses = {}
train_expected_fb_losses = {}

test_expected_rec_losses = {}
test_expected_fb_losses = {}

test_surprise_rec_losses = {}
test_surprise_fb_losses = {}

MSE_mat_full_test = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    train_losses[cntr] = np.zeros(n_epochs+1)
    test_losses[cntr] = np.zeros(n_epochs+1)
    temp_losses[cntr] = np.zeros(n_epochs+1)

    train_loss_min = np.Inf
    best_epoch = 0

    train_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    train_expected_fb_losses[cntr] = np.zeros(n_epochs+1)

    test_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_fb_losses[cntr] = np.zeros(n_epochs+1)
    
    test_surprise_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_surprise_fb_losses[cntr] = np.zeros(n_epochs+1)

    MSE_mat_full_test[cntr] = np.zeros(n_epochs+1)

    for epoch in (range(1,n_epochs+1)):

        train_loss = 0.0

        train_expected_rec_loss = 0.0
        train_expected_fb_loss = 0.0
        
        test_expected_rec_loss = 0.0
        test_expected_fb_loss = 0.0

        temp_rec_loss = 0.0
        temp_fb_loss = 0.0
        
        test_loss = 0.0
        temp_loss = 0.0

        cnt = 0
        
        ## Save model without training
        if epoch == 1:
            
            model[cntr].eval()
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_0.pt') ## Save model before any training
            
            ## Losses at 0th epoch
            for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
                if train_on_gpu:
                    data, f_target = data.float().cuda(), f_target.float().cuda()
                else:
                    data, f_target = data.float(), f_target.float()

                ##define all-sequence targets
                target = f_target

                optimizer_rec[cntr].zero_grad() #clears older gradients
                optimizer_pc[cntr].zero_grad() #clears older gradients
                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

                err_rec = torch.linalg.norm((output_pred-target),dim=2)
                err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
                MSE_samples_rec = findMSE(err_rec)
                MSE_samples_fb = findMSE(err_fb)

                loss = reconLoss(output_pred,target) #calculate the loss for the batch
                train_loss += loss.item()*data.size(0) #update training loss

                train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
                train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
                                    
            ## calculate average loss
            train_loss = train_loss/len(train_loader[cntr].dataset)
            
            ## Training loss at initialization
            train_losses[cntr][0] = train_loss
            train_expected_rec_losses[cntr][0] = train_expected_rec_loss
            train_expected_fb_losses[cntr][0] = train_expected_fb_loss
            
            ## Test losses at initialization
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test

                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)
                
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                # calculate the batch loss
                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
#             print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][0] = test_loss

            test_expected_rec_losses[cntr][0] = test_expected_rec_loss
            test_expected_fb_losses[cntr][0] = test_expected_fb_loss
        
        ## Test temp losses at initialization
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                    
                ##define all-sequence targets
                target_temp = f_target_temp

                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)
                loss_temp = reconLoss(output_pred_temp,target_temp)
                err_temp_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                # calculate the batch loss
                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_temp.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
#             print('Temp Loss: {:.6f}\n'.format(test_loss))

            temp_losses[cntr][0] = temp_loss

            test_surprise_rec_losses[cntr][0] = temp_rec_loss
            test_surprise_fb_losses[cntr][0] = temp_fb_loss

        #train model
        model[cntr].train()
        for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
            if train_on_gpu:
                data, f_target = data.float().cuda(), f_target.float().cuda()
            else:
                data, f_target = data.float(), f_target.float()

            ##define all-sequence targets
            target = f_target

            output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

            err_rec = torch.linalg.norm((output_pred-target),dim=2)
            err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
            MSE_samples_rec = findMSE(err_rec)
            MSE_samples_fb = findMSE(err_fb)
            
            loss = reconLoss(output_pred,target) #calculate the loss for the batch
            train_loss += loss.item()*data.size(0) #update training loss
            fbloss = torch.mean(MSE_samples_fb)

            optimizer_rec[cntr].zero_grad() #clears older gradients
            optimizer_pc[cntr].zero_grad() #clears older gradients
            ######## feedback error updates only higher-cortical area
            if (feedback)&(epoch%2==0):
                for name, param in model[cntr].named_parameters():
                    if ('FF' in name) or ('L23' in name) or ('L4' in name) or ('L56' in name):
                        param.require_grad = False
                fbloss.backward()
                optimizer_pc[cntr].step()
                for name, param in model[cntr].named_parameters():
                    param.require_grad = True
            else:
                loss.backward() #backprop
                optimizer_rec[cntr].step() #update parameters in direction of the -ve gradient  

            train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
            train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
        
        #calculate average loss
        train_loss = train_loss/len(train_loader[cntr].dataset)

        #training/validation stats
        train_losses[cntr][epoch] = train_loss
        train_expected_rec_losses[cntr][epoch] = train_expected_rec_loss
        train_expected_fb_losses[cntr][epoch] = train_expected_fb_loss

        #save model if the training loss decreased
        if train_loss <= train_loss_min:
            print('Epoch: {}, Train Loss Decreased!! ({:.6f}-->{:.6f})'.format(epoch,train_loss_min,train_loss))
            torch.save(model[cntr].state_dict(),pp_pts[cntr]+'predRNN.pt')
            train_loss_min = train_loss
            best_epoch = epoch

        if epoch%div == 0:
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_'+str(epoch)+'.pt')
            
            model[cntr].eval()
            
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test
                
                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)

                # calculate the batch loss
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
            print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][epoch] = test_loss

            test_expected_rec_losses[cntr][epoch] = test_expected_rec_loss
            test_expected_fb_losses[cntr][epoch] = test_expected_fb_loss
            
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                
                ##define all-sequence targets
                target_temp = f_target_temp
                
                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)

                # calculate the batch loss
                err_temp_rec = torch.linalg.norm((output_pred_temp-target_temp),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_temp[0],dim=2)+torch.linalg.norm(feedbackDiffs_temp[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_test.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
            print('Temp Loss: {:.6f}\n'.format(temp_loss))

            temp_losses[cntr][epoch] = temp_loss

            test_surprise_rec_losses[cntr][epoch] = temp_rec_loss
            test_surprise_fb_losses[cntr][epoch] = temp_fb_loss
            
    print('----------------------------------------------------')
            
    outF = open(pp+npp[cntr]+"training-details.txt", "w")
    outF.write('# epochs = ' + str(n_epochs))
    outF.write('\n')
    outF.write('Best epoch = '+str(best_epoch))
    outF.write('\n')
    outF.write('Minimum training loss = ' + str(train_loss_min))
    outF.write('\n')
    outF.write('Total number of samples = ' + str(nTot))
    outF.write('\n')
    outF.write('Number of training samples = ' + str(nTrain))
    outF.write('\n')
    outF.write('Number of testing samples = ' + str(nTest))
    outF.write('\n')
    outF.write('Dimensionality of representations = ' + str(dim))
    outF.write('\n')
    outF.write('Length of sequences = ' + str(lenSeq))
    outF.write('\n')
    outF.close()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1, Train Loss Decreased!! (inf-->0.195523)
# Test Loss: 0.174060
#
# Temp Loss: 0.174624
#
# Epoch: 2, Train Loss Decreased!! (0.195523-->0.172319)
# Test Loss: 0.173357
#
# Temp Loss: 0.173635
#
# Epoch: 3, Train Loss Decreased!! (0.172319-->0.171870)
# Test Loss: 0.171645
#
# Temp Loss: 0.171903
#
# Epoch: 4, Train Loss Decreased!! (0.171870-->0.170653)
# Test Loss: 0.171482
#
# Temp Loss: 0.171844
#
# Epoch: 5, Train Loss Decreased!! (0.170653-->0.170174)
# Test Loss: 0.170793
#
# Temp Loss: 0.171467
#
# Epoch: 6, Train Loss Decreased!! (0.170174-->0.169889)
# Test Loss: 0.170826
#
# Temp Loss: 0.171444
#
# Epoch: 7, Train Loss Decreased!! (0.169889-->0.169235)
# Test Loss: 0.169127
#
# Temp Loss: 0.170877
#
# Epoch: 8, Train Loss Decreased!! (0.169235-->0.168379)
# Test Loss: 0.169178
#
# Temp Loss: 0.170997
#
# Epoch: 9, Train Loss Decreased!! (0.168379-->0.167211)
# Test Loss: 0.165720
#
# Temp Loss: 0.172064
#
# Epoch: 10, Train Loss Decreased!! (0.167211-->0.165101)
# Test Loss: 0.165637
#
# Temp Loss: 0.171681
#
# Epoch: 11, Train Loss Decreased!! (0.165101-->0.163324)
# Test Loss: 0.161458
#
# Temp Loss: 0.175367
#
# Epoch: 12, Train Loss Decreased!! (0.163324-->0.160857)
# Test Loss: 0.161177
#
# Temp Loss: 0.174618
#
# Epoch: 13, Train Loss Decreased!! (0.160857-->0.159499)
# Test Loss: 0.158242
#
# Temp Loss: 0.175950
#
# Epoch: 14, Train Loss Decreased!! (0.159499-->0.158110)
# Test Loss: 0.158316
#
# Temp Loss: 0.175369
#
# Epoch: 15, Train Loss Decreased!! (0.158110-->0.156858)
# Test Loss: 0.155911
#
# Temp Loss: 0.178040
#
# Epoch: 16, Train Loss Decreased!! (0.156858-->0.154882)
# Test Loss: 0.155629
#
# Temp Loss: 0.177002
#
# Epoch: 17, Train Loss Decreased!! (0.154882-->0.153593)
# Test Loss: 0.152507
#
# Temp Loss: 0.179769
#
# Epoch: 18, Train Loss Decreased!! (0.153593-->0.151411)
# Test Loss: 0.152499
#
# Temp Loss: 0.178861
#
# Epoch: 19, Train Loss Decreased!! (0.151411-->0.150226)
# Test Loss: 0.150349
#
# Temp Loss: 0.180746
#
# Epoch: 20, Train Loss Decreased!! (0.150226-->0.148362)
# Test Loss: 0.150127
#
# Temp Loss: 0.179624
#
# Epoch: 21, Train Loss Decreased!! (0.148362-->0.147408)
# Test Loss: 0.147600
#
# Temp Loss: 0.183520
#
# Epoch: 22, Train Loss Decreased!! (0.147408-->0.145396)
# Test Loss: 0.147672
#
# Temp Loss: 0.182555
#
# Epoch: 23, Train Loss Decreased!! (0.145396-->0.144420)
# Test Loss: 0.145273
#
# Temp Loss: 0.184457
#
# Epoch: 24, Train Loss Decreased!! (0.144420-->0.142487)
# Test Loss: 0.145581
#
# Temp Loss: 0.183893
#
# Epoch: 25, Train Loss Decreased!! (0.142487-->0.141175)
# Test Loss: 0.141632
#
# Temp Loss: 0.186209
#
# Epoch: 26, Train Loss Decreased!! (0.141175-->0.138846)
# Test Loss: 0.142140
#
# Temp Loss: 0.185918
#
# Epoch: 27, Train Loss Decreased!! (0.138846-->0.136680)
# Test Loss: 0.136824
#
# Temp Loss: 0.186846
#
# Epoch: 28, Train Loss Decreased!! (0.136680-->0.133872)
# Test Loss: 0.137317
#
# Temp Loss: 0.186558
#
# Epoch: 29, Train Loss Decreased!! (0.133872-->0.131751)
# Test Loss: 0.131343
#
# Temp Loss: 0.188699
#
# Epoch: 30, Train Loss Decreased!! (0.131751-->0.128742)
# Test Loss: 0.131873
#
# Temp Loss: 0.188612
#
# Epoch: 31, Train Loss Decreased!! (0.128742-->0.126738)
# Test Loss: 0.126654
#
# Temp Loss: 0.189984
#
# Epoch: 32, Train Loss Decreased!! (0.126738-->0.123565)
# Test Loss: 0.127055
#
# Temp Loss: 0.189867
#
# Epoch: 33, Train Loss Decreased!! (0.123565-->0.121234)
# Test Loss: 0.121168
#
# Temp Loss: 0.192352
#
# Epoch: 34, Train Loss Decreased!! (0.121234-->0.117980)
# Test Loss: 0.121575
#
# Temp Loss: 0.191969
#
# Epoch: 35, Train Loss Decreased!! (0.117980-->0.115666)
# Test Loss: 0.115576
#
# Temp Loss: 0.193294
#
# Epoch: 36, Train Loss Decreased!! (0.115666-->0.112150)
# Test Loss: 0.115790
#
# Temp Loss: 0.193307
#
# Epoch: 37, Train Loss Decreased!! (0.112150-->0.109627)
# Test Loss: 0.109350
#
# Temp Loss: 0.194809
#
# Epoch: 38, Train Loss Decreased!! (0.109627-->0.105798)
# Test Loss: 0.109713
#
# Temp Loss: 0.194651
#
# Epoch: 39, Train Loss Decreased!! (0.105798-->0.102506)
# Test Loss: 0.102073
#
# Temp Loss: 0.194296
#
# Epoch: 40, Train Loss Decreased!! (0.102506-->0.097942)
# Test Loss: 0.102621
#
# Temp Loss: 0.194691
#
# Epoch: 41, Train Loss Decreased!! (0.097942-->0.094329)
# Test Loss: 0.093668
#
# Temp Loss: 0.197699
#
# Epoch: 42, Train Loss Decreased!! (0.094329-->0.089127)
# Test Loss: 0.094459
#
# Temp Loss: 0.198034
#
# Epoch: 43, Train Loss Decreased!! (0.089127-->0.085249)
# Test Loss: 0.084530
#
# Temp Loss: 0.197732
#
# Epoch: 44, Train Loss Decreased!! (0.085249-->0.079962)
# Test Loss: 0.085401
#
# Temp Loss: 0.198322
#
# Epoch: 45, Train Loss Decreased!! (0.079962-->0.075978)
# Test Loss: 0.075305
#
# Temp Loss: 0.199482
#
# Epoch: 46, Train Loss Decreased!! (0.075978-->0.070689)
# Test Loss: 0.075982
#
# Temp Loss: 0.200204
#
# Epoch: 47, Train Loss Decreased!! (0.070689-->0.066777)
# Test Loss: 0.065939
#
# Temp Loss: 0.202796
#
# Epoch: 48, Train Loss Decreased!! (0.066777-->0.061695)
# Test Loss: 0.066966
#
# Temp Loss: 0.202977
#
# Epoch: 49, Train Loss Decreased!! (0.061695-->0.057801)
# Test Loss: 0.057192
#
# Temp Loss: 0.205693
#
# Epoch: 50, Train Loss Decreased!! (0.057801-->0.052934)
# Test Loss: 0.058217
#
# Temp Loss: 0.205778
#
# Epoch: 51, Train Loss Decreased!! (0.052934-->0.049428)
# Test Loss: 0.048781
#
# Temp Loss: 0.209243
#
# Epoch: 52, Train Loss Decreased!! (0.049428-->0.045012)
# Test Loss: 0.049878
#
# Temp Loss: 0.209041
#
# Epoch: 53, Train Loss Decreased!! (0.045012-->0.041650)
# Test Loss: 0.040389
#
# Temp Loss: 0.212177
#
# Epoch: 54, Train Loss Decreased!! (0.041650-->0.037376)
# Test Loss: 0.041580
#
# Temp Loss: 0.211750
#
# Epoch: 55, Train Loss Decreased!! (0.037376-->0.034624)
# Test Loss: 0.033897
#
# Temp Loss: 0.216908
#
# Epoch: 56, Train Loss Decreased!! (0.034624-->0.031240)
# Test Loss: 0.035022
#
# Temp Loss: 0.216410
#
# Epoch: 57, Train Loss Decreased!! (0.031240-->0.028603)
# Test Loss: 0.027761
#
# Temp Loss: 0.219065
#
# Epoch: 58, Train Loss Decreased!! (0.028603-->0.025240)
# Test Loss: 0.028317
#
# Temp Loss: 0.218322
#
# Epoch: 59, Train Loss Decreased!! (0.025240-->0.022911)
# Test Loss: 0.022454
#
# Temp Loss: 0.221487
#
# Epoch: 60, Train Loss Decreased!! (0.022911-->0.020258)
# Test Loss: 0.023365
#
# Temp Loss: 0.219974
#
# Epoch: 61, Train Loss Decreased!! (0.020258-->0.018575)
# Test Loss: 0.018395
#
# Temp Loss: 0.224257
#
# Epoch: 62, Train Loss Decreased!! (0.018575-->0.016628)
# Test Loss: 0.019355
#
# Temp Loss: 0.223140
#
# Epoch: 63, Train Loss Decreased!! (0.016628-->0.015339)
# Test Loss: 0.015248
#
# Temp Loss: 0.225732
#
# Epoch: 64, Train Loss Decreased!! (0.015339-->0.013563)
# Test Loss: 0.015989
#
# Temp Loss: 0.224377
#
# Epoch: 65, Train Loss Decreased!! (0.013563-->0.012562)
# Test Loss: 0.012754
#
# Temp Loss: 0.226956
#
# Epoch: 66, Train Loss Decreased!! (0.012562-->0.011238)
# Test Loss: 0.013402
#
# Temp Loss: 0.225428
#
# Epoch: 67, Train Loss Decreased!! (0.011238-->0.010347)
# Test Loss: 0.010610
#
# Temp Loss: 0.229056
#
# Epoch: 68, Train Loss Decreased!! (0.010347-->0.009389)
# Test Loss: 0.011578
#
# Temp Loss: 0.227647
#
# Epoch: 69, Train Loss Decreased!! (0.009389-->0.008900)
# Test Loss: 0.008952
#
# Temp Loss: 0.230294
#
# Epoch: 70, Train Loss Decreased!! (0.008900-->0.007978)
# Test Loss: 0.009917
#
# Temp Loss: 0.228940
#
# Epoch: 71, Train Loss Decreased!! (0.007978-->0.007447)
# Test Loss: 0.007750
#
# Temp Loss: 0.231320
#
# Epoch: 72, Train Loss Decreased!! (0.007447-->0.006853)
# Test Loss: 0.008540
#
# Temp Loss: 0.229792
#
# Epoch: 73, Train Loss Decreased!! (0.006853-->0.006425)
# Test Loss: 0.006621
#
# Temp Loss: 0.231386
#
# Epoch: 74, Train Loss Decreased!! (0.006425-->0.005936)
# Test Loss: 0.007551
#
# Temp Loss: 0.229534
#
# Epoch: 75, Train Loss Decreased!! (0.005936-->0.005688)
# Test Loss: 0.005782
#
# Temp Loss: 0.232184
#
# Epoch: 76, Train Loss Decreased!! (0.005688-->0.005267)
# Test Loss: 0.006678
#
# Temp Loss: 0.230726
#
# Epoch: 77, Train Loss Decreased!! (0.005267-->0.005009)
# Test Loss: 0.005163
#
# Temp Loss: 0.233107
#
# Epoch: 78, Train Loss Decreased!! (0.005009-->0.004672)
# Test Loss: 0.005931
#
# Temp Loss: 0.231513
#
# Epoch: 79, Train Loss Decreased!! (0.004672-->0.004438)
# Test Loss: 0.004525
#
# Temp Loss: 0.233623
#
# Epoch: 80, Train Loss Decreased!! (0.004438-->0.004147)
# Test Loss: 0.005328
#
# Temp Loss: 0.231989
#
# Epoch: 81, Train Loss Decreased!! (0.004147-->0.003914)
# Test Loss: 0.004089
#
# Temp Loss: 0.233875
#
# Epoch: 82, Train Loss Decreased!! (0.003914-->0.003723)
# Test Loss: 0.004923
#
# Temp Loss: 0.232228
#
# Epoch: 83, Train Loss Decreased!! (0.003723-->0.003646)
# Test Loss: 0.003651
#
# Temp Loss: 0.233743
#
# Epoch: 84, Train Loss Decreased!! (0.003646-->0.003370)
# Test Loss: 0.004395
#
# Temp Loss: 0.232054
#
# Epoch: 85, Train Loss Decreased!! (0.003370-->0.003251)
# Test Loss: 0.003239
#
# Temp Loss: 0.234458
#
# Epoch: 86, Train Loss Decreased!! (0.003251-->0.003034)
# Test Loss: 0.004020
#
# Temp Loss: 0.232792
#
# Epoch: 87, Train Loss Decreased!! (0.003034-->0.003002)
# Test Loss: 0.002999
#
# Temp Loss: 0.234368
#
# Epoch: 88, Train Loss Decreased!! (0.003002-->0.002862)
# Test Loss: 0.003761
#
# Temp Loss: 0.232534
#
# Epoch: 89, Train Loss Decreased!! (0.002862-->0.002814)
# Test Loss: 0.002791
#
# Temp Loss: 0.234585
#
# Epoch: 90, Train Loss Decreased!! (0.002814-->0.002673)
# Test Loss: 0.003525
#
# Temp Loss: 0.232888
#
# Epoch: 91, Train Loss Decreased!! (0.002673-->0.002544)
# Test Loss: 0.002435
#
# Temp Loss: 0.234868
#
# Epoch: 92, Train Loss Decreased!! (0.002544-->0.002444)
# Test Loss: 0.003326
#
# Temp Loss: 0.232918
#
# Epoch: 93, Train Loss Decreased!! (0.002444-->0.002372)
# Test Loss: 0.002309
#
# Temp Loss: 0.234837
#
# Epoch: 94, Train Loss Decreased!! (0.002372-->0.002314)
# Test Loss: 0.003076
#
# Temp Loss: 0.232820
#
# Epoch: 95, Train Loss Decreased!! (0.002314-->0.002229)
# Test Loss: 0.002168
#
# Temp Loss: 0.234834
#
# Epoch: 96, Train Loss Decreased!! (0.002229-->0.002145)
# Test Loss: 0.002913
#
# Temp Loss: 0.232962
#
# Epoch: 97, Train Loss Decreased!! (0.002145-->0.002130)
# Test Loss: 0.001999
#
# Temp Loss: 0.234696
#
# Epoch: 98, Train Loss Decreased!! (0.002130-->0.002038)
# Test Loss: 0.002846
#
# Temp Loss: 0.232613
#
# Epoch: 99, Train Loss Decreased!! (0.002038-->0.002018)
# Test Loss: 0.001975
#
# Temp Loss: 0.234824
#  20%|██        | 1/5 [00:50<03:20, 50.18s/it]
# Epoch: 100, Train Loss Decreased!! (0.002018-->0.001985)
# Test Loss: 0.002671
#
# Temp Loss: 0.232726
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.221539)
# Test Loss: 0.190276
#
# Temp Loss: 0.190559
#
# Epoch: 2, Train Loss Decreased!! (0.221539-->0.189426)
# Test Loss: 0.189160
#
# Temp Loss: 0.189416
#
# Epoch: 3, Train Loss Decreased!! (0.189426-->0.187869)
# Test Loss: 0.186165
#
# Temp Loss: 0.186261
#
# Epoch: 4, Train Loss Decreased!! (0.187869-->0.186393)
# Test Loss: 0.186315
#
# Temp Loss: 0.186412
#
# Epoch: 5, Train Loss Decreased!! (0.186393-->0.185972)
# Test Loss: 0.185349
#
# Temp Loss: 0.185817
#
# Epoch: 6, Train Loss Decreased!! (0.185972-->0.185376)
# Test Loss: 0.185258
#
# Temp Loss: 0.185722
#
# Epoch: 7, Train Loss Decreased!! (0.185376-->0.185196)
# Test Loss: 0.184527
#
# Temp Loss: 0.185536
#
# Epoch: 8, Train Loss Decreased!! (0.185196-->0.184680)
# Test Loss: 0.184626
#
# Temp Loss: 0.185570
#
# Epoch: 9, Train Loss Decreased!! (0.184680-->0.184039)
# Test Loss: 0.182593
#
# Temp Loss: 0.186651
#
# Epoch: 10, Train Loss Decreased!! (0.184039-->0.182640)
# Test Loss: 0.182690
#
# Temp Loss: 0.186312
#
# Epoch: 11, Train Loss Decreased!! (0.182640-->0.181242)
# Test Loss: 0.179336
#
# Temp Loss: 0.189381
#
# Epoch: 12, Train Loss Decreased!! (0.181242-->0.179332)
# Test Loss: 0.179598
#
# Temp Loss: 0.188902
#
# Epoch: 13, Train Loss Decreased!! (0.179332-->0.177545)
# Test Loss: 0.175508
#
# Temp Loss: 0.193916
#
# Epoch: 14, Train Loss Decreased!! (0.177545-->0.175239)
# Test Loss: 0.175537
#
# Temp Loss: 0.193421
#
# Epoch: 15, Train Loss Decreased!! (0.175239-->0.173528)
# Test Loss: 0.172310
#
# Temp Loss: 0.197135
#
# Epoch: 16, Train Loss Decreased!! (0.173528-->0.171472)
# Test Loss: 0.172002
#
# Temp Loss: 0.196258
#
# Epoch: 17, Train Loss Decreased!! (0.171472-->0.170506)
# Test Loss: 0.169496
#
# Temp Loss: 0.198170
#
# Epoch: 18, Train Loss Decreased!! (0.170506-->0.168973)
# Test Loss: 0.169682
#
# Temp Loss: 0.197861
#
# Epoch: 19, Train Loss Decreased!! (0.168973-->0.167864)
# Test Loss: 0.166450
#
# Temp Loss: 0.198322
#
# Epoch: 20, Train Loss Decreased!! (0.167864-->0.165932)
# Test Loss: 0.166552
#
# Temp Loss: 0.198010
#
# Epoch: 21, Train Loss Decreased!! (0.165932-->0.164734)
# Test Loss: 0.163104
#
# Temp Loss: 0.198004
#
# Epoch: 22, Train Loss Decreased!! (0.164734-->0.162767)
# Test Loss: 0.163218
#
# Temp Loss: 0.197436
#
# Epoch: 23, Train Loss Decreased!! (0.162767-->0.161460)
# Test Loss: 0.159449
#
# Temp Loss: 0.199997
#
# Epoch: 24, Train Loss Decreased!! (0.161460-->0.159411)
# Test Loss: 0.159858
#
# Temp Loss: 0.199552
#
# Epoch: 25, Train Loss Decreased!! (0.159411-->0.158036)
# Test Loss: 0.156085
#
# Temp Loss: 0.202115
#
# Epoch: 26, Train Loss Decreased!! (0.158036-->0.155968)
# Test Loss: 0.156257
#
# Temp Loss: 0.201488
#
# Epoch: 27, Train Loss Decreased!! (0.155968-->0.154132)
# Test Loss: 0.152023
#
# Temp Loss: 0.202364
#
# Epoch: 28, Train Loss Decreased!! (0.154132-->0.151462)
# Test Loss: 0.152615
#
# Temp Loss: 0.202337
#
# Epoch: 29, Train Loss Decreased!! (0.151462-->0.149584)
# Test Loss: 0.147602
#
# Temp Loss: 0.206190
#
# Epoch: 30, Train Loss Decreased!! (0.149584-->0.146944)
# Test Loss: 0.148169
#
# Temp Loss: 0.206082
#
# Epoch: 31, Train Loss Decreased!! (0.146944-->0.145229)
# Test Loss: 0.143317
#
# Temp Loss: 0.206204
#
# Epoch: 32, Train Loss Decreased!! (0.145229-->0.142692)
# Test Loss: 0.143952
#
# Temp Loss: 0.206076
#
# Epoch: 33, Train Loss Decreased!! (0.142692-->0.140706)
# Test Loss: 0.138313
#
# Temp Loss: 0.207973
#
# Epoch: 34, Train Loss Decreased!! (0.140706-->0.137714)
# Test Loss: 0.139008
#
# Temp Loss: 0.207868
#
# Epoch: 35, Train Loss Decreased!! (0.137714-->0.135854)
# Test Loss: 0.133016
#
# Temp Loss: 0.209086
#
# Epoch: 36, Train Loss Decreased!! (0.135854-->0.132756)
# Test Loss: 0.133883
#
# Temp Loss: 0.209146
#
# Epoch: 37, Train Loss Decreased!! (0.132756-->0.130793)
# Test Loss: 0.127516
#
# Temp Loss: 0.210374
#
# Epoch: 38, Train Loss Decreased!! (0.130793-->0.127574)
# Test Loss: 0.128694
#
# Temp Loss: 0.210354
#
# Epoch: 39, Train Loss Decreased!! (0.127574-->0.124844)
# Test Loss: 0.121205
#
# Temp Loss: 0.209834
#
# Epoch: 40, Train Loss Decreased!! (0.124844-->0.120897)
# Test Loss: 0.121804
#
# Temp Loss: 0.209871
#
# Epoch: 41, Train Loss Decreased!! (0.120897-->0.118326)
# Test Loss: 0.114110
#
# Temp Loss: 0.210280
#
# Epoch: 42, Train Loss Decreased!! (0.118326-->0.114695)
# Test Loss: 0.115910
#
# Temp Loss: 0.210880
#
# Epoch: 43, Train Loss Decreased!! (0.114695-->0.111317)
# Test Loss: 0.106443
#
# Temp Loss: 0.211982
#
# Epoch: 44, Train Loss Decreased!! (0.111317-->0.106641)
# Test Loss: 0.107192
#
# Temp Loss: 0.212374
#
# Epoch: 45, Train Loss Decreased!! (0.106641-->0.103034)
# Test Loss: 0.097594
#
# Temp Loss: 0.212826
#
# Epoch: 46, Train Loss Decreased!! (0.103034-->0.098227)
# Test Loss: 0.098861
#
# Temp Loss: 0.213462
#
# Epoch: 47, Train Loss Decreased!! (0.098227-->0.093677)
# Test Loss: 0.087890
#
# Temp Loss: 0.215163
#
# Epoch: 48, Train Loss Decreased!! (0.093677-->0.088282)
# Test Loss: 0.089089
#
# Temp Loss: 0.215750
#
# Epoch: 49, Train Loss Decreased!! (0.088282-->0.083466)
# Test Loss: 0.078029
#
# Temp Loss: 0.218319
#
# Epoch: 50, Train Loss Decreased!! (0.083466-->0.077867)
# Test Loss: 0.079240
#
# Temp Loss: 0.218802
#
# Epoch: 51, Train Loss Decreased!! (0.077867-->0.073614)
# Test Loss: 0.068441
#
# Temp Loss: 0.221587
#
# Epoch: 52, Train Loss Decreased!! (0.073614-->0.068557)
# Test Loss: 0.069615
#
# Temp Loss: 0.221826
#
# Epoch: 53, Train Loss Decreased!! (0.068557-->0.064215)
# Test Loss: 0.059440
#
# Temp Loss: 0.225847
#
# Epoch: 54, Train Loss Decreased!! (0.064215-->0.059611)
# Test Loss: 0.060995
#
# Temp Loss: 0.225888
#
# Epoch: 55, Train Loss Decreased!! (0.059611-->0.055166)
# Test Loss: 0.049884
#
# Temp Loss: 0.229050
#
# Epoch: 56, Train Loss Decreased!! (0.055166-->0.049720)
# Test Loss: 0.050798
#
# Temp Loss: 0.228452
#
# Epoch: 57, Train Loss Decreased!! (0.049720-->0.045880)
# Test Loss: 0.041455
#
# Temp Loss: 0.230753
#
# Epoch: 58, Train Loss Decreased!! (0.045880-->0.041032)
# Test Loss: 0.042677
#
# Temp Loss: 0.229950
#
# Epoch: 59, Train Loss Decreased!! (0.041032-->0.037363)
# Test Loss: 0.033811
#
# Temp Loss: 0.233413
#
# Epoch: 60, Train Loss Decreased!! (0.037363-->0.033434)
# Test Loss: 0.035710
#
# Temp Loss: 0.232349
#
# Epoch: 61, Train Loss Decreased!! (0.033434-->0.030101)
# Test Loss: 0.026774
#
# Temp Loss: 0.237721
#
# Epoch: 62, Train Loss Decreased!! (0.030101-->0.026172)
# Test Loss: 0.028245
#
# Temp Loss: 0.236310
#
# Epoch: 63, Train Loss Decreased!! (0.026172-->0.023274)
# Test Loss: 0.021297
#
# Temp Loss: 0.239739
#
# Epoch: 64, Train Loss Decreased!! (0.023274-->0.020636)
# Test Loss: 0.023063
#
# Temp Loss: 0.238142
#
# Epoch: 65, Train Loss Decreased!! (0.020636-->0.017980)
# Test Loss: 0.016045
#
# Temp Loss: 0.244341
#
# Epoch: 66, Train Loss Decreased!! (0.017980-->0.015628)
# Test Loss: 0.017974
#
# Temp Loss: 0.242992
#
# Epoch: 67, Train Loss Decreased!! (0.015628-->0.013840)
# Test Loss: 0.012285
#
# Temp Loss: 0.245929
#
# Epoch: 68, Train Loss Decreased!! (0.013840-->0.011710)
# Test Loss: 0.013759
#
# Temp Loss: 0.244720
#
# Epoch: 69, Train Loss Decreased!! (0.011710-->0.010653)
# Test Loss: 0.009759
#
# Temp Loss: 0.248210
#
# Epoch: 70, Train Loss Decreased!! (0.010653-->0.009267)
# Test Loss: 0.011278
#
# Temp Loss: 0.246755
#
# Epoch: 71, Train Loss Decreased!! (0.009267-->0.008634)
# Test Loss: 0.007892
#
# Temp Loss: 0.250110
#
# Epoch: 72, Train Loss Decreased!! (0.008634-->0.007638)
# Test Loss: 0.009488
#
# Temp Loss: 0.247977
#
# Epoch: 73, Train Loss Decreased!! (0.007638-->0.007016)
# Test Loss: 0.006670
#
# Temp Loss: 0.251519
#
# Epoch: 74, Train Loss Decreased!! (0.007016-->0.006602)
# Test Loss: 0.008737
#
# Temp Loss: 0.249258
#
# Epoch: 75, Train Loss Decreased!! (0.006602-->0.006270)
# Test Loss: 0.005845
#
# Temp Loss: 0.252060
#
# Epoch: 76, Train Loss Decreased!! (0.006270-->0.005893)
# Test Loss: 0.008062
#
# Temp Loss: 0.249719
#
# Epoch: 77, Train Loss Decreased!! (0.005893-->0.005560)
# Test Loss: 0.005236
#
# Temp Loss: 0.253198
#
# Test Loss: 0.007713
#
# Temp Loss: 0.250516
#
# Epoch: 79, Train Loss Decreased!! (0.005560-->0.004988)
# Test Loss: 0.004431
#
# Temp Loss: 0.253593
#
# Epoch: 80, Train Loss Decreased!! (0.004988-->0.004389)
# Test Loss: 0.005894
#
# Temp Loss: 0.251436
#
# Epoch: 81, Train Loss Decreased!! (0.004389-->0.004131)
# Test Loss: 0.003797
#
# Temp Loss: 0.254350
#
# Epoch: 82, Train Loss Decreased!! (0.004131-->0.003808)
# Test Loss: 0.005189
#
# Temp Loss: 0.251652
#
# Epoch: 83, Train Loss Decreased!! (0.003808-->0.003672)
# Test Loss: 0.003494
#
# Temp Loss: 0.254453
#
# Epoch: 84, Train Loss Decreased!! (0.003672-->0.003539)
# Test Loss: 0.004974
#
# Temp Loss: 0.251653
#
# Epoch: 85, Train Loss Decreased!! (0.003539-->0.003415)
# Test Loss: 0.003195
#
# Temp Loss: 0.254264
#
# Epoch: 86, Train Loss Decreased!! (0.003415-->0.003154)
# Test Loss: 0.004620
#
# Temp Loss: 0.251369
#
# Test Loss: 0.002970
#
# Temp Loss: 0.254797
#
# Epoch: 88, Train Loss Decreased!! (0.003154-->0.003002)
# Test Loss: 0.004253
#
# Temp Loss: 0.251901
#
# Epoch: 89, Train Loss Decreased!! (0.003002-->0.002968)
# Test Loss: 0.002719
#
# Temp Loss: 0.255133
#
# Epoch: 90, Train Loss Decreased!! (0.002968-->0.002838)
# Test Loss: 0.004170
#
# Temp Loss: 0.251757
#
# Epoch: 91, Train Loss Decreased!! (0.002838-->0.002773)
# Test Loss: 0.002501
#
# Temp Loss: 0.255196
#
# Epoch: 92, Train Loss Decreased!! (0.002773-->0.002693)
# Test Loss: 0.004109
#
# Temp Loss: 0.251567
#
# Epoch: 93, Train Loss Decreased!! (0.002693-->0.002676)
# Test Loss: 0.002382
#
# Temp Loss: 0.255137
#
# Epoch: 94, Train Loss Decreased!! (0.002676-->0.002515)
# Test Loss: 0.003707
#
# Temp Loss: 0.251471
#
# Epoch: 95, Train Loss Decreased!! (0.002515-->0.002468)
# Test Loss: 0.002280
#
# Temp Loss: 0.255330
#
# Test Loss: 0.003915
#
# Temp Loss: 0.251179
#
# Epoch: 97, Train Loss Decreased!! (0.002468-->0.002467)
# Test Loss: 0.002118
#
# Temp Loss: 0.255429
#
# Epoch: 98, Train Loss Decreased!! (0.002467-->0.002284)
# Test Loss: 0.003404
#
# Temp Loss: 0.251564
#
# Epoch: 99, Train Loss Decreased!! (0.002284-->0.002215)
# Test Loss: 0.002025
#
# Temp Loss: 0.255549
#  40%|████      | 2/5 [01:39<02:29, 49.91s/it]
# Test Loss: 0.003426
#
# Temp Loss: 0.251252
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.214179)
# Test Loss: 0.184808
#
# Temp Loss: 0.184061
#
# Epoch: 2, Train Loss Decreased!! (0.214179-->0.184384)
# Test Loss: 0.183894
#
# Temp Loss: 0.183559
#
# Epoch: 3, Train Loss Decreased!! (0.184384-->0.183478)
# Test Loss: 0.181538
#
# Temp Loss: 0.181230
#
# Epoch: 4, Train Loss Decreased!! (0.183478-->0.182135)
# Test Loss: 0.181575
#
# Temp Loss: 0.181106
#
# Epoch: 5, Train Loss Decreased!! (0.182135-->0.181539)
# Test Loss: 0.180336
#
# Temp Loss: 0.180195
#
# Epoch: 6, Train Loss Decreased!! (0.181539-->0.180973)
# Test Loss: 0.180418
#
# Temp Loss: 0.180262
#
# Epoch: 7, Train Loss Decreased!! (0.180973-->0.180328)
# Test Loss: 0.178519
#
# Temp Loss: 0.179421
#
# Epoch: 8, Train Loss Decreased!! (0.180328-->0.178815)
# Test Loss: 0.178506
#
# Temp Loss: 0.179433
#
# Epoch: 9, Train Loss Decreased!! (0.178815-->0.177557)
# Test Loss: 0.175931
#
# Temp Loss: 0.179878
#
# Epoch: 10, Train Loss Decreased!! (0.177557-->0.175647)
# Test Loss: 0.176059
#
# Temp Loss: 0.179762
#
# Epoch: 11, Train Loss Decreased!! (0.175647-->0.174695)
# Test Loss: 0.173455
#
# Temp Loss: 0.182170
#
# Epoch: 12, Train Loss Decreased!! (0.174695-->0.173235)
# Test Loss: 0.173509
#
# Temp Loss: 0.181625
#
# Epoch: 13, Train Loss Decreased!! (0.173235-->0.172478)
# Test Loss: 0.171136
#
# Temp Loss: 0.180912
#
# Epoch: 14, Train Loss Decreased!! (0.172478-->0.170912)
# Test Loss: 0.171123
#
# Temp Loss: 0.180526
#
# Epoch: 15, Train Loss Decreased!! (0.170912-->0.169498)
# Test Loss: 0.167440
#
# Temp Loss: 0.183657
#
# Epoch: 16, Train Loss Decreased!! (0.169498-->0.166991)
# Test Loss: 0.167465
#
# Temp Loss: 0.183317
#
# Epoch: 17, Train Loss Decreased!! (0.166991-->0.165686)
# Test Loss: 0.163688
#
# Temp Loss: 0.186957
#
# Epoch: 18, Train Loss Decreased!! (0.165686-->0.163258)
# Test Loss: 0.163813
#
# Temp Loss: 0.186456
#
# Epoch: 19, Train Loss Decreased!! (0.163258-->0.161845)
# Test Loss: 0.159595
#
# Temp Loss: 0.190344
#
# Epoch: 20, Train Loss Decreased!! (0.161845-->0.159284)
# Test Loss: 0.159776
#
# Temp Loss: 0.189719
#
# Epoch: 21, Train Loss Decreased!! (0.159284-->0.157670)
# Test Loss: 0.155890
#
# Temp Loss: 0.194907
#
# Epoch: 22, Train Loss Decreased!! (0.157670-->0.155233)
# Test Loss: 0.155848
#
# Temp Loss: 0.193784
#
# Epoch: 23, Train Loss Decreased!! (0.155233-->0.153782)
# Test Loss: 0.151755
#
# Temp Loss: 0.194999
#
# Epoch: 24, Train Loss Decreased!! (0.153782-->0.151399)
# Test Loss: 0.152151
#
# Temp Loss: 0.194317
#
# Epoch: 25, Train Loss Decreased!! (0.151399-->0.149552)
# Test Loss: 0.147479
#
# Temp Loss: 0.197300
#
# Epoch: 26, Train Loss Decreased!! (0.149552-->0.146784)
# Test Loss: 0.147584
#
# Temp Loss: 0.196780
#
# Epoch: 27, Train Loss Decreased!! (0.146784-->0.144781)
# Test Loss: 0.142684
#
# Temp Loss: 0.198966
#
# Epoch: 28, Train Loss Decreased!! (0.144781-->0.141662)
# Test Loss: 0.143080
#
# Temp Loss: 0.198865
#
# Epoch: 29, Train Loss Decreased!! (0.141662-->0.139809)
# Test Loss: 0.137830
#
# Temp Loss: 0.200491
#
# Epoch: 30, Train Loss Decreased!! (0.139809-->0.136572)
# Test Loss: 0.138360
#
# Temp Loss: 0.199830
#
# Epoch: 31, Train Loss Decreased!! (0.136572-->0.134169)
# Test Loss: 0.132495
#
# Temp Loss: 0.200104
#
# Epoch: 32, Train Loss Decreased!! (0.134169-->0.130783)
# Test Loss: 0.133164
#
# Temp Loss: 0.199958
#
# Epoch: 33, Train Loss Decreased!! (0.130783-->0.128297)
# Test Loss: 0.126293
#
# Temp Loss: 0.202148
#
# Epoch: 34, Train Loss Decreased!! (0.128297-->0.124346)
# Test Loss: 0.127207
#
# Temp Loss: 0.201990
#
# Epoch: 35, Train Loss Decreased!! (0.124346-->0.121450)
# Test Loss: 0.119917
#
# Temp Loss: 0.202816
#
# Epoch: 36, Train Loss Decreased!! (0.121450-->0.117054)
# Test Loss: 0.120617
#
# Temp Loss: 0.202975
#
# Epoch: 37, Train Loss Decreased!! (0.117054-->0.113903)
# Test Loss: 0.112800
#
# Temp Loss: 0.205520
#
# Epoch: 38, Train Loss Decreased!! (0.113903-->0.109548)
# Test Loss: 0.113374
#
# Temp Loss: 0.205370
#
# Epoch: 39, Train Loss Decreased!! (0.109548-->0.106116)
# Test Loss: 0.104845
#
# Temp Loss: 0.206136
#
# Epoch: 40, Train Loss Decreased!! (0.106116-->0.101579)
# Test Loss: 0.105684
#
# Temp Loss: 0.205855
#
# Epoch: 41, Train Loss Decreased!! (0.101579-->0.097626)
# Test Loss: 0.095845
#
# Temp Loss: 0.208401
#
# Epoch: 42, Train Loss Decreased!! (0.097626-->0.092335)
# Test Loss: 0.096765
#
# Temp Loss: 0.208373
#
# Epoch: 43, Train Loss Decreased!! (0.092335-->0.088425)
# Test Loss: 0.086166
#
# Temp Loss: 0.209679
#
# Epoch: 44, Train Loss Decreased!! (0.088425-->0.083084)
# Test Loss: 0.087273
#
# Temp Loss: 0.209555
#
# Epoch: 45, Train Loss Decreased!! (0.083084-->0.078771)
# Test Loss: 0.075963
#
# Temp Loss: 0.212163
#
# Epoch: 46, Train Loss Decreased!! (0.078771-->0.073465)
# Test Loss: 0.077461
#
# Temp Loss: 0.211875
#
# Epoch: 47, Train Loss Decreased!! (0.073465-->0.069000)
# Test Loss: 0.066450
#
# Temp Loss: 0.215792
#
# Epoch: 48, Train Loss Decreased!! (0.069000-->0.064054)
# Test Loss: 0.067503
#
# Temp Loss: 0.215724
#
# Epoch: 49, Train Loss Decreased!! (0.064054-->0.059536)
# Test Loss: 0.056047
#
# Temp Loss: 0.219079
#
# Epoch: 50, Train Loss Decreased!! (0.059536-->0.054287)
# Test Loss: 0.057661
#
# Temp Loss: 0.218923
#
# Epoch: 51, Train Loss Decreased!! (0.054287-->0.050121)
# Test Loss: 0.047104
#
# Temp Loss: 0.221729
#
# Epoch: 52, Train Loss Decreased!! (0.050121-->0.045145)
# Test Loss: 0.048054
#
# Temp Loss: 0.221758
#
# Epoch: 53, Train Loss Decreased!! (0.045145-->0.041220)
# Test Loss: 0.038235
#
# Temp Loss: 0.223891
#
# Epoch: 54, Train Loss Decreased!! (0.041220-->0.037067)
# Test Loss: 0.040051
#
# Temp Loss: 0.223740
#
# Epoch: 55, Train Loss Decreased!! (0.037067-->0.033680)
# Test Loss: 0.031006
#
# Temp Loss: 0.227724
#
# Epoch: 56, Train Loss Decreased!! (0.033680-->0.029886)
# Test Loss: 0.032385
#
# Temp Loss: 0.227449
#
# Epoch: 57, Train Loss Decreased!! (0.029886-->0.027019)
# Test Loss: 0.024717
#
# Temp Loss: 0.230546
#
# Epoch: 58, Train Loss Decreased!! (0.027019-->0.024064)
# Test Loss: 0.026619
#
# Temp Loss: 0.230257
#
# Epoch: 59, Train Loss Decreased!! (0.024064-->0.021713)
# Test Loss: 0.020073
#
# Temp Loss: 0.233607
#
# Epoch: 60, Train Loss Decreased!! (0.021713-->0.019342)
# Test Loss: 0.021839
#
# Temp Loss: 0.233108
#
# Epoch: 61, Train Loss Decreased!! (0.019342-->0.017329)
# Test Loss: 0.015899
#
# Temp Loss: 0.235814
#
# Epoch: 62, Train Loss Decreased!! (0.017329-->0.015504)
# Test Loss: 0.017793
#
# Temp Loss: 0.235019
#
# Epoch: 63, Train Loss Decreased!! (0.015504-->0.014109)
# Test Loss: 0.013068
#
# Temp Loss: 0.237439
#
# Epoch: 64, Train Loss Decreased!! (0.014109-->0.012417)
# Test Loss: 0.014400
#
# Temp Loss: 0.236693
#
# Epoch: 65, Train Loss Decreased!! (0.012417-->0.011556)
# Test Loss: 0.010641
#
# Temp Loss: 0.238656
#
# Epoch: 66, Train Loss Decreased!! (0.011556-->0.010494)
# Test Loss: 0.012494
#
# Temp Loss: 0.237570
#
# Epoch: 67, Train Loss Decreased!! (0.010494-->0.009683)
# Test Loss: 0.008784
#
# Temp Loss: 0.240336
#
# Epoch: 68, Train Loss Decreased!! (0.009683-->0.008762)
# Test Loss: 0.010867
#
# Temp Loss: 0.239302
#
# Epoch: 69, Train Loss Decreased!! (0.008762-->0.007900)
# Test Loss: 0.007422
#
# Temp Loss: 0.241148
#
# Epoch: 70, Train Loss Decreased!! (0.007900-->0.007496)
# Test Loss: 0.009286
#
# Temp Loss: 0.239909
#
# Epoch: 71, Train Loss Decreased!! (0.007496-->0.006866)
# Test Loss: 0.006360
#
# Temp Loss: 0.242033
#
# Epoch: 72, Train Loss Decreased!! (0.006866-->0.006639)
# Test Loss: 0.008512
#
# Temp Loss: 0.240639
#
# Epoch: 73, Train Loss Decreased!! (0.006639-->0.006008)
# Test Loss: 0.005990
#
# Temp Loss: 0.242568
#
# Test Loss: 0.008179
#
# Temp Loss: 0.241472
#
# Epoch: 75, Train Loss Decreased!! (0.006008-->0.005387)
# Test Loss: 0.004931
#
# Temp Loss: 0.242496
#
# Epoch: 76, Train Loss Decreased!! (0.005387-->0.004969)
# Test Loss: 0.006309
#
# Temp Loss: 0.241316
#
# Epoch: 77, Train Loss Decreased!! (0.004969-->0.004589)
# Test Loss: 0.004361
#
# Temp Loss: 0.243116
#
# Epoch: 78, Train Loss Decreased!! (0.004589-->0.004338)
# Test Loss: 0.005634
#
# Temp Loss: 0.241751
#
# Epoch: 79, Train Loss Decreased!! (0.004338-->0.004077)
# Test Loss: 0.003804
#
# Temp Loss: 0.243343
#
# Epoch: 80, Train Loss Decreased!! (0.004077-->0.003794)
# Test Loss: 0.004868
#
# Temp Loss: 0.241852
#
# Epoch: 81, Train Loss Decreased!! (0.003794-->0.003611)
# Test Loss: 0.003345
#
# Temp Loss: 0.243485
#
# Epoch: 82, Train Loss Decreased!! (0.003611-->0.003398)
# Test Loss: 0.004382
#
# Temp Loss: 0.241644
#
# Test Loss: 0.003111
#
# Temp Loss: 0.243922
#
# Epoch: 84, Train Loss Decreased!! (0.003398-->0.003188)
# Test Loss: 0.004159
#
# Temp Loss: 0.242285
#
# Epoch: 85, Train Loss Decreased!! (0.003188-->0.003076)
# Test Loss: 0.002939
#
# Temp Loss: 0.243953
#
# Epoch: 86, Train Loss Decreased!! (0.003076-->0.002868)
# Test Loss: 0.003717
#
# Temp Loss: 0.242323
#
# Epoch: 87, Train Loss Decreased!! (0.002868-->0.002837)
# Test Loss: 0.002618
#
# Temp Loss: 0.244117
#
# Epoch: 88, Train Loss Decreased!! (0.002837-->0.002709)
# Test Loss: 0.003500
#
# Temp Loss: 0.242390
#
# Epoch: 89, Train Loss Decreased!! (0.002709-->0.002658)
# Test Loss: 0.002531
#
# Temp Loss: 0.244210
#
# Epoch: 90, Train Loss Decreased!! (0.002658-->0.002529)
# Test Loss: 0.003421
#
# Temp Loss: 0.242369
#
# Test Loss: 0.002384
#
# Temp Loss: 0.243959
#
# Epoch: 92, Train Loss Decreased!! (0.002529-->0.002468)
# Test Loss: 0.003463
#
# Temp Loss: 0.241958
#
# Epoch: 93, Train Loss Decreased!! (0.002468-->0.002395)
# Test Loss: 0.002198
#
# Temp Loss: 0.244234
#
# Epoch: 94, Train Loss Decreased!! (0.002395-->0.002312)
# Test Loss: 0.003107
#
# Temp Loss: 0.242235
#
# Epoch: 95, Train Loss Decreased!! (0.002312-->0.002297)
# Test Loss: 0.002136
#
# Temp Loss: 0.244492
#
# Epoch: 96, Train Loss Decreased!! (0.002297-->0.002195)
# Test Loss: 0.003071
#
# Temp Loss: 0.242439
#
# Test Loss: 0.002010
#
# Temp Loss: 0.244683
#
# Epoch: 98, Train Loss Decreased!! (0.002195-->0.002153)
# Test Loss: 0.003017
#
# Temp Loss: 0.242526
#
# Test Loss: 0.001968
#
# Temp Loss: 0.244385
#  60%|██████    | 3/5 [02:29<01:39, 49.59s/it]
# Epoch: 100, Train Loss Decreased!! (0.002153-->0.002087)
# Test Loss: 0.002895
#
# Temp Loss: 0.242221
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.222556)
# Test Loss: 0.189984
#
# Temp Loss: 0.189945
#
# Epoch: 2, Train Loss Decreased!! (0.222556-->0.189777)
# Test Loss: 0.189450
#
# Temp Loss: 0.189203
#
# Epoch: 3, Train Loss Decreased!! (0.189777-->0.188795)
# Test Loss: 0.186851
#
# Temp Loss: 0.187094
#
# Epoch: 4, Train Loss Decreased!! (0.188795-->0.187469)
# Test Loss: 0.186785
#
# Temp Loss: 0.187069
#
# Epoch: 5, Train Loss Decreased!! (0.187469-->0.186986)
# Test Loss: 0.185990
#
# Temp Loss: 0.186261
#
# Epoch: 6, Train Loss Decreased!! (0.186986-->0.186422)
# Test Loss: 0.186026
#
# Temp Loss: 0.185969
#
# Epoch: 7, Train Loss Decreased!! (0.186422-->0.186301)
# Test Loss: 0.185480
#
# Temp Loss: 0.185639
#
# Epoch: 8, Train Loss Decreased!! (0.186301-->0.185773)
# Test Loss: 0.185569
#
# Temp Loss: 0.185777
#
# Epoch: 9, Train Loss Decreased!! (0.185773-->0.185230)
# Test Loss: 0.183509
#
# Temp Loss: 0.184946
#
# Epoch: 10, Train Loss Decreased!! (0.185230-->0.183877)
# Test Loss: 0.183666
#
# Temp Loss: 0.184969
#
# Epoch: 11, Train Loss Decreased!! (0.183877-->0.182156)
# Test Loss: 0.179997
#
# Temp Loss: 0.186898
#
# Epoch: 12, Train Loss Decreased!! (0.182156-->0.179602)
# Test Loss: 0.179962
#
# Temp Loss: 0.186901
#
# Epoch: 13, Train Loss Decreased!! (0.179602-->0.177738)
# Test Loss: 0.175832
#
# Temp Loss: 0.191568
#
# Epoch: 14, Train Loss Decreased!! (0.177738-->0.175137)
# Test Loss: 0.175980
#
# Temp Loss: 0.191172
#
# Epoch: 15, Train Loss Decreased!! (0.175137-->0.173608)
# Test Loss: 0.172416
#
# Temp Loss: 0.195690
#
# Epoch: 16, Train Loss Decreased!! (0.173608-->0.171231)
# Test Loss: 0.172281
#
# Temp Loss: 0.194771
#
# Epoch: 17, Train Loss Decreased!! (0.171231-->0.170031)
# Test Loss: 0.169395
#
# Temp Loss: 0.196423
#
# Epoch: 18, Train Loss Decreased!! (0.170031-->0.168149)
# Test Loss: 0.169466
#
# Temp Loss: 0.195898
#
# Epoch: 19, Train Loss Decreased!! (0.168149-->0.167476)
# Test Loss: 0.167422
#
# Temp Loss: 0.197569
#
# Epoch: 20, Train Loss Decreased!! (0.167476-->0.165968)
# Test Loss: 0.167185
#
# Temp Loss: 0.196765
#
# Epoch: 21, Train Loss Decreased!! (0.165968-->0.165443)
# Test Loss: 0.165537
#
# Temp Loss: 0.199066
#
# Epoch: 22, Train Loss Decreased!! (0.165443-->0.164154)
# Test Loss: 0.165688
#
# Temp Loss: 0.198757
#
# Epoch: 23, Train Loss Decreased!! (0.164154-->0.163510)
# Test Loss: 0.163284
#
# Temp Loss: 0.198975
#
# Epoch: 24, Train Loss Decreased!! (0.163510-->0.161972)
# Test Loss: 0.163228
#
# Temp Loss: 0.198279
#
# Epoch: 25, Train Loss Decreased!! (0.161972-->0.161141)
# Test Loss: 0.160899
#
# Temp Loss: 0.200640
#
# Epoch: 26, Train Loss Decreased!! (0.161141-->0.159236)
# Test Loss: 0.161156
#
# Temp Loss: 0.200249
#
# Epoch: 27, Train Loss Decreased!! (0.159236-->0.158693)
# Test Loss: 0.158151
#
# Temp Loss: 0.202751
#
# Epoch: 28, Train Loss Decreased!! (0.158693-->0.156580)
# Test Loss: 0.158491
#
# Temp Loss: 0.202328
#
# Epoch: 29, Train Loss Decreased!! (0.156580-->0.155422)
# Test Loss: 0.155161
#
# Temp Loss: 0.206465
#
# Epoch: 30, Train Loss Decreased!! (0.155422-->0.152976)
# Test Loss: 0.155556
#
# Temp Loss: 0.205427
#
# Epoch: 31, Train Loss Decreased!! (0.152976-->0.151981)
# Test Loss: 0.152392
#
# Temp Loss: 0.208624
#
# Epoch: 32, Train Loss Decreased!! (0.151981-->0.149789)
# Test Loss: 0.152578
#
# Temp Loss: 0.207272
#
# Epoch: 33, Train Loss Decreased!! (0.149789-->0.148175)
# Test Loss: 0.148207
#
# Temp Loss: 0.210054
#
# Epoch: 34, Train Loss Decreased!! (0.148175-->0.145586)
# Test Loss: 0.148487
#
# Temp Loss: 0.208902
#
# Epoch: 35, Train Loss Decreased!! (0.145586-->0.144440)
# Test Loss: 0.144563
#
# Temp Loss: 0.212261
#
# Epoch: 36, Train Loss Decreased!! (0.144440-->0.142000)
# Test Loss: 0.144939
#
# Temp Loss: 0.210655
#
# Epoch: 37, Train Loss Decreased!! (0.142000-->0.140216)
# Test Loss: 0.139520
#
# Temp Loss: 0.212975
#
# Epoch: 38, Train Loss Decreased!! (0.140216-->0.137176)
# Test Loss: 0.139566
#
# Temp Loss: 0.210740
#
# Epoch: 39, Train Loss Decreased!! (0.137176-->0.135338)
# Test Loss: 0.133678
#
# Temp Loss: 0.215334
#
# Epoch: 40, Train Loss Decreased!! (0.135338-->0.132393)
# Test Loss: 0.135084
#
# Temp Loss: 0.213969
#
# Epoch: 41, Train Loss Decreased!! (0.132393-->0.129892)
# Test Loss: 0.128169
#
# Temp Loss: 0.216791
#
# Epoch: 42, Train Loss Decreased!! (0.129892-->0.127014)
# Test Loss: 0.129864
#
# Temp Loss: 0.215283
#
# Epoch: 43, Train Loss Decreased!! (0.127014-->0.124203)
# Test Loss: 0.121712
#
# Temp Loss: 0.218587
#
# Epoch: 44, Train Loss Decreased!! (0.124203-->0.120234)
# Test Loss: 0.123538
#
# Temp Loss: 0.216761
#
# Epoch: 45, Train Loss Decreased!! (0.120234-->0.117703)
# Test Loss: 0.115673
#
# Temp Loss: 0.220415
#
# Epoch: 46, Train Loss Decreased!! (0.117703-->0.114250)
# Test Loss: 0.117886
#
# Temp Loss: 0.218622
#
# Epoch: 47, Train Loss Decreased!! (0.114250-->0.111096)
# Test Loss: 0.108098
#
# Temp Loss: 0.223022
#
# Epoch: 48, Train Loss Decreased!! (0.111096-->0.106355)
# Test Loss: 0.110496
#
# Temp Loss: 0.221625
#
# Epoch: 49, Train Loss Decreased!! (0.106355-->0.103177)
# Test Loss: 0.100296
#
# Temp Loss: 0.224526
#
# Epoch: 50, Train Loss Decreased!! (0.103177-->0.098197)
# Test Loss: 0.101653
#
# Temp Loss: 0.222989
#
# Epoch: 51, Train Loss Decreased!! (0.098197-->0.094303)
# Test Loss: 0.090466
#
# Temp Loss: 0.227257
#
# Epoch: 52, Train Loss Decreased!! (0.094303-->0.088978)
# Test Loss: 0.093876
#
# Temp Loss: 0.225711
#
# Epoch: 53, Train Loss Decreased!! (0.088978-->0.085225)
# Test Loss: 0.081013
#
# Temp Loss: 0.229535
#
# Epoch: 54, Train Loss Decreased!! (0.085225-->0.079852)
# Test Loss: 0.084890
#
# Temp Loss: 0.228164
#
# Epoch: 55, Train Loss Decreased!! (0.079852-->0.075320)
# Test Loss: 0.071201
#
# Temp Loss: 0.230832
#
# Epoch: 56, Train Loss Decreased!! (0.075320-->0.069470)
# Test Loss: 0.073891
#
# Temp Loss: 0.229094
#
# Epoch: 57, Train Loss Decreased!! (0.069470-->0.064765)
# Test Loss: 0.060995
#
# Temp Loss: 0.234101
#
# Epoch: 58, Train Loss Decreased!! (0.064765-->0.060530)
# Test Loss: 0.065687
#
# Temp Loss: 0.232220
#
# Epoch: 59, Train Loss Decreased!! (0.060530-->0.055618)
# Test Loss: 0.050714
#
# Temp Loss: 0.235780
#
# Epoch: 60, Train Loss Decreased!! (0.055618-->0.050451)
# Test Loss: 0.056334
#
# Temp Loss: 0.234508
#
# Epoch: 61, Train Loss Decreased!! (0.050451-->0.046468)
# Test Loss: 0.042084
#
# Temp Loss: 0.237441
#
# Epoch: 62, Train Loss Decreased!! (0.046468-->0.041405)
# Test Loss: 0.046156
#
# Temp Loss: 0.236159
#
# Epoch: 63, Train Loss Decreased!! (0.041405-->0.037812)
# Test Loss: 0.033730
#
# Temp Loss: 0.240050
#
# Epoch: 64, Train Loss Decreased!! (0.037812-->0.032835)
# Test Loss: 0.036591
#
# Temp Loss: 0.238969
#
# Epoch: 65, Train Loss Decreased!! (0.032835-->0.029560)
# Test Loss: 0.026442
#
# Temp Loss: 0.242126
#
# Epoch: 66, Train Loss Decreased!! (0.029560-->0.026459)
# Test Loss: 0.030995
#
# Temp Loss: 0.241408
#
# Epoch: 67, Train Loss Decreased!! (0.026459-->0.024303)
# Test Loss: 0.020755
#
# Temp Loss: 0.245153
#
# Epoch: 68, Train Loss Decreased!! (0.024303-->0.020943)
# Test Loss: 0.024621
#
# Temp Loss: 0.243733
#
# Epoch: 69, Train Loss Decreased!! (0.020943-->0.018486)
# Test Loss: 0.015839
#
# Temp Loss: 0.248420
#
# Epoch: 70, Train Loss Decreased!! (0.018486-->0.016719)
# Test Loss: 0.021348
#
# Temp Loss: 0.246960
#
# Epoch: 71, Train Loss Decreased!! (0.016719-->0.015217)
# Test Loss: 0.012946
#
# Temp Loss: 0.249797
#
# Epoch: 72, Train Loss Decreased!! (0.015217-->0.013137)
# Test Loss: 0.016644
#
# Temp Loss: 0.248669
#
# Epoch: 73, Train Loss Decreased!! (0.013137-->0.012146)
# Test Loss: 0.010472
#
# Temp Loss: 0.252092
#
# Epoch: 74, Train Loss Decreased!! (0.012146-->0.010695)
# Test Loss: 0.014196
#
# Temp Loss: 0.250334
#
# Epoch: 75, Train Loss Decreased!! (0.010695-->0.009907)
# Test Loss: 0.008038
#
# Temp Loss: 0.254680
#
# Epoch: 76, Train Loss Decreased!! (0.009907-->0.009554)
# Test Loss: 0.013661
#
# Temp Loss: 0.252612
#
# Epoch: 77, Train Loss Decreased!! (0.009554-->0.009100)
# Test Loss: 0.007155
#
# Temp Loss: 0.256163
#
# Epoch: 78, Train Loss Decreased!! (0.009100-->0.008284)
# Test Loss: 0.011862
#
# Temp Loss: 0.253752
#
# Epoch: 79, Train Loss Decreased!! (0.008284-->0.007531)
# Test Loss: 0.006710
#
# Temp Loss: 0.256628
#
# Epoch: 80, Train Loss Decreased!! (0.007531-->0.007263)
# Test Loss: 0.010251
#
# Temp Loss: 0.254308
#
# Epoch: 81, Train Loss Decreased!! (0.007263-->0.006464)
# Test Loss: 0.005623
#
# Temp Loss: 0.257595
#
# Epoch: 82, Train Loss Decreased!! (0.006464-->0.006309)
# Test Loss: 0.008691
#
# Temp Loss: 0.254915
#
# Epoch: 83, Train Loss Decreased!! (0.006309-->0.005589)
# Test Loss: 0.004755
#
# Temp Loss: 0.257378
#
# Epoch: 84, Train Loss Decreased!! (0.005589-->0.005252)
# Test Loss: 0.007231
#
# Temp Loss: 0.254965
#
# Epoch: 85, Train Loss Decreased!! (0.005252-->0.004865)
# Test Loss: 0.004195
#
# Temp Loss: 0.257333
#
# Epoch: 86, Train Loss Decreased!! (0.004865-->0.004491)
# Test Loss: 0.006423
#
# Temp Loss: 0.254560
#
# Epoch: 87, Train Loss Decreased!! (0.004491-->0.004430)
# Test Loss: 0.003896
#
# Temp Loss: 0.258293
#
# Epoch: 88, Train Loss Decreased!! (0.004430-->0.004161)
# Test Loss: 0.006153
#
# Temp Loss: 0.255266
#
# Epoch: 89, Train Loss Decreased!! (0.004161-->0.004111)
# Test Loss: 0.003541
#
# Temp Loss: 0.258713
#
# Epoch: 90, Train Loss Decreased!! (0.004111-->0.003984)
# Test Loss: 0.006253
#
# Temp Loss: 0.255589
#
# Epoch: 91, Train Loss Decreased!! (0.003984-->0.003906)
# Test Loss: 0.003303
#
# Temp Loss: 0.259015
#
# Epoch: 92, Train Loss Decreased!! (0.003906-->0.003755)
# Test Loss: 0.005688
#
# Temp Loss: 0.255680
#
# Epoch: 93, Train Loss Decreased!! (0.003755-->0.003735)
# Test Loss: 0.003178
#
# Temp Loss: 0.258835
#
# Epoch: 94, Train Loss Decreased!! (0.003735-->0.003556)
# Test Loss: 0.005393
#
# Temp Loss: 0.255636
#
# Epoch: 95, Train Loss Decreased!! (0.003556-->0.003543)
# Test Loss: 0.003001
#
# Temp Loss: 0.259388
#
# Epoch: 96, Train Loss Decreased!! (0.003543-->0.003275)
# Test Loss: 0.004829
#
# Temp Loss: 0.255856
#
# Epoch: 97, Train Loss Decreased!! (0.003275-->0.003234)
# Test Loss: 0.002733
#
# Temp Loss: 0.259061
#
# Test Loss: 0.005100
#
# Temp Loss: 0.255251
#
# Epoch: 99, Train Loss Decreased!! (0.003234-->0.003229)
# Test Loss: 0.002664
#
# Temp Loss: 0.259356
#  80%|████████  | 4/5 [03:19<00:49, 49.80s/it]
# Epoch: 100, Train Loss Decreased!! (0.003229-->0.003125)
# Test Loss: 0.004828
#
# Temp Loss: 0.255501
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.208880)
# Test Loss: 0.185207
#
# Temp Loss: 0.185735
#
# Epoch: 2, Train Loss Decreased!! (0.208880-->0.184443)
# Test Loss: 0.184558
#
# Temp Loss: 0.184829
#
# Epoch: 3, Train Loss Decreased!! (0.184443-->0.184074)
# Test Loss: 0.182856
#
# Temp Loss: 0.183426
#
# Epoch: 4, Train Loss Decreased!! (0.184074-->0.182605)
# Test Loss: 0.182931
#
# Temp Loss: 0.183431
#
# Epoch: 5, Train Loss Decreased!! (0.182605-->0.182241)
# Test Loss: 0.182053
#
# Temp Loss: 0.182702
#
# Epoch: 6, Train Loss Decreased!! (0.182241-->0.181652)
# Test Loss: 0.181891
#
# Temp Loss: 0.182778
#
# Epoch: 7, Train Loss Decreased!! (0.181652-->0.180823)
# Test Loss: 0.179615
#
# Temp Loss: 0.182597
#
# Epoch: 8, Train Loss Decreased!! (0.180823-->0.179224)
# Test Loss: 0.179679
#
# Temp Loss: 0.182446
#
# Epoch: 9, Train Loss Decreased!! (0.179224-->0.177363)
# Test Loss: 0.175094
#
# Temp Loss: 0.184658
#
# Epoch: 10, Train Loss Decreased!! (0.177363-->0.174706)
# Test Loss: 0.175141
#
# Temp Loss: 0.184299
#
# Epoch: 11, Train Loss Decreased!! (0.174706-->0.172616)
# Test Loss: 0.170569
#
# Temp Loss: 0.186555
#
# Epoch: 12, Train Loss Decreased!! (0.172616-->0.170123)
# Test Loss: 0.170912
#
# Temp Loss: 0.186210
#
# Epoch: 13, Train Loss Decreased!! (0.170123-->0.168569)
# Test Loss: 0.167387
#
# Temp Loss: 0.187414
#
# Epoch: 14, Train Loss Decreased!! (0.168569-->0.166460)
# Test Loss: 0.167194
#
# Temp Loss: 0.186446
#
# Epoch: 15, Train Loss Decreased!! (0.166460-->0.165148)
# Test Loss: 0.163677
#
# Temp Loss: 0.188344
#
# Epoch: 16, Train Loss Decreased!! (0.165148-->0.163104)
# Test Loss: 0.163860
#
# Temp Loss: 0.187974
#
# Epoch: 17, Train Loss Decreased!! (0.163104-->0.161506)
# Test Loss: 0.160196
#
# Temp Loss: 0.191467
#
# Epoch: 18, Train Loss Decreased!! (0.161506-->0.159154)
# Test Loss: 0.160252
#
# Temp Loss: 0.191051
#
# Epoch: 19, Train Loss Decreased!! (0.159154-->0.158041)
# Test Loss: 0.157560
#
# Temp Loss: 0.195908
#
# Epoch: 20, Train Loss Decreased!! (0.158041-->0.156181)
# Test Loss: 0.157436
#
# Temp Loss: 0.195504
#
# Epoch: 21, Train Loss Decreased!! (0.156181-->0.155284)
# Test Loss: 0.154959
#
# Temp Loss: 0.196064
#
# Epoch: 22, Train Loss Decreased!! (0.155284-->0.153977)
# Test Loss: 0.155199
#
# Temp Loss: 0.195923
#
# Epoch: 23, Train Loss Decreased!! (0.153977-->0.152998)
# Test Loss: 0.152633
#
# Temp Loss: 0.197352
#
# Epoch: 24, Train Loss Decreased!! (0.152998-->0.150978)
# Test Loss: 0.152596
#
# Temp Loss: 0.197284
#
# Epoch: 25, Train Loss Decreased!! (0.150978-->0.150065)
# Test Loss: 0.149286
#
# Temp Loss: 0.198849
#
# Epoch: 26, Train Loss Decreased!! (0.150065-->0.147748)
# Test Loss: 0.149864
#
# Temp Loss: 0.199308
#
# Epoch: 27, Train Loss Decreased!! (0.147748-->0.146532)
# Test Loss: 0.145865
#
# Temp Loss: 0.200917
#
# Epoch: 28, Train Loss Decreased!! (0.146532-->0.144225)
# Test Loss: 0.146537
#
# Temp Loss: 0.201606
#
# Epoch: 29, Train Loss Decreased!! (0.144225-->0.142538)
# Test Loss: 0.141723
#
# Temp Loss: 0.201633
#
# Epoch: 30, Train Loss Decreased!! (0.142538-->0.140022)
# Test Loss: 0.142842
#
# Temp Loss: 0.203179
#
# Epoch: 31, Train Loss Decreased!! (0.140022-->0.138163)
# Test Loss: 0.137944
#
# Temp Loss: 0.202753
#
# Epoch: 32, Train Loss Decreased!! (0.138163-->0.135421)
# Test Loss: 0.138787
#
# Temp Loss: 0.204100
#
# Epoch: 33, Train Loss Decreased!! (0.135421-->0.133510)
# Test Loss: 0.133257
#
# Temp Loss: 0.205112
#
# Epoch: 34, Train Loss Decreased!! (0.133510-->0.130603)
# Test Loss: 0.134428
#
# Temp Loss: 0.206350
#
# Epoch: 35, Train Loss Decreased!! (0.130603-->0.128666)
# Test Loss: 0.127961
#
# Temp Loss: 0.205492
#
# Epoch: 36, Train Loss Decreased!! (0.128666-->0.125490)
# Test Loss: 0.129432
#
# Temp Loss: 0.206703
#
# Epoch: 37, Train Loss Decreased!! (0.125490-->0.123662)
# Test Loss: 0.123722
#
# Temp Loss: 0.207268
#
# Epoch: 38, Train Loss Decreased!! (0.123662-->0.120503)
# Test Loss: 0.125077
#
# Temp Loss: 0.208103
#
# Epoch: 39, Train Loss Decreased!! (0.120503-->0.118194)
# Test Loss: 0.117767
#
# Temp Loss: 0.207320
#
# Epoch: 40, Train Loss Decreased!! (0.118194-->0.114244)
# Test Loss: 0.119054
#
# Temp Loss: 0.207875
#
# Epoch: 41, Train Loss Decreased!! (0.114244-->0.111544)
# Test Loss: 0.111179
#
# Temp Loss: 0.210343
#
# Epoch: 42, Train Loss Decreased!! (0.111544-->0.107523)
# Test Loss: 0.112798
#
# Temp Loss: 0.211202
#
# Epoch: 43, Train Loss Decreased!! (0.107523-->0.103754)
# Test Loss: 0.102075
#
# Temp Loss: 0.210802
#
# Epoch: 44, Train Loss Decreased!! (0.103754-->0.099131)
# Test Loss: 0.104301
#
# Temp Loss: 0.211455
#
# Epoch: 45, Train Loss Decreased!! (0.099131-->0.094936)
# Test Loss: 0.092744
#
# Temp Loss: 0.213397
#
# Epoch: 46, Train Loss Decreased!! (0.094936-->0.089579)
# Test Loss: 0.094664
#
# Temp Loss: 0.214131
#
# Epoch: 47, Train Loss Decreased!! (0.089579-->0.085497)
# Test Loss: 0.083004
#
# Temp Loss: 0.215571
#
# Epoch: 48, Train Loss Decreased!! (0.085497-->0.080446)
# Test Loss: 0.085036
#
# Temp Loss: 0.216132
#
# Epoch: 49, Train Loss Decreased!! (0.080446-->0.075841)
# Test Loss: 0.072871
#
# Temp Loss: 0.215350
#
# Epoch: 50, Train Loss Decreased!! (0.075841-->0.070655)
# Test Loss: 0.074818
#
# Temp Loss: 0.215786
#
# Epoch: 51, Train Loss Decreased!! (0.070655-->0.066783)
# Test Loss: 0.064225
#
# Temp Loss: 0.217961
#
# Epoch: 52, Train Loss Decreased!! (0.066783-->0.062244)
# Test Loss: 0.066676
#
# Temp Loss: 0.218643
#
# Epoch: 53, Train Loss Decreased!! (0.062244-->0.058663)
# Test Loss: 0.056401
#
# Temp Loss: 0.221360
#
# Epoch: 54, Train Loss Decreased!! (0.058663-->0.054014)
# Test Loss: 0.058187
#
# Temp Loss: 0.221172
#
# Epoch: 55, Train Loss Decreased!! (0.054014-->0.050545)
# Test Loss: 0.048446
#
# Temp Loss: 0.223474
#
# Epoch: 56, Train Loss Decreased!! (0.050545-->0.046431)
# Test Loss: 0.050900
#
# Temp Loss: 0.223329
#
# Epoch: 57, Train Loss Decreased!! (0.046431-->0.043299)
# Test Loss: 0.041638
#
# Temp Loss: 0.226529
#
# Epoch: 58, Train Loss Decreased!! (0.043299-->0.039644)
# Test Loss: 0.043567
#
# Temp Loss: 0.226288
#
# Epoch: 59, Train Loss Decreased!! (0.039644-->0.036648)
# Test Loss: 0.034681
#
# Temp Loss: 0.228793
#
# Epoch: 60, Train Loss Decreased!! (0.036648-->0.033219)
# Test Loss: 0.037071
#
# Temp Loss: 0.228443
#
# Epoch: 61, Train Loss Decreased!! (0.033219-->0.030454)
# Test Loss: 0.028800
#
# Temp Loss: 0.231372
#
# Epoch: 62, Train Loss Decreased!! (0.030454-->0.027297)
# Test Loss: 0.030360
#
# Temp Loss: 0.231189
#
# Epoch: 63, Train Loss Decreased!! (0.027297-->0.025006)
# Test Loss: 0.023554
#
# Temp Loss: 0.234520
#
# Epoch: 64, Train Loss Decreased!! (0.025006-->0.022650)
# Test Loss: 0.025723
#
# Temp Loss: 0.234146
#
# Epoch: 65, Train Loss Decreased!! (0.022650-->0.020660)
# Test Loss: 0.019606
#
# Temp Loss: 0.236598
#
# Epoch: 66, Train Loss Decreased!! (0.020660-->0.018394)
# Test Loss: 0.021276
#
# Temp Loss: 0.236085
#
# Epoch: 67, Train Loss Decreased!! (0.018394-->0.016914)
# Test Loss: 0.016015
#
# Temp Loss: 0.239229
#
# Epoch: 68, Train Loss Decreased!! (0.016914-->0.015322)
# Test Loss: 0.018198
#
# Temp Loss: 0.238631
#
# Epoch: 69, Train Loss Decreased!! (0.015322-->0.014055)
# Test Loss: 0.013126
#
# Temp Loss: 0.239832
#
# Epoch: 70, Train Loss Decreased!! (0.014055-->0.012633)
# Test Loss: 0.015164
#
# Temp Loss: 0.239013
#
# Epoch: 71, Train Loss Decreased!! (0.012633-->0.011663)
# Test Loss: 0.011013
#
# Temp Loss: 0.242354
#
# Epoch: 72, Train Loss Decreased!! (0.011663-->0.010802)
# Test Loss: 0.013154
#
# Temp Loss: 0.240994
#
# Epoch: 73, Train Loss Decreased!! (0.010802-->0.009967)
# Test Loss: 0.009269
#
# Temp Loss: 0.242888
#
# Epoch: 74, Train Loss Decreased!! (0.009967-->0.009499)
# Test Loss: 0.012119
#
# Temp Loss: 0.241706
#
# Epoch: 75, Train Loss Decreased!! (0.009499-->0.008772)
# Test Loss: 0.008033
#
# Temp Loss: 0.243705
#
# Epoch: 76, Train Loss Decreased!! (0.008772-->0.008153)
# Test Loss: 0.010397
#
# Temp Loss: 0.242317
#
# Epoch: 77, Train Loss Decreased!! (0.008153-->0.007602)
# Test Loss: 0.007042
#
# Temp Loss: 0.244395
#
# Epoch: 78, Train Loss Decreased!! (0.007602-->0.007339)
# Test Loss: 0.009547
#
# Temp Loss: 0.242699
#
# Epoch: 79, Train Loss Decreased!! (0.007339-->0.006906)
# Test Loss: 0.006143
#
# Temp Loss: 0.244660
#
# Epoch: 80, Train Loss Decreased!! (0.006906-->0.006265)
# Test Loss: 0.008186
#
# Temp Loss: 0.242713
#
# Epoch: 81, Train Loss Decreased!! (0.006265-->0.005877)
# Test Loss: 0.005439
#
# Temp Loss: 0.245784
#
# Epoch: 82, Train Loss Decreased!! (0.005877-->0.005741)
# Test Loss: 0.007712
#
# Temp Loss: 0.243420
#
# Epoch: 83, Train Loss Decreased!! (0.005741-->0.005348)
# Test Loss: 0.004811
#
# Temp Loss: 0.245963
#
# Epoch: 84, Train Loss Decreased!! (0.005348-->0.005104)
# Test Loss: 0.006723
#
# Temp Loss: 0.243784
#
# Epoch: 85, Train Loss Decreased!! (0.005104-->0.004828)
# Test Loss: 0.004472
#
# Temp Loss: 0.246121
#
# Epoch: 86, Train Loss Decreased!! (0.004828-->0.004721)
# Test Loss: 0.006303
#
# Temp Loss: 0.243713
#
# Epoch: 87, Train Loss Decreased!! (0.004721-->0.004504)
# Test Loss: 0.004131
#
# Temp Loss: 0.246171
#
# Epoch: 88, Train Loss Decreased!! (0.004504-->0.004467)
# Test Loss: 0.005956
#
# Temp Loss: 0.243987
#
# Epoch: 89, Train Loss Decreased!! (0.004467-->0.004223)
# Test Loss: 0.003831
#
# Temp Loss: 0.246823
#
# Epoch: 90, Train Loss Decreased!! (0.004223-->0.004167)
# Test Loss: 0.005873
#
# Temp Loss: 0.244033
#
# Epoch: 91, Train Loss Decreased!! (0.004167-->0.003938)
# Test Loss: 0.003610
#
# Temp Loss: 0.246618
#
# Test Loss: 0.005368
#
# Temp Loss: 0.243932
#
# Epoch: 93, Train Loss Decreased!! (0.003938-->0.003718)
# Test Loss: 0.003347
#
# Temp Loss: 0.246798
#
# Epoch: 94, Train Loss Decreased!! (0.003718-->0.003604)
# Test Loss: 0.005015
#
# Temp Loss: 0.244005
#
# Epoch: 95, Train Loss Decreased!! (0.003604-->0.003420)
# Test Loss: 0.003122
#
# Temp Loss: 0.246626
#
# Test Loss: 0.004895
#
# Temp Loss: 0.243754
#
# Epoch: 97, Train Loss Decreased!! (0.003420-->0.003266)
# Test Loss: 0.002996
#
# Temp Loss: 0.247529
#
# Epoch: 98, Train Loss Decreased!! (0.003266-->0.003228)
# Test Loss: 0.004533
#
# Temp Loss: 0.244545
#
# Epoch: 99, Train Loss Decreased!! (0.003228-->0.003066)
# Test Loss: 0.002738
#
# Temp Loss: 0.247087
# 100%|██████████| 5/5 [04:13<00:00, 50.72s/it]
# Epoch: 100, Train Loss Decreased!! (0.003066-->0.003045)
# Test Loss: 0.004536
#
# Temp Loss: 0.243887
#
# ----------------------------------------------------

# %%
train_losses_mat = np.zeros((nRuns,n_epochs+1))
test_losses_mat = np.zeros((nRuns,n_epochs+1))
temp_losses_mat = np.zeros((nRuns,n_epochs+1))

train_expected_losses_mat = np.zeros((nRuns,n_epochs+1))

test_expected_losses_mat = np.zeros((nRuns,n_epochs+1))
test_surprise_losses_mat = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    train_losses_mat[cntr] = train_losses[cntr]
    test_losses_mat[cntr] = test_losses[cntr]
    temp_losses_mat[cntr] = temp_losses[cntr]
    
    train_expected_losses_mat[cntr] = train_expected_rec_losses[cntr]
    
    test_expected_losses_mat[cntr] = test_expected_rec_losses[cntr]
    test_surprise_losses_mat[cntr] = test_surprise_rec_losses[cntr]

# %%
train_losses_mean = np.mean(train_losses_mat,axis=0)
test_losses_mean = np.mean(test_losses_mat,axis=0)
temp_losses_mean = np.mean(temp_losses_mat,axis=0)

train_expected_losses_mean = np.mean(train_expected_losses_mat,axis=0)

test_expected_losses_mean = np.mean(test_expected_losses_mat,axis=0)
test_surprise_losses_mean = np.mean(test_surprise_losses_mat,axis=0)

# %%
train_losses_std = np.std(train_losses_mat,axis=0)
test_losses_std = np.std(test_losses_mat,axis=0)
temp_losses_std = np.std(test_losses_mat,axis=0)

train_expected_losses_std = np.std(train_expected_losses_mat,axis=0)

test_expected_losses_std = np.std(test_expected_losses_mat,axis=0)
test_surprise_losses_std = np.std(test_surprise_losses_mat,axis=0)

# %%
train_expected_losses_mean[0] = train_losses_mean[0]

# %%
f = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.errorbar(np.arange(n_epochs+1),train_losses_mean,yerr=train_losses_std)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,2)
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.subplot(2,2,3)
plt.errorbar(np.arange(n_epochs+1),test_losses_mean,yerr=test_losses_std)
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,4)
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
# kk=4
# a = np.unique(allStatesTest[kk][:,0])
# b = np.unique(allStatesTrain[kk][:,0])
# len(np.intersect1d(a,b))

# %% [markdown]
# ### Representational Analyses

# %% [markdown]
# #### RNN Names

# %%
rnn_names = ['L4','L23','L56','H4','H23','H56']

# %%
# analyses_train_loader = {}

# %%
# for cntr in range(nRuns):
#     analyses_train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
#                                            batch_size,shuffle=False)

# %% [markdown]
# #### Pass data and store activations

# %%
def pass_data_store_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        activations_hidden_L23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_L4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_L56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_hidden_H23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_H4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_H56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_out_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
        for e in tqdm(range(n_epochs+1)):

            cnt = 0

            ## Load model
            model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr],task='lattice')
            model[cntr].to(device)
            model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
            model[cntr].eval()

            ## Pass clean samples
            for data, f_target, lastEvent, surpriseBinary in loader[cntr]:

                if train_on_gpu:
                    data, f_targetC = data.float().cuda(), f_target.float().cuda()
                else: data, f_targetC = data.float(), f_target.float()

                target = f_target

                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                ## Collect activations  
                act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                for i in range(batch_size):
                    if i < len(data):
                        label = target.data[i]

                        activations_hidden_L23_np[cntr][e,cnt] = act_hidden_L23[i]
                        activations_hidden_L4_np[cntr][e,cnt] = act_hidden_L4[i]
                        activations_hidden_L56_np[cntr][e,cnt] = act_hidden_L56[i]

                        activations_hidden_H23_np[cntr][e,cnt] = act_hidden_H23[i]
                        activations_hidden_H4_np[cntr][e,cnt] = act_hidden_H4[i]
                        activations_hidden_H56_np[cntr][e,cnt] = act_hidden_H56[i]

                        activations_out_np[cntr][e,cnt] = output_pred[i]

                        cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# (L23_train,L4_train,L56_train,
#  H23_train,H4_train,H56_train,), out_train = pass_data_store_activations(analyses_train_loader, nTrain)

# %%
(L23_test,L4_test,L56_test,
 H23_test,H4_test,H56_test), out_test = pass_data_store_activations(test_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:08<00:00, 11.43it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.44it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.27it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.99it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.93it/s]

# %%
(L23_temp,L4_temp,L56_temp,
 H23_temp,H4_temp,H56_temp), out_temp = pass_data_store_activations(test_temp_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:08<00:00, 11.37it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.40it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.38it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.31it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.39it/s]

# %% [markdown]
# #### PCA for RNNs

# %%
def repsPCA(rnnActs):
    nEpochs, nSeqs, nRolls, nNeurons = rnnActs.shape
    pca_dict = {}
    nSamps = nSeqs*nRolls
    dimPCA = min(nNeurons,nSamps)
    repsR_transformed = np.zeros((nEpochs,nSamps,dimPCA))
    
    for ep in tqdm(range(nEpochs)):
        
        reps = rnnActs[ep]
        
        ## reshape
        repsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        for ii in range(nSeqs):
            for jj in range(nRolls):
                repsR[cnt] = reps[ii,jj]
                cnt += 1
        ## PCA
        rnnPCA = PCA()
        repsR_transformed[ep] = rnnPCA.fit_transform(repsR)
        pca_dict[str(ep)] = rnnPCA
        
    return repsR_transformed, pca_dict

# %%
L23pca_train = {}
L4pca_train = {}
L56pca_train = {}

H23pca_train = {}
H4pca_train = {}
H56pca_train = {}

L23pca_test = {}
L4pca_test = {}
L56pca_test = {}

H23pca_test = {}
H4pca_test = {}
H56pca_test = {}

L23pca_temp = {}
L4pca_temp = {}
L56pca_temp = {}

H23pca_temp = {}
H4pca_temp = {}
H56pca_temp = {}

# %%
# for cntr in range(nRuns):
#     L23pca_train[cntr], _ = repsPCA(L23_train[cntr])
#     L4pca_train[cntr], _ = repsPCA(L4_train[cntr])
#     L56pca_train[cntr], _ = repsPCA(L56_train[cntr])

#     H23pca_train[cntr], _ = repsPCA(H23_train[cntr])
#     H4pca_train[cntr], _ = repsPCA(H4_train[cntr])
#     H56pca_train[cntr], _ = repsPCA(H56_train[cntr])

# %%
for cntr in range(nRuns):
    L23pca_test[cntr], _ = repsPCA(L23_test[cntr])
    L4pca_test[cntr], _ = repsPCA(L4_test[cntr])
    L56pca_test[cntr], _ = repsPCA(L56_test[cntr])

    H23pca_test[cntr], _ = repsPCA(H23_test[cntr])
    H4pca_test[cntr], _ = repsPCA(H4_test[cntr])
    H56pca_test[cntr], _ = repsPCA(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 124.41it/s]
# 100%|██████████| 101/101 [00:00<00:00, 295.25it/s]
# 100%|██████████| 101/101 [00:00<00:00, 157.01it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.18it/s]
# 100%|██████████| 101/101 [00:00<00:00, 298.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 156.76it/s]
# 100%|██████████| 101/101 [00:00<00:00, 129.01it/s]
# 100%|██████████| 101/101 [00:00<00:00, 305.95it/s]
# 100%|██████████| 101/101 [00:00<00:00, 159.23it/s]
# 100%|██████████| 101/101 [00:00<00:00, 134.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 294.39it/s]
# 100%|██████████| 101/101 [00:00<00:00, 162.55it/s]
# 100%|██████████| 101/101 [00:00<00:00, 132.03it/s]
# 100%|██████████| 101/101 [00:00<00:00, 313.53it/s]
# 100%|██████████| 101/101 [00:00<00:00, 158.98it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.35it/s]
# 100%|██████████| 101/101 [00:00<00:00, 306.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 159.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 125.96it/s]
# 100%|██████████| 101/101 [00:00<00:00, 291.84it/s]
# 100%|██████████| 101/101 [00:00<00:00, 162.03it/s]
# 100%|██████████| 101/101 [00:00<00:00, 133.95it/s]
# 100%|██████████| 101/101 [00:00<00:00, 300.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 161.77it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.35it/s]
# 100%|██████████| 101/101 [00:00<00:00, 298.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 146.77it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.35it/s]
# 100%|██████████| 101/101 [00:00<00:00, 308.75it/s]
# 100%|██████████| 101/101 [00:00<00:00, 159.73it/s]

# %%
for cntr in range(nRuns):
    L23pca_temp[cntr], _ = repsPCA(L23_temp[cntr])
    L4pca_temp[cntr], _ = repsPCA(L4_temp[cntr])
    L56pca_temp[cntr], _ = repsPCA(L56_temp[cntr])

    H23pca_temp[cntr], _ = repsPCA(H23_temp[cntr])
    H4pca_temp[cntr], _ = repsPCA(H4_temp[cntr])
    H56pca_temp[cntr], _ = repsPCA(H56_temp[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 135.21it/s]
# 100%|██████████| 101/101 [00:00<00:00, 291.01it/s]
# 100%|██████████| 101/101 [00:00<00:00, 152.75it/s]
# 100%|██████████| 101/101 [00:00<00:00, 132.90it/s]
# 100%|██████████| 101/101 [00:00<00:00, 284.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 164.13it/s]
# 100%|██████████| 101/101 [00:00<00:00, 130.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 305.95it/s]
# 100%|██████████| 101/101 [00:00<00:00, 159.23it/s]
# 100%|██████████| 101/101 [00:00<00:00, 132.38it/s]
# 100%|██████████| 101/101 [00:00<00:00, 282.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 157.99it/s]
# 100%|██████████| 101/101 [00:00<00:00, 135.75it/s]
# 100%|██████████| 101/101 [00:00<00:00, 291.84it/s]
# 100%|██████████| 101/101 [00:00<00:00, 158.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 130.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 291.84it/s]
# 100%|██████████| 101/101 [00:00<00:00, 161.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 126.27it/s]
# 100%|██████████| 101/101 [00:00<00:00, 311.60it/s]
# 100%|██████████| 101/101 [00:00<00:00, 160.24it/s]
# 100%|██████████| 101/101 [00:00<00:00, 132.38it/s]
# 100%|██████████| 101/101 [00:00<00:00, 310.64it/s]
# 100%|██████████| 101/101 [00:00<00:00, 161.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 135.39it/s]
# 100%|██████████| 101/101 [00:00<00:00, 296.98it/s]
# 100%|██████████| 101/101 [00:00<00:00, 154.37it/s]
# 100%|██████████| 101/101 [00:00<00:00, 132.90it/s]
# 100%|██████████| 101/101 [00:00<00:00, 299.62it/s]
# 100%|██████████| 101/101 [00:00<00:00, 161.26it/s]

# %% [markdown]
# #### Labels, etc.

# %%
allStatesLabelsTrain = {}
allStatesLabelsTest = {}
allStatesLabelsTestTemp = {}

actionsLabelsTrain = {}
actionsLabelsTest = {}
actionsLabelsTestTemp = {}

# %%
def allStatesLabels(allStates,latLabs):
    nSamps, nSeqs, nDim = allStates.shape
    labels = np.zeros((nSamps,nSeqs),dtype=int)
    for ii in range(nSamps):
        for jj in range(nSeqs):
            labels[ii,jj] = np.where((latLabs[:,None] == allStates[ii,jj]).all(-1).any(-1)==1)[0][0]
    return labels

# %%
for cntr in range(nRuns):
#     allStatesLabelsTrain[cntr] = allStatesLabels(allStatesTrain[cntr],lattice_labels)
    allStatesLabelsTest[cntr] = allStatesLabels(allStatesTest[cntr],lattice_labels)
    allStatesLabelsTestTemp[cntr] = allStatesLabels(allStatesTestTemp[cntr],lattice_labels)
    
#     actionsLabelsTrain[cntr] = np.argmax(actionsTrain[cntr],-1)
    actionsLabelsTest[cntr] = np.argmax(actionsTest[cntr],-1)
    actionsLabelsTestTemp[cntr] = np.argmax(actionsTestTemp[cntr],-1)

# %%
# idxs0_train = np.array([6*x for x in range(nTrain)])
# idxs1_train = idxs0_train + 1
# idxs2_train = idxs0_train + 2
# idxs3_train = idxs0_train + 3
# idxs4_train = idxs0_train + 4
# idxs5_train = idxs0_train + 5

# %%
idxs0_test = np.array([6*x for x in range(nTest)])
idxs1_test = idxs0_test + 1
idxs2_test = idxs0_test + 2
idxs3_test = idxs0_test + 3
idxs4_test = idxs0_test + 4
idxs5_test = idxs0_test + 5

# %%
idxs_test_surp = np.sort(np.hstack((idxs4_test,idxs5_test)))

# %%
pos_test = np.tile(np.arange(nSteps),nTest).ravel()

# %% [markdown]
# #### Plots

# %% [markdown]
# #### Coloured by states

# %%
# cnt = 0
# ep = 50
# ix = idxs5_test
# seq = 3 ##0-3
# c = allStatesLabelsTest[cnt][:,seq] + 1
# s = 10#1*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = allStatesTest[cnt][:,seq,xy] + 0.5
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %% [markdown]
# #### Coloured by distance from lattice centre

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %% [markdown]
# #### 3D plot

# %%
# cnt = 1
# ix = idxs0_test
# seq = 0

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# c = np.repeat(c,n_epochs+1,0)
# s = 10#5*c

# sub = 1
# colmap = 'copper'

# Zs = np.repeat(np.arange(n_epochs+1).reshape(-1,1),nTest,1)

# %%
# fig = plt.figure(figsize=(17,12))

# ax = fig.add_subplot(2, 3, 1, projection='3d')
# ax.scatter3D(L4pca_test[cnt][:,ix,0].ravel()[::sub],L4pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 2, projection='3d')
# ax.scatter3D(L23pca_test[cnt][:,ix,0].ravel()[::sub],L23pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 3, projection='3d')
# ax.scatter3D(L56pca_test[cnt][:,ix,0].ravel()[::sub],L56pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 4, projection='3d')
# ax.scatter3D(H4pca_test[cnt][:,ix,0].ravel()[::sub],H4pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 5, projection='3d')
# ax.scatter3D(H23pca_test[cnt][:,ix,0].ravel()[::sub],H23pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 6, projection='3d')
# ax.scatter3D(H56pca_test[cnt][:,ix,0].ravel()[::sub],H56pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# plt.show()

# %% [markdown]
# #### Coloured by actions

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 3 ##0-3
# step = 5
# c = actionsLabelsTest[cnt][:,step] + 1
# s = 5*c
# colmap='Set1'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 2 ##0-3
# step = 5
# c = (actionsLabelsTest[cnt][:,step]%2)*1. + 1
# s = 5*c
# colmap='Dark2'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 2 ##0-3
# step = 5
# c = (actionsLabelsTest[cnt][:,step]>1)*1. + 1
# s = 5*c
# colmap='Dark2'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = 50
# ix = idxs4_test
# seq = 2 ##0-3
# step = 3
# c = allStatesLabelsTest[cnt][:,seq]
# s = 1*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs_surp
# seq = -1 ##0-3
# step = 4
# # c = actionsLabelsTest[cnt][:,step]
# # s = 5*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H5/6')

# %% [markdown]
# #### Supervised Decoding

# %% [markdown]
# #### Position

# %%
def repsDecodeSupervisedPosition(rnnActs,labels,clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    nClasses = 6
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
testPCs = {}
tempPCs = {}

contextPCs_sub = {}

# %%
for cntr in range(nRuns):
    testPCs[cntr] = (L4pca_test[cntr],L23pca_test[cntr],L56pca_test[cntr],
                     H4pca_test[cntr],H23pca_test[cntr],H56pca_test[cntr])
    tempPCs[cntr] = (L4pca_temp[cntr],L23pca_temp[cntr],L56pca_temp[cntr],
                     H4pca_temp[cntr],H23pca_temp[cntr],H56pca_temp[cntr])
    
    for rnnNo in range(len(rnn_names)):
        contextPCs_sub[cntr,rnnNo] = np.hstack((testPCs[cntr][rnnNo][:,idxs_test_surp,:],
                                                tempPCs[cntr][rnnNo][:,idxs_test_surp,:]))

# %%
L4posPC = {}
L23posPC = {}
L56posPC = {}
H4posPC = {}
H23posPC = {}
H56posPC = {}

# %%
dims23 = np.array([1,2,4,8,16,32,64,80])
dims4 = np.array([1,2,4,8,16,32])
dims56 = np.array([1,2,4,8,16,32,64])

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][1][:,:,:d],pos_test)
        H23posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][4][:,:,:d],pos_test)
    
    for d in dims4:
        L4posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][0][:,:,:d],pos_test)
        H4posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][3][:,:,:d],pos_test)
        
    for d in dims56:
        L56posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][2][:,:,:d],pos_test)      
        H56posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][5][:,:,:d],pos_test)
# Out:
# 100%|██████████| 5/5 [06:21<00:00, 76.37s/it]

# %%
preds_L23posPC = {}
preds_L4posPC = {}
preds_L56posPC = {}

preds_H23posPC = {}
preds_H4posPC = {}
preds_H56posPC = {}

# %%
accs_L23posPC = {}
accs_L4posPC = {}
accs_L56posPC = {}

accs_H23posPC = {}
accs_H4posPC = {}
accs_H56posPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23posPC[cntr,d,ep] = np.argmax(L23posPC[cntr,d][ep],axis=-1)
            preds_H23posPC[cntr,d,ep] = np.argmax(H23posPC[cntr,d][ep],axis=-1)
            
            accs_L23posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L23posPC[cntr,d,ep])
            accs_H23posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H23posPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4posPC[cntr,d,ep] = np.argmax(L4posPC[cntr,d][ep],axis=-1)
            preds_H4posPC[cntr,d,ep] = np.argmax(H4posPC[cntr,d][ep],axis=-1)
            
            accs_L4posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L4posPC[cntr,d,ep])
            accs_H4posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H4posPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56posPC[cntr,d,ep] = np.argmax(L56posPC[cntr,d][ep],axis=-1)
            preds_H56posPC[cntr,d,ep] = np.argmax(H56posPC[cntr,d][ep],axis=-1)
            
            accs_L56posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L56posPC[cntr,d,ep])
            accs_H56posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H56posPC[cntr,d,ep])

# %%
tensor_accs_L23posPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4posPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56posPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23posPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4posPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56posPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23posPC[ii,jj,kk] = accs_L23posPC[ii,d,kk]
            tensor_accs_H23posPC[ii,jj,kk] = accs_H23posPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4posPC[ii,jj,kk] = accs_L4posPC[ii,d,kk]
            tensor_accs_H4posPC[ii,jj,kk] = accs_H4posPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56posPC[ii,jj,kk] = accs_L56posPC[ii,d,kk]            
            tensor_accs_H56posPC[ii,jj,kk] = accs_H56posPC[ii,d,kk]

# %%
mean_accs_L4posPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23posPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56posPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4posPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23posPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56posPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4posPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23posPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56posPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4posPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23posPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56posPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23posPC[dd,ep] = np.mean(tensor_accs_L23posPC[:,dd,ep])
        mean_accs_H23posPC[dd,ep] = np.mean(tensor_accs_H23posPC[:,dd,ep])
        
        std_accs_L23posPC[dd,ep] = np.var(tensor_accs_L23posPC[:,dd,ep])
        std_accs_H23posPC[dd,ep] = np.var(tensor_accs_H23posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4posPC[dd,ep] = np.mean(tensor_accs_L4posPC[:,dd,ep])
        mean_accs_H4posPC[dd,ep] = np.mean(tensor_accs_H4posPC[:,dd,ep])
        
        std_accs_L4posPC[dd,ep] = np.var(tensor_accs_L4posPC[:,dd,ep])
        std_accs_H4posPC[dd,ep] = np.var(tensor_accs_H4posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56posPC[dd,ep] = np.mean(tensor_accs_L56posPC[:,dd,ep])
        mean_accs_H56posPC[dd,ep] = np.mean(tensor_accs_H56posPC[:,dd,ep])
        
        std_accs_L56posPC[dd,ep] = np.var(tensor_accs_L56posPC[:,dd,ep])
        std_accs_H56posPC[dd,ep] = np.var(tensor_accs_H56posPC[:,dd,ep])

# %%
ffpos = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Position Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,0],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,0],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,0],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,0],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,0],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,0],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Position Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,1],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,1],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,1],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,1],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,1],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,1],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Position Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,-1],yerr=std_accs_L4posPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,-1],yerr=std_accs_L23posPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,-1],yerr=std_accs_L56posPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,-1],yerr=std_accs_H4posPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,-1],yerr=std_accs_H23posPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,-1],yerr=std_accs_H56posPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
ffpos_epoch = plt.figure(figsize=(15,5))

plt.subplot(231)
plt.title('Position Decoding - 1D')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[0],yerr=std_accs_L4posPC[0],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[0],yerr=std_accs_L23posPC[0],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[0],yerr=std_accs_L56posPC[0],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[0],yerr=std_accs_H4posPC[0],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[0],yerr=std_accs_H23posPC[0],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[0],yerr=std_accs_H56posPC[0],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.subplot(232)
plt.title('Position Decoding - 2D')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[1],yerr=std_accs_L4posPC[1],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[1],yerr=std_accs_L23posPC[1],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[1],yerr=std_accs_L56posPC[1],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[1],yerr=std_accs_H4posPC[1],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[1],yerr=std_accs_H23posPC[1],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[1],yerr=std_accs_H56posPC[1],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.subplot(233)
plt.title('Position Decoding - Full Dim')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[-1],yerr=std_accs_L4posPC[-1],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[-1],yerr=std_accs_L23posPC[-1],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[-1],yerr=std_accs_L56posPC[-1],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[-1],yerr=std_accs_H4posPC[-1],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[-1],yerr=std_accs_H23posPC[-1],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[-1],yerr=std_accs_H56posPC[-1],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
fpos_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4posPC,0),yerr=np.var(mean_accs_L4posPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23posPC,0),yerr=np.var(mean_accs_L23posPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56posPC,0),yerr=np.var(mean_accs_L56posPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4posPC,0),yerr=np.var(mean_accs_H4posPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23posPC,0),yerr=np.var(mean_accs_H23posPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56posPC,0),yerr=np.var(mean_accs_H56posPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Position Decodability across Epochs - Bidirectional Feedback')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# #### Image ID and Surprise (only surprise position)

# %%
context_sub_surp = np.array([0]*2*nTest + [1]*2*nTest)

# %%
context_sub_imgIDs = {}
for cntr in range(nRuns):
    context_sub_imgIDs[cntr] = np.hstack((np.repeat(allStatesLabelsTest[cntr][:,2],nRepeats),
                                          np.repeat(allStatesLabelsTestTemp[cntr][:,2],nRepeats)))

# %%
L23imgPC = {}
L4imgPC = {}
L56imgPC = {}

H23imgPC = {}
H4imgPC = {}
H56imgPC = {}

L23surpPC = {}
L4surpPC = {}
L56surpPC = {}

H23surpPC = {}
H4surpPC = {}
H56surpPC = {}

# %%
def repsDecodeSupervisedContext(rnnActs,labels,decodeType='surprise',clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'surprise':
        nClasses = 2
    elif decodeType == 'imageID':
        nClasses = nStates
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        
        L23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][:,:,:d],context_sub_surp,decodeType='surprise')
        H23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][:,:,:d],context_sub_surp,decodeType='surprise')
        
    for d in dims4:
        L4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        
        L4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][:,:,:d],context_sub_surp,decodeType='surprise')
        H4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][:,:,:d],context_sub_surp,decodeType='surprise')
    for d in dims56:

        ## Context Sub, ImageID
        L56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')

        ## Context Sub, Surprise
        L56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][:,:,:d],context_sub_surp,decodeType='surprise')
        H56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][:,:,:d],context_sub_surp,decodeType='surprise')
# Out:
# 100%|██████████| 5/5 [17:07<00:00, 205.55s/it]

# %%
preds_L23imgPC = {}
preds_L4imgPC = {}
preds_L56imgPC = {}

preds_H23imgPC = {}
preds_H4imgPC = {}
preds_H56imgPC = {}

preds_L23surpPC = {}
preds_L4surpPC = {}
preds_L56surpPC = {}

preds_H23surpPC = {}
preds_H4surpPC = {}
preds_H56surpPC = {}

# %%
accs_L23imgPC = {}
accs_L4imgPC = {}
accs_L56imgPC = {}

accs_H23imgPC = {}
accs_H4imgPC = {}
accs_H56imgPC = {}

accs_L23surpPC = {}
accs_L4surpPC = {}
accs_L56surpPC = {}

accs_H23surpPC = {}
accs_H4surpPC = {}
accs_H56surpPC = {}

# %%
for cntr in range(nRuns):
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23imgPC[cntr,d,ep] = np.argmax(L23imgPC[cntr,d][ep],axis=-1)
            preds_H23imgPC[cntr,d,ep] = np.argmax(H23imgPC[cntr,d][ep],axis=-1)
            
            preds_L23surpPC[cntr,d,ep] = np.argmax(L23surpPC[cntr,d][ep],axis=-1)
            preds_H23surpPC[cntr,d,ep] = np.argmax(H23surpPC[cntr,d][ep],axis=-1)
            
            accs_L23imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L23imgPC[cntr,d,ep])
            accs_H23imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H23imgPC[cntr,d,ep])
            
            accs_L23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L23surpPC[cntr,d,ep])
            accs_H23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H23surpPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4imgPC[cntr,d,ep] = np.argmax(L4imgPC[cntr,d][ep],axis=-1)
            preds_H4imgPC[cntr,d,ep] = np.argmax(H4imgPC[cntr,d][ep],axis=-1)
            
            preds_L4surpPC[cntr,d,ep] = np.argmax(L4surpPC[cntr,d][ep],axis=-1)
            preds_H4surpPC[cntr,d,ep] = np.argmax(H4surpPC[cntr,d][ep],axis=-1)
            
            accs_L4imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L4imgPC[cntr,d,ep])
            accs_H4imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H4imgPC[cntr,d,ep])
            
            accs_L4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L4surpPC[cntr,d,ep])
            accs_H4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H4surpPC[cntr,d,ep])
                
        for d in dims56:        
            preds_L56imgPC[cntr,d,ep] = np.argmax(L56imgPC[cntr,d][ep],axis=-1)
            preds_H56imgPC[cntr,d,ep] = np.argmax(H56imgPC[cntr,d][ep],axis=-1)
            
            preds_L56surpPC[cntr,d,ep] = np.argmax(L56surpPC[cntr,d][ep],axis=-1)
            preds_H56surpPC[cntr,d,ep] = np.argmax(H56surpPC[cntr,d][ep],axis=-1)
            
            accs_L56imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L56imgPC[cntr,d,ep])
            accs_H56imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H56imgPC[cntr,d,ep])
            
            accs_L56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L56surpPC[cntr,d,ep])
            accs_H56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H56surpPC[cntr,d,ep])

# %%
tensor_accs_L23imgPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4imgPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56imgPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23imgPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4imgPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56imgPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_L23surpPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4surpPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56surpPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23surpPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4surpPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56surpPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23imgPC[ii,jj,kk] = accs_L23imgPC[ii,d,kk]
            tensor_accs_H23imgPC[ii,jj,kk] = accs_H23imgPC[ii,d,kk]
            
            tensor_accs_L23surpPC[ii,jj,kk] = accs_L23surpPC[ii,d,kk]
            tensor_accs_H23surpPC[ii,jj,kk] = accs_H23surpPC[ii,d,kk]
            
        
        for jj,d in enumerate(dims4):
            tensor_accs_L4imgPC[ii,jj,kk] = accs_L4imgPC[ii,d,kk]
            tensor_accs_H4imgPC[ii,jj,kk] = accs_H4imgPC[ii,d,kk]
            
            tensor_accs_L4surpPC[ii,jj,kk] = accs_L4surpPC[ii,d,kk]
            tensor_accs_H4surpPC[ii,jj,kk] = accs_H4surpPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56imgPC[ii,jj,kk] = accs_L56imgPC[ii,d,kk]
            tensor_accs_H56imgPC[ii,jj,kk] = accs_H56imgPC[ii,d,kk]

            tensor_accs_L56surpPC[ii,jj,kk] = accs_L56surpPC[ii,d,kk]
            tensor_accs_H56surpPC[ii,jj,kk] = accs_H56surpPC[ii,d,kk]

# %%
mean_accs_L4imgPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23imgPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56imgPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4imgPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23imgPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56imgPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_L4surpPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23surpPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56surpPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4surpPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23surpPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56surpPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4imgPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23imgPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56imgPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4imgPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23imgPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56imgPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4surpPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23surpPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56surpPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4surpPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23surpPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56surpPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dims in enumerate(dims23):
        mean_accs_L23imgPC[dd,ep] = np.mean(tensor_accs_L23imgPC[:,dd,ep])
        mean_accs_H23imgPC[dd,ep] = np.mean(tensor_accs_H23imgPC[:,dd,ep])
        
        std_accs_L23imgPC[dd,ep] = np.var(tensor_accs_L23imgPC[:,dd,ep])
        std_accs_H23imgPC[dd,ep] = np.var(tensor_accs_H23imgPC[:,dd,ep])
        
        mean_accs_L23surpPC[dd,ep] = np.mean(tensor_accs_L23surpPC[:,dd,ep])
        mean_accs_H23surpPC[dd,ep] = np.mean(tensor_accs_H23surpPC[:,dd,ep])
        
        std_accs_L23surpPC[dd,ep] = np.var(tensor_accs_L23surpPC[:,dd,ep])
        std_accs_H23surpPC[dd,ep] = np.var(tensor_accs_H23surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims4):
        mean_accs_L4imgPC[dd,ep] = np.mean(tensor_accs_L4imgPC[:,dd,ep])
        mean_accs_H4imgPC[dd,ep] = np.mean(tensor_accs_H4imgPC[:,dd,ep])
        
        std_accs_L4imgPC[dd,ep] = np.var(tensor_accs_L4imgPC[:,dd,ep])
        std_accs_H4imgPC[dd,ep] = np.var(tensor_accs_H4imgPC[:,dd,ep])
        
        mean_accs_L4surpPC[dd,ep] = np.mean(tensor_accs_L4surpPC[:,dd,ep])
        mean_accs_H4surpPC[dd,ep] = np.mean(tensor_accs_H4surpPC[:,dd,ep])
        
        std_accs_L4surpPC[dd,ep] = np.var(tensor_accs_L4surpPC[:,dd,ep])
        std_accs_H4surpPC[dd,ep] = np.var(tensor_accs_H4surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims56):
        mean_accs_L56imgPC[dd,ep] = np.mean(tensor_accs_L56imgPC[:,dd,ep])        
        mean_accs_H56imgPC[dd,ep] = np.mean(tensor_accs_H56imgPC[:,dd,ep])
        
        std_accs_L56imgPC[dd,ep] = np.var(tensor_accs_L56imgPC[:,dd,ep])
        std_accs_H56imgPC[dd,ep] = np.var(tensor_accs_H56imgPC[:,dd,ep])
        
        mean_accs_L56surpPC[dd,ep] = np.mean(tensor_accs_L56surpPC[:,dd,ep])
        mean_accs_H56surpPC[dd,ep] = np.mean(tensor_accs_H56surpPC[:,dd,ep])
        
        std_accs_L56surpPC[dd,ep] = np.var(tensor_accs_L56surpPC[:,dd,ep])        
        std_accs_H56surpPC[dd,ep] = np.var(tensor_accs_H56surpPC[:,dd,ep])

# %%
ffdim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Image ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,0],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,0],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,0],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,0],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,0],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,0],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Image ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,1],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,1],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,1],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,1],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,1],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,1],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Image ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,-1],yerr=std_accs_L4imgPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,-1],yerr=std_accs_L23imgPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,-1],yerr=std_accs_L56imgPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,-1],yerr=std_accs_H4imgPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,-1],yerr=std_accs_H23imgPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,-1],yerr=std_accs_H56imgPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fimg_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4imgPC,0),yerr=np.var(mean_accs_L4imgPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23imgPC,0),yerr=np.var(mean_accs_L23imgPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56imgPC,0),yerr=np.var(mean_accs_L56imgPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4imgPC,0),yerr=np.var(mean_accs_H4imgPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23imgPC,0),yerr=np.var(mean_accs_H23imgPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56imgPC,0),yerr=np.var(mean_accs_H56imgPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Image Decodability across Epochs - Bidirectional Feedback')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
ffsurp_dim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Surprise ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,0],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,0],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,0],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,0],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,0],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,0],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(132)
plt.title('Surprise ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,1],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,1],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,1],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,1],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,1],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,1],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(133)
plt.title('Surprise ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,-1],yerr=std_accs_L4surpPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,-1],yerr=std_accs_L23surpPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,-1],yerr=std_accs_L56surpPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,-1],yerr=std_accs_H4surpPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,-1],yerr=std_accs_H23surpPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,-1],yerr=std_accs_H56surpPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fsurp_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4surpPC,0),yerr=np.var(mean_accs_L4surpPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23surpPC,0),yerr=np.var(mean_accs_L23surpPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56surpPC,0),yerr=np.var(mean_accs_L56surpPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4surpPC,0),yerr=np.var(mean_accs_H4surpPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23surpPC,0),yerr=np.var(mean_accs_H23surpPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56surpPC,0),yerr=np.var(mean_accs_H56surpPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Surprise Decodability across Epochs - Bidirectional Feedback')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
np.save(pp+'preds_img_temp_L4-bidirectional-fb-lattice',preds_L4imgPC)
np.save(pp+'preds_img_temp_L23-bidirectional-fb-lattice',preds_L23imgPC)
np.save(pp+'preds_img_temp_L56-bidirectional-fb-lattice',preds_L56imgPC)
np.save(pp+'preds_img_temp_H4-bidirectional-fb-lattice',preds_H4imgPC)
np.save(pp+'preds_img_temp_H23-bidirectional-fb-lattice',preds_H23imgPC)
np.save(pp+'preds_img_temp_H56-bidirectional-fb-lattice',preds_H56imgPC)

np.save(pp+'accs_img_temp_L4-bidirectional-fb-lattice',accs_L4imgPC)
np.save(pp+'accs_img_temp_L23-bidirectional-fb-lattice',accs_L23imgPC)
np.save(pp+'accs_img_temp_L56-bidirectional-fb-lattice',accs_L56imgPC)
np.save(pp+'accs_img_temp_H4-bidirectional-fb-lattice',accs_H4imgPC)
np.save(pp+'accs_img_temp_H23-bidirectional-fb-lattice',accs_H23imgPC)
np.save(pp+'accs_img_temp_H56-bidirectional-fb-lattice',accs_H56imgPC)

# %%
np.save(pp+'preds_pos_temp_L4-bidirectional-fb-lattice',preds_L4posPC)
np.save(pp+'preds_pos_temp_L23-bidirectional-fb-lattice',preds_L23posPC)
np.save(pp+'preds_pos_temp_L56-bidirectional-fb-lattice',preds_L56posPC)
np.save(pp+'preds_pos_temp_H4-bidirectional-fb-lattice',preds_H4posPC)
np.save(pp+'preds_pos_temp_H23-bidirectional-fb-lattice',preds_H23posPC)
np.save(pp+'preds_pos_temp_H56-bidirectional-fb-lattice',preds_H56posPC)

np.save(pp+'accs_pos_temp_L4-bidirectional-fb-lattice',accs_L4posPC)
np.save(pp+'accs_pos_temp_L23-bidirectional-fb-lattice',accs_L23posPC)
np.save(pp+'accs_pos_temp_L56-bidirectional-fb-lattice',accs_L56posPC)
np.save(pp+'accs_pos_temp_H4-bidirectional-fb-lattice',accs_H4posPC)
np.save(pp+'accs_pos_temp_H23-bidirectional-fb-lattice',accs_H23posPC)
np.save(pp+'accs_pos_temp_H56-bidirectional-fb-lattice',accs_H56posPC)

# %%
np.save(pp+'preds_surp_temp_L4-bidirectional-fb-lattice',preds_L4surpPC)
np.save(pp+'preds_surp_temp_L23-bidirectional-fb-lattice',preds_L23surpPC)
np.save(pp+'preds_surp_temp_L56-bidirectional-fb-lattice',preds_L56surpPC)
np.save(pp+'preds_surp_temp_H4-bidirectional-fb-lattice',preds_H4surpPC)
np.save(pp+'preds_surp_temp_H23-bidirectional-fb-lattice',preds_H23surpPC)
np.save(pp+'preds_surp_temp_H56-bidirectional-fb-lattice',preds_H56surpPC)

np.save(pp+'accs_surp_temp_L4-bidirectional-fb-lattice',accs_L4surpPC)
np.save(pp+'accs_surp_temp_L23-bidirectional-fb-lattice',accs_L23surpPC)
np.save(pp+'accs_surp_temp_L56-bidirectional-fb-lattice',accs_L56surpPC)
np.save(pp+'accs_surp_temp_H4-bidirectional-fb-lattice',accs_H4surpPC)
np.save(pp+'accs_surp_temp_H23-bidirectional-fb-lattice',accs_H23surpPC)
np.save(pp+'accs_surp_temp_H56-bidirectional-fb-lattice',accs_H56surpPC)

# %% [markdown]
# #### Latent variable decoding

# %%
def repsDecodeSupervisedLatents(rnnActs,labels,decodeType='action',clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'action':
        nClasses = 4
    else:
        nClasses = 5
        
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
L23actPC = {}
L4actPC = {}
L56actPC = {}

H23actPC = {}
H4actPC = {}
H56actPC = {}

L23distPC = {}
L4distPC = {}
L56distPC = {}

H23distPC = {}
H4distPC = {}
H56distPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][1][:,:,:d],actionsLabelsTest[cnt].ravel())
        H23actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][4][:,:,:d],actionsLabelsTest[cnt].ravel())
    
    for d in dims4:
        L4actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][0][:,:,:d],actionsLabelsTest[cnt].ravel())
        H4actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][3][:,:,:d],actionsLabelsTest[cnt].ravel())
        
    for d in dims56:
        L56actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][2][:,:,:d],actionsLabelsTest[cnt].ravel())      
        H56actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][5][:,:,:d],actionsLabelsTest[cnt].ravel())
# Out:
# 100%|██████████| 5/5 [04:24<00:00, 52.99s/it]

# %%
preds_L23actPC = {}
preds_L4actPC = {}
preds_L56actPC = {}

preds_H23actPC = {}
preds_H4actPC = {}
preds_H56actPC = {}

# %%
accs_L23actPC = {}
accs_L4actPC = {}
accs_L56actPC = {}

accs_H23actPC = {}
accs_H4actPC = {}
accs_H56actPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23actPC[cntr,d,ep] = np.argmax(L23actPC[cntr,d][ep],axis=-1)
            preds_H23actPC[cntr,d,ep] = np.argmax(H23actPC[cntr,d][ep],axis=-1)
            
            accs_L23actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L23actPC[cntr,d,ep])
            accs_H23actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H23actPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4actPC[cntr,d,ep] = np.argmax(L4actPC[cntr,d][ep],axis=-1)
            preds_H4actPC[cntr,d,ep] = np.argmax(H4actPC[cntr,d][ep],axis=-1)
            
            accs_L4actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L4actPC[cntr,d,ep])
            accs_H4actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H4actPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56actPC[cntr,d,ep] = np.argmax(L56actPC[cntr,d][ep],axis=-1)
            preds_H56actPC[cntr,d,ep] = np.argmax(H56actPC[cntr,d][ep],axis=-1)
            
            accs_L56actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L56actPC[cntr,d,ep])
            accs_H56actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H56actPC[cntr,d,ep])

# %%
tensor_accs_L23actPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4actPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56actPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23actPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4actPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56actPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23actPC[ii,jj,kk] = accs_L23actPC[ii,d,kk]
            tensor_accs_H23actPC[ii,jj,kk] = accs_H23actPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4actPC[ii,jj,kk] = accs_L4actPC[ii,d,kk]
            tensor_accs_H4actPC[ii,jj,kk] = accs_H4actPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56actPC[ii,jj,kk] = accs_L56actPC[ii,d,kk]            
            tensor_accs_H56actPC[ii,jj,kk] = accs_H56actPC[ii,d,kk]

# %%
mean_accs_L4actPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23actPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56actPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4actPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23actPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56actPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4actPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23actPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56actPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4actPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23actPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56actPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23actPC[dd,ep] = np.mean(tensor_accs_L23actPC[:,dd,ep])
        mean_accs_H23actPC[dd,ep] = np.mean(tensor_accs_H23actPC[:,dd,ep])
        
        std_accs_L23actPC[dd,ep] = np.var(tensor_accs_L23actPC[:,dd,ep])
        std_accs_H23actPC[dd,ep] = np.var(tensor_accs_H23actPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4actPC[dd,ep] = np.mean(tensor_accs_L4actPC[:,dd,ep])
        mean_accs_H4actPC[dd,ep] = np.mean(tensor_accs_H4actPC[:,dd,ep])
        
        std_accs_L4actPC[dd,ep] = np.var(tensor_accs_L4actPC[:,dd,ep])
        std_accs_H4actPC[dd,ep] = np.var(tensor_accs_H4actPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56actPC[dd,ep] = np.mean(tensor_accs_L56actPC[:,dd,ep])
        mean_accs_H56actPC[dd,ep] = np.mean(tensor_accs_H56actPC[:,dd,ep])
        
        std_accs_L56actPC[dd,ep] = np.var(tensor_accs_L56actPC[:,dd,ep])
        std_accs_H56actPC[dd,ep] = np.var(tensor_accs_H56actPC[:,dd,ep])

# %%
ffact = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Action Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,0],yerr=std_accs_L4actPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,0],yerr=std_accs_L23actPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,0],yerr=std_accs_L56actPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,0],yerr=std_accs_H4actPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,0],yerr=std_accs_H23actPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,0],yerr=std_accs_H56actPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Action Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,1],yerr=std_accs_L4actPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,1],yerr=std_accs_L23actPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,1],yerr=std_accs_L56actPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,1],yerr=std_accs_H4actPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,1],yerr=std_accs_H23actPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,1],yerr=std_accs_H56actPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Action Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,-1],yerr=std_accs_L4actPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,-1],yerr=std_accs_L23actPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,-1],yerr=std_accs_L56actPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,-1],yerr=std_accs_H4actPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,-1],yerr=std_accs_H23actPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,-1],yerr=std_accs_H56actPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fact_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4actPC,0),yerr=np.var(mean_accs_L4actPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23actPC,0),yerr=np.var(mean_accs_L23actPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56actPC,0),yerr=np.var(mean_accs_L56actPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4actPC,0),yerr=np.var(mean_accs_H4actPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23actPC,0),yerr=np.var(mean_accs_H23actPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56actPC,0),yerr=np.var(mean_accs_H56actPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Action Decodability across Epochs - Bidirectional Feedback')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# #### Temporal accuracies

# %%
labelsTrain = {}
labelsTest = {}
labelsTestTemp = {}

# %%
for cntr in range(nRuns):
#     labelsTrain[cntr] = np.argmax(yRepsTrain[cntr]@template[cntr].T,-1)
    labelsTest[cntr] = np.argmax(yRepsTest[cntr]@template[cntr].T,-1)
    labelsTestTemp[cntr] = np.argmax(yRepsTestTemp[cntr]@template[cntr].T,-1)

# %%
# preds_train = {}
preds_test = {}
preds_temp = {}

# accs_train = np.zeros((nRuns,n_epochs+1))
accs_test = np.zeros((nRuns,n_epochs+1))
accs_temp = np.zeros((nRuns,n_epochs+1))

for cntr in range(nRuns):
#     preds_train[cntr] = np.argmax(np.abs(np.round_(out_train[cntr]))@template[cntr].T,-1)
    preds_test[cntr] = np.argmax(np.abs(np.round_(out_test[cntr]))@template[cntr].T,-1)
    preds_temp[cntr] = np.argmax(np.abs(np.round_(out_temp[cntr]))@template[cntr].T,-1)
    
    for ep in range(n_epochs+1): 
#         accs_train[cntr,ep] = accuracy_score(labelsTrain[cntr].ravel(),preds_train[cntr][ep].ravel())
        accs_test[cntr,ep] = accuracy_score(labelsTest[cntr].ravel(),preds_test[cntr][ep].ravel())
        accs_temp[cntr,ep] = accuracy_score(labelsTestTemp[cntr].ravel(),preds_temp[cntr][ep].ravel())

# %%
# plt.errorbar(np.arange(n_epochs+1),np.mean(accs_train,0),yerr=np.var(accs_train,0),fmt='-',label='Train')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_test,0),yerr=np.var(accs_test,0),fmt='-',label='Test - Clean')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_temp,0),yerr=np.var(accs_temp,0),fmt='-',label='Test - Surprise')
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend()
plt.title('Prediction accuracy in presence of temporal violation')
plt.show()

# %%
np.save(pp+'bidirectional-fb-no-violations-accs-lattice',accs_test)
np.save(pp+'bidirectional-fb-temporal-violations-accs-lattice',accs_temp)

# %% [markdown]
# ### Spatial violations

# %%
from numpy.random import normal

# %%
noise_stds = np.linspace(0,1,6)

# %%
repsTrainNoisy = {}
repsTestNoisy = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        repsTrainNoisy[cntr,nn] = repsTrain[cntr] + normal(0,noise,repsTrain[cntr].shape)
        repsTestNoisy[cntr,nn] = repsTest[cntr] + normal(0,noise,repsTest[cntr].shape)

# %%
noisy_train_loaders = {}
noisy_test_loaders = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noisy_train_loaders[cntr,nn] = makeTensorLoaders((repsTrainNoisy[cntr,nn],yRepsTrain[cntr],
                                                            eTrain[cntr],surpTrain[cntr]),batch_size,shuffle=False)
        noisy_test_loaders[cntr,nn] = makeTensorLoaders((repsTestNoisy[cntr,nn],yRepsTest[cntr],
                                                            eTest[cntr],surpTest[cntr]),batch_size,shuffle=False)

# %%
nNoise = len(noise_stds)

# %%
def pass_data_store_activations_noisy(loader, nData, 
                                nRuns=nRuns, nNoise=nNoise, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        for nn in range(nNoise):
            activations_hidden_L23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_L4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_L56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_hidden_H23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_H4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_H56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_out_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
            for e in tqdm(range(n_epochs+1)):

                cnt = 0

                ## Load model
                model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr],task='lattice')
                model[cntr].to(device)
                model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
                model[cntr].eval()

                ## Pass clean samples
                for data, f_target, lastEvent, surpriseBinary in loader[cntr,nn]:

                    if train_on_gpu:
                        data, f_targetC = data.float().cuda(), f_target.float().cuda()
                    else: data, f_targetC = data.float(), f_target.float()

                    target = f_target

                    output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                    ## Collect activations  
                    act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                    act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                    act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                    act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                    act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                    act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                    output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                    for i in range(batch_size):
                        if i < len(data):
                            label = target.data[i]

                            activations_hidden_L23_np[cntr,nn][e,cnt] = act_hidden_L23[i]
                            activations_hidden_L4_np[cntr,nn][e,cnt] = act_hidden_L4[i]
                            activations_hidden_L56_np[cntr,nn][e,cnt] = act_hidden_L56[i]

                            activations_hidden_H23_np[cntr,nn][e,cnt] = act_hidden_H23[i]
                            activations_hidden_H4_np[cntr,nn][e,cnt] = act_hidden_H4[i]
                            activations_hidden_H56_np[cntr,nn][e,cnt] = act_hidden_H56[i]

                            activations_out_np[cntr,nn][e,cnt] = output_pred[i]

                            cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# L23_train_noisy = {}
# L4_train_noisy = {}
# L56_train_noisy = {}

# H23_train_noisy = {}
# H4_train_noisy = {}
# H56_train_noisy = {}

# out_train_noisy = {}

# %%
L23_test_noisy = {}
L4_test_noisy = {}
L56_test_noisy = {}

H23_test_noisy = {}
H4_test_noisy = {}
H56_test_noisy = {}

out_test_noisy = {}

# %%
# (L23_train_noisy,L4_train_noisy,L56_train_noisy,
#  H23_train_noisy,H4_train_noisy,H56_train_noisy), out_train_noisy = pass_data_store_activations_noisy(noisy_train_loaders,nTrain)

(L23_test_noisy,L4_test_noisy,L56_test_noisy,
 H23_test_noisy,H4_test_noisy,H56_test_noisy), out_test_noisy = pass_data_store_activations_noisy(noisy_test_loaders,nTest)
# Out:
# 100%|██████████| 101/101 [00:08<00:00, 11.45it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.57it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.53it/s]
# 100%|██████████| 101/101 [00:09<00:00, 11.12it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.41it/s]
# 100%|██████████| 101/101 [00:09<00:00, 11.21it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.73it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.89it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.43it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.71it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.83it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.82it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.74it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.70it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.52it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.95it/s]
# 100%|██████████| 101/101 [00:09<00:00, 11.07it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.67it/s]
# 100%|██████████| 101/101 [00:09<00:00, 11.04it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.64it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.48it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.85it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.99it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.38it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.95it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.31it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.29it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.65it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.89it/s]
# 100%|██████████| 101/101 [00:09<00:00, 11.04it/s]

# %%
predsN_train = {}
accsN_train = np.zeros((nRuns,len(noise_stds),n_epochs+1))

predsN_test = {}
accsN_test = np.zeros((nRuns,len(noise_stds),n_epochs+1))

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        predsN_test[cntr,nn] = np.argmax(out_test_noisy[cntr,nn]@template[cntr].T,-1)
        accsN_test[cntr,nn] = np.sum(np.sum(((labelsTest[cntr] - predsN_test[cntr,nn])==0)*1,-1),-1)/(nTest*6)

# %%
name = "Dark2_r"
cmap = get_cmap(name)  # type: matplotlib.colors.ListedColormap
colors = cmap.colors  # type: list

# %%
fpredspat = plt.figure()
for nn, noise in enumerate(noise_stds):
    plt.errorbar(np.arange(n_epochs+1),np.mean(accsN_test[:,nn],0),yerr=np.var(accsN_test[:,nn],0),
                 fmt='-',label=np.round(noise,2),
                 c=colors[nn])
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend(title="Noise sigma",bbox_to_anchor=(1,0.5))
plt.title('Prediction accuracy with spatial noise - Bidirectional-FB Microcircuit')
plt.show()

# %%
np.save(pp+'bidirectional-fb-spatial-noisy-accs-lattice',accsN_test)

# %% [markdown]
# #### Dimensionality (linear)

# %%
def rnnLinDim(acts):
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    eig_mat = np.zeros((nEpochs,nNeurons))
        
    for ep in tqdm(range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        cov = actsScaled.T@actsScaled
        eig_mat[ep] = eigvals(cov)
        num = np.sum(eig_mat,1)**2
        den = np.sum(eig_mat**2,1) + 1e-17
        PR = num/den
    return PR

# %%
L23LinDim = np.zeros((nRuns,n_epochs+1))
L4LinDim = np.zeros((nRuns,n_epochs+1))
L56LinDim = np.zeros((nRuns,n_epochs+1))

H23LinDim = np.zeros((nRuns,n_epochs+1))
H4LinDim = np.zeros((nRuns,n_epochs+1))
H56LinDim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23LinDim[cntr] = rnnLinDim(L23_test[cntr])
    L4LinDim[cntr] = rnnLinDim(L4_test[cntr])
    L56LinDim[cntr] = rnnLinDim(L56_test[cntr])

    H23LinDim[cntr] = rnnLinDim(H23_test[cntr])
    H4LinDim[cntr] = rnnLinDim(H4_test[cntr])
    H56LinDim[cntr] = rnnLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 201.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 401.91it/s]
# 100%|██████████| 101/101 [00:00<00:00, 207.94it/s]
# 100%|██████████| 101/101 [00:00<00:00, 196.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 415.89it/s]
# 100%|██████████| 101/101 [00:00<00:00, 243.44it/s]
# 100%|██████████| 101/101 [00:00<00:00, 197.39it/s]
# 100%|██████████| 101/101 [00:00<00:00, 340.98it/s]
# 100%|██████████| 101/101 [00:00<00:00, 238.28it/s]
# 100%|██████████| 101/101 [00:00<00:00, 193.93it/s]
# 100%|██████████| 101/101 [00:00<00:00, 394.04it/s]
# 100%|██████████| 101/101 [00:00<00:00, 247.00it/s]
# 100%|██████████| 101/101 [00:00<00:00, 193.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 418.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 250.05it/s]
# 100%|██████████| 101/101 [00:00<00:00, 197.79it/s]
# 100%|██████████| 101/101 [00:00<00:00, 452.10it/s]
# 100%|██████████| 101/101 [00:00<00:00, 228.09it/s]
# 100%|██████████| 101/101 [00:00<00:00, 203.35it/s]
# 100%|██████████| 101/101 [00:00<00:00, 368.25it/s]
# 100%|██████████| 101/101 [00:00<00:00, 233.06it/s]
# 100%|██████████| 101/101 [00:00<00:00, 169.35it/s]
# 100%|██████████| 101/101 [00:00<00:00, 326.68it/s]
# 100%|██████████| 101/101 [00:00<00:00, 204.17it/s]
# 100%|██████████| 101/101 [00:00<00:00, 176.12it/s]
# 100%|██████████| 101/101 [00:00<00:00, 323.55it/s]
# 100%|██████████| 101/101 [00:00<00:00, 201.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 177.05it/s]
# 100%|██████████| 101/101 [00:00<00:00, 314.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 195.50it/s]

# %% [markdown]
# #### Dimensionality (non-linear)

# %%
def rnnNonLinDim(acts,nTypes=2,subsample=True,ds=100):
    
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    dims_mat = np.zeros((nEpochs,nTypes))
        
    for ep in (range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        
        if subsample:
            actsScaled = actsScaled[::ds]
        
        dims_mat[ep,0] = MiND_ML().fit(actsScaled).dimension_
#         print(dims_mat[ep,0])
        dims_mat[ep,1] = CorrInt().fit(actsScaled).dimension_
#         print(dims_mat[ep,1])
#         dims_mat[ep,2] = MLE().fit(actsScaled).dimension_
#         print(dims_mat[ep,2])
#         dims_mat[ep,3] = DANCo().fit(actsScaled).dimension_
        
    return np.mean(dims_mat,-1),dims_mat

# %%
L23NonLinDim = np.zeros((nRuns,n_epochs+1))
L4NonLinDim = np.zeros((nRuns,n_epochs+1))
L56NonLinDim = np.zeros((nRuns,n_epochs+1))

H23NonLinDim = np.zeros((nRuns,n_epochs+1))
H4NonLinDim = np.zeros((nRuns,n_epochs+1))
H56NonLinDim = np.zeros((nRuns,n_epochs+1))

# %%
L23_ND_mat = {}
L4_ND_mat = {}
L56_ND_mat = {}
H23_ND_mat = {}
H4_ND_mat = {}
H56_ND_mat = {}

# %%
for cntr in tqdm(range(nRuns)):
    L23NonLinDim[cntr], L23_ND_mat[cntr] = rnnNonLinDim(L23_test[cntr])
    L4NonLinDim[cntr], L4_ND_mat[cntr] = rnnNonLinDim(L4_test[cntr])
    L56NonLinDim[cntr], L56_ND_mat[cntr] = rnnNonLinDim(L56_test[cntr])

    H23NonLinDim[cntr], H23_ND_mat[cntr] = rnnNonLinDim(H23_test[cntr])
    H4NonLinDim[cntr], H4_ND_mat[cntr] = rnnNonLinDim(H4_test[cntr])
    H56NonLinDim[cntr], H56_ND_mat[cntr] = rnnNonLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 5/5 [02:06<00:00, 25.24s/it]

# %%
L23_NonLineDim_mean = np.mean(L23NonLinDim,0)
L4_NonLineDim_mean = np.mean(L4NonLinDim,0)
L56_NonLineDim_mean = np.mean(L56NonLinDim,0)

H23_NonLineDim_mean = np.mean(H23NonLinDim,0)
H4_NonLineDim_mean = np.mean(H4NonLinDim,0)
H56_NonLineDim_mean = np.mean(H56NonLinDim,0)

L23_NonLineDim_std = np.var(L23NonLinDim,0)
L4_NonLineDim_std = np.var(L4NonLinDim,0)
L56_NonLineDim_std = np.var(L56NonLinDim,0)

H23_NonLineDim_std = np.var(H23NonLinDim,0)
H4_NonLineDim_std = np.var(H4NonLinDim,0)
H56_NonLineDim_std = np.var(H56NonLinDim,0)

# %%
L23_dim = np.zeros((nRuns,n_epochs+1))
L4_dim = np.zeros((nRuns,n_epochs+1))
L56_dim = np.zeros((nRuns,n_epochs+1))

H23_dim = np.zeros((nRuns,n_epochs+1))
H4_dim = np.zeros((nRuns,n_epochs+1))
H56_dim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23_dim[cntr] = L23LinDim[cntr]/L23NonLinDim[cntr]
    L4_dim[cntr] = L4LinDim[cntr]/L4NonLinDim[cntr]
    L56_dim[cntr] = L56LinDim[cntr]/L56NonLinDim[cntr]
    H23_dim[cntr] = H23LinDim[cntr]/H23NonLinDim[cntr]
    H4_dim[cntr] = H4LinDim[cntr]/H4NonLinDim[cntr]
    H56_dim[cntr] = H56LinDim[cntr]/H56NonLinDim[cntr]

# %%
np.save(pp+'L23DG_bidirectional-fb_lattice',L23_dim)
np.save(pp+'L4DG_bidirectional-fb_lattice',L4_dim)
np.save(pp+'L56DG_bidirectional-fb_lattice',L56_dim)
np.save(pp+'H23DG_bidirectional-fb_lattice',H23_dim)
np.save(pp+'H4DG_bidirectional-fb_lattice',H4_dim)
np.save(pp+'H56DG_bidirectional-fb_lattice',H56_dim)

# %%
ffTotDim = plt.figure(figsize=(5,5))

plt.subplot(111)

plt.plot(np.arange(n_epochs+1),np.mean(L4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(L4_dim,0)-np.var(L4_dim,0),np.mean(L4_dim,0)+np.var(L4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(L23_dim,0)-np.var(L23_dim,0),np.mean(L23_dim,0)+np.var(L23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(L56_dim,0)-np.var(L56_dim,0),np.mean(L56_dim,0)+np.var(L56_dim,0),alpha=0.5)

plt.plot(np.arange(n_epochs+1),np.mean(H4_dim,0),label='Higher layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(H4_dim,0)-np.var(H4_dim,0),np.mean(H4_dim,0)+np.var(H4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H23_dim,0),label='Higher layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(H23_dim,0)-np.var(H23_dim,0),np.mean(H23_dim,0)+np.var(H23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H56_dim,0),label='Higher layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(H56_dim,0)-np.var(H56_dim,0),np.mean(H56_dim,0)+np.var(H56_dim,0),alpha=0.5)

plt.xlabel('Epochs')
plt.ylabel('Dimensionality Gain')
# plt.ylim(0.9,2.2)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Bidirectional Feedback')
plt.show()

# %%
ffTotDim.savefig('Dimensionality-gain-bidirectional-fb-across-learning-lattice.png',dpi=300,bbox_inches='tight')
ffTotDim.savefig('Dimensionality-gain-bidirectional-fb-across-learning-lattice.svg',dpi=300,bbox_inches='tight')
