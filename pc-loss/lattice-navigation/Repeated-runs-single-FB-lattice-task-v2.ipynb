# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from numpy.random import choice
from numpy.linalg import norm

from math import factorial

from itertools import permutations

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE, Isomap
import umap

from tqdm import tqdm
import os

# %%
from numpy.linalg import svd, eigvals
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, homogeneity_completeness_v_measure, confusion_matrix, ConfusionMatrixDisplay

# %%
from skdim.id import *

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import get_cmap

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.style.use('seaborn-whitegrid')
# plt.style.use('default')

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

# %%
from generate_data import generate_lattice_based_task, makeTensorLoaders

# %% [markdown]
# #### Test for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('No GPU, training on CPU')
    device = torch.device('cpu')
else:
    print('GPU found, training on GPU')
    device = torch.device('cuda')
# Out:
# GPU found, training on GPU

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Number of runs

# %%
nRuns = 5

# %% [markdown]
# #### Generate data for runs

# %%
dim = 64
nTot = 2000
latticeDim = 2

fracTrain = 0.8
fracTest = np.round(1-fracTrain,2)

nTrain = int(nTot*fracTrain)
nTest = nTot - nTrain

lenSeq = 4
nRepeats = 2

dimsL = np.array([5,5])
nStates = np.prod(dimsL)

# %%
cnt = 0
lattice_labels = np.zeros((nStates,latticeDim),dtype=int)
for y in range(-2,3):
    for x in range(-2,3):
        lattice_labels[cnt] = (x,y)
        cnt += 1

# %%
def templateMaker(nStates, dim):
    ## Generate template representations (for expected elements)
    template = np.zeros((nStates, dim))
    for ii in range(nStates):
        template[ii] = choice(2, dim, p=[0.75, 0.25])## p=[Pr(0),Pr(1)]
    return template

# %%
template = {}
for cntr in range(nRuns):
    template[cntr] = templateMaker(nStates=nStates,dim=dim)

# %%
repsTrain = {}
yRepsTrain = {}
eTrain = {}
pTrain = {}
surpTrain = {}
allStatesTrain = {}
actionsTrain = {}

# %%
repsTest = {}
yRepsTest = {}
eTest = {}
pTest = {}
surpTest = {}
allStatesTest = {}
actionsTest = {}

# %%
repsTestTemp = {}
yRepsTestTemp = {}
eTestTemp = {}
pTestTemp = {}
surpTestTemp = {}
allStatesTestTemp = {}
actionsTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]),\
    (actionsTrain[cntr],actionsTest[cntr],actionsTestTemp[cntr]) = generate_lattice_based_task(nTot,fracTrain,dim,lenSeq,
                                                                                               lattice_labels=lattice_labels,
                                                                                               latticeDim=latticeDim,
                                                                                               repeats=True, numRepeats=nRepeats,
                                                                                               template=template[cntr])

# %% [markdown]
# #### Create directories to save data and representations

# %%
pp = ## specify path

# %%
npp = {}
pp_npy = {}
pp_pts = {}

# %%
for cntr in range(nRuns):
    
    npp[cntr] = 'lattice-unidirectional-fb-'+str(cntr)+'/'
    pp_npy[cntr] = pp+npp[cntr]+'npys-'+str(cntr)+'/'
    pp_pts[cntr] = pp+npp[cntr]+'pts-'+str(cntr)+'/'

## uncomment the following lines to create the folders. comment out if already created
    
#     os.mkdir(os.path.join(pp,npp[cntr]))
#     os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr]))
#     os.mkdir(os.path.join(pp,npp[cntr],pp_pts[cntr]))

#     os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr],'Dataset/'))

# %% [markdown]
# #### Save seeds and dataset

# %%
seeds = np.random.randint(1000, size=nRuns)
np.save(pp_npy[cntr]+'seeds',seeds)

# %%
for cntr in range(nRuns):
    ## Template
    np.save(pp_npy[cntr]+'Dataset/template',template[cntr])

    ## Train Data
    np.save(pp_npy[cntr]+'Dataset/repsTrain',repsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTrain',yRepsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTrain',eTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTrain',surpTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTrain',allStatesTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTrain',actionsTrain[cntr])

    ## Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTest',repsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTest',yRepsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTest',eTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTest',surpTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTest',allStatesTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTest',actionsTest[cntr])
    
    ## Temporally violated Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTestTemp',repsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTestTemp',yRepsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTestTemp',eTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTestTemp',surpTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTestTemp',allStatesTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTestTemp',actionsTestTemp[cntr])

# %% [markdown]
# #### Load seeds

# %%
seeds = np.load(pp_npy[cntr]+'seeds.npy')

# %%
seeds
# Out:
# array([475, 541, 104, 888, 561])

# %% [markdown]
# #### Convert data into tensors, etc.

# %%
batch_size = 100 ##100

# %%
pos_seq_idx = np.array([0,0,1,1,2,2])

# %%
train_loader = {}
test_loader = {}
test_temp_loader = {}

# %%
for cntr in range(nRuns):
    train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=True)
    test_loader[cntr] = makeTensorLoaders((repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)
    test_temp_loader[cntr] = makeTensorLoaders((repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),
                                          batch_size,shuffle=False)

# %%
# kk = 3
# print(np.min(allStatesTestTemp[kk]))
# ix = np.where(allStatesTestTemp[kk]==np.min(allStatesTestTemp[kk]))[0]
# print(repsTestTemp[kk][ix])
# print(yRepsTestTemp[kk][ix])

# %% [markdown]
# #### Load architectures, models, etc.

# %%
n_latent = 16 ## make sure it is the same in the architecture file as well
pop_list = [2,5,4] ## make sure it is the same in the architecture file as well

# %%
from architecture_single_feedback import microcircuit

# %%
model = {}
optimizer_rec = {}
optimizer_pc = {}

# %%
#specify loss function
reconLoss = nn.MSELoss()

#optimizer learning rate
eta_rec = 0.001
eta_pc = 0.0001

# %%
for cntr in range(nRuns):
    model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,pop_list=pop_list,bsize=batch_size,
                               manual_seed=seeds[cntr],task='lattice')
    model[cntr].to(device)

# %%
for cntr in range(nRuns):
    optimizer_rec[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_rec)
    optimizer_pc[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_pc)

# %% [markdown]
# #### Train and collect activations

# %%
for data, f_target, lastEvent, surpriseBinary in train_loader[0]:
    if train_on_gpu:
        data, f_target = data.float().cuda(), f_target.float().cuda()
    else: data, f_target = data.float(), f_target.float()

# %%
output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[0](data)

# %%
nSteps = data.shape[1]

# %%
n_epochs = 100 ## number of epochs
div = n_epochs//n_epochs ## try ensuring that number used to divide by is a factor of n_epochs

# %%
feedback = True

# %%
def findMSE(output):
    errSq = output**2
    MSE_mat_samples_seq = errSq/np.prod(errSq.shape)
    MSE_samples = torch.mean(MSE_mat_samples_seq,1)
    return MSE_samples

# %%
train_losses = {}
test_losses = {}
temp_losses = {}

train_expected_rec_losses = {}
train_expected_fb_losses = {}

test_expected_rec_losses = {}
test_expected_fb_losses = {}

test_surprise_rec_losses = {}
test_surprise_fb_losses = {}

MSE_mat_full_test = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    train_losses[cntr] = np.zeros(n_epochs+1)
    test_losses[cntr] = np.zeros(n_epochs+1)
    temp_losses[cntr] = np.zeros(n_epochs+1)

    train_loss_min = np.Inf
    best_epoch = 0

    train_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    train_expected_fb_losses[cntr] = np.zeros(n_epochs+1)

    test_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_fb_losses[cntr] = np.zeros(n_epochs+1)
    
    test_surprise_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_surprise_fb_losses[cntr] = np.zeros(n_epochs+1)

    MSE_mat_full_test[cntr] = np.zeros(n_epochs+1)

    for epoch in (range(1,n_epochs+1)):

        train_loss = 0.0

        train_expected_rec_loss = 0.0
        train_expected_fb_loss = 0.0
        
        test_expected_rec_loss = 0.0
        test_expected_fb_loss = 0.0

        temp_rec_loss = 0.0
        temp_fb_loss = 0.0
        
        test_loss = 0.0
        temp_loss = 0.0

        cnt = 0
        
        ## Save model without training
        if epoch == 1:
            
            model[cntr].eval()
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_0.pt') ## Save model before any training
            
            ## Losses at 0th epoch
            for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
                if train_on_gpu:
                    data, f_target = data.float().cuda(), f_target.float().cuda()
                else:
                    data, f_target = data.float(), f_target.float()

                ##define all-sequence targets
                target = f_target

                optimizer_rec[cntr].zero_grad() #clears older gradients
                optimizer_pc[cntr].zero_grad() #clears older gradients
                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

                err_rec = torch.linalg.norm((output_pred-target),dim=2)
                err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
                MSE_samples_rec = findMSE(err_rec)
                MSE_samples_fb = findMSE(err_fb)

                loss = reconLoss(output_pred,target) #calculate the loss for the batch
                train_loss += loss.item()*data.size(0) #update training loss

                train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
                train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
                                    
            ## calculate average loss
            train_loss = train_loss/len(train_loader[cntr].dataset)
            
            ## Training loss at initialization
            train_losses[cntr][0] = train_loss
            train_expected_rec_losses[cntr][0] = train_expected_rec_loss
            train_expected_fb_losses[cntr][0] = train_expected_fb_loss
            
            ## Test losses at initialization
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test

                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)
                
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                # calculate the batch loss
                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
#             print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][0] = test_loss

            test_expected_rec_losses[cntr][0] = test_expected_rec_loss
            test_expected_fb_losses[cntr][0] = test_expected_fb_loss
        
        ## Test temp losses at initialization
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                    
                ##define all-sequence targets
                target_temp = f_target_temp

                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)
                loss_temp = reconLoss(output_pred_temp,target_temp)
                err_temp_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                # calculate the batch loss
                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_temp.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
#             print('Temp Loss: {:.6f}\n'.format(test_loss))

            temp_losses[cntr][0] = temp_loss

            test_surprise_rec_losses[cntr][0] = temp_rec_loss
            test_surprise_fb_losses[cntr][0] = temp_fb_loss

        #train model
        model[cntr].train()
        for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
            if train_on_gpu:
                data, f_target = data.float().cuda(), f_target.float().cuda()
            else:
                data, f_target = data.float(), f_target.float()

            ##define all-sequence targets
            target = f_target

            output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

            err_rec = torch.linalg.norm((output_pred-target),dim=2)
            err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
            MSE_samples_rec = findMSE(err_rec)
            MSE_samples_fb = findMSE(err_fb)
            
            loss = reconLoss(output_pred,target) #calculate the loss for the batch
            train_loss += loss.item()*data.size(0) #update training loss
            fbloss = torch.mean(MSE_samples_fb)

            optimizer_rec[cntr].zero_grad() #clears older gradients
            optimizer_pc[cntr].zero_grad() #clears older gradients
            ######## feedback error updates only higher-cortical area
            if (feedback)&(epoch%2==0):
                for name, param in model[cntr].named_parameters():
                    if ('FF' in name) or ('L23' in name) or ('L4' in name) or ('L56' in name):
                        param.require_grad = False
                fbloss.backward()
                optimizer_pc[cntr].step()
                for name, param in model[cntr].named_parameters():
                    param.require_grad = True
            else:
                loss.backward() #backprop
                optimizer_rec[cntr].step() #update parameters in direction of the -ve gradient  

            train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
            train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
        
        #calculate average loss
        train_loss = train_loss/len(train_loader[cntr].dataset)

        #training/validation stats
        train_losses[cntr][epoch] = train_loss
        train_expected_rec_losses[cntr][epoch] = train_expected_rec_loss
        train_expected_fb_losses[cntr][epoch] = train_expected_fb_loss

        #save model if the training loss decreased
        if train_loss <= train_loss_min:
            print('Epoch: {}, Train Loss Decreased!! ({:.6f}-->{:.6f})'.format(epoch,train_loss_min,train_loss))
            torch.save(model[cntr].state_dict(),pp_pts[cntr]+'predRNN.pt')
            train_loss_min = train_loss
            best_epoch = epoch

        if epoch%div == 0:
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_'+str(epoch)+'.pt')
            
            model[cntr].eval()
            
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test
                
                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)

                # calculate the batch loss
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
            print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][epoch] = test_loss

            test_expected_rec_losses[cntr][epoch] = test_expected_rec_loss
            test_expected_fb_losses[cntr][epoch] = test_expected_fb_loss
            
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                
                ##define all-sequence targets
                target_temp = f_target_temp
                
                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)

                # calculate the batch loss
                err_temp_rec = torch.linalg.norm((output_pred_temp-target_temp),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_temp[0],dim=2)+torch.linalg.norm(feedbackDiffs_temp[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_test.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
            print('Temp Loss: {:.6f}\n'.format(temp_loss))

            temp_losses[cntr][epoch] = temp_loss

            test_surprise_rec_losses[cntr][epoch] = temp_rec_loss
            test_surprise_fb_losses[cntr][epoch] = temp_fb_loss
            
    print('----------------------------------------------------')
            
    outF = open(pp+npp[cntr]+"training-details.txt", "w")
    outF.write('# epochs = ' + str(n_epochs))
    outF.write('\n')
    outF.write('Best epoch = '+str(best_epoch))
    outF.write('\n')
    outF.write('Minimum training loss = ' + str(train_loss_min))
    outF.write('\n')
    outF.write('Total number of samples = ' + str(nTot))
    outF.write('\n')
    outF.write('Number of training samples = ' + str(nTrain))
    outF.write('\n')
    outF.write('Number of testing samples = ' + str(nTest))
    outF.write('\n')
    outF.write('Dimensionality of representations = ' + str(dim))
    outF.write('\n')
    outF.write('Length of sequences = ' + str(lenSeq))
    outF.write('\n')
    outF.close()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1, Train Loss Decreased!! (inf-->0.217547)
# Test Loss: 0.185398
#
# Temp Loss: 0.185400
#
# Epoch: 2, Train Loss Decreased!! (0.217547-->0.184473)
# Test Loss: 0.184630
#
# Temp Loss: 0.184493
#
# Epoch: 3, Train Loss Decreased!! (0.184473-->0.182709)
# Test Loss: 0.181245
#
# Temp Loss: 0.181255
#
# Epoch: 4, Train Loss Decreased!! (0.182709-->0.181218)
# Test Loss: 0.181188
#
# Temp Loss: 0.181298
#
# Epoch: 5, Train Loss Decreased!! (0.181218-->0.180888)
# Test Loss: 0.180363
#
# Temp Loss: 0.180547
#
# Epoch: 6, Train Loss Decreased!! (0.180888-->0.180308)
# Test Loss: 0.180394
#
# Temp Loss: 0.180532
#
# Epoch: 7, Train Loss Decreased!! (0.180308-->0.179770)
# Test Loss: 0.178679
#
# Temp Loss: 0.180612
#
# Epoch: 8, Train Loss Decreased!! (0.179770-->0.178696)
# Test Loss: 0.178822
#
# Temp Loss: 0.180500
#
# Epoch: 9, Train Loss Decreased!! (0.178696-->0.177166)
# Test Loss: 0.175065
#
# Temp Loss: 0.184078
#
# Epoch: 10, Train Loss Decreased!! (0.177166-->0.174730)
# Test Loss: 0.175062
#
# Temp Loss: 0.183475
#
# Epoch: 11, Train Loss Decreased!! (0.174730-->0.173196)
# Test Loss: 0.171599
#
# Temp Loss: 0.186109
#
# Epoch: 12, Train Loss Decreased!! (0.173196-->0.171143)
# Test Loss: 0.171867
#
# Temp Loss: 0.185513
#
# Epoch: 13, Train Loss Decreased!! (0.171143-->0.169927)
# Test Loss: 0.168388
#
# Temp Loss: 0.186328
#
# Epoch: 14, Train Loss Decreased!! (0.169927-->0.167637)
# Test Loss: 0.168559
#
# Temp Loss: 0.185999
#
# Epoch: 15, Train Loss Decreased!! (0.167637-->0.166473)
# Test Loss: 0.164685
#
# Temp Loss: 0.188337
#
# Epoch: 16, Train Loss Decreased!! (0.166473-->0.163867)
# Test Loss: 0.164629
#
# Temp Loss: 0.187832
#
# Epoch: 17, Train Loss Decreased!! (0.163867-->0.162398)
# Test Loss: 0.160668
#
# Temp Loss: 0.193134
#
# Epoch: 18, Train Loss Decreased!! (0.162398-->0.160104)
# Test Loss: 0.160870
#
# Temp Loss: 0.192222
#
# Epoch: 19, Train Loss Decreased!! (0.160104-->0.158603)
# Test Loss: 0.157709
#
# Temp Loss: 0.195380
#
# Epoch: 20, Train Loss Decreased!! (0.158603-->0.156690)
# Test Loss: 0.157733
#
# Temp Loss: 0.194521
#
# Epoch: 21, Train Loss Decreased!! (0.156690-->0.155821)
# Test Loss: 0.155378
#
# Temp Loss: 0.196277
#
# Epoch: 22, Train Loss Decreased!! (0.155821-->0.154238)
# Test Loss: 0.155406
#
# Temp Loss: 0.195331
#
# Epoch: 23, Train Loss Decreased!! (0.154238-->0.153513)
# Test Loss: 0.152817
#
# Temp Loss: 0.196929
#
# Epoch: 24, Train Loss Decreased!! (0.153513-->0.151824)
# Test Loss: 0.153040
#
# Temp Loss: 0.195713
#
# Epoch: 25, Train Loss Decreased!! (0.151824-->0.151135)
# Test Loss: 0.150181
#
# Temp Loss: 0.197501
#
# Epoch: 26, Train Loss Decreased!! (0.151135-->0.149046)
# Test Loss: 0.150434
#
# Temp Loss: 0.196057
#
# Epoch: 27, Train Loss Decreased!! (0.149046-->0.148286)
# Test Loss: 0.147863
#
# Temp Loss: 0.199234
#
# Epoch: 28, Train Loss Decreased!! (0.148286-->0.146476)
# Test Loss: 0.148184
#
# Temp Loss: 0.197812
#
# Epoch: 29, Train Loss Decreased!! (0.146476-->0.145050)
# Test Loss: 0.143317
#
# Temp Loss: 0.199039
#
# Epoch: 30, Train Loss Decreased!! (0.145050-->0.142665)
# Test Loss: 0.144278
#
# Temp Loss: 0.197456
#
# Epoch: 31, Train Loss Decreased!! (0.142665-->0.141481)
# Test Loss: 0.140366
#
# Temp Loss: 0.199650
#
# Epoch: 32, Train Loss Decreased!! (0.141481-->0.139342)
# Test Loss: 0.141126
#
# Temp Loss: 0.198039
#
# Epoch: 33, Train Loss Decreased!! (0.139342-->0.137829)
# Test Loss: 0.136341
#
# Temp Loss: 0.202970
#
# Epoch: 34, Train Loss Decreased!! (0.137829-->0.135433)
# Test Loss: 0.137246
#
# Temp Loss: 0.201793
#
# Epoch: 35, Train Loss Decreased!! (0.135433-->0.133870)
# Test Loss: 0.132058
#
# Temp Loss: 0.204566
#
# Epoch: 36, Train Loss Decreased!! (0.133870-->0.131269)
# Test Loss: 0.133294
#
# Temp Loss: 0.203082
#
# Epoch: 37, Train Loss Decreased!! (0.131269-->0.129743)
# Test Loss: 0.127983
#
# Temp Loss: 0.207347
#
# Epoch: 38, Train Loss Decreased!! (0.129743-->0.126988)
# Test Loss: 0.129002
#
# Temp Loss: 0.205466
#
# Epoch: 39, Train Loss Decreased!! (0.126988-->0.124919)
# Test Loss: 0.122416
#
# Temp Loss: 0.206909
#
# Epoch: 40, Train Loss Decreased!! (0.124919-->0.121695)
# Test Loss: 0.123795
#
# Temp Loss: 0.205357
#
# Epoch: 41, Train Loss Decreased!! (0.121695-->0.119160)
# Test Loss: 0.115988
#
# Temp Loss: 0.210002
#
# Epoch: 42, Train Loss Decreased!! (0.119160-->0.115597)
# Test Loss: 0.117597
#
# Temp Loss: 0.208343
#
# Epoch: 43, Train Loss Decreased!! (0.115597-->0.112946)
# Test Loss: 0.109987
#
# Temp Loss: 0.211066
#
# Epoch: 44, Train Loss Decreased!! (0.112946-->0.109218)
# Test Loss: 0.111483
#
# Temp Loss: 0.209463
#
# Epoch: 45, Train Loss Decreased!! (0.109218-->0.106517)
# Test Loss: 0.103478
#
# Temp Loss: 0.212956
#
# Epoch: 46, Train Loss Decreased!! (0.106517-->0.102607)
# Test Loss: 0.105728
#
# Temp Loss: 0.211439
#
# Epoch: 47, Train Loss Decreased!! (0.102607-->0.098851)
# Test Loss: 0.095370
#
# Temp Loss: 0.214897
#
# Epoch: 48, Train Loss Decreased!! (0.098851-->0.094099)
# Test Loss: 0.097285
#
# Temp Loss: 0.213285
#
# Epoch: 49, Train Loss Decreased!! (0.094099-->0.090574)
# Test Loss: 0.086519
#
# Temp Loss: 0.217015
#
# Epoch: 50, Train Loss Decreased!! (0.090574-->0.085235)
# Test Loss: 0.088668
#
# Temp Loss: 0.216032
#
# Epoch: 51, Train Loss Decreased!! (0.085235-->0.081253)
# Test Loss: 0.076932
#
# Temp Loss: 0.218575
#
# Epoch: 52, Train Loss Decreased!! (0.081253-->0.075954)
# Test Loss: 0.079442
#
# Temp Loss: 0.216711
#
# Epoch: 53, Train Loss Decreased!! (0.075954-->0.071890)
# Test Loss: 0.068142
#
# Temp Loss: 0.222667
#
# Epoch: 54, Train Loss Decreased!! (0.071890-->0.066709)
# Test Loss: 0.069997
#
# Temp Loss: 0.220819
#
# Epoch: 55, Train Loss Decreased!! (0.066709-->0.062416)
# Test Loss: 0.058544
#
# Temp Loss: 0.224317
#
# Epoch: 56, Train Loss Decreased!! (0.062416-->0.057293)
# Test Loss: 0.060934
#
# Temp Loss: 0.222836
#
# Epoch: 57, Train Loss Decreased!! (0.057293-->0.053176)
# Test Loss: 0.049371
#
# Temp Loss: 0.229538
#
# Epoch: 58, Train Loss Decreased!! (0.053176-->0.048871)
# Test Loss: 0.053031
#
# Temp Loss: 0.228343
#
# Epoch: 59, Train Loss Decreased!! (0.048871-->0.044632)
# Test Loss: 0.040794
#
# Temp Loss: 0.232753
#
# Epoch: 60, Train Loss Decreased!! (0.044632-->0.040294)
# Test Loss: 0.043532
#
# Temp Loss: 0.230496
#
# Epoch: 61, Train Loss Decreased!! (0.040294-->0.036670)
# Test Loss: 0.033169
#
# Temp Loss: 0.236345
#
# Epoch: 62, Train Loss Decreased!! (0.036670-->0.033000)
# Test Loss: 0.036343
#
# Temp Loss: 0.234080
#
# Epoch: 63, Train Loss Decreased!! (0.033000-->0.030193)
# Test Loss: 0.026987
#
# Temp Loss: 0.238467
#
# Epoch: 64, Train Loss Decreased!! (0.030193-->0.026502)
# Test Loss: 0.029469
#
# Temp Loss: 0.236135
#
# Epoch: 65, Train Loss Decreased!! (0.026502-->0.024424)
# Test Loss: 0.021965
#
# Temp Loss: 0.241293
#
# Epoch: 66, Train Loss Decreased!! (0.024424-->0.021463)
# Test Loss: 0.024302
#
# Temp Loss: 0.238752
#
# Epoch: 67, Train Loss Decreased!! (0.021463-->0.019989)
# Test Loss: 0.018137
#
# Temp Loss: 0.244159
#
# Epoch: 68, Train Loss Decreased!! (0.019989-->0.017810)
# Test Loss: 0.020600
#
# Temp Loss: 0.241899
#
# Epoch: 69, Train Loss Decreased!! (0.017810-->0.016346)
# Test Loss: 0.014722
#
# Temp Loss: 0.245889
#
# Epoch: 70, Train Loss Decreased!! (0.016346-->0.014492)
# Test Loss: 0.016825
#
# Temp Loss: 0.243508
#
# Epoch: 71, Train Loss Decreased!! (0.014492-->0.013457)
# Test Loss: 0.012350
#
# Temp Loss: 0.247585
#
# Epoch: 72, Train Loss Decreased!! (0.013457-->0.012094)
# Test Loss: 0.014055
#
# Temp Loss: 0.244613
#
# Epoch: 73, Train Loss Decreased!! (0.012094-->0.011297)
# Test Loss: 0.010318
#
# Temp Loss: 0.249404
#
# Epoch: 74, Train Loss Decreased!! (0.011297-->0.010351)
# Test Loss: 0.012427
#
# Temp Loss: 0.246246
#
# Epoch: 75, Train Loss Decreased!! (0.010351-->0.009702)
# Test Loss: 0.008833
#
# Temp Loss: 0.250545
#
# Epoch: 76, Train Loss Decreased!! (0.009702-->0.008588)
# Test Loss: 0.010301
#
# Temp Loss: 0.247072
#
# Epoch: 77, Train Loss Decreased!! (0.008588-->0.007910)
# Test Loss: 0.007290
#
# Temp Loss: 0.251179
#
# Epoch: 78, Train Loss Decreased!! (0.007910-->0.007438)
# Test Loss: 0.009302
#
# Temp Loss: 0.247148
#
# Epoch: 79, Train Loss Decreased!! (0.007438-->0.006918)
# Test Loss: 0.006217
#
# Temp Loss: 0.251616
#
# Epoch: 80, Train Loss Decreased!! (0.006918-->0.006264)
# Test Loss: 0.007834
#
# Temp Loss: 0.248062
#
# Epoch: 81, Train Loss Decreased!! (0.006264-->0.006157)
# Test Loss: 0.005597
#
# Temp Loss: 0.252479
#
# Epoch: 82, Train Loss Decreased!! (0.006157-->0.005528)
# Test Loss: 0.006683
#
# Temp Loss: 0.248560
#
# Epoch: 83, Train Loss Decreased!! (0.005528-->0.005406)
# Test Loss: 0.004782
#
# Temp Loss: 0.253031
#
# Epoch: 84, Train Loss Decreased!! (0.005406-->0.004983)
# Test Loss: 0.006367
#
# Temp Loss: 0.248778
#
# Epoch: 85, Train Loss Decreased!! (0.004983-->0.004756)
# Test Loss: 0.004372
#
# Temp Loss: 0.252985
#
# Epoch: 86, Train Loss Decreased!! (0.004756-->0.004417)
# Test Loss: 0.005624
#
# Temp Loss: 0.249061
#
# Epoch: 87, Train Loss Decreased!! (0.004417-->0.004366)
# Test Loss: 0.003953
#
# Temp Loss: 0.253193
#
# Epoch: 88, Train Loss Decreased!! (0.004366-->0.004156)
# Test Loss: 0.005632
#
# Temp Loss: 0.248869
#
# Epoch: 89, Train Loss Decreased!! (0.004156-->0.004007)
# Test Loss: 0.003641
#
# Temp Loss: 0.253256
#
# Epoch: 90, Train Loss Decreased!! (0.004007-->0.003851)
# Test Loss: 0.005171
#
# Temp Loss: 0.249158
#
# Epoch: 91, Train Loss Decreased!! (0.003851-->0.003826)
# Test Loss: 0.003496
#
# Temp Loss: 0.254046
#
# Epoch: 92, Train Loss Decreased!! (0.003826-->0.003549)
# Test Loss: 0.004732
#
# Temp Loss: 0.249896
#
# Epoch: 93, Train Loss Decreased!! (0.003549-->0.003544)
# Test Loss: 0.003202
#
# Temp Loss: 0.253959
#
# Epoch: 94, Train Loss Decreased!! (0.003544-->0.003431)
# Test Loss: 0.004655
#
# Temp Loss: 0.249314
#
# Epoch: 95, Train Loss Decreased!! (0.003431-->0.003301)
# Test Loss: 0.002872
#
# Temp Loss: 0.253595
#
# Epoch: 96, Train Loss Decreased!! (0.003301-->0.003209)
# Test Loss: 0.004372
#
# Temp Loss: 0.249044
#
# Epoch: 97, Train Loss Decreased!! (0.003209-->0.003173)
# Test Loss: 0.002760
#
# Temp Loss: 0.253597
#
# Epoch: 98, Train Loss Decreased!! (0.003173-->0.003048)
# Test Loss: 0.004164
#
# Temp Loss: 0.249453
#
# Epoch: 99, Train Loss Decreased!! (0.003048-->0.002971)
# Test Loss: 0.002553
#
# Temp Loss: 0.254032
#  20%|██        | 1/5 [00:48<03:14, 48.64s/it]
# Epoch: 100, Train Loss Decreased!! (0.002971-->0.002883)
# Test Loss: 0.004010
#
# Temp Loss: 0.249731
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.204052)
# Test Loss: 0.178591
#
# Temp Loss: 0.179549
#
# Epoch: 2, Train Loss Decreased!! (0.204052-->0.178142)
# Test Loss: 0.177896
#
# Temp Loss: 0.178775
#
# Epoch: 3, Train Loss Decreased!! (0.178142-->0.176915)
# Test Loss: 0.175680
#
# Temp Loss: 0.176376
#
# Epoch: 4, Train Loss Decreased!! (0.176915-->0.175391)
# Test Loss: 0.175755
#
# Temp Loss: 0.176493
#
# Epoch: 5, Train Loss Decreased!! (0.175391-->0.174969)
# Test Loss: 0.174543
#
# Temp Loss: 0.175900
#
# Epoch: 6, Train Loss Decreased!! (0.174969-->0.174266)
# Test Loss: 0.174657
#
# Temp Loss: 0.175878
#
# Epoch: 7, Train Loss Decreased!! (0.174266-->0.173587)
# Test Loss: 0.172268
#
# Temp Loss: 0.176129
#
# Epoch: 8, Train Loss Decreased!! (0.173587-->0.172157)
# Test Loss: 0.172488
#
# Temp Loss: 0.175914
#
# Epoch: 9, Train Loss Decreased!! (0.172157-->0.170668)
# Test Loss: 0.169489
#
# Temp Loss: 0.178628
#
# Epoch: 10, Train Loss Decreased!! (0.170668-->0.168744)
# Test Loss: 0.169312
#
# Temp Loss: 0.178377
#
# Epoch: 11, Train Loss Decreased!! (0.168744-->0.167160)
# Test Loss: 0.166229
#
# Temp Loss: 0.180580
#
# Epoch: 12, Train Loss Decreased!! (0.167160-->0.165058)
# Test Loss: 0.165953
#
# Temp Loss: 0.180300
#
# Epoch: 13, Train Loss Decreased!! (0.165058-->0.164062)
# Test Loss: 0.163718
#
# Temp Loss: 0.179631
#
# Epoch: 14, Train Loss Decreased!! (0.164062-->0.162490)
# Test Loss: 0.163686
#
# Temp Loss: 0.179389
#
# Epoch: 15, Train Loss Decreased!! (0.162490-->0.161232)
# Test Loss: 0.160705
#
# Temp Loss: 0.179833
#
# Epoch: 16, Train Loss Decreased!! (0.161232-->0.159312)
# Test Loss: 0.160663
#
# Temp Loss: 0.179525
#
# Epoch: 17, Train Loss Decreased!! (0.159312-->0.158117)
# Test Loss: 0.157963
#
# Temp Loss: 0.182490
#
# Epoch: 18, Train Loss Decreased!! (0.158117-->0.156107)
# Test Loss: 0.157785
#
# Temp Loss: 0.182023
#
# Epoch: 19, Train Loss Decreased!! (0.156107-->0.154941)
# Test Loss: 0.155001
#
# Temp Loss: 0.186295
#
# Epoch: 20, Train Loss Decreased!! (0.154941-->0.152895)
# Test Loss: 0.154769
#
# Temp Loss: 0.185314
#
# Epoch: 21, Train Loss Decreased!! (0.152895-->0.151620)
# Test Loss: 0.151516
#
# Temp Loss: 0.188667
#
# Epoch: 22, Train Loss Decreased!! (0.151620-->0.149398)
# Test Loss: 0.151446
#
# Temp Loss: 0.187695
#
# Epoch: 23, Train Loss Decreased!! (0.149398-->0.148116)
# Test Loss: 0.147862
#
# Temp Loss: 0.190088
#
# Epoch: 24, Train Loss Decreased!! (0.148116-->0.145663)
# Test Loss: 0.147885
#
# Temp Loss: 0.189205
#
# Epoch: 25, Train Loss Decreased!! (0.145663-->0.144476)
# Test Loss: 0.144620
#
# Temp Loss: 0.190400
#
# Epoch: 26, Train Loss Decreased!! (0.144476-->0.142275)
# Test Loss: 0.144706
#
# Temp Loss: 0.189716
#
# Epoch: 27, Train Loss Decreased!! (0.142275-->0.140996)
# Test Loss: 0.141370
#
# Temp Loss: 0.190181
#
# Epoch: 28, Train Loss Decreased!! (0.140996-->0.139157)
# Test Loss: 0.141681
#
# Temp Loss: 0.189789
#
# Epoch: 29, Train Loss Decreased!! (0.139157-->0.137144)
# Test Loss: 0.136430
#
# Temp Loss: 0.189312
#
# Epoch: 30, Train Loss Decreased!! (0.137144-->0.134357)
# Test Loss: 0.136887
#
# Temp Loss: 0.189581
#
# Epoch: 31, Train Loss Decreased!! (0.134357-->0.132724)
# Test Loss: 0.131772
#
# Temp Loss: 0.191972
#
# Epoch: 32, Train Loss Decreased!! (0.132724-->0.130222)
# Test Loss: 0.132561
#
# Temp Loss: 0.191627
#
# Epoch: 33, Train Loss Decreased!! (0.130222-->0.128438)
# Test Loss: 0.127553
#
# Temp Loss: 0.192334
#
# Epoch: 34, Train Loss Decreased!! (0.128438-->0.125637)
# Test Loss: 0.128004
#
# Temp Loss: 0.192106
#
# Epoch: 35, Train Loss Decreased!! (0.125637-->0.123860)
# Test Loss: 0.122958
#
# Temp Loss: 0.193916
#
# Epoch: 36, Train Loss Decreased!! (0.123860-->0.120993)
# Test Loss: 0.123586
#
# Temp Loss: 0.194200
#
# Epoch: 37, Train Loss Decreased!! (0.120993-->0.118989)
# Test Loss: 0.118370
#
# Temp Loss: 0.196954
#
# Epoch: 38, Train Loss Decreased!! (0.118989-->0.116206)
# Test Loss: 0.119104
#
# Temp Loss: 0.197090
#
# Epoch: 39, Train Loss Decreased!! (0.116206-->0.113856)
# Test Loss: 0.113029
#
# Temp Loss: 0.198570
#
# Epoch: 40, Train Loss Decreased!! (0.113856-->0.110671)
# Test Loss: 0.113705
#
# Temp Loss: 0.198292
#
# Epoch: 41, Train Loss Decreased!! (0.110671-->0.108326)
# Test Loss: 0.106965
#
# Temp Loss: 0.200077
#
# Epoch: 42, Train Loss Decreased!! (0.108326-->0.104787)
# Test Loss: 0.107729
#
# Temp Loss: 0.200275
#
# Epoch: 43, Train Loss Decreased!! (0.104787-->0.102522)
# Test Loss: 0.101210
#
# Temp Loss: 0.200683
#
# Epoch: 44, Train Loss Decreased!! (0.102522-->0.099028)
# Test Loss: 0.102017
#
# Temp Loss: 0.200697
#
# Epoch: 45, Train Loss Decreased!! (0.099028-->0.096196)
# Test Loss: 0.094328
#
# Temp Loss: 0.203026
#
# Epoch: 46, Train Loss Decreased!! (0.096196-->0.091961)
# Test Loss: 0.094929
#
# Temp Loss: 0.202817
#
# Epoch: 47, Train Loss Decreased!! (0.091961-->0.088835)
# Test Loss: 0.086215
#
# Temp Loss: 0.202856
#
# Epoch: 48, Train Loss Decreased!! (0.088835-->0.084450)
# Test Loss: 0.087046
#
# Temp Loss: 0.202358
#
# Epoch: 49, Train Loss Decreased!! (0.084450-->0.081074)
# Test Loss: 0.077690
#
# Temp Loss: 0.206161
#
# Epoch: 50, Train Loss Decreased!! (0.081074-->0.076520)
# Test Loss: 0.078832
#
# Temp Loss: 0.206070
#
# Epoch: 51, Train Loss Decreased!! (0.076520-->0.073159)
# Test Loss: 0.069980
#
# Temp Loss: 0.206890
#
# Epoch: 52, Train Loss Decreased!! (0.073159-->0.068629)
# Test Loss: 0.071096
#
# Temp Loss: 0.206458
#
# Epoch: 53, Train Loss Decreased!! (0.068629-->0.065291)
# Test Loss: 0.061890
#
# Temp Loss: 0.211460
#
# Epoch: 54, Train Loss Decreased!! (0.065291-->0.060929)
# Test Loss: 0.063395
#
# Temp Loss: 0.211127
#
# Epoch: 55, Train Loss Decreased!! (0.060929-->0.057837)
# Test Loss: 0.054743
#
# Temp Loss: 0.212898
#
# Epoch: 56, Train Loss Decreased!! (0.057837-->0.053840)
# Test Loss: 0.055733
#
# Temp Loss: 0.212742
#
# Epoch: 57, Train Loss Decreased!! (0.053840-->0.050747)
# Test Loss: 0.048393
#
# Temp Loss: 0.215062
#
# Epoch: 58, Train Loss Decreased!! (0.050747-->0.047025)
# Test Loss: 0.049284
#
# Temp Loss: 0.214786
#
# Epoch: 59, Train Loss Decreased!! (0.047025-->0.044174)
# Test Loss: 0.041754
#
# Temp Loss: 0.217109
#
# Epoch: 60, Train Loss Decreased!! (0.044174-->0.040934)
# Test Loss: 0.043418
#
# Temp Loss: 0.216549
#
# Epoch: 61, Train Loss Decreased!! (0.040934-->0.038193)
# Test Loss: 0.036121
#
# Temp Loss: 0.219458
#
# Epoch: 62, Train Loss Decreased!! (0.038193-->0.035075)
# Test Loss: 0.037019
#
# Temp Loss: 0.218764
#
# Epoch: 63, Train Loss Decreased!! (0.035075-->0.032810)
# Test Loss: 0.031036
#
# Temp Loss: 0.222949
#
# Epoch: 64, Train Loss Decreased!! (0.032810-->0.029990)
# Test Loss: 0.032062
#
# Temp Loss: 0.222378
#
# Epoch: 65, Train Loss Decreased!! (0.029990-->0.028107)
# Test Loss: 0.026434
#
# Temp Loss: 0.223699
#
# Epoch: 66, Train Loss Decreased!! (0.028107-->0.025853)
# Test Loss: 0.027371
#
# Temp Loss: 0.222771
#
# Epoch: 67, Train Loss Decreased!! (0.025853-->0.024220)
# Test Loss: 0.022503
#
# Temp Loss: 0.226411
#
# Epoch: 68, Train Loss Decreased!! (0.024220-->0.022055)
# Test Loss: 0.023257
#
# Temp Loss: 0.225550
#
# Epoch: 69, Train Loss Decreased!! (0.022055-->0.020809)
# Test Loss: 0.019634
#
# Temp Loss: 0.227425
#
# Epoch: 70, Train Loss Decreased!! (0.020809-->0.019112)
# Test Loss: 0.020318
#
# Temp Loss: 0.226459
#
# Epoch: 71, Train Loss Decreased!! (0.019112-->0.018184)
# Test Loss: 0.017259
#
# Temp Loss: 0.229967
#
# Epoch: 72, Train Loss Decreased!! (0.018184-->0.016844)
# Test Loss: 0.017951
#
# Temp Loss: 0.228695
#
# Epoch: 73, Train Loss Decreased!! (0.016844-->0.015933)
# Test Loss: 0.015004
#
# Temp Loss: 0.231190
#
# Epoch: 74, Train Loss Decreased!! (0.015933-->0.014783)
# Test Loss: 0.015898
#
# Temp Loss: 0.230151
#
# Epoch: 75, Train Loss Decreased!! (0.014783-->0.013748)
# Test Loss: 0.013025
#
# Temp Loss: 0.231476
#
# Epoch: 76, Train Loss Decreased!! (0.013748-->0.012771)
# Test Loss: 0.013635
#
# Temp Loss: 0.230521
#
# Epoch: 77, Train Loss Decreased!! (0.012771-->0.011983)
# Test Loss: 0.011281
#
# Temp Loss: 0.232828
#
# Epoch: 78, Train Loss Decreased!! (0.011983-->0.011054)
# Test Loss: 0.012027
#
# Temp Loss: 0.231746
#
# Epoch: 79, Train Loss Decreased!! (0.011054-->0.010451)
# Test Loss: 0.009624
#
# Temp Loss: 0.233603
#
# Epoch: 80, Train Loss Decreased!! (0.010451-->0.009476)
# Test Loss: 0.010449
#
# Temp Loss: 0.232547
#
# Epoch: 81, Train Loss Decreased!! (0.009476-->0.008911)
# Test Loss: 0.008434
#
# Temp Loss: 0.235253
#
# Epoch: 82, Train Loss Decreased!! (0.008911-->0.008264)
# Test Loss: 0.009186
#
# Temp Loss: 0.233951
#
# Epoch: 83, Train Loss Decreased!! (0.008264-->0.007842)
# Test Loss: 0.007337
#
# Temp Loss: 0.235148
#
# Epoch: 84, Train Loss Decreased!! (0.007842-->0.007171)
# Test Loss: 0.007988
#
# Temp Loss: 0.233878
#
# Epoch: 85, Train Loss Decreased!! (0.007171-->0.006697)
# Test Loss: 0.006341
#
# Temp Loss: 0.236013
#
# Epoch: 86, Train Loss Decreased!! (0.006697-->0.006281)
# Test Loss: 0.007205
#
# Temp Loss: 0.234536
#
# Epoch: 87, Train Loss Decreased!! (0.006281-->0.005960)
# Test Loss: 0.005620
#
# Temp Loss: 0.236184
#
# Epoch: 88, Train Loss Decreased!! (0.005960-->0.005586)
# Test Loss: 0.006540
#
# Temp Loss: 0.234619
#
# Epoch: 89, Train Loss Decreased!! (0.005586-->0.005187)
# Test Loss: 0.004916
#
# Temp Loss: 0.236912
#
# Epoch: 90, Train Loss Decreased!! (0.005187-->0.004886)
# Test Loss: 0.005802
#
# Temp Loss: 0.235326
#
# Epoch: 91, Train Loss Decreased!! (0.004886-->0.004575)
# Test Loss: 0.004308
#
# Temp Loss: 0.237689
#
# Epoch: 92, Train Loss Decreased!! (0.004575-->0.004359)
# Test Loss: 0.005196
#
# Temp Loss: 0.235803
#
# Epoch: 93, Train Loss Decreased!! (0.004359-->0.004140)
# Test Loss: 0.003946
#
# Temp Loss: 0.237515
#
# Epoch: 94, Train Loss Decreased!! (0.004140-->0.003895)
# Test Loss: 0.004736
#
# Temp Loss: 0.235677
#
# Epoch: 95, Train Loss Decreased!! (0.003895-->0.003699)
# Test Loss: 0.003442
#
# Temp Loss: 0.238342
#
# Epoch: 96, Train Loss Decreased!! (0.003699-->0.003508)
# Test Loss: 0.004349
#
# Temp Loss: 0.236026
#
# Epoch: 97, Train Loss Decreased!! (0.003508-->0.003360)
# Test Loss: 0.003194
#
# Temp Loss: 0.238443
#
# Epoch: 98, Train Loss Decreased!! (0.003360-->0.003160)
# Test Loss: 0.003795
#
# Temp Loss: 0.236353
#
# Epoch: 99, Train Loss Decreased!! (0.003160-->0.003040)
# Test Loss: 0.002773
#
# Temp Loss: 0.238471
#  40%|████      | 2/5 [01:36<02:25, 48.39s/it]
# Epoch: 100, Train Loss Decreased!! (0.003040-->0.003036)
# Test Loss: 0.003995
#
# Temp Loss: 0.235983
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.211829)
# Test Loss: 0.179530
#
# Temp Loss: 0.179045
#
# Epoch: 2, Train Loss Decreased!! (0.211829-->0.179109)
# Test Loss: 0.178894
#
# Temp Loss: 0.178262
#
# Epoch: 3, Train Loss Decreased!! (0.179109-->0.178104)
# Test Loss: 0.176569
#
# Temp Loss: 0.175818
#
# Epoch: 4, Train Loss Decreased!! (0.178104-->0.176733)
# Test Loss: 0.176377
#
# Temp Loss: 0.175828
#
# Epoch: 5, Train Loss Decreased!! (0.176733-->0.176296)
# Test Loss: 0.175429
#
# Temp Loss: 0.174771
#
# Epoch: 6, Train Loss Decreased!! (0.176296-->0.175873)
# Test Loss: 0.175368
#
# Temp Loss: 0.174836
#
# Epoch: 7, Train Loss Decreased!! (0.175873-->0.175631)
# Test Loss: 0.174757
#
# Temp Loss: 0.174874
#
# Epoch: 8, Train Loss Decreased!! (0.175631-->0.175166)
# Test Loss: 0.174900
#
# Temp Loss: 0.174827
#
# Epoch: 9, Train Loss Decreased!! (0.175166-->0.174402)
# Test Loss: 0.172643
#
# Temp Loss: 0.175122
#
# Epoch: 10, Train Loss Decreased!! (0.174402-->0.172858)
# Test Loss: 0.172809
#
# Temp Loss: 0.174678
#
# Epoch: 11, Train Loss Decreased!! (0.172858-->0.170987)
# Test Loss: 0.169126
#
# Temp Loss: 0.178921
#
# Epoch: 12, Train Loss Decreased!! (0.170987-->0.168643)
# Test Loss: 0.169034
#
# Temp Loss: 0.178291
#
# Epoch: 13, Train Loss Decreased!! (0.168643-->0.166801)
# Test Loss: 0.165839
#
# Temp Loss: 0.181886
#
# Epoch: 14, Train Loss Decreased!! (0.166801-->0.164782)
# Test Loss: 0.165615
#
# Temp Loss: 0.181182
#
# Epoch: 15, Train Loss Decreased!! (0.164782-->0.163733)
# Test Loss: 0.163166
#
# Temp Loss: 0.183773
#
# Epoch: 16, Train Loss Decreased!! (0.163733-->0.162059)
# Test Loss: 0.163277
#
# Temp Loss: 0.182992
#
# Epoch: 17, Train Loss Decreased!! (0.162059-->0.160717)
# Test Loss: 0.160687
#
# Temp Loss: 0.189390
#
# Epoch: 18, Train Loss Decreased!! (0.160717-->0.158741)
# Test Loss: 0.160750
#
# Temp Loss: 0.188375
#
# Epoch: 19, Train Loss Decreased!! (0.158741-->0.157916)
# Test Loss: 0.158349
#
# Temp Loss: 0.189455
#
# Epoch: 20, Train Loss Decreased!! (0.157916-->0.156698)
# Test Loss: 0.158284
#
# Temp Loss: 0.188366
#
# Epoch: 21, Train Loss Decreased!! (0.156698-->0.155414)
# Test Loss: 0.155157
#
# Temp Loss: 0.190923
#
# Epoch: 22, Train Loss Decreased!! (0.155414-->0.153888)
# Test Loss: 0.155433
#
# Temp Loss: 0.190049
#
# Epoch: 23, Train Loss Decreased!! (0.153888-->0.152600)
# Test Loss: 0.152454
#
# Temp Loss: 0.196351
#
# Epoch: 24, Train Loss Decreased!! (0.152600-->0.150559)
# Test Loss: 0.152282
#
# Temp Loss: 0.194866
#
# Epoch: 25, Train Loss Decreased!! (0.150559-->0.149395)
# Test Loss: 0.148981
#
# Temp Loss: 0.196338
#
# Epoch: 26, Train Loss Decreased!! (0.149395-->0.147440)
# Test Loss: 0.149374
#
# Temp Loss: 0.195428
#
# Epoch: 27, Train Loss Decreased!! (0.147440-->0.145968)
# Test Loss: 0.145329
#
# Temp Loss: 0.197295
#
# Epoch: 28, Train Loss Decreased!! (0.145968-->0.143627)
# Test Loss: 0.145606
#
# Temp Loss: 0.195996
#
# Epoch: 29, Train Loss Decreased!! (0.143627-->0.142435)
# Test Loss: 0.141123
#
# Temp Loss: 0.200428
#
# Epoch: 30, Train Loss Decreased!! (0.142435-->0.139880)
# Test Loss: 0.141881
#
# Temp Loss: 0.199335
#
# Epoch: 31, Train Loss Decreased!! (0.139880-->0.138512)
# Test Loss: 0.137996
#
# Temp Loss: 0.202030
#
# Epoch: 32, Train Loss Decreased!! (0.138512-->0.136111)
# Test Loss: 0.138561
#
# Temp Loss: 0.200308
#
# Epoch: 33, Train Loss Decreased!! (0.136111-->0.134297)
# Test Loss: 0.133843
#
# Temp Loss: 0.204477
#
# Epoch: 34, Train Loss Decreased!! (0.134297-->0.131697)
# Test Loss: 0.134448
#
# Temp Loss: 0.202985
#
# Epoch: 35, Train Loss Decreased!! (0.131697-->0.130219)
# Test Loss: 0.129921
#
# Temp Loss: 0.205841
#
# Epoch: 36, Train Loss Decreased!! (0.130219-->0.127484)
# Test Loss: 0.130801
#
# Temp Loss: 0.204719
#
# Epoch: 37, Train Loss Decreased!! (0.127484-->0.125649)
# Test Loss: 0.125279
#
# Temp Loss: 0.206818
#
# Epoch: 38, Train Loss Decreased!! (0.125649-->0.122582)
# Test Loss: 0.125994
#
# Temp Loss: 0.205083
#
# Epoch: 39, Train Loss Decreased!! (0.122582-->0.120879)
# Test Loss: 0.120215
#
# Temp Loss: 0.206546
#
# Epoch: 40, Train Loss Decreased!! (0.120879-->0.117390)
# Test Loss: 0.120828
#
# Temp Loss: 0.205238
#
# Epoch: 41, Train Loss Decreased!! (0.117390-->0.115251)
# Test Loss: 0.114537
#
# Temp Loss: 0.208941
#
# Epoch: 42, Train Loss Decreased!! (0.115251-->0.111469)
# Test Loss: 0.115286
#
# Temp Loss: 0.206899
#
# Epoch: 43, Train Loss Decreased!! (0.111469-->0.108764)
# Test Loss: 0.107160
#
# Temp Loss: 0.209483
#
# Epoch: 44, Train Loss Decreased!! (0.108764-->0.104269)
# Test Loss: 0.108155
#
# Temp Loss: 0.208405
#
# Epoch: 45, Train Loss Decreased!! (0.104269-->0.101277)
# Test Loss: 0.099964
#
# Temp Loss: 0.211252
#
# Epoch: 46, Train Loss Decreased!! (0.101277-->0.097198)
# Test Loss: 0.101595
#
# Temp Loss: 0.210369
#
# Epoch: 47, Train Loss Decreased!! (0.097198-->0.093677)
# Test Loss: 0.091919
#
# Temp Loss: 0.213089
#
# Epoch: 48, Train Loss Decreased!! (0.093677-->0.088595)
# Test Loss: 0.093134
#
# Temp Loss: 0.211982
#
# Epoch: 49, Train Loss Decreased!! (0.088595-->0.084534)
# Test Loss: 0.082755
#
# Temp Loss: 0.214601
#
# Epoch: 50, Train Loss Decreased!! (0.084534-->0.079534)
# Test Loss: 0.084826
#
# Temp Loss: 0.214168
#
# Epoch: 51, Train Loss Decreased!! (0.079534-->0.075432)
# Test Loss: 0.073867
#
# Temp Loss: 0.216951
#
# Epoch: 52, Train Loss Decreased!! (0.075432-->0.070458)
# Test Loss: 0.076277
#
# Temp Loss: 0.216661
#
# Epoch: 53, Train Loss Decreased!! (0.070458-->0.065604)
# Test Loss: 0.063541
#
# Temp Loss: 0.219098
#
# Epoch: 54, Train Loss Decreased!! (0.065604-->0.060101)
# Test Loss: 0.066335
#
# Temp Loss: 0.218286
#
# Epoch: 55, Train Loss Decreased!! (0.060101-->0.055581)
# Test Loss: 0.053744
#
# Temp Loss: 0.223094
#
# Epoch: 56, Train Loss Decreased!! (0.055581-->0.050316)
# Test Loss: 0.056781
#
# Temp Loss: 0.221959
#
# Epoch: 57, Train Loss Decreased!! (0.050316-->0.046001)
# Test Loss: 0.043821
#
# Temp Loss: 0.225443
#
# Epoch: 58, Train Loss Decreased!! (0.046001-->0.041237)
# Test Loss: 0.047294
#
# Temp Loss: 0.223930
#
# Epoch: 59, Train Loss Decreased!! (0.041237-->0.037485)
# Test Loss: 0.035384
#
# Temp Loss: 0.228421
#
# Epoch: 60, Train Loss Decreased!! (0.037485-->0.033332)
# Test Loss: 0.038853
#
# Temp Loss: 0.227211
#
# Epoch: 61, Train Loss Decreased!! (0.033332-->0.030298)
# Test Loss: 0.028261
#
# Temp Loss: 0.230893
#
# Epoch: 62, Train Loss Decreased!! (0.030298-->0.026560)
# Test Loss: 0.030939
#
# Temp Loss: 0.229302
#
# Epoch: 63, Train Loss Decreased!! (0.026560-->0.024213)
# Test Loss: 0.022282
#
# Temp Loss: 0.233400
#
# Epoch: 64, Train Loss Decreased!! (0.024213-->0.021282)
# Test Loss: 0.025183
#
# Temp Loss: 0.231988
#
# Epoch: 65, Train Loss Decreased!! (0.021282-->0.019598)
# Test Loss: 0.018121
#
# Temp Loss: 0.235758
#
# Epoch: 66, Train Loss Decreased!! (0.019598-->0.017264)
# Test Loss: 0.020385
#
# Temp Loss: 0.233647
#
# Epoch: 67, Train Loss Decreased!! (0.017264-->0.015667)
# Test Loss: 0.014449
#
# Temp Loss: 0.237436
#
# Epoch: 68, Train Loss Decreased!! (0.015667-->0.013994)
# Test Loss: 0.017007
#
# Temp Loss: 0.235247
#
# Epoch: 69, Train Loss Decreased!! (0.013994-->0.012865)
# Test Loss: 0.011466
#
# Temp Loss: 0.239235
#
# Epoch: 70, Train Loss Decreased!! (0.012865-->0.011085)
# Test Loss: 0.013508
#
# Temp Loss: 0.237187
#
# Epoch: 71, Train Loss Decreased!! (0.011085-->0.010087)
# Test Loss: 0.009192
#
# Temp Loss: 0.241065
#
# Epoch: 72, Train Loss Decreased!! (0.010087-->0.009097)
# Test Loss: 0.011618
#
# Temp Loss: 0.238158
#
# Epoch: 73, Train Loss Decreased!! (0.009097-->0.008122)
# Test Loss: 0.007203
#
# Temp Loss: 0.242475
#
# Epoch: 74, Train Loss Decreased!! (0.008122-->0.007193)
# Test Loss: 0.009422
#
# Temp Loss: 0.239396
#
# Epoch: 75, Train Loss Decreased!! (0.007193-->0.006687)
# Test Loss: 0.006232
#
# Temp Loss: 0.243933
#
# Epoch: 76, Train Loss Decreased!! (0.006687-->0.006084)
# Test Loss: 0.008141
#
# Temp Loss: 0.240636
#
# Epoch: 77, Train Loss Decreased!! (0.006084-->0.005701)
# Test Loss: 0.005278
#
# Temp Loss: 0.244537
#
# Epoch: 78, Train Loss Decreased!! (0.005701-->0.005164)
# Test Loss: 0.007092
#
# Temp Loss: 0.241351
#
# Epoch: 79, Train Loss Decreased!! (0.005164-->0.004937)
# Test Loss: 0.004635
#
# Temp Loss: 0.245220
#
# Epoch: 80, Train Loss Decreased!! (0.004937-->0.004574)
# Test Loss: 0.006266
#
# Temp Loss: 0.241460
#
# Epoch: 81, Train Loss Decreased!! (0.004574-->0.004452)
# Test Loss: 0.004067
#
# Temp Loss: 0.245299
#
# Epoch: 82, Train Loss Decreased!! (0.004452-->0.004165)
# Test Loss: 0.005874
#
# Temp Loss: 0.241744
#
# Epoch: 83, Train Loss Decreased!! (0.004165-->0.004061)
# Test Loss: 0.003823
#
# Temp Loss: 0.246211
#
# Epoch: 84, Train Loss Decreased!! (0.004061-->0.003943)
# Test Loss: 0.005520
#
# Temp Loss: 0.242087
#
# Epoch: 85, Train Loss Decreased!! (0.003943-->0.003724)
# Test Loss: 0.003405
#
# Temp Loss: 0.245853
#
# Epoch: 86, Train Loss Decreased!! (0.003724-->0.003626)
# Test Loss: 0.005227
#
# Temp Loss: 0.241906
#
# Epoch: 87, Train Loss Decreased!! (0.003626-->0.003586)
# Test Loss: 0.003296
#
# Temp Loss: 0.246473
#
# Epoch: 88, Train Loss Decreased!! (0.003586-->0.003405)
# Test Loss: 0.004723
#
# Temp Loss: 0.242890
#
# Epoch: 89, Train Loss Decreased!! (0.003405-->0.003218)
# Test Loss: 0.002944
#
# Temp Loss: 0.246435
#
# Epoch: 90, Train Loss Decreased!! (0.003218-->0.003177)
# Test Loss: 0.004662
#
# Temp Loss: 0.242272
#
# Epoch: 91, Train Loss Decreased!! (0.003177-->0.003038)
# Test Loss: 0.002840
#
# Temp Loss: 0.246572
#
# Epoch: 92, Train Loss Decreased!! (0.003038-->0.002988)
# Test Loss: 0.004298
#
# Temp Loss: 0.242565
#
# Epoch: 93, Train Loss Decreased!! (0.002988-->0.002852)
# Test Loss: 0.002555
#
# Temp Loss: 0.246673
#
# Epoch: 94, Train Loss Decreased!! (0.002852-->0.002814)
# Test Loss: 0.004144
#
# Temp Loss: 0.242420
#
# Epoch: 95, Train Loss Decreased!! (0.002814-->0.002735)
# Test Loss: 0.002430
#
# Temp Loss: 0.246665
#
# Test Loss: 0.004159
#
# Temp Loss: 0.242461
#
# Test Loss: 0.002446
#
# Temp Loss: 0.246909
#
# Epoch: 98, Train Loss Decreased!! (0.002735-->0.002623)
# Test Loss: 0.003800
#
# Temp Loss: 0.242620
#
# Epoch: 99, Train Loss Decreased!! (0.002623-->0.002511)
# Test Loss: 0.002242
#
# Temp Loss: 0.247185
#  60%|██████    | 3/5 [02:24<01:36, 48.23s/it]
# Epoch: 100, Train Loss Decreased!! (0.002511-->0.002422)
# Test Loss: 0.003561
#
# Temp Loss: 0.243040
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.210869)
# Test Loss: 0.185267
#
# Temp Loss: 0.185145
#
# Epoch: 2, Train Loss Decreased!! (0.210869-->0.183999)
# Test Loss: 0.184597
#
# Temp Loss: 0.184256
#
# Epoch: 3, Train Loss Decreased!! (0.183999-->0.183376)
# Test Loss: 0.182629
#
# Temp Loss: 0.182546
#
# Epoch: 4, Train Loss Decreased!! (0.183376-->0.182349)
# Test Loss: 0.182484
#
# Temp Loss: 0.182594
#
# Epoch: 5, Train Loss Decreased!! (0.182349-->0.181818)
# Test Loss: 0.181653
#
# Temp Loss: 0.182174
#
# Epoch: 6, Train Loss Decreased!! (0.181818-->0.181424)
# Test Loss: 0.181656
#
# Temp Loss: 0.181865
#
# Epoch: 7, Train Loss Decreased!! (0.181424-->0.181101)
# Test Loss: 0.180636
#
# Temp Loss: 0.181928
#
# Epoch: 8, Train Loss Decreased!! (0.181101-->0.180342)
# Test Loss: 0.180745
#
# Temp Loss: 0.181844
#
# Epoch: 9, Train Loss Decreased!! (0.180342-->0.179154)
# Test Loss: 0.177513
#
# Temp Loss: 0.185444
#
# Epoch: 10, Train Loss Decreased!! (0.179154-->0.177154)
# Test Loss: 0.177498
#
# Temp Loss: 0.185055
#
# Epoch: 11, Train Loss Decreased!! (0.177154-->0.175260)
# Test Loss: 0.173469
#
# Temp Loss: 0.188980
#
# Epoch: 12, Train Loss Decreased!! (0.175260-->0.173066)
# Test Loss: 0.173551
#
# Temp Loss: 0.187985
#
# Epoch: 13, Train Loss Decreased!! (0.173066-->0.171235)
# Test Loss: 0.168839
#
# Temp Loss: 0.192184
#
# Epoch: 14, Train Loss Decreased!! (0.171235-->0.168572)
# Test Loss: 0.168590
#
# Temp Loss: 0.191207
#
# Epoch: 15, Train Loss Decreased!! (0.168572-->0.166728)
# Test Loss: 0.164432
#
# Temp Loss: 0.195646
#
# Epoch: 16, Train Loss Decreased!! (0.166728-->0.164346)
# Test Loss: 0.164347
#
# Temp Loss: 0.194698
#
# Epoch: 17, Train Loss Decreased!! (0.164346-->0.163100)
# Test Loss: 0.160756
#
# Temp Loss: 0.196771
#
# Epoch: 18, Train Loss Decreased!! (0.163100-->0.161039)
# Test Loss: 0.160843
#
# Temp Loss: 0.195914
#
# Epoch: 19, Train Loss Decreased!! (0.161039-->0.160050)
# Test Loss: 0.158249
#
# Temp Loss: 0.198673
#
# Epoch: 20, Train Loss Decreased!! (0.160050-->0.158662)
# Test Loss: 0.158263
#
# Temp Loss: 0.197710
#
# Epoch: 21, Train Loss Decreased!! (0.158662-->0.157304)
# Test Loss: 0.155825
#
# Temp Loss: 0.200422
#
# Epoch: 22, Train Loss Decreased!! (0.157304-->0.155537)
# Test Loss: 0.155919
#
# Temp Loss: 0.199292
#
# Epoch: 23, Train Loss Decreased!! (0.155537-->0.154723)
# Test Loss: 0.153009
#
# Temp Loss: 0.200268
#
# Epoch: 24, Train Loss Decreased!! (0.154723-->0.152776)
# Test Loss: 0.153287
#
# Temp Loss: 0.199284
#
# Epoch: 25, Train Loss Decreased!! (0.152776-->0.151866)
# Test Loss: 0.150025
#
# Temp Loss: 0.203061
#
# Epoch: 26, Train Loss Decreased!! (0.151866-->0.150019)
# Test Loss: 0.150287
#
# Temp Loss: 0.201726
#
# Epoch: 27, Train Loss Decreased!! (0.150019-->0.148916)
# Test Loss: 0.146885
#
# Temp Loss: 0.202779
#
# Epoch: 28, Train Loss Decreased!! (0.148916-->0.146674)
# Test Loss: 0.147112
#
# Temp Loss: 0.201533
#
# Epoch: 29, Train Loss Decreased!! (0.146674-->0.145510)
# Test Loss: 0.143389
#
# Temp Loss: 0.202320
#
# Epoch: 30, Train Loss Decreased!! (0.145510-->0.143234)
# Test Loss: 0.143642
#
# Temp Loss: 0.201324
#
# Epoch: 31, Train Loss Decreased!! (0.143234-->0.141835)
# Test Loss: 0.139688
#
# Temp Loss: 0.204459
#
# Epoch: 32, Train Loss Decreased!! (0.141835-->0.139525)
# Test Loss: 0.140274
#
# Temp Loss: 0.203543
#
# Epoch: 33, Train Loss Decreased!! (0.139525-->0.138275)
# Test Loss: 0.136264
#
# Temp Loss: 0.203647
#
# Epoch: 34, Train Loss Decreased!! (0.138275-->0.135972)
# Test Loss: 0.136906
#
# Temp Loss: 0.202719
#
# Epoch: 35, Train Loss Decreased!! (0.135972-->0.134489)
# Test Loss: 0.132232
#
# Temp Loss: 0.204804
#
# Epoch: 36, Train Loss Decreased!! (0.134489-->0.132002)
# Test Loss: 0.132873
#
# Temp Loss: 0.204091
#
# Epoch: 37, Train Loss Decreased!! (0.132002-->0.130447)
# Test Loss: 0.127989
#
# Temp Loss: 0.205422
#
# Epoch: 38, Train Loss Decreased!! (0.130447-->0.127500)
# Test Loss: 0.128331
#
# Temp Loss: 0.204828
#
# Epoch: 39, Train Loss Decreased!! (0.127500-->0.125820)
# Test Loss: 0.123290
#
# Temp Loss: 0.205455
#
# Epoch: 40, Train Loss Decreased!! (0.125820-->0.122758)
# Test Loss: 0.123716
#
# Temp Loss: 0.204736
#
# Epoch: 41, Train Loss Decreased!! (0.122758-->0.120338)
# Test Loss: 0.117148
#
# Temp Loss: 0.205624
#
# Epoch: 42, Train Loss Decreased!! (0.120338-->0.116854)
# Test Loss: 0.117636
#
# Temp Loss: 0.204894
#
# Epoch: 43, Train Loss Decreased!! (0.116854-->0.114302)
# Test Loss: 0.110312
#
# Temp Loss: 0.207039
#
# Epoch: 44, Train Loss Decreased!! (0.114302-->0.110203)
# Test Loss: 0.110871
#
# Temp Loss: 0.206834
#
# Epoch: 45, Train Loss Decreased!! (0.110203-->0.106737)
# Test Loss: 0.101773
#
# Temp Loss: 0.208814
#
# Epoch: 46, Train Loss Decreased!! (0.106737-->0.102258)
# Test Loss: 0.102857
#
# Temp Loss: 0.208189
#
# Epoch: 47, Train Loss Decreased!! (0.102258-->0.098977)
# Test Loss: 0.094247
#
# Temp Loss: 0.209900
#
# Epoch: 48, Train Loss Decreased!! (0.098977-->0.094296)
# Test Loss: 0.094466
#
# Temp Loss: 0.209238
#
# Epoch: 49, Train Loss Decreased!! (0.094296-->0.090264)
# Test Loss: 0.084207
#
# Temp Loss: 0.213008
#
# Epoch: 50, Train Loss Decreased!! (0.090264-->0.085062)
# Test Loss: 0.085210
#
# Temp Loss: 0.212397
#
# Epoch: 51, Train Loss Decreased!! (0.085062-->0.081244)
# Test Loss: 0.075435
#
# Temp Loss: 0.215919
#
# Epoch: 52, Train Loss Decreased!! (0.081244-->0.076211)
# Test Loss: 0.076531
#
# Temp Loss: 0.215455
#
# Epoch: 53, Train Loss Decreased!! (0.076211-->0.072445)
# Test Loss: 0.066335
#
# Temp Loss: 0.220598
#
# Epoch: 54, Train Loss Decreased!! (0.072445-->0.067180)
# Test Loss: 0.067116
#
# Temp Loss: 0.219556
#
# Epoch: 55, Train Loss Decreased!! (0.067180-->0.063201)
# Test Loss: 0.057049
#
# Temp Loss: 0.223031
#
# Epoch: 56, Train Loss Decreased!! (0.063201-->0.058144)
# Test Loss: 0.058604
#
# Temp Loss: 0.221495
#
# Epoch: 57, Train Loss Decreased!! (0.058144-->0.054675)
# Test Loss: 0.048070
#
# Temp Loss: 0.226220
#
# Epoch: 58, Train Loss Decreased!! (0.054675-->0.049359)
# Test Loss: 0.049510
#
# Temp Loss: 0.224613
#
# Epoch: 59, Train Loss Decreased!! (0.049359-->0.045963)
# Test Loss: 0.039939
#
# Temp Loss: 0.230477
#
# Epoch: 60, Train Loss Decreased!! (0.045963-->0.041417)
# Test Loss: 0.041140
#
# Temp Loss: 0.228657
#
# Epoch: 61, Train Loss Decreased!! (0.041417-->0.038364)
# Test Loss: 0.032779
#
# Temp Loss: 0.233524
#
# Epoch: 62, Train Loss Decreased!! (0.038364-->0.034433)
# Test Loss: 0.034228
#
# Temp Loss: 0.231505
#
# Epoch: 63, Train Loss Decreased!! (0.034433-->0.031606)
# Test Loss: 0.026838
#
# Temp Loss: 0.236685
#
# Epoch: 64, Train Loss Decreased!! (0.031606-->0.028281)
# Test Loss: 0.028154
#
# Temp Loss: 0.234199
#
# Epoch: 65, Train Loss Decreased!! (0.028281-->0.025570)
# Test Loss: 0.021458
#
# Temp Loss: 0.238531
#
# Epoch: 66, Train Loss Decreased!! (0.025570-->0.022680)
# Test Loss: 0.023176
#
# Temp Loss: 0.236111
#
# Epoch: 67, Train Loss Decreased!! (0.022680-->0.020599)
# Test Loss: 0.017323
#
# Temp Loss: 0.241011
#
# Epoch: 68, Train Loss Decreased!! (0.020599-->0.018401)
# Test Loss: 0.019180
#
# Temp Loss: 0.238113
#
# Epoch: 69, Train Loss Decreased!! (0.018401-->0.016465)
# Test Loss: 0.013377
#
# Temp Loss: 0.242415
#
# Epoch: 70, Train Loss Decreased!! (0.016465-->0.014498)
# Test Loss: 0.015350
#
# Temp Loss: 0.239503
#
# Epoch: 71, Train Loss Decreased!! (0.014498-->0.013039)
# Test Loss: 0.010751
#
# Temp Loss: 0.243970
#
# Epoch: 72, Train Loss Decreased!! (0.013039-->0.011368)
# Test Loss: 0.012325
#
# Temp Loss: 0.240994
#
# Epoch: 73, Train Loss Decreased!! (0.011368-->0.010319)
# Test Loss: 0.008708
#
# Temp Loss: 0.245566
#
# Epoch: 74, Train Loss Decreased!! (0.010319-->0.009368)
# Test Loss: 0.010575
#
# Temp Loss: 0.242549
#
# Epoch: 75, Train Loss Decreased!! (0.009368-->0.008561)
# Test Loss: 0.007197
#
# Temp Loss: 0.247449
#
# Epoch: 76, Train Loss Decreased!! (0.008561-->0.008027)
# Test Loss: 0.009042
#
# Temp Loss: 0.244433
#
# Epoch: 77, Train Loss Decreased!! (0.008027-->0.007144)
# Test Loss: 0.005918
#
# Temp Loss: 0.247670
#
# Epoch: 78, Train Loss Decreased!! (0.007144-->0.006575)
# Test Loss: 0.007586
#
# Temp Loss: 0.244425
#
# Epoch: 79, Train Loss Decreased!! (0.006575-->0.005973)
# Test Loss: 0.005009
#
# Temp Loss: 0.248183
#
# Epoch: 80, Train Loss Decreased!! (0.005973-->0.005492)
# Test Loss: 0.006572
#
# Temp Loss: 0.244721
#
# Epoch: 81, Train Loss Decreased!! (0.005492-->0.005102)
# Test Loss: 0.004351
#
# Temp Loss: 0.249088
#
# Epoch: 82, Train Loss Decreased!! (0.005102-->0.004706)
# Test Loss: 0.005531
#
# Temp Loss: 0.245856
#
# Epoch: 83, Train Loss Decreased!! (0.004706-->0.004515)
# Test Loss: 0.004002
#
# Temp Loss: 0.249331
#
# Epoch: 84, Train Loss Decreased!! (0.004515-->0.004315)
# Test Loss: 0.005196
#
# Temp Loss: 0.245862
#
# Epoch: 85, Train Loss Decreased!! (0.004315-->0.004017)
# Test Loss: 0.003500
#
# Temp Loss: 0.249472
#
# Epoch: 86, Train Loss Decreased!! (0.004017-->0.003985)
# Test Loss: 0.004896
#
# Temp Loss: 0.245777
#
# Epoch: 87, Train Loss Decreased!! (0.003985-->0.003655)
# Test Loss: 0.003042
#
# Temp Loss: 0.250186
#
# Epoch: 88, Train Loss Decreased!! (0.003655-->0.003477)
# Test Loss: 0.004327
#
# Temp Loss: 0.246525
#
# Epoch: 89, Train Loss Decreased!! (0.003477-->0.003292)
# Test Loss: 0.002922
#
# Temp Loss: 0.250194
#
# Epoch: 90, Train Loss Decreased!! (0.003292-->0.003273)
# Test Loss: 0.004132
#
# Temp Loss: 0.246508
#
# Epoch: 91, Train Loss Decreased!! (0.003273-->0.003113)
# Test Loss: 0.002738
#
# Temp Loss: 0.250812
#
# Epoch: 92, Train Loss Decreased!! (0.003113-->0.002963)
# Test Loss: 0.003692
#
# Temp Loss: 0.246978
#
# Epoch: 93, Train Loss Decreased!! (0.002963-->0.002860)
# Test Loss: 0.002604
#
# Temp Loss: 0.250865
#
# Epoch: 94, Train Loss Decreased!! (0.002860-->0.002794)
# Test Loss: 0.003585
#
# Temp Loss: 0.246936
#
# Epoch: 95, Train Loss Decreased!! (0.002794-->0.002717)
# Test Loss: 0.002354
#
# Temp Loss: 0.250652
#
# Epoch: 96, Train Loss Decreased!! (0.002717-->0.002661)
# Test Loss: 0.003543
#
# Temp Loss: 0.246640
#
# Epoch: 97, Train Loss Decreased!! (0.002661-->0.002536)
# Test Loss: 0.002222
#
# Temp Loss: 0.251152
#
# Epoch: 98, Train Loss Decreased!! (0.002536-->0.002469)
# Test Loss: 0.003184
#
# Temp Loss: 0.247214
#
# Epoch: 99, Train Loss Decreased!! (0.002469-->0.002354)
# Test Loss: 0.002049
#
# Temp Loss: 0.250901
#  80%|████████  | 4/5 [03:13<00:48, 48.34s/it]
# Test Loss: 0.003364
#
# Temp Loss: 0.246672
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.208353)
# Test Loss: 0.185513
#
# Temp Loss: 0.186486
#
# Epoch: 2, Train Loss Decreased!! (0.208353-->0.185154)
# Test Loss: 0.184775
#
# Temp Loss: 0.185625
#
# Epoch: 3, Train Loss Decreased!! (0.185154-->0.184096)
# Test Loss: 0.182000
#
# Temp Loss: 0.183037
#
# Epoch: 4, Train Loss Decreased!! (0.184096-->0.182652)
# Test Loss: 0.182069
#
# Temp Loss: 0.183102
#
# Epoch: 5, Train Loss Decreased!! (0.182652-->0.182350)
# Test Loss: 0.181575
#
# Temp Loss: 0.182728
#
# Epoch: 6, Train Loss Decreased!! (0.182350-->0.182062)
# Test Loss: 0.181682
#
# Temp Loss: 0.182813
#
# Epoch: 7, Train Loss Decreased!! (0.182062-->0.181930)
# Test Loss: 0.180866
#
# Temp Loss: 0.182700
#
# Epoch: 8, Train Loss Decreased!! (0.181930-->0.181463)
# Test Loss: 0.181115
#
# Temp Loss: 0.182577
#
# Epoch: 9, Train Loss Decreased!! (0.181463-->0.180898)
# Test Loss: 0.179304
#
# Temp Loss: 0.182285
#
# Epoch: 10, Train Loss Decreased!! (0.180898-->0.179754)
# Test Loss: 0.179365
#
# Temp Loss: 0.182273
#
# Epoch: 11, Train Loss Decreased!! (0.179754-->0.177919)
# Test Loss: 0.174934
#
# Temp Loss: 0.185808
#
# Epoch: 12, Train Loss Decreased!! (0.177919-->0.175236)
# Test Loss: 0.174864
#
# Temp Loss: 0.185210
#
# Epoch: 13, Train Loss Decreased!! (0.175236-->0.173510)
# Test Loss: 0.170489
#
# Temp Loss: 0.188441
#
# Epoch: 14, Train Loss Decreased!! (0.173510-->0.170927)
# Test Loss: 0.170559
#
# Temp Loss: 0.187853
#
# Epoch: 15, Train Loss Decreased!! (0.170927-->0.169561)
# Test Loss: 0.167296
#
# Temp Loss: 0.192678
#
# Epoch: 16, Train Loss Decreased!! (0.169561-->0.167280)
# Test Loss: 0.167308
#
# Temp Loss: 0.191986
#
# Epoch: 17, Train Loss Decreased!! (0.167280-->0.166128)
# Test Loss: 0.164434
#
# Temp Loss: 0.195931
#
# Epoch: 18, Train Loss Decreased!! (0.166128-->0.164424)
# Test Loss: 0.164572
#
# Temp Loss: 0.194636
#
# Epoch: 19, Train Loss Decreased!! (0.164424-->0.163495)
# Test Loss: 0.161888
#
# Temp Loss: 0.197604
#
# Epoch: 20, Train Loss Decreased!! (0.163495-->0.161638)
# Test Loss: 0.161930
#
# Temp Loss: 0.196714
#
# Epoch: 21, Train Loss Decreased!! (0.161638-->0.160650)
# Test Loss: 0.159191
#
# Temp Loss: 0.198491
#
# Epoch: 22, Train Loss Decreased!! (0.160650-->0.158837)
# Test Loss: 0.159839
#
# Temp Loss: 0.198057
#
# Epoch: 23, Train Loss Decreased!! (0.158837-->0.157766)
# Test Loss: 0.156171
#
# Temp Loss: 0.199126
#
# Epoch: 24, Train Loss Decreased!! (0.157766-->0.155814)
# Test Loss: 0.156731
#
# Temp Loss: 0.198376
#
# Epoch: 25, Train Loss Decreased!! (0.155814-->0.154796)
# Test Loss: 0.153562
#
# Temp Loss: 0.199493
#
# Epoch: 26, Train Loss Decreased!! (0.154796-->0.152795)
# Test Loss: 0.154001
#
# Temp Loss: 0.199131
#
# Epoch: 27, Train Loss Decreased!! (0.152795-->0.151874)
# Test Loss: 0.150680
#
# Temp Loss: 0.199941
#
# Epoch: 28, Train Loss Decreased!! (0.151874-->0.149809)
# Test Loss: 0.151197
#
# Temp Loss: 0.199532
#
# Epoch: 29, Train Loss Decreased!! (0.149809-->0.148603)
# Test Loss: 0.147102
#
# Temp Loss: 0.200414
#
# Epoch: 30, Train Loss Decreased!! (0.148603-->0.146060)
# Test Loss: 0.147454
#
# Temp Loss: 0.199921
#
# Epoch: 31, Train Loss Decreased!! (0.146060-->0.144451)
# Test Loss: 0.142792
#
# Temp Loss: 0.203116
#
# Epoch: 32, Train Loss Decreased!! (0.144451-->0.141768)
# Test Loss: 0.143487
#
# Temp Loss: 0.202505
#
# Epoch: 33, Train Loss Decreased!! (0.141768-->0.139968)
# Test Loss: 0.137943
#
# Temp Loss: 0.205075
#
# Epoch: 34, Train Loss Decreased!! (0.139968-->0.136746)
# Test Loss: 0.138107
#
# Temp Loss: 0.203984
#
# Epoch: 35, Train Loss Decreased!! (0.136746-->0.134382)
# Test Loss: 0.132166
#
# Temp Loss: 0.207846
#
# Epoch: 36, Train Loss Decreased!! (0.134382-->0.131043)
# Test Loss: 0.132739
#
# Temp Loss: 0.207595
#
# Epoch: 37, Train Loss Decreased!! (0.131043-->0.128568)
# Test Loss: 0.126238
#
# Temp Loss: 0.208910
#
# Epoch: 38, Train Loss Decreased!! (0.128568-->0.124838)
# Test Loss: 0.126978
#
# Temp Loss: 0.209175
#
# Epoch: 39, Train Loss Decreased!! (0.124838-->0.121959)
# Test Loss: 0.119390
#
# Temp Loss: 0.209570
#
# Epoch: 40, Train Loss Decreased!! (0.121959-->0.118002)
# Test Loss: 0.120442
#
# Temp Loss: 0.210570
#
# Epoch: 41, Train Loss Decreased!! (0.118002-->0.115142)
# Test Loss: 0.112694
#
# Temp Loss: 0.213332
#
# Epoch: 42, Train Loss Decreased!! (0.115142-->0.110572)
# Test Loss: 0.113297
#
# Temp Loss: 0.214414
#
# Epoch: 43, Train Loss Decreased!! (0.110572-->0.107261)
# Test Loss: 0.104211
#
# Temp Loss: 0.216041
#
# Epoch: 44, Train Loss Decreased!! (0.107261-->0.103044)
# Test Loss: 0.106120
#
# Temp Loss: 0.217454
#
# Epoch: 45, Train Loss Decreased!! (0.103044-->0.099414)
# Test Loss: 0.096533
#
# Temp Loss: 0.217572
#
# Epoch: 46, Train Loss Decreased!! (0.099414-->0.094407)
# Test Loss: 0.097306
#
# Temp Loss: 0.218779
#
# Epoch: 47, Train Loss Decreased!! (0.094407-->0.090605)
# Test Loss: 0.086574
#
# Temp Loss: 0.218662
#
# Epoch: 48, Train Loss Decreased!! (0.090605-->0.085221)
# Test Loss: 0.088128
#
# Temp Loss: 0.219699
#
# Epoch: 49, Train Loss Decreased!! (0.085221-->0.081342)
# Test Loss: 0.077180
#
# Temp Loss: 0.219982
#
# Epoch: 50, Train Loss Decreased!! (0.081342-->0.075933)
# Test Loss: 0.078535
#
# Temp Loss: 0.220600
#
# Epoch: 51, Train Loss Decreased!! (0.075933-->0.071736)
# Test Loss: 0.067886
#
# Temp Loss: 0.223916
#
# Epoch: 52, Train Loss Decreased!! (0.071736-->0.066909)
# Test Loss: 0.069336
#
# Temp Loss: 0.224129
#
# Epoch: 53, Train Loss Decreased!! (0.066909-->0.062697)
# Test Loss: 0.059369
#
# Temp Loss: 0.228572
#
# Epoch: 54, Train Loss Decreased!! (0.062697-->0.058098)
# Test Loss: 0.060698
#
# Temp Loss: 0.227806
#
# Epoch: 55, Train Loss Decreased!! (0.058098-->0.054546)
# Test Loss: 0.051467
#
# Temp Loss: 0.229145
#
# Epoch: 56, Train Loss Decreased!! (0.054546-->0.050185)
# Test Loss: 0.053126
#
# Temp Loss: 0.228489
#
# Epoch: 57, Train Loss Decreased!! (0.050185-->0.046897)
# Test Loss: 0.044300
#
# Temp Loss: 0.231944
#
# Epoch: 58, Train Loss Decreased!! (0.046897-->0.043277)
# Test Loss: 0.046373
#
# Temp Loss: 0.230911
#
# Epoch: 59, Train Loss Decreased!! (0.043277-->0.040125)
# Test Loss: 0.037241
#
# Temp Loss: 0.234658
#
# Epoch: 60, Train Loss Decreased!! (0.040125-->0.036271)
# Test Loss: 0.039159
#
# Temp Loss: 0.233594
#
# Epoch: 61, Train Loss Decreased!! (0.036271-->0.033336)
# Test Loss: 0.030787
#
# Temp Loss: 0.237626
#
# Epoch: 62, Train Loss Decreased!! (0.033336-->0.030065)
# Test Loss: 0.032870
#
# Temp Loss: 0.236145
#
# Epoch: 63, Train Loss Decreased!! (0.030065-->0.027468)
# Test Loss: 0.025734
#
# Temp Loss: 0.240219
#
# Epoch: 64, Train Loss Decreased!! (0.027468-->0.025060)
# Test Loss: 0.027557
#
# Temp Loss: 0.237996
#
# Epoch: 65, Train Loss Decreased!! (0.025060-->0.022757)
# Test Loss: 0.021347
#
# Temp Loss: 0.242616
#
# Epoch: 66, Train Loss Decreased!! (0.022757-->0.020879)
# Test Loss: 0.023522
#
# Temp Loss: 0.240855
#
# Epoch: 67, Train Loss Decreased!! (0.020879-->0.018860)
# Test Loss: 0.017448
#
# Temp Loss: 0.245060
#
# Epoch: 68, Train Loss Decreased!! (0.018860-->0.017218)
# Test Loss: 0.019601
#
# Temp Loss: 0.243225
#
# Epoch: 69, Train Loss Decreased!! (0.017218-->0.015764)
# Test Loss: 0.014560
#
# Temp Loss: 0.246905
#
# Epoch: 70, Train Loss Decreased!! (0.015764-->0.014315)
# Test Loss: 0.016264
#
# Temp Loss: 0.244887
#
# Epoch: 71, Train Loss Decreased!! (0.014315-->0.013142)
# Test Loss: 0.012110
#
# Temp Loss: 0.247991
#
# Epoch: 72, Train Loss Decreased!! (0.013142-->0.011985)
# Test Loss: 0.013707
#
# Temp Loss: 0.246177
#
# Epoch: 73, Train Loss Decreased!! (0.011985-->0.011027)
# Test Loss: 0.010296
#
# Temp Loss: 0.249517
#
# Epoch: 74, Train Loss Decreased!! (0.011027-->0.010062)
# Test Loss: 0.011716
#
# Temp Loss: 0.247515
#
# Epoch: 75, Train Loss Decreased!! (0.010062-->0.009344)
# Test Loss: 0.008848
#
# Temp Loss: 0.249575
#
# Epoch: 76, Train Loss Decreased!! (0.009344-->0.008753)
# Test Loss: 0.010543
#
# Temp Loss: 0.247742
#
# Epoch: 77, Train Loss Decreased!! (0.008753-->0.008154)
# Test Loss: 0.007622
#
# Temp Loss: 0.250909
#
# Epoch: 78, Train Loss Decreased!! (0.008154-->0.007733)
# Test Loss: 0.009250
#
# Temp Loss: 0.248891
#
# Epoch: 79, Train Loss Decreased!! (0.007733-->0.007073)
# Test Loss: 0.006723
#
# Temp Loss: 0.250956
#
# Epoch: 80, Train Loss Decreased!! (0.007073-->0.006726)
# Test Loss: 0.008326
#
# Temp Loss: 0.248651
#
# Epoch: 81, Train Loss Decreased!! (0.006726-->0.006345)
# Test Loss: 0.005986
#
# Temp Loss: 0.251306
#
# Epoch: 82, Train Loss Decreased!! (0.006345-->0.005975)
# Test Loss: 0.007408
#
# Temp Loss: 0.249532
#
# Epoch: 83, Train Loss Decreased!! (0.005975-->0.005571)
# Test Loss: 0.005144
#
# Temp Loss: 0.252317
#
# Epoch: 84, Train Loss Decreased!! (0.005571-->0.005243)
# Test Loss: 0.006602
#
# Temp Loss: 0.249930
#
# Epoch: 85, Train Loss Decreased!! (0.005243-->0.004989)
# Test Loss: 0.004651
#
# Temp Loss: 0.252501
#
# Epoch: 86, Train Loss Decreased!! (0.004989-->0.004649)
# Test Loss: 0.005894
#
# Temp Loss: 0.250153
#
# Epoch: 87, Train Loss Decreased!! (0.004649-->0.004459)
# Test Loss: 0.004200
#
# Temp Loss: 0.252305
#
# Epoch: 88, Train Loss Decreased!! (0.004459-->0.004245)
# Test Loss: 0.005417
#
# Temp Loss: 0.249885
#
# Epoch: 89, Train Loss Decreased!! (0.004245-->0.003998)
# Test Loss: 0.003828
#
# Temp Loss: 0.253018
#
# Epoch: 90, Train Loss Decreased!! (0.003998-->0.003814)
# Test Loss: 0.005055
#
# Temp Loss: 0.250538
#
# Epoch: 91, Train Loss Decreased!! (0.003814-->0.003756)
# Test Loss: 0.003565
#
# Temp Loss: 0.253025
#
# Epoch: 92, Train Loss Decreased!! (0.003756-->0.003728)
# Test Loss: 0.005119
#
# Temp Loss: 0.250441
#
# Epoch: 93, Train Loss Decreased!! (0.003728-->0.003558)
# Test Loss: 0.003357
#
# Temp Loss: 0.253539
#
# Epoch: 94, Train Loss Decreased!! (0.003558-->0.003327)
# Test Loss: 0.004466
#
# Temp Loss: 0.251109
#
# Epoch: 95, Train Loss Decreased!! (0.003327-->0.003175)
# Test Loss: 0.002955
#
# Temp Loss: 0.253441
#
# Test Loss: 0.004612
#
# Temp Loss: 0.250388
#
# Epoch: 97, Train Loss Decreased!! (0.003175-->0.003147)
# Test Loss: 0.002922
#
# Temp Loss: 0.253327
#
# Epoch: 98, Train Loss Decreased!! (0.003147-->0.002922)
# Test Loss: 0.004152
#
# Temp Loss: 0.250627
#
# Epoch: 99, Train Loss Decreased!! (0.002922-->0.002906)
# Test Loss: 0.002726
#
# Temp Loss: 0.253844
# 100%|██████████| 5/5 [04:01<00:00, 48.29s/it]
# Epoch: 100, Train Loss Decreased!! (0.002906-->0.002831)
# Test Loss: 0.003924
#
# Temp Loss: 0.250849
#
# ----------------------------------------------------

# %%
train_losses_mat = np.zeros((nRuns,n_epochs+1))
test_losses_mat = np.zeros((nRuns,n_epochs+1))
temp_losses_mat = np.zeros((nRuns,n_epochs+1))

train_expected_losses_mat = np.zeros((nRuns,n_epochs+1))

test_expected_losses_mat = np.zeros((nRuns,n_epochs+1))
test_surprise_losses_mat = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    train_losses_mat[cntr] = train_losses[cntr]
    test_losses_mat[cntr] = test_losses[cntr]
    temp_losses_mat[cntr] = temp_losses[cntr]
    
    train_expected_losses_mat[cntr] = train_expected_rec_losses[cntr]
    
    test_expected_losses_mat[cntr] = test_expected_rec_losses[cntr]
    test_surprise_losses_mat[cntr] = test_surprise_rec_losses[cntr]

# %%
train_losses_mean = np.mean(train_losses_mat,axis=0)
test_losses_mean = np.mean(test_losses_mat,axis=0)
temp_losses_mean = np.mean(temp_losses_mat,axis=0)

train_expected_losses_mean = np.mean(train_expected_losses_mat,axis=0)

test_expected_losses_mean = np.mean(test_expected_losses_mat,axis=0)
test_surprise_losses_mean = np.mean(test_surprise_losses_mat,axis=0)

# %%
train_losses_std = np.std(train_losses_mat,axis=0)
test_losses_std = np.std(test_losses_mat,axis=0)
temp_losses_std = np.std(test_losses_mat,axis=0)

train_expected_losses_std = np.std(train_expected_losses_mat,axis=0)

test_expected_losses_std = np.std(test_expected_losses_mat,axis=0)
test_surprise_losses_std = np.std(test_surprise_losses_mat,axis=0)

# %%
train_expected_losses_mean[0] = train_losses_mean[0]

# %%
f = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.errorbar(np.arange(n_epochs+1),train_losses_mean,yerr=train_losses_std)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,2)
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.subplot(2,2,3)
plt.errorbar(np.arange(n_epochs+1),test_losses_mean,yerr=test_losses_std)
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,4)
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
# kk=4
# a = np.unique(allStatesTest[kk][:,0])
# b = np.unique(allStatesTrain[kk][:,0])
# len(np.intersect1d(a,b))

# %% [markdown]
# ### Representational Analyses

# %% [markdown]
# #### RNN Names

# %%
rnn_names = ['L4','L23','L56','H4','H23','H56']

# %%
# analyses_train_loader = {}

# %%
# for cntr in range(nRuns):
#     analyses_train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
#                                            batch_size,shuffle=False)

# %% [markdown]
# #### Pass data and store activations

# %%
def pass_data_store_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        activations_hidden_L23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_L4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_L56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_hidden_H23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_H4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_H56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_out_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
        for e in tqdm(range(n_epochs+1)):

            cnt = 0

            ## Load model
            model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr],task='lattice')
            model[cntr].to(device)
            model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
            model[cntr].eval()

            ## Pass clean samples
            for data, f_target, lastEvent, surpriseBinary in loader[cntr]:

                if train_on_gpu:
                    data, f_targetC = data.float().cuda(), f_target.float().cuda()
                else: data, f_targetC = data.float(), f_target.float()

                target = f_target

                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                ## Collect activations  
                act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                for i in range(batch_size):
                    if i < len(data):
                        label = target.data[i]

                        activations_hidden_L23_np[cntr][e,cnt] = act_hidden_L23[i]
                        activations_hidden_L4_np[cntr][e,cnt] = act_hidden_L4[i]
                        activations_hidden_L56_np[cntr][e,cnt] = act_hidden_L56[i]

                        activations_hidden_H23_np[cntr][e,cnt] = act_hidden_H23[i]
                        activations_hidden_H4_np[cntr][e,cnt] = act_hidden_H4[i]
                        activations_hidden_H56_np[cntr][e,cnt] = act_hidden_H56[i]

                        activations_out_np[cntr][e,cnt] = output_pred[i]

                        cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# (L23_train,L4_train,L56_train,
#  H23_train,H4_train,H56_train,), out_train = pass_data_store_activations(analyses_train_loader, nTrain)

# %%
(L23_test,L4_test,L56_test,
 H23_test,H4_test,H56_test), out_test = pass_data_store_activations(test_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:07<00:00, 12.89it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.61it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.73it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.69it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.53it/s]

# %%
(L23_temp,L4_temp,L56_temp,
 H23_temp,H4_temp,H56_temp), out_temp = pass_data_store_activations(test_temp_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:07<00:00, 12.90it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.72it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.72it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.77it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.74it/s]

# %% [markdown]
# #### PCA for RNNs

# %%
def repsPCA(rnnActs):
    nEpochs, nSeqs, nRolls, nNeurons = rnnActs.shape
    pca_dict = {}
    nSamps = nSeqs*nRolls
    dimPCA = min(nNeurons,nSamps)
    repsR_transformed = np.zeros((nEpochs,nSamps,dimPCA))
    
    for ep in tqdm(range(nEpochs)):
        
        reps = rnnActs[ep]
        
        ## reshape
        repsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        for ii in range(nSeqs):
            for jj in range(nRolls):
                repsR[cnt] = reps[ii,jj]
                cnt += 1
        ## PCA
        rnnPCA = PCA()
        repsR_transformed[ep] = rnnPCA.fit_transform(repsR)
        pca_dict[str(ep)] = rnnPCA
        
    return repsR_transformed, pca_dict

# %%
L23pca_train = {}
L4pca_train = {}
L56pca_train = {}

H23pca_train = {}
H4pca_train = {}
H56pca_train = {}

L23pca_test = {}
L4pca_test = {}
L56pca_test = {}

H23pca_test = {}
H4pca_test = {}
H56pca_test = {}

L23pca_temp = {}
L4pca_temp = {}
L56pca_temp = {}

H23pca_temp = {}
H4pca_temp = {}
H56pca_temp = {}

# %%
# for cntr in range(nRuns):
#     L23pca_train[cntr], _ = repsPCA(L23_train[cntr])
#     L4pca_train[cntr], _ = repsPCA(L4_train[cntr])
#     L56pca_train[cntr], _ = repsPCA(L56_train[cntr])

#     H23pca_train[cntr], _ = repsPCA(H23_train[cntr])
#     H4pca_train[cntr], _ = repsPCA(H4_train[cntr])
#     H56pca_train[cntr], _ = repsPCA(H56_train[cntr])

# %%
for cntr in range(nRuns):
    L23pca_test[cntr], _ = repsPCA(L23_test[cntr])
    L4pca_test[cntr], _ = repsPCA(L4_test[cntr])
    L56pca_test[cntr], _ = repsPCA(L56_test[cntr])

    H23pca_test[cntr], _ = repsPCA(H23_test[cntr])
    H4pca_test[cntr], _ = repsPCA(H4_test[cntr])
    H56pca_test[cntr], _ = repsPCA(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 127.06it/s]
# 100%|██████████| 101/101 [00:00<00:00, 403.44it/s]
# 100%|██████████| 101/101 [00:00<00:00, 190.72it/s]
# 100%|██████████| 101/101 [00:00<00:00, 158.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 408.29it/s]
# 100%|██████████| 101/101 [00:00<00:00, 195.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 156.52it/s]
# 100%|██████████| 101/101 [00:00<00:00, 389.44it/s]
# 100%|██████████| 101/101 [00:00<00:00, 192.54it/s]
# 100%|██████████| 101/101 [00:00<00:00, 153.91it/s]
# 100%|██████████| 101/101 [00:00<00:00, 401.86it/s]
# 100%|██████████| 101/101 [00:00<00:00, 195.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 156.28it/s]
# 100%|██████████| 101/101 [00:00<00:00, 379.29it/s]
# 100%|██████████| 101/101 [00:00<00:00, 190.36it/s]
# 100%|██████████| 101/101 [00:00<00:00, 154.11it/s]
# 100%|██████████| 101/101 [00:00<00:00, 398.70it/s]
# 100%|██████████| 101/101 [00:00<00:00, 196.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 136.30it/s]
# 100%|██████████| 101/101 [00:00<00:00, 340.97it/s]
# 100%|██████████| 101/101 [00:00<00:00, 169.92it/s]
# 100%|██████████| 101/101 [00:00<00:00, 140.65it/s]
# 100%|██████████| 101/101 [00:00<00:00, 376.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 169.35it/s]
# 100%|██████████| 101/101 [00:00<00:00, 144.46it/s]
# 100%|██████████| 101/101 [00:00<00:00, 379.29it/s]
# 100%|██████████| 101/101 [00:00<00:00, 188.23it/s]
# 100%|██████████| 101/101 [00:00<00:00, 153.32it/s]
# 100%|██████████| 101/101 [00:00<00:00, 383.60it/s]
# 100%|██████████| 101/101 [00:00<00:00, 185.13it/s]

# %%
for cntr in range(nRuns):
    L23pca_temp[cntr], _ = repsPCA(L23_temp[cntr])
    L4pca_temp[cntr], _ = repsPCA(L4_temp[cntr])
    L56pca_temp[cntr], _ = repsPCA(L56_temp[cntr])

    H23pca_temp[cntr], _ = repsPCA(H23_temp[cntr])
    H4pca_temp[cntr], _ = repsPCA(H4_temp[cntr])
    H56pca_temp[cntr], _ = repsPCA(H56_temp[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 148.91it/s]
# 100%|██████████| 101/101 [00:00<00:00, 392.52it/s]
# 100%|██████████| 101/101 [00:00<00:00, 183.45it/s]
# 100%|██████████| 101/101 [00:00<00:00, 144.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 389.44it/s]
# 100%|██████████| 101/101 [00:00<00:00, 187.89it/s]
# 100%|██████████| 101/101 [00:00<00:00, 142.83it/s]
# 100%|██████████| 101/101 [00:00<00:00, 394.04it/s]
# 100%|██████████| 101/101 [00:00<00:00, 188.23it/s]
# 100%|██████████| 101/101 [00:00<00:00, 157.23it/s]
# 100%|██████████| 101/101 [00:00<00:00, 386.53it/s]
# 100%|██████████| 101/101 [00:00<00:00, 195.11it/s]
# 100%|██████████| 101/101 [00:00<00:00, 157.24it/s]
# 100%|██████████| 101/101 [00:00<00:00, 397.14it/s]
# 100%|██████████| 101/101 [00:00<00:00, 196.64it/s]
# 100%|██████████| 101/101 [00:00<00:00, 145.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 408.35it/s]
# 100%|██████████| 101/101 [00:00<00:00, 187.19it/s]
# 100%|██████████| 101/101 [00:00<00:00, 152.28it/s]
# 100%|██████████| 101/101 [00:00<00:00, 398.70it/s]
# 100%|██████████| 101/101 [00:00<00:00, 186.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 158.11it/s]
# 100%|██████████| 101/101 [00:00<00:00, 389.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 196.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 158.98it/s]
# 100%|██████████| 101/101 [00:00<00:00, 397.14it/s]
# 100%|██████████| 101/101 [00:00<00:00, 190.72it/s]
# 100%|██████████| 101/101 [00:00<00:00, 162.29it/s]
# 100%|██████████| 101/101 [00:00<00:00, 388.01it/s]
# 100%|██████████| 101/101 [00:00<00:00, 200.53it/s]

# %% [markdown]
# #### Labels, etc.

# %%
allStatesLabelsTrain = {}
allStatesLabelsTest = {}
allStatesLabelsTestTemp = {}

actionsLabelsTrain = {}
actionsLabelsTest = {}
actionsLabelsTestTemp = {}

# %%
def allStatesLabels(allStates,latLabs):
    nSamps, nSeqs, nDim = allStates.shape
    labels = np.zeros((nSamps,nSeqs),dtype=int)
    for ii in range(nSamps):
        for jj in range(nSeqs):
            labels[ii,jj] = np.where((latLabs[:,None] == allStates[ii,jj]).all(-1).any(-1)==1)[0][0]
    return labels

# %%
for cntr in range(nRuns):
#     allStatesLabelsTrain[cntr] = allStatesLabels(allStatesTrain[cntr],lattice_labels)
    allStatesLabelsTest[cntr] = allStatesLabels(allStatesTest[cntr],lattice_labels)
    allStatesLabelsTestTemp[cntr] = allStatesLabels(allStatesTestTemp[cntr],lattice_labels)
    
#     actionsLabelsTrain[cntr] = np.argmax(actionsTrain[cntr],-1)
    actionsLabelsTest[cntr] = np.argmax(actionsTest[cntr],-1)
    actionsLabelsTestTemp[cntr] = np.argmax(actionsTestTemp[cntr],-1)

# %%
# idxs0_train = np.array([6*x for x in range(nTrain)])
# idxs1_train = idxs0_train + 1
# idxs2_train = idxs0_train + 2
# idxs3_train = idxs0_train + 3
# idxs4_train = idxs0_train + 4
# idxs5_train = idxs0_train + 5

# %%
idxs0_test = np.array([6*x for x in range(nTest)])
idxs1_test = idxs0_test + 1
idxs2_test = idxs0_test + 2
idxs3_test = idxs0_test + 3
idxs4_test = idxs0_test + 4
idxs5_test = idxs0_test + 5

# %%
idxs_test_surp = np.sort(np.hstack((idxs4_test,idxs5_test)))

# %%
pos_test = np.tile(np.arange(nSteps),nTest).ravel()

# %% [markdown]
# #### Plots

# %% [markdown]
# #### Coloured by states

# %%
# cnt = 0
# ep = 50
# ix = idxs5_test
# seq = 3 ##0-3
# c = allStatesLabelsTest[cnt][:,seq] + 1
# s = 10#1*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = allStatesTest[cnt][:,seq,xy] + 0.5
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %% [markdown]
# #### Coloured by distance from lattice centre

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %% [markdown]
# #### 3D plot

# %%
# cnt = 1
# ix = idxs0_test
# seq = 0

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# c = np.repeat(c,n_epochs+1,0)
# s = 10#5*c

# sub = 1
# colmap = 'copper'

# Zs = np.repeat(np.arange(n_epochs+1).reshape(-1,1),nTest,1)

# %%
# fig = plt.figure(figsize=(17,12))

# ax = fig.add_subplot(2, 3, 1, projection='3d')
# ax.scatter3D(L4pca_test[cnt][:,ix,0].ravel()[::sub],L4pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 2, projection='3d')
# ax.scatter3D(L23pca_test[cnt][:,ix,0].ravel()[::sub],L23pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 3, projection='3d')
# ax.scatter3D(L56pca_test[cnt][:,ix,0].ravel()[::sub],L56pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 4, projection='3d')
# ax.scatter3D(H4pca_test[cnt][:,ix,0].ravel()[::sub],H4pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 5, projection='3d')
# ax.scatter3D(H23pca_test[cnt][:,ix,0].ravel()[::sub],H23pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 6, projection='3d')
# ax.scatter3D(H56pca_test[cnt][:,ix,0].ravel()[::sub],H56pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# plt.show()

# %% [markdown]
# #### Coloured by actions

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 3 ##0-3
# step = 5
# c = actionsLabelsTest[cnt][:,step] + 1
# s = 5*c
# colmap='Set1'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 2 ##0-3
# step = 5
# c = (actionsLabelsTest[cnt][:,step]%2)*1. + 1
# s = 5*c
# colmap='Dark2'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 2 ##0-3
# step = 5
# c = (actionsLabelsTest[cnt][:,step]>1)*1. + 1
# s = 5*c
# colmap='Dark2'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = 50
# ix = idxs4_test
# seq = 2 ##0-3
# step = 3
# c = allStatesLabelsTest[cnt][:,seq]
# s = 1*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs_surp
# seq = -1 ##0-3
# step = 4
# # c = actionsLabelsTest[cnt][:,step]
# # s = 5*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H5/6')

# %% [markdown]
# #### Supervised Decoding

# %% [markdown]
# #### Position

# %%
def repsDecodeSupervisedPosition(rnnActs,labels,clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    nClasses = 6
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
testPCs = {}
tempPCs = {}

contextPCs_sub = {}

# %%
for cntr in range(nRuns):
    testPCs[cntr] = (L4pca_test[cntr],L23pca_test[cntr],L56pca_test[cntr],
                     H4pca_test[cntr],H23pca_test[cntr],H56pca_test[cntr])
    tempPCs[cntr] = (L4pca_temp[cntr],L23pca_temp[cntr],L56pca_temp[cntr],
                     H4pca_temp[cntr],H23pca_temp[cntr],H56pca_temp[cntr])
    
    for rnnNo in range(len(rnn_names)):
        contextPCs_sub[cntr,rnnNo] = np.hstack((testPCs[cntr][rnnNo][:,idxs_test_surp,:],
                                                tempPCs[cntr][rnnNo][:,idxs_test_surp,:]))

# %%
L4posPC = {}
L23posPC = {}
L56posPC = {}
H4posPC = {}
H23posPC = {}
H56posPC = {}

# %%
dims23 = np.array([1,2,4,8,16,32,64,80])
dims4 = np.array([1,2,4,8,16,32])
dims56 = np.array([1,2,4,8,16,32,64])

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][1][:,:,:d],pos_test)
        H23posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][4][:,:,:d],pos_test)
    
    for d in dims4:
        L4posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][0][:,:,:d],pos_test)
        H4posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][3][:,:,:d],pos_test)
        
    for d in dims56:
        L56posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][2][:,:,:d],pos_test)      
        H56posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][5][:,:,:d],pos_test)
# Out:
# 100%|██████████| 5/5 [05:38<00:00, 67.73s/it]

# %%
preds_L23posPC = {}
preds_L4posPC = {}
preds_L56posPC = {}

preds_H23posPC = {}
preds_H4posPC = {}
preds_H56posPC = {}

# %%
accs_L23posPC = {}
accs_L4posPC = {}
accs_L56posPC = {}

accs_H23posPC = {}
accs_H4posPC = {}
accs_H56posPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23posPC[cntr,d,ep] = np.argmax(L23posPC[cntr,d][ep],axis=-1)
            preds_H23posPC[cntr,d,ep] = np.argmax(H23posPC[cntr,d][ep],axis=-1)
            
            accs_L23posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L23posPC[cntr,d,ep])
            accs_H23posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H23posPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4posPC[cntr,d,ep] = np.argmax(L4posPC[cntr,d][ep],axis=-1)
            preds_H4posPC[cntr,d,ep] = np.argmax(H4posPC[cntr,d][ep],axis=-1)
            
            accs_L4posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L4posPC[cntr,d,ep])
            accs_H4posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H4posPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56posPC[cntr,d,ep] = np.argmax(L56posPC[cntr,d][ep],axis=-1)
            preds_H56posPC[cntr,d,ep] = np.argmax(H56posPC[cntr,d][ep],axis=-1)
            
            accs_L56posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L56posPC[cntr,d,ep])
            accs_H56posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H56posPC[cntr,d,ep])

# %%
tensor_accs_L23posPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4posPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56posPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23posPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4posPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56posPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23posPC[ii,jj,kk] = accs_L23posPC[ii,d,kk]
            tensor_accs_H23posPC[ii,jj,kk] = accs_H23posPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4posPC[ii,jj,kk] = accs_L4posPC[ii,d,kk]
            tensor_accs_H4posPC[ii,jj,kk] = accs_H4posPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56posPC[ii,jj,kk] = accs_L56posPC[ii,d,kk]            
            tensor_accs_H56posPC[ii,jj,kk] = accs_H56posPC[ii,d,kk]

# %%
mean_accs_L4posPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23posPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56posPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4posPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23posPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56posPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4posPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23posPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56posPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4posPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23posPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56posPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23posPC[dd,ep] = np.mean(tensor_accs_L23posPC[:,dd,ep])
        mean_accs_H23posPC[dd,ep] = np.mean(tensor_accs_H23posPC[:,dd,ep])
        
        std_accs_L23posPC[dd,ep] = np.var(tensor_accs_L23posPC[:,dd,ep])
        std_accs_H23posPC[dd,ep] = np.var(tensor_accs_H23posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4posPC[dd,ep] = np.mean(tensor_accs_L4posPC[:,dd,ep])
        mean_accs_H4posPC[dd,ep] = np.mean(tensor_accs_H4posPC[:,dd,ep])
        
        std_accs_L4posPC[dd,ep] = np.var(tensor_accs_L4posPC[:,dd,ep])
        std_accs_H4posPC[dd,ep] = np.var(tensor_accs_H4posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56posPC[dd,ep] = np.mean(tensor_accs_L56posPC[:,dd,ep])
        mean_accs_H56posPC[dd,ep] = np.mean(tensor_accs_H56posPC[:,dd,ep])
        
        std_accs_L56posPC[dd,ep] = np.var(tensor_accs_L56posPC[:,dd,ep])
        std_accs_H56posPC[dd,ep] = np.var(tensor_accs_H56posPC[:,dd,ep])

# %%
ffpos = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Position Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,0],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,0],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,0],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,0],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,0],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,0],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Position Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,1],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,1],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,1],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,1],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,1],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,1],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Position Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,-1],yerr=std_accs_L4posPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,-1],yerr=std_accs_L23posPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,-1],yerr=std_accs_L56posPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,-1],yerr=std_accs_H4posPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,-1],yerr=std_accs_H23posPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,-1],yerr=std_accs_H56posPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
ffpos_epoch = plt.figure(figsize=(15,5))

plt.subplot(231)
plt.title('Position Decoding - 1D')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[0],yerr=std_accs_L4posPC[0],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[0],yerr=std_accs_L23posPC[0],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[0],yerr=std_accs_L56posPC[0],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[0],yerr=std_accs_H4posPC[0],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[0],yerr=std_accs_H23posPC[0],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[0],yerr=std_accs_H56posPC[0],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.subplot(232)
plt.title('Position Decoding - 2D')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[1],yerr=std_accs_L4posPC[1],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[1],yerr=std_accs_L23posPC[1],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[1],yerr=std_accs_L56posPC[1],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[1],yerr=std_accs_H4posPC[1],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[1],yerr=std_accs_H23posPC[1],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[1],yerr=std_accs_H56posPC[1],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.subplot(233)
plt.title('Position Decoding - Full Dim')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[-1],yerr=std_accs_L4posPC[-1],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[-1],yerr=std_accs_L23posPC[-1],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[-1],yerr=std_accs_L56posPC[-1],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[-1],yerr=std_accs_H4posPC[-1],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[-1],yerr=std_accs_H23posPC[-1],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[-1],yerr=std_accs_H56posPC[-1],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
fpos_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4posPC,0),yerr=np.var(mean_accs_L4posPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23posPC,0),yerr=np.var(mean_accs_L23posPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56posPC,0),yerr=np.var(mean_accs_L56posPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4posPC,0),yerr=np.var(mean_accs_H4posPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23posPC,0),yerr=np.var(mean_accs_H23posPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56posPC,0),yerr=np.var(mean_accs_H56posPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Position Decodability across Epochs - Unidirectional Feedback')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# #### Image ID and Surprise (only surprise position)

# %%
context_sub_surp = np.array([0]*2*nTest + [1]*2*nTest)

# %%
context_sub_imgIDs = {}
for cntr in range(nRuns):
    context_sub_imgIDs[cntr] = np.hstack((np.repeat(allStatesLabelsTest[cntr][:,2],nRepeats),
                                          np.repeat(allStatesLabelsTestTemp[cntr][:,2],nRepeats)))

# %%
L23imgPC = {}
L4imgPC = {}
L56imgPC = {}

H23imgPC = {}
H4imgPC = {}
H56imgPC = {}

L23surpPC = {}
L4surpPC = {}
L56surpPC = {}

H23surpPC = {}
H4surpPC = {}
H56surpPC = {}

# %%
def repsDecodeSupervisedContext(rnnActs,labels,decodeType='surprise',clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'surprise':
        nClasses = 2
    elif decodeType == 'imageID':
        nClasses = nStates
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        
        L23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][:,:,:d],context_sub_surp,decodeType='surprise')
        H23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][:,:,:d],context_sub_surp,decodeType='surprise')
        
    for d in dims4:
        L4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        
        L4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][:,:,:d],context_sub_surp,decodeType='surprise')
        H4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][:,:,:d],context_sub_surp,decodeType='surprise')
    for d in dims56:

        ## Context Sub, ImageID
        L56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')

        ## Context Sub, Surprise
        L56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][:,:,:d],context_sub_surp,decodeType='surprise')
        H56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][:,:,:d],context_sub_surp,decodeType='surprise')
# Out:
# 100%|██████████| 5/5 [14:22<00:00, 172.60s/it]

# %%
preds_L23imgPC = {}
preds_L4imgPC = {}
preds_L56imgPC = {}

preds_H23imgPC = {}
preds_H4imgPC = {}
preds_H56imgPC = {}

preds_L23surpPC = {}
preds_L4surpPC = {}
preds_L56surpPC = {}

preds_H23surpPC = {}
preds_H4surpPC = {}
preds_H56surpPC = {}

# %%
accs_L23imgPC = {}
accs_L4imgPC = {}
accs_L56imgPC = {}

accs_H23imgPC = {}
accs_H4imgPC = {}
accs_H56imgPC = {}

accs_L23surpPC = {}
accs_L4surpPC = {}
accs_L56surpPC = {}

accs_H23surpPC = {}
accs_H4surpPC = {}
accs_H56surpPC = {}

# %%
for cntr in range(nRuns):
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23imgPC[cntr,d,ep] = np.argmax(L23imgPC[cntr,d][ep],axis=-1)
            preds_H23imgPC[cntr,d,ep] = np.argmax(H23imgPC[cntr,d][ep],axis=-1)
            
            preds_L23surpPC[cntr,d,ep] = np.argmax(L23surpPC[cntr,d][ep],axis=-1)
            preds_H23surpPC[cntr,d,ep] = np.argmax(H23surpPC[cntr,d][ep],axis=-1)
            
            accs_L23imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L23imgPC[cntr,d,ep])
            accs_H23imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H23imgPC[cntr,d,ep])
            
            accs_L23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L23surpPC[cntr,d,ep])
            accs_H23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H23surpPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4imgPC[cntr,d,ep] = np.argmax(L4imgPC[cntr,d][ep],axis=-1)
            preds_H4imgPC[cntr,d,ep] = np.argmax(H4imgPC[cntr,d][ep],axis=-1)
            
            preds_L4surpPC[cntr,d,ep] = np.argmax(L4surpPC[cntr,d][ep],axis=-1)
            preds_H4surpPC[cntr,d,ep] = np.argmax(H4surpPC[cntr,d][ep],axis=-1)
            
            accs_L4imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L4imgPC[cntr,d,ep])
            accs_H4imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H4imgPC[cntr,d,ep])
            
            accs_L4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L4surpPC[cntr,d,ep])
            accs_H4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H4surpPC[cntr,d,ep])
                
        for d in dims56:        
            preds_L56imgPC[cntr,d,ep] = np.argmax(L56imgPC[cntr,d][ep],axis=-1)
            preds_H56imgPC[cntr,d,ep] = np.argmax(H56imgPC[cntr,d][ep],axis=-1)
            
            preds_L56surpPC[cntr,d,ep] = np.argmax(L56surpPC[cntr,d][ep],axis=-1)
            preds_H56surpPC[cntr,d,ep] = np.argmax(H56surpPC[cntr,d][ep],axis=-1)
            
            accs_L56imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L56imgPC[cntr,d,ep])
            accs_H56imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H56imgPC[cntr,d,ep])
            
            accs_L56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L56surpPC[cntr,d,ep])
            accs_H56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H56surpPC[cntr,d,ep])

# %%
tensor_accs_L23imgPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4imgPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56imgPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23imgPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4imgPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56imgPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_L23surpPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4surpPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56surpPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23surpPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4surpPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56surpPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23imgPC[ii,jj,kk] = accs_L23imgPC[ii,d,kk]
            tensor_accs_H23imgPC[ii,jj,kk] = accs_H23imgPC[ii,d,kk]
            
            tensor_accs_L23surpPC[ii,jj,kk] = accs_L23surpPC[ii,d,kk]
            tensor_accs_H23surpPC[ii,jj,kk] = accs_H23surpPC[ii,d,kk]
            
        
        for jj,d in enumerate(dims4):
            tensor_accs_L4imgPC[ii,jj,kk] = accs_L4imgPC[ii,d,kk]
            tensor_accs_H4imgPC[ii,jj,kk] = accs_H4imgPC[ii,d,kk]
            
            tensor_accs_L4surpPC[ii,jj,kk] = accs_L4surpPC[ii,d,kk]
            tensor_accs_H4surpPC[ii,jj,kk] = accs_H4surpPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56imgPC[ii,jj,kk] = accs_L56imgPC[ii,d,kk]
            tensor_accs_H56imgPC[ii,jj,kk] = accs_H56imgPC[ii,d,kk]

            tensor_accs_L56surpPC[ii,jj,kk] = accs_L56surpPC[ii,d,kk]
            tensor_accs_H56surpPC[ii,jj,kk] = accs_H56surpPC[ii,d,kk]

# %%
mean_accs_L4imgPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23imgPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56imgPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4imgPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23imgPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56imgPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_L4surpPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23surpPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56surpPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4surpPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23surpPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56surpPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4imgPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23imgPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56imgPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4imgPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23imgPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56imgPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4surpPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23surpPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56surpPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4surpPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23surpPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56surpPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dims in enumerate(dims23):
        mean_accs_L23imgPC[dd,ep] = np.mean(tensor_accs_L23imgPC[:,dd,ep])
        mean_accs_H23imgPC[dd,ep] = np.mean(tensor_accs_H23imgPC[:,dd,ep])
        
        std_accs_L23imgPC[dd,ep] = np.var(tensor_accs_L23imgPC[:,dd,ep])
        std_accs_H23imgPC[dd,ep] = np.var(tensor_accs_H23imgPC[:,dd,ep])
        
        mean_accs_L23surpPC[dd,ep] = np.mean(tensor_accs_L23surpPC[:,dd,ep])
        mean_accs_H23surpPC[dd,ep] = np.mean(tensor_accs_H23surpPC[:,dd,ep])
        
        std_accs_L23surpPC[dd,ep] = np.var(tensor_accs_L23surpPC[:,dd,ep])
        std_accs_H23surpPC[dd,ep] = np.var(tensor_accs_H23surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims4):
        mean_accs_L4imgPC[dd,ep] = np.mean(tensor_accs_L4imgPC[:,dd,ep])
        mean_accs_H4imgPC[dd,ep] = np.mean(tensor_accs_H4imgPC[:,dd,ep])
        
        std_accs_L4imgPC[dd,ep] = np.var(tensor_accs_L4imgPC[:,dd,ep])
        std_accs_H4imgPC[dd,ep] = np.var(tensor_accs_H4imgPC[:,dd,ep])
        
        mean_accs_L4surpPC[dd,ep] = np.mean(tensor_accs_L4surpPC[:,dd,ep])
        mean_accs_H4surpPC[dd,ep] = np.mean(tensor_accs_H4surpPC[:,dd,ep])
        
        std_accs_L4surpPC[dd,ep] = np.var(tensor_accs_L4surpPC[:,dd,ep])
        std_accs_H4surpPC[dd,ep] = np.var(tensor_accs_H4surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims56):
        mean_accs_L56imgPC[dd,ep] = np.mean(tensor_accs_L56imgPC[:,dd,ep])        
        mean_accs_H56imgPC[dd,ep] = np.mean(tensor_accs_H56imgPC[:,dd,ep])
        
        std_accs_L56imgPC[dd,ep] = np.var(tensor_accs_L56imgPC[:,dd,ep])
        std_accs_H56imgPC[dd,ep] = np.var(tensor_accs_H56imgPC[:,dd,ep])
        
        mean_accs_L56surpPC[dd,ep] = np.mean(tensor_accs_L56surpPC[:,dd,ep])
        mean_accs_H56surpPC[dd,ep] = np.mean(tensor_accs_H56surpPC[:,dd,ep])
        
        std_accs_L56surpPC[dd,ep] = np.var(tensor_accs_L56surpPC[:,dd,ep])        
        std_accs_H56surpPC[dd,ep] = np.var(tensor_accs_H56surpPC[:,dd,ep])

# %%
ffdim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Image ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,0],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,0],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,0],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,0],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,0],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,0],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Image ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,1],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,1],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,1],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,1],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,1],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,1],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Image ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,-1],yerr=std_accs_L4imgPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,-1],yerr=std_accs_L23imgPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,-1],yerr=std_accs_L56imgPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,-1],yerr=std_accs_H4imgPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,-1],yerr=std_accs_H23imgPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,-1],yerr=std_accs_H56imgPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fimg_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4imgPC,0),yerr=np.var(mean_accs_L4imgPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23imgPC,0),yerr=np.var(mean_accs_L23imgPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56imgPC,0),yerr=np.var(mean_accs_L56imgPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4imgPC,0),yerr=np.var(mean_accs_H4imgPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23imgPC,0),yerr=np.var(mean_accs_H23imgPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56imgPC,0),yerr=np.var(mean_accs_H56imgPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Image Decodability across Epochs - Unidirectional Feedback')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
ffsurp_dim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Surprise ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,0],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,0],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,0],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,0],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,0],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,0],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(132)
plt.title('Surprise ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,1],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,1],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,1],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,1],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,1],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,1],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(133)
plt.title('Surprise ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,-1],yerr=std_accs_L4surpPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,-1],yerr=std_accs_L23surpPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,-1],yerr=std_accs_L56surpPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,-1],yerr=std_accs_H4surpPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,-1],yerr=std_accs_H23surpPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,-1],yerr=std_accs_H56surpPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fsurp_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4surpPC,0),yerr=np.var(mean_accs_L4surpPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23surpPC,0),yerr=np.var(mean_accs_L23surpPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56surpPC,0),yerr=np.var(mean_accs_L56surpPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4surpPC,0),yerr=np.var(mean_accs_H4surpPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23surpPC,0),yerr=np.var(mean_accs_H23surpPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56surpPC,0),yerr=np.var(mean_accs_H56surpPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Surprise Decodability across Epochs - Unidirectional Feedback')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
np.save(pp+'preds_img_temp_L4-unidirectional-fb-lattice',preds_L4imgPC)
np.save(pp+'preds_img_temp_L23-unidirectional-fb-lattice',preds_L23imgPC)
np.save(pp+'preds_img_temp_L56-unidirectional-fb-lattice',preds_L56imgPC)
np.save(pp+'preds_img_temp_H4-unidirectional-fb-lattice',preds_H4imgPC)
np.save(pp+'preds_img_temp_H23-unidirectional-fb-lattice',preds_H23imgPC)
np.save(pp+'preds_img_temp_H56-unidirectional-fb-lattice',preds_H56imgPC)

np.save(pp+'accs_img_temp_L4-unidirectional-fb-lattice',accs_L4imgPC)
np.save(pp+'accs_img_temp_L23-unidirectional-fb-lattice',accs_L23imgPC)
np.save(pp+'accs_img_temp_L56-unidirectional-fb-lattice',accs_L56imgPC)
np.save(pp+'accs_img_temp_H4-unidirectional-fb-lattice',accs_H4imgPC)
np.save(pp+'accs_img_temp_H23-unidirectional-fb-lattice',accs_H23imgPC)
np.save(pp+'accs_img_temp_H56-unidirectional-fb-lattice',accs_H56imgPC)

# %%
np.save(pp+'preds_pos_temp_L4-unidirectional-fb-lattice',preds_L4posPC)
np.save(pp+'preds_pos_temp_L23-unidirectional-fb-lattice',preds_L23posPC)
np.save(pp+'preds_pos_temp_L56-unidirectional-fb-lattice',preds_L56posPC)
np.save(pp+'preds_pos_temp_H4-unidirectional-fb-lattice',preds_H4posPC)
np.save(pp+'preds_pos_temp_H23-unidirectional-fb-lattice',preds_H23posPC)
np.save(pp+'preds_pos_temp_H56-unidirectional-fb-lattice',preds_H56posPC)

np.save(pp+'accs_pos_temp_L4-unidirectional-fb-lattice',accs_L4posPC)
np.save(pp+'accs_pos_temp_L23-unidirectional-fb-lattice',accs_L23posPC)
np.save(pp+'accs_pos_temp_L56-unidirectional-fb-lattice',accs_L56posPC)
np.save(pp+'accs_pos_temp_H4-unidirectional-fb-lattice',accs_H4posPC)
np.save(pp+'accs_pos_temp_H23-unidirectional-fb-lattice',accs_H23posPC)
np.save(pp+'accs_pos_temp_H56-unidirectional-fb-lattice',accs_H56posPC)

# %%
np.save(pp+'preds_surp_temp_L4-unidirectional-fb-lattice',preds_L4surpPC)
np.save(pp+'preds_surp_temp_L23-unidirectional-fb-lattice',preds_L23surpPC)
np.save(pp+'preds_surp_temp_L56-unidirectional-fb-lattice',preds_L56surpPC)
np.save(pp+'preds_surp_temp_H4-unidirectional-fb-lattice',preds_H4surpPC)
np.save(pp+'preds_surp_temp_H23-unidirectional-fb-lattice',preds_H23surpPC)
np.save(pp+'preds_surp_temp_H56-unidirectional-fb-lattice',preds_H56surpPC)

np.save(pp+'accs_surp_temp_L4-unidirectional-fb-lattice',accs_L4surpPC)
np.save(pp+'accs_surp_temp_L23-unidirectional-fb-lattice',accs_L23surpPC)
np.save(pp+'accs_surp_temp_L56-unidirectional-fb-lattice',accs_L56surpPC)
np.save(pp+'accs_surp_temp_H4-unidirectional-fb-lattice',accs_H4surpPC)
np.save(pp+'accs_surp_temp_H23-unidirectional-fb-lattice',accs_H23surpPC)
np.save(pp+'accs_surp_temp_H56-unidirectional-fb-lattice',accs_H56surpPC)

# %% [markdown]
# #### Latent variable decoding

# %%
def repsDecodeSupervisedLatents(rnnActs,labels,decodeType='action',clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'action':
        nClasses = 4
    else:
        nClasses = 5
        
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
L23actPC = {}
L4actPC = {}
L56actPC = {}

H23actPC = {}
H4actPC = {}
H56actPC = {}

L23distPC = {}
L4distPC = {}
L56distPC = {}

H23distPC = {}
H4distPC = {}
H56distPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][1][:,:,:d],actionsLabelsTest[cnt].ravel())
        H23actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][4][:,:,:d],actionsLabelsTest[cnt].ravel())
    
    for d in dims4:
        L4actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][0][:,:,:d],actionsLabelsTest[cnt].ravel())
        H4actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][3][:,:,:d],actionsLabelsTest[cnt].ravel())
        
    for d in dims56:
        L56actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][2][:,:,:d],actionsLabelsTest[cnt].ravel())      
        H56actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][5][:,:,:d],actionsLabelsTest[cnt].ravel())
# Out:
# 100%|██████████| 5/5 [03:41<00:00, 44.31s/it]

# %%
preds_L23actPC = {}
preds_L4actPC = {}
preds_L56actPC = {}

preds_H23actPC = {}
preds_H4actPC = {}
preds_H56actPC = {}

# %%
accs_L23actPC = {}
accs_L4actPC = {}
accs_L56actPC = {}

accs_H23actPC = {}
accs_H4actPC = {}
accs_H56actPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23actPC[cntr,d,ep] = np.argmax(L23actPC[cntr,d][ep],axis=-1)
            preds_H23actPC[cntr,d,ep] = np.argmax(H23actPC[cntr,d][ep],axis=-1)
            
            accs_L23actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L23actPC[cntr,d,ep])
            accs_H23actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H23actPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4actPC[cntr,d,ep] = np.argmax(L4actPC[cntr,d][ep],axis=-1)
            preds_H4actPC[cntr,d,ep] = np.argmax(H4actPC[cntr,d][ep],axis=-1)
            
            accs_L4actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L4actPC[cntr,d,ep])
            accs_H4actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H4actPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56actPC[cntr,d,ep] = np.argmax(L56actPC[cntr,d][ep],axis=-1)
            preds_H56actPC[cntr,d,ep] = np.argmax(H56actPC[cntr,d][ep],axis=-1)
            
            accs_L56actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L56actPC[cntr,d,ep])
            accs_H56actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H56actPC[cntr,d,ep])

# %%
tensor_accs_L23actPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4actPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56actPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23actPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4actPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56actPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23actPC[ii,jj,kk] = accs_L23actPC[ii,d,kk]
            tensor_accs_H23actPC[ii,jj,kk] = accs_H23actPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4actPC[ii,jj,kk] = accs_L4actPC[ii,d,kk]
            tensor_accs_H4actPC[ii,jj,kk] = accs_H4actPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56actPC[ii,jj,kk] = accs_L56actPC[ii,d,kk]            
            tensor_accs_H56actPC[ii,jj,kk] = accs_H56actPC[ii,d,kk]

# %%
mean_accs_L4actPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23actPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56actPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4actPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23actPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56actPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4actPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23actPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56actPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4actPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23actPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56actPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23actPC[dd,ep] = np.mean(tensor_accs_L23actPC[:,dd,ep])
        mean_accs_H23actPC[dd,ep] = np.mean(tensor_accs_H23actPC[:,dd,ep])
        
        std_accs_L23actPC[dd,ep] = np.var(tensor_accs_L23actPC[:,dd,ep])
        std_accs_H23actPC[dd,ep] = np.var(tensor_accs_H23actPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4actPC[dd,ep] = np.mean(tensor_accs_L4actPC[:,dd,ep])
        mean_accs_H4actPC[dd,ep] = np.mean(tensor_accs_H4actPC[:,dd,ep])
        
        std_accs_L4actPC[dd,ep] = np.var(tensor_accs_L4actPC[:,dd,ep])
        std_accs_H4actPC[dd,ep] = np.var(tensor_accs_H4actPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56actPC[dd,ep] = np.mean(tensor_accs_L56actPC[:,dd,ep])
        mean_accs_H56actPC[dd,ep] = np.mean(tensor_accs_H56actPC[:,dd,ep])
        
        std_accs_L56actPC[dd,ep] = np.var(tensor_accs_L56actPC[:,dd,ep])
        std_accs_H56actPC[dd,ep] = np.var(tensor_accs_H56actPC[:,dd,ep])

# %%
ffact = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Action Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,0],yerr=std_accs_L4actPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,0],yerr=std_accs_L23actPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,0],yerr=std_accs_L56actPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,0],yerr=std_accs_H4actPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,0],yerr=std_accs_H23actPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,0],yerr=std_accs_H56actPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Action Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,1],yerr=std_accs_L4actPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,1],yerr=std_accs_L23actPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,1],yerr=std_accs_L56actPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,1],yerr=std_accs_H4actPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,1],yerr=std_accs_H23actPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,1],yerr=std_accs_H56actPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Action Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,-1],yerr=std_accs_L4actPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,-1],yerr=std_accs_L23actPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,-1],yerr=std_accs_L56actPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,-1],yerr=std_accs_H4actPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,-1],yerr=std_accs_H23actPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,-1],yerr=std_accs_H56actPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fact_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4actPC,0),yerr=np.var(mean_accs_L4actPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23actPC,0),yerr=np.var(mean_accs_L23actPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56actPC,0),yerr=np.var(mean_accs_L56actPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4actPC,0),yerr=np.var(mean_accs_H4actPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23actPC,0),yerr=np.var(mean_accs_H23actPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56actPC,0),yerr=np.var(mean_accs_H56actPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Action Decodability across Epochs - Unidirectional Feedback')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# #### Temporal accuracies

# %%
labelsTrain = {}
labelsTest = {}
labelsTestTemp = {}

# %%
for cntr in range(nRuns):
#     labelsTrain[cntr] = np.argmax(yRepsTrain[cntr]@template[cntr].T,-1)
    labelsTest[cntr] = np.argmax(yRepsTest[cntr]@template[cntr].T,-1)
    labelsTestTemp[cntr] = np.argmax(yRepsTestTemp[cntr]@template[cntr].T,-1)

# %%
# preds_train = {}
preds_test = {}
preds_temp = {}

# accs_train = np.zeros((nRuns,n_epochs+1))
accs_test = np.zeros((nRuns,n_epochs+1))
accs_temp = np.zeros((nRuns,n_epochs+1))

for cntr in range(nRuns):
#     preds_train[cntr] = np.argmax(np.abs(np.round_(out_train[cntr]))@template[cntr].T,-1)
    preds_test[cntr] = np.argmax(np.abs(np.round_(out_test[cntr]))@template[cntr].T,-1)
    preds_temp[cntr] = np.argmax(np.abs(np.round_(out_temp[cntr]))@template[cntr].T,-1)
    
    for ep in range(n_epochs+1): 
#         accs_train[cntr,ep] = accuracy_score(labelsTrain[cntr].ravel(),preds_train[cntr][ep].ravel())
        accs_test[cntr,ep] = accuracy_score(labelsTest[cntr].ravel(),preds_test[cntr][ep].ravel())
        accs_temp[cntr,ep] = accuracy_score(labelsTestTemp[cntr].ravel(),preds_temp[cntr][ep].ravel())

# %%
# plt.errorbar(np.arange(n_epochs+1),np.mean(accs_train,0),yerr=np.var(accs_train,0),fmt='-',label='Train')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_test,0),yerr=np.var(accs_test,0),fmt='-',label='Test - Clean')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_temp,0),yerr=np.var(accs_temp,0),fmt='-',label='Test - Surprise')
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend()
plt.title('Prediction accuracy in presence of temporal violation')
plt.show()

# %%
np.save(pp+'unidirectional-fb-no-violations-accs-lattice',accs_test)
np.save(pp+'unidirectional-fb-temporal-violations-accs-lattice',accs_temp)

# %% [markdown]
# ### Spatial violations

# %%
from numpy.random import normal

# %%
noise_stds = np.linspace(0,1,6)

# %%
repsTrainNoisy = {}
repsTestNoisy = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        repsTrainNoisy[cntr,nn] = repsTrain[cntr] + normal(0,noise,repsTrain[cntr].shape)
        repsTestNoisy[cntr,nn] = repsTest[cntr] + normal(0,noise,repsTest[cntr].shape)

# %%
noisy_train_loaders = {}
noisy_test_loaders = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noisy_train_loaders[cntr,nn] = makeTensorLoaders((repsTrainNoisy[cntr,nn],yRepsTrain[cntr],
                                                            eTrain[cntr],surpTrain[cntr]),batch_size,shuffle=False)
        noisy_test_loaders[cntr,nn] = makeTensorLoaders((repsTestNoisy[cntr,nn],yRepsTest[cntr],
                                                            eTest[cntr],surpTest[cntr]),batch_size,shuffle=False)

# %%
nNoise = len(noise_stds)

# %%
def pass_data_store_activations_noisy(loader, nData, 
                                nRuns=nRuns, nNoise=nNoise, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        for nn in range(nNoise):
            activations_hidden_L23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_L4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_L56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_hidden_H23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_H4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_H56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_out_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
            for e in tqdm(range(n_epochs+1)):

                cnt = 0

                ## Load model
                model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr],task='lattice')
                model[cntr].to(device)
                model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
                model[cntr].eval()

                ## Pass clean samples
                for data, f_target, lastEvent, surpriseBinary in loader[cntr,nn]:

                    if train_on_gpu:
                        data, f_targetC = data.float().cuda(), f_target.float().cuda()
                    else: data, f_targetC = data.float(), f_target.float()

                    target = f_target

                    output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                    ## Collect activations  
                    act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                    act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                    act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                    act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                    act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                    act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                    output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                    for i in range(batch_size):
                        if i < len(data):
                            label = target.data[i]

                            activations_hidden_L23_np[cntr,nn][e,cnt] = act_hidden_L23[i]
                            activations_hidden_L4_np[cntr,nn][e,cnt] = act_hidden_L4[i]
                            activations_hidden_L56_np[cntr,nn][e,cnt] = act_hidden_L56[i]

                            activations_hidden_H23_np[cntr,nn][e,cnt] = act_hidden_H23[i]
                            activations_hidden_H4_np[cntr,nn][e,cnt] = act_hidden_H4[i]
                            activations_hidden_H56_np[cntr,nn][e,cnt] = act_hidden_H56[i]

                            activations_out_np[cntr,nn][e,cnt] = output_pred[i]

                            cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# L23_train_noisy = {}
# L4_train_noisy = {}
# L56_train_noisy = {}

# H23_train_noisy = {}
# H4_train_noisy = {}
# H56_train_noisy = {}

# out_train_noisy = {}

# %%
L23_test_noisy = {}
L4_test_noisy = {}
L56_test_noisy = {}

H23_test_noisy = {}
H4_test_noisy = {}
H56_test_noisy = {}

out_test_noisy = {}

# %%
# (L23_train_noisy,L4_train_noisy,L56_train_noisy,
#  H23_train_noisy,H4_train_noisy,H56_train_noisy), out_train_noisy = pass_data_store_activations_noisy(noisy_train_loaders,nTrain)

(L23_test_noisy,L4_test_noisy,L56_test_noisy,
 H23_test_noisy,H4_test_noisy,H56_test_noisy), out_test_noisy = pass_data_store_activations_noisy(noisy_test_loaders,nTest)
# Out:
# 100%|██████████| 101/101 [00:14<00:00,  7.04it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.46it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.54it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.50it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.60it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.45it/s]
# 100%|██████████| 101/101 [00:14<00:00,  7.20it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.43it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.47it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.41it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.68it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.68it/s]
# 100%|██████████| 101/101 [00:13<00:00,  7.34it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.49it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.58it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.66it/s]
# 100%|██████████| 101/101 [00:07<00:00, 12.63it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.47it/s]
# 100%|██████████| 101/101 [00:13<00:00,  7.23it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.47it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.46it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.58it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.62it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.56it/s]
# 100%|██████████| 101/101 [00:13<00:00,  7.29it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.53it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.57it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.59it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.59it/s]
# 100%|██████████| 101/101 [00:08<00:00, 12.41it/s]

# %%
predsN_train = {}
accsN_train = np.zeros((nRuns,len(noise_stds),n_epochs+1))

predsN_test = {}
accsN_test = np.zeros((nRuns,len(noise_stds),n_epochs+1))

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        predsN_test[cntr,nn] = np.argmax(out_test_noisy[cntr,nn]@template[cntr].T,-1)
        accsN_test[cntr,nn] = np.sum(np.sum(((labelsTest[cntr] - predsN_test[cntr,nn])==0)*1,-1),-1)/(nTest*6)

# %%
name = "Dark2_r"
cmap = get_cmap(name)  # type: matplotlib.colors.ListedColormap
colors = cmap.colors  # type: list

# %%
fpredspat = plt.figure()
for nn, noise in enumerate(noise_stds):
    plt.errorbar(np.arange(n_epochs+1),np.mean(accsN_test[:,nn],0),yerr=np.var(accsN_test[:,nn],0),
                 fmt='-',label=np.round(noise,2),
                 c=colors[nn])
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend(title="Noise sigma",bbox_to_anchor=(1,0.5))
plt.title('Prediction accuracy with spatial noise - Unidirectional-FB Microcircuit')
plt.show()

# %%
np.save(pp+'unidirectional-fb-spatial-noisy-accs-lattice',accsN_test)

# %% [markdown]
# #### Dimensionality (linear)

# %%
def rnnLinDim(acts):
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    eig_mat = np.zeros((nEpochs,nNeurons))
        
    for ep in tqdm(range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        cov = actsScaled.T@actsScaled
        eig_mat[ep] = eigvals(cov)
        num = np.sum(eig_mat,1)**2
        den = np.sum(eig_mat**2,1) + 1e-17
        PR = num/den
    return PR

# %%
L23LinDim = np.zeros((nRuns,n_epochs+1))
L4LinDim = np.zeros((nRuns,n_epochs+1))
L56LinDim = np.zeros((nRuns,n_epochs+1))

H23LinDim = np.zeros((nRuns,n_epochs+1))
H4LinDim = np.zeros((nRuns,n_epochs+1))
H56LinDim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23LinDim[cntr] = rnnLinDim(L23_test[cntr])
    L4LinDim[cntr] = rnnLinDim(L4_test[cntr])
    L56LinDim[cntr] = rnnLinDim(L56_test[cntr])

    H23LinDim[cntr] = rnnLinDim(H23_test[cntr])
    H4LinDim[cntr] = rnnLinDim(H4_test[cntr])
    H56LinDim[cntr] = rnnLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 215.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 460.32it/s]
# 100%|██████████| 101/101 [00:00<00:00, 267.20it/s]
# 100%|██████████| 101/101 [00:00<00:00, 227.06it/s]
# 100%|██████████| 101/101 [00:00<00:00, 460.32it/s]
# 100%|██████████| 101/101 [00:00<00:00, 292.69it/s]
# 100%|██████████| 101/101 [00:00<00:00, 232.27it/s]
# 100%|██████████| 101/101 [00:00<00:00, 438.40it/s]
# 100%|██████████| 101/101 [00:00<00:00, 282.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 231.21it/s]
# 100%|██████████| 101/101 [00:00<00:00, 496.42it/s]
# 100%|██████████| 101/101 [00:00<00:00, 294.39it/s]
# 100%|██████████| 101/101 [00:00<00:00, 233.34it/s]
# 100%|██████████| 101/101 [00:00<00:00, 473.23it/s]
# 100%|██████████| 101/101 [00:00<00:00, 206.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 227.06it/s]
# 100%|██████████| 101/101 [00:00<00:00, 456.17it/s]
# 100%|██████████| 101/101 [00:00<00:00, 295.25it/s]
# 100%|██████████| 101/101 [00:00<00:00, 226.05it/s]
# 100%|██████████| 101/101 [00:00<00:00, 475.45it/s]
# 100%|██████████| 101/101 [00:00<00:00, 276.69it/s]
# 100%|██████████| 101/101 [00:00<00:00, 228.09it/s]
# 100%|██████████| 101/101 [00:00<00:00, 477.68it/s]
# 100%|██████████| 101/101 [00:00<00:00, 281.30it/s]
# 100%|██████████| 101/101 [00:00<00:00, 227.06it/s]
# 100%|██████████| 101/101 [00:00<00:00, 430.94it/s]
# 100%|██████████| 101/101 [00:00<00:00, 272.23it/s]
# 100%|██████████| 101/101 [00:00<00:00, 244.61it/s]
# 100%|██████████| 101/101 [00:00<00:00, 462.42it/s]
# 100%|██████████| 101/101 [00:00<00:00, 226.55it/s]

# %% [markdown]
# #### Dimensionality (non-linear)

# %%
def rnnNonLinDim(acts,nTypes=2,subsample=True,ds=100):
    
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    dims_mat = np.zeros((nEpochs,nTypes))
        
    for ep in (range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        
        if subsample:
            actsScaled = actsScaled[::ds]
        
        dims_mat[ep,0] = MiND_ML().fit(actsScaled).dimension_
#         print(dims_mat[ep,0])
        dims_mat[ep,1] = CorrInt().fit(actsScaled).dimension_
#         print(dims_mat[ep,1])
#         dims_mat[ep,2] = MLE().fit(actsScaled).dimension_
#         print(dims_mat[ep,2])
#         dims_mat[ep,3] = DANCo().fit(actsScaled).dimension_
        
    return np.mean(dims_mat,-1),dims_mat

# %%
L23NonLinDim = np.zeros((nRuns,n_epochs+1))
L4NonLinDim = np.zeros((nRuns,n_epochs+1))
L56NonLinDim = np.zeros((nRuns,n_epochs+1))

H23NonLinDim = np.zeros((nRuns,n_epochs+1))
H4NonLinDim = np.zeros((nRuns,n_epochs+1))
H56NonLinDim = np.zeros((nRuns,n_epochs+1))

# %%
L23_ND_mat = {}
L4_ND_mat = {}
L56_ND_mat = {}
H23_ND_mat = {}
H4_ND_mat = {}
H56_ND_mat = {}

# %%
for cntr in tqdm(range(nRuns)):
    L23NonLinDim[cntr], L23_ND_mat[cntr] = rnnNonLinDim(L23_test[cntr])
    L4NonLinDim[cntr], L4_ND_mat[cntr] = rnnNonLinDim(L4_test[cntr])
    L56NonLinDim[cntr], L56_ND_mat[cntr] = rnnNonLinDim(L56_test[cntr])

    H23NonLinDim[cntr], H23_ND_mat[cntr] = rnnNonLinDim(H23_test[cntr])
    H4NonLinDim[cntr], H4_ND_mat[cntr] = rnnNonLinDim(H4_test[cntr])
    H56NonLinDim[cntr], H56_ND_mat[cntr] = rnnNonLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 5/5 [02:00<00:00, 24.16s/it]

# %%
L23_NonLineDim_mean = np.mean(L23NonLinDim,0)
L4_NonLineDim_mean = np.mean(L4NonLinDim,0)
L56_NonLineDim_mean = np.mean(L56NonLinDim,0)

H23_NonLineDim_mean = np.mean(H23NonLinDim,0)
H4_NonLineDim_mean = np.mean(H4NonLinDim,0)
H56_NonLineDim_mean = np.mean(H56NonLinDim,0)

L23_NonLineDim_std = np.var(L23NonLinDim,0)
L4_NonLineDim_std = np.var(L4NonLinDim,0)
L56_NonLineDim_std = np.var(L56NonLinDim,0)

H23_NonLineDim_std = np.var(H23NonLinDim,0)
H4_NonLineDim_std = np.var(H4NonLinDim,0)
H56_NonLineDim_std = np.var(H56NonLinDim,0)

# %%
L23_dim = np.zeros((nRuns,n_epochs+1))
L4_dim = np.zeros((nRuns,n_epochs+1))
L56_dim = np.zeros((nRuns,n_epochs+1))

H23_dim = np.zeros((nRuns,n_epochs+1))
H4_dim = np.zeros((nRuns,n_epochs+1))
H56_dim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23_dim[cntr] = L23LinDim[cntr]/L23NonLinDim[cntr]
    L4_dim[cntr] = L4LinDim[cntr]/L4NonLinDim[cntr]
    L56_dim[cntr] = L56LinDim[cntr]/L56NonLinDim[cntr]
    H23_dim[cntr] = H23LinDim[cntr]/H23NonLinDim[cntr]
    H4_dim[cntr] = H4LinDim[cntr]/H4NonLinDim[cntr]
    H56_dim[cntr] = H56LinDim[cntr]/H56NonLinDim[cntr]

# %%
np.save(pp+'L23DG_unidirectional-fb_lattice',L23_dim)
np.save(pp+'L4DG_unidirectional-fb_lattice',L4_dim)
np.save(pp+'L56DG_unidirectional-fb_lattice',L56_dim)
np.save(pp+'H23DG_unidirectional-fb_lattice',H23_dim)
np.save(pp+'H4DG_unidirectional-fb_lattice',H4_dim)
np.save(pp+'H56DG_unidirectional-fb_lattice',H56_dim)

# %%
ffTotDim = plt.figure(figsize=(5,5))

plt.subplot(111)

plt.plot(np.arange(n_epochs+1),np.mean(L4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(L4_dim,0)-np.var(L4_dim,0),np.mean(L4_dim,0)+np.var(L4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(L23_dim,0)-np.var(L23_dim,0),np.mean(L23_dim,0)+np.var(L23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(L56_dim,0)-np.var(L56_dim,0),np.mean(L56_dim,0)+np.var(L56_dim,0),alpha=0.5)

plt.plot(np.arange(n_epochs+1),np.mean(H4_dim,0),label='Higher layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(H4_dim,0)-np.var(H4_dim,0),np.mean(H4_dim,0)+np.var(H4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H23_dim,0),label='Higher layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(H23_dim,0)-np.var(H23_dim,0),np.mean(H23_dim,0)+np.var(H23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H56_dim,0),label='Higher layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(H56_dim,0)-np.var(H56_dim,0),np.mean(H56_dim,0)+np.var(H56_dim,0),alpha=0.5)

plt.xlabel('Epochs')
plt.ylabel('Dimensionality Gain')
# plt.ylim(0.9,2.2)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Unidirectional Feedback')
plt.show()

# %%
ffTotDim.savefig('Dimensionality-gain-unidirectional-fb-across-learning-lattice.png',dpi=300,bbox_inches='tight')
ffTotDim.savefig('Dimensionality-gain-unidirectional-fb-across-learning-lattice.svg',dpi=300,bbox_inches='tight')
