# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from numpy.random import choice
from numpy.linalg import norm

from math import factorial

from itertools import permutations

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE, Isomap
import umap

from tqdm import tqdm
import os

# %%
from numpy.linalg import svd, eigvals
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, homogeneity_completeness_v_measure, confusion_matrix, ConfusionMatrixDisplay

# %%
from skdim.id import *

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import get_cmap

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.style.use('seaborn-whitegrid')
# plt.style.use('default')

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

# %%
from generate_data import generate_lattice_based_task, makeTensorLoaders

# %% [markdown]
# #### Test for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('No GPU, training on CPU')
    device = torch.device('cpu')
else:
    print('GPU found, training on GPU')
    device = torch.device('cuda')
# Out:
# GPU found, training on GPU

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Number of runs

# %%
nRuns = 5

# %% [markdown]
# #### Generate data for runs

# %%
dim = 64
nTot = 2000
latticeDim = 2

fracTrain = 0.8
fracTest = np.round(1-fracTrain,2)

nTrain = int(nTot*fracTrain)
nTest = nTot - nTrain

lenSeq = 4
nRepeats = 2

dimsL = np.array([5,5])
nStates = np.prod(dimsL)

# %%
cnt = 0
lattice_labels = np.zeros((nStates,latticeDim),dtype=int)
for y in range(-2,3):
    for x in range(-2,3):
        lattice_labels[cnt] = (x,y)
        cnt += 1

# %%
def templateMaker(nStates, dim):
    ## Generate template representations (for expected elements)
    template = np.zeros((nStates, dim))
    for ii in range(nStates):
        template[ii] = choice(2, dim, p=[0.75, 0.25])## p=[Pr(0),Pr(1)]
    return template

# %%
template = {}
for cntr in range(nRuns):
    template[cntr] = templateMaker(nStates=nStates,dim=dim)

# %%
repsTrain = {}
yRepsTrain = {}
eTrain = {}
pTrain = {}
surpTrain = {}
allStatesTrain = {}
actionsTrain = {}

# %%
repsTest = {}
yRepsTest = {}
eTest = {}
pTest = {}
surpTest = {}
allStatesTest = {}
actionsTest = {}

# %%
repsTestTemp = {}
yRepsTestTemp = {}
eTestTemp = {}
pTestTemp = {}
surpTestTemp = {}
allStatesTestTemp = {}
actionsTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]),\
    (actionsTrain[cntr],actionsTest[cntr],actionsTestTemp[cntr]) = generate_lattice_based_task(nTot,fracTrain,dim,lenSeq,
                                                                                               lattice_labels=lattice_labels,
                                                                                               latticeDim=latticeDim,
                                                                                               repeats=True, numRepeats=nRepeats,
                                                                                               template=template[cntr])

# %% [markdown]
# #### Create directories to save data and representations

# %%
pp = ## specify path

# %%
npp = {}
pp_npy = {}
pp_pts = {}

# %%
for cntr in range(nRuns):
    
    npp[cntr] = 'lattice-regular-'+str(cntr)+'/'
    pp_npy[cntr] = pp+npp[cntr]+'npys-'+str(cntr)+'/'
    pp_pts[cntr] = pp+npp[cntr]+'pts-'+str(cntr)+'/'
    
## uncomment the following lines to create the folders. comment out if already created
    
#     os.mkdir(os.path.join(pp,npp[cntr]))
#     os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr]))
#     os.mkdir(os.path.join(pp,npp[cntr],pp_pts[cntr]))

#     os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr],'Dataset/'))

# %% [markdown]
# #### Save seeds and dataset

# %%
seeds = np.random.randint(1000, size=nRuns)
np.save(pp_npy[cntr]+'seeds',seeds)

# %%
for cntr in range(nRuns):
    ## Template
    np.save(pp_npy[cntr]+'Dataset/template',template[cntr])

    ## Train Data
    np.save(pp_npy[cntr]+'Dataset/repsTrain',repsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTrain',yRepsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTrain',eTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTrain',surpTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTrain',allStatesTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTrain',actionsTrain[cntr])

    ## Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTest',repsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTest',yRepsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTest',eTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTest',surpTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTest',allStatesTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTest',actionsTest[cntr])
    
    ## Temporally violated Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTestTemp',repsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTestTemp',yRepsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTestTemp',eTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTestTemp',surpTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTestTemp',allStatesTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/actionsTestTemp',actionsTestTemp[cntr])

# %% [markdown]
# #### Load seeds

# %%
seeds = np.load(pp_npy[cntr]+'seeds.npy')

# %%
seeds
# Out:
# array([756, 310, 315, 660, 148])

# %% [markdown]
# #### Convert data into tensors, etc.

# %%
batch_size = 100 ##100

# %%
pos_seq_idx = np.array([0,0,1,1,2,2])

# %%
train_loader = {}
test_loader = {}
test_temp_loader = {}

# %%
for cntr in range(nRuns):
    train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=True)
    test_loader[cntr] = makeTensorLoaders((repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)
    test_temp_loader[cntr] = makeTensorLoaders((repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),
                                          batch_size,shuffle=False)

# %%
# kk = 3
# print(np.min(allStatesTestTemp[kk]))
# ix = np.where(allStatesTestTemp[kk]==np.min(allStatesTestTemp[kk]))[0]
# print(repsTestTemp[kk][ix])
# print(yRepsTestTemp[kk][ix])

# %% [markdown]
# #### Load architectures, models, etc.

# %%
n_latent = 16 ## make sure it is the same in the architecture file as well
pop_list = [2,5,4] ## make sure it is the same in the architecture file as well

# %%
from architecture_original import microcircuit

# %%
model = {}
optimizer_rec = {}
optimizer_pc = {}

# %%
#specify loss function
reconLoss = nn.MSELoss()

#optimizer learning rate
eta_rec = 0.001
eta_pc = 0.0001

# %%
for cntr in range(nRuns):
    model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,pop_list=pop_list,bsize=batch_size,
                               manual_seed=seeds[cntr],task='lattice')
    model[cntr].to(device)

# %%
for cntr in range(nRuns):
    optimizer_rec[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_rec)
    optimizer_pc[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_pc)

# %% [markdown]
# #### Train and collect activations

# %%
for data, f_target, lastEvent, surpriseBinary in train_loader[0]:
    if train_on_gpu:
        data, f_target = data.float().cuda(), f_target.float().cuda()
    else: data, f_target = data.float(), f_target.float()

# %%
output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[0](data)

# %%
nSteps = data.shape[1]

# %%
n_epochs = 100 ## number of epochs
div = n_epochs//n_epochs ## try ensuring that number used to divide by is a factor of n_epochs

# %%
feedback = True

# %%
def findMSE(output):
    errSq = output**2
    MSE_mat_samples_seq = errSq/np.prod(errSq.shape)
    MSE_samples = torch.mean(MSE_mat_samples_seq,1)
    return MSE_samples

# %%
train_losses = {}
test_losses = {}
temp_losses = {}

train_expected_rec_losses = {}
train_expected_fb_losses = {}

test_expected_rec_losses = {}
test_expected_fb_losses = {}

test_surprise_rec_losses = {}
test_surprise_fb_losses = {}

MSE_mat_full_test = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    train_losses[cntr] = np.zeros(n_epochs+1)
    test_losses[cntr] = np.zeros(n_epochs+1)
    temp_losses[cntr] = np.zeros(n_epochs+1)

    train_loss_min = np.Inf
    best_epoch = 0

    train_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    train_expected_fb_losses[cntr] = np.zeros(n_epochs+1)

    test_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_fb_losses[cntr] = np.zeros(n_epochs+1)
    
    test_surprise_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_surprise_fb_losses[cntr] = np.zeros(n_epochs+1)

    MSE_mat_full_test[cntr] = np.zeros(n_epochs+1)

    for epoch in (range(1,n_epochs+1)):

        train_loss = 0.0

        train_expected_rec_loss = 0.0
        train_expected_fb_loss = 0.0
        
        test_expected_rec_loss = 0.0
        test_expected_fb_loss = 0.0

        temp_rec_loss = 0.0
        temp_fb_loss = 0.0
        
        test_loss = 0.0
        temp_loss = 0.0

        cnt = 0
        
        ## Save model without training
        if epoch == 1:
            
            model[cntr].eval()
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_0.pt') ## Save model before any training
            
            ## Losses at 0th epoch
            for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
                if train_on_gpu:
                    data, f_target = data.float().cuda(), f_target.float().cuda()
                else:
                    data, f_target = data.float(), f_target.float()

                ##define all-sequence targets
                target = f_target

                optimizer_rec[cntr].zero_grad() #clears older gradients
                optimizer_pc[cntr].zero_grad() #clears older gradients
                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

                err_rec = torch.linalg.norm((output_pred-target),dim=2)
                err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
                MSE_samples_rec = findMSE(err_rec)
                MSE_samples_fb = findMSE(err_fb)

                loss = reconLoss(output_pred,target) #calculate the loss for the batch
                train_loss += loss.item()*data.size(0) #update training loss

                train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
                train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
                                    
            ## calculate average loss
            train_loss = train_loss/len(train_loader[cntr].dataset)
            
            ## Training loss at initialization
            train_losses[cntr][0] = train_loss
            train_expected_rec_losses[cntr][0] = train_expected_rec_loss
            train_expected_fb_losses[cntr][0] = train_expected_fb_loss
            
            ## Test losses at initialization
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test

                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)
                
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                # calculate the batch loss
                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
#             print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][0] = test_loss

            test_expected_rec_losses[cntr][0] = test_expected_rec_loss
            test_expected_fb_losses[cntr][0] = test_expected_fb_loss
        
        ## Test temp losses at initialization
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                    
                ##define all-sequence targets
                target_temp = f_target_temp

                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)
                loss_temp = reconLoss(output_pred_temp,target_temp)
                err_temp_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                # calculate the batch loss
                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_temp.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
#             print('Temp Loss: {:.6f}\n'.format(test_loss))

            temp_losses[cntr][0] = temp_loss

            test_surprise_rec_losses[cntr][0] = temp_rec_loss
            test_surprise_fb_losses[cntr][0] = temp_fb_loss

        #train model
        model[cntr].train()
        for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
            if train_on_gpu:
                data, f_target = data.float().cuda(), f_target.float().cuda()
            else:
                data, f_target = data.float(), f_target.float()

            ##define all-sequence targets
            target = f_target

            output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

            err_rec = torch.linalg.norm((output_pred-target),dim=2)
            err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
            MSE_samples_rec = findMSE(err_rec)
            MSE_samples_fb = findMSE(err_fb)
            
            loss = reconLoss(output_pred,target) #calculate the loss for the batch
            train_loss += loss.item()*data.size(0) #update training loss
            fbloss = torch.mean(MSE_samples_fb)

            optimizer_rec[cntr].zero_grad() #clears older gradients
            optimizer_pc[cntr].zero_grad() #clears older gradients
            ######## feedback error updates only higher-cortical area
            if (feedback)&(epoch%2==0):
                for name, param in model[cntr].named_parameters():
                    if ('FF' in name) or ('L23' in name) or ('L4' in name) or ('L56' in name):
                        param.require_grad = False
                fbloss.backward()
                optimizer_pc[cntr].step()
                for name, param in model[cntr].named_parameters():
                    param.require_grad = True
            else:
                loss.backward() #backprop
                optimizer_rec[cntr].step() #update parameters in direction of the -ve gradient  

            train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
            train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
        
        #calculate average loss
        train_loss = train_loss/len(train_loader[cntr].dataset)

        #training/validation stats
        train_losses[cntr][epoch] = train_loss
        train_expected_rec_losses[cntr][epoch] = train_expected_rec_loss
        train_expected_fb_losses[cntr][epoch] = train_expected_fb_loss

        #save model if the training loss decreased
        if train_loss <= train_loss_min:
            print('Epoch: {}, Train Loss Decreased!! ({:.6f}-->{:.6f})'.format(epoch,train_loss_min,train_loss))
            torch.save(model[cntr].state_dict(),pp_pts[cntr]+'predRNN.pt')
            train_loss_min = train_loss
            best_epoch = epoch

        if epoch%div == 0:
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_'+str(epoch)+'.pt')
            
            model[cntr].eval()
            
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test
                
                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)

                # calculate the batch loss
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
            print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][epoch] = test_loss

            test_expected_rec_losses[cntr][epoch] = test_expected_rec_loss
            test_expected_fb_losses[cntr][epoch] = test_expected_fb_loss
            
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                
                ##define all-sequence targets
                target_temp = f_target_temp
                
                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)

                # calculate the batch loss
                err_temp_rec = torch.linalg.norm((output_pred_temp-target_temp),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_temp[0],dim=2)+torch.linalg.norm(feedbackDiffs_temp[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_test.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
            print('Temp Loss: {:.6f}\n'.format(temp_loss))

            temp_losses[cntr][epoch] = temp_loss

            test_surprise_rec_losses[cntr][epoch] = temp_rec_loss
            test_surprise_fb_losses[cntr][epoch] = temp_fb_loss
            
    print('----------------------------------------------------')
            
    outF = open(pp+npp[cntr]+"training-details.txt", "w")
    outF.write('# epochs = ' + str(n_epochs))
    outF.write('\n')
    outF.write('Best epoch = '+str(best_epoch))
    outF.write('\n')
    outF.write('Minimum training loss = ' + str(train_loss_min))
    outF.write('\n')
    outF.write('Total number of samples = ' + str(nTot))
    outF.write('\n')
    outF.write('Number of training samples = ' + str(nTrain))
    outF.write('\n')
    outF.write('Number of testing samples = ' + str(nTest))
    outF.write('\n')
    outF.write('Dimensionality of representations = ' + str(dim))
    outF.write('\n')
    outF.write('Length of sequences = ' + str(lenSeq))
    outF.write('\n')
    outF.close()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1, Train Loss Decreased!! (inf-->0.220294)
# Test Loss: 0.194105
#
# Temp Loss: 0.194767
#
# Epoch: 2, Train Loss Decreased!! (0.220294-->0.191937)
# Test Loss: 0.193284
#
# Temp Loss: 0.193950
#
# Epoch: 3, Train Loss Decreased!! (0.191937-->0.190758)
# Test Loss: 0.191155
#
# Temp Loss: 0.191947
#
# Epoch: 4, Train Loss Decreased!! (0.190758-->0.189409)
# Test Loss: 0.191061
#
# Temp Loss: 0.192015
#
# Epoch: 5, Train Loss Decreased!! (0.189409-->0.189023)
# Test Loss: 0.190110
#
# Temp Loss: 0.190963
#
# Epoch: 6, Train Loss Decreased!! (0.189023-->0.188342)
# Test Loss: 0.190075
#
# Temp Loss: 0.190824
#
# Epoch: 7, Train Loss Decreased!! (0.188342-->0.187986)
# Test Loss: 0.189079
#
# Temp Loss: 0.191193
#
# Epoch: 8, Train Loss Decreased!! (0.187986-->0.187181)
# Test Loss: 0.189215
#
# Temp Loss: 0.190965
#
# Epoch: 9, Train Loss Decreased!! (0.187181-->0.186002)
# Test Loss: 0.186335
#
# Temp Loss: 0.194251
#
# Epoch: 10, Train Loss Decreased!! (0.186002-->0.184159)
# Test Loss: 0.186324
#
# Temp Loss: 0.193611
#
# Epoch: 11, Train Loss Decreased!! (0.184159-->0.182833)
# Test Loss: 0.183658
#
# Temp Loss: 0.196667
#
# Epoch: 12, Train Loss Decreased!! (0.182833-->0.181076)
# Test Loss: 0.183534
#
# Temp Loss: 0.196389
#
# Epoch: 13, Train Loss Decreased!! (0.181076-->0.179946)
# Test Loss: 0.180709
#
# Temp Loss: 0.197684
#
# Epoch: 14, Train Loss Decreased!! (0.179946-->0.177969)
# Test Loss: 0.180586
#
# Temp Loss: 0.197392
#
# Epoch: 15, Train Loss Decreased!! (0.177969-->0.176650)
# Test Loss: 0.177318
#
# Temp Loss: 0.199164
#
# Epoch: 16, Train Loss Decreased!! (0.176650-->0.174370)
# Test Loss: 0.177192
#
# Temp Loss: 0.198088
#
# Epoch: 17, Train Loss Decreased!! (0.174370-->0.172699)
# Test Loss: 0.173275
#
# Temp Loss: 0.199818
#
# Epoch: 18, Train Loss Decreased!! (0.172699-->0.170545)
# Test Loss: 0.173594
#
# Temp Loss: 0.199118
#
# Epoch: 19, Train Loss Decreased!! (0.170545-->0.169418)
# Test Loss: 0.170558
#
# Temp Loss: 0.199886
#
# Epoch: 20, Train Loss Decreased!! (0.169418-->0.167245)
# Test Loss: 0.170902
#
# Temp Loss: 0.199033
#
# Epoch: 21, Train Loss Decreased!! (0.167245-->0.166591)
# Test Loss: 0.168015
#
# Temp Loss: 0.200965
#
# Epoch: 22, Train Loss Decreased!! (0.166591-->0.165018)
# Test Loss: 0.168795
#
# Temp Loss: 0.200197
#
# Epoch: 23, Train Loss Decreased!! (0.165018-->0.163689)
# Test Loss: 0.164933
#
# Temp Loss: 0.202243
#
# Epoch: 24, Train Loss Decreased!! (0.163689-->0.161612)
# Test Loss: 0.165062
#
# Temp Loss: 0.201042
#
# Epoch: 25, Train Loss Decreased!! (0.161612-->0.160421)
# Test Loss: 0.161709
#
# Temp Loss: 0.201909
#
# Epoch: 26, Train Loss Decreased!! (0.160421-->0.158466)
# Test Loss: 0.162221
#
# Temp Loss: 0.200779
#
# Epoch: 27, Train Loss Decreased!! (0.158466-->0.157453)
# Test Loss: 0.158521
#
# Temp Loss: 0.204808
#
# Epoch: 28, Train Loss Decreased!! (0.157453-->0.155195)
# Test Loss: 0.158854
#
# Temp Loss: 0.203689
#
# Epoch: 29, Train Loss Decreased!! (0.155195-->0.153572)
# Test Loss: 0.153617
#
# Temp Loss: 0.205902
#
# Epoch: 30, Train Loss Decreased!! (0.153572-->0.150750)
# Test Loss: 0.154514
#
# Temp Loss: 0.204941
#
# Epoch: 31, Train Loss Decreased!! (0.150750-->0.149199)
# Test Loss: 0.149158
#
# Temp Loss: 0.209193
#
# Epoch: 32, Train Loss Decreased!! (0.149199-->0.146364)
# Test Loss: 0.149776
#
# Temp Loss: 0.207941
#
# Epoch: 33, Train Loss Decreased!! (0.146364-->0.144104)
# Test Loss: 0.143862
#
# Temp Loss: 0.209340
#
# Epoch: 34, Train Loss Decreased!! (0.144104-->0.141107)
# Test Loss: 0.144648
#
# Temp Loss: 0.208067
#
# Epoch: 35, Train Loss Decreased!! (0.141107-->0.138923)
# Test Loss: 0.138494
#
# Temp Loss: 0.212869
#
# Epoch: 36, Train Loss Decreased!! (0.138923-->0.135768)
# Test Loss: 0.139291
#
# Temp Loss: 0.211106
#
# Epoch: 37, Train Loss Decreased!! (0.135768-->0.133896)
# Test Loss: 0.133307
#
# Temp Loss: 0.213556
#
# Epoch: 38, Train Loss Decreased!! (0.133896-->0.130813)
# Test Loss: 0.134308
#
# Temp Loss: 0.211604
#
# Epoch: 39, Train Loss Decreased!! (0.130813-->0.128676)
# Test Loss: 0.127857
#
# Temp Loss: 0.214757
#
# Epoch: 40, Train Loss Decreased!! (0.128676-->0.125566)
# Test Loss: 0.128471
#
# Temp Loss: 0.212344
#
# Epoch: 41, Train Loss Decreased!! (0.125566-->0.122755)
# Test Loss: 0.121512
#
# Temp Loss: 0.215079
#
# Epoch: 42, Train Loss Decreased!! (0.122755-->0.119496)
# Test Loss: 0.122808
#
# Temp Loss: 0.213369
#
# Epoch: 43, Train Loss Decreased!! (0.119496-->0.116860)
# Test Loss: 0.115083
#
# Temp Loss: 0.217588
#
# Epoch: 44, Train Loss Decreased!! (0.116860-->0.112832)
# Test Loss: 0.115545
#
# Temp Loss: 0.215543
#
# Epoch: 45, Train Loss Decreased!! (0.112832-->0.109715)
# Test Loss: 0.106825
#
# Temp Loss: 0.219586
#
# Epoch: 46, Train Loss Decreased!! (0.109715-->0.105266)
# Test Loss: 0.107698
#
# Temp Loss: 0.216823
#
# Epoch: 47, Train Loss Decreased!! (0.105266-->0.102175)
# Test Loss: 0.098926
#
# Temp Loss: 0.220289
#
# Epoch: 48, Train Loss Decreased!! (0.102175-->0.097658)
# Test Loss: 0.100548
#
# Temp Loss: 0.218788
#
# Epoch: 49, Train Loss Decreased!! (0.097658-->0.093825)
# Test Loss: 0.089513
#
# Temp Loss: 0.222046
#
# Epoch: 50, Train Loss Decreased!! (0.093825-->0.088150)
# Test Loss: 0.090211
#
# Temp Loss: 0.220415
#
# Epoch: 51, Train Loss Decreased!! (0.088150-->0.083929)
# Test Loss: 0.078921
#
# Temp Loss: 0.225395
#
# Epoch: 52, Train Loss Decreased!! (0.083929-->0.077797)
# Test Loss: 0.079734
#
# Temp Loss: 0.223432
#
# Epoch: 53, Train Loss Decreased!! (0.077797-->0.073125)
# Test Loss: 0.067929
#
# Temp Loss: 0.227992
#
# Epoch: 54, Train Loss Decreased!! (0.073125-->0.067377)
# Test Loss: 0.069435
#
# Temp Loss: 0.226272
#
# Epoch: 55, Train Loss Decreased!! (0.067377-->0.062535)
# Test Loss: 0.057053
#
# Temp Loss: 0.230662
#
# Epoch: 56, Train Loss Decreased!! (0.062535-->0.056279)
# Test Loss: 0.057821
#
# Temp Loss: 0.228954
#
# Epoch: 57, Train Loss Decreased!! (0.056279-->0.052069)
# Test Loss: 0.047036
#
# Temp Loss: 0.233420
#
# Epoch: 58, Train Loss Decreased!! (0.052069-->0.046567)
# Test Loss: 0.048398
#
# Temp Loss: 0.232046
#
# Epoch: 59, Train Loss Decreased!! (0.046567-->0.042559)
# Test Loss: 0.038209
#
# Temp Loss: 0.235293
#
# Epoch: 60, Train Loss Decreased!! (0.042559-->0.037998)
# Test Loss: 0.039625
#
# Temp Loss: 0.234987
#
# Epoch: 61, Train Loss Decreased!! (0.037998-->0.034492)
# Test Loss: 0.030720
#
# Temp Loss: 0.239032
#
# Epoch: 62, Train Loss Decreased!! (0.034492-->0.030363)
# Test Loss: 0.031445
#
# Temp Loss: 0.238478
#
# Epoch: 63, Train Loss Decreased!! (0.030363-->0.027316)
# Test Loss: 0.024136
#
# Temp Loss: 0.242017
#
# Epoch: 64, Train Loss Decreased!! (0.027316-->0.024151)
# Test Loss: 0.025150
#
# Temp Loss: 0.241706
#
# Epoch: 65, Train Loss Decreased!! (0.024151-->0.021749)
# Test Loss: 0.018959
#
# Temp Loss: 0.243604
#
# Epoch: 66, Train Loss Decreased!! (0.021749-->0.018905)
# Test Loss: 0.019854
#
# Temp Loss: 0.243023
#
# Epoch: 67, Train Loss Decreased!! (0.018905-->0.017101)
# Test Loss: 0.014973
#
# Temp Loss: 0.246439
#
# Epoch: 68, Train Loss Decreased!! (0.017101-->0.015055)
# Test Loss: 0.016261
#
# Temp Loss: 0.246274
#
# Epoch: 69, Train Loss Decreased!! (0.015055-->0.013446)
# Test Loss: 0.011831
#
# Temp Loss: 0.248826
#
# Epoch: 70, Train Loss Decreased!! (0.013446-->0.011782)
# Test Loss: 0.012861
#
# Temp Loss: 0.247969
#
# Epoch: 71, Train Loss Decreased!! (0.011782-->0.010819)
# Test Loss: 0.009500
#
# Temp Loss: 0.250615
#
# Epoch: 72, Train Loss Decreased!! (0.010819-->0.009538)
# Test Loss: 0.010576
#
# Temp Loss: 0.249810
#
# Epoch: 73, Train Loss Decreased!! (0.009538-->0.008734)
# Test Loss: 0.007700
#
# Temp Loss: 0.252411
#
# Epoch: 74, Train Loss Decreased!! (0.008734-->0.007801)
# Test Loss: 0.008895
#
# Temp Loss: 0.251653
#
# Epoch: 75, Train Loss Decreased!! (0.007801-->0.007243)
# Test Loss: 0.006478
#
# Temp Loss: 0.253528
#
# Epoch: 76, Train Loss Decreased!! (0.007243-->0.006651)
# Test Loss: 0.007582
#
# Temp Loss: 0.252828
#
# Epoch: 77, Train Loss Decreased!! (0.006651-->0.006211)
# Test Loss: 0.005694
#
# Temp Loss: 0.254062
#
# Epoch: 78, Train Loss Decreased!! (0.006211-->0.005790)
# Test Loss: 0.006861
#
# Temp Loss: 0.253068
#
# Epoch: 79, Train Loss Decreased!! (0.005790-->0.005428)
# Test Loss: 0.004858
#
# Temp Loss: 0.254789
#
# Epoch: 80, Train Loss Decreased!! (0.005428-->0.005091)
# Test Loss: 0.006074
#
# Temp Loss: 0.253924
#
# Epoch: 81, Train Loss Decreased!! (0.005091-->0.004811)
# Test Loss: 0.004310
#
# Temp Loss: 0.254776
#
# Epoch: 82, Train Loss Decreased!! (0.004811-->0.004514)
# Test Loss: 0.005425
#
# Temp Loss: 0.253698
#
# Epoch: 83, Train Loss Decreased!! (0.004514-->0.004327)
# Test Loss: 0.003885
#
# Temp Loss: 0.255333
#
# Epoch: 84, Train Loss Decreased!! (0.004327-->0.004074)
# Test Loss: 0.004927
#
# Temp Loss: 0.254307
#
# Epoch: 85, Train Loss Decreased!! (0.004074-->0.003904)
# Test Loss: 0.003576
#
# Temp Loss: 0.256451
#
# Epoch: 86, Train Loss Decreased!! (0.003904-->0.003828)
# Test Loss: 0.004714
#
# Temp Loss: 0.255344
#
# Epoch: 87, Train Loss Decreased!! (0.003828-->0.003699)
# Test Loss: 0.003212
#
# Temp Loss: 0.256542
#
# Epoch: 88, Train Loss Decreased!! (0.003699-->0.003426)
# Test Loss: 0.004395
#
# Temp Loss: 0.255373
#
# Epoch: 89, Train Loss Decreased!! (0.003426-->0.003341)
# Test Loss: 0.002950
#
# Temp Loss: 0.256303
#
# Epoch: 90, Train Loss Decreased!! (0.003341-->0.003112)
# Test Loss: 0.003743
#
# Temp Loss: 0.255103
#
# Epoch: 91, Train Loss Decreased!! (0.003112-->0.003012)
# Test Loss: 0.002689
#
# Temp Loss: 0.256373
#
# Epoch: 92, Train Loss Decreased!! (0.003012-->0.002850)
# Test Loss: 0.003681
#
# Temp Loss: 0.255043
#
# Epoch: 93, Train Loss Decreased!! (0.002850-->0.002808)
# Test Loss: 0.002600
#
# Temp Loss: 0.257025
#
# Epoch: 94, Train Loss Decreased!! (0.002808-->0.002770)
# Test Loss: 0.003553
#
# Temp Loss: 0.255411
#
# Epoch: 95, Train Loss Decreased!! (0.002770-->0.002688)
# Test Loss: 0.002425
#
# Temp Loss: 0.256971
#
# Epoch: 96, Train Loss Decreased!! (0.002688-->0.002654)
# Test Loss: 0.003553
#
# Temp Loss: 0.255406
#
# Epoch: 97, Train Loss Decreased!! (0.002654-->0.002557)
# Test Loss: 0.002210
#
# Temp Loss: 0.256989
#
# Epoch: 98, Train Loss Decreased!! (0.002557-->0.002444)
# Test Loss: 0.003351
#
# Temp Loss: 0.254955
#
# Epoch: 99, Train Loss Decreased!! (0.002444-->0.002430)
# Test Loss: 0.002160
#
# Temp Loss: 0.257471
#  20%|██        | 1/5 [00:52<03:28, 52.12s/it]
# Epoch: 100, Train Loss Decreased!! (0.002430-->0.002428)
# Test Loss: 0.003358
#
# Temp Loss: 0.255808
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.219168)
# Test Loss: 0.188253
#
# Temp Loss: 0.187976
#
# Epoch: 2, Train Loss Decreased!! (0.219168-->0.187129)
# Test Loss: 0.187357
#
# Temp Loss: 0.186797
#
# Epoch: 3, Train Loss Decreased!! (0.187129-->0.185444)
# Test Loss: 0.184158
#
# Temp Loss: 0.183954
#
# Epoch: 4, Train Loss Decreased!! (0.185444-->0.184174)
# Test Loss: 0.184366
#
# Temp Loss: 0.184017
#
# Epoch: 5, Train Loss Decreased!! (0.184174-->0.183488)
# Test Loss: 0.183579
#
# Temp Loss: 0.183252
#
# Epoch: 6, Train Loss Decreased!! (0.183488-->0.183151)
# Test Loss: 0.183537
#
# Temp Loss: 0.183166
#
# Epoch: 7, Train Loss Decreased!! (0.183151-->0.182754)
# Test Loss: 0.182078
#
# Temp Loss: 0.182765
#
# Epoch: 8, Train Loss Decreased!! (0.182754-->0.181942)
# Test Loss: 0.182191
#
# Temp Loss: 0.182905
#
# Epoch: 9, Train Loss Decreased!! (0.181942-->0.180572)
# Test Loss: 0.178738
#
# Temp Loss: 0.183675
#
# Epoch: 10, Train Loss Decreased!! (0.180572-->0.178290)
# Test Loss: 0.178682
#
# Temp Loss: 0.183448
#
# Epoch: 11, Train Loss Decreased!! (0.178290-->0.176226)
# Test Loss: 0.174117
#
# Temp Loss: 0.184325
#
# Epoch: 12, Train Loss Decreased!! (0.176226-->0.173611)
# Test Loss: 0.174188
#
# Temp Loss: 0.184158
#
# Epoch: 13, Train Loss Decreased!! (0.173611-->0.171728)
# Test Loss: 0.169829
#
# Temp Loss: 0.186361
#
# Epoch: 14, Train Loss Decreased!! (0.171728-->0.169179)
# Test Loss: 0.170068
#
# Temp Loss: 0.186530
#
# Epoch: 15, Train Loss Decreased!! (0.169179-->0.167612)
# Test Loss: 0.166187
#
# Temp Loss: 0.188810
#
# Epoch: 16, Train Loss Decreased!! (0.167612-->0.165587)
# Test Loss: 0.166188
#
# Temp Loss: 0.188598
#
# Epoch: 17, Train Loss Decreased!! (0.165587-->0.164770)
# Test Loss: 0.163929
#
# Temp Loss: 0.191593
#
# Epoch: 18, Train Loss Decreased!! (0.164770-->0.162860)
# Test Loss: 0.164100
#
# Temp Loss: 0.191621
#
# Epoch: 19, Train Loss Decreased!! (0.162860-->0.161902)
# Test Loss: 0.161136
#
# Temp Loss: 0.193488
#
# Epoch: 20, Train Loss Decreased!! (0.161902-->0.160007)
# Test Loss: 0.161247
#
# Temp Loss: 0.193312
#
# Epoch: 21, Train Loss Decreased!! (0.160007-->0.159263)
# Test Loss: 0.158600
#
# Temp Loss: 0.195390
#
# Epoch: 22, Train Loss Decreased!! (0.159263-->0.157265)
# Test Loss: 0.158915
#
# Temp Loss: 0.194737
#
# Epoch: 23, Train Loss Decreased!! (0.157265-->0.156177)
# Test Loss: 0.155799
#
# Temp Loss: 0.195769
#
# Epoch: 24, Train Loss Decreased!! (0.156177-->0.154198)
# Test Loss: 0.155866
#
# Temp Loss: 0.195333
#
# Epoch: 25, Train Loss Decreased!! (0.154198-->0.152861)
# Test Loss: 0.152084
#
# Temp Loss: 0.197578
#
# Epoch: 26, Train Loss Decreased!! (0.152861-->0.150601)
# Test Loss: 0.152312
#
# Temp Loss: 0.197219
#
# Epoch: 27, Train Loss Decreased!! (0.150601-->0.149290)
# Test Loss: 0.148155
#
# Temp Loss: 0.199109
#
# Epoch: 28, Train Loss Decreased!! (0.149290-->0.147026)
# Test Loss: 0.148772
#
# Temp Loss: 0.198675
#
# Epoch: 29, Train Loss Decreased!! (0.147026-->0.145692)
# Test Loss: 0.144251
#
# Temp Loss: 0.200934
#
# Epoch: 30, Train Loss Decreased!! (0.145692-->0.143281)
# Test Loss: 0.145194
#
# Temp Loss: 0.201159
#
# Epoch: 31, Train Loss Decreased!! (0.143281-->0.141115)
# Test Loss: 0.139226
#
# Temp Loss: 0.202861
#
# Epoch: 32, Train Loss Decreased!! (0.141115-->0.138843)
# Test Loss: 0.140845
#
# Temp Loss: 0.202505
#
# Epoch: 33, Train Loss Decreased!! (0.138843-->0.136474)
# Test Loss: 0.134176
#
# Temp Loss: 0.202695
#
# Epoch: 34, Train Loss Decreased!! (0.136474-->0.133315)
# Test Loss: 0.135471
#
# Temp Loss: 0.202451
#
# Epoch: 35, Train Loss Decreased!! (0.133315-->0.131022)
# Test Loss: 0.128473
#
# Temp Loss: 0.204401
#
# Epoch: 36, Train Loss Decreased!! (0.131022-->0.127683)
# Test Loss: 0.129937
#
# Temp Loss: 0.204401
#
# Epoch: 37, Train Loss Decreased!! (0.127683-->0.125292)
# Test Loss: 0.122280
#
# Temp Loss: 0.205157
#
# Epoch: 38, Train Loss Decreased!! (0.125292-->0.121980)
# Test Loss: 0.124594
#
# Temp Loss: 0.205292
#
# Epoch: 39, Train Loss Decreased!! (0.121980-->0.119146)
# Test Loss: 0.115862
#
# Temp Loss: 0.209137
#
# Epoch: 40, Train Loss Decreased!! (0.119146-->0.115249)
# Test Loss: 0.119127
#
# Temp Loss: 0.209111
#
# Epoch: 41, Train Loss Decreased!! (0.115249-->0.112141)
# Test Loss: 0.108190
#
# Temp Loss: 0.209242
#
# Epoch: 42, Train Loss Decreased!! (0.112141-->0.107862)
# Test Loss: 0.111508
#
# Temp Loss: 0.209244
#
# Epoch: 43, Train Loss Decreased!! (0.107862-->0.104008)
# Test Loss: 0.099667
#
# Temp Loss: 0.211795
#
# Epoch: 44, Train Loss Decreased!! (0.104008-->0.099051)
# Test Loss: 0.102970
#
# Temp Loss: 0.211482
#
# Epoch: 45, Train Loss Decreased!! (0.099051-->0.095351)
# Test Loss: 0.090962
#
# Temp Loss: 0.213825
#
# Epoch: 46, Train Loss Decreased!! (0.095351-->0.090226)
# Test Loss: 0.094023
#
# Temp Loss: 0.213105
#
# Epoch: 47, Train Loss Decreased!! (0.090226-->0.086404)
# Test Loss: 0.082286
#
# Temp Loss: 0.217189
#
# Epoch: 48, Train Loss Decreased!! (0.086404-->0.081537)
# Test Loss: 0.085694
#
# Temp Loss: 0.216034
#
# Epoch: 49, Train Loss Decreased!! (0.081537-->0.078234)
# Test Loss: 0.074484
#
# Temp Loss: 0.219552
#
# Epoch: 50, Train Loss Decreased!! (0.078234-->0.073845)
# Test Loss: 0.078018
#
# Temp Loss: 0.217764
#
# Epoch: 51, Train Loss Decreased!! (0.073845-->0.069952)
# Test Loss: 0.066658
#
# Temp Loss: 0.221750
#
# Epoch: 52, Train Loss Decreased!! (0.069952-->0.065667)
# Test Loss: 0.069506
#
# Temp Loss: 0.219547
#
# Epoch: 53, Train Loss Decreased!! (0.065667-->0.062112)
# Test Loss: 0.058597
#
# Temp Loss: 0.224628
#
# Epoch: 54, Train Loss Decreased!! (0.062112-->0.057323)
# Test Loss: 0.061408
#
# Temp Loss: 0.221848
#
# Epoch: 55, Train Loss Decreased!! (0.057323-->0.053621)
# Test Loss: 0.051369
#
# Temp Loss: 0.227195
#
# Epoch: 56, Train Loss Decreased!! (0.053621-->0.049682)
# Test Loss: 0.053525
#
# Temp Loss: 0.225255
#
# Epoch: 57, Train Loss Decreased!! (0.049682-->0.045866)
# Test Loss: 0.043286
#
# Temp Loss: 0.229603
#
# Epoch: 58, Train Loss Decreased!! (0.045866-->0.042296)
# Test Loss: 0.046771
#
# Temp Loss: 0.227558
#
# Epoch: 59, Train Loss Decreased!! (0.042296-->0.038748)
# Test Loss: 0.036707
#
# Temp Loss: 0.233729
#
# Epoch: 60, Train Loss Decreased!! (0.038748-->0.034849)
# Test Loss: 0.038312
#
# Temp Loss: 0.232039
#
# Epoch: 61, Train Loss Decreased!! (0.034849-->0.032088)
# Test Loss: 0.030195
#
# Temp Loss: 0.235553
#
# Epoch: 62, Train Loss Decreased!! (0.032088-->0.029135)
# Test Loss: 0.032898
#
# Temp Loss: 0.233481
#
# Epoch: 63, Train Loss Decreased!! (0.029135-->0.026722)
# Test Loss: 0.024851
#
# Temp Loss: 0.239008
#
# Epoch: 64, Train Loss Decreased!! (0.026722-->0.024003)
# Test Loss: 0.027373
#
# Temp Loss: 0.237331
#
# Epoch: 65, Train Loss Decreased!! (0.024003-->0.021902)
# Test Loss: 0.020560
#
# Temp Loss: 0.240840
#
# Epoch: 66, Train Loss Decreased!! (0.021902-->0.019687)
# Test Loss: 0.022915
#
# Temp Loss: 0.238655
#
# Epoch: 67, Train Loss Decreased!! (0.019687-->0.018080)
# Test Loss: 0.016844
#
# Temp Loss: 0.242865
#
# Epoch: 68, Train Loss Decreased!! (0.018080-->0.016314)
# Test Loss: 0.019384
#
# Temp Loss: 0.240594
#
# Epoch: 69, Train Loss Decreased!! (0.016314-->0.014976)
# Test Loss: 0.014424
#
# Temp Loss: 0.244579
#
# Epoch: 70, Train Loss Decreased!! (0.014976-->0.013637)
# Test Loss: 0.016022
#
# Temp Loss: 0.242677
#
# Epoch: 71, Train Loss Decreased!! (0.013637-->0.012350)
# Test Loss: 0.011432
#
# Temp Loss: 0.245849
#
# Epoch: 72, Train Loss Decreased!! (0.012350-->0.011020)
# Test Loss: 0.013408
#
# Temp Loss: 0.243776
#
# Epoch: 73, Train Loss Decreased!! (0.011020-->0.010302)
# Test Loss: 0.009767
#
# Temp Loss: 0.247694
#
# Epoch: 74, Train Loss Decreased!! (0.010302-->0.009313)
# Test Loss: 0.011324
#
# Temp Loss: 0.245197
#
# Epoch: 75, Train Loss Decreased!! (0.009313-->0.008634)
# Test Loss: 0.008199
#
# Temp Loss: 0.247987
#
# Epoch: 76, Train Loss Decreased!! (0.008634-->0.007851)
# Test Loss: 0.009378
#
# Temp Loss: 0.245492
#
# Epoch: 77, Train Loss Decreased!! (0.007851-->0.007234)
# Test Loss: 0.006856
#
# Temp Loss: 0.248789
#
# Epoch: 78, Train Loss Decreased!! (0.007234-->0.006570)
# Test Loss: 0.008028
#
# Temp Loss: 0.246524
#
# Epoch: 79, Train Loss Decreased!! (0.006570-->0.006213)
# Test Loss: 0.005917
#
# Temp Loss: 0.250046
#
# Epoch: 80, Train Loss Decreased!! (0.006213-->0.005737)
# Test Loss: 0.007226
#
# Temp Loss: 0.247206
#
# Epoch: 81, Train Loss Decreased!! (0.005737-->0.005494)
# Test Loss: 0.005065
#
# Temp Loss: 0.250399
#
# Epoch: 82, Train Loss Decreased!! (0.005494-->0.005125)
# Test Loss: 0.006499
#
# Temp Loss: 0.247723
#
# Epoch: 83, Train Loss Decreased!! (0.005125-->0.004855)
# Test Loss: 0.004525
#
# Temp Loss: 0.251039
#
# Epoch: 84, Train Loss Decreased!! (0.004855-->0.004532)
# Test Loss: 0.005708
#
# Temp Loss: 0.248277
#
# Epoch: 85, Train Loss Decreased!! (0.004532-->0.004328)
# Test Loss: 0.004031
#
# Temp Loss: 0.251292
#
# Epoch: 86, Train Loss Decreased!! (0.004328-->0.004054)
# Test Loss: 0.005044
#
# Temp Loss: 0.248747
#
# Epoch: 87, Train Loss Decreased!! (0.004054-->0.003963)
# Test Loss: 0.003740
#
# Temp Loss: 0.251698
#
# Epoch: 88, Train Loss Decreased!! (0.003963-->0.003649)
# Test Loss: 0.004708
#
# Temp Loss: 0.248726
#
# Epoch: 89, Train Loss Decreased!! (0.003649-->0.003584)
# Test Loss: 0.003351
#
# Temp Loss: 0.251755
#
# Epoch: 90, Train Loss Decreased!! (0.003584-->0.003455)
# Test Loss: 0.004565
#
# Temp Loss: 0.248919
#
# Epoch: 91, Train Loss Decreased!! (0.003455-->0.003406)
# Test Loss: 0.003130
#
# Temp Loss: 0.252282
#
# Epoch: 92, Train Loss Decreased!! (0.003406-->0.003210)
# Test Loss: 0.004043
#
# Temp Loss: 0.249521
#
# Epoch: 93, Train Loss Decreased!! (0.003210-->0.003121)
# Test Loss: 0.002918
#
# Temp Loss: 0.252026
#
# Epoch: 94, Train Loss Decreased!! (0.003121-->0.003062)
# Test Loss: 0.004167
#
# Temp Loss: 0.248614
#
# Epoch: 95, Train Loss Decreased!! (0.003062-->0.002970)
# Test Loss: 0.002744
#
# Temp Loss: 0.251895
#
# Epoch: 96, Train Loss Decreased!! (0.002970-->0.002862)
# Test Loss: 0.003931
#
# Temp Loss: 0.248568
#
# Epoch: 97, Train Loss Decreased!! (0.002862-->0.002763)
# Test Loss: 0.002574
#
# Temp Loss: 0.252062
#
# Epoch: 98, Train Loss Decreased!! (0.002763-->0.002668)
# Test Loss: 0.003630
#
# Temp Loss: 0.248614
#
# Epoch: 99, Train Loss Decreased!! (0.002668-->0.002657)
# Test Loss: 0.002493
#
# Temp Loss: 0.252316
#  40%|████      | 2/5 [01:46<02:40, 53.37s/it]
# Epoch: 100, Train Loss Decreased!! (0.002657-->0.002551)
# Test Loss: 0.003374
#
# Temp Loss: 0.248983
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.208438)
# Test Loss: 0.180655
#
# Temp Loss: 0.180549
#
# Epoch: 2, Train Loss Decreased!! (0.208438-->0.179755)
# Test Loss: 0.180211
#
# Temp Loss: 0.179858
#
# Epoch: 3, Train Loss Decreased!! (0.179755-->0.179276)
# Test Loss: 0.178072
#
# Temp Loss: 0.178347
#
# Epoch: 4, Train Loss Decreased!! (0.179276-->0.178162)
# Test Loss: 0.178064
#
# Temp Loss: 0.178429
#
# Epoch: 5, Train Loss Decreased!! (0.178162-->0.177740)
# Test Loss: 0.177512
#
# Temp Loss: 0.177537
#
# Epoch: 6, Train Loss Decreased!! (0.177740-->0.177388)
# Test Loss: 0.177547
#
# Temp Loss: 0.177689
#
# Epoch: 7, Train Loss Decreased!! (0.177388-->0.177166)
# Test Loss: 0.176852
#
# Temp Loss: 0.177295
#
# Epoch: 8, Train Loss Decreased!! (0.177166-->0.176661)
# Test Loss: 0.176826
#
# Temp Loss: 0.177392
#
# Epoch: 9, Train Loss Decreased!! (0.176661-->0.176136)
# Test Loss: 0.175357
#
# Temp Loss: 0.178006
#
# Epoch: 10, Train Loss Decreased!! (0.176136-->0.175090)
# Test Loss: 0.175427
#
# Temp Loss: 0.177830
#
# Epoch: 11, Train Loss Decreased!! (0.175090-->0.173424)
# Test Loss: 0.171079
#
# Temp Loss: 0.180684
#
# Epoch: 12, Train Loss Decreased!! (0.173424-->0.171043)
# Test Loss: 0.170980
#
# Temp Loss: 0.180201
#
# Epoch: 13, Train Loss Decreased!! (0.171043-->0.169325)
# Test Loss: 0.167568
#
# Temp Loss: 0.181105
#
# Epoch: 14, Train Loss Decreased!! (0.169325-->0.167380)
# Test Loss: 0.167839
#
# Temp Loss: 0.180601
#
# Epoch: 15, Train Loss Decreased!! (0.167380-->0.166194)
# Test Loss: 0.164661
#
# Temp Loss: 0.182746
#
# Epoch: 16, Train Loss Decreased!! (0.166194-->0.164334)
# Test Loss: 0.164772
#
# Temp Loss: 0.182263
#
# Epoch: 17, Train Loss Decreased!! (0.164334-->0.163229)
# Test Loss: 0.162006
#
# Temp Loss: 0.186431
#
# Epoch: 18, Train Loss Decreased!! (0.163229-->0.161327)
# Test Loss: 0.161932
#
# Temp Loss: 0.185691
#
# Epoch: 19, Train Loss Decreased!! (0.161327-->0.159933)
# Test Loss: 0.158865
#
# Temp Loss: 0.189329
#
# Epoch: 20, Train Loss Decreased!! (0.159933-->0.157867)
# Test Loss: 0.158880
#
# Temp Loss: 0.188469
#
# Epoch: 21, Train Loss Decreased!! (0.157867-->0.156880)
# Test Loss: 0.156545
#
# Temp Loss: 0.193260
#
# Epoch: 22, Train Loss Decreased!! (0.156880-->0.155291)
# Test Loss: 0.156604
#
# Temp Loss: 0.192448
#
# Epoch: 23, Train Loss Decreased!! (0.155291-->0.153805)
# Test Loss: 0.152693
#
# Temp Loss: 0.194493
#
# Epoch: 24, Train Loss Decreased!! (0.153805-->0.151791)
# Test Loss: 0.153044
#
# Temp Loss: 0.193899
#
# Epoch: 25, Train Loss Decreased!! (0.151791-->0.150750)
# Test Loss: 0.149978
#
# Temp Loss: 0.197111
#
# Epoch: 26, Train Loss Decreased!! (0.150750-->0.148925)
# Test Loss: 0.150579
#
# Temp Loss: 0.196216
#
# Epoch: 27, Train Loss Decreased!! (0.148925-->0.147796)
# Test Loss: 0.146680
#
# Temp Loss: 0.196482
#
# Epoch: 28, Train Loss Decreased!! (0.147796-->0.145680)
# Test Loss: 0.146858
#
# Temp Loss: 0.195214
#
# Epoch: 29, Train Loss Decreased!! (0.145680-->0.144056)
# Test Loss: 0.142613
#
# Temp Loss: 0.198099
#
# Epoch: 30, Train Loss Decreased!! (0.144056-->0.141780)
# Test Loss: 0.143136
#
# Temp Loss: 0.197263
#
# Epoch: 31, Train Loss Decreased!! (0.141780-->0.140093)
# Test Loss: 0.137154
#
# Temp Loss: 0.198519
#
# Epoch: 32, Train Loss Decreased!! (0.140093-->0.137173)
# Test Loss: 0.137929
#
# Temp Loss: 0.197810
#
# Epoch: 33, Train Loss Decreased!! (0.137173-->0.135494)
# Test Loss: 0.133041
#
# Temp Loss: 0.200518
#
# Epoch: 34, Train Loss Decreased!! (0.135494-->0.132769)
# Test Loss: 0.133560
#
# Temp Loss: 0.199583
#
# Epoch: 35, Train Loss Decreased!! (0.132769-->0.130966)
# Test Loss: 0.128342
#
# Temp Loss: 0.200715
#
# Epoch: 36, Train Loss Decreased!! (0.130966-->0.128215)
# Test Loss: 0.129069
#
# Temp Loss: 0.200125
#
# Epoch: 37, Train Loss Decreased!! (0.128215-->0.126336)
# Test Loss: 0.123669
#
# Temp Loss: 0.202300
#
# Epoch: 38, Train Loss Decreased!! (0.126336-->0.123591)
# Test Loss: 0.124439
#
# Temp Loss: 0.201333
#
# Epoch: 39, Train Loss Decreased!! (0.123591-->0.120688)
# Test Loss: 0.116621
#
# Temp Loss: 0.203470
#
# Epoch: 40, Train Loss Decreased!! (0.120688-->0.116701)
# Test Loss: 0.117597
#
# Temp Loss: 0.202532
#
# Epoch: 41, Train Loss Decreased!! (0.116701-->0.113820)
# Test Loss: 0.109675
#
# Temp Loss: 0.205075
#
# Epoch: 42, Train Loss Decreased!! (0.113820-->0.109730)
# Test Loss: 0.110511
#
# Temp Loss: 0.204569
#
# Epoch: 43, Train Loss Decreased!! (0.109730-->0.106348)
# Test Loss: 0.101150
#
# Temp Loss: 0.207121
#
# Epoch: 44, Train Loss Decreased!! (0.106348-->0.101843)
# Test Loss: 0.102716
#
# Temp Loss: 0.206160
#
# Epoch: 45, Train Loss Decreased!! (0.101843-->0.098324)
# Test Loss: 0.092947
#
# Temp Loss: 0.209109
#
# Epoch: 46, Train Loss Decreased!! (0.098324-->0.093438)
# Test Loss: 0.094411
#
# Temp Loss: 0.207898
#
# Epoch: 47, Train Loss Decreased!! (0.093438-->0.089004)
# Test Loss: 0.083478
#
# Temp Loss: 0.211137
#
# Epoch: 48, Train Loss Decreased!! (0.089004-->0.084154)
# Test Loss: 0.084704
#
# Temp Loss: 0.210243
#
# Epoch: 49, Train Loss Decreased!! (0.084154-->0.079811)
# Test Loss: 0.073693
#
# Temp Loss: 0.213362
#
# Epoch: 50, Train Loss Decreased!! (0.079811-->0.074506)
# Test Loss: 0.075456
#
# Temp Loss: 0.212162
#
# Epoch: 51, Train Loss Decreased!! (0.074506-->0.070612)
# Test Loss: 0.064555
#
# Temp Loss: 0.213949
#
# Epoch: 52, Train Loss Decreased!! (0.070612-->0.065251)
# Test Loss: 0.066364
#
# Temp Loss: 0.213015
#
# Epoch: 53, Train Loss Decreased!! (0.065251-->0.060547)
# Test Loss: 0.054591
#
# Temp Loss: 0.217355
#
# Epoch: 54, Train Loss Decreased!! (0.060547-->0.055028)
# Test Loss: 0.056106
#
# Temp Loss: 0.216455
#
# Epoch: 55, Train Loss Decreased!! (0.055028-->0.051009)
# Test Loss: 0.045802
#
# Temp Loss: 0.221755
#
# Epoch: 56, Train Loss Decreased!! (0.051009-->0.046231)
# Test Loss: 0.047572
#
# Temp Loss: 0.220528
#
# Epoch: 57, Train Loss Decreased!! (0.046231-->0.042308)
# Test Loss: 0.037917
#
# Temp Loss: 0.225052
#
# Epoch: 58, Train Loss Decreased!! (0.042308-->0.037965)
# Test Loss: 0.039565
#
# Temp Loss: 0.223802
#
# Epoch: 59, Train Loss Decreased!! (0.037965-->0.034449)
# Test Loss: 0.030701
#
# Temp Loss: 0.228128
#
# Epoch: 60, Train Loss Decreased!! (0.034449-->0.030456)
# Test Loss: 0.031982
#
# Temp Loss: 0.227098
#
# Epoch: 61, Train Loss Decreased!! (0.030456-->0.027504)
# Test Loss: 0.024573
#
# Temp Loss: 0.232905
#
# Epoch: 62, Train Loss Decreased!! (0.027504-->0.024681)
# Test Loss: 0.026201
#
# Temp Loss: 0.231335
#
# Epoch: 63, Train Loss Decreased!! (0.024681-->0.022124)
# Test Loss: 0.019455
#
# Temp Loss: 0.235106
#
# Epoch: 64, Train Loss Decreased!! (0.022124-->0.019575)
# Test Loss: 0.021013
#
# Temp Loss: 0.233383
#
# Epoch: 65, Train Loss Decreased!! (0.019575-->0.017405)
# Test Loss: 0.015077
#
# Temp Loss: 0.237528
#
# Epoch: 66, Train Loss Decreased!! (0.017405-->0.015250)
# Test Loss: 0.016443
#
# Temp Loss: 0.236136
#
# Epoch: 67, Train Loss Decreased!! (0.015250-->0.013672)
# Test Loss: 0.011984
#
# Temp Loss: 0.239930
#
# Epoch: 68, Train Loss Decreased!! (0.013672-->0.012182)
# Test Loss: 0.013310
#
# Temp Loss: 0.238513
#
# Epoch: 69, Train Loss Decreased!! (0.012182-->0.010904)
# Test Loss: 0.009534
#
# Temp Loss: 0.240932
#
# Epoch: 70, Train Loss Decreased!! (0.010904-->0.009922)
# Test Loss: 0.011140
#
# Temp Loss: 0.239070
#
# Epoch: 71, Train Loss Decreased!! (0.009922-->0.008860)
# Test Loss: 0.007581
#
# Temp Loss: 0.243177
#
# Epoch: 72, Train Loss Decreased!! (0.008860-->0.007960)
# Test Loss: 0.008922
#
# Temp Loss: 0.241119
#
# Epoch: 73, Train Loss Decreased!! (0.007960-->0.007355)
# Test Loss: 0.006290
#
# Temp Loss: 0.243456
#
# Epoch: 74, Train Loss Decreased!! (0.007355-->0.006633)
# Test Loss: 0.007581
#
# Temp Loss: 0.241601
#
# Epoch: 75, Train Loss Decreased!! (0.006633-->0.006066)
# Test Loss: 0.005259
#
# Temp Loss: 0.244370
#
# Epoch: 76, Train Loss Decreased!! (0.006066-->0.005573)
# Test Loss: 0.006469
#
# Temp Loss: 0.242176
#
# Epoch: 77, Train Loss Decreased!! (0.005573-->0.005251)
# Test Loss: 0.004624
#
# Temp Loss: 0.245133
#
# Epoch: 78, Train Loss Decreased!! (0.005251-->0.004979)
# Test Loss: 0.006093
#
# Temp Loss: 0.242555
#
# Epoch: 79, Train Loss Decreased!! (0.004979-->0.004637)
# Test Loss: 0.004003
#
# Temp Loss: 0.245523
#
# Epoch: 80, Train Loss Decreased!! (0.004637-->0.004305)
# Test Loss: 0.005193
#
# Temp Loss: 0.242824
#
# Epoch: 81, Train Loss Decreased!! (0.004305-->0.004021)
# Test Loss: 0.003588
#
# Temp Loss: 0.245863
#
# Epoch: 82, Train Loss Decreased!! (0.004021-->0.003813)
# Test Loss: 0.004732
#
# Temp Loss: 0.243306
#
# Epoch: 83, Train Loss Decreased!! (0.003813-->0.003697)
# Test Loss: 0.003247
#
# Temp Loss: 0.246620
#
# Epoch: 84, Train Loss Decreased!! (0.003697-->0.003614)
# Test Loss: 0.004526
#
# Temp Loss: 0.243843
#
# Epoch: 85, Train Loss Decreased!! (0.003614-->0.003421)
# Test Loss: 0.003021
#
# Temp Loss: 0.246850
#
# Epoch: 86, Train Loss Decreased!! (0.003421-->0.003309)
# Test Loss: 0.004262
#
# Temp Loss: 0.243789
#
# Epoch: 87, Train Loss Decreased!! (0.003309-->0.003127)
# Test Loss: 0.002807
#
# Temp Loss: 0.246468
#
# Epoch: 88, Train Loss Decreased!! (0.003127-->0.003106)
# Test Loss: 0.004020
#
# Temp Loss: 0.243242
#
# Epoch: 89, Train Loss Decreased!! (0.003106-->0.002972)
# Test Loss: 0.002528
#
# Temp Loss: 0.246630
#
# Epoch: 90, Train Loss Decreased!! (0.002972-->0.002887)
# Test Loss: 0.003810
#
# Temp Loss: 0.243451
#
# Epoch: 91, Train Loss Decreased!! (0.002887-->0.002778)
# Test Loss: 0.002438
#
# Temp Loss: 0.246606
#
# Epoch: 92, Train Loss Decreased!! (0.002778-->0.002671)
# Test Loss: 0.003637
#
# Temp Loss: 0.243078
#
# Epoch: 93, Train Loss Decreased!! (0.002671-->0.002607)
# Test Loss: 0.002218
#
# Temp Loss: 0.246748
#
# Epoch: 94, Train Loss Decreased!! (0.002607-->0.002535)
# Test Loss: 0.003430
#
# Temp Loss: 0.243228
#
# Epoch: 95, Train Loss Decreased!! (0.002535-->0.002483)
# Test Loss: 0.002117
#
# Temp Loss: 0.246686
#
# Epoch: 96, Train Loss Decreased!! (0.002483-->0.002406)
# Test Loss: 0.003333
#
# Temp Loss: 0.243002
#
# Epoch: 97, Train Loss Decreased!! (0.002406-->0.002336)
# Test Loss: 0.002128
#
# Temp Loss: 0.246357
#
# Epoch: 98, Train Loss Decreased!! (0.002336-->0.002313)
# Test Loss: 0.003323
#
# Temp Loss: 0.242782
#
# Epoch: 99, Train Loss Decreased!! (0.002313-->0.002214)
# Test Loss: 0.001905
#
# Temp Loss: 0.246977
#  60%|██████    | 3/5 [02:41<01:47, 53.96s/it]
# Test Loss: 0.003149
#
# Temp Loss: 0.242900
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.213663)
# Test Loss: 0.186215
#
# Temp Loss: 0.187033
#
# Epoch: 2, Train Loss Decreased!! (0.213663-->0.186049)
# Test Loss: 0.185567
#
# Temp Loss: 0.186261
#
# Epoch: 3, Train Loss Decreased!! (0.186049-->0.185326)
# Test Loss: 0.183406
#
# Temp Loss: 0.184542
#
# Epoch: 4, Train Loss Decreased!! (0.185326-->0.183870)
# Test Loss: 0.183543
#
# Temp Loss: 0.184697
#
# Epoch: 5, Train Loss Decreased!! (0.183870-->0.183462)
# Test Loss: 0.182640
#
# Temp Loss: 0.184098
#
# Epoch: 6, Train Loss Decreased!! (0.183462-->0.182943)
# Test Loss: 0.182909
#
# Temp Loss: 0.184116
#
# Epoch: 7, Train Loss Decreased!! (0.182943-->0.182325)
# Test Loss: 0.180349
#
# Temp Loss: 0.183952
#
# Epoch: 8, Train Loss Decreased!! (0.182325-->0.180913)
# Test Loss: 0.180569
#
# Temp Loss: 0.183888
#
# Epoch: 9, Train Loss Decreased!! (0.180913-->0.179640)
# Test Loss: 0.176753
#
# Temp Loss: 0.187166
#
# Epoch: 10, Train Loss Decreased!! (0.179640-->0.177108)
# Test Loss: 0.176742
#
# Temp Loss: 0.186826
#
# Epoch: 11, Train Loss Decreased!! (0.177108-->0.174692)
# Test Loss: 0.171402
#
# Temp Loss: 0.191443
#
# Epoch: 12, Train Loss Decreased!! (0.174692-->0.171775)
# Test Loss: 0.171320
#
# Temp Loss: 0.191193
#
# Epoch: 13, Train Loss Decreased!! (0.171775-->0.169320)
# Test Loss: 0.166016
#
# Temp Loss: 0.194503
#
# Epoch: 14, Train Loss Decreased!! (0.169320-->0.166272)
# Test Loss: 0.166176
#
# Temp Loss: 0.193734
#
# Epoch: 15, Train Loss Decreased!! (0.166272-->0.164423)
# Test Loss: 0.161882
#
# Temp Loss: 0.196743
#
# Epoch: 16, Train Loss Decreased!! (0.164423-->0.161705)
# Test Loss: 0.162178
#
# Temp Loss: 0.196189
#
# Epoch: 17, Train Loss Decreased!! (0.161705-->0.160725)
# Test Loss: 0.159247
#
# Temp Loss: 0.200917
#
# Epoch: 18, Train Loss Decreased!! (0.160725-->0.158894)
# Test Loss: 0.159627
#
# Temp Loss: 0.200414
#
# Epoch: 19, Train Loss Decreased!! (0.158894-->0.158074)
# Test Loss: 0.156743
#
# Temp Loss: 0.200093
#
# Epoch: 20, Train Loss Decreased!! (0.158074-->0.156210)
# Test Loss: 0.156981
#
# Temp Loss: 0.199708
#
# Epoch: 21, Train Loss Decreased!! (0.156210-->0.155526)
# Test Loss: 0.154053
#
# Temp Loss: 0.201015
#
# Epoch: 22, Train Loss Decreased!! (0.155526-->0.153551)
# Test Loss: 0.154275
#
# Temp Loss: 0.200662
#
# Epoch: 23, Train Loss Decreased!! (0.153551-->0.152444)
# Test Loss: 0.151381
#
# Temp Loss: 0.199485
#
# Epoch: 24, Train Loss Decreased!! (0.152444-->0.150154)
# Test Loss: 0.151560
#
# Temp Loss: 0.199272
#
# Epoch: 25, Train Loss Decreased!! (0.150154-->0.148728)
# Test Loss: 0.147667
#
# Temp Loss: 0.199727
#
# Epoch: 26, Train Loss Decreased!! (0.148728-->0.146019)
# Test Loss: 0.147905
#
# Temp Loss: 0.199699
#
# Epoch: 27, Train Loss Decreased!! (0.146019-->0.144214)
# Test Loss: 0.142478
#
# Temp Loss: 0.200285
#
# Epoch: 28, Train Loss Decreased!! (0.144214-->0.140673)
# Test Loss: 0.142743
#
# Temp Loss: 0.199967
#
# Epoch: 29, Train Loss Decreased!! (0.140673-->0.138632)
# Test Loss: 0.137252
#
# Temp Loss: 0.202717
#
# Epoch: 30, Train Loss Decreased!! (0.138632-->0.134764)
# Test Loss: 0.137519
#
# Temp Loss: 0.202395
#
# Epoch: 31, Train Loss Decreased!! (0.134764-->0.132449)
# Test Loss: 0.131695
#
# Temp Loss: 0.204582
#
# Epoch: 32, Train Loss Decreased!! (0.132449-->0.129305)
# Test Loss: 0.132273
#
# Temp Loss: 0.203992
#
# Epoch: 33, Train Loss Decreased!! (0.129305-->0.126908)
# Test Loss: 0.126796
#
# Temp Loss: 0.208936
#
# Epoch: 34, Train Loss Decreased!! (0.126908-->0.124017)
# Test Loss: 0.127727
#
# Temp Loss: 0.208344
#
# Epoch: 35, Train Loss Decreased!! (0.124017-->0.121558)
# Test Loss: 0.121151
#
# Temp Loss: 0.210362
#
# Epoch: 36, Train Loss Decreased!! (0.121558-->0.118207)
# Test Loss: 0.121704
#
# Temp Loss: 0.209912
#
# Epoch: 37, Train Loss Decreased!! (0.118207-->0.116102)
# Test Loss: 0.116353
#
# Temp Loss: 0.212338
#
# Epoch: 38, Train Loss Decreased!! (0.116102-->0.112709)
# Test Loss: 0.116661
#
# Temp Loss: 0.211831
#
# Epoch: 39, Train Loss Decreased!! (0.112709-->0.110276)
# Test Loss: 0.109891
#
# Temp Loss: 0.213791
#
# Epoch: 40, Train Loss Decreased!! (0.110276-->0.106288)
# Test Loss: 0.110651
#
# Temp Loss: 0.213630
#
# Epoch: 41, Train Loss Decreased!! (0.106288-->0.103027)
# Test Loss: 0.101814
#
# Temp Loss: 0.215137
#
# Epoch: 42, Train Loss Decreased!! (0.103027-->0.098708)
# Test Loss: 0.102779
#
# Temp Loss: 0.214843
#
# Epoch: 43, Train Loss Decreased!! (0.098708-->0.095034)
# Test Loss: 0.093283
#
# Temp Loss: 0.218793
#
# Epoch: 44, Train Loss Decreased!! (0.095034-->0.089856)
# Test Loss: 0.093960
#
# Temp Loss: 0.218560
#
# Epoch: 45, Train Loss Decreased!! (0.089856-->0.085820)
# Test Loss: 0.083339
#
# Temp Loss: 0.220540
#
# Epoch: 46, Train Loss Decreased!! (0.085820-->0.080071)
# Test Loss: 0.083978
#
# Temp Loss: 0.219961
#
# Epoch: 47, Train Loss Decreased!! (0.080071-->0.075647)
# Test Loss: 0.072805
#
# Temp Loss: 0.223870
#
# Epoch: 48, Train Loss Decreased!! (0.075647-->0.070150)
# Test Loss: 0.073772
#
# Temp Loss: 0.223088
#
# Epoch: 49, Train Loss Decreased!! (0.070150-->0.065707)
# Test Loss: 0.062159
#
# Temp Loss: 0.225762
#
# Epoch: 50, Train Loss Decreased!! (0.065707-->0.059959)
# Test Loss: 0.063001
#
# Temp Loss: 0.225435
#
# Epoch: 51, Train Loss Decreased!! (0.059959-->0.055480)
# Test Loss: 0.051680
#
# Temp Loss: 0.231255
#
# Epoch: 52, Train Loss Decreased!! (0.055480-->0.050061)
# Test Loss: 0.052769
#
# Temp Loss: 0.230018
#
# Epoch: 53, Train Loss Decreased!! (0.050061-->0.045890)
# Test Loss: 0.042054
#
# Temp Loss: 0.234964
#
# Epoch: 54, Train Loss Decreased!! (0.045890-->0.040952)
# Test Loss: 0.043011
#
# Temp Loss: 0.233768
#
# Epoch: 55, Train Loss Decreased!! (0.040952-->0.037316)
# Test Loss: 0.033767
#
# Temp Loss: 0.236442
#
# Epoch: 56, Train Loss Decreased!! (0.037316-->0.033054)
# Test Loss: 0.035117
#
# Temp Loss: 0.235038
#
# Epoch: 57, Train Loss Decreased!! (0.033054-->0.029882)
# Test Loss: 0.026810
#
# Temp Loss: 0.238897
#
# Epoch: 58, Train Loss Decreased!! (0.029882-->0.026735)
# Test Loss: 0.028631
#
# Temp Loss: 0.237245
#
# Epoch: 59, Train Loss Decreased!! (0.026735-->0.023952)
# Test Loss: 0.021221
#
# Temp Loss: 0.242023
#
# Epoch: 60, Train Loss Decreased!! (0.023952-->0.021175)
# Test Loss: 0.022387
#
# Temp Loss: 0.240686
#
# Epoch: 61, Train Loss Decreased!! (0.021175-->0.018793)
# Test Loss: 0.016297
#
# Temp Loss: 0.244443
#
# Epoch: 62, Train Loss Decreased!! (0.018793-->0.016262)
# Test Loss: 0.017389
#
# Temp Loss: 0.242940
#
# Epoch: 63, Train Loss Decreased!! (0.016262-->0.014542)
# Test Loss: 0.012606
#
# Temp Loss: 0.246307
#
# Epoch: 64, Train Loss Decreased!! (0.014542-->0.012534)
# Test Loss: 0.013641
#
# Temp Loss: 0.244923
#
# Epoch: 65, Train Loss Decreased!! (0.012534-->0.011350)
# Test Loss: 0.010024
#
# Temp Loss: 0.247714
#
# Epoch: 66, Train Loss Decreased!! (0.011350-->0.009933)
# Test Loss: 0.010804
#
# Temp Loss: 0.246259
#
# Epoch: 67, Train Loss Decreased!! (0.009933-->0.008835)
# Test Loss: 0.007735
#
# Temp Loss: 0.249510
#
# Epoch: 68, Train Loss Decreased!! (0.008835-->0.007723)
# Test Loss: 0.008615
#
# Temp Loss: 0.247799
#
# Epoch: 69, Train Loss Decreased!! (0.007723-->0.007002)
# Test Loss: 0.006288
#
# Temp Loss: 0.250269
#
# Epoch: 70, Train Loss Decreased!! (0.007002-->0.006262)
# Test Loss: 0.007063
#
# Temp Loss: 0.248457
#
# Epoch: 71, Train Loss Decreased!! (0.006262-->0.005843)
# Test Loss: 0.005149
#
# Temp Loss: 0.251413
#
# Epoch: 72, Train Loss Decreased!! (0.005843-->0.005090)
# Test Loss: 0.005859
#
# Temp Loss: 0.249948
#
# Epoch: 73, Train Loss Decreased!! (0.005090-->0.004815)
# Test Loss: 0.004497
#
# Temp Loss: 0.252128
#
# Epoch: 74, Train Loss Decreased!! (0.004815-->0.004446)
# Test Loss: 0.005224
#
# Temp Loss: 0.250605
#
# Epoch: 75, Train Loss Decreased!! (0.004446-->0.004169)
# Test Loss: 0.003792
#
# Temp Loss: 0.252386
#
# Epoch: 76, Train Loss Decreased!! (0.004169-->0.003773)
# Test Loss: 0.004382
#
# Temp Loss: 0.250724
#
# Epoch: 77, Train Loss Decreased!! (0.003773-->0.003604)
# Test Loss: 0.003353
#
# Temp Loss: 0.252407
#
# Epoch: 78, Train Loss Decreased!! (0.003604-->0.003435)
# Test Loss: 0.004120
#
# Temp Loss: 0.250671
#
# Epoch: 79, Train Loss Decreased!! (0.003435-->0.003276)
# Test Loss: 0.002992
#
# Temp Loss: 0.252998
#
# Epoch: 80, Train Loss Decreased!! (0.003276-->0.003127)
# Test Loss: 0.003769
#
# Temp Loss: 0.251039
#
# Epoch: 81, Train Loss Decreased!! (0.003127-->0.002986)
# Test Loss: 0.002748
#
# Temp Loss: 0.253390
#
# Epoch: 82, Train Loss Decreased!! (0.002986-->0.002777)
# Test Loss: 0.003509
#
# Temp Loss: 0.251410
#
# Epoch: 83, Train Loss Decreased!! (0.002777-->0.002705)
# Test Loss: 0.002540
#
# Temp Loss: 0.253586
#
# Epoch: 84, Train Loss Decreased!! (0.002705-->0.002598)
# Test Loss: 0.003216
#
# Temp Loss: 0.251373
#
# Epoch: 85, Train Loss Decreased!! (0.002598-->0.002549)
# Test Loss: 0.002349
#
# Temp Loss: 0.253569
#
# Epoch: 86, Train Loss Decreased!! (0.002549-->0.002445)
# Test Loss: 0.003002
#
# Temp Loss: 0.251266
#
# Epoch: 87, Train Loss Decreased!! (0.002445-->0.002315)
# Test Loss: 0.002172
#
# Temp Loss: 0.253595
#
# Test Loss: 0.002926
#
# Temp Loss: 0.251474
#
# Epoch: 89, Train Loss Decreased!! (0.002315-->0.002213)
# Test Loss: 0.002091
#
# Temp Loss: 0.253823
#
# Epoch: 90, Train Loss Decreased!! (0.002213-->0.002171)
# Test Loss: 0.002779
#
# Temp Loss: 0.251413
#
# Epoch: 91, Train Loss Decreased!! (0.002171-->0.002131)
# Test Loss: 0.001939
#
# Temp Loss: 0.254157
#
# Epoch: 92, Train Loss Decreased!! (0.002131-->0.002070)
# Test Loss: 0.002735
#
# Temp Loss: 0.251389
#
# Epoch: 93, Train Loss Decreased!! (0.002070-->0.002002)
# Test Loss: 0.001819
#
# Temp Loss: 0.254231
#
# Epoch: 94, Train Loss Decreased!! (0.002002-->0.001889)
# Test Loss: 0.002392
#
# Temp Loss: 0.251633
#
# Epoch: 95, Train Loss Decreased!! (0.001889-->0.001874)
# Test Loss: 0.001720
#
# Temp Loss: 0.254265
#
# Epoch: 96, Train Loss Decreased!! (0.001874-->0.001850)
# Test Loss: 0.002417
#
# Temp Loss: 0.251445
#
# Epoch: 97, Train Loss Decreased!! (0.001850-->0.001818)
# Test Loss: 0.001622
#
# Temp Loss: 0.254083
#
# Epoch: 98, Train Loss Decreased!! (0.001818-->0.001786)
# Test Loss: 0.002347
#
# Temp Loss: 0.251130
#
# Epoch: 99, Train Loss Decreased!! (0.001786-->0.001713)
# Test Loss: 0.001538
#
# Temp Loss: 0.253874
#  80%|████████  | 4/5 [03:34<00:53, 53.73s/it]
# Epoch: 100, Train Loss Decreased!! (0.001713-->0.001708)
# Test Loss: 0.002281
#
# Temp Loss: 0.250874
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.212073)
# Test Loss: 0.187662
#
# Temp Loss: 0.187959
#
# Epoch: 2, Train Loss Decreased!! (0.212073-->0.187147)
# Test Loss: 0.186957
#
# Temp Loss: 0.187217
#
# Epoch: 3, Train Loss Decreased!! (0.187147-->0.186472)
# Test Loss: 0.185323
#
# Temp Loss: 0.185885
#
# Epoch: 4, Train Loss Decreased!! (0.186472-->0.185176)
# Test Loss: 0.185214
#
# Temp Loss: 0.185985
#
# Epoch: 5, Train Loss Decreased!! (0.185176-->0.184876)
# Test Loss: 0.184322
#
# Temp Loss: 0.184932
#
# Epoch: 6, Train Loss Decreased!! (0.184876-->0.184340)
# Test Loss: 0.184112
#
# Temp Loss: 0.184977
#
# Epoch: 7, Train Loss Decreased!! (0.184340-->0.184101)
# Test Loss: 0.183276
#
# Temp Loss: 0.184819
#
# Epoch: 8, Train Loss Decreased!! (0.184101-->0.183282)
# Test Loss: 0.183252
#
# Temp Loss: 0.184648
#
# Epoch: 9, Train Loss Decreased!! (0.183282-->0.181881)
# Test Loss: 0.180081
#
# Temp Loss: 0.186172
#
# Epoch: 10, Train Loss Decreased!! (0.181881-->0.179939)
# Test Loss: 0.180295
#
# Temp Loss: 0.185908
#
# Epoch: 11, Train Loss Decreased!! (0.179939-->0.177793)
# Test Loss: 0.175818
#
# Temp Loss: 0.187902
#
# Epoch: 12, Train Loss Decreased!! (0.177793-->0.175338)
# Test Loss: 0.176146
#
# Temp Loss: 0.187869
#
# Epoch: 13, Train Loss Decreased!! (0.175338-->0.173852)
# Test Loss: 0.172038
#
# Temp Loss: 0.188064
#
# Epoch: 14, Train Loss Decreased!! (0.173852-->0.171390)
# Test Loss: 0.171932
#
# Temp Loss: 0.187708
#
# Epoch: 15, Train Loss Decreased!! (0.171390-->0.170269)
# Test Loss: 0.168608
#
# Temp Loss: 0.189696
#
# Epoch: 16, Train Loss Decreased!! (0.170269-->0.168339)
# Test Loss: 0.168722
#
# Temp Loss: 0.189420
#
# Epoch: 17, Train Loss Decreased!! (0.168339-->0.166994)
# Test Loss: 0.165342
#
# Temp Loss: 0.192908
#
# Epoch: 18, Train Loss Decreased!! (0.166994-->0.164976)
# Test Loss: 0.165525
#
# Temp Loss: 0.192202
#
# Epoch: 19, Train Loss Decreased!! (0.164976-->0.163511)
# Test Loss: 0.161951
#
# Temp Loss: 0.195880
#
# Epoch: 20, Train Loss Decreased!! (0.163511-->0.161644)
# Test Loss: 0.162085
#
# Temp Loss: 0.195040
#
# Epoch: 21, Train Loss Decreased!! (0.161644-->0.160514)
# Test Loss: 0.159133
#
# Temp Loss: 0.196872
#
# Epoch: 22, Train Loss Decreased!! (0.160514-->0.158429)
# Test Loss: 0.159182
#
# Temp Loss: 0.196111
#
# Epoch: 23, Train Loss Decreased!! (0.158429-->0.157605)
# Test Loss: 0.156514
#
# Temp Loss: 0.197757
#
# Epoch: 24, Train Loss Decreased!! (0.157605-->0.155832)
# Test Loss: 0.156671
#
# Temp Loss: 0.197113
#
# Epoch: 25, Train Loss Decreased!! (0.155832-->0.154654)
# Test Loss: 0.153488
#
# Temp Loss: 0.198732
#
# Epoch: 26, Train Loss Decreased!! (0.154654-->0.152743)
# Test Loss: 0.153751
#
# Temp Loss: 0.198269
#
# Epoch: 27, Train Loss Decreased!! (0.152743-->0.151634)
# Test Loss: 0.150658
#
# Temp Loss: 0.200905
#
# Epoch: 28, Train Loss Decreased!! (0.151634-->0.149805)
# Test Loss: 0.150817
#
# Temp Loss: 0.200063
#
# Epoch: 29, Train Loss Decreased!! (0.149805-->0.148449)
# Test Loss: 0.147452
#
# Temp Loss: 0.200376
#
# Epoch: 30, Train Loss Decreased!! (0.148449-->0.146332)
# Test Loss: 0.147828
#
# Temp Loss: 0.199687
#
# Epoch: 31, Train Loss Decreased!! (0.146332-->0.144902)
# Test Loss: 0.143544
#
# Temp Loss: 0.200300
#
# Epoch: 32, Train Loss Decreased!! (0.144902-->0.142194)
# Test Loss: 0.143920
#
# Temp Loss: 0.199634
#
# Epoch: 33, Train Loss Decreased!! (0.142194-->0.140554)
# Test Loss: 0.139091
#
# Temp Loss: 0.202902
#
# Epoch: 34, Train Loss Decreased!! (0.140554-->0.137621)
# Test Loss: 0.139385
#
# Temp Loss: 0.202805
#
# Epoch: 35, Train Loss Decreased!! (0.137621-->0.135482)
# Test Loss: 0.133577
#
# Temp Loss: 0.204857
#
# Epoch: 36, Train Loss Decreased!! (0.135482-->0.132024)
# Test Loss: 0.133799
#
# Temp Loss: 0.204903
#
# Epoch: 37, Train Loss Decreased!! (0.132024-->0.128921)
# Test Loss: 0.126541
#
# Temp Loss: 0.206436
#
# Epoch: 38, Train Loss Decreased!! (0.128921-->0.124696)
# Test Loss: 0.126738
#
# Temp Loss: 0.206304
#
# Epoch: 39, Train Loss Decreased!! (0.124696-->0.121207)
# Test Loss: 0.117872
#
# Temp Loss: 0.208624
#
# Epoch: 40, Train Loss Decreased!! (0.121207-->0.115734)
# Test Loss: 0.118270
#
# Temp Loss: 0.208719
#
# Epoch: 41, Train Loss Decreased!! (0.115734-->0.112054)
# Test Loss: 0.108995
#
# Temp Loss: 0.211498
#
# Epoch: 42, Train Loss Decreased!! (0.112054-->0.106793)
# Test Loss: 0.109959
#
# Temp Loss: 0.211636
#
# Epoch: 43, Train Loss Decreased!! (0.106793-->0.102164)
# Test Loss: 0.099443
#
# Temp Loss: 0.213534
#
# Epoch: 44, Train Loss Decreased!! (0.102164-->0.096861)
# Test Loss: 0.099829
#
# Temp Loss: 0.212992
#
# Epoch: 45, Train Loss Decreased!! (0.096861-->0.091452)
# Test Loss: 0.088233
#
# Temp Loss: 0.217230
#
# Epoch: 46, Train Loss Decreased!! (0.091452-->0.085534)
# Test Loss: 0.088940
#
# Temp Loss: 0.217399
#
# Epoch: 47, Train Loss Decreased!! (0.085534-->0.080448)
# Test Loss: 0.076552
#
# Temp Loss: 0.219961
#
# Epoch: 48, Train Loss Decreased!! (0.080448-->0.073902)
# Test Loss: 0.077434
#
# Temp Loss: 0.220044
#
# Epoch: 49, Train Loss Decreased!! (0.073902-->0.068494)
# Test Loss: 0.065037
#
# Temp Loss: 0.222831
#
# Epoch: 50, Train Loss Decreased!! (0.068494-->0.062663)
# Test Loss: 0.066212
#
# Temp Loss: 0.223059
#
# Epoch: 51, Train Loss Decreased!! (0.062663-->0.057153)
# Test Loss: 0.053731
#
# Temp Loss: 0.225226
#
# Epoch: 52, Train Loss Decreased!! (0.057153-->0.051206)
# Test Loss: 0.054147
#
# Temp Loss: 0.225077
#
# Epoch: 53, Train Loss Decreased!! (0.051206-->0.047035)
# Test Loss: 0.044162
#
# Temp Loss: 0.229335
#
# Epoch: 54, Train Loss Decreased!! (0.047035-->0.041969)
# Test Loss: 0.044964
#
# Temp Loss: 0.229292
#
# Epoch: 55, Train Loss Decreased!! (0.041969-->0.037841)
# Test Loss: 0.034569
#
# Temp Loss: 0.232220
#
# Epoch: 56, Train Loss Decreased!! (0.037841-->0.032862)
# Test Loss: 0.035042
#
# Temp Loss: 0.232211
#
# Epoch: 57, Train Loss Decreased!! (0.032862-->0.029694)
# Test Loss: 0.027038
#
# Temp Loss: 0.235560
#
# Epoch: 58, Train Loss Decreased!! (0.029694-->0.025787)
# Test Loss: 0.027946
#
# Temp Loss: 0.235390
#
# Epoch: 59, Train Loss Decreased!! (0.025787-->0.022808)
# Test Loss: 0.020500
#
# Temp Loss: 0.239971
#
# Epoch: 60, Train Loss Decreased!! (0.022808-->0.019589)
# Test Loss: 0.021723
#
# Temp Loss: 0.239635
#
# Epoch: 61, Train Loss Decreased!! (0.019589-->0.017323)
# Test Loss: 0.015232
#
# Temp Loss: 0.243585
#
# Epoch: 62, Train Loss Decreased!! (0.017323-->0.014597)
# Test Loss: 0.016183
#
# Temp Loss: 0.242986
#
# Epoch: 63, Train Loss Decreased!! (0.014597-->0.012973)
# Test Loss: 0.011373
#
# Temp Loss: 0.246140
#
# Epoch: 64, Train Loss Decreased!! (0.012973-->0.010955)
# Test Loss: 0.012322
#
# Temp Loss: 0.245444
#
# Epoch: 65, Train Loss Decreased!! (0.010955-->0.009684)
# Test Loss: 0.008648
#
# Temp Loss: 0.247992
#
# Epoch: 66, Train Loss Decreased!! (0.009684-->0.008381)
# Test Loss: 0.009588
#
# Temp Loss: 0.247119
#
# Epoch: 67, Train Loss Decreased!! (0.008381-->0.007475)
# Test Loss: 0.006797
#
# Temp Loss: 0.249959
#
# Epoch: 68, Train Loss Decreased!! (0.007475-->0.006736)
# Test Loss: 0.007800
#
# Temp Loss: 0.249182
#
# Epoch: 69, Train Loss Decreased!! (0.006736-->0.006155)
# Test Loss: 0.005524
#
# Temp Loss: 0.251094
#
# Epoch: 70, Train Loss Decreased!! (0.006155-->0.005574)
# Test Loss: 0.006629
#
# Temp Loss: 0.250169
#
# Epoch: 71, Train Loss Decreased!! (0.005574-->0.005124)
# Test Loss: 0.004707
#
# Temp Loss: 0.251156
#
# Epoch: 72, Train Loss Decreased!! (0.005124-->0.004804)
# Test Loss: 0.005816
#
# Temp Loss: 0.250136
#
# Epoch: 73, Train Loss Decreased!! (0.004804-->0.004437)
# Test Loss: 0.004026
#
# Temp Loss: 0.252089
#
# Epoch: 74, Train Loss Decreased!! (0.004437-->0.004249)
# Test Loss: 0.005216
#
# Temp Loss: 0.251007
#
# Epoch: 75, Train Loss Decreased!! (0.004249-->0.003952)
# Test Loss: 0.003611
#
# Temp Loss: 0.252253
#
# Epoch: 76, Train Loss Decreased!! (0.003952-->0.003830)
# Test Loss: 0.004680
#
# Temp Loss: 0.251132
#
# Epoch: 77, Train Loss Decreased!! (0.003830-->0.003562)
# Test Loss: 0.003302
#
# Temp Loss: 0.252586
#
# Epoch: 78, Train Loss Decreased!! (0.003562-->0.003490)
# Test Loss: 0.004291
#
# Temp Loss: 0.251406
#
# Epoch: 79, Train Loss Decreased!! (0.003490-->0.003276)
# Test Loss: 0.002880
#
# Temp Loss: 0.252864
#
# Epoch: 80, Train Loss Decreased!! (0.003276-->0.003101)
# Test Loss: 0.003870
#
# Temp Loss: 0.251770
#
# Epoch: 81, Train Loss Decreased!! (0.003101-->0.002931)
# Test Loss: 0.002765
#
# Temp Loss: 0.253200
#
# Test Loss: 0.003928
#
# Temp Loss: 0.251936
#
# Epoch: 83, Train Loss Decreased!! (0.002931-->0.002775)
# Test Loss: 0.002609
#
# Temp Loss: 0.253134
#
# Test Loss: 0.003536
#
# Temp Loss: 0.251626
#
# Epoch: 85, Train Loss Decreased!! (0.002775-->0.002592)
# Test Loss: 0.002466
#
# Temp Loss: 0.253585
#
# Test Loss: 0.003405
#
# Temp Loss: 0.252085
#
# Epoch: 87, Train Loss Decreased!! (0.002592-->0.002472)
# Test Loss: 0.002310
#
# Temp Loss: 0.253005
#
# Epoch: 88, Train Loss Decreased!! (0.002472-->0.002471)
# Test Loss: 0.003230
#
# Temp Loss: 0.251517
#
# Epoch: 89, Train Loss Decreased!! (0.002471-->0.002332)
# Test Loss: 0.002091
#
# Temp Loss: 0.253755
#
# Epoch: 90, Train Loss Decreased!! (0.002332-->0.002311)
# Test Loss: 0.002982
#
# Temp Loss: 0.252032
#
# Epoch: 91, Train Loss Decreased!! (0.002311-->0.002196)
# Test Loss: 0.001994
#
# Temp Loss: 0.253404
#
# Test Loss: 0.002834
#
# Temp Loss: 0.251785
#
# Epoch: 93, Train Loss Decreased!! (0.002196-->0.002018)
# Test Loss: 0.001796
#
# Temp Loss: 0.253389
#
# Epoch: 94, Train Loss Decreased!! (0.002018-->0.001974)
# Test Loss: 0.002617
#
# Temp Loss: 0.251775
#
# Epoch: 95, Train Loss Decreased!! (0.001974-->0.001939)
# Test Loss: 0.001817
#
# Temp Loss: 0.253577
#
# Test Loss: 0.002670
#
# Temp Loss: 0.251742
#
# Epoch: 97, Train Loss Decreased!! (0.001939-->0.001891)
# Test Loss: 0.001738
#
# Temp Loss: 0.253780
#
# Test Loss: 0.002648
#
# Temp Loss: 0.251819
#
# Epoch: 99, Train Loss Decreased!! (0.001891-->0.001850)
# Test Loss: 0.001672
#
# Temp Loss: 0.253728
# 100%|██████████| 5/5 [04:26<00:00, 53.29s/it]
# Test Loss: 0.002592
#
# Temp Loss: 0.251629
#
# ----------------------------------------------------

# %%
train_losses_mat = np.zeros((nRuns,n_epochs+1))
test_losses_mat = np.zeros((nRuns,n_epochs+1))
temp_losses_mat = np.zeros((nRuns,n_epochs+1))

train_expected_losses_mat = np.zeros((nRuns,n_epochs+1))

test_expected_losses_mat = np.zeros((nRuns,n_epochs+1))
test_surprise_losses_mat = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    train_losses_mat[cntr] = train_losses[cntr]
    test_losses_mat[cntr] = test_losses[cntr]
    temp_losses_mat[cntr] = temp_losses[cntr]
    
    train_expected_losses_mat[cntr] = train_expected_rec_losses[cntr]
    
    test_expected_losses_mat[cntr] = test_expected_rec_losses[cntr]
    test_surprise_losses_mat[cntr] = test_surprise_rec_losses[cntr]

# %%
train_losses_mean = np.mean(train_losses_mat,axis=0)
test_losses_mean = np.mean(test_losses_mat,axis=0)
temp_losses_mean = np.mean(temp_losses_mat,axis=0)

train_expected_losses_mean = np.mean(train_expected_losses_mat,axis=0)

test_expected_losses_mean = np.mean(test_expected_losses_mat,axis=0)
test_surprise_losses_mean = np.mean(test_surprise_losses_mat,axis=0)

# %%
train_losses_std = np.std(train_losses_mat,axis=0)
test_losses_std = np.std(test_losses_mat,axis=0)
temp_losses_std = np.std(test_losses_mat,axis=0)

train_expected_losses_std = np.std(train_expected_losses_mat,axis=0)

test_expected_losses_std = np.std(test_expected_losses_mat,axis=0)
test_surprise_losses_std = np.std(test_surprise_losses_mat,axis=0)

# %%
train_expected_losses_mean[0] = train_losses_mean[0]

# %%
f = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.errorbar(np.arange(n_epochs+1),train_losses_mean,yerr=train_losses_std)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,2)
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.subplot(2,2,3)
plt.errorbar(np.arange(n_epochs+1),test_losses_mean,yerr=test_losses_std)
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,4)
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
# kk=4
# a = np.unique(allStatesTest[kk][:,0])
# b = np.unique(allStatesTrain[kk][:,0])
# len(np.intersect1d(a,b))

# %% [markdown]
# ### Representational Analyses

# %% [markdown]
# #### RNN Names

# %%
rnn_names = ['L4','L23','L56','H4','H23','H56']

# %%
# analyses_train_loader = {}

# %%
# for cntr in range(nRuns):
#     analyses_train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
#                                            batch_size,shuffle=False)

# %% [markdown]
# #### Pass data and store activations

# %%
def pass_data_store_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        activations_hidden_L23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_L4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_L56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_hidden_H23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_H4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_H56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_out_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
        for e in tqdm(range(n_epochs+1)):

            cnt = 0

            ## Load model
            model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr],task='lattice')
            model[cntr].to(device)
            model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
            model[cntr].eval()

            ## Pass clean samples
            for data, f_target, lastEvent, surpriseBinary in loader[cntr]:

                if train_on_gpu:
                    data, f_targetC = data.float().cuda(), f_target.float().cuda()
                else: data, f_targetC = data.float(), f_target.float()

                target = f_target

                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                ## Collect activations  
                act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                for i in range(batch_size):
                    if i < len(data):
                        label = target.data[i]

                        activations_hidden_L23_np[cntr][e,cnt] = act_hidden_L23[i]
                        activations_hidden_L4_np[cntr][e,cnt] = act_hidden_L4[i]
                        activations_hidden_L56_np[cntr][e,cnt] = act_hidden_L56[i]

                        activations_hidden_H23_np[cntr][e,cnt] = act_hidden_H23[i]
                        activations_hidden_H4_np[cntr][e,cnt] = act_hidden_H4[i]
                        activations_hidden_H56_np[cntr][e,cnt] = act_hidden_H56[i]

                        activations_out_np[cntr][e,cnt] = output_pred[i]

                        cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# (L23_train,L4_train,L56_train,
#  H23_train,H4_train,H56_train,), out_train = pass_data_store_activations(analyses_train_loader, nTrain)

# %%
(L23_test,L4_test,L56_test,
 H23_test,H4_test,H56_test), out_test = pass_data_store_activations(test_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:08<00:00, 11.69it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.87it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.73it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.64it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.74it/s]

# %%
(L23_temp,L4_temp,L56_temp,
 H23_temp,H4_temp,H56_temp), out_temp = pass_data_store_activations(test_temp_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:08<00:00, 11.73it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.56it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.40it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.70it/s]
# 100%|██████████| 101/101 [00:08<00:00, 11.68it/s]

# %% [markdown]
# #### PCA for RNNs

# %%
def repsPCA(rnnActs):
    nEpochs, nSeqs, nRolls, nNeurons = rnnActs.shape
    pca_dict = {}
    nSamps = nSeqs*nRolls
    dimPCA = min(nNeurons,nSamps)
    repsR_transformed = np.zeros((nEpochs,nSamps,dimPCA))
    
    for ep in tqdm(range(nEpochs)):
        
        reps = rnnActs[ep]
        
        ## reshape
        repsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        for ii in range(nSeqs):
            for jj in range(nRolls):
                repsR[cnt] = reps[ii,jj]
                cnt += 1
        ## PCA
        rnnPCA = PCA()
        repsR_transformed[ep] = rnnPCA.fit_transform(repsR)
        pca_dict[str(ep)] = rnnPCA
        
    return repsR_transformed, pca_dict

# %%
L23pca_train = {}
L4pca_train = {}
L56pca_train = {}

H23pca_train = {}
H4pca_train = {}
H56pca_train = {}

L23pca_test = {}
L4pca_test = {}
L56pca_test = {}

H23pca_test = {}
H4pca_test = {}
H56pca_test = {}

L23pca_temp = {}
L4pca_temp = {}
L56pca_temp = {}

H23pca_temp = {}
H4pca_temp = {}
H56pca_temp = {}

# %%
# for cntr in range(nRuns):
#     L23pca_train[cntr], _ = repsPCA(L23_train[cntr])
#     L4pca_train[cntr], _ = repsPCA(L4_train[cntr])
#     L56pca_train[cntr], _ = repsPCA(L56_train[cntr])

#     H23pca_train[cntr], _ = repsPCA(H23_train[cntr])
#     H4pca_train[cntr], _ = repsPCA(H4_train[cntr])
#     H56pca_train[cntr], _ = repsPCA(H56_train[cntr])

# %%
for cntr in range(nRuns):
    L23pca_test[cntr], _ = repsPCA(L23_test[cntr])
    L4pca_test[cntr], _ = repsPCA(L4_test[cntr])
    L56pca_test[cntr], _ = repsPCA(L56_test[cntr])

    H23pca_test[cntr], _ = repsPCA(H23_test[cntr])
    H4pca_test[cntr], _ = repsPCA(H4_test[cntr])
    H56pca_test[cntr], _ = repsPCA(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 142.16it/s]
# 100%|██████████| 101/101 [00:00<00:00, 400.27it/s]
# 100%|██████████| 101/101 [00:00<00:00, 178.60it/s]
# 100%|██████████| 101/101 [00:00<00:00, 158.20it/s]
# 100%|██████████| 101/101 [00:00<00:00, 372.32it/s]
# 100%|██████████| 101/101 [00:00<00:00, 188.17it/s]
# 100%|██████████| 101/101 [00:00<00:00, 151.25it/s]
# 100%|██████████| 101/101 [00:00<00:00, 383.46it/s]
# 100%|██████████| 101/101 [00:00<00:00, 193.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 154.37it/s]
# 100%|██████████| 101/101 [00:00<00:00, 372.31it/s]
# 100%|██████████| 101/101 [00:00<00:00, 186.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 151.03it/s]
# 100%|██████████| 101/101 [00:00<00:00, 406.70it/s]
# 100%|██████████| 101/101 [00:00<00:00, 187.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 154.61it/s]
# 100%|██████████| 101/101 [00:00<00:00, 390.94it/s]
# 100%|██████████| 101/101 [00:00<00:00, 187.89it/s]
# 100%|██████████| 101/101 [00:00<00:00, 163.60it/s]
# 100%|██████████| 101/101 [00:00<00:00, 379.24it/s]
# 100%|██████████| 101/101 [00:00<00:00, 194.75it/s]
# 100%|██████████| 101/101 [00:00<00:00, 152.75it/s]
# 100%|██████████| 101/101 [00:00<00:00, 397.13it/s]
# 100%|██████████| 101/101 [00:00<00:00, 188.94it/s]
# 100%|██████████| 101/101 [00:00<00:00, 162.55it/s]
# 100%|██████████| 101/101 [00:00<00:00, 372.32it/s]
# 100%|██████████| 101/101 [00:00<00:00, 196.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 151.76it/s]
# 100%|██████████| 101/101 [00:00<00:00, 380.71it/s]
# 100%|██████████| 101/101 [00:00<00:00, 192.53it/s]

# %%
for cntr in range(nRuns):
    L23pca_temp[cntr], _ = repsPCA(L23_temp[cntr])
    L4pca_temp[cntr], _ = repsPCA(L4_temp[cntr])
    L56pca_temp[cntr], _ = repsPCA(L56_temp[cntr])

    H23pca_temp[cntr], _ = repsPCA(H23_temp[cntr])
    H4pca_temp[cntr], _ = repsPCA(H4_temp[cntr])
    H56pca_temp[cntr], _ = repsPCA(H56_temp[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 159.68it/s]
# 100%|██████████| 101/101 [00:00<00:00, 403.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 190.36it/s]
# 100%|██████████| 101/101 [00:00<00:00, 155.32it/s]
# 100%|██████████| 101/101 [00:00<00:00, 406.77it/s]
# 100%|██████████| 101/101 [00:00<00:00, 195.68it/s]
# 100%|██████████| 101/101 [00:00<00:00, 150.45it/s]
# 100%|██████████| 101/101 [00:00<00:00, 416.75it/s]
# 100%|██████████| 101/101 [00:00<00:00, 189.24it/s]
# 100%|██████████| 101/101 [00:00<00:00, 160.23it/s]
# 100%|██████████| 101/101 [00:00<00:00, 368.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 198.18it/s]
# 100%|██████████| 101/101 [00:00<00:00, 154.13it/s]
# 100%|██████████| 101/101 [00:00<00:00, 379.29it/s]
# 100%|██████████| 101/101 [00:00<00:00, 189.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 159.22it/s]
# 100%|██████████| 101/101 [00:00<00:00, 392.46it/s]
# 100%|██████████| 101/101 [00:00<00:00, 195.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 149.81it/s]
# 100%|██████████| 101/101 [00:00<00:00, 405.04it/s]
# 100%|██████████| 101/101 [00:00<00:00, 187.86it/s]
# 100%|██████████| 101/101 [00:00<00:00, 159.72it/s]
# 100%|██████████| 101/101 [00:00<00:00, 376.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 195.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 152.06it/s]
# 100%|██████████| 101/101 [00:00<00:00, 397.14it/s]
# 100%|██████████| 101/101 [00:00<00:00, 200.53it/s]
# 100%|██████████| 101/101 [00:00<00:00, 158.72it/s]
# 100%|██████████| 101/101 [00:00<00:00, 408.35it/s]
# 100%|██████████| 101/101 [00:00<00:00, 186.84it/s]

# %% [markdown]
# #### Labels, etc.

# %%
allStatesLabelsTrain = {}
allStatesLabelsTest = {}
allStatesLabelsTestTemp = {}

actionsLabelsTrain = {}
actionsLabelsTest = {}
actionsLabelsTestTemp = {}

# %%
def allStatesLabels(allStates,latLabs):
    nSamps, nSeqs, nDim = allStates.shape
    labels = np.zeros((nSamps,nSeqs),dtype=int)
    for ii in range(nSamps):
        for jj in range(nSeqs):
            labels[ii,jj] = np.where((latLabs[:,None] == allStates[ii,jj]).all(-1).any(-1)==1)[0][0]
    return labels

# %%
for cntr in range(nRuns):
#     allStatesLabelsTrain[cntr] = allStatesLabels(allStatesTrain[cntr],lattice_labels)
    allStatesLabelsTest[cntr] = allStatesLabels(allStatesTest[cntr],lattice_labels)
    allStatesLabelsTestTemp[cntr] = allStatesLabels(allStatesTestTemp[cntr],lattice_labels)
    
#     actionsLabelsTrain[cntr] = np.argmax(actionsTrain[cntr],-1)
    actionsLabelsTest[cntr] = np.argmax(actionsTest[cntr],-1)
    actionsLabelsTestTemp[cntr] = np.argmax(actionsTestTemp[cntr],-1)

# %%
# idxs0_train = np.array([6*x for x in range(nTrain)])
# idxs1_train = idxs0_train + 1
# idxs2_train = idxs0_train + 2
# idxs3_train = idxs0_train + 3
# idxs4_train = idxs0_train + 4
# idxs5_train = idxs0_train + 5

# %%
idxs0_test = np.array([6*x for x in range(nTest)])
idxs1_test = idxs0_test + 1
idxs2_test = idxs0_test + 2
idxs3_test = idxs0_test + 3
idxs4_test = idxs0_test + 4
idxs5_test = idxs0_test + 5

# %%
idxs_test_surp = np.sort(np.hstack((idxs4_test,idxs5_test)))

# %%
pos_test = np.tile(np.arange(nSteps),nTest).ravel()

# %% [markdown]
# #### Plots

# %% [markdown]
# #### Coloured by states

# %%
# cnt = 0
# ep = 50
# ix = idxs5_test
# seq = 3 ##0-3
# c = allStatesLabelsTest[cnt][:,seq] + 1
# s = 10#1*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = allStatesTest[cnt][:,seq,xy] + 0.5
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %% [markdown]
# #### Coloured by distance from lattice centre

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 1
# ep = -1

# ix = idxs5_test
# seq = 3 ##0-3
# xy = 1 ##0/1

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# s = 10#5*c
# colmap = 'copper'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %% [markdown]
# #### 3D plot

# %%
# cnt = 1
# ix = idxs0_test
# seq = 0

# c = norm(allStatesTest[cnt][:,seq],axis=-1)
# c = np.repeat(c,n_epochs+1,0)
# s = 10#5*c

# sub = 1
# colmap = 'copper'

# Zs = np.repeat(np.arange(n_epochs+1).reshape(-1,1),nTest,1)

# %%
# fig = plt.figure(figsize=(17,12))

# ax = fig.add_subplot(2, 3, 1, projection='3d')
# ax.scatter3D(L4pca_test[cnt][:,ix,0].ravel()[::sub],L4pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 2, projection='3d')
# ax.scatter3D(L23pca_test[cnt][:,ix,0].ravel()[::sub],L23pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 3, projection='3d')
# ax.scatter3D(L56pca_test[cnt][:,ix,0].ravel()[::sub],L56pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 4, projection='3d')
# ax.scatter3D(H4pca_test[cnt][:,ix,0].ravel()[::sub],H4pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 5, projection='3d')
# ax.scatter3D(H23pca_test[cnt][:,ix,0].ravel()[::sub],H23pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# ax = fig.add_subplot(2, 3, 6, projection='3d')
# ax.scatter3D(H56pca_test[cnt][:,ix,0].ravel()[::sub],H56pca_test[cnt][:,ix,1].ravel()[::sub],
#              Zs.ravel()[::sub], c=c.ravel()[::sub], s=s, cmap=colmap);

# plt.show()

# %% [markdown]
# #### Coloured by actions

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 3 ##0-3
# step = 5
# c = actionsLabelsTest[cnt][:,step] + 1
# s = 5*c
# colmap='Set1'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 2 ##0-3
# step = 5
# c = (actionsLabelsTest[cnt][:,step]%2)*1. + 1
# s = 5*c
# colmap='Dark2'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs5_test
# seq = 2 ##0-3
# step = 5
# c = (actionsLabelsTest[cnt][:,step]>1)*1. + 1
# s = 5*c
# colmap='Dark2'

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap=colmap)
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = 50
# ix = idxs4_test
# seq = 2 ##0-3
# step = 3
# c = allStatesLabelsTest[cnt][:,seq]
# s = 1*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H5/6')

# %%
# cnt = 0
# ep = -1
# ix = idxs_surp
# seq = -1 ##0-3
# step = 4
# # c = actionsLabelsTest[cnt][:,step]
# # s = 5*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             cmap='Purples')
# plt.title('Layer H5/6')

# %% [markdown]
# #### Supervised Decoding

# %% [markdown]
# #### Position

# %%
def repsDecodeSupervisedPosition(rnnActs,labels,clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    nClasses = 6
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
testPCs = {}
tempPCs = {}

contextPCs_sub = {}

# %%
for cntr in range(nRuns):
    testPCs[cntr] = (L4pca_test[cntr],L23pca_test[cntr],L56pca_test[cntr],
                     H4pca_test[cntr],H23pca_test[cntr],H56pca_test[cntr])
    tempPCs[cntr] = (L4pca_temp[cntr],L23pca_temp[cntr],L56pca_temp[cntr],
                     H4pca_temp[cntr],H23pca_temp[cntr],H56pca_temp[cntr])
    
    for rnnNo in range(len(rnn_names)):
        contextPCs_sub[cntr,rnnNo] = np.hstack((testPCs[cntr][rnnNo][:,idxs_test_surp,:],
                                                tempPCs[cntr][rnnNo][:,idxs_test_surp,:]))

# %%
L4posPC = {}
L23posPC = {}
L56posPC = {}
H4posPC = {}
H23posPC = {}
H56posPC = {}

# %%
dims23 = np.array([1,2,4,8,16,32,64,80])
dims4 = np.array([1,2,4,8,16,32])
dims56 = np.array([1,2,4,8,16,32,64])

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][1][:,:,:d],pos_test)
        H23posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][4][:,:,:d],pos_test)
    
    for d in dims4:
        L4posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][0][:,:,:d],pos_test)
        H4posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][3][:,:,:d],pos_test)
        
    for d in dims56:
        L56posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][2][:,:,:d],pos_test)      
        H56posPC[cntr,d], _ = repsDecodeSupervisedPosition(testPCs[cntr][5][:,:,:d],pos_test)
# Out:
# 100%|██████████| 5/5 [05:41<00:00, 68.30s/it]

# %%
preds_L23posPC = {}
preds_L4posPC = {}
preds_L56posPC = {}

preds_H23posPC = {}
preds_H4posPC = {}
preds_H56posPC = {}

# %%
accs_L23posPC = {}
accs_L4posPC = {}
accs_L56posPC = {}

accs_H23posPC = {}
accs_H4posPC = {}
accs_H56posPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23posPC[cntr,d,ep] = np.argmax(L23posPC[cntr,d][ep],axis=-1)
            preds_H23posPC[cntr,d,ep] = np.argmax(H23posPC[cntr,d][ep],axis=-1)
            
            accs_L23posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L23posPC[cntr,d,ep])
            accs_H23posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H23posPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4posPC[cntr,d,ep] = np.argmax(L4posPC[cntr,d][ep],axis=-1)
            preds_H4posPC[cntr,d,ep] = np.argmax(H4posPC[cntr,d][ep],axis=-1)
            
            accs_L4posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L4posPC[cntr,d,ep])
            accs_H4posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H4posPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56posPC[cntr,d,ep] = np.argmax(L56posPC[cntr,d][ep],axis=-1)
            preds_H56posPC[cntr,d,ep] = np.argmax(H56posPC[cntr,d][ep],axis=-1)
            
            accs_L56posPC[cntr,d,ep] = accuracy_score(pos_test,preds_L56posPC[cntr,d,ep])
            accs_H56posPC[cntr,d,ep] = accuracy_score(pos_test,preds_H56posPC[cntr,d,ep])

# %%
tensor_accs_L23posPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4posPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56posPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23posPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4posPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56posPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23posPC[ii,jj,kk] = accs_L23posPC[ii,d,kk]
            tensor_accs_H23posPC[ii,jj,kk] = accs_H23posPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4posPC[ii,jj,kk] = accs_L4posPC[ii,d,kk]
            tensor_accs_H4posPC[ii,jj,kk] = accs_H4posPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56posPC[ii,jj,kk] = accs_L56posPC[ii,d,kk]            
            tensor_accs_H56posPC[ii,jj,kk] = accs_H56posPC[ii,d,kk]

# %%
mean_accs_L4posPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23posPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56posPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4posPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23posPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56posPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4posPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23posPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56posPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4posPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23posPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56posPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23posPC[dd,ep] = np.mean(tensor_accs_L23posPC[:,dd,ep])
        mean_accs_H23posPC[dd,ep] = np.mean(tensor_accs_H23posPC[:,dd,ep])
        
        std_accs_L23posPC[dd,ep] = np.var(tensor_accs_L23posPC[:,dd,ep])
        std_accs_H23posPC[dd,ep] = np.var(tensor_accs_H23posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4posPC[dd,ep] = np.mean(tensor_accs_L4posPC[:,dd,ep])
        mean_accs_H4posPC[dd,ep] = np.mean(tensor_accs_H4posPC[:,dd,ep])
        
        std_accs_L4posPC[dd,ep] = np.var(tensor_accs_L4posPC[:,dd,ep])
        std_accs_H4posPC[dd,ep] = np.var(tensor_accs_H4posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56posPC[dd,ep] = np.mean(tensor_accs_L56posPC[:,dd,ep])
        mean_accs_H56posPC[dd,ep] = np.mean(tensor_accs_H56posPC[:,dd,ep])
        
        std_accs_L56posPC[dd,ep] = np.var(tensor_accs_L56posPC[:,dd,ep])
        std_accs_H56posPC[dd,ep] = np.var(tensor_accs_H56posPC[:,dd,ep])

# %%
ffpos = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Position Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,0],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,0],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,0],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,0],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,0],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,0],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Position Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,1],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,1],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,1],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,1],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,1],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,1],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Position Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,-1],yerr=std_accs_L4posPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,-1],yerr=std_accs_L23posPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,-1],yerr=std_accs_L56posPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,-1],yerr=std_accs_H4posPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,-1],yerr=std_accs_H23posPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,-1],yerr=std_accs_H56posPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
ffpos_epoch = plt.figure(figsize=(15,5))

plt.subplot(231)
plt.title('Position Decoding - 1D')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[0],yerr=std_accs_L4posPC[0],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[0],yerr=std_accs_L23posPC[0],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[0],yerr=std_accs_L56posPC[0],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[0],yerr=std_accs_H4posPC[0],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[0],yerr=std_accs_H23posPC[0],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[0],yerr=std_accs_H56posPC[0],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.subplot(232)
plt.title('Position Decoding - 2D')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[1],yerr=std_accs_L4posPC[1],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[1],yerr=std_accs_L23posPC[1],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[1],yerr=std_accs_L56posPC[1],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[1],yerr=std_accs_H4posPC[1],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[1],yerr=std_accs_H23posPC[1],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[1],yerr=std_accs_H56posPC[1],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.subplot(233)
plt.title('Position Decoding - Full Dim')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L4posPC[-1],yerr=std_accs_L4posPC[-1],label='L4',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L23posPC[-1],yerr=std_accs_L23posPC[-1],label='L23',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_L56posPC[-1],yerr=std_accs_L56posPC[-1],label='L56',fmt='--')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H4posPC[-1],yerr=std_accs_H4posPC[-1],label='H4',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H23posPC[-1],yerr=std_accs_H23posPC[-1],label='H23',fmt='-')
plt.errorbar(np.arange(n_epochs+1),mean_accs_H56posPC[-1],yerr=std_accs_H56posPC[-1],label='H56',fmt='-')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
# plt.legend()

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
fpos_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4posPC,0),yerr=np.var(mean_accs_L4posPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23posPC,0),yerr=np.var(mean_accs_L23posPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56posPC,0),yerr=np.var(mean_accs_L56posPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4posPC,0),yerr=np.var(mean_accs_H4posPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23posPC,0),yerr=np.var(mean_accs_H23posPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56posPC,0),yerr=np.var(mean_accs_H56posPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Position Decodability across Epochs - Canonical Microcircuit')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# #### Image ID and Surprise (only surprise position)

# %%
context_sub_surp = np.array([0]*2*nTest + [1]*2*nTest)

# %%
context_sub_imgIDs = {}
for cntr in range(nRuns):
    context_sub_imgIDs[cntr] = np.hstack((np.repeat(allStatesLabelsTest[cntr][:,2],nRepeats),
                                          np.repeat(allStatesLabelsTestTemp[cntr][:,2],nRepeats)))

# %%
L23imgPC = {}
L4imgPC = {}
L56imgPC = {}

H23imgPC = {}
H4imgPC = {}
H56imgPC = {}

L23surpPC = {}
L4surpPC = {}
L56surpPC = {}

H23surpPC = {}
H4surpPC = {}
H56surpPC = {}

# %%
def repsDecodeSupervisedContext(rnnActs,labels,decodeType='surprise',clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'surprise':
        nClasses = 2
    elif decodeType == 'imageID':
        nClasses = nStates
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        
        L23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][:,:,:d],context_sub_surp,decodeType='surprise')
        H23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][:,:,:d],context_sub_surp,decodeType='surprise')
        
    for d in dims4:
        L4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        
        L4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][:,:,:d],context_sub_surp,decodeType='surprise')
        H4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][:,:,:d],context_sub_surp,decodeType='surprise')
    for d in dims56:

        ## Context Sub, ImageID
        L56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')
        H56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][:,:,:d],context_sub_imgIDs[cntr],decodeType='imageID')

        ## Context Sub, Surprise
        L56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][:,:,:d],context_sub_surp,decodeType='surprise')
        H56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][:,:,:d],context_sub_surp,decodeType='surprise')
# Out:
# 100%|██████████| 5/5 [14:22<00:00, 172.43s/it]

# %%
preds_L23imgPC = {}
preds_L4imgPC = {}
preds_L56imgPC = {}

preds_H23imgPC = {}
preds_H4imgPC = {}
preds_H56imgPC = {}

preds_L23surpPC = {}
preds_L4surpPC = {}
preds_L56surpPC = {}

preds_H23surpPC = {}
preds_H4surpPC = {}
preds_H56surpPC = {}

# %%
accs_L23imgPC = {}
accs_L4imgPC = {}
accs_L56imgPC = {}

accs_H23imgPC = {}
accs_H4imgPC = {}
accs_H56imgPC = {}

accs_L23surpPC = {}
accs_L4surpPC = {}
accs_L56surpPC = {}

accs_H23surpPC = {}
accs_H4surpPC = {}
accs_H56surpPC = {}

# %%
for cntr in range(nRuns):
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23imgPC[cntr,d,ep] = np.argmax(L23imgPC[cntr,d][ep],axis=-1)
            preds_H23imgPC[cntr,d,ep] = np.argmax(H23imgPC[cntr,d][ep],axis=-1)
            
            preds_L23surpPC[cntr,d,ep] = np.argmax(L23surpPC[cntr,d][ep],axis=-1)
            preds_H23surpPC[cntr,d,ep] = np.argmax(H23surpPC[cntr,d][ep],axis=-1)
            
            accs_L23imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L23imgPC[cntr,d,ep])
            accs_H23imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H23imgPC[cntr,d,ep])
            
            accs_L23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L23surpPC[cntr,d,ep])
            accs_H23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H23surpPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4imgPC[cntr,d,ep] = np.argmax(L4imgPC[cntr,d][ep],axis=-1)
            preds_H4imgPC[cntr,d,ep] = np.argmax(H4imgPC[cntr,d][ep],axis=-1)
            
            preds_L4surpPC[cntr,d,ep] = np.argmax(L4surpPC[cntr,d][ep],axis=-1)
            preds_H4surpPC[cntr,d,ep] = np.argmax(H4surpPC[cntr,d][ep],axis=-1)
            
            accs_L4imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L4imgPC[cntr,d,ep])
            accs_H4imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H4imgPC[cntr,d,ep])
            
            accs_L4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L4surpPC[cntr,d,ep])
            accs_H4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H4surpPC[cntr,d,ep])
                
        for d in dims56:        
            preds_L56imgPC[cntr,d,ep] = np.argmax(L56imgPC[cntr,d][ep],axis=-1)
            preds_H56imgPC[cntr,d,ep] = np.argmax(H56imgPC[cntr,d][ep],axis=-1)
            
            preds_L56surpPC[cntr,d,ep] = np.argmax(L56surpPC[cntr,d][ep],axis=-1)
            preds_H56surpPC[cntr,d,ep] = np.argmax(H56surpPC[cntr,d][ep],axis=-1)
            
            accs_L56imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_L56imgPC[cntr,d,ep])
            accs_H56imgPC[cntr,d,ep] = accuracy_score(context_sub_imgIDs[cntr],preds_H56imgPC[cntr,d,ep])
            
            accs_L56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L56surpPC[cntr,d,ep])
            accs_H56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H56surpPC[cntr,d,ep])

# %%
tensor_accs_L23imgPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4imgPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56imgPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23imgPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4imgPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56imgPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_L23surpPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4surpPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56surpPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23surpPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4surpPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56surpPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23imgPC[ii,jj,kk] = accs_L23imgPC[ii,d,kk]
            tensor_accs_H23imgPC[ii,jj,kk] = accs_H23imgPC[ii,d,kk]
            
            tensor_accs_L23surpPC[ii,jj,kk] = accs_L23surpPC[ii,d,kk]
            tensor_accs_H23surpPC[ii,jj,kk] = accs_H23surpPC[ii,d,kk]
            
        
        for jj,d in enumerate(dims4):
            tensor_accs_L4imgPC[ii,jj,kk] = accs_L4imgPC[ii,d,kk]
            tensor_accs_H4imgPC[ii,jj,kk] = accs_H4imgPC[ii,d,kk]
            
            tensor_accs_L4surpPC[ii,jj,kk] = accs_L4surpPC[ii,d,kk]
            tensor_accs_H4surpPC[ii,jj,kk] = accs_H4surpPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56imgPC[ii,jj,kk] = accs_L56imgPC[ii,d,kk]
            tensor_accs_H56imgPC[ii,jj,kk] = accs_H56imgPC[ii,d,kk]

            tensor_accs_L56surpPC[ii,jj,kk] = accs_L56surpPC[ii,d,kk]
            tensor_accs_H56surpPC[ii,jj,kk] = accs_H56surpPC[ii,d,kk]

# %%
mean_accs_L4imgPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23imgPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56imgPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4imgPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23imgPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56imgPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_L4surpPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23surpPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56surpPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4surpPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23surpPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56surpPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4imgPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23imgPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56imgPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4imgPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23imgPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56imgPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4surpPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23surpPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56surpPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4surpPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23surpPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56surpPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dims in enumerate(dims23):
        mean_accs_L23imgPC[dd,ep] = np.mean(tensor_accs_L23imgPC[:,dd,ep])
        mean_accs_H23imgPC[dd,ep] = np.mean(tensor_accs_H23imgPC[:,dd,ep])
        
        std_accs_L23imgPC[dd,ep] = np.var(tensor_accs_L23imgPC[:,dd,ep])
        std_accs_H23imgPC[dd,ep] = np.var(tensor_accs_H23imgPC[:,dd,ep])
        
        mean_accs_L23surpPC[dd,ep] = np.mean(tensor_accs_L23surpPC[:,dd,ep])
        mean_accs_H23surpPC[dd,ep] = np.mean(tensor_accs_H23surpPC[:,dd,ep])
        
        std_accs_L23surpPC[dd,ep] = np.var(tensor_accs_L23surpPC[:,dd,ep])
        std_accs_H23surpPC[dd,ep] = np.var(tensor_accs_H23surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims4):
        mean_accs_L4imgPC[dd,ep] = np.mean(tensor_accs_L4imgPC[:,dd,ep])
        mean_accs_H4imgPC[dd,ep] = np.mean(tensor_accs_H4imgPC[:,dd,ep])
        
        std_accs_L4imgPC[dd,ep] = np.var(tensor_accs_L4imgPC[:,dd,ep])
        std_accs_H4imgPC[dd,ep] = np.var(tensor_accs_H4imgPC[:,dd,ep])
        
        mean_accs_L4surpPC[dd,ep] = np.mean(tensor_accs_L4surpPC[:,dd,ep])
        mean_accs_H4surpPC[dd,ep] = np.mean(tensor_accs_H4surpPC[:,dd,ep])
        
        std_accs_L4surpPC[dd,ep] = np.var(tensor_accs_L4surpPC[:,dd,ep])
        std_accs_H4surpPC[dd,ep] = np.var(tensor_accs_H4surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims56):
        mean_accs_L56imgPC[dd,ep] = np.mean(tensor_accs_L56imgPC[:,dd,ep])        
        mean_accs_H56imgPC[dd,ep] = np.mean(tensor_accs_H56imgPC[:,dd,ep])
        
        std_accs_L56imgPC[dd,ep] = np.var(tensor_accs_L56imgPC[:,dd,ep])
        std_accs_H56imgPC[dd,ep] = np.var(tensor_accs_H56imgPC[:,dd,ep])
        
        mean_accs_L56surpPC[dd,ep] = np.mean(tensor_accs_L56surpPC[:,dd,ep])
        mean_accs_H56surpPC[dd,ep] = np.mean(tensor_accs_H56surpPC[:,dd,ep])
        
        std_accs_L56surpPC[dd,ep] = np.var(tensor_accs_L56surpPC[:,dd,ep])        
        std_accs_H56surpPC[dd,ep] = np.var(tensor_accs_H56surpPC[:,dd,ep])

# %%
ffdim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Image ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,0],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,0],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,0],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,0],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,0],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,0],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Image ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,1],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,1],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,1],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,1],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,1],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,1],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Image ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,-1],yerr=std_accs_L4imgPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,-1],yerr=std_accs_L23imgPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,-1],yerr=std_accs_L56imgPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,-1],yerr=std_accs_H4imgPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,-1],yerr=std_accs_H23imgPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,-1],yerr=std_accs_H56imgPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fimg_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4imgPC,0),yerr=np.var(mean_accs_L4imgPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23imgPC,0),yerr=np.var(mean_accs_L23imgPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56imgPC,0),yerr=np.var(mean_accs_L56imgPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4imgPC,0),yerr=np.var(mean_accs_H4imgPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23imgPC,0),yerr=np.var(mean_accs_H23imgPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56imgPC,0),yerr=np.var(mean_accs_H56imgPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Image Decodability across Epochs - Canonical Microcircuit')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
ffsurp_dim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Surprise ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,0],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,0],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,0],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,0],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,0],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,0],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(132)
plt.title('Surprise ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,1],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,1],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,1],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,1],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,1],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,1],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(133)
plt.title('Surprise ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,-1],yerr=std_accs_L4surpPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,-1],yerr=std_accs_L23surpPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,-1],yerr=std_accs_L56surpPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,-1],yerr=std_accs_H4surpPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,-1],yerr=std_accs_H23surpPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,-1],yerr=std_accs_H56surpPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fsurp_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4surpPC,0),yerr=np.var(mean_accs_L4surpPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23surpPC,0),yerr=np.var(mean_accs_L23surpPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56surpPC,0),yerr=np.var(mean_accs_L56surpPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4surpPC,0),yerr=np.var(mean_accs_H4surpPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23surpPC,0),yerr=np.var(mean_accs_H23surpPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56surpPC,0),yerr=np.var(mean_accs_H56surpPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Surprise Decodability across Epochs - Canonical Microcircuit')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
np.save(pp+'preds_img_temp_L4-corticalRNN-lattice',preds_L4imgPC)
np.save(pp+'preds_img_temp_L23-corticalRNN-lattice',preds_L23imgPC)
np.save(pp+'preds_img_temp_L56-corticalRNN-lattice',preds_L56imgPC)
np.save(pp+'preds_img_temp_H4-corticalRNN-lattice',preds_H4imgPC)
np.save(pp+'preds_img_temp_H23-corticalRNN-lattice',preds_H23imgPC)
np.save(pp+'preds_img_temp_H56-corticalRNN-lattice',preds_H56imgPC)

np.save(pp+'accs_img_temp_L4-corticalRNN-lattice',accs_L4imgPC)
np.save(pp+'accs_img_temp_L23-corticalRNN-lattice',accs_L23imgPC)
np.save(pp+'accs_img_temp_L56-corticalRNN-lattice',accs_L56imgPC)
np.save(pp+'accs_img_temp_H4-corticalRNN-lattice',accs_H4imgPC)
np.save(pp+'accs_img_temp_H23-corticalRNN-lattice',accs_H23imgPC)
np.save(pp+'accs_img_temp_H56-corticalRNN-lattice',accs_H56imgPC)

# %%
np.save(pp+'preds_pos_temp_L4-corticalRNN-lattice',preds_L4posPC)
np.save(pp+'preds_pos_temp_L23-corticalRNN-lattice',preds_L23posPC)
np.save(pp+'preds_pos_temp_L56-corticalRNN-lattice',preds_L56posPC)
np.save(pp+'preds_pos_temp_H4-corticalRNN-lattice',preds_H4posPC)
np.save(pp+'preds_pos_temp_H23-corticalRNN-lattice',preds_H23posPC)
np.save(pp+'preds_pos_temp_H56-corticalRNN-lattice',preds_H56posPC)

np.save(pp+'accs_pos_temp_L4-corticalRNN-lattice',accs_L4posPC)
np.save(pp+'accs_pos_temp_L23-corticalRNN-lattice',accs_L23posPC)
np.save(pp+'accs_pos_temp_L56-corticalRNN-lattice',accs_L56posPC)
np.save(pp+'accs_pos_temp_H4-corticalRNN-lattice',accs_H4posPC)
np.save(pp+'accs_pos_temp_H23-corticalRNN-lattice',accs_H23posPC)
np.save(pp+'accs_pos_temp_H56-corticalRNN-lattice',accs_H56posPC)

# %%
np.save(pp+'preds_surp_temp_L4-corticalRNN-lattice',preds_L4surpPC)
np.save(pp+'preds_surp_temp_L23-corticalRNN-lattice',preds_L23surpPC)
np.save(pp+'preds_surp_temp_L56-corticalRNN-lattice',preds_L56surpPC)
np.save(pp+'preds_surp_temp_H4-corticalRNN-lattice',preds_H4surpPC)
np.save(pp+'preds_surp_temp_H23-corticalRNN-lattice',preds_H23surpPC)
np.save(pp+'preds_surp_temp_H56-corticalRNN-lattice',preds_H56surpPC)

np.save(pp+'accs_surp_temp_L4-corticalRNN-lattice',accs_L4surpPC)
np.save(pp+'accs_surp_temp_L23-corticalRNN-lattice',accs_L23surpPC)
np.save(pp+'accs_surp_temp_L56-corticalRNN-lattice',accs_L56surpPC)
np.save(pp+'accs_surp_temp_H4-corticalRNN-lattice',accs_H4surpPC)
np.save(pp+'accs_surp_temp_H23-corticalRNN-lattice',accs_H23surpPC)
np.save(pp+'accs_surp_temp_H56-corticalRNN-lattice',accs_H56surpPC)

# %% [markdown]
# #### Latent variable decoding

# %%
def repsDecodeSupervisedLatents(rnnActs,labels,decodeType='action',clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'action':
        nClasses = 4
    else:
        nClasses = 5
        
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
L23actPC = {}
L4actPC = {}
L56actPC = {}

H23actPC = {}
H4actPC = {}
H56actPC = {}

L23distPC = {}
L4distPC = {}
L56distPC = {}

H23distPC = {}
H4distPC = {}
H56distPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][1][:,:,:d],actionsLabelsTest[cnt].ravel())
        H23actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][4][:,:,:d],actionsLabelsTest[cnt].ravel())
    
    for d in dims4:
        L4actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][0][:,:,:d],actionsLabelsTest[cnt].ravel())
        H4actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][3][:,:,:d],actionsLabelsTest[cnt].ravel())
        
    for d in dims56:
        L56actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][2][:,:,:d],actionsLabelsTest[cnt].ravel())      
        H56actPC[cntr,d], _ = repsDecodeSupervisedLatents(testPCs[cntr][5][:,:,:d],actionsLabelsTest[cnt].ravel())
# Out:
# 100%|██████████| 5/5 [04:21<00:00, 52.26s/it]

# %%
preds_L23actPC = {}
preds_L4actPC = {}
preds_L56actPC = {}

preds_H23actPC = {}
preds_H4actPC = {}
preds_H56actPC = {}

# %%
accs_L23actPC = {}
accs_L4actPC = {}
accs_L56actPC = {}

accs_H23actPC = {}
accs_H4actPC = {}
accs_H56actPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(n_epochs+1):
        
        for d in dims23:
            preds_L23actPC[cntr,d,ep] = np.argmax(L23actPC[cntr,d][ep],axis=-1)
            preds_H23actPC[cntr,d,ep] = np.argmax(H23actPC[cntr,d][ep],axis=-1)
            
            accs_L23actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L23actPC[cntr,d,ep])
            accs_H23actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H23actPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4actPC[cntr,d,ep] = np.argmax(L4actPC[cntr,d][ep],axis=-1)
            preds_H4actPC[cntr,d,ep] = np.argmax(H4actPC[cntr,d][ep],axis=-1)
            
            accs_L4actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L4actPC[cntr,d,ep])
            accs_H4actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H4actPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56actPC[cntr,d,ep] = np.argmax(L56actPC[cntr,d][ep],axis=-1)
            preds_H56actPC[cntr,d,ep] = np.argmax(H56actPC[cntr,d][ep],axis=-1)
            
            accs_L56actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_L56actPC[cntr,d,ep])
            accs_H56actPC[cntr,d,ep] = accuracy_score(actionsLabelsTest[cnt].ravel(),preds_H56actPC[cntr,d,ep])

# %%
tensor_accs_L23actPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_L4actPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_L56actPC = np.zeros((nRuns,len(dims56),n_epochs+1))

tensor_accs_H23actPC = np.zeros((nRuns,len(dims23),n_epochs+1))
tensor_accs_H4actPC = np.zeros((nRuns,len(dims4),n_epochs+1))
tensor_accs_H56actPC = np.zeros((nRuns,len(dims56),n_epochs+1))

# %%
for ii in range(nRuns):
    
    for kk in range(n_epochs+1):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23actPC[ii,jj,kk] = accs_L23actPC[ii,d,kk]
            tensor_accs_H23actPC[ii,jj,kk] = accs_H23actPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4actPC[ii,jj,kk] = accs_L4actPC[ii,d,kk]
            tensor_accs_H4actPC[ii,jj,kk] = accs_H4actPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56actPC[ii,jj,kk] = accs_L56actPC[ii,d,kk]            
            tensor_accs_H56actPC[ii,jj,kk] = accs_H56actPC[ii,d,kk]

# %%
mean_accs_L4actPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_L23actPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_L56actPC = np.zeros((len(dims56),n_epochs+1))

mean_accs_H4actPC = np.zeros((len(dims4),n_epochs+1))
mean_accs_H23actPC = np.zeros((len(dims23),n_epochs+1))
mean_accs_H56actPC = np.zeros((len(dims56),n_epochs+1))

std_accs_L4actPC = np.zeros((len(dims4),n_epochs+1))
std_accs_L23actPC = np.zeros((len(dims23),n_epochs+1))
std_accs_L56actPC = np.zeros((len(dims56),n_epochs+1))

std_accs_H4actPC = np.zeros((len(dims4),n_epochs+1))
std_accs_H23actPC = np.zeros((len(dims23),n_epochs+1))
std_accs_H56actPC = np.zeros((len(dims56),n_epochs+1))

# %%
for ep in range(n_epochs+1):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23actPC[dd,ep] = np.mean(tensor_accs_L23actPC[:,dd,ep])
        mean_accs_H23actPC[dd,ep] = np.mean(tensor_accs_H23actPC[:,dd,ep])
        
        std_accs_L23actPC[dd,ep] = np.var(tensor_accs_L23actPC[:,dd,ep])
        std_accs_H23actPC[dd,ep] = np.var(tensor_accs_H23actPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4actPC[dd,ep] = np.mean(tensor_accs_L4actPC[:,dd,ep])
        mean_accs_H4actPC[dd,ep] = np.mean(tensor_accs_H4actPC[:,dd,ep])
        
        std_accs_L4actPC[dd,ep] = np.var(tensor_accs_L4actPC[:,dd,ep])
        std_accs_H4actPC[dd,ep] = np.var(tensor_accs_H4actPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56actPC[dd,ep] = np.mean(tensor_accs_L56actPC[:,dd,ep])
        mean_accs_H56actPC[dd,ep] = np.mean(tensor_accs_H56actPC[:,dd,ep])
        
        std_accs_L56actPC[dd,ep] = np.var(tensor_accs_L56actPC[:,dd,ep])
        std_accs_H56actPC[dd,ep] = np.var(tensor_accs_H56actPC[:,dd,ep])

# %%
ffact = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Action Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,0],yerr=std_accs_L4actPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,0],yerr=std_accs_L23actPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,0],yerr=std_accs_L56actPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,0],yerr=std_accs_H4actPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,0],yerr=std_accs_H23actPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,0],yerr=std_accs_H56actPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Action Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,1],yerr=std_accs_L4actPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,1],yerr=std_accs_L23actPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,1],yerr=std_accs_L56actPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,1],yerr=std_accs_H4actPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,1],yerr=std_accs_H23actPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,1],yerr=std_accs_H56actPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Action Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4actPC[:,-1],yerr=std_accs_L4actPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23actPC[:,-1],yerr=std_accs_L23actPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56actPC[:,-1],yerr=std_accs_L56actPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4actPC[:,-1],yerr=std_accs_H4actPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23actPC[:,-1],yerr=std_accs_H23actPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56actPC[:,-1],yerr=std_accs_H56actPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
fact_pcs = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L4actPC,0),yerr=np.var(mean_accs_L4actPC,0),label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L23actPC,0),yerr=np.var(mean_accs_L23actPC,0),label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_L56actPC,0),yerr=np.var(mean_accs_L56actPC,0),label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H4actPC,0),yerr=np.var(mean_accs_H4actPC,0),label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H23actPC,0),yerr=np.var(mean_accs_H23actPC,0),label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(n_epochs+1),np.mean(mean_accs_H56actPC,0),yerr=np.var(mean_accs_H56actPC,0),label='Higer layer 5/6',fmt='-s')
plt.xlabel('Epochs')
plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(1,1))
plt.title('Action Decodability across Epochs - Canonical Microcircuit')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# #### Temporal accuracies

# %%
labelsTrain = {}
labelsTest = {}
labelsTestTemp = {}

# %%
for cntr in range(nRuns):
    labelsTest[cntr] = np.argmax(yRepsTest[cntr]@template[cntr].T,-1)
    labelsTestTemp[cntr] = np.argmax(yRepsTestTemp[cntr]@template[cntr].T,-1)

# %%
# preds_train = {}
preds_test = {}
preds_temp = {}

# accs_train = np.zeros((nRuns,n_epochs+1))
accs_test = np.zeros((nRuns,n_epochs+1))
accs_temp = np.zeros((nRuns,n_epochs+1))

for cntr in range(nRuns):
#     preds_train[cntr] = np.argmax(np.abs(np.round_(out_train[cntr]))@template[cntr].T,-1)
    preds_test[cntr] = np.argmax(np.abs(np.round_(out_test[cntr]))@template[cntr].T,-1)
    preds_temp[cntr] = np.argmax(np.abs(np.round_(out_temp[cntr]))@template[cntr].T,-1)
    
    for ep in range(n_epochs+1): 
#         accs_train[cntr,ep] = accuracy_score(labelsTrain[cntr].ravel(),preds_train[cntr][ep].ravel())
        accs_test[cntr,ep] = accuracy_score(labelsTest[cntr].ravel(),preds_test[cntr][ep].ravel())
        accs_temp[cntr,ep] = accuracy_score(labelsTestTemp[cntr].ravel(),preds_temp[cntr][ep].ravel())

# %%
# plt.errorbar(np.arange(n_epochs+1),np.mean(accs_train,0),yerr=np.var(accs_train,0),fmt='-',label='Train')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_test,0),yerr=np.var(accs_test,0),fmt='-',label='Test - Clean')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_temp,0),yerr=np.var(accs_temp,0),fmt='-',label='Test - Surprise')
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend()
plt.title('Prediction accuracy in presence of temporal violation')
plt.show()

# %%
np.save(pp+'corticalRNN-no-violations-accs-lattice',accs_test)
np.save(pp+'corticalRNN-temporal-violations-accs-lattice',accs_temp)

# %% [markdown]
# ### Spatial violations

# %%
from numpy.random import normal

# %%
noise_stds = np.linspace(0,1,6)

# %%
repsTrainNoisy = {}
repsTestNoisy = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        repsTrainNoisy[cntr,nn] = repsTrain[cntr] + normal(0,noise,repsTrain[cntr].shape)
        repsTestNoisy[cntr,nn] = repsTest[cntr] + normal(0,noise,repsTest[cntr].shape)

# %%
noisy_train_loaders = {}
noisy_test_loaders = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noisy_train_loaders[cntr,nn] = makeTensorLoaders((repsTrainNoisy[cntr,nn],yRepsTrain[cntr],
                                                            eTrain[cntr],surpTrain[cntr]),batch_size,shuffle=False)
        noisy_test_loaders[cntr,nn] = makeTensorLoaders((repsTestNoisy[cntr,nn],yRepsTest[cntr],
                                                            eTest[cntr],surpTest[cntr]),batch_size,shuffle=False)

# %%
nNoise = len(noise_stds)

# %%
def pass_data_store_activations_noisy(loader, nData, 
                                nRuns=nRuns, nNoise=nNoise, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        for nn in range(nNoise):
            activations_hidden_L23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_L4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_L56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_hidden_H23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_H4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_H56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_out_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
            for e in tqdm(range(n_epochs+1)):

                cnt = 0

                ## Load model
                model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr],task='lattice')
                model[cntr].to(device)
                model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
                model[cntr].eval()

                ## Pass clean samples
                for data, f_target, lastEvent, surpriseBinary in loader[cntr,nn]:

                    if train_on_gpu:
                        data, f_targetC = data.float().cuda(), f_target.float().cuda()
                    else: data, f_targetC = data.float(), f_target.float()

                    target = f_target

                    output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                    ## Collect activations  
                    act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                    act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                    act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                    act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                    act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                    act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                    output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                    for i in range(batch_size):
                        if i < len(data):
                            label = target.data[i]

                            activations_hidden_L23_np[cntr,nn][e,cnt] = act_hidden_L23[i]
                            activations_hidden_L4_np[cntr,nn][e,cnt] = act_hidden_L4[i]
                            activations_hidden_L56_np[cntr,nn][e,cnt] = act_hidden_L56[i]

                            activations_hidden_H23_np[cntr,nn][e,cnt] = act_hidden_H23[i]
                            activations_hidden_H4_np[cntr,nn][e,cnt] = act_hidden_H4[i]
                            activations_hidden_H56_np[cntr,nn][e,cnt] = act_hidden_H56[i]

                            activations_out_np[cntr,nn][e,cnt] = output_pred[i]

                            cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# L23_train_noisy = {}
# L4_train_noisy = {}
# L56_train_noisy = {}

# H23_train_noisy = {}
# H4_train_noisy = {}
# H56_train_noisy = {}

# out_train_noisy = {}

# %%
L23_test_noisy = {}
L4_test_noisy = {}
L56_test_noisy = {}

H23_test_noisy = {}
H4_test_noisy = {}
H56_test_noisy = {}

out_test_noisy = {}

# %%
# (L23_train_noisy,L4_train_noisy,L56_train_noisy,
#  H23_train_noisy,H4_train_noisy,H56_train_noisy), out_train_noisy = pass_data_store_activations_noisy(noisy_train_loaders,nTrain)

(L23_test_noisy,L4_test_noisy,L56_test_noisy,
 H23_test_noisy,H4_test_noisy,H56_test_noisy), out_test_noisy = pass_data_store_activations_noisy(noisy_test_loaders,nTest)
# Out:
# 100%|██████████| 101/101 [00:09<00:00, 10.33it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.45it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.40it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.42it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.48it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.34it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.34it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.52it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.38it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.99it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.94it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.95it/s]
# 100%|██████████| 101/101 [00:10<00:00, 10.02it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.89it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.89it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.91it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.91it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.26it/s]
# 100%|██████████| 101/101 [00:11<00:00,  8.95it/s]
# 100%|██████████| 101/101 [00:11<00:00,  8.89it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.81it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.45it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.20it/s]
# 100%|██████████| 101/101 [00:10<00:00,  9.87it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.43it/s]
# 100%|██████████| 101/101 [00:10<00:00, 10.09it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.86it/s]
# 100%|██████████| 101/101 [00:10<00:00, 10.05it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.22it/s]
# 100%|██████████| 101/101 [00:09<00:00, 10.18it/s]

# %%
predsN_train = {}
accsN_train = np.zeros((nRuns,len(noise_stds),n_epochs+1))

predsN_test = {}
accsN_test = np.zeros((nRuns,len(noise_stds),n_epochs+1))

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        predsN_test[cntr,nn] = np.argmax(out_test_noisy[cntr,nn]@template[cntr].T,-1)
        accsN_test[cntr,nn] = np.sum(np.sum(((labelsTest[cntr] - predsN_test[cntr,nn])==0)*1,-1),-1)/(nTest*6)

# %%
name = "Dark2_r"
cmap = get_cmap(name)  # type: matplotlib.colors.ListedColormap
colors = cmap.colors  # type: list

# %%
fpredspat = plt.figure()
for nn, noise in enumerate(noise_stds):
    plt.errorbar(np.arange(n_epochs+1),np.mean(accsN_test[:,nn],0),yerr=np.var(accsN_test[:,nn],0),
                 fmt='-',label=np.round(noise,2),
                 c=colors[nn])
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend(title="Noise sigma",bbox_to_anchor=(1,0.5))
plt.title('Prediction accuracy with spatial noise - Canonical Microcircuit')
plt.show()

# %%
np.save(pp+'corticalRNN-spatial-noisy-accs-lattice',accsN_test)

# %% [markdown]
# #### Dimensionality (Linear)

# %%
def rnnLinDim(acts):
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    eig_mat = np.zeros((nEpochs,nNeurons))
        
    for ep in tqdm(range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        cov = actsScaled.T@actsScaled
        eig_mat[ep] = eigvals(cov)
        num = np.sum(eig_mat,1)**2
        den = np.sum(eig_mat**2,1) + 1e-17
        PR = num/den
    return PR

# %%
L23LinDim = np.zeros((nRuns,n_epochs+1))
L4LinDim = np.zeros((nRuns,n_epochs+1))
L56LinDim = np.zeros((nRuns,n_epochs+1))

H23LinDim = np.zeros((nRuns,n_epochs+1))
H4LinDim = np.zeros((nRuns,n_epochs+1))
H56LinDim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23LinDim[cntr] = rnnLinDim(L23_test[cntr])
    L4LinDim[cntr] = rnnLinDim(L4_test[cntr])
    L56LinDim[cntr] = rnnLinDim(L56_test[cntr])

    H23LinDim[cntr] = rnnLinDim(H23_test[cntr])
    H4LinDim[cntr] = rnnLinDim(H4_test[cntr])
    H56LinDim[cntr] = rnnLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 169.35it/s]
# 100%|██████████| 101/101 [00:00<00:00, 332.03it/s]
# 100%|██████████| 101/101 [00:00<00:00, 218.02it/s]
# 100%|██████████| 101/101 [00:00<00:00, 185.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 348.01it/s]
# 100%|██████████| 101/101 [00:00<00:00, 232.27it/s]
# 100%|██████████| 101/101 [00:00<00:00, 189.29it/s]
# 100%|██████████| 101/101 [00:00<00:00, 351.63it/s]
# 100%|██████████| 101/101 [00:00<00:00, 218.25it/s]
# 100%|██████████| 101/101 [00:00<00:00, 191.08it/s]
# 100%|██████████| 101/101 [00:00<00:00, 364.28it/s]
# 100%|██████████| 101/101 [00:00<00:00, 229.64it/s]
# 100%|██████████| 101/101 [00:00<00:00, 195.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 351.63it/s]
# 100%|██████████| 101/101 [00:00<00:00, 224.05it/s]
# 100%|██████████| 101/101 [00:00<00:00, 193.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 343.29it/s]
# 100%|██████████| 101/101 [00:00<00:00, 225.04it/s]
# 100%|██████████| 101/101 [00:00<00:00, 184.13it/s]
# 100%|██████████| 101/101 [00:00<00:00, 354.09it/s]
# 100%|██████████| 101/101 [00:00<00:00, 225.55it/s]
# 100%|██████████| 101/101 [00:00<00:00, 196.64it/s]
# 100%|██████████| 101/101 [00:00<00:00, 334.22it/s]
# 100%|██████████| 101/101 [00:00<00:00, 224.05it/s]
# 100%|██████████| 101/101 [00:00<00:00, 194.00it/s]
# 100%|██████████| 101/101 [00:00<00:00, 359.11it/s]
# 100%|██████████| 101/101 [00:00<00:00, 229.12it/s]
# 100%|██████████| 101/101 [00:00<00:00, 192.16it/s]
# 100%|██████████| 101/101 [00:00<00:00, 355.33it/s]
# 100%|██████████| 101/101 [00:00<00:00, 231.21it/s]

# %% [markdown]
# #### Dimensionality (non-linear)

# %%
def rnnNonLinDim(acts,nTypes=2,subsample=True,ds=100):
    
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    dims_mat = np.zeros((nEpochs,nTypes))
        
    for ep in (range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        
        if subsample:
            actsScaled = actsScaled[::ds]
        
        dims_mat[ep,0] = MiND_ML().fit(actsScaled).dimension_
#         print(dims_mat[ep,0])
        dims_mat[ep,1] = CorrInt().fit(actsScaled).dimension_
#         print(dims_mat[ep,1])
#         dims_mat[ep,2] = MLE().fit(actsScaled).dimension_
#         print(dims_mat[ep,2])
#         dims_mat[ep,3] = DANCo().fit(actsScaled).dimension_
        
    return np.mean(dims_mat,-1),dims_mat

# %%
L23NonLinDim = np.zeros((nRuns,n_epochs+1))
L4NonLinDim = np.zeros((nRuns,n_epochs+1))
L56NonLinDim = np.zeros((nRuns,n_epochs+1))

H23NonLinDim = np.zeros((nRuns,n_epochs+1))
H4NonLinDim = np.zeros((nRuns,n_epochs+1))
H56NonLinDim = np.zeros((nRuns,n_epochs+1))

# %%
L23_ND_mat = {}
L4_ND_mat = {}
L56_ND_mat = {}
H23_ND_mat = {}
H4_ND_mat = {}
H56_ND_mat = {}

# %%
for cntr in tqdm(range(nRuns)):
    L23NonLinDim[cntr], L23_ND_mat[cntr] = rnnNonLinDim(L23_test[cntr])
    L4NonLinDim[cntr], L4_ND_mat[cntr] = rnnNonLinDim(L4_test[cntr])
    L56NonLinDim[cntr], L56_ND_mat[cntr] = rnnNonLinDim(L56_test[cntr])

    H23NonLinDim[cntr], H23_ND_mat[cntr] = rnnNonLinDim(H23_test[cntr])
    H4NonLinDim[cntr], H4_ND_mat[cntr] = rnnNonLinDim(H4_test[cntr])
    H56NonLinDim[cntr], H56_ND_mat[cntr] = rnnNonLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 5/5 [02:05<00:00, 25.01s/it]

# %%
L23_NonLineDim_mean = np.mean(L23NonLinDim,0)
L4_NonLineDim_mean = np.mean(L4NonLinDim,0)
L56_NonLineDim_mean = np.mean(L56NonLinDim,0)

H23_NonLineDim_mean = np.mean(H23NonLinDim,0)
H4_NonLineDim_mean = np.mean(H4NonLinDim,0)
H56_NonLineDim_mean = np.mean(H56NonLinDim,0)

L23_NonLineDim_std = np.var(L23NonLinDim,0)
L4_NonLineDim_std = np.var(L4NonLinDim,0)
L56_NonLineDim_std = np.var(L56NonLinDim,0)

H23_NonLineDim_std = np.var(H23NonLinDim,0)
H4_NonLineDim_std = np.var(H4NonLinDim,0)
H56_NonLineDim_std = np.var(H56NonLinDim,0)

# %%
L23_dim = np.zeros((nRuns,n_epochs+1))
L4_dim = np.zeros((nRuns,n_epochs+1))
L56_dim = np.zeros((nRuns,n_epochs+1))

H23_dim = np.zeros((nRuns,n_epochs+1))
H4_dim = np.zeros((nRuns,n_epochs+1))
H56_dim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23_dim[cntr] = L23LinDim[cntr]/L23NonLinDim[cntr]
    L4_dim[cntr] = L4LinDim[cntr]/L4NonLinDim[cntr]
    L56_dim[cntr] = L56LinDim[cntr]/L56NonLinDim[cntr]
    H23_dim[cntr] = H23LinDim[cntr]/H23NonLinDim[cntr]
    H4_dim[cntr] = H4LinDim[cntr]/H4NonLinDim[cntr]
    H56_dim[cntr] = H56LinDim[cntr]/H56NonLinDim[cntr]

# %%
np.save(pp+'L23DG_corticalRNN_lattice',L23_dim)
np.save(pp+'L4DG_corticalRNN_lattice',L4_dim)
np.save(pp+'L56DG_corticalRNN_lattice',L56_dim)
np.save(pp+'H23DG_corticalRNN_lattice',H23_dim)
np.save(pp+'H4DG_corticalRNN_lattice',H4_dim)
np.save(pp+'H56DG_corticalRNN_lattice',H56_dim)

# %%
ffTotDim = plt.figure(figsize=(5,5))

plt.subplot(111)

plt.plot(np.arange(n_epochs+1),np.mean(L4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(L4_dim,0)-np.var(L4_dim,0),np.mean(L4_dim,0)+np.var(L4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(L23_dim,0)-np.var(L23_dim,0),np.mean(L23_dim,0)+np.var(L23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(L56_dim,0)-np.var(L56_dim,0),np.mean(L56_dim,0)+np.var(L56_dim,0),alpha=0.5)

plt.plot(np.arange(n_epochs+1),np.mean(H4_dim,0),label='Higher layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(H4_dim,0)-np.var(H4_dim,0),np.mean(H4_dim,0)+np.var(H4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H23_dim,0),label='Higher layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(H23_dim,0)-np.var(H23_dim,0),np.mean(H23_dim,0)+np.var(H23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H56_dim,0),label='Higher layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(H56_dim,0)-np.var(H56_dim,0),np.mean(H56_dim,0)+np.var(H56_dim,0),alpha=0.5)

plt.xlabel('Epochs')
plt.ylabel('Dimensionality Gain')
# plt.ylim(0.9,2.2)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Canonical Microcircuit')
plt.show()

# %%
ffTotDim.savefig('Dimensionality-gain-corticalRNN-across-learning-lattice.png',dpi=300,bbox_inches='tight')
ffTotDim.savefig('Dimensionality-gain-corticalRNN-across-learning-lattice.svg',dpi=300,bbox_inches='tight')
