# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from tqdm import tqdm

# %%
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# #### Address, axes initializations

# %%
pp = ## specify path

# %%
arch_mods = ['Cortical Microcircuit','No Feedback','Bidirectional Feedback',
             'Unidirectional Feedback','Same-sized Populations']

# %% [markdown]
# #### Initialise nRuns, n_epochs, noise values, PC dims, etc.

# %%
nRuns = 5
n_epochs = 50 ## Keep this the same Suhee!!

# %%
dims23 = np.array([1,2,4,8,16,32,64,80])
dims4 = np.array([1,2,4,8,16,32])
dims56 = np.array([1,2,4,8,16,32,64])

# %%
noise_stds = np.linspace(0,5,6)
noise_stds = np.round(noise_stds,3)
noise_stds = noise_stds[1:]

# %%
spatAccs = {}

spatAccs[arch_mods[0]] = np.load(pp+'corticalRNN-spatial-noisy-accs-binary.npy')[:,1:] + 1e-6
spatAccs[arch_mods[1]] = np.load(pp+'no-fb-spatial-noisy-accs-binary.npy')[:,1:] + 1e-6
spatAccs[arch_mods[2]] = np.load(pp+'bidirectional-fb-spatial-noisy-accs-binary.npy')[:,1:] + 1e-6
spatAccs[arch_mods[3]] = np.load(pp+'unidirectional-fb-spatial-noisy-accs-binary.npy')[:,1:] + 1e-6
spatAccs[arch_mods[4]] = np.load(pp+'same-pop-spatial-noisy-accs-binary.npy')[:,1:] + 1e-6

# %%
cleanAccs = {}

cleanAccs[arch_mods[0]] = np.load(pp+'corticalRNN-no-violations-accs-binary.npy')
cleanAccs[arch_mods[1]] = np.load(pp+'no-fb-no-violations-accs-binary.npy')
cleanAccs[arch_mods[2]] = np.load(pp+'bidirectional-fb-no-violations-accs-binary.npy')
cleanAccs[arch_mods[3]] = np.load(pp+'unidirectional-fb-no-violations-accs-binary.npy')
cleanAccs[arch_mods[4]] = np.load(pp+'same-pop-no-violations-accs-binary.npy')

# %% [markdown]
# #### Temporal violation plots

# %%
cleanAccs = {}

cleanAccs[arch_mods[0]] = np.load(pp+'corticalRNN-no-violations-accs-binary.npy')
cleanAccs[arch_mods[1]] = np.load(pp+'no-fb-no-violations-accs-binary.npy')
cleanAccs[arch_mods[2]] = np.load(pp+'bidirectional-fb-no-violations-accs-binary.npy')
cleanAccs[arch_mods[3]] = np.load(pp+'unidirectional-fb-no-violations-accs-binary.npy')
cleanAccs[arch_mods[4]] = np.load(pp+'same-pop-no-violations-accs-binary.npy')

# %%
tempAccs = {}

tempAccs[arch_mods[0]] = np.load(pp+'corticalRNN-temporal-violations-accs-binary.npy')
tempAccs[arch_mods[1]] = np.load(pp+'no-fb-temporal-violations-accs-binary.npy')
tempAccs[arch_mods[2]] = np.load(pp+'bidirectional-fb-temporal-violations-accs-binary.npy')
tempAccs[arch_mods[3]] = np.load(pp+'unidirectional-fb-temporal-violations-accs-binary.npy')
tempAccs[arch_mods[4]] = np.load(pp+'same-pop-temporal-violations-accs-binary.npy')

# %% [markdown]
# #### Spatial-Temporal joint plots

# %%
df_joint = pd.DataFrame(columns=['Run','Epoch','Architecture','Accuracy','Violation'])

# %%
for rr in range(nRuns):
    
    for cnt, mod in enumerate(arch_mods):
        
        for ee in range(n_epochs+1):
            
            arch_tp = [(k,v) for k,v in tempAccs.items()][cnt][0]
            
            acc_cl = [(k,v) for k,v in cleanAccs.items()][cnt][1][rr,ee]
            df_joint.loc[len(df_joint)] = [rr,ee,arch_tp,acc_cl,'Clean']
            
            acc_tp = [(k,v) for k,v in tempAccs.items()][cnt][1][rr,ee]
            df_joint.loc[len(df_joint)] = [rr,ee,arch_tp,acc_tp,'Temporal violation']
            
            for nn, noise in enumerate(noise_stds):
            
                arch_sp = [(k,v) for k,v in spatAccs.items()][cnt][0]

                acc_sp = [(k,v) for k,v in spatAccs.items()][cnt][1][rr,nn,ee]

                df_joint.loc[len(df_joint)] = [rr,ee,arch_sp,acc_sp,'Spatial violation']

# %%
df_joint_final = df_joint[df_joint["Epoch"] == n_epochs]
df_joint_init = df_joint[df_joint["Epoch"] == 0]

# %%
cols_list = ['slategray','salmon','cornflowerblue']

# %%
f_all = plt.figure(figsize=(12,5))
sns.boxplot(data=df_joint, x='Architecture', y='Accuracy', hue="Violation", palette=cols_list,
            dodge=True,fliersize=0.0,width=0.8,whis=1)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Accuracy across Architectures in presence of Violations (Binary Prediction)')
# Out:
# Text(0.5, 1.0, 'Accuracy across Architectures in presence of Violations (Binary Prediction)')

# %%
f_final = plt.figure(figsize=(12,5))
sns.boxplot(data=df_joint_final, x='Architecture', y='Accuracy', hue="Violation", palette=cols_list,
            dodge=True,fliersize=0.0,width=0.8,whis=1)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Accuracy across Architectures in presence of Violations (Binary Prediction)')
# Out:
# Text(0.5, 1.0, 'Accuracy across Architectures in presence of Violations (Binary Prediction)')

# %%
f_all.savefig('Accuracy-across-Violations-iclr-all-binary.png',dpi=300,bbox_inches='tight')
f_all.savefig('Accuracy-across-Violations-iclr-all-binary.svg',dpi=300,bbox_inches='tight')

# %%
f_final.savefig('Accuracy-across-Violations-iclr-final-binary.png',dpi=300,bbox_inches='tight')
f_final.savefig('Accuracy-across-Violations-iclr-final-binary.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# #### Dimensionality plots

# %%
rnnNames = ['L4','L23','L56','H4','H23','H56']

# %%
DGs = {}

for rnn in rnnNames:
    DGs[arch_mods[0],rnn] = np.load(pp+rnn+'DG_corticalRNN_binary.npy')
    DGs[arch_mods[1],rnn] = np.load(pp+rnn+'DG_no-fb_binary.npy')
    DGs[arch_mods[2],rnn] = np.load(pp+rnn+'DG_bidirectional-fb_binary.npy')
    DGs[arch_mods[3],rnn] = np.load(pp+rnn+'DG_unidirectional-fb_binary.npy')
    DGs[arch_mods[4],rnn] = np.load(pp+rnn+'DG_same-pop_binary.npy')

# %%
df_dg = pd.DataFrame(columns=['Run','Epoch','Architecture','DG','RNN','Hierarchy'])

# %%
for cntr in range(len(rnnNames)*nRuns):
    
    arch = [(k,v) for k,v in DGs.items()][cntr][0][0]
    rnn = [(k,v) for k,v in DGs.items()][cntr][0][1]
        
    for rr in range(nRuns):
        for ee in range(n_epochs+1):
            
            dg = [(k,v) for k,v in DGs.items()][cntr][1][rr,ee]
            df_dg.loc[len(df_dg)] = [rr,ee,arch,dg,rnn,rnn[0]]

# %%
dg_plot = sns.relplot(data=df_dg, x='Epoch', y='DG', hue="Hierarchy", palette='coolwarm_r',kind='line',ci=80,
            style="Hierarchy",col="Architecture",height=5, aspect=1)

# %%
dg2_plot = sns.relplot(data=df_dg, x='Epoch', y='DG', hue="RNN", palette='coolwarm_r',kind='line',ci=60,
            style="Hierarchy",col="Architecture",height=5, aspect=0.9)
dg2_plot.fig.suptitle('Dimensionality Gain across Architectures (Binary Prediction)',y=1.05)
# Out:
# Text(0.5, 1.05, 'Dimensionality Gain across Architectures (Binary Prediction)')

# %%
dg_plot.savefig('DG-across-archs-iclr-binary.png',dpi=300,bbox_inches='tight')
dg_plot.savefig('DG-across-archs-iclr-binary.svg',dpi=300,bbox_inches='tight')

# %%
dg2_plot.savefig('DG-across-archs-iclr-binary-layers.png',dpi=300,bbox_inches='tight')
dg2_plot.savefig('DG-across-archs-iclr-binary-layers.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# #### Decodability

# %%
accs_temp_img = {}

for rnn in rnnNames:
    accs_temp_img[arch_mods[0],rnn] = np.load(pp+'accs_img_temp_'+rnn+'-corticalRNN-binary.npy',allow_pickle=True)
    accs_temp_img[arch_mods[1],rnn] = np.load(pp+'accs_img_temp_'+rnn+'-no-fb-binary.npy',allow_pickle=True)
    accs_temp_img[arch_mods[2],rnn] = np.load(pp+'accs_img_temp_'+rnn+'-bidirectional-fb-binary.npy',allow_pickle=True)
    accs_temp_img[arch_mods[3],rnn] = np.load(pp+'accs_img_temp_'+rnn+'-unidirectional-fb-binary.npy',allow_pickle=True)
    accs_temp_img[arch_mods[4],rnn] = np.load(pp+'accs_img_temp_'+rnn+'-same-pop-binary.npy',allow_pickle=True)

# %%
accs_temp_pos = {}

for rnn in rnnNames:
    accs_temp_pos[arch_mods[0],rnn] = np.load(pp+'accs_pos_temp_'+rnn+'-corticalRNN-binary.npy',allow_pickle=True)
    accs_temp_pos[arch_mods[1],rnn] = np.load(pp+'accs_pos_temp_'+rnn+'-no-fb-binary.npy',allow_pickle=True)
    accs_temp_pos[arch_mods[2],rnn] = np.load(pp+'accs_pos_temp_'+rnn+'-bidirectional-fb-binary.npy',allow_pickle=True)
    accs_temp_pos[arch_mods[3],rnn] = np.load(pp+'accs_pos_temp_'+rnn+'-unidirectional-fb-binary.npy',allow_pickle=True)
    accs_temp_pos[arch_mods[4],rnn] = np.load(pp+'accs_pos_temp_'+rnn+'-same-pop-binary.npy',allow_pickle=True)

# %%
accs_temp_surp = {}

for rnn in rnnNames:
    accs_temp_surp[arch_mods[0],rnn] = np.load(pp+'accs_surp_temp_'+rnn+'-corticalRNN.npy',allow_pickle=True)
    accs_temp_surp[arch_mods[1],rnn] = np.load(pp+'accs_surp_temp_'+rnn+'-no-fb.npy',allow_pickle=True)
    accs_temp_surp[arch_mods[2],rnn] = np.load(pp+'accs_surp_temp_'+rnn+'-bidirectional-fb.npy',allow_pickle=True)
    accs_temp_surp[arch_mods[3],rnn] = np.load(pp+'accs_surp_temp_'+rnn+'-unidirectional-fb.npy',allow_pickle=True)
    accs_temp_surp[arch_mods[4],rnn] = np.load(pp+'accs_surp_temp_'+rnn+'-same-pop-binary.npy',allow_pickle=True)

# %%
preds_temp_surp = {}

for rnn in rnnNames:
    preds_temp_surp[arch_mods[0],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-corticalRNN-binary.npy',allow_pickle=True)
    preds_temp_surp[arch_mods[1],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-no-fb-binary.npy',allow_pickle=True)
    preds_temp_surp[arch_mods[2],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-bidirectional-fb-binary.npy',allow_pickle=True)
    preds_temp_surp[arch_mods[3],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-unidirectional-fb-binary.npy',allow_pickle=True)
    preds_temp_surp[arch_mods[4],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-same-pop-binary.npy',allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-7e4afd515674> in <module>
#       2
#       3 for rnn in rnnNames:
# ----> 4     preds_temp_surp[arch_mods[0],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-corticalRNN-binary.npy',allow_pickle=True)
#       5     preds_temp_surp[arch_mods[1],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-no-fb-binary.npy',allow_pickle=True)
#       6     preds_temp_surp[arch_mods[2],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-bidirectional-fb-binary.npy',allow_pickle=True)
#
# c:\Users\user\anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/SC/transition-learning/preds_surp_temp_L4-corticalRNN-binary.npy'

# %%
# accs_temp_surp = {}

# for rnn in rnnNames:
#     accs_temp_surp[arch_mods[0],rnn] = np.load(pp+'accs_surp_temp_'+rnn+'-corticalRNN.npy',allow_pickle=True)
#     accs_temp_surp[arch_mods[1],rnn] = np.load(pp+'accs_surp_temp_'+rnn+'-no-fb.npy',allow_pickle=True)
#     accs_temp_surp[arch_mods[2],rnn] = np.load(pp+'accs_surp_temp_'+rnn+'-bidirectional-fb.npy',allow_pickle=True)
#     accs_temp_surp[arch_mods[3],rnn] = np.load(pp+'accs_surp_temp_'+rnn+'-unidirectional-fb.npy',allow_pickle=True)
#     accs_temp_surp[arch_mods[4],rnn] = np.load(pp+'accs_surp_temp_'+rnn+'-same-pop.npy',allow_pickle=True)

# %%
# preds_temp_surp = {}

# for rnn in rnnNames:
#     preds_temp_surp[arch_mods[0],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-corticalRNN.npy',allow_pickle=True)
#     preds_temp_surp[arch_mods[1],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-no-fb.npy',allow_pickle=True)
#     preds_temp_surp[arch_mods[2],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-bidirectional-fb.npy',allow_pickle=True)
#     preds_temp_surp[arch_mods[3],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-unidirectional-fb.npy',allow_pickle=True)
#     preds_temp_surp[arch_mods[4],rnn] = np.load(pp+'preds_surp_temp_'+rnn+'-same-pop.npy',allow_pickle=True)

# %%
df_temp_img = pd.DataFrame(columns=['Run','Epoch','Architecture','Accuracy','PC Dimension','RNN','Hierarchy'])
df_temp_pos = pd.DataFrame(columns=['Run','Epoch','Architecture','Accuracy','PC Dimension','RNN','Hierarchy'])
df_temp_surp = pd.DataFrame(columns=['Run','Epoch','Architecture','Accuracy','PC Dimension','RNN','Hierarchy'])

# %%
for cntr in tqdm(range(len(rnnNames)*nRuns)):
    
    arch = [(k,v) for k,v in accs_temp_img.items()][cntr][0][0]
    rnn = [(k,v) for k,v in accs_temp_img.items()][cntr][0][1]
        
    for rr in range(nRuns):
        for ee in range(3):
            
            if rnn[-1]=='4':
                for pc in dims4:
                    acc = [(k,v) for k,v in accs_temp_img.items()][cntr][1].item()[rr,pc,ee]
                    df_temp_img.loc[len(df_temp_img)] = [rr,ee,arch,acc,pc,rnn,rnn[0]]
            elif rnn[-1]=='6':
                for pc in dims56:
                    acc = [(k,v) for k,v in accs_temp_img.items()][cntr][1].item()[rr,pc,ee]
                    df_temp_img.loc[len(df_temp_img)] = [rr,ee,arch,acc,pc,rnn,rnn[0]]
            else:
                for pc in dims23:
                    acc = [(k,v) for k,v in accs_temp_img.items()][cntr][1].item()[rr,pc,ee]
                    df_temp_img.loc[len(df_temp_img)] = [rr,ee,arch,acc,pc,rnn,rnn[0]]
# Out:
# 100%|██████████| 30/30 [00:06<00:00,  4.75it/s]

# %%
for cntr in tqdm(range(len(rnnNames)*nRuns)):
    
    arch = [(k,v) for k,v in accs_temp_pos.items()][cntr][0][0]
    rnn = [(k,v) for k,v in accs_temp_pos.items()][cntr][0][1]
        
    for rr in range(nRuns):
        for ee in range(3):
            
            if rnn[-1]=='4':
                for pc in dims4:
                    acc = [(k,v) for k,v in accs_temp_pos.items()][cntr][1].item()[rr,pc,ee]
                    df_temp_pos.loc[len(df_temp_pos)] = [rr,ee,arch,acc,pc,rnn,rnn[0]]
            elif rnn[-1]=='6':
                for pc in dims56:
                    acc = [(k,v) for k,v in accs_temp_pos.items()][cntr][1].item()[rr,pc,ee]
                    df_temp_pos.loc[len(df_temp_pos)] = [rr,ee,arch,acc,pc,rnn,rnn[0]]
                    
            else:
                for pc in dims23:
                    acc = [(k,v) for k,v in accs_temp_pos.items()][cntr][1].item()[rr,pc,ee]
                    df_temp_pos.loc[len(df_temp_pos)] = [rr,ee,arch,acc,pc,rnn,rnn[0]]
# Out:
# 100%|██████████| 30/30 [00:06<00:00,  4.61it/s]

# %%
for cntr in tqdm(range(len(rnnNames)*nRuns)):
    
    arch = [(k,v) for k,v in accs_temp_surp.items()][cntr][0][0]
    rnn = [(k,v) for k,v in accs_temp_surp.items()][cntr][0][1]
        
    for rr in range(nRuns):
        for ee in range(3):
            
            if rnn[-1]=='4':
                for pc in dims4:
                    acc = [(k,v) for k,v in accs_temp_surp.items()][cntr][1].item()[rr,pc,ee]
                    df_temp_surp.loc[len(df_temp_surp)] = [rr,ee,arch,acc,pc,rnn,rnn[0]]
            elif rnn[-1]=='6':
                for pc in dims56:
                    acc = [(k,v) for k,v in accs_temp_surp.items()][cntr][1].item()[rr,pc,ee]
                    df_temp_surp.loc[len(df_temp_surp)] = [rr,ee,arch,acc,pc,rnn,rnn[0]]
            else:
                for pc in dims23:
                    acc = [(k,v) for k,v in accs_temp_surp.items()][cntr][1].item()[rr,pc,ee]
                    df_temp_surp.loc[len(df_temp_surp)] = [rr,ee,arch,acc,pc,rnn,rnn[0]]
# Out:
# 100%|██████████| 30/30 [00:06<00:00,  4.79it/s]

# %% [markdown]
# #### Decoding surprise at init

# %%
arch_mods
# Out:
# ['Cortical Microcircuit',
#  'No Feedback',
#  'Bidirectional Feedback',
#  'Unidirectional Feedback',
#  'Same-sized Populations']

# %%
ix = df_temp_surp['Epoch'] == 0
df_init_surp = df_temp_surp[ix]

# %%
ixFB = np.hstack((
                  (np.where((df_init_surp['RNN']=='L23')*(df_init_surp['Architecture']==arch_mods[0])>0)[0]),
    (np.where((df_init_surp['RNN']=='L56')*(df_init_surp['Architecture']==arch_mods[0])>0)[0]),
    (np.where((df_init_surp['RNN']=='L23')*(df_init_surp['Architecture']==arch_mods[2])>0)[0]),
    (np.where((df_init_surp['RNN']=='L56')*(df_init_surp['Architecture']==arch_mods[3])>0)[0]),
    (np.where((df_init_surp['RNN']=='L23')*(df_init_surp['Architecture']==arch_mods[4])>0)[0]),
    (np.where((df_init_surp['RNN']=='L56')*(df_init_surp['Architecture']==arch_mods[4])>0)[0])
))

ixFB = ixFB.ravel()
fb_indicator = np.array(['Other']*len(df_init_surp))
fb_indicator[ixFB] = 'FB'
fb_indicator = list(fb_indicator)
# Out:
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:204: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(

# %%
df_init_surp['Feedback Indicator'] = fb_indicator
# Out:
# <ipython-input-32-47c825ac2eb1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_init_surp['Feedback Indicator'] = fb_indicator

# %%
f = plt.figure(figsize=(15,5))
sns.barplot(data=df_temp_surp[ix], x='Architecture', y='Accuracy', hue="RNN", palette='tab10',ci=50)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Temporal Unexpectedness Decoding Accuracy across Architectures at Initialization')
# Out:
# C:\Users\abalwani6\AppData\Local\Temp\ipykernel_107828\2636002884.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 50)` for the same effect.
#
#   sns.barplot(data=df_temp_surp[ix], x='Architecture', y='Accuracy', hue="RNN", palette='tab10',ci=50)
# Text(0.5, 1.0, 'Temporal Unexpectedness Decoding Accuracy across Architectures at Initialization')

# %%
cols_dark = ['#1b9e77','#d95f02']
cols_dark_r = ['#7570b3','#1b9e77']

# %%
fsurpinit = plt.figure(figsize=(6.5,5))
sns.barplot(data=df_init_surp, x='Architecture', y='Accuracy', hue="Feedback Indicator", palette=cols_dark_r,ci=50,saturation=1)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Temporal Unexpectedness Decoding Accuracy across\n Architectures at Initialization (Binary Prediction)')
plt.xticks(np.arange(len(arch_mods)),
           ['Cortical\nMicrocircuit','No\nFeedack','Bidirectional\nFeedback',
            'Unidirectional\nFeedback','Same-sized\nPopulations'])
plt.show()
# Out:
# C:\Users\abalwani6\AppData\Local\Temp\ipykernel_107828\90652529.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 50)` for the same effect.
#
#   sns.barplot(data=df_init_surp, x='Architecture', y='Accuracy', hue="Feedback Indicator", palette=cols_dark_r,ci=50,saturation=1)

# %%
fsurpinit.savefig('Accs-surp-init-across-archs-iclr-binary.png',dpi=300,bbox_inches='tight')
fsurpinit.savefig('Accs-surp-init-across-archs-iclr-binary.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# #### Joint temporal violin plots

# %%
ix_img = df_temp_img['Architecture'] == arch_mods[0]
ix_pos = df_temp_pos['Architecture'] == arch_mods[0]
ix_surp = df_temp_surp['Architecture'] == arch_mods[0]

# %%
df_temporal_violations = pd.concat([df_temp_img[ix_img], df_temp_pos[ix_pos], df_temp_surp[ix_surp]])

# %%
df_temporal_violations['Decoding Variable'] = ['Input ID (Temporal Violation)']*sum(ix_img) + ['Temporal Position']*sum(ix_pos) + ['Temporal Surprise']*sum(ix_surp)

# %%
df_temporal_violations_final = df_temporal_violations[df_temporal_violations["Epoch"]==2]
df_temporal_violations_init = df_temporal_violations[df_temporal_violations["Epoch"]==0]

# %%
figTaskVariables_all = plt.figure(figsize=(12,4))
sns.violinplot(data=df_temporal_violations, x='Decoding Variable', y='Accuracy', hue="RNN", palette='coolwarm_r',
            dodge=True,fliersize=0.0,width=0.8,whis=0.5,bw=0.2,scale='width',linewidth=1)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Decoding Accuracies in the Cortical Microcircuit across Task variables (Binary Prediction - All)')
# Out:
# Text(0.5, 1.0, 'Decoding Accuracies in the Cortical Microcircuit across Task variables (Binary Prediction - All)')

# %%
figTaskVariables_init = plt.figure(figsize=(12,4))
sns.violinplot(data=df_temporal_violations_init, x='Decoding Variable', y='Accuracy', hue="RNN", palette='coolwarm_r',
            dodge=True,fliersize=0.0,width=0.8,whis=0.5,bw=0.2,scale='width',linewidth=1)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Decoding Accuracies in the Cortical Microcircuit across Task variables (Binary Prediction - Init)')
# Out:
# Text(0.5, 1.0, 'Decoding Accuracies in the Cortical Microcircuit across Task variables (Binary Prediction - Init)')

# %%
figTaskVariables_final = plt.figure(figsize=(12,4))
sns.violinplot(data=df_temporal_violations_final, x='Decoding Variable', y='Accuracy', hue="RNN", palette='coolwarm_r',
            dodge=True,fliersize=0.0,width=0.8,whis=0.5,bw=0.2,scale='width',linewidth=1)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Decoding Accuracies in the Cortical Microcircuit across Task variables (Binary Prediction - Final)')
# Out:
# Text(0.5, 1.0, 'Decoding Accuracies in the Cortical Microcircuit across Task variables (Binary Prediction - Final)')

# %%
figTaskVariables_all.savefig('Accs-across-task-vars-iclr-all-binary.png',dpi=300,bbox_inches='tight')
figTaskVariables_all.savefig('Accs-across-task-vars-iclr-all-binary.svg',dpi=300,bbox_inches='tight')

# %%
figTaskVariables_init.savefig('Accs-across-task-vars-iclr-init-binary.png',dpi=300,bbox_inches='tight')
figTaskVariables_init.savefig('Accs-across-task-vars-iclr-init-binary.svg',dpi=300,bbox_inches='tight')

# %%
figTaskVariables_final.savefig('Accs-across-task-vars-iclr-final-binary.png',dpi=300,bbox_inches='tight')
figTaskVariables_final.savefig('Accs-across-task-vars-iclr-final-binary.svg',dpi=300,bbox_inches='tight')
