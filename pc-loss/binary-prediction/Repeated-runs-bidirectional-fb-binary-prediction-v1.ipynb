# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

from numpy.random import choice
from numpy.linalg import norm

from math import factorial

from itertools import permutations

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap

from tqdm import tqdm
import os

# %%
from numpy.linalg import svd, eigvals
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, homogeneity_completeness_v_measure, confusion_matrix, ConfusionMatrixDisplay, homogeneity_score

# %%
from skdim.id import *

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import get_cmap

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.style.use('seaborn-whitegrid')
# plt.style.use('default')

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

# %%
from generate_data import generate_binary_rep_data, makeTensorLoaders

# %% [markdown]
# #### Test for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('No GPU, training on CPU')
    device = torch.device('cpu')
else:
    print('GPU found, training on GPU')
    device = torch.device('cuda')
# Out:
# GPU found, training on GPU

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Number of runs

# %%
nRuns = 5

# %% [markdown]
# #### Generate data for runs

# %%
dim = 16
nTot = 5000

fracTrain = 0.8
fracTest = np.round(1-fracTrain,2)

nTrain = int(nTot*fracTrain)
nTest = nTot - nTrain

lenSeq = 4
nRepeats = 2

# %%
numM = 2**dim-1

# %%
repsTrain = {}
yRepsTrain = {}
eTrain = {}
pTrain = {}
surpTrain = {}
allStatesTrain = {}

# %%
repsTest = {}
yRepsTest = {}
eTest = {}
pTest = {}
surpTest = {}
allStatesTest = {}

# %%
repsTestTemp = {}
yRepsTestTemp = {}
eTestTemp = {}
pTestTemp = {}
surpTestTemp = {}
allStatesTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]) = generate_binary_rep_data(nTot,fracTrain,dim,lenSeq)

# %%
labelsTrain = {}
labelsTest = {}
labelsTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]) = generate_binary_rep_data(nTot,fracTrain,dim,lenSeq)

# %%
for cntr in range(nRuns):
    labelsTrain[cntr] = np.repeat(allStatesTrain[cntr][:,:-1],2).reshape(nTrain,-1)
    labelsTest[cntr] = np.repeat(allStatesTest[cntr][:,1:],2).reshape(nTest,-1)
    labelsTestTemp[cntr] = np.repeat(allStatesTestTemp[cntr][:,1:],2).reshape(nTest,-1)

# %% [markdown]
# #### Create directories to save data and representations

# %%
pp = ## specify path

# %%
npp = {}
pp_npy = {}
pp_pts = {}

# %%
for cntr in range(nRuns):
    
    npp[cntr] = 'binary-bidirectional-fb-'+str(cntr)+'/'
    pp_npy[cntr] = pp+npp[cntr]+'npys-'+str(cntr)+'/'
    pp_pts[cntr] = pp+npp[cntr]+'pts-'+str(cntr)+'/'
    
## uncomment the following lines to create the folders. comment out if already created
    
    # os.mkdir(os.path.join(pp,npp[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_pts[cntr]))

    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr],'Dataset/'))

# %% [markdown]
# #### Save seeds and dataset

# %%
seeds = np.random.randint(1000, size=nRuns)
np.save(pp_npy[cntr]+'seeds',seeds)

# %%
for cntr in range(nRuns):

    ## Train Data
    np.save(pp_npy[cntr]+'Dataset/repsTrain',repsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTrain',yRepsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTrain',eTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTrain',surpTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTrain',allStatesTrain[cntr])

    ## Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTest',repsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTest',yRepsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTest',eTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTest',surpTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTest',allStatesTest[cntr])
    
    ## Temporally violated Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTestTemp',repsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTestTemp',yRepsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTestTemp',eTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTestTemp',surpTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTestTemp',allStatesTestTemp[cntr])

# %% [markdown]
# #### Load seeds

# %%
seeds = np.load(pp_npy[cntr]+'seeds.npy')

# %% [markdown]
# #### Convert data into tensors, etc.

# %%
batch_size = 100 ##100

# %%
pos_seq_idx = np.array([0,0,1,1,2,2])

# %%
train_loader = {}
test_loader = {}
test_temp_loader = {}

# %%
for cntr in range(nRuns):
    train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=True)
    test_loader[cntr] = makeTensorLoaders((repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)
    test_temp_loader[cntr] = makeTensorLoaders((repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),
                                          batch_size,shuffle=False)

# %%
# kk = 3
# print(np.min(allStatesTestTemp[kk]))
# ix = np.where(allStatesTestTemp[kk]==np.min(allStatesTestTemp[kk]))[0]
# print(repsTestTemp[kk][ix])
# print(yRepsTestTemp[kk][ix])

# %% [markdown]
# #### Load architectures, models, etc.

# %%
n_latent = 16 ## make sure it is the same in the architecture file as well
pop_list = [2,5,4] ## make sure it is the same in the architecture file as well

# %%
from architecture_bidirectional_feedback import microcircuit

# %%
model = {}
optimizer_rec = {}
optimizer_pc = {}

# %%
#specify loss function
reconLoss = nn.MSELoss()

#optimizer learning rate
eta_rec = 0.001
eta_pc = 0.0001

# %%
for cntr in range(nRuns):
    model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,pop_list=pop_list,bsize=batch_size,
                               manual_seed=seeds[cntr])
    model[cntr].to(device)
    optimizer_rec[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_rec)
    optimizer_pc[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_pc)

# %% [markdown]
# #### Train and collect activations

# %%
for data, f_target, lastEvent, surpriseBinary in train_loader[0]:
    if train_on_gpu:
        data, f_target = data.float().cuda(), f_target.float().cuda()
    else: data, f_target = data.float(), f_target.float()

# %%
output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[0](data)

# %%
nSteps = data.shape[1]

# %%
n_epochs = 100 ## number of epochs
div = n_epochs//n_epochs ## try ensuring that number used to divide by is a factor of n_epochs

# %%
feedback = True

# %%
def findMSE(output):
    errSq = output**2
    MSE_mat_samples_seq = errSq/np.prod(errSq.shape)
    MSE_samples = torch.mean(MSE_mat_samples_seq,1)
    return MSE_samples

# %%
train_losses = {}
test_losses = {}
temp_losses = {}

train_expected_rec_losses = {}
train_expected_fb_losses = {}

test_expected_rec_losses = {}
test_expected_fb_losses = {}

test_surprise_rec_losses = {}
test_surprise_fb_losses = {}

MSE_mat_full_test = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    train_losses[cntr] = np.zeros(n_epochs+1)
    test_losses[cntr] = np.zeros(n_epochs+1)
    temp_losses[cntr] = np.zeros(n_epochs+1)

    train_loss_min = np.Inf
    best_epoch = 0

    train_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    train_expected_fb_losses[cntr] = np.zeros(n_epochs+1)

    test_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_fb_losses[cntr] = np.zeros(n_epochs+1)
    
    test_surprise_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_surprise_fb_losses[cntr] = np.zeros(n_epochs+1)

    MSE_mat_full_test[cntr] = np.zeros(n_epochs+1)

    for epoch in (range(1,n_epochs+1)):

        train_loss = 0.0

        train_expected_rec_loss = 0.0
        train_expected_fb_loss = 0.0
        
        test_expected_rec_loss = 0.0
        test_expected_fb_loss = 0.0

        temp_rec_loss = 0.0
        temp_fb_loss = 0.0
        
        test_loss = 0.0
        temp_loss = 0.0

        cnt = 0
        
        ## Save model without training
        if epoch == 1:
            
            model[cntr].eval()
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_0.pt') ## Save model before any training
            
            ## Losses at 0th epoch
            for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
                if train_on_gpu:
                    data, f_target = data.float().cuda(), f_target.float().cuda()
                else:
                    data, f_target = data.float(), f_target.float()

                ##define all-sequence targets
                target = f_target

                optimizer_rec[cntr].zero_grad() #clears older gradients
                optimizer_pc[cntr].zero_grad() #clears older gradients
                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

                err_rec = torch.linalg.norm((output_pred-target),dim=2)
                err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
                MSE_samples_rec = findMSE(err_rec)
                MSE_samples_fb = findMSE(err_fb)

                loss = reconLoss(output_pred,target) #calculate the loss for the batch
                train_loss += loss.item()*data.size(0) #update training loss

                train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
                train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
                                    
            ## calculate average loss
            train_loss = train_loss/len(train_loader[cntr].dataset)
            
            ## Training loss at initialization
            train_losses[cntr][0] = train_loss
            train_expected_rec_losses[cntr][0] = train_expected_rec_loss
            train_expected_fb_losses[cntr][0] = train_expected_fb_loss
            
            ## Test losses at initialization
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test

                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)
                
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                # calculate the batch loss
                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
#             print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][0] = test_loss

            test_expected_rec_losses[cntr][0] = test_expected_rec_loss
            test_expected_fb_losses[cntr][0] = test_expected_fb_loss
        
        ## Test temp losses at initialization
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                    
                ##define all-sequence targets
                target_temp = f_target_temp

                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)
                loss_temp = reconLoss(output_pred_temp,target_temp)
                err_temp_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                # calculate the batch loss
                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_temp.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
#             print('Temp Loss: {:.6f}\n'.format(test_loss))

            temp_losses[cntr][0] = temp_loss

            test_surprise_rec_losses[cntr][0] = temp_rec_loss
            test_surprise_fb_losses[cntr][0] = temp_fb_loss

        #train model
        model[cntr].train()
        for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
            if train_on_gpu:
                data, f_target = data.float().cuda(), f_target.float().cuda()
            else:
                data, f_target = data.float(), f_target.float()

            ##define all-sequence targets
            target = f_target

            output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

            err_rec = torch.linalg.norm((output_pred-target),dim=2)
            err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
            MSE_samples_rec = findMSE(err_rec)
            MSE_samples_fb = findMSE(err_fb)
            
            loss = reconLoss(output_pred,target) #calculate the loss for the batch
            train_loss += loss.item()*data.size(0) #update training loss
            fbloss = torch.mean(MSE_samples_fb)

            optimizer_rec[cntr].zero_grad() #clears older gradients
            optimizer_pc[cntr].zero_grad() #clears older gradients
            ######## feedback error updates only higher-cortical area
            if (feedback)&(epoch%2==0):
                for name, param in model[cntr].named_parameters():
                    if ('FF' in name) or ('L23' in name) or ('L4' in name) or ('L56' in name):
                        param.require_grad = False
                fbloss.backward()
                optimizer_pc[cntr].step()
                for name, param in model[cntr].named_parameters():
                    param.require_grad = True
            else:
                loss.backward() #backprop
                optimizer_rec[cntr].step() #update parameters in direction of the -ve gradient  

            train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
            train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
        
        #calculate average loss
        train_loss = train_loss/len(train_loader[cntr].dataset)

        #training/validation stats
        train_losses[cntr][epoch] = train_loss
        train_expected_rec_losses[cntr][epoch] = train_expected_rec_loss
        train_expected_fb_losses[cntr][epoch] = train_expected_fb_loss

        #save model if the training loss decreased
        if train_loss <= train_loss_min:
            print('Epoch: {}, Train Loss Decreased!! ({:.6f}-->{:.6f})'.format(epoch,train_loss_min,train_loss))
            torch.save(model[cntr].state_dict(),pp_pts[cntr]+'predRNN.pt')
            train_loss_min = train_loss
            best_epoch = epoch

        if epoch%div == 0:
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_'+str(epoch)+'.pt')
            
            model[cntr].eval()
            
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test
                
                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)

                # calculate the batch loss
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
            print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][epoch] = test_loss

            test_expected_rec_losses[cntr][epoch] = test_expected_rec_loss
            test_expected_fb_losses[cntr][epoch] = test_expected_fb_loss
            
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                
                ##define all-sequence targets
                target_temp = f_target_temp
                
                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)

                # calculate the batch loss
                err_temp_rec = torch.linalg.norm((output_pred_temp-target_temp),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_temp[0],dim=2)+torch.linalg.norm(feedbackDiffs_temp[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_test.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
            print('Temp Loss: {:.6f}\n'.format(temp_loss))

            temp_losses[cntr][epoch] = temp_loss

            test_surprise_rec_losses[cntr][epoch] = temp_rec_loss
            test_surprise_fb_losses[cntr][epoch] = temp_fb_loss
            
    print('----------------------------------------------------')
            
    outF = open(pp+npp[cntr]+"training-details.txt", "w")
    outF.write('# epochs = ' + str(n_epochs))
    outF.write('\n')
    outF.write('Best epoch = '+str(best_epoch))
    outF.write('\n')
    outF.write('Minimum training loss = ' + str(train_loss_min))
    outF.write('\n')
    outF.write('Total number of samples = ' + str(nTot))
    outF.write('\n')
    outF.write('Number of training samples = ' + str(nTrain))
    outF.write('\n')
    outF.write('Number of testing samples = ' + str(nTest))
    outF.write('\n')
    outF.write('Dimensionality of representations = ' + str(dim))
    outF.write('\n')
    outF.write('Length of sequences = ' + str(lenSeq))
    outF.write('\n')
    outF.close()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1, Train Loss Decreased!! (inf-->0.297787)
# Test Loss: 0.254179
#
# Temp Loss: 0.254544
#
# Epoch: 2, Train Loss Decreased!! (0.297787-->0.253537)
# Test Loss: 0.253646
#
# Temp Loss: 0.253877
#
# Epoch: 3, Train Loss Decreased!! (0.253537-->0.249641)
# Test Loss: 0.239480
#
# Temp Loss: 0.239567
#
# Epoch: 4, Train Loss Decreased!! (0.249641-->0.240491)
# Test Loss: 0.241009
#
# Temp Loss: 0.240797
#
# Epoch: 5, Train Loss Decreased!! (0.240491-->0.224609)
# Test Loss: 0.204964
#
# Temp Loss: 0.207238
#
# Epoch: 6, Train Loss Decreased!! (0.224609-->0.206136)
# Test Loss: 0.206722
#
# Temp Loss: 0.208876
#
# Epoch: 7, Train Loss Decreased!! (0.206136-->0.196303)
# Test Loss: 0.186527
#
# Temp Loss: 0.204041
#
# Epoch: 8, Train Loss Decreased!! (0.196303-->0.187595)
# Test Loss: 0.189280
#
# Temp Loss: 0.205363
#
# Epoch: 9, Train Loss Decreased!! (0.187595-->0.176325)
# Test Loss: 0.161906
#
# Temp Loss: 0.190050
#
# Epoch: 10, Train Loss Decreased!! (0.176325-->0.162763)
# Test Loss: 0.164749
#
# Temp Loss: 0.192792
#
# Epoch: 11, Train Loss Decreased!! (0.162763-->0.157050)
# Test Loss: 0.150782
#
# Temp Loss: 0.181594
#
# Epoch: 12, Train Loss Decreased!! (0.157050-->0.153348)
# Test Loss: 0.157936
#
# Temp Loss: 0.185821
#
# Epoch: 13, Train Loss Decreased!! (0.153348-->0.144866)
# Test Loss: 0.135879
#
# Temp Loss: 0.167717
#
# Epoch: 14, Train Loss Decreased!! (0.144866-->0.142596)
# Test Loss: 0.154489
#
# Temp Loss: 0.183214
#
# Epoch: 15, Train Loss Decreased!! (0.142596-->0.132302)
# Test Loss: 0.125807
#
# Temp Loss: 0.158049
#
# Epoch: 16, Train Loss Decreased!! (0.132302-->0.131417)
# Test Loss: 0.142294
#
# Temp Loss: 0.171731
#
# Epoch: 17, Train Loss Decreased!! (0.131417-->0.125429)
# Test Loss: 0.121607
#
# Temp Loss: 0.153522
#
# Epoch: 18, Train Loss Decreased!! (0.125429-->0.123261)
# Test Loss: 0.130942
#
# Temp Loss: 0.160598
#
# Epoch: 19, Train Loss Decreased!! (0.123261-->0.119061)
# Test Loss: 0.112814
#
# Temp Loss: 0.144727
#
# Epoch: 20, Train Loss Decreased!! (0.119061-->0.114092)
# Test Loss: 0.120996
#
# Temp Loss: 0.151240
#
# Epoch: 21, Train Loss Decreased!! (0.114092-->0.107205)
# Test Loss: 0.100541
#
# Temp Loss: 0.134291
#
# Epoch: 22, Train Loss Decreased!! (0.107205-->0.102792)
# Test Loss: 0.110263
#
# Temp Loss: 0.142194
#
# Epoch: 23, Train Loss Decreased!! (0.102792-->0.096187)
# Test Loss: 0.090912
#
# Temp Loss: 0.125721
#
# Epoch: 24, Train Loss Decreased!! (0.096187-->0.093576)
# Test Loss: 0.101871
#
# Temp Loss: 0.135122
#
# Epoch: 25, Train Loss Decreased!! (0.093576-->0.086871)
# Test Loss: 0.083338
#
# Temp Loss: 0.119636
#
# Epoch: 26, Train Loss Decreased!! (0.086871-->0.086029)
# Test Loss: 0.095055
#
# Temp Loss: 0.130412
#
# Epoch: 27, Train Loss Decreased!! (0.086029-->0.081364)
# Test Loss: 0.078866
#
# Temp Loss: 0.114993
#
# Epoch: 28, Train Loss Decreased!! (0.081364-->0.080002)
# Test Loss: 0.086747
#
# Temp Loss: 0.121630
#
# Epoch: 29, Train Loss Decreased!! (0.080002-->0.076550)
# Test Loss: 0.074537
#
# Temp Loss: 0.112115
#
# Epoch: 30, Train Loss Decreased!! (0.076550-->0.075392)
# Test Loss: 0.081762
#
# Temp Loss: 0.117689
#
# Epoch: 31, Train Loss Decreased!! (0.075392-->0.072427)
# Test Loss: 0.070985
#
# Temp Loss: 0.110579
#
# Epoch: 32, Train Loss Decreased!! (0.072427-->0.071671)
# Test Loss: 0.078234
#
# Temp Loss: 0.115866
#
# Epoch: 33, Train Loss Decreased!! (0.071671-->0.069276)
# Test Loss: 0.068881
#
# Temp Loss: 0.109555
#
# Test Loss: 0.075502
#
# Temp Loss: 0.114034
#
# Epoch: 35, Train Loss Decreased!! (0.069276-->0.067515)
# Test Loss: 0.067634
#
# Temp Loss: 0.108779
#
# Test Loss: 0.074509
#
# Temp Loss: 0.113598
#
# Epoch: 37, Train Loss Decreased!! (0.067515-->0.066253)
# Test Loss: 0.066155
#
# Temp Loss: 0.106797
#
# Test Loss: 0.072563
#
# Temp Loss: 0.111318
#
# Epoch: 39, Train Loss Decreased!! (0.066253-->0.064058)
# Test Loss: 0.062545
#
# Temp Loss: 0.102683
#
# Epoch: 40, Train Loss Decreased!! (0.064058-->0.063212)
# Test Loss: 0.070285
#
# Temp Loss: 0.107453
#
# Epoch: 41, Train Loss Decreased!! (0.063212-->0.058786)
# Test Loss: 0.056660
#
# Temp Loss: 0.098378
#
# Test Loss: 0.070050
#
# Temp Loss: 0.108145
#
# Epoch: 43, Train Loss Decreased!! (0.058786-->0.055788)
# Test Loss: 0.053164
#
# Temp Loss: 0.094913
#
# Test Loss: 0.063708
#
# Temp Loss: 0.102171
#
# Epoch: 45, Train Loss Decreased!! (0.055788-->0.052172)
# Test Loss: 0.049334
#
# Temp Loss: 0.091001
#
# Epoch: 46, Train Loss Decreased!! (0.052172-->0.052122)
# Test Loss: 0.060599
#
# Temp Loss: 0.098637
#
# Epoch: 47, Train Loss Decreased!! (0.052122-->0.047521)
# Test Loss: 0.043984
#
# Temp Loss: 0.087690
#
# Epoch: 48, Train Loss Decreased!! (0.047521-->0.047346)
# Test Loss: 0.056288
#
# Temp Loss: 0.095420
#
# Epoch: 49, Train Loss Decreased!! (0.047346-->0.043172)
# Test Loss: 0.040375
#
# Temp Loss: 0.085667
#
# Test Loss: 0.051820
#
# Temp Loss: 0.092013
#
# Epoch: 51, Train Loss Decreased!! (0.043172-->0.039439)
# Test Loss: 0.037255
#
# Temp Loss: 0.085438
#
# Test Loss: 0.051681
#
# Temp Loss: 0.093273
#
# Epoch: 53, Train Loss Decreased!! (0.039439-->0.036840)
# Test Loss: 0.034110
#
# Temp Loss: 0.086531
#
# Test Loss: 0.051938
#
# Temp Loss: 0.097110
#
# Epoch: 55, Train Loss Decreased!! (0.036840-->0.033755)
# Test Loss: 0.030301
#
# Temp Loss: 0.085822
#
# Test Loss: 0.054693
#
# Temp Loss: 0.102072
#
# Epoch: 57, Train Loss Decreased!! (0.033755-->0.031731)
# Test Loss: 0.027726
#
# Temp Loss: 0.085332
#
# Test Loss: 0.054651
#
# Temp Loss: 0.103515
#
# Epoch: 59, Train Loss Decreased!! (0.031731-->0.029313)
# Test Loss: 0.025004
#
# Temp Loss: 0.085614
#
# Test Loss: 0.059763
#
# Temp Loss: 0.109387
#
# Epoch: 61, Train Loss Decreased!! (0.029313-->0.028072)
# Test Loss: 0.022586
#
# Temp Loss: 0.082916
#
# Test Loss: 0.055238
#
# Temp Loss: 0.103998
#
# Epoch: 63, Train Loss Decreased!! (0.028072-->0.025959)
# Test Loss: 0.020199
#
# Temp Loss: 0.082810
#
# Test Loss: 0.052386
#
# Temp Loss: 0.102396
#
# Epoch: 65, Train Loss Decreased!! (0.025959-->0.023154)
# Test Loss: 0.018077
#
# Temp Loss: 0.081642
#
# Test Loss: 0.049558
#
# Temp Loss: 0.100378
#
# Epoch: 67, Train Loss Decreased!! (0.023154-->0.020995)
# Test Loss: 0.016409
#
# Temp Loss: 0.080944
#
# Test Loss: 0.046459
#
# Temp Loss: 0.098880
#
# Epoch: 69, Train Loss Decreased!! (0.020995-->0.019138)
# Test Loss: 0.014665
#
# Temp Loss: 0.081223
#
# Test Loss: 0.045300
#
# Temp Loss: 0.098639
#
# Epoch: 71, Train Loss Decreased!! (0.019138-->0.017763)
# Test Loss: 0.013453
#
# Temp Loss: 0.080372
#
# Test Loss: 0.041065
#
# Temp Loss: 0.094409
#
# Epoch: 73, Train Loss Decreased!! (0.017763-->0.016036)
# Test Loss: 0.012066
#
# Temp Loss: 0.080725
#
# Test Loss: 0.038165
#
# Temp Loss: 0.092339
#
# Epoch: 75, Train Loss Decreased!! (0.016036-->0.014441)
# Test Loss: 0.011122
#
# Temp Loss: 0.081190
#
# Test Loss: 0.035672
#
# Temp Loss: 0.090790
#
# Epoch: 77, Train Loss Decreased!! (0.014441-->0.013348)
# Test Loss: 0.010012
#
# Temp Loss: 0.081615
#
# Test Loss: 0.034137
#
# Temp Loss: 0.090452
#
# Epoch: 79, Train Loss Decreased!! (0.013348-->0.012164)
# Test Loss: 0.009142
#
# Temp Loss: 0.082502
#
# Test Loss: 0.032171
#
# Temp Loss: 0.089104
#
# Epoch: 81, Train Loss Decreased!! (0.012164-->0.011323)
# Test Loss: 0.008328
#
# Temp Loss: 0.083696
#
# Test Loss: 0.029389
#
# Temp Loss: 0.088342
#
# Epoch: 83, Train Loss Decreased!! (0.011323-->0.010598)
# Test Loss: 0.007832
#
# Temp Loss: 0.083496
#
# Test Loss: 0.028260
#
# Temp Loss: 0.087354
#
# Epoch: 85, Train Loss Decreased!! (0.010598-->0.009746)
# Test Loss: 0.007320
#
# Temp Loss: 0.084322
#
# Test Loss: 0.027693
#
# Temp Loss: 0.088346
#
# Epoch: 87, Train Loss Decreased!! (0.009746-->0.009149)
# Test Loss: 0.006866
#
# Temp Loss: 0.085087
#
# Test Loss: 0.026647
#
# Temp Loss: 0.088748
#
# Epoch: 89, Train Loss Decreased!! (0.009149-->0.008762)
# Test Loss: 0.006620
#
# Temp Loss: 0.085495
#
# Test Loss: 0.026298
#
# Temp Loss: 0.089588
#
# Epoch: 91, Train Loss Decreased!! (0.008762-->0.008565)
# Test Loss: 0.006344
#
# Temp Loss: 0.085601
#
# Test Loss: 0.026325
#
# Temp Loss: 0.090105
#
# Epoch: 93, Train Loss Decreased!! (0.008565-->0.008306)
# Test Loss: 0.006044
#
# Temp Loss: 0.085766
#
# Test Loss: 0.025297
#
# Temp Loss: 0.090889
#
# Epoch: 95, Train Loss Decreased!! (0.008306-->0.007779)
# Test Loss: 0.005838
#
# Temp Loss: 0.085567
#
# Test Loss: 0.024668
#
# Temp Loss: 0.091008
#
# Epoch: 97, Train Loss Decreased!! (0.007779-->0.007694)
# Test Loss: 0.005687
#
# Temp Loss: 0.085992
#
# Test Loss: 0.023898
#
# Temp Loss: 0.090693
#
# Epoch: 99, Train Loss Decreased!! (0.007694-->0.007348)
# Test Loss: 0.005488
#
# Temp Loss: 0.086046
#  20%|██        | 1/5 [02:03<08:15, 123.76s/it]
# Test Loss: 0.024115
#
# Temp Loss: 0.091610
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.287266)
# Test Loss: 0.253262
#
# Temp Loss: 0.253702
#
# Epoch: 2, Train Loss Decreased!! (0.287266-->0.252628)
# Test Loss: 0.252518
#
# Temp Loss: 0.252738
#
# Epoch: 3, Train Loss Decreased!! (0.252628-->0.244854)
# Test Loss: 0.230034
#
# Temp Loss: 0.230390
#
# Epoch: 4, Train Loss Decreased!! (0.244854-->0.230339)
# Test Loss: 0.231404
#
# Temp Loss: 0.231779
#
# Epoch: 5, Train Loss Decreased!! (0.230339-->0.217187)
# Test Loss: 0.206867
#
# Temp Loss: 0.209606
#
# Epoch: 6, Train Loss Decreased!! (0.217187-->0.210041)
# Test Loss: 0.216383
#
# Temp Loss: 0.218983
#
# Epoch: 7, Train Loss Decreased!! (0.210041-->0.195922)
# Test Loss: 0.181166
#
# Temp Loss: 0.198269
#
# Epoch: 8, Train Loss Decreased!! (0.195922-->0.183849)
# Test Loss: 0.188880
#
# Temp Loss: 0.205045
#
# Epoch: 9, Train Loss Decreased!! (0.183849-->0.174495)
# Test Loss: 0.169057
#
# Temp Loss: 0.197203
#
# Epoch: 10, Train Loss Decreased!! (0.174495-->0.169644)
# Test Loss: 0.174092
#
# Temp Loss: 0.200114
#
# Epoch: 11, Train Loss Decreased!! (0.169644-->0.162921)
# Test Loss: 0.152071
#
# Temp Loss: 0.182740
#
# Epoch: 12, Train Loss Decreased!! (0.162921-->0.154474)
# Test Loss: 0.159638
#
# Temp Loss: 0.188902
#
# Epoch: 13, Train Loss Decreased!! (0.154474-->0.145804)
# Test Loss: 0.140516
#
# Temp Loss: 0.172073
#
# Test Loss: 0.157096
#
# Temp Loss: 0.186473
#
# Epoch: 15, Train Loss Decreased!! (0.145804-->0.139435)
# Test Loss: 0.132462
#
# Temp Loss: 0.164330
#
# Epoch: 16, Train Loss Decreased!! (0.139435-->0.136014)
# Test Loss: 0.145045
#
# Temp Loss: 0.174627
#
# Epoch: 17, Train Loss Decreased!! (0.136014-->0.128790)
# Test Loss: 0.123946
#
# Temp Loss: 0.156447
#
# Epoch: 18, Train Loss Decreased!! (0.128790-->0.127376)
# Test Loss: 0.136126
#
# Temp Loss: 0.166445
#
# Epoch: 19, Train Loss Decreased!! (0.127376-->0.123247)
# Test Loss: 0.120172
#
# Temp Loss: 0.153826
#
# Epoch: 20, Train Loss Decreased!! (0.123247-->0.121613)
# Test Loss: 0.128106
#
# Temp Loss: 0.159535
#
# Epoch: 21, Train Loss Decreased!! (0.121613-->0.117030)
# Test Loss: 0.111505
#
# Temp Loss: 0.145999
#
# Epoch: 22, Train Loss Decreased!! (0.117030-->0.115462)
# Test Loss: 0.125015
#
# Temp Loss: 0.157307
#
# Epoch: 23, Train Loss Decreased!! (0.115462-->0.107530)
# Test Loss: 0.102155
#
# Temp Loss: 0.138047
#
# Epoch: 24, Train Loss Decreased!! (0.107530-->0.105567)
# Test Loss: 0.115167
#
# Temp Loss: 0.148022
#
# Epoch: 25, Train Loss Decreased!! (0.105567-->0.097672)
# Test Loss: 0.089746
#
# Temp Loss: 0.125689
#
# Epoch: 26, Train Loss Decreased!! (0.097672-->0.093509)
# Test Loss: 0.101236
#
# Temp Loss: 0.134651
#
# Epoch: 27, Train Loss Decreased!! (0.093509-->0.084036)
# Test Loss: 0.078402
#
# Temp Loss: 0.115556
#
# Epoch: 28, Train Loss Decreased!! (0.084036-->0.082121)
# Test Loss: 0.092531
#
# Temp Loss: 0.126377
#
# Epoch: 29, Train Loss Decreased!! (0.082121-->0.075871)
# Test Loss: 0.070768
#
# Temp Loss: 0.107667
#
# Epoch: 30, Train Loss Decreased!! (0.075871-->0.073296)
# Test Loss: 0.082414
#
# Temp Loss: 0.117084
#
# Epoch: 31, Train Loss Decreased!! (0.073296-->0.067668)
# Test Loss: 0.062143
#
# Temp Loss: 0.099827
#
# Epoch: 32, Train Loss Decreased!! (0.067668-->0.064730)
# Test Loss: 0.073213
#
# Temp Loss: 0.109610
#
# Epoch: 33, Train Loss Decreased!! (0.064730-->0.060582)
# Test Loss: 0.057087
#
# Temp Loss: 0.096766
#
# Epoch: 34, Train Loss Decreased!! (0.060582-->0.060241)
# Test Loss: 0.067860
#
# Temp Loss: 0.105776
#
# Epoch: 35, Train Loss Decreased!! (0.060241-->0.057219)
# Test Loss: 0.055099
#
# Temp Loss: 0.095509
#
# Test Loss: 0.065663
#
# Temp Loss: 0.104142
#
# Epoch: 37, Train Loss Decreased!! (0.057219-->0.055513)
# Test Loss: 0.053701
#
# Temp Loss: 0.095241
#
# Test Loss: 0.063534
#
# Temp Loss: 0.102702
#
# Epoch: 39, Train Loss Decreased!! (0.055513-->0.053955)
# Test Loss: 0.052418
#
# Temp Loss: 0.093632
#
# Test Loss: 0.062846
#
# Temp Loss: 0.101420
#
# Epoch: 41, Train Loss Decreased!! (0.053955-->0.051964)
# Test Loss: 0.049026
#
# Temp Loss: 0.090481
#
# Test Loss: 0.061631
#
# Temp Loss: 0.100333
#
# Epoch: 43, Train Loss Decreased!! (0.051964-->0.047953)
# Test Loss: 0.044910
#
# Temp Loss: 0.086845
#
# Epoch: 44, Train Loss Decreased!! (0.047953-->0.047781)
# Test Loss: 0.056404
#
# Temp Loss: 0.096207
#
# Epoch: 45, Train Loss Decreased!! (0.047781-->0.044561)
# Test Loss: 0.041797
#
# Temp Loss: 0.084575
#
# Test Loss: 0.052874
#
# Temp Loss: 0.092911
#
# Epoch: 47, Train Loss Decreased!! (0.044561-->0.040786)
# Test Loss: 0.037823
#
# Temp Loss: 0.080701
#
# Test Loss: 0.051734
#
# Temp Loss: 0.091679
#
# Epoch: 49, Train Loss Decreased!! (0.040786-->0.037025)
# Test Loss: 0.034013
#
# Temp Loss: 0.078674
#
# Test Loss: 0.049159
#
# Temp Loss: 0.091092
#
# Epoch: 51, Train Loss Decreased!! (0.037025-->0.032972)
# Test Loss: 0.028782
#
# Temp Loss: 0.077074
#
# Test Loss: 0.044465
#
# Temp Loss: 0.089958
#
# Epoch: 53, Train Loss Decreased!! (0.032972-->0.028417)
# Test Loss: 0.024411
#
# Temp Loss: 0.078438
#
# Test Loss: 0.040701
#
# Temp Loss: 0.090776
#
# Epoch: 55, Train Loss Decreased!! (0.028417-->0.024727)
# Test Loss: 0.021829
#
# Temp Loss: 0.079646
#
# Test Loss: 0.039219
#
# Temp Loss: 0.091978
#
# Epoch: 57, Train Loss Decreased!! (0.024727-->0.023001)
# Test Loss: 0.020171
#
# Temp Loss: 0.080760
#
# Test Loss: 0.038102
#
# Temp Loss: 0.092059
#
# Epoch: 59, Train Loss Decreased!! (0.023001-->0.021728)
# Test Loss: 0.018735
#
# Temp Loss: 0.080804
#
# Test Loss: 0.036898
#
# Temp Loss: 0.091744
#
# Epoch: 61, Train Loss Decreased!! (0.021728-->0.020389)
# Test Loss: 0.017787
#
# Temp Loss: 0.081629
#
# Test Loss: 0.037069
#
# Temp Loss: 0.093452
#
# Epoch: 63, Train Loss Decreased!! (0.020389-->0.019824)
# Test Loss: 0.016926
#
# Temp Loss: 0.081589
#
# Test Loss: 0.037839
#
# Temp Loss: 0.093665
#
# Epoch: 65, Train Loss Decreased!! (0.019824-->0.019267)
# Test Loss: 0.016232
#
# Temp Loss: 0.081803
#
# Test Loss: 0.036467
#
# Temp Loss: 0.092007
#
# Epoch: 67, Train Loss Decreased!! (0.019267-->0.018478)
# Test Loss: 0.015375
#
# Temp Loss: 0.080763
#
# Test Loss: 0.036097
#
# Temp Loss: 0.091751
#
# Epoch: 69, Train Loss Decreased!! (0.018478-->0.017388)
# Test Loss: 0.014815
#
# Temp Loss: 0.080921
#
# Test Loss: 0.034577
#
# Temp Loss: 0.090910
#
# Epoch: 71, Train Loss Decreased!! (0.017388-->0.017070)
# Test Loss: 0.014227
#
# Temp Loss: 0.080988
#
# Test Loss: 0.034186
#
# Temp Loss: 0.090370
#
# Epoch: 73, Train Loss Decreased!! (0.017070-->0.016508)
# Test Loss: 0.013825
#
# Temp Loss: 0.080619
#
# Test Loss: 0.033550
#
# Temp Loss: 0.090350
#
# Epoch: 75, Train Loss Decreased!! (0.016508-->0.015982)
# Test Loss: 0.013332
#
# Temp Loss: 0.080495
#
# Test Loss: 0.032370
#
# Temp Loss: 0.089645
#
# Epoch: 77, Train Loss Decreased!! (0.015982-->0.015500)
# Test Loss: 0.012786
#
# Temp Loss: 0.080101
#
# Test Loss: 0.031567
#
# Temp Loss: 0.089046
#
# Epoch: 79, Train Loss Decreased!! (0.015500-->0.015066)
# Test Loss: 0.012483
#
# Temp Loss: 0.080477
#
# Test Loss: 0.032080
#
# Temp Loss: 0.089470
#
# Epoch: 81, Train Loss Decreased!! (0.015066-->0.014663)
# Test Loss: 0.012107
#
# Temp Loss: 0.079928
#
# Test Loss: 0.031083
#
# Temp Loss: 0.088684
#
# Epoch: 83, Train Loss Decreased!! (0.014663-->0.013983)
# Test Loss: 0.011728
#
# Temp Loss: 0.080272
#
# Test Loss: 0.031002
#
# Temp Loss: 0.089176
#
# Test Loss: 0.011348
#
# Temp Loss: 0.080033
#
# Test Loss: 0.029021
#
# Temp Loss: 0.087959
#
# Epoch: 87, Train Loss Decreased!! (0.013983-->0.013202)
# Test Loss: 0.010919
#
# Temp Loss: 0.080146
#
# Test Loss: 0.029732
#
# Temp Loss: 0.088537
#
# Epoch: 89, Train Loss Decreased!! (0.013202-->0.013054)
# Test Loss: 0.010550
#
# Temp Loss: 0.079747
#
# Test Loss: 0.028336
#
# Temp Loss: 0.087458
#
# Epoch: 91, Train Loss Decreased!! (0.013054-->0.012853)
# Test Loss: 0.010497
#
# Temp Loss: 0.079682
#
# Test Loss: 0.028128
#
# Temp Loss: 0.087436
#
# Epoch: 93, Train Loss Decreased!! (0.012853-->0.012096)
# Test Loss: 0.010074
#
# Temp Loss: 0.080155
#
# Test Loss: 0.028018
#
# Temp Loss: 0.088003
#
# Test Loss: 0.009756
#
# Temp Loss: 0.079844
#
# Test Loss: 0.028046
#
# Temp Loss: 0.088111
#
# Epoch: 97, Train Loss Decreased!! (0.012096-->0.011869)
# Test Loss: 0.009569
#
# Temp Loss: 0.080206
#
# Test Loss: 0.027702
#
# Temp Loss: 0.088251
#
# Epoch: 99, Train Loss Decreased!! (0.011869-->0.011709)
# Test Loss: 0.009262
#
# Temp Loss: 0.080364
#  40%|████      | 2/5 [04:06<06:09, 123.29s/it]
# Test Loss: 0.026603
#
# Temp Loss: 0.087529
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.299612)
# Test Loss: 0.253688
#
# Temp Loss: 0.253837
#
# Epoch: 2, Train Loss Decreased!! (0.299612-->0.252980)
# Test Loss: 0.253118
#
# Temp Loss: 0.253519
#
# Epoch: 3, Train Loss Decreased!! (0.252980-->0.249661)
# Test Loss: 0.240260
#
# Temp Loss: 0.241193
#
# Epoch: 4, Train Loss Decreased!! (0.249661-->0.240655)
# Test Loss: 0.240921
#
# Temp Loss: 0.241704
#
# Epoch: 5, Train Loss Decreased!! (0.240655-->0.230661)
# Test Loss: 0.222470
#
# Temp Loss: 0.225247
#
# Epoch: 6, Train Loss Decreased!! (0.230661-->0.224205)
# Test Loss: 0.227635
#
# Temp Loss: 0.230355
#
# Epoch: 7, Train Loss Decreased!! (0.224205-->0.213005)
# Test Loss: 0.203437
#
# Temp Loss: 0.221678
#
# Epoch: 8, Train Loss Decreased!! (0.213005-->0.205304)
# Test Loss: 0.210902
#
# Temp Loss: 0.228603
#
# Epoch: 9, Train Loss Decreased!! (0.205304-->0.194463)
# Test Loss: 0.186154
#
# Temp Loss: 0.214081
#
# Epoch: 10, Train Loss Decreased!! (0.194463-->0.186298)
# Test Loss: 0.192720
#
# Temp Loss: 0.220794
#
# Epoch: 11, Train Loss Decreased!! (0.186298-->0.178059)
# Test Loss: 0.169242
#
# Temp Loss: 0.198843
#
# Epoch: 12, Train Loss Decreased!! (0.178059-->0.169645)
# Test Loss: 0.174494
#
# Temp Loss: 0.203682
#
# Epoch: 13, Train Loss Decreased!! (0.169645-->0.159725)
# Test Loss: 0.151535
#
# Temp Loss: 0.183623
#
# Epoch: 14, Train Loss Decreased!! (0.159725-->0.152691)
# Test Loss: 0.159910
#
# Temp Loss: 0.189119
#
# Epoch: 15, Train Loss Decreased!! (0.152691-->0.143984)
# Test Loss: 0.137840
#
# Temp Loss: 0.171357
#
# Epoch: 16, Train Loss Decreased!! (0.143984-->0.142143)
# Test Loss: 0.155521
#
# Temp Loss: 0.185678
#
# Epoch: 17, Train Loss Decreased!! (0.142143-->0.133599)
# Test Loss: 0.127277
#
# Temp Loss: 0.162190
#
# Epoch: 18, Train Loss Decreased!! (0.133599-->0.128995)
# Test Loss: 0.139103
#
# Temp Loss: 0.171916
#
# Epoch: 19, Train Loss Decreased!! (0.128995-->0.122111)
# Test Loss: 0.118014
#
# Temp Loss: 0.151638
#
# Epoch: 20, Train Loss Decreased!! (0.122111-->0.118455)
# Test Loss: 0.128092
#
# Temp Loss: 0.161133
#
# Epoch: 21, Train Loss Decreased!! (0.118455-->0.112675)
# Test Loss: 0.110010
#
# Temp Loss: 0.143119
#
# Epoch: 22, Train Loss Decreased!! (0.112675-->0.111183)
# Test Loss: 0.120580
#
# Temp Loss: 0.152813
#
# Epoch: 23, Train Loss Decreased!! (0.111183-->0.108061)
# Test Loss: 0.107146
#
# Temp Loss: 0.139894
#
# Epoch: 24, Train Loss Decreased!! (0.108061-->0.107000)
# Test Loss: 0.114134
#
# Temp Loss: 0.146110
#
# Epoch: 25, Train Loss Decreased!! (0.107000-->0.105063)
# Test Loss: 0.105214
#
# Temp Loss: 0.138283
#
# Epoch: 26, Train Loss Decreased!! (0.105063-->0.104321)
# Test Loss: 0.111066
#
# Temp Loss: 0.143339
#
# Epoch: 27, Train Loss Decreased!! (0.104321-->0.102191)
# Test Loss: 0.100995
#
# Temp Loss: 0.134950
#
# Epoch: 28, Train Loss Decreased!! (0.102191-->0.100115)
# Test Loss: 0.106395
#
# Temp Loss: 0.139787
#
# Epoch: 29, Train Loss Decreased!! (0.100115-->0.094446)
# Test Loss: 0.091975
#
# Temp Loss: 0.127752
#
# Epoch: 30, Train Loss Decreased!! (0.094446-->0.090865)
# Test Loss: 0.097240
#
# Temp Loss: 0.132638
#
# Epoch: 31, Train Loss Decreased!! (0.090865-->0.087713)
# Test Loss: 0.086275
#
# Temp Loss: 0.122731
#
# Epoch: 32, Train Loss Decreased!! (0.087713-->0.086026)
# Test Loss: 0.093223
#
# Temp Loss: 0.128247
#
# Epoch: 33, Train Loss Decreased!! (0.086026-->0.080497)
# Test Loss: 0.076260
#
# Temp Loss: 0.113703
#
# Epoch: 34, Train Loss Decreased!! (0.080497-->0.079933)
# Test Loss: 0.090192
#
# Temp Loss: 0.125942
#
# Epoch: 35, Train Loss Decreased!! (0.079933-->0.073987)
# Test Loss: 0.070001
#
# Temp Loss: 0.109474
#
# Epoch: 36, Train Loss Decreased!! (0.073987-->0.072094)
# Test Loss: 0.079977
#
# Temp Loss: 0.118213
#
# Epoch: 37, Train Loss Decreased!! (0.072094-->0.066854)
# Test Loss: 0.062213
#
# Temp Loss: 0.104139
#
# Epoch: 38, Train Loss Decreased!! (0.066854-->0.064073)
# Test Loss: 0.070415
#
# Temp Loss: 0.111513
#
# Epoch: 39, Train Loss Decreased!! (0.064073-->0.059836)
# Test Loss: 0.057042
#
# Temp Loss: 0.100765
#
# Epoch: 40, Train Loss Decreased!! (0.059836-->0.059001)
# Test Loss: 0.064867
#
# Temp Loss: 0.107887
#
# Epoch: 41, Train Loss Decreased!! (0.059001-->0.056010)
# Test Loss: 0.054183
#
# Temp Loss: 0.099965
#
# Epoch: 42, Train Loss Decreased!! (0.056010-->0.055726)
# Test Loss: 0.061196
#
# Temp Loss: 0.106109
#
# Epoch: 43, Train Loss Decreased!! (0.055726-->0.053257)
# Test Loss: 0.051819
#
# Temp Loss: 0.098844
#
# Epoch: 44, Train Loss Decreased!! (0.053257-->0.053242)
# Test Loss: 0.058480
#
# Temp Loss: 0.104111
#
# Epoch: 45, Train Loss Decreased!! (0.053242-->0.050193)
# Test Loss: 0.047574
#
# Temp Loss: 0.095607
#
# Epoch: 46, Train Loss Decreased!! (0.050193-->0.048463)
# Test Loss: 0.053830
#
# Temp Loss: 0.100224
#
# Epoch: 47, Train Loss Decreased!! (0.048463-->0.044690)
# Test Loss: 0.042544
#
# Temp Loss: 0.091855
#
# Epoch: 48, Train Loss Decreased!! (0.044690-->0.043855)
# Test Loss: 0.049677
#
# Temp Loss: 0.097469
#
# Epoch: 49, Train Loss Decreased!! (0.043855-->0.041113)
# Test Loss: 0.039300
#
# Temp Loss: 0.091011
#
# Epoch: 50, Train Loss Decreased!! (0.041113-->0.040836)
# Test Loss: 0.046288
#
# Temp Loss: 0.095575
#
# Epoch: 51, Train Loss Decreased!! (0.040836-->0.038647)
# Test Loss: 0.037465
#
# Temp Loss: 0.090404
#
# Test Loss: 0.044338
#
# Temp Loss: 0.093465
#
# Epoch: 53, Train Loss Decreased!! (0.038647-->0.036541)
# Test Loss: 0.035353
#
# Temp Loss: 0.090000
#
# Test Loss: 0.042756
#
# Temp Loss: 0.093423
#
# Epoch: 55, Train Loss Decreased!! (0.036541-->0.034437)
# Test Loss: 0.032899
#
# Temp Loss: 0.088865
#
# Test Loss: 0.042719
#
# Temp Loss: 0.094551
#
# Epoch: 57, Train Loss Decreased!! (0.034437-->0.032860)
# Test Loss: 0.030959
#
# Temp Loss: 0.087715
#
# Test Loss: 0.042439
#
# Temp Loss: 0.094991
#
# Epoch: 59, Train Loss Decreased!! (0.032860-->0.031153)
# Test Loss: 0.028970
#
# Temp Loss: 0.086985
#
# Test Loss: 0.043131
#
# Temp Loss: 0.097412
#
# Epoch: 61, Train Loss Decreased!! (0.031153-->0.029855)
# Test Loss: 0.027508
#
# Temp Loss: 0.086411
#
# Test Loss: 0.041434
#
# Temp Loss: 0.096413
#
# Epoch: 63, Train Loss Decreased!! (0.029855-->0.028179)
# Test Loss: 0.025669
#
# Temp Loss: 0.085062
#
# Test Loss: 0.040760
#
# Temp Loss: 0.095795
#
# Epoch: 65, Train Loss Decreased!! (0.028179-->0.026288)
# Test Loss: 0.023432
#
# Temp Loss: 0.083719
#
# Test Loss: 0.037945
#
# Temp Loss: 0.094288
#
# Epoch: 67, Train Loss Decreased!! (0.026288-->0.023755)
# Test Loss: 0.020790
#
# Temp Loss: 0.081514
#
# Test Loss: 0.036858
#
# Temp Loss: 0.094085
#
# Epoch: 69, Train Loss Decreased!! (0.023755-->0.021534)
# Test Loss: 0.018420
#
# Temp Loss: 0.080852
#
# Test Loss: 0.034901
#
# Temp Loss: 0.094204
#
# Epoch: 71, Train Loss Decreased!! (0.021534-->0.019463)
# Test Loss: 0.016400
#
# Temp Loss: 0.079806
#
# Test Loss: 0.033105
#
# Temp Loss: 0.092336
#
# Epoch: 73, Train Loss Decreased!! (0.019463-->0.017507)
# Test Loss: 0.013977
#
# Temp Loss: 0.079953
#
# Test Loss: 0.031540
#
# Temp Loss: 0.092237
#
# Epoch: 75, Train Loss Decreased!! (0.017507-->0.015710)
# Test Loss: 0.012620
#
# Temp Loss: 0.080287
#
# Test Loss: 0.033636
#
# Temp Loss: 0.094511
#
# Epoch: 77, Train Loss Decreased!! (0.015710-->0.015007)
# Test Loss: 0.011401
#
# Temp Loss: 0.080085
#
# Test Loss: 0.031859
#
# Temp Loss: 0.092443
#
# Epoch: 79, Train Loss Decreased!! (0.015007-->0.013454)
# Test Loss: 0.010458
#
# Temp Loss: 0.080640
#
# Test Loss: 0.032356
#
# Temp Loss: 0.093684
#
# Epoch: 81, Train Loss Decreased!! (0.013454-->0.012816)
# Test Loss: 0.009560
#
# Temp Loss: 0.080158
#
# Test Loss: 0.033396
#
# Temp Loss: 0.094410
#
# Epoch: 83, Train Loss Decreased!! (0.012816-->0.012543)
# Test Loss: 0.009040
#
# Temp Loss: 0.080327
#
# Test Loss: 0.033655
#
# Temp Loss: 0.094383
#
# Epoch: 85, Train Loss Decreased!! (0.012543-->0.012098)
# Test Loss: 0.008445
#
# Temp Loss: 0.080839
#
# Test Loss: 0.034161
#
# Temp Loss: 0.095365
#
# Epoch: 87, Train Loss Decreased!! (0.012098-->0.011526)
# Test Loss: 0.008114
#
# Temp Loss: 0.080983
#
# Test Loss: 0.034536
#
# Temp Loss: 0.095337
#
# Test Loss: 0.008131
#
# Temp Loss: 0.081070
#
# Test Loss: 0.033292
#
# Temp Loss: 0.094798
#
# Epoch: 91, Train Loss Decreased!! (0.011526-->0.011287)
# Test Loss: 0.007647
#
# Temp Loss: 0.080690
#
# Test Loss: 0.031357
#
# Temp Loss: 0.093550
#
# Epoch: 93, Train Loss Decreased!! (0.011287-->0.010388)
# Test Loss: 0.007187
#
# Temp Loss: 0.081068
#
# Test Loss: 0.032398
#
# Temp Loss: 0.094616
#
# Test Loss: 0.007206
#
# Temp Loss: 0.081424
#
# Test Loss: 0.031264
#
# Temp Loss: 0.093997
#
# Epoch: 97, Train Loss Decreased!! (0.010388-->0.010109)
# Test Loss: 0.006733
#
# Temp Loss: 0.080997
#
# Test Loss: 0.030569
#
# Temp Loss: 0.093711
#
# Epoch: 99, Train Loss Decreased!! (0.010109-->0.009992)
# Test Loss: 0.006614
#
# Temp Loss: 0.081954
#  60%|██████    | 3/5 [06:09<04:05, 122.95s/it]
# Test Loss: 0.030904
#
# Temp Loss: 0.094453
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.295898)
# Test Loss: 0.253532
#
# Temp Loss: 0.253644
#
# Epoch: 2, Train Loss Decreased!! (0.295898-->0.252583)
# Test Loss: 0.253121
#
# Temp Loss: 0.252807
#
# Epoch: 3, Train Loss Decreased!! (0.252583-->0.244644)
# Test Loss: 0.235148
#
# Temp Loss: 0.236574
#
# Epoch: 4, Train Loss Decreased!! (0.244644-->0.235834)
# Test Loss: 0.237695
#
# Temp Loss: 0.238467
#
# Epoch: 5, Train Loss Decreased!! (0.235834-->0.226266)
# Test Loss: 0.219081
#
# Temp Loss: 0.228080
#
# Epoch: 6, Train Loss Decreased!! (0.226266-->0.219661)
# Test Loss: 0.220833
#
# Temp Loss: 0.229198
#
# Epoch: 7, Train Loss Decreased!! (0.219661-->0.211181)
# Test Loss: 0.195908
#
# Temp Loss: 0.222150
#
# Epoch: 8, Train Loss Decreased!! (0.211181-->0.196339)
# Test Loss: 0.198692
#
# Temp Loss: 0.223743
#
# Epoch: 9, Train Loss Decreased!! (0.196339-->0.187717)
# Test Loss: 0.182138
#
# Temp Loss: 0.213339
#
# Epoch: 10, Train Loss Decreased!! (0.187717-->0.183912)
# Test Loss: 0.188230
#
# Temp Loss: 0.216998
#
# Epoch: 11, Train Loss Decreased!! (0.183912-->0.176004)
# Test Loss: 0.167132
#
# Temp Loss: 0.198779
#
# Epoch: 12, Train Loss Decreased!! (0.176004-->0.170915)
# Test Loss: 0.177090
#
# Temp Loss: 0.206219
#
# Epoch: 13, Train Loss Decreased!! (0.170915-->0.160501)
# Test Loss: 0.153759
#
# Temp Loss: 0.183947
#
# Epoch: 14, Train Loss Decreased!! (0.160501-->0.155189)
# Test Loss: 0.160286
#
# Temp Loss: 0.189202
#
# Epoch: 15, Train Loss Decreased!! (0.155189-->0.149958)
# Test Loss: 0.143844
#
# Temp Loss: 0.177301
#
# Epoch: 16, Train Loss Decreased!! (0.149958-->0.147229)
# Test Loss: 0.153667
#
# Temp Loss: 0.183370
#
# Epoch: 17, Train Loss Decreased!! (0.147229-->0.140574)
# Test Loss: 0.136459
#
# Temp Loss: 0.169163
#
# Epoch: 18, Train Loss Decreased!! (0.140574-->0.138869)
# Test Loss: 0.146491
#
# Temp Loss: 0.176150
#
# Epoch: 19, Train Loss Decreased!! (0.138869-->0.132256)
# Test Loss: 0.125373
#
# Temp Loss: 0.157862
#
# Epoch: 20, Train Loss Decreased!! (0.132256-->0.126610)
# Test Loss: 0.133765
#
# Temp Loss: 0.164402
#
# Epoch: 21, Train Loss Decreased!! (0.126610-->0.118905)
# Test Loss: 0.111751
#
# Temp Loss: 0.144795
#
# Epoch: 22, Train Loss Decreased!! (0.118905-->0.113290)
# Test Loss: 0.119439
#
# Temp Loss: 0.150658
#
# Epoch: 23, Train Loss Decreased!! (0.113290-->0.108529)
# Test Loss: 0.105427
#
# Temp Loss: 0.140725
#
# Epoch: 24, Train Loss Decreased!! (0.108529-->0.106146)
# Test Loss: 0.111491
#
# Temp Loss: 0.144640
#
# Epoch: 25, Train Loss Decreased!! (0.106146-->0.101682)
# Test Loss: 0.099006
#
# Temp Loss: 0.137860
#
# Epoch: 26, Train Loss Decreased!! (0.101682-->0.099541)
# Test Loss: 0.104854
#
# Temp Loss: 0.141521
#
# Epoch: 27, Train Loss Decreased!! (0.099541-->0.095088)
# Test Loss: 0.091089
#
# Temp Loss: 0.128383
#
# Epoch: 28, Train Loss Decreased!! (0.095088-->0.092030)
# Test Loss: 0.097602
#
# Temp Loss: 0.133181
#
# Epoch: 29, Train Loss Decreased!! (0.092030-->0.087804)
# Test Loss: 0.083740
#
# Temp Loss: 0.123523
#
# Epoch: 30, Train Loss Decreased!! (0.087804-->0.087398)
# Test Loss: 0.093861
#
# Temp Loss: 0.131124
#
# Epoch: 31, Train Loss Decreased!! (0.087398-->0.082509)
# Test Loss: 0.078080
#
# Temp Loss: 0.117821
#
# Epoch: 32, Train Loss Decreased!! (0.082509-->0.081922)
# Test Loss: 0.089332
#
# Temp Loss: 0.126824
#
# Epoch: 33, Train Loss Decreased!! (0.081922-->0.073626)
# Test Loss: 0.068348
#
# Temp Loss: 0.108209
#
# Test Loss: 0.081999
#
# Temp Loss: 0.121335
#
# Epoch: 35, Train Loss Decreased!! (0.073626-->0.068150)
# Test Loss: 0.065184
#
# Temp Loss: 0.105782
#
# Test Loss: 0.077522
#
# Temp Loss: 0.116773
#
# Epoch: 37, Train Loss Decreased!! (0.068150-->0.064699)
# Test Loss: 0.061395
#
# Temp Loss: 0.102454
#
# Test Loss: 0.073867
#
# Temp Loss: 0.112504
#
# Epoch: 39, Train Loss Decreased!! (0.064699-->0.060374)
# Test Loss: 0.056548
#
# Temp Loss: 0.099118
#
# Test Loss: 0.073017
#
# Temp Loss: 0.111474
#
# Epoch: 41, Train Loss Decreased!! (0.060374-->0.056130)
# Test Loss: 0.051678
#
# Temp Loss: 0.096945
#
# Test Loss: 0.066328
#
# Temp Loss: 0.107161
#
# Epoch: 43, Train Loss Decreased!! (0.056130-->0.051431)
# Test Loss: 0.047002
#
# Temp Loss: 0.096215
#
# Epoch: 44, Train Loss Decreased!! (0.051431-->0.050682)
# Test Loss: 0.059304
#
# Temp Loss: 0.103856
#
# Epoch: 45, Train Loss Decreased!! (0.050682-->0.045470)
# Test Loss: 0.040615
#
# Temp Loss: 0.092827
#
# Epoch: 46, Train Loss Decreased!! (0.045470-->0.044488)
# Test Loss: 0.052245
#
# Temp Loss: 0.098892
#
# Epoch: 47, Train Loss Decreased!! (0.044488-->0.040780)
# Test Loss: 0.036993
#
# Temp Loss: 0.089863
#
# Test Loss: 0.049163
#
# Temp Loss: 0.095501
#
# Epoch: 49, Train Loss Decreased!! (0.040780-->0.037827)
# Test Loss: 0.034187
#
# Temp Loss: 0.088541
#
# Test Loss: 0.048532
#
# Temp Loss: 0.094963
#
# Epoch: 51, Train Loss Decreased!! (0.037827-->0.035747)
# Test Loss: 0.032126
#
# Temp Loss: 0.086859
#
# Test Loss: 0.045602
#
# Temp Loss: 0.093566
#
# Epoch: 53, Train Loss Decreased!! (0.035747-->0.033260)
# Test Loss: 0.029923
#
# Temp Loss: 0.085548
#
# Test Loss: 0.045775
#
# Temp Loss: 0.094584
#
# Epoch: 55, Train Loss Decreased!! (0.033260-->0.031841)
# Test Loss: 0.027991
#
# Temp Loss: 0.085299
#
# Test Loss: 0.044527
#
# Temp Loss: 0.094959
#
# Epoch: 57, Train Loss Decreased!! (0.031841-->0.030118)
# Test Loss: 0.026120
#
# Temp Loss: 0.085012
#
# Test Loss: 0.044581
#
# Temp Loss: 0.096464
#
# Epoch: 59, Train Loss Decreased!! (0.030118-->0.028285)
# Test Loss: 0.023848
#
# Temp Loss: 0.085082
#
# Test Loss: 0.043270
#
# Temp Loss: 0.096535
#
# Epoch: 61, Train Loss Decreased!! (0.028285-->0.025800)
# Test Loss: 0.021165
#
# Temp Loss: 0.083448
#
# Test Loss: 0.042677
#
# Temp Loss: 0.095936
#
# Epoch: 63, Train Loss Decreased!! (0.025800-->0.023538)
# Test Loss: 0.018253
#
# Temp Loss: 0.080986
#
# Test Loss: 0.038712
#
# Temp Loss: 0.091812
#
# Epoch: 65, Train Loss Decreased!! (0.023538-->0.020765)
# Test Loss: 0.015933
#
# Temp Loss: 0.081074
#
# Test Loss: 0.035411
#
# Temp Loss: 0.090541
#
# Epoch: 67, Train Loss Decreased!! (0.020765-->0.018515)
# Test Loss: 0.014182
#
# Temp Loss: 0.081371
#
# Test Loss: 0.033470
#
# Temp Loss: 0.089959
#
# Epoch: 69, Train Loss Decreased!! (0.018515-->0.016601)
# Test Loss: 0.012563
#
# Temp Loss: 0.081914
#
# Test Loss: 0.032322
#
# Temp Loss: 0.090726
#
# Epoch: 71, Train Loss Decreased!! (0.016601-->0.015446)
# Test Loss: 0.011638
#
# Temp Loss: 0.081751
#
# Test Loss: 0.031647
#
# Temp Loss: 0.090683
#
# Epoch: 73, Train Loss Decreased!! (0.015446-->0.014542)
# Test Loss: 0.010738
#
# Temp Loss: 0.082496
#
# Test Loss: 0.029872
#
# Temp Loss: 0.090898
#
# Epoch: 75, Train Loss Decreased!! (0.014542-->0.013581)
# Test Loss: 0.010072
#
# Temp Loss: 0.082589
#
# Test Loss: 0.029572
#
# Temp Loss: 0.091363
#
# Epoch: 77, Train Loss Decreased!! (0.013581-->0.012889)
# Test Loss: 0.009608
#
# Temp Loss: 0.082644
#
# Test Loss: 0.029575
#
# Temp Loss: 0.092124
#
# Epoch: 79, Train Loss Decreased!! (0.012889-->0.012785)
# Test Loss: 0.009116
#
# Temp Loss: 0.082940
#
# Test Loss: 0.029026
#
# Temp Loss: 0.092189
#
# Epoch: 81, Train Loss Decreased!! (0.012785-->0.012078)
# Test Loss: 0.008816
#
# Temp Loss: 0.083186
#
# Test Loss: 0.028032
#
# Temp Loss: 0.092234
#
# Epoch: 83, Train Loss Decreased!! (0.012078-->0.011668)
# Test Loss: 0.008409
#
# Temp Loss: 0.083831
#
# Test Loss: 0.027838
#
# Temp Loss: 0.092785
#
# Epoch: 85, Train Loss Decreased!! (0.011668-->0.011614)
# Test Loss: 0.008103
#
# Temp Loss: 0.083740
#
# Test Loss: 0.027271
#
# Temp Loss: 0.093230
#
# Epoch: 87, Train Loss Decreased!! (0.011614-->0.011300)
# Test Loss: 0.007895
#
# Temp Loss: 0.083727
#
# Test Loss: 0.025893
#
# Temp Loss: 0.092110
#
# Epoch: 89, Train Loss Decreased!! (0.011300-->0.010861)
# Test Loss: 0.007597
#
# Temp Loss: 0.083518
#
# Test Loss: 0.026278
#
# Temp Loss: 0.092772
#
# Epoch: 91, Train Loss Decreased!! (0.010861-->0.010709)
# Test Loss: 0.007652
#
# Temp Loss: 0.083334
#
# Test Loss: 0.025578
#
# Temp Loss: 0.092181
#
# Epoch: 93, Train Loss Decreased!! (0.010709-->0.010543)
# Test Loss: 0.007511
#
# Temp Loss: 0.084378
#
# Test Loss: 0.025784
#
# Temp Loss: 0.093276
#
# Epoch: 95, Train Loss Decreased!! (0.010543-->0.010242)
# Test Loss: 0.007099
#
# Temp Loss: 0.083953
#
# Test Loss: 0.025201
#
# Temp Loss: 0.092533
#
# Epoch: 97, Train Loss Decreased!! (0.010242-->0.010049)
# Test Loss: 0.006990
#
# Temp Loss: 0.083510
#
# Test Loss: 0.024838
#
# Temp Loss: 0.091985
#
# Epoch: 99, Train Loss Decreased!! (0.010049-->0.009883)
# Test Loss: 0.006767
#
# Temp Loss: 0.083820
#  80%|████████  | 4/5 [08:12<02:02, 122.95s/it]
# Test Loss: 0.025331
#
# Temp Loss: 0.092576
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.282582)
# Test Loss: 0.252542
#
# Temp Loss: 0.252512
#
# Epoch: 2, Train Loss Decreased!! (0.282582-->0.251955)
# Test Loss: 0.251968
#
# Temp Loss: 0.252147
#
# Epoch: 3, Train Loss Decreased!! (0.251955-->0.246205)
# Test Loss: 0.238695
#
# Temp Loss: 0.239349
#
# Epoch: 4, Train Loss Decreased!! (0.246205-->0.240127)
# Test Loss: 0.240524
#
# Temp Loss: 0.241361
#
# Epoch: 5, Train Loss Decreased!! (0.240127-->0.226335)
# Test Loss: 0.208952
#
# Temp Loss: 0.223875
#
# Epoch: 6, Train Loss Decreased!! (0.226335-->0.208117)
# Test Loss: 0.209362
#
# Temp Loss: 0.224049
#
# Epoch: 7, Train Loss Decreased!! (0.208117-->0.197256)
# Test Loss: 0.187691
#
# Temp Loss: 0.217157
#
# Epoch: 8, Train Loss Decreased!! (0.197256-->0.187673)
# Test Loss: 0.189534
#
# Temp Loss: 0.218942
#
# Epoch: 9, Train Loss Decreased!! (0.187673-->0.181728)
# Test Loss: 0.172831
#
# Temp Loss: 0.202409
#
# Epoch: 10, Train Loss Decreased!! (0.181728-->0.173760)
# Test Loss: 0.177335
#
# Temp Loss: 0.205987
#
# Epoch: 11, Train Loss Decreased!! (0.173760-->0.165586)
# Test Loss: 0.155413
#
# Temp Loss: 0.186151
#
# Epoch: 12, Train Loss Decreased!! (0.165586-->0.159237)
# Test Loss: 0.167505
#
# Temp Loss: 0.194698
#
# Epoch: 13, Train Loss Decreased!! (0.159237-->0.147062)
# Test Loss: 0.140546
#
# Temp Loss: 0.171608
#
# Epoch: 14, Train Loss Decreased!! (0.147062-->0.141172)
# Test Loss: 0.147879
#
# Temp Loss: 0.177312
#
# Epoch: 15, Train Loss Decreased!! (0.141172-->0.134109)
# Test Loss: 0.127909
#
# Temp Loss: 0.159659
#
# Epoch: 16, Train Loss Decreased!! (0.134109-->0.130099)
# Test Loss: 0.137218
#
# Temp Loss: 0.167872
#
# Epoch: 17, Train Loss Decreased!! (0.130099-->0.124308)
# Test Loss: 0.120461
#
# Temp Loss: 0.152530
#
# Epoch: 18, Train Loss Decreased!! (0.124308-->0.120920)
# Test Loss: 0.126288
#
# Temp Loss: 0.156422
#
# Epoch: 19, Train Loss Decreased!! (0.120920-->0.113854)
# Test Loss: 0.109120
#
# Temp Loss: 0.143043
#
# Epoch: 20, Train Loss Decreased!! (0.113854-->0.110899)
# Test Loss: 0.118431
#
# Temp Loss: 0.150771
#
# Epoch: 21, Train Loss Decreased!! (0.110899-->0.104825)
# Test Loss: 0.099286
#
# Temp Loss: 0.133883
#
# Epoch: 22, Train Loss Decreased!! (0.104825-->0.101991)
# Test Loss: 0.110544
#
# Temp Loss: 0.143365
#
# Epoch: 23, Train Loss Decreased!! (0.101991-->0.095815)
# Test Loss: 0.092088
#
# Temp Loss: 0.126208
#
# Epoch: 24, Train Loss Decreased!! (0.095815-->0.093757)
# Test Loss: 0.100664
#
# Temp Loss: 0.132758
#
# Epoch: 25, Train Loss Decreased!! (0.093757-->0.090468)
# Test Loss: 0.086934
#
# Temp Loss: 0.122984
#
# Epoch: 26, Train Loss Decreased!! (0.090468-->0.087735)
# Test Loss: 0.093384
#
# Temp Loss: 0.127667
#
# Epoch: 27, Train Loss Decreased!! (0.087735-->0.082891)
# Test Loss: 0.078307
#
# Temp Loss: 0.115219
#
# Epoch: 28, Train Loss Decreased!! (0.082891-->0.079859)
# Test Loss: 0.085623
#
# Temp Loss: 0.120294
#
# Epoch: 29, Train Loss Decreased!! (0.079859-->0.076634)
# Test Loss: 0.073912
#
# Temp Loss: 0.109536
#
# Epoch: 30, Train Loss Decreased!! (0.076634-->0.075441)
# Test Loss: 0.081363
#
# Temp Loss: 0.114775
#
# Epoch: 31, Train Loss Decreased!! (0.075441-->0.072111)
# Test Loss: 0.068452
#
# Temp Loss: 0.106958
#
# Test Loss: 0.080462
#
# Temp Loss: 0.116479
#
# Epoch: 33, Train Loss Decreased!! (0.072111-->0.067799)
# Test Loss: 0.064569
#
# Temp Loss: 0.103003
#
# Epoch: 34, Train Loss Decreased!! (0.067799-->0.066747)
# Test Loss: 0.073785
#
# Temp Loss: 0.110354
#
# Epoch: 35, Train Loss Decreased!! (0.066747-->0.062866)
# Test Loss: 0.058564
#
# Temp Loss: 0.096930
#
# Epoch: 36, Train Loss Decreased!! (0.062866-->0.060213)
# Test Loss: 0.065201
#
# Temp Loss: 0.101633
#
# Epoch: 37, Train Loss Decreased!! (0.060213-->0.057489)
# Test Loss: 0.054889
#
# Temp Loss: 0.095123
#
# Epoch: 38, Train Loss Decreased!! (0.057489-->0.057403)
# Test Loss: 0.062786
#
# Temp Loss: 0.100088
#
# Epoch: 39, Train Loss Decreased!! (0.057403-->0.054812)
# Test Loss: 0.052750
#
# Temp Loss: 0.093741
#
# Epoch: 40, Train Loss Decreased!! (0.054812-->0.054659)
# Test Loss: 0.059044
#
# Temp Loss: 0.097525
#
# Epoch: 41, Train Loss Decreased!! (0.054659-->0.052848)
# Test Loss: 0.050575
#
# Temp Loss: 0.092181
#
# Epoch: 42, Train Loss Decreased!! (0.052848-->0.052695)
# Test Loss: 0.057707
#
# Temp Loss: 0.096227
#
# Epoch: 43, Train Loss Decreased!! (0.052695-->0.049394)
# Test Loss: 0.045139
#
# Temp Loss: 0.090226
#
# Epoch: 44, Train Loss Decreased!! (0.049394-->0.048113)
# Test Loss: 0.054142
#
# Temp Loss: 0.096037
#
# Epoch: 45, Train Loss Decreased!! (0.048113-->0.044706)
# Test Loss: 0.041750
#
# Temp Loss: 0.088304
#
# Test Loss: 0.050860
#
# Temp Loss: 0.094743
#
# Epoch: 47, Train Loss Decreased!! (0.044706-->0.042399)
# Test Loss: 0.039867
#
# Temp Loss: 0.089102
#
# Epoch: 48, Train Loss Decreased!! (0.042399-->0.042371)
# Test Loss: 0.047527
#
# Temp Loss: 0.093559
#
# Epoch: 49, Train Loss Decreased!! (0.042371-->0.040365)
# Test Loss: 0.038080
#
# Temp Loss: 0.089926
#
# Epoch: 50, Train Loss Decreased!! (0.040365-->0.040322)
# Test Loss: 0.044882
#
# Temp Loss: 0.093218
#
# Epoch: 51, Train Loss Decreased!! (0.040322-->0.038037)
# Test Loss: 0.035184
#
# Temp Loss: 0.089889
#
# Epoch: 52, Train Loss Decreased!! (0.038037-->0.037451)
# Test Loss: 0.041854
#
# Temp Loss: 0.092595
#
# Epoch: 53, Train Loss Decreased!! (0.037451-->0.034465)
# Test Loss: 0.031499
#
# Temp Loss: 0.091168
#
# Epoch: 54, Train Loss Decreased!! (0.034465-->0.034438)
# Test Loss: 0.039013
#
# Temp Loss: 0.095218
#
# Epoch: 55, Train Loss Decreased!! (0.034438-->0.031942)
# Test Loss: 0.029579
#
# Temp Loss: 0.090743
#
# Test Loss: 0.038690
#
# Temp Loss: 0.097111
#
# Epoch: 57, Train Loss Decreased!! (0.031942-->0.030607)
# Test Loss: 0.028139
#
# Temp Loss: 0.091334
#
# Test Loss: 0.039514
#
# Temp Loss: 0.099406
#
# Epoch: 59, Train Loss Decreased!! (0.030607-->0.029254)
# Test Loss: 0.026438
#
# Temp Loss: 0.090677
#
# Test Loss: 0.042265
#
# Temp Loss: 0.104629
#
# Epoch: 61, Train Loss Decreased!! (0.029254-->0.028319)
# Test Loss: 0.024810
#
# Temp Loss: 0.090133
#
# Test Loss: 0.044125
#
# Temp Loss: 0.107373
#
# Epoch: 63, Train Loss Decreased!! (0.028319-->0.027926)
# Test Loss: 0.024199
#
# Temp Loss: 0.090327
#
# Test Loss: 0.043580
#
# Temp Loss: 0.106953
#
# Epoch: 65, Train Loss Decreased!! (0.027926-->0.026655)
# Test Loss: 0.023118
#
# Temp Loss: 0.089395
#
# Test Loss: 0.040733
#
# Temp Loss: 0.103926
#
# Epoch: 67, Train Loss Decreased!! (0.026655-->0.025400)
# Test Loss: 0.021557
#
# Temp Loss: 0.086986
#
# Test Loss: 0.036965
#
# Temp Loss: 0.098643
#
# Epoch: 69, Train Loss Decreased!! (0.025400-->0.023365)
# Test Loss: 0.020202
#
# Temp Loss: 0.085761
#
# Test Loss: 0.035796
#
# Temp Loss: 0.097051
#
# Epoch: 71, Train Loss Decreased!! (0.023365-->0.021937)
# Test Loss: 0.019301
#
# Temp Loss: 0.085516
#
# Test Loss: 0.033542
#
# Temp Loss: 0.095128
#
# Epoch: 73, Train Loss Decreased!! (0.021937-->0.020832)
# Test Loss: 0.017879
#
# Temp Loss: 0.084263
#
# Test Loss: 0.032817
#
# Temp Loss: 0.093923
#
# Epoch: 75, Train Loss Decreased!! (0.020832-->0.019594)
# Test Loss: 0.016346
#
# Temp Loss: 0.083318
#
# Test Loss: 0.032839
#
# Temp Loss: 0.093809
#
# Epoch: 77, Train Loss Decreased!! (0.019594-->0.017772)
# Test Loss: 0.014888
#
# Temp Loss: 0.082258
#
# Test Loss: 0.032958
#
# Temp Loss: 0.093262
#
# Epoch: 79, Train Loss Decreased!! (0.017772-->0.017061)
# Test Loss: 0.013838
#
# Temp Loss: 0.082962
#
# Test Loss: 0.032868
#
# Temp Loss: 0.093873
#
# Epoch: 81, Train Loss Decreased!! (0.017061-->0.016441)
# Test Loss: 0.013190
#
# Temp Loss: 0.082005
#
# Test Loss: 0.030987
#
# Temp Loss: 0.092561
#
# Epoch: 83, Train Loss Decreased!! (0.016441-->0.015464)
# Test Loss: 0.012604
#
# Temp Loss: 0.081870
#
# Test Loss: 0.030076
#
# Temp Loss: 0.091660
#
# Epoch: 85, Train Loss Decreased!! (0.015464-->0.015032)
# Test Loss: 0.011914
#
# Temp Loss: 0.081927
#
# Test Loss: 0.028278
#
# Temp Loss: 0.090949
#
# Epoch: 87, Train Loss Decreased!! (0.015032-->0.014094)
# Test Loss: 0.011214
#
# Temp Loss: 0.082376
#
# Test Loss: 0.027685
#
# Temp Loss: 0.091270
#
# Epoch: 89, Train Loss Decreased!! (0.014094-->0.013413)
# Test Loss: 0.010482
#
# Temp Loss: 0.082517
#
# Test Loss: 0.025773
#
# Temp Loss: 0.090790
#
# Epoch: 91, Train Loss Decreased!! (0.013413-->0.012392)
# Test Loss: 0.009439
#
# Temp Loss: 0.083201
#
# Test Loss: 0.026510
#
# Temp Loss: 0.092488
#
# Epoch: 93, Train Loss Decreased!! (0.012392-->0.011629)
# Test Loss: 0.008530
#
# Temp Loss: 0.082232
#
# Test Loss: 0.024103
#
# Temp Loss: 0.091474
#
# Epoch: 95, Train Loss Decreased!! (0.011629-->0.010601)
# Test Loss: 0.007718
#
# Temp Loss: 0.082530
#
# Test Loss: 0.024013
#
# Temp Loss: 0.093168
#
# Epoch: 97, Train Loss Decreased!! (0.010601-->0.009925)
# Test Loss: 0.007131
#
# Temp Loss: 0.083400
#
# Test Loss: 0.024520
#
# Temp Loss: 0.094644
#
# Epoch: 99, Train Loss Decreased!! (0.009925-->0.009383)
# Test Loss: 0.006489
#
# Temp Loss: 0.084106
# 100%|██████████| 5/5 [10:14<00:00, 122.95s/it]
# Test Loss: 0.022881
#
# Temp Loss: 0.094456
#
# ----------------------------------------------------

# %%
train_losses_mat = np.zeros((nRuns,n_epochs+1))
test_losses_mat = np.zeros((nRuns,n_epochs+1))
temp_losses_mat = np.zeros((nRuns,n_epochs+1))

train_expected_losses_mat = np.zeros((nRuns,n_epochs+1))

test_expected_losses_mat = np.zeros((nRuns,n_epochs+1))
test_surprise_losses_mat = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    train_losses_mat[cntr] = train_losses[cntr]
    test_losses_mat[cntr] = test_losses[cntr]
    temp_losses_mat[cntr] = temp_losses[cntr]
    
    train_expected_losses_mat[cntr] = train_expected_rec_losses[cntr]
    
    test_expected_losses_mat[cntr] = test_expected_rec_losses[cntr]
    test_surprise_losses_mat[cntr] = test_surprise_rec_losses[cntr]

# %%
train_losses_mean = np.mean(train_losses_mat,axis=0)
test_losses_mean = np.mean(test_losses_mat,axis=0)
temp_losses_mean = np.mean(temp_losses_mat,axis=0)

train_expected_losses_mean = np.mean(train_expected_losses_mat,axis=0)

test_expected_losses_mean = np.mean(test_expected_losses_mat,axis=0)
test_surprise_losses_mean = np.mean(test_surprise_losses_mat,axis=0)

# %%
train_losses_std = np.std(train_losses_mat,axis=0)
test_losses_std = np.std(test_losses_mat,axis=0)
temp_losses_std = np.std(test_losses_mat,axis=0)

train_expected_losses_std = np.std(train_expected_losses_mat,axis=0)

test_expected_losses_std = np.std(test_expected_losses_mat,axis=0)
test_surprise_losses_std = np.std(test_surprise_losses_mat,axis=0)

# %%
train_expected_losses_mean[0] = train_losses_mean[0]

# %%
f = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.errorbar(np.arange(n_epochs+1),train_losses_mean,yerr=train_losses_std)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,2)
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.subplot(2,2,3)
plt.errorbar(np.arange(n_epochs+1),test_losses_mean,yerr=test_losses_std)
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,4)
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
# kk=4
# a = np.unique(allStatesTest[kk][:,0])
# b = np.unique(allStatesTrain[kk][:,0])
# len(np.intersect1d(a,b))

# %% [markdown]
# ### Representational Analyses

# %% [markdown]
# #### RNN Names

# %%
rnn_names = ['L4','L23','L56','H4','H23','H56']

# %% [markdown]
# #### Analyses train loader

# %%
analyses_train_loader = {}

# %%
for cntr in range(nRuns):
    analyses_train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=False)

# %% [markdown]
# #### Pass data and store activations

# %%
def pass_data_store_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        activations_hidden_L23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_L4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_L56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_hidden_H23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_H4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_H56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_out_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
        for e in tqdm(range(n_epochs+1)):

            cnt = 0

            ## Load model
            model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr])
            model[cntr].to(device)
            model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
            model[cntr].eval()

            ## Pass clean samples
            for data, f_target, lastEvent, surpriseBinary in loader[cntr]:

                if train_on_gpu:
                    data, f_targetC = data.float().cuda(), f_target.float().cuda()
                else: data, f_targetC = data.float(), f_target.float()

                target = f_target

                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                ## Collect activations  
                act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                for i in range(batch_size):
                    if i < len(data):
                        label = target.data[i]

                        activations_hidden_L23_np[cntr][e,cnt] = act_hidden_L23[i]
                        activations_hidden_L4_np[cntr][e,cnt] = act_hidden_L4[i]
                        activations_hidden_L56_np[cntr][e,cnt] = act_hidden_L56[i]

                        activations_hidden_H23_np[cntr][e,cnt] = act_hidden_H23[i]
                        activations_hidden_H4_np[cntr][e,cnt] = act_hidden_H4[i]
                        activations_hidden_H56_np[cntr][e,cnt] = act_hidden_H56[i]

                        activations_out_np[cntr][e,cnt] = output_pred[i]

                        cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# (L23_train,L4_train,L56_train,
#  H23_train,H4_train,H56_train,), out_train = pass_data_store_activations(analyses_train_loader, nTrain)

# %%
(L23_test,L4_test,L56_test,
 H23_test,H4_test,H56_test,), out_test = pass_data_store_activations(test_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:18<00:00,  5.57it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.59it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.58it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.59it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.57it/s]

# %%
(L23_temp,L4_temp,L56_temp,
 H23_temp,H4_temp,H56_temp,), out_temp = pass_data_store_activations(test_temp_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:18<00:00,  5.55it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.57it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.49it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.58it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.59it/s]

# %% [markdown]
# #### PCA for RNNs

# %%
def repsPCA(rnnActs):
    nEpochs, nSeqs, nRolls, nNeurons = rnnActs.shape
    pca_dict = {}
    nSamps = nSeqs*nRolls
    dimPCA = min(nNeurons,nSamps)
    repsR_transformed = np.zeros((nEpochs,nSamps,dimPCA))
    
    for ep in tqdm(range(nEpochs)):
        
        reps = rnnActs[ep]
        
        ## reshape
        repsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        for ii in range(nSeqs):
            for jj in range(nRolls):
                repsR[cnt] = reps[ii,jj]
                cnt += 1
        ## PCA
        rnnPCA = PCA()
        repsR_transformed[ep] = rnnPCA.fit_transform(repsR)
        pca_dict[str(ep)] = rnnPCA
        
    return repsR_transformed, pca_dict

# %%
# L23pca_train = {}
# L4pca_train = {}
# L56pca_train = {}

# H23pca_train = {}
# H4pca_train = {}
# H56pca_train = {}

L23pca_test = {}
L4pca_test = {}
L56pca_test = {}

H23pca_test = {}
H4pca_test = {}
H56pca_test = {}

L23pca_temp = {}
L4pca_temp = {}
L56pca_temp = {}

H23pca_temp = {}
H4pca_temp = {}
H56pca_temp = {}

# %%
# for cntr in range(nRuns):
#     L23pca_train[cntr], _ = repsPCA(L23_train[cntr])
#     L4pca_train[cntr], _ = repsPCA(L4_train[cntr])
#     L56pca_train[cntr], _ = repsPCA(L56_train[cntr])

#     H23pca_train[cntr], _ = repsPCA(H23_train[cntr])
#     H4pca_train[cntr], _ = repsPCA(H4_train[cntr])
#     H56pca_train[cntr], _ = repsPCA(H56_train[cntr])

# %%
for cntr in range(nRuns):
    L23pca_test[cntr], _ = repsPCA(L23_test[cntr])
    L4pca_test[cntr], _ = repsPCA(L4_test[cntr])
    L56pca_test[cntr], _ = repsPCA(L56_test[cntr])

    H23pca_test[cntr], _ = repsPCA(H23_test[cntr])
    H4pca_test[cntr], _ = repsPCA(H4_test[cntr])
    H56pca_test[cntr], _ = repsPCA(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 58.71it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.77it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.92it/s]
# 100%|██████████| 101/101 [00:01<00:00, 62.13it/s]
# 100%|██████████| 101/101 [00:00<00:00, 133.07it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.61it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.94it/s]
# 100%|██████████| 101/101 [00:00<00:00, 135.02it/s]
# 100%|██████████| 101/101 [00:01<00:00, 84.39it/s]
# 100%|██████████| 101/101 [00:01<00:00, 65.46it/s]
# 100%|██████████| 101/101 [00:00<00:00, 136.30it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.82it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.14it/s]
# 100%|██████████| 101/101 [00:00<00:00, 128.03it/s]
# 100%|██████████| 101/101 [00:01<00:00, 76.60it/s]
# 100%|██████████| 101/101 [00:01<00:00, 61.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 132.12it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.76it/s]
# 100%|██████████| 101/101 [00:01<00:00, 62.82it/s]
# 100%|██████████| 101/101 [00:00<00:00, 132.73it/s]
# 100%|██████████| 101/101 [00:01<00:00, 84.18it/s]
# 100%|██████████| 101/101 [00:01<00:00, 65.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 137.97it/s]
# 100%|██████████| 101/101 [00:01<00:00, 82.27it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.22it/s]
# 100%|██████████| 101/101 [00:00<00:00, 134.31it/s]
# 100%|██████████| 101/101 [00:01<00:00, 83.35it/s]
# 100%|██████████| 101/101 [00:01<00:00, 65.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 133.25it/s]
# 100%|██████████| 101/101 [00:01<00:00, 84.85it/s]

# %%
for cntr in range(nRuns):
    L23pca_temp[cntr], _ = repsPCA(L23_temp[cntr])
    L4pca_temp[cntr], _ = repsPCA(L4_temp[cntr])
    L56pca_temp[cntr], _ = repsPCA(L56_temp[cntr])

    H23pca_temp[cntr], _ = repsPCA(H23_temp[cntr])
    H4pca_temp[cntr], _ = repsPCA(H4_temp[cntr])
    H56pca_temp[cntr], _ = repsPCA(H56_temp[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 65.93it/s]
# 100%|██████████| 101/101 [00:00<00:00, 138.53it/s]
# 100%|██████████| 101/101 [00:01<00:00, 85.97it/s]
# 100%|██████████| 101/101 [00:01<00:00, 67.15it/s]
# 100%|██████████| 101/101 [00:00<00:00, 141.04it/s]
# 100%|██████████| 101/101 [00:01<00:00, 83.94it/s]
# 100%|██████████| 101/101 [00:01<00:00, 67.20it/s]
# 100%|██████████| 101/101 [00:00<00:00, 137.13it/s]
# 100%|██████████| 101/101 [00:01<00:00, 82.94it/s]
# 100%|██████████| 101/101 [00:01<00:00, 67.42it/s]
# 100%|██████████| 101/101 [00:00<00:00, 134.85it/s]
# 100%|██████████| 101/101 [00:01<00:00, 83.21it/s]
# 100%|██████████| 101/101 [00:01<00:00, 66.58it/s]
# 100%|██████████| 101/101 [00:00<00:00, 136.30it/s]
# 100%|██████████| 101/101 [00:01<00:00, 83.90it/s]
# 100%|██████████| 101/101 [00:01<00:00, 67.74it/s]
# 100%|██████████| 101/101 [00:00<00:00, 140.26it/s]
# 100%|██████████| 101/101 [00:01<00:00, 82.87it/s]
# 100%|██████████| 101/101 [00:01<00:00, 66.54it/s]
# 100%|██████████| 101/101 [00:00<00:00, 137.04it/s]
# 100%|██████████| 101/101 [00:01<00:00, 83.90it/s]
# 100%|██████████| 101/101 [00:01<00:00, 67.20it/s]
# 100%|██████████| 101/101 [00:00<00:00, 135.39it/s]
# 100%|██████████| 101/101 [00:01<00:00, 82.13it/s]
# 100%|██████████| 101/101 [00:01<00:00, 66.28it/s]
# 100%|██████████| 101/101 [00:00<00:00, 136.24it/s]
# 100%|██████████| 101/101 [00:01<00:00, 84.11it/s]
# 100%|██████████| 101/101 [00:01<00:00, 67.42it/s]
# 100%|██████████| 101/101 [00:00<00:00, 137.22it/s]
# 100%|██████████| 101/101 [00:01<00:00, 83.83it/s]

# %%
idxs0_train = np.array([6*x for x in range(nTrain)])
idxs1_train = idxs0_train + 1
idxs2_train = idxs0_train + 2
idxs3_train = idxs0_train + 3
idxs4_train = idxs0_train + 4
idxs5_train = idxs0_train + 5

# %%
idxs0_test = np.array([6*x for x in range(nTest)])
idxs1_test = idxs0_test + 1
idxs2_test = idxs0_test + 2
idxs3_test = idxs0_test + 3
idxs4_test = idxs0_test + 4
idxs5_test = idxs0_test + 5

# %%
# cnt = 4
# ep = -1
# ix = idxs5_train
# c = allStatesTrain[cnt][:,0]/numM
# s = 20*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_train[cnt][ep,ix,0],L4pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_train[cnt][ep,ix,0],L23pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_train[cnt][ep,ix,0],L56pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_train[cnt][ep,ix,0],H4pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_train[cnt][ep,ix,0],H23pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_train[cnt][ep,ix,0],H56pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H5/6')

# %%
# cnt = 4
# ep = 50
# ix = idxs4_test
# c = allStatesTest[cnt][:,0]/numM
# s = 20*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H5/6')

# %% [markdown]
# #### Subset indices, etc.

# %%
idxs00_train = np.hstack((idxs0_train.reshape(-1,1),idxs1_train.reshape(-1,1)))
idxs11_train = np.hstack((idxs2_train.reshape(-1,1),idxs3_train.reshape(-1,1)))
idxs22_train = np.hstack((idxs4_train.reshape(-1,1),idxs5_train.reshape(-1,1)))

# %%
idxs00_test = np.hstack((idxs0_test.reshape(-1,1),idxs1_test.reshape(-1,1))).ravel()
idxs11_test = np.hstack((idxs2_test.reshape(-1,1),idxs3_test.reshape(-1,1))).ravel()
idxs22_test = np.hstack((idxs4_test.reshape(-1,1),idxs5_test.reshape(-1,1))).ravel()

# %%
cleanPCs = {}
surpPCs = {}

contextPCs_sub = {}

# %%
for cntr in range(nRuns):
    cleanPCs[cntr] = (L4pca_test[cntr],L23pca_test[cntr],L56pca_test[cntr],
                      H4pca_test[cntr],H23pca_test[cntr],H56pca_test[cntr])
    surpPCs[cntr] = (L4pca_temp[cntr],L23pca_temp[cntr],L56pca_temp[cntr],
                     H4pca_temp[cntr],H23pca_temp[cntr],H56pca_temp[cntr])
    
    for rnnNo in range(len(rnn_names)):
        contextPCs_sub[cntr,rnnNo] = np.hstack((cleanPCs[cntr][rnnNo][:,idxs22_test,:],surpPCs[cntr][rnnNo][:,idxs22_test,:]))

# %%
context_sub_surp = np.array([0]*nRepeats*nTest + [1]*nRepeats*nTest)

# %%
context_sub_imgIDs = {}
for cntr in range(nRuns):
    context_sub_imgIDs[cntr] = np.hstack((np.repeat(labelsTest[cntr][:,2:3],nRepeats),
                                          np.repeat(labelsTestTemp[cntr][:,2:3],nRepeats)))

# %% [markdown]
# #### Supervised Decoding

# %%
sub_Eps = np.array([0,1,50])
ds_im = 100

# %%
def repsDecodeSupervisedContext(rnnActs,labels,decodeType='surprise',clf='logistic',sub=True,ds=ds_im):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'surprise':
        nClasses = 2
    elif decodeType == 'imageID':
        if sub:
            rnnActs = rnnActs[:,::ds,:]
            nEpochs, nSamps, nNeurons = rnnActs.shape
            labels = labels[::ds]
            nClasses = len(np.unique(labels))
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression(multi_class='ovr').fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)    
        
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
dims23 = np.array([1,2,4,8,16,32,64,80])
dims4 = np.array([1,2,4,8,16,32])
dims56 = np.array([1,2,4,8,16,32,64])

# %%
L23surpPC = {}
L4surpPC = {}
L56surpPC = {}

H23surpPC = {}
H4surpPC = {}
H56surpPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        
    for d in dims4:
        L4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
    
    for d in dims56:
        L56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  1.80it/s]

# %%
L23imgPC = {}
L4imgPC = {}
L56imgPC = {}

H23imgPC = {}
H4imgPC = {}
H56imgPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        
    for d in dims4:
        L4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][sub_Eps,:,:d],
                                                          context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][sub_Eps,:,:d],
                                                          context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
    
    for d in dims56:
        L56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
# Out:
# 100%|██████████| 5/5 [00:17<00:00,  3.41s/it]

# %% [markdown]
# #### Generate plots

# %%
preds_L23imgPC = {}
preds_L4imgPC = {}
preds_L56imgPC = {}

preds_H23imgPC = {}
preds_H4imgPC = {}
preds_H56imgPC = {}

preds_L23surpPC = {}
preds_L4surpPC = {}
preds_L56surpPC = {}

preds_H23surpPC = {}
preds_H4surpPC = {}
preds_H56surpPC = {}

# %%
accs_L23imgPC = {}
accs_L4imgPC = {}
accs_L56imgPC = {}

accs_H23imgPC = {}
accs_H4imgPC = {}
accs_H56imgPC = {}

accs_L23surpPC = {}
accs_L4surpPC = {}
accs_L56surpPC = {}

accs_H23surpPC = {}
accs_H4surpPC = {}
accs_H56surpPC = {}

# %%
for cntr in range(nRuns):
    for ep in range(len(sub_Eps)):
        
        for d in dims23:
            preds_L23imgPC[cntr,d,ep] = np.argmax(L23imgPC[cntr,d][ep],axis=-1)
            preds_H23imgPC[cntr,d,ep] = np.argmax(H23imgPC[cntr,d][ep],axis=-1)
            
            preds_L23surpPC[cntr,d,ep] = np.argmax(L23surpPC[cntr,d][ep],axis=-1)
            preds_H23surpPC[cntr,d,ep] = np.argmax(H23surpPC[cntr,d][ep],axis=-1)
            
            accs_L23imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L23imgPC[cntr,d,ep])
            accs_H23imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H23imgPC[cntr,d,ep])
            
            accs_L23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L23surpPC[cntr,d,ep])
            accs_H23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H23surpPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4imgPC[cntr,d,ep] = np.argmax(L4imgPC[cntr,d][ep],axis=-1)
            preds_H4imgPC[cntr,d,ep] = np.argmax(H4imgPC[cntr,d][ep],axis=-1)
            
            preds_L4surpPC[cntr,d,ep] = np.argmax(L4surpPC[cntr,d][ep],axis=-1)
            preds_H4surpPC[cntr,d,ep] = np.argmax(H4surpPC[cntr,d][ep],axis=-1)
            
            accs_L4imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L4imgPC[cntr,d,ep])
            accs_H4imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H4imgPC[cntr,d,ep])
            
            accs_L4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L4surpPC[cntr,d,ep])
            accs_H4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H4surpPC[cntr,d,ep])
                
        for d in dims56:        
            preds_L56imgPC[cntr,d,ep] = np.argmax(L56imgPC[cntr,d][ep],axis=-1)
            preds_H56imgPC[cntr,d,ep] = np.argmax(H56imgPC[cntr,d][ep],axis=-1)
            
            preds_L56surpPC[cntr,d,ep] = np.argmax(L56surpPC[cntr,d][ep],axis=-1)
            preds_H56surpPC[cntr,d,ep] = np.argmax(H56surpPC[cntr,d][ep],axis=-1)
            
            accs_L56imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L56imgPC[cntr,d,ep])
            accs_H56imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H56imgPC[cntr,d,ep])
            
            accs_L56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L56surpPC[cntr,d,ep])
            accs_H56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H56surpPC[cntr,d,ep])

# %%
tensor_accs_L23imgPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4imgPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56imgPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23imgPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4imgPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56imgPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_L23surpPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4surpPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56surpPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23surpPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4surpPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56surpPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

# %%
for ii in range(nRuns):
    for kk in range(len(sub_Eps)):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23imgPC[ii,jj,kk] = accs_L23imgPC[ii,d,kk]
            tensor_accs_H23imgPC[ii,jj,kk] = accs_H23imgPC[ii,d,kk]
            
            tensor_accs_L23surpPC[ii,jj,kk] = accs_L23surpPC[ii,d,kk]
            tensor_accs_H23surpPC[ii,jj,kk] = accs_H23surpPC[ii,d,kk]
            
        
        for jj,d in enumerate(dims4):
            tensor_accs_L4imgPC[ii,jj,kk] = accs_L4imgPC[ii,d,kk]
            tensor_accs_H4imgPC[ii,jj,kk] = accs_H4imgPC[ii,d,kk]
            
            tensor_accs_L4surpPC[ii,jj,kk] = accs_L4surpPC[ii,d,kk]
            tensor_accs_H4surpPC[ii,jj,kk] = accs_H4surpPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56imgPC[ii,jj,kk] = accs_L56imgPC[ii,d,kk]
            tensor_accs_H56imgPC[ii,jj,kk] = accs_H56imgPC[ii,d,kk]

            tensor_accs_L56surpPC[ii,jj,kk] = accs_L56surpPC[ii,d,kk]
            tensor_accs_H56surpPC[ii,jj,kk] = accs_H56surpPC[ii,d,kk]

# %%
mean_accs_L4imgPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23imgPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56imgPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4imgPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23imgPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56imgPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_L4surpPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23surpPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56surpPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4surpPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23surpPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56surpPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4imgPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23imgPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56imgPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4imgPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23imgPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56imgPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4surpPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23surpPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56surpPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4surpPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23surpPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56surpPC = np.zeros((len(dims56),len(sub_Eps)))

# %%
for ep in range(len(sub_Eps)):
    
    for dd, dims in enumerate(dims23):
        mean_accs_L23imgPC[dd,ep] = np.mean(tensor_accs_L23imgPC[:,dd,ep])
        mean_accs_H23imgPC[dd,ep] = np.mean(tensor_accs_H23imgPC[:,dd,ep])
        
        std_accs_L23imgPC[dd,ep] = np.var(tensor_accs_L23imgPC[:,dd,ep])
        std_accs_H23imgPC[dd,ep] = np.var(tensor_accs_H23imgPC[:,dd,ep])
        
        mean_accs_L23surpPC[dd,ep] = np.mean(tensor_accs_L23surpPC[:,dd,ep])
        mean_accs_H23surpPC[dd,ep] = np.mean(tensor_accs_H23surpPC[:,dd,ep])
        
        std_accs_L23surpPC[dd,ep] = np.var(tensor_accs_L23surpPC[:,dd,ep])
        std_accs_H23surpPC[dd,ep] = np.var(tensor_accs_H23surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims4):
        mean_accs_L4imgPC[dd,ep] = np.mean(tensor_accs_L4imgPC[:,dd,ep])
        mean_accs_H4imgPC[dd,ep] = np.mean(tensor_accs_H4imgPC[:,dd,ep])
        
        std_accs_L4imgPC[dd,ep] = np.var(tensor_accs_L4imgPC[:,dd,ep])
        std_accs_H4imgPC[dd,ep] = np.var(tensor_accs_H4imgPC[:,dd,ep])
        
        mean_accs_L4surpPC[dd,ep] = np.mean(tensor_accs_L4surpPC[:,dd,ep])
        mean_accs_H4surpPC[dd,ep] = np.mean(tensor_accs_H4surpPC[:,dd,ep])
        
        std_accs_L4surpPC[dd,ep] = np.var(tensor_accs_L4surpPC[:,dd,ep])
        std_accs_H4surpPC[dd,ep] = np.var(tensor_accs_H4surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims56):
        mean_accs_L56imgPC[dd,ep] = np.mean(tensor_accs_L56imgPC[:,dd,ep])        
        mean_accs_H56imgPC[dd,ep] = np.mean(tensor_accs_H56imgPC[:,dd,ep])
        
        std_accs_L56imgPC[dd,ep] = np.var(tensor_accs_L56imgPC[:,dd,ep])
        std_accs_H56imgPC[dd,ep] = np.var(tensor_accs_H56imgPC[:,dd,ep])
        
        mean_accs_L56surpPC[dd,ep] = np.mean(tensor_accs_L56surpPC[:,dd,ep])
        mean_accs_H56surpPC[dd,ep] = np.mean(tensor_accs_H56surpPC[:,dd,ep])
        
        std_accs_L56surpPC[dd,ep] = np.var(tensor_accs_L56surpPC[:,dd,ep])        
        std_accs_H56surpPC[dd,ep] = np.var(tensor_accs_H56surpPC[:,dd,ep])

# %%
ffsurp_dim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Surprise ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,0],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,0],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,0],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,0],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,0],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,0],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(132)
plt.title('Surprise ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,1],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,1],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,1],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,1],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,1],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,1],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(133)
plt.title('Surprise ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,-1],yerr=std_accs_L4surpPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,-1],yerr=std_accs_L23surpPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,-1],yerr=std_accs_L56surpPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,-1],yerr=std_accs_H4surpPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,-1],yerr=std_accs_H23surpPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,-1],yerr=std_accs_H56surpPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
ffdim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Image ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,0],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,0],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,0],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,0],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,0],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,0],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Image ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,1],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,1],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,1],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,1],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,1],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,1],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Image ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,-1],yerr=std_accs_L4imgPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,-1],yerr=std_accs_L23imgPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,-1],yerr=std_accs_L56imgPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,-1],yerr=std_accs_H4imgPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,-1],yerr=std_accs_H23imgPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,-1],yerr=std_accs_H56imgPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# #### Position

# %%
step_labels = np.array([x%nSteps for x in range(nTest*nSteps)])

# %%
def repsDecodeSupervisedPosition(rnnActs,labels,clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    nClasses = 6
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
L4posPC = {}
L23posPC = {}
L56posPC = {}
H4posPC = {}
H23posPC = {}
H56posPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][1][sub_Eps,:,:d],step_labels)
        H23posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][4][sub_Eps,:,:d],step_labels)
    
    for d in dims4:
        L4posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][0][sub_Eps,:,:d],step_labels)
        H4posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][3][sub_Eps,:,:d],step_labels)
        
    for d in dims56:
        ## Position
        L56posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][2][sub_Eps,:,:d],step_labels)      
        H56posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][5][sub_Eps,:,:d],step_labels)
# Out:
# 100%|██████████| 5/5 [00:24<00:00,  4.97s/it]

# %%
preds_L23posPC = {}
preds_L4posPC = {}
preds_L56posPC = {}

preds_H23posPC = {}
preds_H4posPC = {}
preds_H56posPC = {}

# %%
accs_L23posPC = {}
accs_L4posPC = {}
accs_L56posPC = {}

accs_H23posPC = {}
accs_H4posPC = {}
accs_H56posPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(len(sub_Eps)):
        
        for d in dims23:
            preds_L23posPC[cntr,d,ep] = np.argmax(L23posPC[cntr,d][ep],axis=-1)
            preds_H23posPC[cntr,d,ep] = np.argmax(H23posPC[cntr,d][ep],axis=-1)
            
            accs_L23posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L23posPC[cntr,d,ep])
            accs_H23posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H23posPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4posPC[cntr,d,ep] = np.argmax(L4posPC[cntr,d][ep],axis=-1)
            preds_H4posPC[cntr,d,ep] = np.argmax(H4posPC[cntr,d][ep],axis=-1)
            
            accs_L4posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L4posPC[cntr,d,ep])
            accs_H4posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H4posPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56posPC[cntr,d,ep] = np.argmax(L56posPC[cntr,d][ep],axis=-1)
            preds_H56posPC[cntr,d,ep] = np.argmax(H56posPC[cntr,d][ep],axis=-1)
            
            accs_L56posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L56posPC[cntr,d,ep])
            accs_H56posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H56posPC[cntr,d,ep])

# %%
tensor_accs_L23posPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4posPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56posPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23posPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4posPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56posPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

# %%
for ii in range(nRuns):
    
    for kk in range(len(sub_Eps)):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23posPC[ii,jj,kk] = accs_L23posPC[ii,d,kk]
            tensor_accs_H23posPC[ii,jj,kk] = accs_H23posPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4posPC[ii,jj,kk] = accs_L4posPC[ii,d,kk]
            tensor_accs_H4posPC[ii,jj,kk] = accs_H4posPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56posPC[ii,jj,kk] = accs_L56posPC[ii,d,kk]            
            tensor_accs_H56posPC[ii,jj,kk] = accs_H56posPC[ii,d,kk]

# %%
mean_accs_L4posPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23posPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56posPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4posPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23posPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56posPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4posPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23posPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56posPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4posPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23posPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56posPC = np.zeros((len(dims56),len(sub_Eps)))

# %%
for ep in range(len(sub_Eps)):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23posPC[dd,ep] = np.mean(tensor_accs_L23posPC[:,dd,ep])
        mean_accs_H23posPC[dd,ep] = np.mean(tensor_accs_H23posPC[:,dd,ep])
        
        std_accs_L23posPC[dd,ep] = np.var(tensor_accs_L23posPC[:,dd,ep])
        std_accs_H23posPC[dd,ep] = np.var(tensor_accs_H23posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4posPC[dd,ep] = np.mean(tensor_accs_L4posPC[:,dd,ep])
        mean_accs_H4posPC[dd,ep] = np.mean(tensor_accs_H4posPC[:,dd,ep])
        
        std_accs_L4posPC[dd,ep] = np.var(tensor_accs_L4posPC[:,dd,ep])
        std_accs_H4posPC[dd,ep] = np.var(tensor_accs_H4posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56posPC[dd,ep] = np.mean(tensor_accs_L56posPC[:,dd,ep])
        mean_accs_H56posPC[dd,ep] = np.mean(tensor_accs_H56posPC[:,dd,ep])
        
        std_accs_L56posPC[dd,ep] = np.var(tensor_accs_L56posPC[:,dd,ep])
        std_accs_H56posPC[dd,ep] = np.var(tensor_accs_H56posPC[:,dd,ep])

# %%
ffpos = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Position Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,0],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,0],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,0],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,0],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,0],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,0],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Position Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,1],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,1],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,1],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,1],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,1],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,1],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Position Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,-1],yerr=std_accs_L4posPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,-1],yerr=std_accs_L23posPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,-1],yerr=std_accs_L56posPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,-1],yerr=std_accs_H4posPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,-1],yerr=std_accs_H23posPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,-1],yerr=std_accs_H56posPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
np.save(pp+'preds_img_temp_L4-bidirectional-fb-binary',preds_L4imgPC)
np.save(pp+'preds_img_temp_L23-bidirectional-fb-binary',preds_L23imgPC)
np.save(pp+'preds_img_temp_L56-bidirectional-fb-binary',preds_L56imgPC)
np.save(pp+'preds_img_temp_H4-bidirectional-fb-binary',preds_H4imgPC)
np.save(pp+'preds_img_temp_H23-bidirectional-fb-binary',preds_H23imgPC)
np.save(pp+'preds_img_temp_H56-bidirectional-fb-binary',preds_H56imgPC)

np.save(pp+'accs_img_temp_L4-bidirectional-fb-binary',accs_L4imgPC)
np.save(pp+'accs_img_temp_L23-bidirectional-fb-binary',accs_L23imgPC)
np.save(pp+'accs_img_temp_L56-bidirectional-fb-binary',accs_L56imgPC)
np.save(pp+'accs_img_temp_H4-bidirectional-fb-binary',accs_H4imgPC)
np.save(pp+'accs_img_temp_H23-bidirectional-fb-binary',accs_H23imgPC)
np.save(pp+'accs_img_temp_H56-bidirectional-fb-binary',accs_H56imgPC)

# %%
np.save(pp+'preds_pos_temp_L4-bidirectional-fb-binary',preds_L4posPC)
np.save(pp+'preds_pos_temp_L23-bidirectional-fb-binary',preds_L23posPC)
np.save(pp+'preds_pos_temp_L56-bidirectional-fb-binary',preds_L56posPC)
np.save(pp+'preds_pos_temp_H4-bidirectional-fb-binary',preds_H4posPC)
np.save(pp+'preds_pos_temp_H23-bidirectional-fb-binary',preds_H23posPC)
np.save(pp+'preds_pos_temp_H56-bidirectional-fb-binary',preds_H56posPC)

np.save(pp+'accs_pos_temp_L4-bidirectional-fb-binary',accs_L4posPC)
np.save(pp+'accs_pos_temp_L23-bidirectional-fb-binary',accs_L23posPC)
np.save(pp+'accs_pos_temp_L56-bidirectional-fb-binary',accs_L56posPC)
np.save(pp+'accs_pos_temp_H4-bidirectional-fb-binary',accs_H4posPC)
np.save(pp+'accs_pos_temp_H23-bidirectional-fb-binary',accs_H23posPC)
np.save(pp+'accs_pos_temp_H56-bidirectional-fb-binary',accs_H56posPC)

# %%
np.save(pp+'preds_surp_temp_L4-bidirectional-fb',preds_L4surpPC)
np.save(pp+'preds_surp_temp_L23-bidirectional-fb',preds_L23surpPC)
np.save(pp+'preds_surp_temp_L56-bidirectional-fb',preds_L56surpPC)
np.save(pp+'preds_surp_temp_H4-bidirectional-fb',preds_H4surpPC)
np.save(pp+'preds_surp_temp_H23-bidirectional-fb',preds_H23surpPC)
np.save(pp+'preds_surp_temp_H56-bidirectional-fb',preds_H56surpPC)

np.save(pp+'accs_surp_temp_L4-bidirectional-fb',accs_L4surpPC)
np.save(pp+'accs_surp_temp_L23-bidirectional-fb',accs_L23surpPC)
np.save(pp+'accs_surp_temp_L56-bidirectional-fb',accs_L56surpPC)
np.save(pp+'accs_surp_temp_H4-bidirectional-fb',accs_H4surpPC)
np.save(pp+'accs_surp_temp_H23-bidirectional-fb',accs_H23surpPC)
np.save(pp+'accs_surp_temp_H56-bidirectional-fb',accs_H56surpPC)

# %% [markdown]
# #### Temporal accuracies

# %%
preds_test = {}
preds_temp = {}

accs_test = np.zeros((nRuns,n_epochs+1))
accs_temp = np.zeros((nRuns,n_epochs+1))

for cntr in range(nRuns):
    preds_test[cntr] = np.abs(np.round_(out_test[cntr]*(out_test[cntr]>0)))
    preds_temp[cntr] = np.abs(np.round_(out_test[cntr]*(out_temp[cntr]>0)))
    
    accs_test[cntr] = np.sum(np.sum(np.sum(((yRepsTest[cntr] - preds_test[cntr])==0)*1,-1),-1),-1)/np.prod(yRepsTest[cntr].shape)
    accs_temp[cntr] = np.sum(np.sum(np.sum(((yRepsTestTemp[cntr] - preds_temp[cntr])==0)*1,-1),-1),-1)/np.prod(yRepsTestTemp[cntr].shape)

# %%
ff_final_temp_noise = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_test,0),yerr=np.var(accs_test,0),fmt='-',label='Test - Clean')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_temp,0),yerr=np.var(accs_temp,0),fmt='-',label='Test - Surprise')
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend()
plt.title('Prediction accuracy in presence of temporal violation')
plt.show()

# %%
np.save(pp+'bidirectional-fb-no-violations-accs-binary',accs_test)
np.save(pp+'bidirectional-fb-temporal-violations-accs-binary',accs_temp)

# %%
ff_final_temp_noise.savefig('temporal-violation-final-acc-repeated-runs-bidirectional-fb-bianry.png',dpi=300,bbox_inches='tight')
ff_final_temp_noise.savefig('temporal-violation-final-acc-repeated-runs-bidirectional-fb-binary.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# #### Dimensioanlity (Linear)

# %%
def rnnLinDim(acts):
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    eig_mat = np.zeros((nEpochs,nNeurons))
        
    for ep in tqdm(range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        cov = actsScaled.T@actsScaled
        eig_mat[ep] = eigvals(cov)
        num = np.sum(eig_mat,1)**2
        den = np.sum(eig_mat**2,1) + 1e-17
        PR = num/den
    return PR

# %%
L23LinDim = np.zeros((nRuns,n_epochs+1))
L4LinDim = np.zeros((nRuns,n_epochs+1))
L56LinDim = np.zeros((nRuns,n_epochs+1))

H23LinDim = np.zeros((nRuns,n_epochs+1))
H4LinDim = np.zeros((nRuns,n_epochs+1))
H56LinDim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23LinDim[cntr] = rnnLinDim(L23_test[cntr])
    L4LinDim[cntr] = rnnLinDim(L4_test[cntr])
    L56LinDim[cntr] = rnnLinDim(L56_test[cntr])

    H23LinDim[cntr] = rnnLinDim(H23_test[cntr])
    H4LinDim[cntr] = rnnLinDim(H4_test[cntr])
    H56LinDim[cntr] = rnnLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 100.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 183.13it/s]
# 100%|██████████| 101/101 [00:00<00:00, 123.95it/s]
# 100%|██████████| 101/101 [00:00<00:00, 109.60it/s]
# 100%|██████████| 101/101 [00:00<00:00, 187.54it/s]
# 100%|██████████| 101/101 [00:00<00:00, 125.64it/s]
# 100%|██████████| 101/101 [00:00<00:00, 105.82it/s]
# 100%|██████████| 101/101 [00:00<00:00, 184.12it/s]
# 100%|██████████| 101/101 [00:00<00:00, 125.49it/s]
# 100%|██████████| 101/101 [00:00<00:00, 104.40it/s]
# 100%|██████████| 101/101 [00:00<00:00, 173.70it/s]
# 100%|██████████| 101/101 [00:00<00:00, 122.90it/s]
# 100%|██████████| 101/101 [00:00<00:00, 105.16it/s]
# 100%|██████████| 101/101 [00:00<00:00, 179.56it/s]
# 100%|██████████| 101/101 [00:00<00:00, 120.63it/s]
# 100%|██████████| 101/101 [00:00<00:00, 105.71it/s]
# 100%|██████████| 101/101 [00:00<00:00, 188.58it/s]
# 100%|██████████| 101/101 [00:00<00:00, 122.75it/s]
# 100%|██████████| 101/101 [00:00<00:00, 103.44it/s]
# 100%|██████████| 101/101 [00:00<00:00, 172.52it/s]
# 100%|██████████| 101/101 [00:00<00:00, 123.05it/s]
# 100%|██████████| 101/101 [00:00<00:00, 104.19it/s]
# 100%|██████████| 101/101 [00:00<00:00, 184.46it/s]
# 100%|██████████| 101/101 [00:00<00:00, 120.99it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 182.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 121.43it/s]
# 100%|██████████| 101/101 [00:00<00:00, 102.39it/s]
# 100%|██████████| 101/101 [00:00<00:00, 183.79it/s]
# 100%|██████████| 101/101 [00:00<00:00, 117.62it/s]

# %% [markdown]
# #### Dimensionality (non-linear)

# %%
def rnnNonLinDim(acts,nTypes=2,subsample=True,ds=100):
    
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    dims_mat = np.zeros((nEpochs,nTypes))
        
    for ep in (range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        
        if subsample:
            actsScaled = actsScaled[::ds]
        
        dims_mat[ep,0] = MiND_ML().fit(actsScaled).dimension_
#         print(dims_mat[ep,0])
        dims_mat[ep,1] = CorrInt().fit(actsScaled).dimension_
#         print(dims_mat[ep,1])
#         dims_mat[ep,2] = MLE().fit(actsScaled).dimension_
#         print(dims_mat[ep,2])
#         dims_mat[ep,3] = DANCo().fit(actsScaled).dimension_
        
    return np.mean(dims_mat,-1),dims_mat

# %%
L23NonLinDim = np.zeros((nRuns,n_epochs+1))
L4NonLinDim = np.zeros((nRuns,n_epochs+1))
L56NonLinDim = np.zeros((nRuns,n_epochs+1))

H23NonLinDim = np.zeros((nRuns,n_epochs+1))
H4NonLinDim = np.zeros((nRuns,n_epochs+1))
H56NonLinDim = np.zeros((nRuns,n_epochs+1))

# %%
L23_ND_mat = {}
L4_ND_mat = {}
L56_ND_mat = {}
H23_ND_mat = {}
H4_ND_mat = {}
H56_ND_mat = {}

# %%
for cntr in tqdm(range(nRuns)):
    L23NonLinDim[cntr], L23_ND_mat[cntr] = rnnNonLinDim(L23_test[cntr])
    L4NonLinDim[cntr], L4_ND_mat[cntr] = rnnNonLinDim(L4_test[cntr])
    L56NonLinDim[cntr], L56_ND_mat[cntr] = rnnNonLinDim(L56_test[cntr])

    H23NonLinDim[cntr], H23_ND_mat[cntr] = rnnNonLinDim(H23_test[cntr])
    H4NonLinDim[cntr], H4_ND_mat[cntr] = rnnNonLinDim(H4_test[cntr])
    H56NonLinDim[cntr], H56_ND_mat[cntr] = rnnNonLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 5/5 [02:15<00:00, 27.09s/it]

# %%
L23_NonLineDim_mean = np.mean(L23NonLinDim,0)
L4_NonLineDim_mean = np.mean(L4NonLinDim,0)
L56_NonLineDim_mean = np.mean(L56NonLinDim,0)

H23_NonLineDim_mean = np.mean(H23NonLinDim,0)
H4_NonLineDim_mean = np.mean(H4NonLinDim,0)
H56_NonLineDim_mean = np.mean(H56NonLinDim,0)

L23_NonLineDim_std = np.var(L23NonLinDim,0)
L4_NonLineDim_std = np.var(L4NonLinDim,0)
L56_NonLineDim_std = np.var(L56NonLinDim,0)

H23_NonLineDim_std = np.var(H23NonLinDim,0)
H4_NonLineDim_std = np.var(H4NonLinDim,0)
H56_NonLineDim_std = np.var(H56NonLinDim,0)

# %%
L23_dim = np.zeros((nRuns,n_epochs+1))
L4_dim = np.zeros((nRuns,n_epochs+1))
L56_dim = np.zeros((nRuns,n_epochs+1))

H23_dim = np.zeros((nRuns,n_epochs+1))
H4_dim = np.zeros((nRuns,n_epochs+1))
H56_dim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23_dim[cntr] = L23LinDim[cntr]/L23NonLinDim[cntr]
    L4_dim[cntr] = L4LinDim[cntr]/L4NonLinDim[cntr]
    L56_dim[cntr] = L56LinDim[cntr]/L56NonLinDim[cntr]
    H23_dim[cntr] = H23LinDim[cntr]/H23NonLinDim[cntr]
    H4_dim[cntr] = H4LinDim[cntr]/H4NonLinDim[cntr]
    H56_dim[cntr] = H56LinDim[cntr]/H56NonLinDim[cntr]

# %%
np.save(pp+'L23DG_bidirectional-fb_binary',L23_dim)
np.save(pp+'L4DG_bidirectional-fb_binary',L4_dim)
np.save(pp+'L56DG_bidirectional-fb_binary',L56_dim)
np.save(pp+'H23DG_bidirectional-fb_binary',H23_dim)
np.save(pp+'H4DG_bidirectional-fb_binary',H4_dim)
np.save(pp+'H56DG_bidirectional-fb_binary',H56_dim)

# %%
ffTotDim = plt.figure(figsize=(5,5))

plt.subplot(111)

plt.plot(np.arange(n_epochs+1),np.mean(L4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(L4_dim,0)-np.var(L4_dim,0),np.mean(L4_dim,0)+np.var(L4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(L23_dim,0)-np.var(L23_dim,0),np.mean(L23_dim,0)+np.var(L23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(L56_dim,0)-np.var(L56_dim,0),np.mean(L56_dim,0)+np.var(L56_dim,0),alpha=0.5)

plt.plot(np.arange(n_epochs+1),np.mean(H4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(H4_dim,0)-np.var(H4_dim,0),np.mean(H4_dim,0)+np.var(H4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(H23_dim,0)-np.var(H23_dim,0),np.mean(H23_dim,0)+np.var(H23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(H56_dim,0)-np.var(H56_dim,0),np.mean(H56_dim,0)+np.var(H56_dim,0),alpha=0.5)

plt.xlabel('Epochs')
plt.ylabel('Dimensionality Gain')
# plt.ylim(0.9,2.2)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Bidirectional-FB Microcircuit')
plt.show()

# %%
ffTotDim.savefig('Dimensionality-gain-bidirectional-fb-across-learning-binary.png',dpi=300,bbox_inches='tight')
ffTotDim.savefig('Dimensionality-gain-bidirectional-fb-across-learning-binary.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# #### Spatial violations

# %%
dim = 16

# %%
from numpy.random import normal

# %%
noise_stds = np.linspace(0,5,6)

# %%
noiseSeqs = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noiseSeqs[cntr,nn] = repsTest[cntr] + normal(0,noise,repsTest[cntr].shape)

# %%
noisy_loader_analyses = {}

for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noisy_loader_analyses[cntr,nn] = makeTensorLoaders((noiseSeqs[cntr,nn],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)

# %%
L23_noisy = {}
L4_noisy = {}
L56_noisy = {}

H23_noisy = {}
H4_noisy = {}
H56_noisy = {}

out_noisy = {}

# %%
def pass_data_store_noisy_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        for nn in range(len(noise_stds)):
            activations_hidden_L23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_L4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_L56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_hidden_H23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_H4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_H56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_out_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,dim))

            for e in tqdm(range(n_epochs+1)):

                cnt = 0

                ## Load model
                model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr])
                model[cntr].to(device)
                model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
                model[cntr].eval()

                ## Pass clean samples
                for data, f_target, lastEvent, surpriseBinary in loader[cntr,nn]:

                    if train_on_gpu:
                        data, f_targetC = data.float().cuda(), f_target.float().cuda()
                    else: data, f_targetC = data.float(), f_target.float()

                    target = f_target

                    output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                    ## Collect activations  
                    act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                    act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                    act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                    act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                    act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                    act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                    output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                    for i in range(batch_size):
                        if i < len(data):
                            label = target.data[i]

                            activations_hidden_L23_np[cntr,nn][e,cnt] = act_hidden_L23[i]
                            activations_hidden_L4_np[cntr,nn][e,cnt] = act_hidden_L4[i]
                            activations_hidden_L56_np[cntr,nn][e,cnt] = act_hidden_L56[i]

                            activations_hidden_H23_np[cntr,nn][e,cnt] = act_hidden_H23[i]
                            activations_hidden_H4_np[cntr,nn][e,cnt] = act_hidden_H4[i]
                            activations_hidden_H56_np[cntr,nn][e,cnt] = act_hidden_H56[i]

                            activations_out_np[cntr,nn][e,cnt] = output_pred[i]

                            cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
(L23_noisy,L4_noisy,L56_noisy,
 H23_noisy,H4_noisy,H56_noisy,), out_noisy = pass_data_store_noisy_activations(noisy_loader_analyses, nTest)
# Out:
# 100%|██████████| 101/101 [00:18<00:00,  5.59it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.59it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.64it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.64it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.63it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.64it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.56it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.64it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.61it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.66it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.61it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.64it/s]
# 100%|██████████| 101/101 [00:22<00:00,  4.41it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.63it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.66it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.62it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.60it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.62it/s]
# 100%|██████████| 101/101 [00:22<00:00,  4.41it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.60it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.63it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.61it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.60it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.63it/s]
# 100%|██████████| 101/101 [00:23<00:00,  4.37it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.20it/s]
# 100%|██████████| 101/101 [00:23<00:00,  4.35it/s]
# 100%|██████████| 101/101 [00:23<00:00,  4.35it/s]
# 100%|██████████| 101/101 [00:23<00:00,  4.30it/s]
# 100%|██████████| 101/101 [00:23<00:00,  4.32it/s]

# %%
predsN = {}
accsN = np.zeros((nRuns,len(noise_stds),n_epochs+1))

# %%
for cntr in range(nRuns):
    for nn in range(len(noise_stds)):
        predsN[cntr,nn] = np.abs(np.round_(out_noisy[cntr,nn]*(out_noisy[cntr,nn]>0)))
        accsN[cntr,nn] = np.sum(np.sum(np.sum(((yRepsTest[cntr] - predsN[cntr,nn])==0)*1,-1),-1),-1)/np.prod(yRepsTest[cntr].shape)

# %%
name = "Dark2_r"
cmap = get_cmap(name)  # type: matplotlib.colors.ListedColormap
colors = cmap.colors  # type: list

# %%
fpredspat = plt.figure()
for nn, noise in enumerate(noise_stds):
    plt.errorbar(np.arange(n_epochs+1),np.mean(accsN[:,nn],0),yerr=np.var(accsN[:,nn],0),fmt='-',label=np.round(noise,2),
                 c=colors[nn])
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
# plt.ylim(0,1)
plt.legend(title="Noise sigma",bbox_to_anchor=(1,0.5))
plt.title('Prediction accuracy with spatial noise - Bidirectional Feedback')
plt.show()

# %%
np.save(pp+'bidirectional-fb-spatial-noisy-accs-binary',accsN)
