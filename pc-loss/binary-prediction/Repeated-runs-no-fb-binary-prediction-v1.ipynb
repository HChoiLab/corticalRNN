# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

from numpy.random import choice
from numpy.linalg import norm

from math import factorial

from itertools import permutations

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap

from tqdm import tqdm
import os

# %%
from numpy.linalg import svd, eigvals
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, homogeneity_completeness_v_measure, confusion_matrix, ConfusionMatrixDisplay, homogeneity_score

# %%
from skdim.id import *

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import get_cmap

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.style.use('seaborn-whitegrid')
# plt.style.use('default')

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

# %%
from generate_data import generate_binary_rep_data, makeTensorLoaders

# %% [markdown]
# #### Test for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('No GPU, training on CPU')
    device = torch.device('cpu')
else:
    print('GPU found, training on GPU')
    device = torch.device('cuda')
# Out:
# GPU found, training on GPU

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Number of runs

# %%
nRuns = 5

# %% [markdown]
# #### Generate data for runs

# %%
dim = 16
nTot = 5000

fracTrain = 0.8
fracTest = np.round(1-fracTrain,2)

nTrain = int(nTot*fracTrain)
nTest = nTot - nTrain

lenSeq = 4
nRepeats = 2

# %%
numM = 2**dim-1

# %%
repsTrain = {}
yRepsTrain = {}
eTrain = {}
pTrain = {}
surpTrain = {}
allStatesTrain = {}

# %%
repsTest = {}
yRepsTest = {}
eTest = {}
pTest = {}
surpTest = {}
allStatesTest = {}

# %%
repsTestTemp = {}
yRepsTestTemp = {}
eTestTemp = {}
pTestTemp = {}
surpTestTemp = {}
allStatesTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]) = generate_binary_rep_data(nTot,fracTrain,dim,lenSeq)

# %%
labelsTrain = {}
labelsTest = {}
labelsTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]) = generate_binary_rep_data(nTot,fracTrain,dim,lenSeq)

# %%
for cntr in range(nRuns):
    labelsTrain[cntr] = np.repeat(allStatesTrain[cntr][:,:-1],2).reshape(nTrain,-1)
    labelsTest[cntr] = np.repeat(allStatesTest[cntr][:,1:],2).reshape(nTest,-1)
    labelsTestTemp[cntr] = np.repeat(allStatesTestTemp[cntr][:,1:],2).reshape(nTest,-1)

# %% [markdown]
# #### Create directories to save data and representations

# %%
pp = ## specify path

# %%
npp = {}
pp_npy = {}
pp_pts = {}

# %%
for cntr in range(nRuns):
    
    npp[cntr] = 'binary-no-fb-'+str(cntr)+'/'
    pp_npy[cntr] = pp+npp[cntr]+'npys-'+str(cntr)+'/'
    pp_pts[cntr] = pp+npp[cntr]+'pts-'+str(cntr)+'/'

    ## uncomment the following lines to create the folders. comment out if already created
    
    # os.mkdir(os.path.join(pp,npp[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_pts[cntr]))

    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr],'Dataset/'))

# %% [markdown]
# #### Save seeds and dataset

# %%
seeds = np.random.randint(1000, size=nRuns)
np.save(pp_npy[cntr]+'seeds',seeds)

# %%
for cntr in range(nRuns):

    ## Train Data
    np.save(pp_npy[cntr]+'Dataset/repsTrain',repsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTrain',yRepsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTrain',eTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTrain',surpTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTrain',allStatesTrain[cntr])

    ## Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTest',repsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTest',yRepsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTest',eTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTest',surpTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTest',allStatesTest[cntr])
    
    ## Temporally violated Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTestTemp',repsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTestTemp',yRepsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTestTemp',eTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTestTemp',surpTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTestTemp',allStatesTestTemp[cntr])

# %% [markdown]
# #### Load seeds

# %%
seeds = np.load(pp_npy[cntr]+'seeds.npy')

# %% [markdown]
# #### Convert data into tensors, etc.

# %%
batch_size = 100 ##100

# %%
pos_seq_idx = np.array([0,0,1,1,2,2])

# %%
train_loader = {}
test_loader = {}
test_temp_loader = {}

# %%
for cntr in range(nRuns):
    train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=True)
    test_loader[cntr] = makeTensorLoaders((repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)
    test_temp_loader[cntr] = makeTensorLoaders((repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),
                                          batch_size,shuffle=False)

# %% [markdown]
# #### Load architectures, models, etc.

# %%
n_latent = 16 ## make sure it is the same in the architecture file as well
pop_list = [2,5,4] ## make sure it is the same in the architecture file as well

# %%
from architecture_no_feedback import microcircuit

# %%
model = {}
optimizer_rec = {}
optimizer_pc = {}

# %%
#specify loss function
reconLoss = nn.MSELoss()

#optimizer learning rate
eta_rec = 0.001
eta_pc = 0.0001

# %%
for cntr in range(nRuns):
    model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,pop_list=pop_list,bsize=batch_size,
                               manual_seed=seeds[cntr])
    model[cntr].to(device)
    optimizer_rec[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_rec)
    optimizer_pc[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_pc)

# %% [markdown]
# #### Train and collect activations

# %%
for data, f_target, lastEvent, surpriseBinary in train_loader[0]:
    if train_on_gpu:
        data, f_target = data.float().cuda(), f_target.float().cuda()
    else: data, f_target = data.float(), f_target.float()

# %%
output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[0](data)

# %%
nSteps = data.shape[1]

# %%
n_epochs = 100 ## number of epochs
div = n_epochs//n_epochs ## try ensuring that number used to divide by is a factor of n_epochs

# %%
feedback = True

# %%
def findMSE(output):
    errSq = output**2
    MSE_mat_samples_seq = errSq/np.prod(errSq.shape)
    MSE_samples = torch.mean(MSE_mat_samples_seq,1)
    return MSE_samples

# %%
train_losses = {}
test_losses = {}
temp_losses = {}

train_expected_rec_losses = {}
train_expected_fb_losses = {}

test_expected_rec_losses = {}
test_expected_fb_losses = {}

test_surprise_rec_losses = {}
test_surprise_fb_losses = {}

MSE_mat_full_test = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    train_losses[cntr] = np.zeros(n_epochs+1)
    test_losses[cntr] = np.zeros(n_epochs+1)
    temp_losses[cntr] = np.zeros(n_epochs+1)

    train_loss_min = np.Inf
    best_epoch = 0

    train_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    train_expected_fb_losses[cntr] = np.zeros(n_epochs+1)

    test_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_fb_losses[cntr] = np.zeros(n_epochs+1)
    
    test_surprise_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_surprise_fb_losses[cntr] = np.zeros(n_epochs+1)

    MSE_mat_full_test[cntr] = np.zeros(n_epochs+1)

    for epoch in (range(1,n_epochs+1)):

        train_loss = 0.0

        train_expected_rec_loss = 0.0
        train_expected_fb_loss = 0.0
        
        test_expected_rec_loss = 0.0
        test_expected_fb_loss = 0.0

        temp_rec_loss = 0.0
        temp_fb_loss = 0.0
        
        test_loss = 0.0
        temp_loss = 0.0

        cnt = 0
        
        ## Save model without training
        if epoch == 1:
            
            model[cntr].eval()
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_0.pt') ## Save model before any training
            
            ## Losses at 0th epoch
            for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
                if train_on_gpu:
                    data, f_target = data.float().cuda(), f_target.float().cuda()
                else:
                    data, f_target = data.float(), f_target.float()

                ##define all-sequence targets
                target = f_target

                optimizer_rec[cntr].zero_grad() #clears older gradients
                optimizer_pc[cntr].zero_grad() #clears older gradients
                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

                err_rec = torch.linalg.norm((output_pred-target),dim=2)
                err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
                MSE_samples_rec = findMSE(err_rec)
                MSE_samples_fb = findMSE(err_fb)

                loss = reconLoss(output_pred,target) #calculate the loss for the batch
                train_loss += loss.item()*data.size(0) #update training loss

                train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
                train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
                                    
            ## calculate average loss
            train_loss = train_loss/len(train_loader[cntr].dataset)
            
            ## Training loss at initialization
            train_losses[cntr][0] = train_loss
            train_expected_rec_losses[cntr][0] = train_expected_rec_loss
            train_expected_fb_losses[cntr][0] = train_expected_fb_loss
            
            ## Test losses at initialization
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test

                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)
                
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                # calculate the batch loss
                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
#             print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][0] = test_loss

            test_expected_rec_losses[cntr][0] = test_expected_rec_loss
            test_expected_fb_losses[cntr][0] = test_expected_fb_loss
        
        ## Test temp losses at initialization
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                    
                ##define all-sequence targets
                target_temp = f_target_temp

                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)
                loss_temp = reconLoss(output_pred_temp,target_temp)
                err_temp_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                # calculate the batch loss
                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_temp.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
#             print('Temp Loss: {:.6f}\n'.format(test_loss))

            temp_losses[cntr][0] = temp_loss

            test_surprise_rec_losses[cntr][0] = temp_rec_loss
            test_surprise_fb_losses[cntr][0] = temp_fb_loss

        #train model
        model[cntr].train()
        for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
            if train_on_gpu:
                data, f_target = data.float().cuda(), f_target.float().cuda()
            else:
                data, f_target = data.float(), f_target.float()

            ##define all-sequence targets
            target = f_target

            output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

            err_rec = torch.linalg.norm((output_pred-target),dim=2)
            err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
            MSE_samples_rec = findMSE(err_rec)
            MSE_samples_fb = findMSE(err_fb)
            
            loss = reconLoss(output_pred,target) #calculate the loss for the batch
            train_loss += loss.item()*data.size(0) #update training loss
            fbloss = torch.mean(MSE_samples_fb)

            optimizer_rec[cntr].zero_grad() #clears older gradients
            optimizer_pc[cntr].zero_grad() #clears older gradients
            ######## feedback error updates only higher-cortical area
            if (feedback)&(epoch%2==0):
                for name, param in model[cntr].named_parameters():
                    if ('FF' in name) or ('L23' in name) or ('L4' in name) or ('L56' in name):
                        param.require_grad = False
                fbloss.backward()
                optimizer_pc[cntr].step()
                for name, param in model[cntr].named_parameters():
                    param.require_grad = True
            else:
                loss.backward() #backprop
                optimizer_rec[cntr].step() #update parameters in direction of the -ve gradient  

            train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
            train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
        
        #calculate average loss
        train_loss = train_loss/len(train_loader[cntr].dataset)

        #training/validation stats
        train_losses[cntr][epoch] = train_loss
        train_expected_rec_losses[cntr][epoch] = train_expected_rec_loss
        train_expected_fb_losses[cntr][epoch] = train_expected_fb_loss

        #save model if the training loss decreased
        if train_loss <= train_loss_min:
            print('Epoch: {}, Train Loss Decreased!! ({:.6f}-->{:.6f})'.format(epoch,train_loss_min,train_loss))
            torch.save(model[cntr].state_dict(),pp_pts[cntr]+'predRNN.pt')
            train_loss_min = train_loss
            best_epoch = epoch

        if epoch%div == 0:
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_'+str(epoch)+'.pt')
            
            model[cntr].eval()
            
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test
                
                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)

                # calculate the batch loss
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
            print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][epoch] = test_loss

            test_expected_rec_losses[cntr][epoch] = test_expected_rec_loss
            test_expected_fb_losses[cntr][epoch] = test_expected_fb_loss
            
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                
                ##define all-sequence targets
                target_temp = f_target_temp
                
                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)

                # calculate the batch loss
                err_temp_rec = torch.linalg.norm((output_pred_temp-target_temp),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_temp[0],dim=2)+torch.linalg.norm(feedbackDiffs_temp[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_test.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
            print('Temp Loss: {:.6f}\n'.format(temp_loss))

            temp_losses[cntr][epoch] = temp_loss

            test_surprise_rec_losses[cntr][epoch] = temp_rec_loss
            test_surprise_fb_losses[cntr][epoch] = temp_fb_loss
            
    print('----------------------------------------------------')
            
    outF = open(pp+npp[cntr]+"training-details.txt", "w")
    outF.write('# epochs = ' + str(n_epochs))
    outF.write('\n')
    outF.write('Best epoch = '+str(best_epoch))
    outF.write('\n')
    outF.write('Minimum training loss = ' + str(train_loss_min))
    outF.write('\n')
    outF.write('Total number of samples = ' + str(nTot))
    outF.write('\n')
    outF.write('Number of training samples = ' + str(nTrain))
    outF.write('\n')
    outF.write('Number of testing samples = ' + str(nTest))
    outF.write('\n')
    outF.write('Dimensionality of representations = ' + str(dim))
    outF.write('\n')
    outF.write('Length of sequences = ' + str(lenSeq))
    outF.write('\n')
    outF.close()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1, Train Loss Decreased!! (inf-->0.290410)
# Test Loss: 0.253911
#
# Temp Loss: 0.254309
#
# Epoch: 2, Train Loss Decreased!! (0.290410-->0.252963)
# Test Loss: 0.253810
#
# Temp Loss: 0.253899
#
# Epoch: 3, Train Loss Decreased!! (0.252963-->0.249205)
# Test Loss: 0.241760
#
# Temp Loss: 0.241808
#
# Epoch: 4, Train Loss Decreased!! (0.249205-->0.241335)
# Test Loss: 0.241640
#
# Temp Loss: 0.241705
#
# Epoch: 5, Train Loss Decreased!! (0.241335-->0.230403)
# Test Loss: 0.221610
#
# Temp Loss: 0.223163
#
# Epoch: 6, Train Loss Decreased!! (0.230403-->0.220988)
# Test Loss: 0.222657
#
# Temp Loss: 0.224023
#
# Epoch: 7, Train Loss Decreased!! (0.220988-->0.210393)
# Test Loss: 0.201341
#
# Temp Loss: 0.219411
#
# Epoch: 8, Train Loss Decreased!! (0.210393-->0.199943)
# Test Loss: 0.203278
#
# Temp Loss: 0.220509
#
# Epoch: 9, Train Loss Decreased!! (0.199943-->0.190471)
# Test Loss: 0.179714
#
# Temp Loss: 0.209984
#
# Epoch: 10, Train Loss Decreased!! (0.190471-->0.180175)
# Test Loss: 0.185896
#
# Temp Loss: 0.215664
#
# Epoch: 11, Train Loss Decreased!! (0.180175-->0.167643)
# Test Loss: 0.157806
#
# Temp Loss: 0.189689
#
# Epoch: 12, Train Loss Decreased!! (0.167643-->0.163304)
# Test Loss: 0.174379
#
# Temp Loss: 0.202860
#
# Epoch: 13, Train Loss Decreased!! (0.163304-->0.153997)
# Test Loss: 0.145789
#
# Temp Loss: 0.177442
#
# Epoch: 14, Train Loss Decreased!! (0.153997-->0.146456)
# Test Loss: 0.152475
#
# Temp Loss: 0.183415
#
# Epoch: 15, Train Loss Decreased!! (0.146456-->0.138241)
# Test Loss: 0.130688
#
# Temp Loss: 0.162769
#
# Epoch: 16, Train Loss Decreased!! (0.138241-->0.131257)
# Test Loss: 0.137318
#
# Temp Loss: 0.168020
#
# Epoch: 17, Train Loss Decreased!! (0.131257-->0.125921)
# Test Loss: 0.123083
#
# Temp Loss: 0.155700
#
# Epoch: 18, Train Loss Decreased!! (0.125921-->0.122193)
# Test Loss: 0.128039
#
# Temp Loss: 0.160562
#
# Epoch: 19, Train Loss Decreased!! (0.122193-->0.116529)
# Test Loss: 0.112517
#
# Temp Loss: 0.146283
#
# Epoch: 20, Train Loss Decreased!! (0.116529-->0.112177)
# Test Loss: 0.119879
#
# Temp Loss: 0.153436
#
# Epoch: 21, Train Loss Decreased!! (0.112177-->0.105157)
# Test Loss: 0.098632
#
# Temp Loss: 0.131431
#
# Epoch: 22, Train Loss Decreased!! (0.105157-->0.099354)
# Test Loss: 0.105478
#
# Temp Loss: 0.137889
#
# Epoch: 23, Train Loss Decreased!! (0.099354-->0.094621)
# Test Loss: 0.092447
#
# Temp Loss: 0.125938
#
# Epoch: 24, Train Loss Decreased!! (0.094621-->0.091953)
# Test Loss: 0.097293
#
# Temp Loss: 0.129691
#
# Epoch: 25, Train Loss Decreased!! (0.091953-->0.087536)
# Test Loss: 0.084713
#
# Temp Loss: 0.120704
#
# Epoch: 26, Train Loss Decreased!! (0.087536-->0.083718)
# Test Loss: 0.088858
#
# Temp Loss: 0.123749
#
# Epoch: 27, Train Loss Decreased!! (0.083718-->0.080770)
# Test Loss: 0.080133
#
# Temp Loss: 0.113633
#
# Epoch: 28, Train Loss Decreased!! (0.080770-->0.079187)
# Test Loss: 0.083964
#
# Temp Loss: 0.115935
#
# Epoch: 29, Train Loss Decreased!! (0.079187-->0.077276)
# Test Loss: 0.077307
#
# Temp Loss: 0.110631
#
# Epoch: 30, Train Loss Decreased!! (0.077276-->0.076760)
# Test Loss: 0.081613
#
# Temp Loss: 0.113045
#
# Epoch: 31, Train Loss Decreased!! (0.076760-->0.075109)
# Test Loss: 0.074799
#
# Temp Loss: 0.109827
#
# Epoch: 32, Train Loss Decreased!! (0.075109-->0.074264)
# Test Loss: 0.079555
#
# Temp Loss: 0.112645
#
# Epoch: 33, Train Loss Decreased!! (0.074264-->0.072022)
# Test Loss: 0.070414
#
# Temp Loss: 0.109685
#
# Test Loss: 0.082277
#
# Temp Loss: 0.119074
#
# Epoch: 35, Train Loss Decreased!! (0.072022-->0.069330)
# Test Loss: 0.067815
#
# Temp Loss: 0.109429
#
# Test Loss: 0.080357
#
# Temp Loss: 0.118197
#
# Epoch: 37, Train Loss Decreased!! (0.069330-->0.067351)
# Test Loss: 0.065558
#
# Temp Loss: 0.107462
#
# Test Loss: 0.077822
#
# Temp Loss: 0.116251
#
# Epoch: 39, Train Loss Decreased!! (0.067351-->0.063128)
# Test Loss: 0.057851
#
# Temp Loss: 0.099971
#
# Test Loss: 0.080189
#
# Temp Loss: 0.118632
#
# Epoch: 41, Train Loss Decreased!! (0.063128-->0.058074)
# Test Loss: 0.053946
#
# Temp Loss: 0.095875
#
# Epoch: 42, Train Loss Decreased!! (0.058074-->0.057357)
# Test Loss: 0.067978
#
# Temp Loss: 0.107661
#
# Epoch: 43, Train Loss Decreased!! (0.057357-->0.054030)
# Test Loss: 0.051254
#
# Temp Loss: 0.093767
#
# Test Loss: 0.063081
#
# Temp Loss: 0.102847
#
# Epoch: 45, Train Loss Decreased!! (0.054030-->0.050959)
# Test Loss: 0.047626
#
# Temp Loss: 0.089773
#
# Test Loss: 0.059454
#
# Temp Loss: 0.098400
#
# Epoch: 47, Train Loss Decreased!! (0.050959-->0.046880)
# Test Loss: 0.043467
#
# Temp Loss: 0.087584
#
# Test Loss: 0.055935
#
# Temp Loss: 0.097216
#
# Epoch: 49, Train Loss Decreased!! (0.046880-->0.043601)
# Test Loss: 0.039938
#
# Temp Loss: 0.086029
#
# Epoch: 50, Train Loss Decreased!! (0.043601-->0.043001)
# Test Loss: 0.050397
#
# Temp Loss: 0.092828
#
# Epoch: 51, Train Loss Decreased!! (0.043001-->0.039566)
# Test Loss: 0.036566
#
# Temp Loss: 0.085860
#
# Epoch: 52, Train Loss Decreased!! (0.039566-->0.039150)
# Test Loss: 0.045965
#
# Temp Loss: 0.091716
#
# Epoch: 53, Train Loss Decreased!! (0.039150-->0.036273)
# Test Loss: 0.034048
#
# Temp Loss: 0.086565
#
# Test Loss: 0.045241
#
# Temp Loss: 0.094177
#
# Epoch: 55, Train Loss Decreased!! (0.036273-->0.034444)
# Test Loss: 0.032001
#
# Temp Loss: 0.086981
#
# Test Loss: 0.044886
#
# Temp Loss: 0.095986
#
# Epoch: 57, Train Loss Decreased!! (0.034444-->0.033238)
# Test Loss: 0.030993
#
# Temp Loss: 0.085273
#
# Test Loss: 0.044570
#
# Temp Loss: 0.095214
#
# Epoch: 59, Train Loss Decreased!! (0.033238-->0.031847)
# Test Loss: 0.029466
#
# Temp Loss: 0.085425
#
# Test Loss: 0.044598
#
# Temp Loss: 0.095807
#
# Epoch: 61, Train Loss Decreased!! (0.031847-->0.030984)
# Test Loss: 0.028402
#
# Temp Loss: 0.084380
#
# Test Loss: 0.045978
#
# Temp Loss: 0.096580
#
# Epoch: 63, Train Loss Decreased!! (0.030984-->0.030377)
# Test Loss: 0.027355
#
# Temp Loss: 0.084290
#
# Test Loss: 0.044062
#
# Temp Loss: 0.095781
#
# Epoch: 65, Train Loss Decreased!! (0.030377-->0.029195)
# Test Loss: 0.026473
#
# Temp Loss: 0.083851
#
# Test Loss: 0.044971
#
# Temp Loss: 0.096371
#
# Epoch: 67, Train Loss Decreased!! (0.029195-->0.028177)
# Test Loss: 0.024762
#
# Temp Loss: 0.084074
#
# Test Loss: 0.042532
#
# Temp Loss: 0.095498
#
# Epoch: 69, Train Loss Decreased!! (0.028177-->0.025991)
# Test Loss: 0.021390
#
# Temp Loss: 0.081502
#
# Test Loss: 0.039625
#
# Temp Loss: 0.093683
#
# Epoch: 71, Train Loss Decreased!! (0.025991-->0.022272)
# Test Loss: 0.017251
#
# Temp Loss: 0.078255
#
# Test Loss: 0.034185
#
# Temp Loss: 0.089719
#
# Epoch: 73, Train Loss Decreased!! (0.022272-->0.018571)
# Test Loss: 0.014788
#
# Temp Loss: 0.078109
#
# Test Loss: 0.032389
#
# Temp Loss: 0.089600
#
# Epoch: 75, Train Loss Decreased!! (0.018571-->0.016499)
# Test Loss: 0.013199
#
# Temp Loss: 0.078004
#
# Test Loss: 0.030447
#
# Temp Loss: 0.088525
#
# Epoch: 77, Train Loss Decreased!! (0.016499-->0.015181)
# Test Loss: 0.012048
#
# Temp Loss: 0.079241
#
# Test Loss: 0.029616
#
# Temp Loss: 0.089882
#
# Epoch: 79, Train Loss Decreased!! (0.015181-->0.014114)
# Test Loss: 0.010959
#
# Temp Loss: 0.080038
#
# Test Loss: 0.030023
#
# Temp Loss: 0.091136
#
# Epoch: 81, Train Loss Decreased!! (0.014114-->0.013222)
# Test Loss: 0.009975
#
# Temp Loss: 0.080982
#
# Test Loss: 0.027672
#
# Temp Loss: 0.090582
#
# Epoch: 83, Train Loss Decreased!! (0.013222-->0.011862)
# Test Loss: 0.008974
#
# Temp Loss: 0.082196
#
# Test Loss: 0.026717
#
# Temp Loss: 0.091683
#
# Epoch: 85, Train Loss Decreased!! (0.011862-->0.011102)
# Test Loss: 0.008122
#
# Temp Loss: 0.083451
#
# Test Loss: 0.026401
#
# Temp Loss: 0.093256
#
# Epoch: 87, Train Loss Decreased!! (0.011102-->0.010223)
# Test Loss: 0.007372
#
# Temp Loss: 0.083868
#
# Test Loss: 0.025352
#
# Temp Loss: 0.093704
#
# Epoch: 89, Train Loss Decreased!! (0.010223-->0.009703)
# Test Loss: 0.006969
#
# Temp Loss: 0.084545
#
# Test Loss: 0.025543
#
# Temp Loss: 0.094787
#
# Epoch: 91, Train Loss Decreased!! (0.009703-->0.009182)
# Test Loss: 0.006250
#
# Temp Loss: 0.084849
#
# Test Loss: 0.025146
#
# Temp Loss: 0.095240
#
# Epoch: 93, Train Loss Decreased!! (0.009182-->0.008942)
# Test Loss: 0.006072
#
# Temp Loss: 0.084690
#
# Test Loss: 0.024257
#
# Temp Loss: 0.094598
#
# Epoch: 95, Train Loss Decreased!! (0.008942-->0.008395)
# Test Loss: 0.005667
#
# Temp Loss: 0.085138
#
# Test Loss: 0.024275
#
# Temp Loss: 0.095372
#
# Epoch: 97, Train Loss Decreased!! (0.008395-->0.008145)
# Test Loss: 0.005432
#
# Temp Loss: 0.085108
#
# Test Loss: 0.023863
#
# Temp Loss: 0.095372
#
# Epoch: 99, Train Loss Decreased!! (0.008145-->0.008031)
# Test Loss: 0.005142
#
# Temp Loss: 0.084637
#  20%|██        | 1/5 [01:55<07:41, 115.37s/it]
# Test Loss: 0.021888
#
# Temp Loss: 0.094024
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.294114)
# Test Loss: 0.252733
#
# Temp Loss: 0.252513
#
# Epoch: 2, Train Loss Decreased!! (0.294114-->0.252191)
# Test Loss: 0.252485
#
# Temp Loss: 0.252272
#
# Epoch: 3, Train Loss Decreased!! (0.252191-->0.246408)
# Test Loss: 0.237468
#
# Temp Loss: 0.237535
#
# Epoch: 4, Train Loss Decreased!! (0.246408-->0.238184)
# Test Loss: 0.238399
#
# Temp Loss: 0.238701
#
# Epoch: 5, Train Loss Decreased!! (0.238184-->0.226220)
# Test Loss: 0.212604
#
# Temp Loss: 0.214685
#
# Epoch: 6, Train Loss Decreased!! (0.226220-->0.214583)
# Test Loss: 0.214654
#
# Temp Loss: 0.217100
#
# Epoch: 7, Train Loss Decreased!! (0.214583-->0.202806)
# Test Loss: 0.183725
#
# Temp Loss: 0.204879
#
# Epoch: 8, Train Loss Decreased!! (0.202806-->0.186298)
# Test Loss: 0.185689
#
# Temp Loss: 0.205897
#
# Epoch: 9, Train Loss Decreased!! (0.186298-->0.174982)
# Test Loss: 0.165492
#
# Temp Loss: 0.194360
#
# Epoch: 10, Train Loss Decreased!! (0.174982-->0.168001)
# Test Loss: 0.166859
#
# Temp Loss: 0.195042
#
# Epoch: 11, Train Loss Decreased!! (0.168001-->0.161248)
# Test Loss: 0.148254
#
# Temp Loss: 0.178534
#
# Epoch: 12, Train Loss Decreased!! (0.161248-->0.151151)
# Test Loss: 0.152566
#
# Temp Loss: 0.181940
#
# Epoch: 13, Train Loss Decreased!! (0.151151-->0.142957)
# Test Loss: 0.136244
#
# Temp Loss: 0.168402
#
# Epoch: 14, Train Loss Decreased!! (0.142957-->0.138409)
# Test Loss: 0.140236
#
# Temp Loss: 0.171204
#
# Epoch: 15, Train Loss Decreased!! (0.138409-->0.133864)
# Test Loss: 0.124830
#
# Temp Loss: 0.154834
#
# Epoch: 16, Train Loss Decreased!! (0.133864-->0.127838)
# Test Loss: 0.131055
#
# Temp Loss: 0.160550
#
# Epoch: 17, Train Loss Decreased!! (0.127838-->0.122861)
# Test Loss: 0.117898
#
# Temp Loss: 0.149199
#
# Epoch: 18, Train Loss Decreased!! (0.122861-->0.119810)
# Test Loss: 0.123401
#
# Temp Loss: 0.154562
#
# Epoch: 19, Train Loss Decreased!! (0.119810-->0.113326)
# Test Loss: 0.107504
#
# Temp Loss: 0.138841
#
# Epoch: 20, Train Loss Decreased!! (0.113326-->0.109730)
# Test Loss: 0.114586
#
# Temp Loss: 0.145676
#
# Epoch: 21, Train Loss Decreased!! (0.109730-->0.104738)
# Test Loss: 0.098232
#
# Temp Loss: 0.129145
#
# Epoch: 22, Train Loss Decreased!! (0.104738-->0.100466)
# Test Loss: 0.105961
#
# Temp Loss: 0.136251
#
# Epoch: 23, Train Loss Decreased!! (0.100466-->0.093211)
# Test Loss: 0.087231
#
# Temp Loss: 0.119058
#
# Epoch: 24, Train Loss Decreased!! (0.093211-->0.088367)
# Test Loss: 0.093054
#
# Temp Loss: 0.124336
#
# Epoch: 25, Train Loss Decreased!! (0.088367-->0.081288)
# Test Loss: 0.076823
#
# Temp Loss: 0.109833
#
# Epoch: 26, Train Loss Decreased!! (0.081288-->0.077752)
# Test Loss: 0.082177
#
# Temp Loss: 0.114353
#
# Epoch: 27, Train Loss Decreased!! (0.077752-->0.074611)
# Test Loss: 0.072097
#
# Temp Loss: 0.106442
#
# Epoch: 28, Train Loss Decreased!! (0.074611-->0.073331)
# Test Loss: 0.078600
#
# Temp Loss: 0.111515
#
# Epoch: 29, Train Loss Decreased!! (0.073331-->0.068686)
# Test Loss: 0.064127
#
# Temp Loss: 0.099640
#
# Epoch: 30, Train Loss Decreased!! (0.068686-->0.065145)
# Test Loss: 0.072002
#
# Temp Loss: 0.105306
#
# Epoch: 31, Train Loss Decreased!! (0.065145-->0.058110)
# Test Loss: 0.054632
#
# Temp Loss: 0.091539
#
# Epoch: 32, Train Loss Decreased!! (0.058110-->0.054455)
# Test Loss: 0.060732
#
# Temp Loss: 0.096894
#
# Epoch: 33, Train Loss Decreased!! (0.054455-->0.051692)
# Test Loss: 0.050676
#
# Temp Loss: 0.089899
#
# Epoch: 34, Train Loss Decreased!! (0.051692-->0.050071)
# Test Loss: 0.055049
#
# Temp Loss: 0.092607
#
# Epoch: 35, Train Loss Decreased!! (0.050071-->0.048130)
# Test Loss: 0.047372
#
# Temp Loss: 0.087905
#
# Epoch: 36, Train Loss Decreased!! (0.048130-->0.046831)
# Test Loss: 0.052001
#
# Temp Loss: 0.091268
#
# Epoch: 37, Train Loss Decreased!! (0.046831-->0.044762)
# Test Loss: 0.043940
#
# Temp Loss: 0.087115
#
# Epoch: 38, Train Loss Decreased!! (0.044762-->0.044139)
# Test Loss: 0.050416
#
# Temp Loss: 0.090990
#
# Epoch: 39, Train Loss Decreased!! (0.044139-->0.042160)
# Test Loss: 0.041434
#
# Temp Loss: 0.087066
#
# Epoch: 40, Train Loss Decreased!! (0.042160-->0.041729)
# Test Loss: 0.048766
#
# Temp Loss: 0.091223
#
# Epoch: 41, Train Loss Decreased!! (0.041729-->0.039589)
# Test Loss: 0.038733
#
# Temp Loss: 0.087308
#
# Test Loss: 0.050144
#
# Temp Loss: 0.094507
#
# Epoch: 43, Train Loss Decreased!! (0.039589-->0.037324)
# Test Loss: 0.036249
#
# Temp Loss: 0.086460
#
# Test Loss: 0.046391
#
# Temp Loss: 0.092458
#
# Epoch: 45, Train Loss Decreased!! (0.037324-->0.035310)
# Test Loss: 0.034491
#
# Temp Loss: 0.087027
#
# Test Loss: 0.046484
#
# Temp Loss: 0.093884
#
# Epoch: 47, Train Loss Decreased!! (0.035310-->0.034064)
# Test Loss: 0.033154
#
# Temp Loss: 0.085686
#
# Test Loss: 0.044065
#
# Temp Loss: 0.091673
#
# Epoch: 49, Train Loss Decreased!! (0.034064-->0.032663)
# Test Loss: 0.031880
#
# Temp Loss: 0.086031
#
# Test Loss: 0.044219
#
# Temp Loss: 0.092343
#
# Epoch: 51, Train Loss Decreased!! (0.032663-->0.031683)
# Test Loss: 0.030729
#
# Temp Loss: 0.085826
#
# Test Loss: 0.044215
#
# Temp Loss: 0.092894
#
# Epoch: 53, Train Loss Decreased!! (0.031683-->0.030407)
# Test Loss: 0.029356
#
# Temp Loss: 0.085902
#
# Test Loss: 0.044645
#
# Temp Loss: 0.093648
#
# Epoch: 55, Train Loss Decreased!! (0.030407-->0.029045)
# Test Loss: 0.027516
#
# Temp Loss: 0.085823
#
# Test Loss: 0.043081
#
# Temp Loss: 0.093387
#
# Epoch: 57, Train Loss Decreased!! (0.029045-->0.026773)
# Test Loss: 0.024000
#
# Temp Loss: 0.083746
#
# Test Loss: 0.038927
#
# Temp Loss: 0.090754
#
# Epoch: 59, Train Loss Decreased!! (0.026773-->0.022460)
# Test Loss: 0.019738
#
# Temp Loss: 0.081474
#
# Test Loss: 0.034441
#
# Temp Loss: 0.088602
#
# Epoch: 61, Train Loss Decreased!! (0.022460-->0.019096)
# Test Loss: 0.017041
#
# Temp Loss: 0.081257
#
# Test Loss: 0.032869
#
# Temp Loss: 0.088327
#
# Epoch: 63, Train Loss Decreased!! (0.019096-->0.017484)
# Test Loss: 0.015477
#
# Temp Loss: 0.081843
#
# Test Loss: 0.030025
#
# Temp Loss: 0.087228
#
# Epoch: 65, Train Loss Decreased!! (0.017484-->0.015919)
# Test Loss: 0.014428
#
# Temp Loss: 0.081244
#
# Test Loss: 0.031097
#
# Temp Loss: 0.088017
#
# Epoch: 67, Train Loss Decreased!! (0.015919-->0.015058)
# Test Loss: 0.013372
#
# Temp Loss: 0.081692
#
# Test Loss: 0.030280
#
# Temp Loss: 0.088082
#
# Epoch: 69, Train Loss Decreased!! (0.015058-->0.014141)
# Test Loss: 0.012735
#
# Temp Loss: 0.082591
#
# Test Loss: 0.030005
#
# Temp Loss: 0.088998
#
# Epoch: 71, Train Loss Decreased!! (0.014141-->0.013387)
# Test Loss: 0.011752
#
# Temp Loss: 0.083160
#
# Test Loss: 0.027527
#
# Temp Loss: 0.087674
#
# Epoch: 73, Train Loss Decreased!! (0.013387-->0.012361)
# Test Loss: 0.010907
#
# Temp Loss: 0.083703
#
# Test Loss: 0.028800
#
# Temp Loss: 0.089101
#
# Epoch: 75, Train Loss Decreased!! (0.012361-->0.011788)
# Test Loss: 0.010144
#
# Temp Loss: 0.084259
#
# Test Loss: 0.028744
#
# Temp Loss: 0.089375
#
# Epoch: 77, Train Loss Decreased!! (0.011788-->0.011028)
# Test Loss: 0.009387
#
# Temp Loss: 0.084956
#
# Test Loss: 0.027895
#
# Temp Loss: 0.089954
#
# Epoch: 79, Train Loss Decreased!! (0.011028-->0.010411)
# Test Loss: 0.008608
#
# Temp Loss: 0.085745
#
# Test Loss: 0.026642
#
# Temp Loss: 0.089001
#
# Epoch: 81, Train Loss Decreased!! (0.010411-->0.009563)
# Test Loss: 0.007931
#
# Temp Loss: 0.085439
#
# Test Loss: 0.027354
#
# Temp Loss: 0.089423
#
# Epoch: 83, Train Loss Decreased!! (0.009563-->0.009164)
# Test Loss: 0.007585
#
# Temp Loss: 0.085947
#
# Test Loss: 0.025900
#
# Temp Loss: 0.088734
#
# Epoch: 85, Train Loss Decreased!! (0.009164-->0.008637)
# Test Loss: 0.006848
#
# Temp Loss: 0.085432
#
# Test Loss: 0.026531
#
# Temp Loss: 0.089032
#
# Epoch: 87, Train Loss Decreased!! (0.008637-->0.008439)
# Test Loss: 0.006865
#
# Temp Loss: 0.085385
#
# Test Loss: 0.025729
#
# Temp Loss: 0.088614
#
# Epoch: 89, Train Loss Decreased!! (0.008439-->0.008074)
# Test Loss: 0.006517
#
# Temp Loss: 0.084997
#
# Test Loss: 0.025143
#
# Temp Loss: 0.087957
#
# Test Loss: 0.006425
#
# Temp Loss: 0.085299
#
# Test Loss: 0.024845
#
# Temp Loss: 0.087983
#
# Epoch: 93, Train Loss Decreased!! (0.008074-->0.008002)
# Test Loss: 0.006121
#
# Temp Loss: 0.085398
#
# Test Loss: 0.023668
#
# Temp Loss: 0.087569
#
# Epoch: 95, Train Loss Decreased!! (0.008002-->0.007534)
# Test Loss: 0.005973
#
# Temp Loss: 0.085254
#
# Test Loss: 0.022908
#
# Temp Loss: 0.087252
#
# Epoch: 97, Train Loss Decreased!! (0.007534-->0.007364)
# Test Loss: 0.005705
#
# Temp Loss: 0.085225
#
# Test Loss: 0.022592
#
# Temp Loss: 0.086941
#
# Epoch: 99, Train Loss Decreased!! (0.007364-->0.007044)
# Test Loss: 0.005526
#
# Temp Loss: 0.085474
#  40%|████      | 2/5 [03:49<05:43, 114.41s/it]
# Test Loss: 0.022468
#
# Temp Loss: 0.087721
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.290318)
# Test Loss: 0.253203
#
# Temp Loss: 0.252828
#
# Epoch: 2, Train Loss Decreased!! (0.290318-->0.252133)
# Test Loss: 0.252782
#
# Temp Loss: 0.252509
#
# Epoch: 3, Train Loss Decreased!! (0.252133-->0.248720)
# Test Loss: 0.243067
#
# Temp Loss: 0.242978
#
# Epoch: 4, Train Loss Decreased!! (0.248720-->0.242456)
# Test Loss: 0.243947
#
# Temp Loss: 0.244313
#
# Epoch: 5, Train Loss Decreased!! (0.242456-->0.235095)
# Test Loss: 0.226818
#
# Temp Loss: 0.228486
#
# Epoch: 6, Train Loss Decreased!! (0.235095-->0.226240)
# Test Loss: 0.227698
#
# Temp Loss: 0.228755
#
# Epoch: 7, Train Loss Decreased!! (0.226240-->0.217494)
# Test Loss: 0.207698
#
# Temp Loss: 0.209004
#
# Epoch: 8, Train Loss Decreased!! (0.217494-->0.208633)
# Test Loss: 0.211227
#
# Temp Loss: 0.212558
#
# Epoch: 9, Train Loss Decreased!! (0.208633-->0.193719)
# Test Loss: 0.180506
#
# Temp Loss: 0.189653
#
# Epoch: 10, Train Loss Decreased!! (0.193719-->0.180929)
# Test Loss: 0.184705
#
# Temp Loss: 0.193886
#
# Epoch: 11, Train Loss Decreased!! (0.180929-->0.168340)
# Test Loss: 0.157574
#
# Temp Loss: 0.185840
#
# Epoch: 12, Train Loss Decreased!! (0.168340-->0.158576)
# Test Loss: 0.161556
#
# Temp Loss: 0.189133
#
# Epoch: 13, Train Loss Decreased!! (0.158576-->0.154829)
# Test Loss: 0.152308
#
# Temp Loss: 0.183247
#
# Epoch: 14, Train Loss Decreased!! (0.154829-->0.151819)
# Test Loss: 0.153619
#
# Temp Loss: 0.183691
#
# Epoch: 15, Train Loss Decreased!! (0.151819-->0.145631)
# Test Loss: 0.139042
#
# Temp Loss: 0.171327
#
# Epoch: 16, Train Loss Decreased!! (0.145631-->0.138508)
# Test Loss: 0.141534
#
# Temp Loss: 0.174204
#
# Epoch: 17, Train Loss Decreased!! (0.138508-->0.131254)
# Test Loss: 0.125592
#
# Temp Loss: 0.157277
#
# Epoch: 18, Train Loss Decreased!! (0.131254-->0.124916)
# Test Loss: 0.128635
#
# Temp Loss: 0.160231
#
# Epoch: 19, Train Loss Decreased!! (0.124916-->0.122260)
# Test Loss: 0.120736
#
# Temp Loss: 0.153021
#
# Epoch: 20, Train Loss Decreased!! (0.122260-->0.119908)
# Test Loss: 0.123582
#
# Temp Loss: 0.155724
#
# Epoch: 21, Train Loss Decreased!! (0.119908-->0.116089)
# Test Loss: 0.112065
#
# Temp Loss: 0.148349
#
# Epoch: 22, Train Loss Decreased!! (0.116089-->0.113050)
# Test Loss: 0.118766
#
# Temp Loss: 0.153798
#
# Epoch: 23, Train Loss Decreased!! (0.113050-->0.105652)
# Test Loss: 0.098034
#
# Temp Loss: 0.134546
#
# Epoch: 24, Train Loss Decreased!! (0.105652-->0.100159)
# Test Loss: 0.108568
#
# Temp Loss: 0.143420
#
# Epoch: 25, Train Loss Decreased!! (0.100159-->0.088528)
# Test Loss: 0.083811
#
# Temp Loss: 0.119311
#
# Epoch: 26, Train Loss Decreased!! (0.088528-->0.083758)
# Test Loss: 0.091208
#
# Temp Loss: 0.126686
#
# Epoch: 27, Train Loss Decreased!! (0.083758-->0.078724)
# Test Loss: 0.075634
#
# Temp Loss: 0.113445
#
# Epoch: 28, Train Loss Decreased!! (0.078724-->0.075610)
# Test Loss: 0.081486
#
# Temp Loss: 0.119489
#
# Epoch: 29, Train Loss Decreased!! (0.075610-->0.072136)
# Test Loss: 0.071396
#
# Temp Loss: 0.111779
#
# Epoch: 30, Train Loss Decreased!! (0.072136-->0.071085)
# Test Loss: 0.076348
#
# Temp Loss: 0.116522
#
# Epoch: 31, Train Loss Decreased!! (0.071085-->0.069160)
# Test Loss: 0.068974
#
# Temp Loss: 0.109435
#
# Epoch: 32, Train Loss Decreased!! (0.069160-->0.068900)
# Test Loss: 0.073635
#
# Temp Loss: 0.114113
#
# Epoch: 33, Train Loss Decreased!! (0.068900-->0.066909)
# Test Loss: 0.065995
#
# Temp Loss: 0.105781
#
# Epoch: 34, Train Loss Decreased!! (0.066909-->0.066416)
# Test Loss: 0.071587
#
# Temp Loss: 0.110795
#
# Epoch: 35, Train Loss Decreased!! (0.066416-->0.062958)
# Test Loss: 0.060064
#
# Temp Loss: 0.101243
#
# Epoch: 36, Train Loss Decreased!! (0.062958-->0.062044)
# Test Loss: 0.068197
#
# Temp Loss: 0.108873
#
# Epoch: 37, Train Loss Decreased!! (0.062044-->0.057926)
# Test Loss: 0.056576
#
# Temp Loss: 0.097815
#
# Test Loss: 0.064571
#
# Temp Loss: 0.105721
#
# Epoch: 39, Train Loss Decreased!! (0.057926-->0.055412)
# Test Loss: 0.054612
#
# Temp Loss: 0.096457
#
# Test Loss: 0.062551
#
# Temp Loss: 0.104304
#
# Epoch: 41, Train Loss Decreased!! (0.055412-->0.053722)
# Test Loss: 0.053388
#
# Temp Loss: 0.094740
#
# Test Loss: 0.059181
#
# Temp Loss: 0.100737
#
# Epoch: 43, Train Loss Decreased!! (0.053722-->0.051752)
# Test Loss: 0.051131
#
# Temp Loss: 0.093224
#
# Test Loss: 0.058918
#
# Temp Loss: 0.100187
#
# Epoch: 45, Train Loss Decreased!! (0.051752-->0.049341)
# Test Loss: 0.047728
#
# Temp Loss: 0.091043
#
# Test Loss: 0.060529
#
# Temp Loss: 0.101932
#
# Epoch: 47, Train Loss Decreased!! (0.049341-->0.045883)
# Test Loss: 0.042618
#
# Temp Loss: 0.087814
#
# Test Loss: 0.058802
#
# Temp Loss: 0.101298
#
# Epoch: 49, Train Loss Decreased!! (0.045883-->0.041490)
# Test Loss: 0.038155
#
# Temp Loss: 0.084525
#
# Epoch: 50, Train Loss Decreased!! (0.041490-->0.041327)
# Test Loss: 0.051397
#
# Temp Loss: 0.095572
#
# Epoch: 51, Train Loss Decreased!! (0.041327-->0.036185)
# Test Loss: 0.033058
#
# Temp Loss: 0.083641
#
# Test Loss: 0.048033
#
# Temp Loss: 0.096737
#
# Epoch: 53, Train Loss Decreased!! (0.036185-->0.031686)
# Test Loss: 0.028914
#
# Temp Loss: 0.084588
#
# Test Loss: 0.041855
#
# Temp Loss: 0.095999
#
# Epoch: 55, Train Loss Decreased!! (0.031686-->0.028076)
# Test Loss: 0.025982
#
# Temp Loss: 0.083978
#
# Test Loss: 0.038363
#
# Temp Loss: 0.094269
#
# Epoch: 57, Train Loss Decreased!! (0.028076-->0.024747)
# Test Loss: 0.022859
#
# Temp Loss: 0.081772
#
# Epoch: 58, Train Loss Decreased!! (0.024747-->0.024610)
# Test Loss: 0.032491
#
# Temp Loss: 0.088113
#
# Epoch: 59, Train Loss Decreased!! (0.024610-->0.021502)
# Test Loss: 0.020157
#
# Temp Loss: 0.080907
#
# Test Loss: 0.029100
#
# Temp Loss: 0.087307
#
# Epoch: 61, Train Loss Decreased!! (0.021502-->0.018804)
# Test Loss: 0.017333
#
# Temp Loss: 0.081529
#
# Test Loss: 0.025521
#
# Temp Loss: 0.086254
#
# Epoch: 63, Train Loss Decreased!! (0.018804-->0.016484)
# Test Loss: 0.015604
#
# Temp Loss: 0.082904
#
# Test Loss: 0.023293
#
# Temp Loss: 0.086012
#
# Epoch: 65, Train Loss Decreased!! (0.016484-->0.014942)
# Test Loss: 0.014163
#
# Temp Loss: 0.083236
#
# Test Loss: 0.021856
#
# Temp Loss: 0.085601
#
# Epoch: 67, Train Loss Decreased!! (0.014942-->0.013833)
# Test Loss: 0.013296
#
# Temp Loss: 0.083726
#
# Test Loss: 0.020993
#
# Temp Loss: 0.085657
#
# Epoch: 69, Train Loss Decreased!! (0.013833-->0.012837)
# Test Loss: 0.012272
#
# Temp Loss: 0.083542
#
# Test Loss: 0.019441
#
# Temp Loss: 0.084844
#
# Epoch: 71, Train Loss Decreased!! (0.012837-->0.012047)
# Test Loss: 0.011585
#
# Temp Loss: 0.084142
#
# Test Loss: 0.018933
#
# Temp Loss: 0.085377
#
# Epoch: 73, Train Loss Decreased!! (0.012047-->0.011364)
# Test Loss: 0.010864
#
# Temp Loss: 0.083515
#
# Test Loss: 0.018687
#
# Temp Loss: 0.085152
#
# Epoch: 75, Train Loss Decreased!! (0.011364-->0.011098)
# Test Loss: 0.010625
#
# Temp Loss: 0.083544
#
# Test Loss: 0.018124
#
# Temp Loss: 0.085188
#
# Epoch: 77, Train Loss Decreased!! (0.011098-->0.010546)
# Test Loss: 0.009950
#
# Temp Loss: 0.083901
#
# Test Loss: 0.016976
#
# Temp Loss: 0.085246
#
# Epoch: 79, Train Loss Decreased!! (0.010546-->0.009984)
# Test Loss: 0.009569
#
# Temp Loss: 0.083873
#
# Test Loss: 0.016337
#
# Temp Loss: 0.085160
#
# Epoch: 81, Train Loss Decreased!! (0.009984-->0.009645)
# Test Loss: 0.009427
#
# Temp Loss: 0.083865
#
# Test Loss: 0.015398
#
# Temp Loss: 0.084460
#
# Epoch: 83, Train Loss Decreased!! (0.009645-->0.009210)
# Test Loss: 0.008974
#
# Temp Loss: 0.083730
#
# Test Loss: 0.015629
#
# Temp Loss: 0.085214
#
# Epoch: 85, Train Loss Decreased!! (0.009210-->0.009115)
# Test Loss: 0.008682
#
# Temp Loss: 0.084147
#
# Test Loss: 0.015222
#
# Temp Loss: 0.085655
#
# Epoch: 87, Train Loss Decreased!! (0.009115-->0.008800)
# Test Loss: 0.008464
#
# Temp Loss: 0.084232
#
# Test Loss: 0.015288
#
# Temp Loss: 0.086114
#
# Epoch: 89, Train Loss Decreased!! (0.008800-->0.008719)
# Test Loss: 0.008229
#
# Temp Loss: 0.084193
#
# Test Loss: 0.015380
#
# Temp Loss: 0.086664
#
# Epoch: 91, Train Loss Decreased!! (0.008719-->0.008526)
# Test Loss: 0.008065
#
# Temp Loss: 0.084317
#
# Test Loss: 0.014811
#
# Temp Loss: 0.086344
#
# Epoch: 93, Train Loss Decreased!! (0.008526-->0.008374)
# Test Loss: 0.007840
#
# Temp Loss: 0.084383
#
# Test Loss: 0.014622
#
# Temp Loss: 0.086597
#
# Epoch: 95, Train Loss Decreased!! (0.008374-->0.008128)
# Test Loss: 0.007674
#
# Temp Loss: 0.084590
#
# Test Loss: 0.014927
#
# Temp Loss: 0.087226
#
# Epoch: 97, Train Loss Decreased!! (0.008128-->0.008081)
# Test Loss: 0.007646
#
# Temp Loss: 0.084729
#
# Test Loss: 0.014558
#
# Temp Loss: 0.086822
#
# Epoch: 99, Train Loss Decreased!! (0.008081-->0.007858)
# Test Loss: 0.007425
#
# Temp Loss: 0.084372
#  60%|██████    | 3/5 [05:42<03:48, 114.11s/it]
# Test Loss: 0.014821
#
# Temp Loss: 0.086939
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.291095)
# Test Loss: 0.253250
#
# Temp Loss: 0.253518
#
# Epoch: 2, Train Loss Decreased!! (0.291095-->0.253012)
# Test Loss: 0.253177
#
# Temp Loss: 0.253124
#
# Epoch: 3, Train Loss Decreased!! (0.253012-->0.247690)
# Test Loss: 0.237931
#
# Temp Loss: 0.237933
#
# Epoch: 4, Train Loss Decreased!! (0.247690-->0.238887)
# Test Loss: 0.240286
#
# Temp Loss: 0.240508
#
# Epoch: 5, Train Loss Decreased!! (0.238887-->0.227644)
# Test Loss: 0.214819
#
# Temp Loss: 0.215642
#
# Epoch: 6, Train Loss Decreased!! (0.227644-->0.217531)
# Test Loss: 0.220966
#
# Temp Loss: 0.221987
#
# Epoch: 7, Train Loss Decreased!! (0.217531-->0.205481)
# Test Loss: 0.191897
#
# Temp Loss: 0.201653
#
# Epoch: 8, Train Loss Decreased!! (0.205481-->0.195881)
# Test Loss: 0.200450
#
# Temp Loss: 0.209536
#
# Epoch: 9, Train Loss Decreased!! (0.195881-->0.183965)
# Test Loss: 0.172295
#
# Temp Loss: 0.198978
#
# Epoch: 10, Train Loss Decreased!! (0.183965-->0.174493)
# Test Loss: 0.177402
#
# Temp Loss: 0.201605
#
# Epoch: 11, Train Loss Decreased!! (0.174493-->0.168937)
# Test Loss: 0.162257
#
# Temp Loss: 0.192626
#
# Epoch: 12, Train Loss Decreased!! (0.168937-->0.165085)
# Test Loss: 0.170148
#
# Temp Loss: 0.197921
#
# Epoch: 13, Train Loss Decreased!! (0.165085-->0.155156)
# Test Loss: 0.143490
#
# Temp Loss: 0.173915
#
# Epoch: 14, Train Loss Decreased!! (0.155156-->0.146250)
# Test Loss: 0.153102
#
# Temp Loss: 0.182012
#
# Epoch: 15, Train Loss Decreased!! (0.146250-->0.134227)
# Test Loss: 0.124260
#
# Temp Loss: 0.157168
#
# Epoch: 16, Train Loss Decreased!! (0.134227-->0.127544)
# Test Loss: 0.136461
#
# Temp Loss: 0.167813
#
# Epoch: 17, Train Loss Decreased!! (0.127544-->0.119319)
# Test Loss: 0.115016
#
# Temp Loss: 0.152841
#
# Epoch: 18, Train Loss Decreased!! (0.119319-->0.116202)
# Test Loss: 0.122583
#
# Temp Loss: 0.158371
#
# Epoch: 19, Train Loss Decreased!! (0.116202-->0.113005)
# Test Loss: 0.110089
#
# Temp Loss: 0.146529
#
# Epoch: 20, Train Loss Decreased!! (0.113005-->0.110522)
# Test Loss: 0.116007
#
# Temp Loss: 0.150762
#
# Epoch: 21, Train Loss Decreased!! (0.110522-->0.104070)
# Test Loss: 0.098771
#
# Temp Loss: 0.135631
#
# Epoch: 22, Train Loss Decreased!! (0.104070-->0.100530)
# Test Loss: 0.107617
#
# Temp Loss: 0.142737
#
# Epoch: 23, Train Loss Decreased!! (0.100530-->0.094460)
# Test Loss: 0.089348
#
# Temp Loss: 0.125000
#
# Epoch: 24, Train Loss Decreased!! (0.094460-->0.094340)
# Test Loss: 0.102980
#
# Temp Loss: 0.135292
#
# Epoch: 25, Train Loss Decreased!! (0.094340-->0.087764)
# Test Loss: 0.083200
#
# Temp Loss: 0.123388
#
# Test Loss: 0.101960
#
# Temp Loss: 0.138145
#
# Epoch: 27, Train Loss Decreased!! (0.087764-->0.082921)
# Test Loss: 0.077666
#
# Temp Loss: 0.118461
#
# Epoch: 28, Train Loss Decreased!! (0.082921-->0.082257)
# Test Loss: 0.092655
#
# Temp Loss: 0.129214
#
# Epoch: 29, Train Loss Decreased!! (0.082257-->0.074776)
# Test Loss: 0.067907
#
# Temp Loss: 0.108463
#
# Epoch: 30, Train Loss Decreased!! (0.074776-->0.073539)
# Test Loss: 0.084007
#
# Temp Loss: 0.121241
#
# Epoch: 31, Train Loss Decreased!! (0.073539-->0.066722)
# Test Loss: 0.061271
#
# Temp Loss: 0.102005
#
# Epoch: 32, Train Loss Decreased!! (0.066722-->0.065283)
# Test Loss: 0.074436
#
# Temp Loss: 0.112466
#
# Epoch: 33, Train Loss Decreased!! (0.065283-->0.060508)
# Test Loss: 0.056656
#
# Temp Loss: 0.098064
#
# Test Loss: 0.069888
#
# Temp Loss: 0.108994
#
# Epoch: 35, Train Loss Decreased!! (0.060508-->0.056617)
# Test Loss: 0.053231
#
# Temp Loss: 0.095634
#
# Test Loss: 0.066225
#
# Temp Loss: 0.105915
#
# Epoch: 37, Train Loss Decreased!! (0.056617-->0.053105)
# Test Loss: 0.048846
#
# Temp Loss: 0.092488
#
# Test Loss: 0.062200
#
# Temp Loss: 0.103229
#
# Epoch: 39, Train Loss Decreased!! (0.053105-->0.047064)
# Test Loss: 0.041317
#
# Temp Loss: 0.087616
#
# Epoch: 40, Train Loss Decreased!! (0.047064-->0.047030)
# Test Loss: 0.056991
#
# Temp Loss: 0.099892
#
# Epoch: 41, Train Loss Decreased!! (0.047030-->0.041535)
# Test Loss: 0.036208
#
# Temp Loss: 0.084943
#
# Epoch: 42, Train Loss Decreased!! (0.041535-->0.041052)
# Test Loss: 0.050073
#
# Temp Loss: 0.094531
#
# Epoch: 43, Train Loss Decreased!! (0.041052-->0.036571)
# Test Loss: 0.031889
#
# Temp Loss: 0.083730
#
# Test Loss: 0.045625
#
# Temp Loss: 0.093024
#
# Epoch: 45, Train Loss Decreased!! (0.036571-->0.032320)
# Test Loss: 0.028187
#
# Temp Loss: 0.084050
#
# Test Loss: 0.044204
#
# Temp Loss: 0.094788
#
# Epoch: 47, Train Loss Decreased!! (0.032320-->0.029640)
# Test Loss: 0.026137
#
# Temp Loss: 0.085736
#
# Test Loss: 0.042695
#
# Temp Loss: 0.097218
#
# Epoch: 49, Train Loss Decreased!! (0.029640-->0.027682)
# Test Loss: 0.024230
#
# Temp Loss: 0.085385
#
# Test Loss: 0.039934
#
# Temp Loss: 0.094994
#
# Epoch: 51, Train Loss Decreased!! (0.027682-->0.025585)
# Test Loss: 0.022061
#
# Temp Loss: 0.083586
#
# Test Loss: 0.037906
#
# Temp Loss: 0.094221
#
# Epoch: 53, Train Loss Decreased!! (0.025585-->0.023328)
# Test Loss: 0.019434
#
# Temp Loss: 0.083310
#
# Test Loss: 0.036523
#
# Temp Loss: 0.094485
#
# Epoch: 55, Train Loss Decreased!! (0.023328-->0.020764)
# Test Loss: 0.017057
#
# Temp Loss: 0.081717
#
# Test Loss: 0.034880
#
# Temp Loss: 0.093033
#
# Epoch: 57, Train Loss Decreased!! (0.020764-->0.018596)
# Test Loss: 0.014433
#
# Temp Loss: 0.079149
#
# Test Loss: 0.032699
#
# Temp Loss: 0.091577
#
# Epoch: 59, Train Loss Decreased!! (0.018596-->0.016333)
# Test Loss: 0.012711
#
# Temp Loss: 0.079455
#
# Test Loss: 0.031475
#
# Temp Loss: 0.091667
#
# Epoch: 61, Train Loss Decreased!! (0.016333-->0.014663)
# Test Loss: 0.011129
#
# Temp Loss: 0.080471
#
# Test Loss: 0.030314
#
# Temp Loss: 0.092880
#
# Epoch: 63, Train Loss Decreased!! (0.014663-->0.013605)
# Test Loss: 0.010398
#
# Temp Loss: 0.081122
#
# Test Loss: 0.029452
#
# Temp Loss: 0.093489
#
# Epoch: 65, Train Loss Decreased!! (0.013605-->0.012878)
# Test Loss: 0.009513
#
# Temp Loss: 0.081461
#
# Test Loss: 0.028181
#
# Temp Loss: 0.093463
#
# Epoch: 67, Train Loss Decreased!! (0.012878-->0.011681)
# Test Loss: 0.008878
#
# Temp Loss: 0.082622
#
# Test Loss: 0.027095
#
# Temp Loss: 0.093646
#
# Epoch: 69, Train Loss Decreased!! (0.011681-->0.011465)
# Test Loss: 0.008503
#
# Temp Loss: 0.082908
#
# Test Loss: 0.025375
#
# Temp Loss: 0.093026
#
# Epoch: 71, Train Loss Decreased!! (0.011465-->0.010676)
# Test Loss: 0.008103
#
# Temp Loss: 0.083590
#
# Test Loss: 0.024828
#
# Temp Loss: 0.093377
#
# Epoch: 73, Train Loss Decreased!! (0.010676-->0.010329)
# Test Loss: 0.007631
#
# Temp Loss: 0.083646
#
# Test Loss: 0.024311
#
# Temp Loss: 0.093229
#
# Epoch: 75, Train Loss Decreased!! (0.010329-->0.009714)
# Test Loss: 0.007491
#
# Temp Loss: 0.083723
#
# Test Loss: 0.023449
#
# Temp Loss: 0.093086
#
# Epoch: 77, Train Loss Decreased!! (0.009714-->0.009293)
# Test Loss: 0.007093
#
# Temp Loss: 0.084181
#
# Test Loss: 0.022764
#
# Temp Loss: 0.093401
#
# Epoch: 79, Train Loss Decreased!! (0.009293-->0.008952)
# Test Loss: 0.006732
#
# Temp Loss: 0.084269
#
# Test Loss: 0.022138
#
# Temp Loss: 0.093519
#
# Epoch: 81, Train Loss Decreased!! (0.008952-->0.008679)
# Test Loss: 0.006411
#
# Temp Loss: 0.084004
#
# Test Loss: 0.021568
#
# Temp Loss: 0.093386
#
# Epoch: 83, Train Loss Decreased!! (0.008679-->0.008281)
# Test Loss: 0.006186
#
# Temp Loss: 0.084277
#
# Test Loss: 0.020551
#
# Temp Loss: 0.093154
#
# Epoch: 85, Train Loss Decreased!! (0.008281-->0.008074)
# Test Loss: 0.005956
#
# Temp Loss: 0.084754
#
# Test Loss: 0.020898
#
# Temp Loss: 0.093868
#
# Epoch: 87, Train Loss Decreased!! (0.008074-->0.007976)
# Test Loss: 0.005724
#
# Temp Loss: 0.084116
#
# Test Loss: 0.020126
#
# Temp Loss: 0.093114
#
# Epoch: 89, Train Loss Decreased!! (0.007976-->0.007557)
# Test Loss: 0.005746
#
# Temp Loss: 0.084721
#
# Test Loss: 0.020897
#
# Temp Loss: 0.094252
#
# Epoch: 91, Train Loss Decreased!! (0.007557-->0.007376)
# Test Loss: 0.005330
#
# Temp Loss: 0.084468
#
# Test Loss: 0.018978
#
# Temp Loss: 0.092718
#
# Epoch: 93, Train Loss Decreased!! (0.007376-->0.007206)
# Test Loss: 0.005298
#
# Temp Loss: 0.085045
#
# Test Loss: 0.018635
#
# Temp Loss: 0.093189
#
# Epoch: 95, Train Loss Decreased!! (0.007206-->0.006954)
# Test Loss: 0.005041
#
# Temp Loss: 0.084895
#
# Test Loss: 0.019146
#
# Temp Loss: 0.093587
#
# Epoch: 97, Train Loss Decreased!! (0.006954-->0.006781)
# Test Loss: 0.004976
#
# Temp Loss: 0.085375
#
# Test Loss: 0.018506
#
# Temp Loss: 0.093436
#
# Epoch: 99, Train Loss Decreased!! (0.006781-->0.006603)
# Test Loss: 0.004860
#
# Temp Loss: 0.084669
#  80%|████████  | 4/5 [07:36<01:53, 113.99s/it]
# Test Loss: 0.019050
#
# Temp Loss: 0.093458
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.293820)
# Test Loss: 0.252197
#
# Temp Loss: 0.252548
#
# Epoch: 2, Train Loss Decreased!! (0.293820-->0.251911)
# Test Loss: 0.251436
#
# Temp Loss: 0.251724
#
# Epoch: 3, Train Loss Decreased!! (0.251911-->0.244890)
# Test Loss: 0.231460
#
# Temp Loss: 0.231785
#
# Epoch: 4, Train Loss Decreased!! (0.244890-->0.231766)
# Test Loss: 0.232766
#
# Temp Loss: 0.233276
#
# Epoch: 5, Train Loss Decreased!! (0.231766-->0.220295)
# Test Loss: 0.211255
#
# Temp Loss: 0.211626
#
# Epoch: 6, Train Loss Decreased!! (0.220295-->0.211701)
# Test Loss: 0.214979
#
# Temp Loss: 0.215341
#
# Epoch: 7, Train Loss Decreased!! (0.211701-->0.205321)
# Test Loss: 0.197525
#
# Temp Loss: 0.198723
#
# Epoch: 8, Train Loss Decreased!! (0.205321-->0.199378)
# Test Loss: 0.204845
#
# Temp Loss: 0.205825
#
# Epoch: 9, Train Loss Decreased!! (0.199378-->0.188075)
# Test Loss: 0.179092
#
# Temp Loss: 0.185381
#
# Epoch: 10, Train Loss Decreased!! (0.188075-->0.179665)
# Test Loss: 0.185669
#
# Temp Loss: 0.191805
#
# Epoch: 11, Train Loss Decreased!! (0.179665-->0.169457)
# Test Loss: 0.157746
#
# Temp Loss: 0.181113
#
# Epoch: 12, Train Loss Decreased!! (0.169457-->0.158816)
# Test Loss: 0.163838
#
# Temp Loss: 0.186095
#
# Epoch: 13, Train Loss Decreased!! (0.158816-->0.148007)
# Test Loss: 0.142291
#
# Temp Loss: 0.173052
#
# Epoch: 14, Train Loss Decreased!! (0.148007-->0.145299)
# Test Loss: 0.154272
#
# Temp Loss: 0.182493
#
# Epoch: 15, Train Loss Decreased!! (0.145299-->0.139907)
# Test Loss: 0.135938
#
# Temp Loss: 0.167374
#
# Epoch: 16, Train Loss Decreased!! (0.139907-->0.136574)
# Test Loss: 0.143114
#
# Temp Loss: 0.172076
#
# Epoch: 17, Train Loss Decreased!! (0.136574-->0.129711)
# Test Loss: 0.126522
#
# Temp Loss: 0.159605
#
# Epoch: 18, Train Loss Decreased!! (0.129711-->0.127296)
# Test Loss: 0.135198
#
# Temp Loss: 0.165154
#
# Epoch: 19, Train Loss Decreased!! (0.127296-->0.122929)
# Test Loss: 0.122577
#
# Temp Loss: 0.156198
#
# Epoch: 20, Train Loss Decreased!! (0.122929-->0.121452)
# Test Loss: 0.128969
#
# Temp Loss: 0.160428
#
# Epoch: 21, Train Loss Decreased!! (0.121452-->0.116165)
# Test Loss: 0.111012
#
# Temp Loss: 0.147313
#
# Epoch: 22, Train Loss Decreased!! (0.116165-->0.109686)
# Test Loss: 0.116114
#
# Temp Loss: 0.150459
#
# Epoch: 23, Train Loss Decreased!! (0.109686-->0.099048)
# Test Loss: 0.090360
#
# Temp Loss: 0.125058
#
# Epoch: 24, Train Loss Decreased!! (0.099048-->0.090307)
# Test Loss: 0.096112
#
# Temp Loss: 0.129245
#
# Epoch: 25, Train Loss Decreased!! (0.090307-->0.084525)
# Test Loss: 0.080586
#
# Temp Loss: 0.115455
#
# Epoch: 26, Train Loss Decreased!! (0.084525-->0.081343)
# Test Loss: 0.087492
#
# Temp Loss: 0.119695
#
# Epoch: 27, Train Loss Decreased!! (0.081343-->0.077219)
# Test Loss: 0.074222
#
# Temp Loss: 0.112423
#
# Test Loss: 0.093543
#
# Temp Loss: 0.126572
#
# Epoch: 29, Train Loss Decreased!! (0.077219-->0.073770)
# Test Loss: 0.071204
#
# Temp Loss: 0.111843
#
# Test Loss: 0.086910
#
# Temp Loss: 0.122125
#
# Epoch: 31, Train Loss Decreased!! (0.073770-->0.071359)
# Test Loss: 0.069069
#
# Temp Loss: 0.110075
#
# Test Loss: 0.081312
#
# Temp Loss: 0.117578
#
# Epoch: 33, Train Loss Decreased!! (0.071359-->0.069045)
# Test Loss: 0.067540
#
# Temp Loss: 0.109379
#
# Test Loss: 0.076356
#
# Temp Loss: 0.113846
#
# Epoch: 35, Train Loss Decreased!! (0.069045-->0.067076)
# Test Loss: 0.066068
#
# Temp Loss: 0.106503
#
# Test Loss: 0.075660
#
# Temp Loss: 0.111534
#
# Epoch: 37, Train Loss Decreased!! (0.067076-->0.063168)
# Test Loss: 0.059158
#
# Temp Loss: 0.100088
#
# Test Loss: 0.074666
#
# Temp Loss: 0.110812
#
# Epoch: 39, Train Loss Decreased!! (0.063168-->0.057893)
# Test Loss: 0.054611
#
# Temp Loss: 0.095895
#
# Test Loss: 0.068131
#
# Temp Loss: 0.104988
#
# Epoch: 41, Train Loss Decreased!! (0.057893-->0.054776)
# Test Loss: 0.052335
#
# Temp Loss: 0.094455
#
# Test Loss: 0.063811
#
# Temp Loss: 0.102033
#
# Epoch: 43, Train Loss Decreased!! (0.054776-->0.052141)
# Test Loss: 0.049816
#
# Temp Loss: 0.093324
#
# Test Loss: 0.061229
#
# Temp Loss: 0.100755
#
# Epoch: 45, Train Loss Decreased!! (0.052141-->0.049572)
# Test Loss: 0.047453
#
# Temp Loss: 0.093337
#
# Test Loss: 0.057214
#
# Temp Loss: 0.099854
#
# Epoch: 47, Train Loss Decreased!! (0.049572-->0.047155)
# Test Loss: 0.045091
#
# Temp Loss: 0.092338
#
# Test Loss: 0.054459
#
# Temp Loss: 0.098373
#
# Epoch: 49, Train Loss Decreased!! (0.047155-->0.044188)
# Test Loss: 0.042438
#
# Temp Loss: 0.087474
#
# Test Loss: 0.052982
#
# Temp Loss: 0.094837
#
# Epoch: 51, Train Loss Decreased!! (0.044188-->0.041884)
# Test Loss: 0.039300
#
# Temp Loss: 0.083746
#
# Test Loss: 0.054894
#
# Temp Loss: 0.097333
#
# Epoch: 53, Train Loss Decreased!! (0.041884-->0.039402)
# Test Loss: 0.035941
#
# Temp Loss: 0.081944
#
# Test Loss: 0.052883
#
# Temp Loss: 0.097121
#
# Epoch: 55, Train Loss Decreased!! (0.039402-->0.036478)
# Test Loss: 0.033096
#
# Temp Loss: 0.081959
#
# Test Loss: 0.052454
#
# Temp Loss: 0.099922
#
# Epoch: 57, Train Loss Decreased!! (0.036478-->0.033738)
# Test Loss: 0.030112
#
# Temp Loss: 0.080965
#
# Test Loss: 0.049225
#
# Temp Loss: 0.097965
#
# Epoch: 59, Train Loss Decreased!! (0.033738-->0.030905)
# Test Loss: 0.026275
#
# Temp Loss: 0.079719
#
# Test Loss: 0.045780
#
# Temp Loss: 0.096741
#
# Epoch: 61, Train Loss Decreased!! (0.030905-->0.026208)
# Test Loss: 0.021570
#
# Temp Loss: 0.079144
#
# Test Loss: 0.040361
#
# Temp Loss: 0.095751
#
# Epoch: 63, Train Loss Decreased!! (0.026208-->0.021562)
# Test Loss: 0.017595
#
# Temp Loss: 0.079399
#
# Test Loss: 0.035214
#
# Temp Loss: 0.094010
#
# Epoch: 65, Train Loss Decreased!! (0.021562-->0.018456)
# Test Loss: 0.015079
#
# Temp Loss: 0.080156
#
# Test Loss: 0.033595
#
# Temp Loss: 0.093588
#
# Epoch: 67, Train Loss Decreased!! (0.018456-->0.017007)
# Test Loss: 0.013746
#
# Temp Loss: 0.080607
#
# Test Loss: 0.031922
#
# Temp Loss: 0.092639
#
# Epoch: 69, Train Loss Decreased!! (0.017007-->0.015698)
# Test Loss: 0.012634
#
# Temp Loss: 0.081073
#
# Test Loss: 0.031160
#
# Temp Loss: 0.092901
#
# Epoch: 71, Train Loss Decreased!! (0.015698-->0.014402)
# Test Loss: 0.011336
#
# Temp Loss: 0.081210
#
# Test Loss: 0.030449
#
# Temp Loss: 0.093515
#
# Epoch: 73, Train Loss Decreased!! (0.014402-->0.013058)
# Test Loss: 0.009816
#
# Temp Loss: 0.081867
#
# Test Loss: 0.029832
#
# Temp Loss: 0.094486
#
# Epoch: 75, Train Loss Decreased!! (0.013058-->0.011849)
# Test Loss: 0.008745
#
# Temp Loss: 0.082456
#
# Test Loss: 0.029790
#
# Temp Loss: 0.095789
#
# Epoch: 77, Train Loss Decreased!! (0.011849-->0.010957)
# Test Loss: 0.007649
#
# Temp Loss: 0.083636
#
# Test Loss: 0.028433
#
# Temp Loss: 0.096315
#
# Epoch: 79, Train Loss Decreased!! (0.010957-->0.010103)
# Test Loss: 0.007047
#
# Temp Loss: 0.083676
#
# Test Loss: 0.029159
#
# Temp Loss: 0.096501
#
# Epoch: 81, Train Loss Decreased!! (0.010103-->0.009772)
# Test Loss: 0.006473
#
# Temp Loss: 0.084478
#
# Test Loss: 0.027738
#
# Temp Loss: 0.096132
#
# Epoch: 83, Train Loss Decreased!! (0.009772-->0.009347)
# Test Loss: 0.006116
#
# Temp Loss: 0.084426
#
# Test Loss: 0.027949
#
# Temp Loss: 0.096607
#
# Epoch: 85, Train Loss Decreased!! (0.009347-->0.008947)
# Test Loss: 0.005842
#
# Temp Loss: 0.084733
#
# Test Loss: 0.026838
#
# Temp Loss: 0.095805
#
# Epoch: 87, Train Loss Decreased!! (0.008947-->0.008290)
# Test Loss: 0.005562
#
# Temp Loss: 0.085073
#
# Test Loss: 0.026246
#
# Temp Loss: 0.095804
#
# Epoch: 89, Train Loss Decreased!! (0.008290-->0.008066)
# Test Loss: 0.005261
#
# Temp Loss: 0.085284
#
# Test Loss: 0.025133
#
# Temp Loss: 0.095569
#
# Epoch: 91, Train Loss Decreased!! (0.008066-->0.007587)
# Test Loss: 0.005014
#
# Temp Loss: 0.084673
#
# Test Loss: 0.025616
#
# Temp Loss: 0.095556
#
# Epoch: 93, Train Loss Decreased!! (0.007587-->0.007548)
# Test Loss: 0.004878
#
# Temp Loss: 0.084723
#
# Test Loss: 0.024560
#
# Temp Loss: 0.094810
#
# Epoch: 95, Train Loss Decreased!! (0.007548-->0.007373)
# Test Loss: 0.004808
#
# Temp Loss: 0.085048
#
# Test Loss: 0.023532
#
# Temp Loss: 0.094563
#
# Epoch: 97, Train Loss Decreased!! (0.007373-->0.007149)
# Test Loss: 0.004672
#
# Temp Loss: 0.085293
#
# Test Loss: 0.023193
#
# Temp Loss: 0.094461
#
# Epoch: 99, Train Loss Decreased!! (0.007149-->0.006991)
# Test Loss: 0.004335
#
# Temp Loss: 0.085168
# 100%|██████████| 5/5 [09:30<00:00, 114.08s/it]
# Test Loss: 0.022344
#
# Temp Loss: 0.094086
#
# ----------------------------------------------------

# %%
train_losses_mat = np.zeros((nRuns,n_epochs+1))
test_losses_mat = np.zeros((nRuns,n_epochs+1))
temp_losses_mat = np.zeros((nRuns,n_epochs+1))

train_expected_losses_mat = np.zeros((nRuns,n_epochs+1))

test_expected_losses_mat = np.zeros((nRuns,n_epochs+1))
test_surprise_losses_mat = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    train_losses_mat[cntr] = train_losses[cntr]
    test_losses_mat[cntr] = test_losses[cntr]
    temp_losses_mat[cntr] = temp_losses[cntr]
    
    train_expected_losses_mat[cntr] = train_expected_rec_losses[cntr]
    
    test_expected_losses_mat[cntr] = test_expected_rec_losses[cntr]
    test_surprise_losses_mat[cntr] = test_surprise_rec_losses[cntr]

# %%
train_losses_mean = np.mean(train_losses_mat,axis=0)
test_losses_mean = np.mean(test_losses_mat,axis=0)
temp_losses_mean = np.mean(temp_losses_mat,axis=0)

train_expected_losses_mean = np.mean(train_expected_losses_mat,axis=0)

test_expected_losses_mean = np.mean(test_expected_losses_mat,axis=0)
test_surprise_losses_mean = np.mean(test_surprise_losses_mat,axis=0)

# %%
train_losses_std = np.std(train_losses_mat,axis=0)
test_losses_std = np.std(test_losses_mat,axis=0)
temp_losses_std = np.std(test_losses_mat,axis=0)

train_expected_losses_std = np.std(train_expected_losses_mat,axis=0)

test_expected_losses_std = np.std(test_expected_losses_mat,axis=0)
test_surprise_losses_std = np.std(test_surprise_losses_mat,axis=0)

# %%
train_expected_losses_mean[0] = train_losses_mean[0]

# %%
f = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.errorbar(np.arange(n_epochs+1),train_losses_mean,yerr=train_losses_std)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,2)
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.subplot(2,2,3)
plt.errorbar(np.arange(n_epochs+1),test_losses_mean,yerr=test_losses_std)
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,4)
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
# kk=4
# a = np.unique(allStatesTest[kk][:,0])
# b = np.unique(allStatesTrain[kk][:,0])
# len(np.intersect1d(a,b))

# %% [markdown]
# ### Representational Analyses

# %% [markdown]
# #### RNN Names

# %%
rnn_names = ['L4','L23','L56','H4','H23','H56']

# %% [markdown]
# #### Analyses train loader

# %%
analyses_train_loader = {}

# %%
for cntr in range(nRuns):
    analyses_train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=False)

# %% [markdown]
# #### Pass data and store activations

# %%
def pass_data_store_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        activations_hidden_L23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_L4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_L56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_hidden_H23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_H4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_H56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_out_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
        for e in tqdm(range(n_epochs+1)):

            cnt = 0

            ## Load model
            model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr])
            model[cntr].to(device)
            model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
            model[cntr].eval()

            ## Pass clean samples
            for data, f_target, lastEvent, surpriseBinary in loader[cntr]:

                if train_on_gpu:
                    data, f_targetC = data.float().cuda(), f_target.float().cuda()
                else: data, f_targetC = data.float(), f_target.float()

                target = f_target

                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                ## Collect activations  
                act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                for i in range(batch_size):
                    if i < len(data):
                        label = target.data[i]

                        activations_hidden_L23_np[cntr][e,cnt] = act_hidden_L23[i]
                        activations_hidden_L4_np[cntr][e,cnt] = act_hidden_L4[i]
                        activations_hidden_L56_np[cntr][e,cnt] = act_hidden_L56[i]

                        activations_hidden_H23_np[cntr][e,cnt] = act_hidden_H23[i]
                        activations_hidden_H4_np[cntr][e,cnt] = act_hidden_H4[i]
                        activations_hidden_H56_np[cntr][e,cnt] = act_hidden_H56[i]

                        activations_out_np[cntr][e,cnt] = output_pred[i]

                        cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# (L23_train,L4_train,L56_train,
#  H23_train,H4_train,H56_train,), out_train = pass_data_store_activations(analyses_train_loader, nTrain)

# %%
(L23_test,L4_test,L56_test,
 H23_test,H4_test,H56_test,), out_test = pass_data_store_activations(test_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:17<00:00,  5.71it/s]
# 100%|██████████| 101/101 [00:21<00:00,  4.68it/s]
# 100%|██████████| 101/101 [00:21<00:00,  4.63it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.58it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.11it/s]

# %%
(L23_temp,L4_temp,L56_temp,
 H23_temp,H4_temp,H56_temp,), out_temp = pass_data_store_activations(test_temp_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:16<00:00,  6.14it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.12it/s]
# 100%|██████████| 101/101 [00:16<00:00,  5.99it/s]
# 100%|██████████| 101/101 [00:16<00:00,  5.99it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.04it/s]

# %% [markdown]
# #### PCA for RNNs

# %%
def repsPCA(rnnActs):
    nEpochs, nSeqs, nRolls, nNeurons = rnnActs.shape
    pca_dict = {}
    nSamps = nSeqs*nRolls
    dimPCA = min(nNeurons,nSamps)
    repsR_transformed = np.zeros((nEpochs,nSamps,dimPCA))
    
    for ep in tqdm(range(nEpochs)):
        
        reps = rnnActs[ep]
        
        ## reshape
        repsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        for ii in range(nSeqs):
            for jj in range(nRolls):
                repsR[cnt] = reps[ii,jj]
                cnt += 1
        ## PCA
        rnnPCA = PCA()
        repsR_transformed[ep] = rnnPCA.fit_transform(repsR)
        pca_dict[str(ep)] = rnnPCA
        
    return repsR_transformed, pca_dict

# %%
# L23pca_train = {}
# L4pca_train = {}
# L56pca_train = {}

# H23pca_train = {}
# H4pca_train = {}
# H56pca_train = {}

L23pca_test = {}
L4pca_test = {}
L56pca_test = {}

H23pca_test = {}
H4pca_test = {}
H56pca_test = {}

L23pca_temp = {}
L4pca_temp = {}
L56pca_temp = {}

H23pca_temp = {}
H4pca_temp = {}
H56pca_temp = {}

# %%
# for cntr in range(nRuns):
#     L23pca_train[cntr], _ = repsPCA(L23_train[cntr])
#     L4pca_train[cntr], _ = repsPCA(L4_train[cntr])
#     L56pca_train[cntr], _ = repsPCA(L56_train[cntr])

#     H23pca_train[cntr], _ = repsPCA(H23_train[cntr])
#     H4pca_train[cntr], _ = repsPCA(H4_train[cntr])
#     H56pca_train[cntr], _ = repsPCA(H56_train[cntr])

# %%
for cntr in range(nRuns):
    L23pca_test[cntr], _ = repsPCA(L23_test[cntr])
    L4pca_test[cntr], _ = repsPCA(L4_test[cntr])
    L56pca_test[cntr], _ = repsPCA(L56_test[cntr])

    H23pca_test[cntr], _ = repsPCA(H23_test[cntr])
    H4pca_test[cntr], _ = repsPCA(H4_test[cntr])
    H56pca_test[cntr], _ = repsPCA(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 59.17it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.52it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.31it/s]
# 100%|██████████| 101/101 [00:01<00:00, 62.63it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.77it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.63it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.97it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.69it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.66it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.75it/s]
# 100%|██████████| 101/101 [00:00<00:00, 135.93it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.50it/s]
# 100%|██████████| 101/101 [00:01<00:00, 62.80it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.01it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.65it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.53it/s]
# 100%|██████████| 101/101 [00:00<00:00, 129.34it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.74it/s]
# 100%|██████████| 101/101 [00:01<00:00, 62.98it/s]
# 100%|██████████| 101/101 [00:00<00:00, 132.55it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.27it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.42it/s]
# 100%|██████████| 101/101 [00:00<00:00, 130.75it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.12it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 130.67it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.34it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.61it/s]
# 100%|██████████| 101/101 [00:00<00:00, 128.35it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.66it/s]

# %%
for cntr in range(nRuns):
    L23pca_temp[cntr], _ = repsPCA(L23_temp[cntr])
    L4pca_temp[cntr], _ = repsPCA(L4_temp[cntr])
    L56pca_temp[cntr], _ = repsPCA(L56_temp[cntr])

    H23pca_temp[cntr], _ = repsPCA(H23_temp[cntr])
    H4pca_temp[cntr], _ = repsPCA(H4_temp[cntr])
    H56pca_temp[cntr], _ = repsPCA(H56_temp[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 62.34it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.86it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.90it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.94it/s]
# 100%|██████████| 101/101 [00:00<00:00, 136.02it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.18it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.41it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.95it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.44it/s]
# 100%|██████████| 101/101 [00:01<00:00, 62.70it/s]
# 100%|██████████| 101/101 [00:00<00:00, 129.83it/s]
# 100%|██████████| 101/101 [00:01<00:00, 81.70it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.35it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.01it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.69it/s]
# 100%|██████████| 101/101 [00:01<00:00, 60.51it/s]
# 100%|██████████| 101/101 [00:00<00:00, 127.38it/s]
# 100%|██████████| 101/101 [00:01<00:00, 77.19it/s]
# 100%|██████████| 101/101 [00:01<00:00, 62.40it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.43it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.12it/s]
# 100%|██████████| 101/101 [00:01<00:00, 61.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 128.76it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.69it/s]
# 100%|██████████| 101/101 [00:01<00:00, 59.96it/s]
# 100%|██████████| 101/101 [00:00<00:00, 130.67it/s]
# 100%|██████████| 101/101 [00:01<00:00, 73.52it/s]
# 100%|██████████| 101/101 [00:01<00:00, 54.96it/s]
# 100%|██████████| 101/101 [00:00<00:00, 127.86it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.56it/s]

# %%
idxs0_train = np.array([6*x for x in range(nTrain)])
idxs1_train = idxs0_train + 1
idxs2_train = idxs0_train + 2
idxs3_train = idxs0_train + 3
idxs4_train = idxs0_train + 4
idxs5_train = idxs0_train + 5

# %%
idxs0_test = np.array([6*x for x in range(nTest)])
idxs1_test = idxs0_test + 1
idxs2_test = idxs0_test + 2
idxs3_test = idxs0_test + 3
idxs4_test = idxs0_test + 4
idxs5_test = idxs0_test + 5

# %%
# cnt = 2
# ep = -1
# ix = idxs5_train
# c = allStatesTrain[cnt][:,0]/numM
# s = 20*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_train[cnt][ep,ix,0],L4pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_train[cnt][ep,ix,0],L23pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_train[cnt][ep,ix,0],L56pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_train[cnt][ep,ix,0],H4pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_train[cnt][ep,ix,0],H23pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_train[cnt][ep,ix,0],H56pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H5/6')

# %%
# cnt = 4
# ep = -1
# ix = idxs4_test
# c = allStatesTest[cnt][:,0]/numM
# s = 20*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H5/6')

# %% [markdown]
# #### Subset indices, etc.

# %%
idxs00_train = np.hstack((idxs0_train.reshape(-1,1),idxs1_train.reshape(-1,1)))
idxs11_train = np.hstack((idxs2_train.reshape(-1,1),idxs3_train.reshape(-1,1)))
idxs22_train = np.hstack((idxs4_train.reshape(-1,1),idxs5_train.reshape(-1,1)))

# %%
idxs00_test = np.hstack((idxs0_test.reshape(-1,1),idxs1_test.reshape(-1,1))).ravel()
idxs11_test = np.hstack((idxs2_test.reshape(-1,1),idxs3_test.reshape(-1,1))).ravel()
idxs22_test = np.hstack((idxs4_test.reshape(-1,1),idxs5_test.reshape(-1,1))).ravel()

# %%
cleanPCs = {}
surpPCs = {}

contextPCs_sub = {}

# %%
for cntr in range(nRuns):
    cleanPCs[cntr] = (L4pca_test[cntr],L23pca_test[cntr],L56pca_test[cntr],
                      H4pca_test[cntr],H23pca_test[cntr],H56pca_test[cntr])
    surpPCs[cntr] = (L4pca_temp[cntr],L23pca_temp[cntr],L56pca_temp[cntr],
                     H4pca_temp[cntr],H23pca_temp[cntr],H56pca_temp[cntr])
    
    for rnnNo in range(len(rnn_names)):
        contextPCs_sub[cntr,rnnNo] = np.hstack((cleanPCs[cntr][rnnNo][:,idxs22_test,:],surpPCs[cntr][rnnNo][:,idxs22_test,:]))

# %%
context_sub_surp = np.array([0]*nRepeats*nTest + [1]*nRepeats*nTest)

# %%
context_sub_imgIDs = {}
for cntr in range(nRuns):
    context_sub_imgIDs[cntr] = np.hstack((np.repeat(labelsTest[cntr][:,2:3],nRepeats),
                                          np.repeat(labelsTestTemp[cntr][:,2:3],nRepeats)))

# %% [markdown]
# #### Supervised Decoding

# %%
sub_Eps = np.array([0,1,50])
ds_im = 100

# %%
def repsDecodeSupervisedContext(rnnActs,labels,decodeType='surprise',clf='logistic',sub=True,ds=ds_im):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'surprise':
        nClasses = 2
    elif decodeType == 'imageID':
        if sub:
            rnnActs = rnnActs[:,::ds,:]
            nEpochs, nSamps, nNeurons = rnnActs.shape
            labels = labels[::ds]
            nClasses = len(np.unique(labels))
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression(multi_class='ovr').fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)    
        
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
dims23 = np.array([1,2,4,8,16,32,64,80])
dims4 = np.array([1,2,4,8,16,32])
dims56 = np.array([1,2,4,8,16,32,64])

# %%
L23surpPC = {}
L4surpPC = {}
L56surpPC = {}

H23surpPC = {}
H4surpPC = {}
H56surpPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        
    for d in dims4:
        L4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
    
    for d in dims56:
        L56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  1.69it/s]

# %%
L23imgPC = {}
L4imgPC = {}
L56imgPC = {}

H23imgPC = {}
H4imgPC = {}
H56imgPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        
    for d in dims4:
        L4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][sub_Eps,:,:d],
                                                          context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][sub_Eps,:,:d],
                                                          context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
    
    for d in dims56:
        L56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
# Out:
# 100%|██████████| 5/5 [00:17<00:00,  3.45s/it]

# %% [markdown]
# #### Generate plots

# %%
preds_L23imgPC = {}
preds_L4imgPC = {}
preds_L56imgPC = {}

preds_H23imgPC = {}
preds_H4imgPC = {}
preds_H56imgPC = {}

preds_L23surpPC = {}
preds_L4surpPC = {}
preds_L56surpPC = {}

preds_H23surpPC = {}
preds_H4surpPC = {}
preds_H56surpPC = {}

# %%
accs_L23imgPC = {}
accs_L4imgPC = {}
accs_L56imgPC = {}

accs_H23imgPC = {}
accs_H4imgPC = {}
accs_H56imgPC = {}

accs_L23surpPC = {}
accs_L4surpPC = {}
accs_L56surpPC = {}

accs_H23surpPC = {}
accs_H4surpPC = {}
accs_H56surpPC = {}

# %%
for cntr in range(nRuns):
    for ep in range(len(sub_Eps)):
        
        for d in dims23:
            preds_L23imgPC[cntr,d,ep] = np.argmax(L23imgPC[cntr,d][ep],axis=-1)
            preds_H23imgPC[cntr,d,ep] = np.argmax(H23imgPC[cntr,d][ep],axis=-1)
            
            preds_L23surpPC[cntr,d,ep] = np.argmax(L23surpPC[cntr,d][ep],axis=-1)
            preds_H23surpPC[cntr,d,ep] = np.argmax(H23surpPC[cntr,d][ep],axis=-1)
            
            accs_L23imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L23imgPC[cntr,d,ep])
            accs_H23imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H23imgPC[cntr,d,ep])
            
            accs_L23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L23surpPC[cntr,d,ep])
            accs_H23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H23surpPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4imgPC[cntr,d,ep] = np.argmax(L4imgPC[cntr,d][ep],axis=-1)
            preds_H4imgPC[cntr,d,ep] = np.argmax(H4imgPC[cntr,d][ep],axis=-1)
            
            preds_L4surpPC[cntr,d,ep] = np.argmax(L4surpPC[cntr,d][ep],axis=-1)
            preds_H4surpPC[cntr,d,ep] = np.argmax(H4surpPC[cntr,d][ep],axis=-1)
            
            accs_L4imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L4imgPC[cntr,d,ep])
            accs_H4imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H4imgPC[cntr,d,ep])
            
            accs_L4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L4surpPC[cntr,d,ep])
            accs_H4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H4surpPC[cntr,d,ep])
                
        for d in dims56:        
            preds_L56imgPC[cntr,d,ep] = np.argmax(L56imgPC[cntr,d][ep],axis=-1)
            preds_H56imgPC[cntr,d,ep] = np.argmax(H56imgPC[cntr,d][ep],axis=-1)
            
            preds_L56surpPC[cntr,d,ep] = np.argmax(L56surpPC[cntr,d][ep],axis=-1)
            preds_H56surpPC[cntr,d,ep] = np.argmax(H56surpPC[cntr,d][ep],axis=-1)
            
            accs_L56imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L56imgPC[cntr,d,ep])
            accs_H56imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H56imgPC[cntr,d,ep])
            
            accs_L56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L56surpPC[cntr,d,ep])
            accs_H56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H56surpPC[cntr,d,ep])

# %%
tensor_accs_L23imgPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4imgPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56imgPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23imgPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4imgPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56imgPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_L23surpPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4surpPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56surpPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23surpPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4surpPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56surpPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

# %%
for ii in range(nRuns):
    for kk in range(len(sub_Eps)):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23imgPC[ii,jj,kk] = accs_L23imgPC[ii,d,kk]
            tensor_accs_H23imgPC[ii,jj,kk] = accs_H23imgPC[ii,d,kk]
            
            tensor_accs_L23surpPC[ii,jj,kk] = accs_L23surpPC[ii,d,kk]
            tensor_accs_H23surpPC[ii,jj,kk] = accs_H23surpPC[ii,d,kk]
            
        
        for jj,d in enumerate(dims4):
            tensor_accs_L4imgPC[ii,jj,kk] = accs_L4imgPC[ii,d,kk]
            tensor_accs_H4imgPC[ii,jj,kk] = accs_H4imgPC[ii,d,kk]
            
            tensor_accs_L4surpPC[ii,jj,kk] = accs_L4surpPC[ii,d,kk]
            tensor_accs_H4surpPC[ii,jj,kk] = accs_H4surpPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56imgPC[ii,jj,kk] = accs_L56imgPC[ii,d,kk]
            tensor_accs_H56imgPC[ii,jj,kk] = accs_H56imgPC[ii,d,kk]

            tensor_accs_L56surpPC[ii,jj,kk] = accs_L56surpPC[ii,d,kk]
            tensor_accs_H56surpPC[ii,jj,kk] = accs_H56surpPC[ii,d,kk]

# %%
mean_accs_L4imgPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23imgPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56imgPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4imgPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23imgPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56imgPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_L4surpPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23surpPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56surpPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4surpPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23surpPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56surpPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4imgPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23imgPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56imgPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4imgPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23imgPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56imgPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4surpPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23surpPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56surpPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4surpPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23surpPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56surpPC = np.zeros((len(dims56),len(sub_Eps)))

# %%
for ep in range(len(sub_Eps)):
    
    for dd, dims in enumerate(dims23):
        mean_accs_L23imgPC[dd,ep] = np.mean(tensor_accs_L23imgPC[:,dd,ep])
        mean_accs_H23imgPC[dd,ep] = np.mean(tensor_accs_H23imgPC[:,dd,ep])
        
        std_accs_L23imgPC[dd,ep] = np.var(tensor_accs_L23imgPC[:,dd,ep])
        std_accs_H23imgPC[dd,ep] = np.var(tensor_accs_H23imgPC[:,dd,ep])
        
        mean_accs_L23surpPC[dd,ep] = np.mean(tensor_accs_L23surpPC[:,dd,ep])
        mean_accs_H23surpPC[dd,ep] = np.mean(tensor_accs_H23surpPC[:,dd,ep])
        
        std_accs_L23surpPC[dd,ep] = np.var(tensor_accs_L23surpPC[:,dd,ep])
        std_accs_H23surpPC[dd,ep] = np.var(tensor_accs_H23surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims4):
        mean_accs_L4imgPC[dd,ep] = np.mean(tensor_accs_L4imgPC[:,dd,ep])
        mean_accs_H4imgPC[dd,ep] = np.mean(tensor_accs_H4imgPC[:,dd,ep])
        
        std_accs_L4imgPC[dd,ep] = np.var(tensor_accs_L4imgPC[:,dd,ep])
        std_accs_H4imgPC[dd,ep] = np.var(tensor_accs_H4imgPC[:,dd,ep])
        
        mean_accs_L4surpPC[dd,ep] = np.mean(tensor_accs_L4surpPC[:,dd,ep])
        mean_accs_H4surpPC[dd,ep] = np.mean(tensor_accs_H4surpPC[:,dd,ep])
        
        std_accs_L4surpPC[dd,ep] = np.var(tensor_accs_L4surpPC[:,dd,ep])
        std_accs_H4surpPC[dd,ep] = np.var(tensor_accs_H4surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims56):
        mean_accs_L56imgPC[dd,ep] = np.mean(tensor_accs_L56imgPC[:,dd,ep])        
        mean_accs_H56imgPC[dd,ep] = np.mean(tensor_accs_H56imgPC[:,dd,ep])
        
        std_accs_L56imgPC[dd,ep] = np.var(tensor_accs_L56imgPC[:,dd,ep])
        std_accs_H56imgPC[dd,ep] = np.var(tensor_accs_H56imgPC[:,dd,ep])
        
        mean_accs_L56surpPC[dd,ep] = np.mean(tensor_accs_L56surpPC[:,dd,ep])
        mean_accs_H56surpPC[dd,ep] = np.mean(tensor_accs_H56surpPC[:,dd,ep])
        
        std_accs_L56surpPC[dd,ep] = np.var(tensor_accs_L56surpPC[:,dd,ep])        
        std_accs_H56surpPC[dd,ep] = np.var(tensor_accs_H56surpPC[:,dd,ep])

# %%
ffsurp_dim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Surprise ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,0],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,0],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,0],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,0],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,0],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,0],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(132)
plt.title('Surprise ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,1],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,1],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,1],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,1],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,1],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,1],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(133)
plt.title('Surprise ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,-1],yerr=std_accs_L4surpPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,-1],yerr=std_accs_L23surpPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,-1],yerr=std_accs_L56surpPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,-1],yerr=std_accs_H4surpPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,-1],yerr=std_accs_H23surpPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,-1],yerr=std_accs_H56surpPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
ffdim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Image ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,0],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,0],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,0],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,0],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,0],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,0],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Image ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,1],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,1],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,1],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,1],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,1],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,1],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Image ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,-1],yerr=std_accs_L4imgPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,-1],yerr=std_accs_L23imgPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,-1],yerr=std_accs_L56imgPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,-1],yerr=std_accs_H4imgPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,-1],yerr=std_accs_H23imgPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,-1],yerr=std_accs_H56imgPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# #### Position

# %%
step_labels = np.array([x%nSteps for x in range(nTest*nSteps)])

# %%
def repsDecodeSupervisedPosition(rnnActs,labels,clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    nClasses = 6
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
L4posPC = {}
L23posPC = {}
L56posPC = {}
H4posPC = {}
H23posPC = {}
H56posPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][1][sub_Eps,:,:d],step_labels)
        H23posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][4][sub_Eps,:,:d],step_labels)
    
    for d in dims4:
        L4posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][0][sub_Eps,:,:d],step_labels)
        H4posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][3][sub_Eps,:,:d],step_labels)
        
    for d in dims56:
        ## Position
        L56posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][2][sub_Eps,:,:d],step_labels)      
        H56posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][5][sub_Eps,:,:d],step_labels)
# Out:
# 100%|██████████| 5/5 [00:24<00:00,  4.91s/it]

# %%
preds_L23posPC = {}
preds_L4posPC = {}
preds_L56posPC = {}

preds_H23posPC = {}
preds_H4posPC = {}
preds_H56posPC = {}

# %%
accs_L23posPC = {}
accs_L4posPC = {}
accs_L56posPC = {}

accs_H23posPC = {}
accs_H4posPC = {}
accs_H56posPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(len(sub_Eps)):
        
        for d in dims23:
            preds_L23posPC[cntr,d,ep] = np.argmax(L23posPC[cntr,d][ep],axis=-1)
            preds_H23posPC[cntr,d,ep] = np.argmax(H23posPC[cntr,d][ep],axis=-1)
            
            accs_L23posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L23posPC[cntr,d,ep])
            accs_H23posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H23posPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4posPC[cntr,d,ep] = np.argmax(L4posPC[cntr,d][ep],axis=-1)
            preds_H4posPC[cntr,d,ep] = np.argmax(H4posPC[cntr,d][ep],axis=-1)
            
            accs_L4posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L4posPC[cntr,d,ep])
            accs_H4posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H4posPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56posPC[cntr,d,ep] = np.argmax(L56posPC[cntr,d][ep],axis=-1)
            preds_H56posPC[cntr,d,ep] = np.argmax(H56posPC[cntr,d][ep],axis=-1)
            
            accs_L56posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L56posPC[cntr,d,ep])
            accs_H56posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H56posPC[cntr,d,ep])

# %%
tensor_accs_L23posPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4posPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56posPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23posPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4posPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56posPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

# %%
for ii in range(nRuns):
    
    for kk in range(len(sub_Eps)):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23posPC[ii,jj,kk] = accs_L23posPC[ii,d,kk]
            tensor_accs_H23posPC[ii,jj,kk] = accs_H23posPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4posPC[ii,jj,kk] = accs_L4posPC[ii,d,kk]
            tensor_accs_H4posPC[ii,jj,kk] = accs_H4posPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56posPC[ii,jj,kk] = accs_L56posPC[ii,d,kk]            
            tensor_accs_H56posPC[ii,jj,kk] = accs_H56posPC[ii,d,kk]

# %%
mean_accs_L4posPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23posPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56posPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4posPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23posPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56posPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4posPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23posPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56posPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4posPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23posPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56posPC = np.zeros((len(dims56),len(sub_Eps)))

# %%
for ep in range(len(sub_Eps)):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23posPC[dd,ep] = np.mean(tensor_accs_L23posPC[:,dd,ep])
        mean_accs_H23posPC[dd,ep] = np.mean(tensor_accs_H23posPC[:,dd,ep])
        
        std_accs_L23posPC[dd,ep] = np.var(tensor_accs_L23posPC[:,dd,ep])
        std_accs_H23posPC[dd,ep] = np.var(tensor_accs_H23posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4posPC[dd,ep] = np.mean(tensor_accs_L4posPC[:,dd,ep])
        mean_accs_H4posPC[dd,ep] = np.mean(tensor_accs_H4posPC[:,dd,ep])
        
        std_accs_L4posPC[dd,ep] = np.var(tensor_accs_L4posPC[:,dd,ep])
        std_accs_H4posPC[dd,ep] = np.var(tensor_accs_H4posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56posPC[dd,ep] = np.mean(tensor_accs_L56posPC[:,dd,ep])
        mean_accs_H56posPC[dd,ep] = np.mean(tensor_accs_H56posPC[:,dd,ep])
        
        std_accs_L56posPC[dd,ep] = np.var(tensor_accs_L56posPC[:,dd,ep])
        std_accs_H56posPC[dd,ep] = np.var(tensor_accs_H56posPC[:,dd,ep])

# %%
ffpos = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Position Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,0],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,0],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,0],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,0],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,0],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,0],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Position Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,1],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,1],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,1],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,1],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,1],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,1],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Position Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,-1],yerr=std_accs_L4posPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,-1],yerr=std_accs_L23posPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,-1],yerr=std_accs_L56posPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,-1],yerr=std_accs_H4posPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,-1],yerr=std_accs_H23posPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,-1],yerr=std_accs_H56posPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
np.save(pp+'preds_img_temp_L4-no-fb-binary',preds_L4imgPC)
np.save(pp+'preds_img_temp_L23-no-fb-binary',preds_L23imgPC)
np.save(pp+'preds_img_temp_L56-no-fb-binary',preds_L56imgPC)
np.save(pp+'preds_img_temp_H4-no-fb-binary',preds_H4imgPC)
np.save(pp+'preds_img_temp_H23-no-fb-binary',preds_H23imgPC)
np.save(pp+'preds_img_temp_H56-no-fb-binary',preds_H56imgPC)

np.save(pp+'accs_img_temp_L4-no-fb-binary',accs_L4imgPC)
np.save(pp+'accs_img_temp_L23-no-fb-binary',accs_L23imgPC)
np.save(pp+'accs_img_temp_L56-no-fb-binary',accs_L56imgPC)
np.save(pp+'accs_img_temp_H4-no-fb-binary',accs_H4imgPC)
np.save(pp+'accs_img_temp_H23-no-fb-binary',accs_H23imgPC)
np.save(pp+'accs_img_temp_H56-no-fb-binary',accs_H56imgPC)

# %%
np.save(pp+'preds_pos_temp_L4-no-fb-binary',preds_L4posPC)
np.save(pp+'preds_pos_temp_L23-no-fb-binary',preds_L23posPC)
np.save(pp+'preds_pos_temp_L56-no-fb-binary',preds_L56posPC)
np.save(pp+'preds_pos_temp_H4-no-fb-binary',preds_H4posPC)
np.save(pp+'preds_pos_temp_H23-no-fb-binary',preds_H23posPC)
np.save(pp+'preds_pos_temp_H56-no-fb-binary',preds_H56posPC)

np.save(pp+'accs_pos_temp_L4-no-fb-binary',accs_L4posPC)
np.save(pp+'accs_pos_temp_L23-no-fb-binary',accs_L23posPC)
np.save(pp+'accs_pos_temp_L56-no-fb-binary',accs_L56posPC)
np.save(pp+'accs_pos_temp_H4-no-fb-binary',accs_H4posPC)
np.save(pp+'accs_pos_temp_H23-no-fb-binary',accs_H23posPC)
np.save(pp+'accs_pos_temp_H56-no-fb-binary',accs_H56posPC)

# %%
np.save(pp+'preds_surp_temp_L4-no-fb',preds_L4surpPC)
np.save(pp+'preds_surp_temp_L23-no-fb',preds_L23surpPC)
np.save(pp+'preds_surp_temp_L56-no-fb',preds_L56surpPC)
np.save(pp+'preds_surp_temp_H4-no-fb',preds_H4surpPC)
np.save(pp+'preds_surp_temp_H23-no-fb',preds_H23surpPC)
np.save(pp+'preds_surp_temp_H56-no-fb',preds_H56surpPC)

np.save(pp+'accs_surp_temp_L4-no-fb',accs_L4surpPC)
np.save(pp+'accs_surp_temp_L23-no-fb',accs_L23surpPC)
np.save(pp+'accs_surp_temp_L56-no-fb',accs_L56surpPC)
np.save(pp+'accs_surp_temp_H4-no-fb',accs_H4surpPC)
np.save(pp+'accs_surp_temp_H23-no-fb',accs_H23surpPC)
np.save(pp+'accs_surp_temp_H56-no-fb',accs_H56surpPC)

# %% [markdown]
# #### Temporal accuracies

# %%
preds_test = {}
preds_temp = {}

accs_test = np.zeros((nRuns,n_epochs+1))
accs_temp = np.zeros((nRuns,n_epochs+1))

for cntr in range(nRuns):
    preds_test[cntr] = np.abs(np.round_(out_test[cntr]*(out_test[cntr]>0)))
    preds_temp[cntr] = np.abs(np.round_(out_test[cntr]*(out_temp[cntr]>0)))
    
    accs_test[cntr] = np.sum(np.sum(np.sum(((yRepsTest[cntr] - preds_test[cntr])==0)*1,-1),-1),-1)/np.prod(yRepsTest[cntr].shape)
    accs_temp[cntr] = np.sum(np.sum(np.sum(((yRepsTestTemp[cntr] - preds_temp[cntr])==0)*1,-1),-1),-1)/np.prod(yRepsTestTemp[cntr].shape)

# %%
ff_final_temp_noise = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_test,0),yerr=np.var(accs_test,0),fmt='-',label='Test - Clean')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_temp,0),yerr=np.var(accs_temp,0),fmt='-',label='Test - Surprise')
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend()
plt.title('Prediction accuracy in presence of temporal violation')
plt.show()

# %%
np.save(pp+'no-fb-no-violations-accs-binary',accs_test)
np.save(pp+'no-fb-temporal-violations-accs-binary',accs_temp)

# %%
ff_final_temp_noise.savefig('temporal-violation-final-acc-repeated-runs-no-fb-bianry.png',dpi=300,bbox_inches='tight')
ff_final_temp_noise.savefig('temporal-violation-final-acc-repeated-runs-no-fb-binary.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# #### Dimensionality (Linear)

# %%
def rnnLinDim(acts):
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    eig_mat = np.zeros((nEpochs,nNeurons))
        
    for ep in tqdm(range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        cov = actsScaled.T@actsScaled
        eig_mat[ep] = eigvals(cov)
        num = np.sum(eig_mat,1)**2
        den = np.sum(eig_mat**2,1) + 1e-17
        PR = num/den
    return PR

# %%
L23LinDim = np.zeros((nRuns,n_epochs+1))
L4LinDim = np.zeros((nRuns,n_epochs+1))
L56LinDim = np.zeros((nRuns,n_epochs+1))

H23LinDim = np.zeros((nRuns,n_epochs+1))
H4LinDim = np.zeros((nRuns,n_epochs+1))
H56LinDim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23LinDim[cntr] = rnnLinDim(L23_test[cntr])
    L4LinDim[cntr] = rnnLinDim(L4_test[cntr])
    L56LinDim[cntr] = rnnLinDim(L56_test[cntr])

    H23LinDim[cntr] = rnnLinDim(H23_test[cntr])
    H4LinDim[cntr] = rnnLinDim(H4_test[cntr])
    H56LinDim[cntr] = rnnLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 74.41it/s]
# 100%|██████████| 101/101 [00:00<00:00, 138.73it/s]
# 100%|██████████| 101/101 [00:01<00:00, 84.90it/s]
# 100%|██████████| 101/101 [00:02<00:00, 43.62it/s]
# 100%|██████████| 101/101 [00:01<00:00, 59.64it/s]
# 100%|██████████| 101/101 [00:01<00:00, 88.52it/s]
# 100%|██████████| 101/101 [00:01<00:00, 74.03it/s]
# 100%|██████████| 101/101 [00:00<00:00, 139.50it/s]
# 100%|██████████| 101/101 [00:01<00:00, 71.27it/s]
# 100%|██████████| 101/101 [00:01<00:00, 67.34it/s]
# 100%|██████████| 101/101 [00:00<00:00, 179.55it/s]
# 100%|██████████| 101/101 [00:00<00:00, 118.99it/s]
# 100%|██████████| 101/101 [00:00<00:00, 102.81it/s]
# 100%|██████████| 101/101 [00:00<00:00, 176.11it/s]
# 100%|██████████| 101/101 [00:00<00:00, 116.88it/s]
# 100%|██████████| 101/101 [00:01<00:00, 98.80it/s]
# 100%|██████████| 101/101 [00:00<00:00, 177.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 120.86it/s]
# 100%|██████████| 101/101 [00:00<00:00, 101.78it/s]
# 100%|██████████| 101/101 [00:00<00:00, 181.49it/s]
# 100%|██████████| 101/101 [00:00<00:00, 116.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 102.02it/s]
# 100%|██████████| 101/101 [00:00<00:00, 177.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 118.05it/s]
# 100%|██████████| 101/101 [00:01<00:00, 99.77it/s]
# 100%|██████████| 101/101 [00:00<00:00, 171.03it/s]
# 100%|██████████| 101/101 [00:00<00:00, 116.44it/s]
# 100%|██████████| 101/101 [00:01<00:00, 98.02it/s]
# 100%|██████████| 101/101 [00:00<00:00, 161.27it/s]
# 100%|██████████| 101/101 [00:00<00:00, 116.40it/s]

# %% [markdown]
# #### Dimensionality (non-linear)

# %%
def rnnNonLinDim(acts,nTypes=2,subsample=True,ds=100):
    
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    dims_mat = np.zeros((nEpochs,nTypes))
        
    for ep in (range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        
        if subsample:
            actsScaled = actsScaled[::ds]
        
        dims_mat[ep,0] = MiND_ML().fit(actsScaled).dimension_
#         print(dims_mat[ep,0])
        dims_mat[ep,1] = CorrInt().fit(actsScaled).dimension_
#         print(dims_mat[ep,1])
#         dims_mat[ep,2] = MLE().fit(actsScaled).dimension_
#         print(dims_mat[ep,2])
#         dims_mat[ep,3] = DANCo().fit(actsScaled).dimension_
        
    return np.mean(dims_mat,-1),dims_mat

# %%
L23NonLinDim = np.zeros((nRuns,n_epochs+1))
L4NonLinDim = np.zeros((nRuns,n_epochs+1))
L56NonLinDim = np.zeros((nRuns,n_epochs+1))

H23NonLinDim = np.zeros((nRuns,n_epochs+1))
H4NonLinDim = np.zeros((nRuns,n_epochs+1))
H56NonLinDim = np.zeros((nRuns,n_epochs+1))

# %%
L23_ND_mat = {}
L4_ND_mat = {}
L56_ND_mat = {}
H23_ND_mat = {}
H4_ND_mat = {}
H56_ND_mat = {}

# %%
for cntr in tqdm(range(nRuns)):
    L23NonLinDim[cntr], L23_ND_mat[cntr] = rnnNonLinDim(L23_test[cntr])
    L4NonLinDim[cntr], L4_ND_mat[cntr] = rnnNonLinDim(L4_test[cntr])
    L56NonLinDim[cntr], L56_ND_mat[cntr] = rnnNonLinDim(L56_test[cntr])

    H23NonLinDim[cntr], H23_ND_mat[cntr] = rnnNonLinDim(H23_test[cntr])
    H4NonLinDim[cntr], H4_ND_mat[cntr] = rnnNonLinDim(H4_test[cntr])
    H56NonLinDim[cntr], H56_ND_mat[cntr] = rnnNonLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 5/5 [02:17<00:00, 27.59s/it]

# %%
L23_NonLineDim_mean = np.mean(L23NonLinDim,0)
L4_NonLineDim_mean = np.mean(L4NonLinDim,0)
L56_NonLineDim_mean = np.mean(L56NonLinDim,0)

H23_NonLineDim_mean = np.mean(H23NonLinDim,0)
H4_NonLineDim_mean = np.mean(H4NonLinDim,0)
H56_NonLineDim_mean = np.mean(H56NonLinDim,0)

L23_NonLineDim_std = np.var(L23NonLinDim,0)
L4_NonLineDim_std = np.var(L4NonLinDim,0)
L56_NonLineDim_std = np.var(L56NonLinDim,0)

H23_NonLineDim_std = np.var(H23NonLinDim,0)
H4_NonLineDim_std = np.var(H4NonLinDim,0)
H56_NonLineDim_std = np.var(H56NonLinDim,0)

# %%
L23_dim = np.zeros((nRuns,n_epochs+1))
L4_dim = np.zeros((nRuns,n_epochs+1))
L56_dim = np.zeros((nRuns,n_epochs+1))

H23_dim = np.zeros((nRuns,n_epochs+1))
H4_dim = np.zeros((nRuns,n_epochs+1))
H56_dim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23_dim[cntr] = L23LinDim[cntr]/L23NonLinDim[cntr]
    L4_dim[cntr] = L4LinDim[cntr]/L4NonLinDim[cntr]
    L56_dim[cntr] = L56LinDim[cntr]/L56NonLinDim[cntr]
    H23_dim[cntr] = H23LinDim[cntr]/H23NonLinDim[cntr]
    H4_dim[cntr] = H4LinDim[cntr]/H4NonLinDim[cntr]
    H56_dim[cntr] = H56LinDim[cntr]/H56NonLinDim[cntr]

# %%
np.save(pp+'L23DG_no-fb_binary',L23_dim)
np.save(pp+'L4DG_no-fb_binary',L4_dim)
np.save(pp+'L56DG_no-fb_binary',L56_dim)
np.save(pp+'H23DG_no-fb_binary',H23_dim)
np.save(pp+'H4DG_no-fb_binary',H4_dim)
np.save(pp+'H56DG_no-fb_binary',H56_dim)

# %%
ffTotDim = plt.figure(figsize=(5,5))

plt.subplot(111)

plt.plot(np.arange(n_epochs+1),np.mean(L4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(L4_dim,0)-np.var(L4_dim,0),np.mean(L4_dim,0)+np.var(L4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(L23_dim,0)-np.var(L23_dim,0),np.mean(L23_dim,0)+np.var(L23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(L56_dim,0)-np.var(L56_dim,0),np.mean(L56_dim,0)+np.var(L56_dim,0),alpha=0.5)

plt.plot(np.arange(n_epochs+1),np.mean(H4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(H4_dim,0)-np.var(H4_dim,0),np.mean(H4_dim,0)+np.var(H4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(H23_dim,0)-np.var(H23_dim,0),np.mean(H23_dim,0)+np.var(H23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(H56_dim,0)-np.var(H56_dim,0),np.mean(H56_dim,0)+np.var(H56_dim,0),alpha=0.5)

plt.xlabel('Epochs')
plt.ylabel('Dimensionality Gain')
# plt.ylim(0.9,2.2)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('No-FB Microcircuit')
plt.show()

# %%
ffTotDim.savefig('Dimensionality-gain-no-fb-across-learning-binary.png',dpi=300,bbox_inches='tight')
ffTotDim.savefig('Dimensionality-gain-no-fb-across-learning-binary.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# #### Spatial violations

# %%
dim = 16

# %%
from numpy.random import normal

# %%
noise_stds = np.linspace(0,5,6)

# %%
noiseSeqs = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noiseSeqs[cntr,nn] = repsTest[cntr] + normal(0,noise,repsTest[cntr].shape)

# %%
noisy_loader_analyses = {}

for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noisy_loader_analyses[cntr,nn] = makeTensorLoaders((noiseSeqs[cntr,nn],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)

# %%
L23_noisy = {}
L4_noisy = {}
L56_noisy = {}

H23_noisy = {}
H4_noisy = {}
H56_noisy = {}

out_noisy = {}

# %%
def pass_data_store_noisy_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        for nn in range(len(noise_stds)):
            activations_hidden_L23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_L4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_L56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_hidden_H23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_H4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_H56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_out_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,dim))

            for e in tqdm(range(n_epochs+1)):

                cnt = 0

                ## Load model
                model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr])
                model[cntr].to(device)
                model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
                model[cntr].eval()

                ## Pass clean samples
                for data, f_target, lastEvent, surpriseBinary in loader[cntr,nn]:

                    if train_on_gpu:
                        data, f_targetC = data.float().cuda(), f_target.float().cuda()
                    else: data, f_targetC = data.float(), f_target.float()

                    target = f_target

                    output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                    ## Collect activations  
                    act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                    act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                    act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                    act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                    act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                    act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                    output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                    for i in range(batch_size):
                        if i < len(data):
                            label = target.data[i]

                            activations_hidden_L23_np[cntr,nn][e,cnt] = act_hidden_L23[i]
                            activations_hidden_L4_np[cntr,nn][e,cnt] = act_hidden_L4[i]
                            activations_hidden_L56_np[cntr,nn][e,cnt] = act_hidden_L56[i]

                            activations_hidden_H23_np[cntr,nn][e,cnt] = act_hidden_H23[i]
                            activations_hidden_H4_np[cntr,nn][e,cnt] = act_hidden_H4[i]
                            activations_hidden_H56_np[cntr,nn][e,cnt] = act_hidden_H56[i]

                            activations_out_np[cntr,nn][e,cnt] = output_pred[i]

                            cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
(L23_noisy,L4_noisy,L56_noisy,
 H23_noisy,H4_noisy,H56_noisy,), out_noisy = pass_data_store_noisy_activations(noisy_loader_analyses, nTest)
# Out:
# 100%|██████████| 101/101 [00:21<00:00,  4.63it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.01it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.01it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.04it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.02it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.04it/s]
# 100%|██████████| 101/101 [00:21<00:00,  4.72it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.05it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.00it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.03it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.02it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.00it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.00it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.00it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.02it/s]
# 100%|██████████| 101/101 [00:16<00:00,  5.96it/s]
# 100%|██████████| 101/101 [00:16<00:00,  5.97it/s]
# 100%|██████████| 101/101 [00:16<00:00,  6.02it/s]
# 100%|██████████| 101/101 [00:16<00:00,  5.97it/s]
# 100%|██████████| 101/101 [00:16<00:00,  5.97it/s]
# 100%|██████████| 101/101 [00:16<00:00,  5.97it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.26it/s]
# 100%|██████████| 101/101 [00:22<00:00,  4.59it/s]
# 100%|██████████| 101/101 [00:22<00:00,  4.52it/s]
# 100%|██████████| 101/101 [00:22<00:00,  4.55it/s]
# 100%|██████████| 101/101 [00:21<00:00,  4.65it/s]
# 100%|██████████| 101/101 [00:22<00:00,  4.49it/s]
# 100%|██████████| 101/101 [00:21<00:00,  4.72it/s]
# 100%|██████████| 101/101 [00:17<00:00,  5.92it/s]
# 100%|██████████| 101/101 [00:16<00:00,  5.94it/s]

# %%
predsN = {}
accsN = np.zeros((nRuns,len(noise_stds),n_epochs+1))

# %%
for cntr in range(nRuns):
    for nn in range(len(noise_stds)):
        predsN[cntr,nn] = np.abs(np.round_(out_noisy[cntr,nn]*(out_noisy[cntr,nn]>0)))
        accsN[cntr,nn] = np.sum(np.sum(np.sum(((yRepsTest[cntr] - predsN[cntr,nn])==0)*1,-1),-1),-1)/np.prod(yRepsTest[cntr].shape)

# %%
name = "Dark2_r"
cmap = get_cmap(name)  # type: matplotlib.colors.ListedColormap
colors = cmap.colors  # type: list

# %%
fpredspat = plt.figure()
for nn, noise in enumerate(noise_stds):
    plt.errorbar(np.arange(n_epochs+1),np.mean(accsN[:,nn],0),yerr=np.var(accsN[:,nn],0),fmt='-',label=np.round(noise,2),
                 c=colors[nn])
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
# plt.ylim(0,1)
plt.legend(title="Noise sigma",bbox_to_anchor=(1,0.5))
plt.title('Prediction accuracy with spatial noise - No Feedback Microcircuit')
plt.show()

# %%
np.save(pp+'no-fb-spatial-noisy-accs-binary',accsN)
