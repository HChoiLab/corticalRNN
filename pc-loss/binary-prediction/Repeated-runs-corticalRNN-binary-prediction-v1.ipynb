# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

from numpy.random import choice
from numpy.linalg import norm

from math import factorial

from itertools import permutations

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap

from tqdm import tqdm
import os

# %%
from numpy.linalg import svd, eigvals
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, homogeneity_completeness_v_measure, confusion_matrix, ConfusionMatrixDisplay, homogeneity_score

# %%
from skdim.id import *

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import get_cmap

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.style.use('seaborn-whitegrid')
# plt.style.use('default')

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

# %%
from generate_data import generate_binary_rep_data, makeTensorLoaders

# %% [markdown]
# #### Test for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('No GPU, training on CPU')
    device = torch.device('cpu')
else:
    print('GPU found, training on GPU')
    device = torch.device('cuda')
# Out:
# GPU found, training on GPU

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Number of runs

# %%
nRuns = 5

# %% [markdown]
# #### Generate data for runs

# %%
dim = 16
nTot = 5000

fracTrain = 0.8
fracTest = np.round(1-fracTrain,2)

nTrain = int(nTot*fracTrain)
nTest = nTot - nTrain

lenSeq = 4
nRepeats = 2

# %%
numM = 2**dim-1

# %%
repsTrain = {}
yRepsTrain = {}
eTrain = {}
pTrain = {}
surpTrain = {}
allStatesTrain = {}

# %%
repsTest = {}
yRepsTest = {}
eTest = {}
pTest = {}
surpTest = {}
allStatesTest = {}

# %%
repsTestTemp = {}
yRepsTestTemp = {}
eTestTemp = {}
pTestTemp = {}
surpTestTemp = {}
allStatesTestTemp = {}

# %%
labelsTrain = {}
labelsTest = {}
labelsTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]) = generate_binary_rep_data(nTot,fracTrain,dim,lenSeq)

# %%
for cntr in range(nRuns):
    labelsTrain[cntr] = np.repeat(allStatesTrain[cntr][:,:-1],2).reshape(nTrain,-1)
    labelsTest[cntr] = np.repeat(allStatesTest[cntr][:,1:],2).reshape(nTest,-1)
    labelsTestTemp[cntr] = np.repeat(allStatesTestTemp[cntr][:,1:],2).reshape(nTest,-1)

# %% [markdown]
# #### Create directories to save data and representations

# %%
pp = ## specify path

# %%
npp = {}
pp_npy = {}
pp_pts = {}

# %%
for cntr in range(nRuns):
    
    npp[cntr] = 'binary-regular-'+str(cntr)+'/'
    pp_npy[cntr] = pp+npp[cntr]+'npys-'+str(cntr)+'/'
    pp_pts[cntr] = pp+npp[cntr]+'pts-'+str(cntr)+'/'
    try:
        os.mkdir(os.path.join(pp,npp[cntr]))
        os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr]))
        os.mkdir(os.path.join(pp,npp[cntr],pp_pts[cntr]))

        os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr],'Dataset/'))
    except: continue

# %% [markdown]
# #### Save seeds and dataset

# %%
seeds = np.random.randint(1000, size=nRuns)
np.save(pp_npy[cntr]+'seeds',seeds)

# %%
for cntr in range(nRuns):

    ## Train Data
    np.save(pp_npy[cntr]+'Dataset/repsTrain',repsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTrain',yRepsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTrain',eTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTrain',surpTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTrain',allStatesTrain[cntr])

    ## Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTest',repsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTest',yRepsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTest',eTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTest',surpTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTest',allStatesTest[cntr])
    
    ## Temporally violated Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTestTemp',repsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTestTemp',yRepsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTestTemp',eTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTestTemp',surpTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTestTemp',allStatesTestTemp[cntr])

# %% [markdown]
# #### Load seeds

# %%
seeds = np.load(pp_npy[cntr]+'seeds.npy')

# %%
seeds
# Out:
# array([201, 140, 372, 880,  71])

# %% [markdown]
# #### Convert data into tensors, etc.

# %%
batch_size = 100 ##100

# %%
pos_seq_idx = np.array([0,0,1,1,2,2])

# %%
train_loader = {}
test_loader = {}
test_temp_loader = {}

# %%
for cntr in range(nRuns):
    train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=True)
    test_loader[cntr] = makeTensorLoaders((repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)
    test_temp_loader[cntr] = makeTensorLoaders((repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),
                                          batch_size,shuffle=False)

# %% [markdown]
# #### Load architectures, models, etc.

# %%
n_latent = 16 ## make sure it is the same in the architecture file as well
pop_list = [2,5,4] ## make sure it is the same in the architecture file as well

# %%
from architecture_original import microcircuit

# %%
model = {}
optimizer_rec = {}
optimizer_pc = {}

# %%
#specify loss function
reconLoss = nn.MSELoss()

#optimizer learning rate
eta_rec = 0.001
eta_pc = 0.0001

# %%
for cntr in range(nRuns):
    model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,pop_list=pop_list,bsize=batch_size,
                               manual_seed=seeds[cntr])
    model[cntr].to(device)
    optimizer_rec[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_rec)
    optimizer_pc[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_pc)

# %%
# for name, param in model[cntr].named_parameters():
#                         if ('FF' in name) or ('L23' in name) or ('L4' in name) or ('L56' in name):
#                             print(param.shape)
#                             print(name)
#                             print('---------------')

# %% [markdown]
# #### Train and collect activations

# %%
for data, f_target, lastEvent, surpriseBinary in train_loader[0]:
    if train_on_gpu:
        data, f_target = data.float().cuda(), f_target.float().cuda()
    else: data, f_target = data.float(), f_target.float()

# %%
data.size()
# Out:
# torch.Size([100, 6, 16])

# %%
output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[0](data)

# %%
nSteps = data.shape[1]

# %%
n_epochs = 100 ## number of epochs
div = n_epochs//n_epochs ## try ensuring that number used to divide by is a factor of n_epochs

# %%
feedback = True

# %%
def findMSE(output):
    errSq = output**2
    MSE_mat_samples_seq = errSq/np.prod(errSq.shape)
    MSE_samples = torch.mean(MSE_mat_samples_seq,1)
    return MSE_samples

# %%
train_losses = {}
test_losses = {}
temp_losses = {}

train_expected_rec_losses = {}
train_expected_fb_losses = {}

test_expected_rec_losses = {}
test_expected_fb_losses = {}

test_surprise_rec_losses = {}
test_surprise_fb_losses = {}

MSE_mat_full_test = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    train_losses[cntr] = np.zeros(n_epochs+1)
    test_losses[cntr] = np.zeros(n_epochs+1)
    temp_losses[cntr] = np.zeros(n_epochs+1)

    train_loss_min = np.Inf
    best_epoch = 0

    train_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    train_expected_fb_losses[cntr] = np.zeros(n_epochs+1)

    test_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_fb_losses[cntr] = np.zeros(n_epochs+1)
    
    test_surprise_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_surprise_fb_losses[cntr] = np.zeros(n_epochs+1)

    MSE_mat_full_test[cntr] = np.zeros(n_epochs+1)

    for epoch in (range(1,n_epochs+1)):

        train_loss = 0.0

        train_expected_rec_loss = 0.0
        train_expected_fb_loss = 0.0
        
        test_expected_rec_loss = 0.0
        test_expected_fb_loss = 0.0

        temp_rec_loss = 0.0
        temp_fb_loss = 0.0
        
        test_loss = 0.0
        temp_loss = 0.0

        cnt = 0
        
        ## Save model without training
        if epoch == 1:
            
            model[cntr].eval()
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_0.pt') ## Save model before any training
            
            ## Losses at 0th epoch
            for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
                if train_on_gpu:
                    data, f_target = data.float().cuda(), f_target.float().cuda()
                else:
                    data, f_target = data.float(), f_target.float()

                ##define all-sequence targets
                target = f_target

                optimizer_rec[cntr].zero_grad() #clears older gradients
                optimizer_pc[cntr].zero_grad() #clears older gradients
                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

                err_rec = torch.linalg.norm((output_pred-target),dim=2)
                err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
                MSE_samples_rec = findMSE(err_rec)
                MSE_samples_fb = findMSE(err_fb)

                loss = reconLoss(output_pred,target) #calculate the loss for the batch
                train_loss += loss.item()*data.size(0) #update training loss

                train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
                train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
                                    
            ## calculate average loss
            train_loss = train_loss/len(train_loader[cntr].dataset)
            
            ## Training loss at initialization
            train_losses[cntr][0] = train_loss
            train_expected_rec_losses[cntr][0] = train_expected_rec_loss
            train_expected_fb_losses[cntr][0] = train_expected_fb_loss
            
            ## Test losses at initialization
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test

                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)
                
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                # calculate the batch loss
                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
#             print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][0] = test_loss

            test_expected_rec_losses[cntr][0] = test_expected_rec_loss
            test_expected_fb_losses[cntr][0] = test_expected_fb_loss
        
        ## Test temp losses at initialization
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                    
                ##define all-sequence targets
                target_temp = f_target_temp

                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)
                loss_temp = reconLoss(output_pred_temp,target_temp)
                err_temp_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                # calculate the batch loss
                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_temp.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
#             print('Temp Loss: {:.6f}\n'.format(test_loss))

            temp_losses[cntr][0] = temp_loss

            test_surprise_rec_losses[cntr][0] = temp_rec_loss
            test_surprise_fb_losses[cntr][0] = temp_fb_loss

        #train model
        model[cntr].train()
        for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
            if train_on_gpu:
                data, f_target = data.float().cuda(), f_target.float().cuda()
            else:
                data, f_target = data.float(), f_target.float()

            ##define all-sequence targets
            target = f_target

            output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

            err_rec = torch.linalg.norm((output_pred-target),dim=2)
            err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
            MSE_samples_rec = findMSE(err_rec)
            MSE_samples_fb = findMSE(err_fb)
            
            loss = reconLoss(output_pred,target) #calculate the loss for the batch
            train_loss += loss.item()*data.size(0) #update training loss
            fbloss = torch.mean(MSE_samples_fb)

            optimizer_rec[cntr].zero_grad() #clears older gradients
            optimizer_pc[cntr].zero_grad() #clears older gradients
            ######## feedback error updates only higher-cortical area
            if (feedback)&(epoch%2==0):
                for name, param in model[cntr].named_parameters():
                    if ('FF' in name) or ('L23' in name) or ('L4' in name) or ('L56' in name):
                        param.require_grad = False
                fbloss.backward()
                optimizer_pc[cntr].step()
                for name, param in model[cntr].named_parameters():
                    param.require_grad = True
            else:
                loss.backward() #backprop
                optimizer_rec[cntr].step() #update parameters in direction of the -ve gradient  

            train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
            train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
        
        #calculate average loss
        train_loss = train_loss/len(train_loader[cntr].dataset)

        #training/validation stats
        train_losses[cntr][epoch] = train_loss
        train_expected_rec_losses[cntr][epoch] = train_expected_rec_loss
        train_expected_fb_losses[cntr][epoch] = train_expected_fb_loss

        #save model if the training loss decreased
        if train_loss <= train_loss_min:
            print('Epoch: {}, Train Loss Decreased!! ({:.6f}-->{:.6f})'.format(epoch,train_loss_min,train_loss))
            torch.save(model[cntr].state_dict(),pp_pts[cntr]+'predRNN.pt')
            train_loss_min = train_loss
            best_epoch = epoch

        if epoch%div == 0:
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_'+str(epoch)+'.pt')
            
            model[cntr].eval()
            
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test
                
                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)

                # calculate the batch loss
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
            print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][epoch] = test_loss

            test_expected_rec_losses[cntr][epoch] = test_expected_rec_loss
            test_expected_fb_losses[cntr][epoch] = test_expected_fb_loss
            
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                
                ##define all-sequence targets
                target_temp = f_target_temp
                
                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)

                # calculate the batch loss
                err_temp_rec = torch.linalg.norm((output_pred_temp-target_temp),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_temp[0],dim=2)+torch.linalg.norm(feedbackDiffs_temp[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_test.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
            print('Temp Loss: {:.6f}\n'.format(temp_loss))

            temp_losses[cntr][epoch] = temp_loss

            test_surprise_rec_losses[cntr][epoch] = temp_rec_loss
            test_surprise_fb_losses[cntr][epoch] = temp_fb_loss
            
    print('----------------------------------------------------')
            
    outF = open(pp+npp[cntr]+"training-details.txt", "w")
    outF.write('# epochs = ' + str(n_epochs))
    outF.write('\n')
    outF.write('Best epoch = '+str(best_epoch))
    outF.write('\n')
    outF.write('Minimum training loss = ' + str(train_loss_min))
    outF.write('\n')
    outF.write('Total number of samples = ' + str(nTot))
    outF.write('\n')
    outF.write('Number of training samples = ' + str(nTrain))
    outF.write('\n')
    outF.write('Number of testing samples = ' + str(nTest))
    outF.write('\n')
    outF.write('Dimensionality of representations = ' + str(dim))
    outF.write('\n')
    outF.write('Length of sequences = ' + str(lenSeq))
    outF.write('\n')
    outF.close()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1, Train Loss Decreased!! (inf-->0.278616)
# Test Loss: 0.252668
#
# Temp Loss: 0.252416
#
# Epoch: 2, Train Loss Decreased!! (0.278616-->0.251980)
# Test Loss: 0.251504
#
# Temp Loss: 0.251726
#
# Epoch: 3, Train Loss Decreased!! (0.251980-->0.246645)
# Test Loss: 0.234834
#
# Temp Loss: 0.234845
#
# Epoch: 4, Train Loss Decreased!! (0.246645-->0.235042)
# Test Loss: 0.236293
#
# Temp Loss: 0.236211
#
# Epoch: 5, Train Loss Decreased!! (0.235042-->0.226540)
# Test Loss: 0.215194
#
# Temp Loss: 0.217030
#
# Epoch: 6, Train Loss Decreased!! (0.226540-->0.216134)
# Test Loss: 0.218271
#
# Temp Loss: 0.219729
#
# Epoch: 7, Train Loss Decreased!! (0.216134-->0.198193)
# Test Loss: 0.181015
#
# Temp Loss: 0.196785
#
# Epoch: 8, Train Loss Decreased!! (0.198193-->0.181805)
# Test Loss: 0.183973
#
# Temp Loss: 0.198634
#
# Epoch: 9, Train Loss Decreased!! (0.181805-->0.172536)
# Test Loss: 0.163411
#
# Temp Loss: 0.191988
#
# Epoch: 10, Train Loss Decreased!! (0.172536-->0.165154)
# Test Loss: 0.168120
#
# Temp Loss: 0.195116
#
# Epoch: 11, Train Loss Decreased!! (0.165154-->0.157842)
# Test Loss: 0.153032
#
# Temp Loss: 0.184088
#
# Epoch: 12, Train Loss Decreased!! (0.157842-->0.153827)
# Test Loss: 0.156238
#
# Temp Loss: 0.185215
#
# Epoch: 13, Train Loss Decreased!! (0.153827-->0.146958)
# Test Loss: 0.139426
#
# Temp Loss: 0.173011
#
# Epoch: 14, Train Loss Decreased!! (0.146958-->0.140256)
# Test Loss: 0.144416
#
# Temp Loss: 0.175175
#
# Epoch: 15, Train Loss Decreased!! (0.140256-->0.132770)
# Test Loss: 0.124121
#
# Temp Loss: 0.156016
#
# Epoch: 16, Train Loss Decreased!! (0.132770-->0.128704)
# Test Loss: 0.136208
#
# Temp Loss: 0.164502
#
# Epoch: 17, Train Loss Decreased!! (0.128704-->0.116588)
# Test Loss: 0.108853
#
# Temp Loss: 0.140974
#
# Epoch: 18, Train Loss Decreased!! (0.116588-->0.110759)
# Test Loss: 0.116053
#
# Temp Loss: 0.146549
#
# Epoch: 19, Train Loss Decreased!! (0.110759-->0.104991)
# Test Loss: 0.098833
#
# Temp Loss: 0.134465
#
# Epoch: 20, Train Loss Decreased!! (0.104991-->0.100745)
# Test Loss: 0.104895
#
# Temp Loss: 0.137922
#
# Epoch: 21, Train Loss Decreased!! (0.100745-->0.095982)
# Test Loss: 0.092946
#
# Temp Loss: 0.126062
#
# Epoch: 22, Train Loss Decreased!! (0.095982-->0.093705)
# Test Loss: 0.097381
#
# Temp Loss: 0.128912
#
# Epoch: 23, Train Loss Decreased!! (0.093705-->0.090971)
# Test Loss: 0.088866
#
# Temp Loss: 0.123109
#
# Epoch: 24, Train Loss Decreased!! (0.090971-->0.089748)
# Test Loss: 0.093482
#
# Temp Loss: 0.126292
#
# Epoch: 25, Train Loss Decreased!! (0.089748-->0.084885)
# Test Loss: 0.078703
#
# Temp Loss: 0.115405
#
# Epoch: 26, Train Loss Decreased!! (0.084885-->0.080304)
# Test Loss: 0.084529
#
# Temp Loss: 0.119070
#
# Epoch: 27, Train Loss Decreased!! (0.080304-->0.071891)
# Test Loss: 0.065140
#
# Temp Loss: 0.103687
#
# Epoch: 28, Train Loss Decreased!! (0.071891-->0.066754)
# Test Loss: 0.072975
#
# Temp Loss: 0.109284
#
# Epoch: 29, Train Loss Decreased!! (0.066754-->0.061945)
# Test Loss: 0.058941
#
# Temp Loss: 0.100053
#
# Epoch: 30, Train Loss Decreased!! (0.061945-->0.060954)
# Test Loss: 0.067336
#
# Temp Loss: 0.105767
#
# Epoch: 31, Train Loss Decreased!! (0.060954-->0.058055)
# Test Loss: 0.056150
#
# Temp Loss: 0.097463
#
# Epoch: 32, Train Loss Decreased!! (0.058055-->0.057768)
# Test Loss: 0.063127
#
# Temp Loss: 0.101057
#
# Epoch: 33, Train Loss Decreased!! (0.057768-->0.055622)
# Test Loss: 0.054667
#
# Temp Loss: 0.095998
#
# Test Loss: 0.061286
#
# Temp Loss: 0.099910
#
# Epoch: 35, Train Loss Decreased!! (0.055622-->0.053789)
# Test Loss: 0.052706
#
# Temp Loss: 0.093103
#
# Test Loss: 0.059574
#
# Temp Loss: 0.097000
#
# Epoch: 37, Train Loss Decreased!! (0.053789-->0.051254)
# Test Loss: 0.050053
#
# Temp Loss: 0.091353
#
# Epoch: 38, Train Loss Decreased!! (0.051254-->0.051077)
# Test Loss: 0.057226
#
# Temp Loss: 0.094850
#
# Epoch: 39, Train Loss Decreased!! (0.051077-->0.048404)
# Test Loss: 0.047229
#
# Temp Loss: 0.088647
#
# Test Loss: 0.057171
#
# Temp Loss: 0.095013
#
# Epoch: 41, Train Loss Decreased!! (0.048404-->0.045737)
# Test Loss: 0.043951
#
# Temp Loss: 0.086600
#
# Test Loss: 0.064603
#
# Temp Loss: 0.103974
#
# Epoch: 43, Train Loss Decreased!! (0.045737-->0.044537)
# Test Loss: 0.040592
#
# Temp Loss: 0.084006
#
# Test Loss: 0.057743
#
# Temp Loss: 0.096514
#
# Epoch: 45, Train Loss Decreased!! (0.044537-->0.041411)
# Test Loss: 0.038584
#
# Temp Loss: 0.083650
#
# Test Loss: 0.060514
#
# Temp Loss: 0.101011
#
# Epoch: 47, Train Loss Decreased!! (0.041411-->0.040292)
# Test Loss: 0.037035
#
# Temp Loss: 0.081811
#
# Test Loss: 0.055310
#
# Temp Loss: 0.095322
#
# Epoch: 49, Train Loss Decreased!! (0.040292-->0.038556)
# Test Loss: 0.035344
#
# Temp Loss: 0.081160
#
# Test Loss: 0.055091
#
# Temp Loss: 0.096390
#
# Epoch: 51, Train Loss Decreased!! (0.038556-->0.036654)
# Test Loss: 0.033038
#
# Temp Loss: 0.079298
#
# Test Loss: 0.052001
#
# Temp Loss: 0.093907
#
# Epoch: 53, Train Loss Decreased!! (0.036654-->0.033495)
# Test Loss: 0.029160
#
# Temp Loss: 0.077908
#
# Test Loss: 0.049098
#
# Temp Loss: 0.093292
#
# Epoch: 55, Train Loss Decreased!! (0.033495-->0.029726)
# Test Loss: 0.025645
#
# Temp Loss: 0.078177
#
# Test Loss: 0.044144
#
# Temp Loss: 0.091697
#
# Epoch: 57, Train Loss Decreased!! (0.029726-->0.026228)
# Test Loss: 0.022622
#
# Temp Loss: 0.076974
#
# Test Loss: 0.042172
#
# Temp Loss: 0.090134
#
# Epoch: 59, Train Loss Decreased!! (0.026228-->0.023962)
# Test Loss: 0.020330
#
# Temp Loss: 0.075644
#
# Test Loss: 0.039721
#
# Temp Loss: 0.088135
#
# Epoch: 61, Train Loss Decreased!! (0.023962-->0.021638)
# Test Loss: 0.018238
#
# Temp Loss: 0.076212
#
# Test Loss: 0.041210
#
# Temp Loss: 0.091257
#
# Epoch: 63, Train Loss Decreased!! (0.021638-->0.020133)
# Test Loss: 0.016725
#
# Temp Loss: 0.076619
#
# Test Loss: 0.038806
#
# Temp Loss: 0.090042
#
# Epoch: 65, Train Loss Decreased!! (0.020133-->0.018984)
# Test Loss: 0.015691
#
# Temp Loss: 0.077345
#
# Test Loss: 0.036295
#
# Temp Loss: 0.089747
#
# Epoch: 67, Train Loss Decreased!! (0.018984-->0.017447)
# Test Loss: 0.014753
#
# Temp Loss: 0.078702
#
# Test Loss: 0.035542
#
# Temp Loss: 0.090644
#
# Epoch: 69, Train Loss Decreased!! (0.017447-->0.016784)
# Test Loss: 0.013788
#
# Temp Loss: 0.078600
#
# Test Loss: 0.033907
#
# Temp Loss: 0.090449
#
# Epoch: 71, Train Loss Decreased!! (0.016784-->0.015624)
# Test Loss: 0.013055
#
# Temp Loss: 0.079427
#
# Test Loss: 0.033118
#
# Temp Loss: 0.090845
#
# Epoch: 73, Train Loss Decreased!! (0.015624-->0.015275)
# Test Loss: 0.012528
#
# Temp Loss: 0.080040
#
# Test Loss: 0.032911
#
# Temp Loss: 0.091402
#
# Epoch: 75, Train Loss Decreased!! (0.015275-->0.014498)
# Test Loss: 0.011930
#
# Temp Loss: 0.079570
#
# Test Loss: 0.031770
#
# Temp Loss: 0.090481
#
# Epoch: 77, Train Loss Decreased!! (0.014498-->0.013753)
# Test Loss: 0.011277
#
# Temp Loss: 0.080879
#
# Test Loss: 0.030463
#
# Temp Loss: 0.091114
#
# Epoch: 79, Train Loss Decreased!! (0.013753-->0.013502)
# Test Loss: 0.011016
#
# Temp Loss: 0.079922
#
# Test Loss: 0.029608
#
# Temp Loss: 0.090122
#
# Epoch: 81, Train Loss Decreased!! (0.013502-->0.012911)
# Test Loss: 0.010466
#
# Temp Loss: 0.080429
#
# Test Loss: 0.029240
#
# Temp Loss: 0.090655
#
# Epoch: 83, Train Loss Decreased!! (0.012911-->0.012369)
# Test Loss: 0.010299
#
# Temp Loss: 0.079511
#
# Test Loss: 0.028944
#
# Temp Loss: 0.089589
#
# Epoch: 85, Train Loss Decreased!! (0.012369-->0.012191)
# Test Loss: 0.009921
#
# Temp Loss: 0.080089
#
# Test Loss: 0.028061
#
# Temp Loss: 0.089716
#
# Epoch: 87, Train Loss Decreased!! (0.012191-->0.011917)
# Test Loss: 0.009769
#
# Temp Loss: 0.080161
#
# Test Loss: 0.027967
#
# Temp Loss: 0.089918
#
# Epoch: 89, Train Loss Decreased!! (0.011917-->0.011698)
# Test Loss: 0.009575
#
# Temp Loss: 0.080102
#
# Test Loss: 0.028353
#
# Temp Loss: 0.090740
#
# Epoch: 91, Train Loss Decreased!! (0.011698-->0.011538)
# Test Loss: 0.009282
#
# Temp Loss: 0.080029
#
# Test Loss: 0.028373
#
# Temp Loss: 0.090895
#
# Epoch: 93, Train Loss Decreased!! (0.011538-->0.011433)
# Test Loss: 0.009152
#
# Temp Loss: 0.080606
#
# Test Loss: 0.027425
#
# Temp Loss: 0.091014
#
# Epoch: 95, Train Loss Decreased!! (0.011433-->0.011298)
# Test Loss: 0.008999
#
# Temp Loss: 0.080501
#
# Test Loss: 0.027027
#
# Temp Loss: 0.090413
#
# Epoch: 97, Train Loss Decreased!! (0.011298-->0.010674)
# Test Loss: 0.008706
#
# Temp Loss: 0.081063
#
# Test Loss: 0.027537
#
# Temp Loss: 0.091639
#
# Test Loss: 0.008695
#
# Temp Loss: 0.080828
#  20%|██        | 1/5 [02:14<08:58, 134.63s/it]
# Test Loss: 0.026466
#
# Temp Loss: 0.090983
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.284071)
# Test Loss: 0.252064
#
# Temp Loss: 0.251886
#
# Epoch: 2, Train Loss Decreased!! (0.284071-->0.251898)
# Test Loss: 0.251748
#
# Temp Loss: 0.251743
#
# Epoch: 3, Train Loss Decreased!! (0.251898-->0.244524)
# Test Loss: 0.230878
#
# Temp Loss: 0.231220
#
# Epoch: 4, Train Loss Decreased!! (0.244524-->0.232636)
# Test Loss: 0.234640
#
# Temp Loss: 0.235618
#
# Epoch: 5, Train Loss Decreased!! (0.232636-->0.220182)
# Test Loss: 0.210033
#
# Temp Loss: 0.213240
#
# Epoch: 6, Train Loss Decreased!! (0.220182-->0.209801)
# Test Loss: 0.212589
#
# Temp Loss: 0.215629
#
# Epoch: 7, Train Loss Decreased!! (0.209801-->0.196420)
# Test Loss: 0.185982
#
# Temp Loss: 0.210090
#
# Epoch: 8, Train Loss Decreased!! (0.196420-->0.186782)
# Test Loss: 0.190893
#
# Temp Loss: 0.212624
#
# Epoch: 9, Train Loss Decreased!! (0.186782-->0.178797)
# Test Loss: 0.171484
#
# Temp Loss: 0.201868
#
# Epoch: 10, Train Loss Decreased!! (0.178797-->0.173133)
# Test Loss: 0.177425
#
# Temp Loss: 0.205598
#
# Epoch: 11, Train Loss Decreased!! (0.173133-->0.167917)
# Test Loss: 0.161911
#
# Temp Loss: 0.193434
#
# Epoch: 12, Train Loss Decreased!! (0.167917-->0.163710)
# Test Loss: 0.168612
#
# Temp Loss: 0.196531
#
# Epoch: 13, Train Loss Decreased!! (0.163710-->0.154608)
# Test Loss: 0.146697
#
# Temp Loss: 0.178157
#
# Epoch: 14, Train Loss Decreased!! (0.154608-->0.148202)
# Test Loss: 0.154597
#
# Temp Loss: 0.184103
#
# Epoch: 15, Train Loss Decreased!! (0.148202-->0.136410)
# Test Loss: 0.125716
#
# Temp Loss: 0.158183
#
# Epoch: 16, Train Loss Decreased!! (0.136410-->0.133688)
# Test Loss: 0.142479
#
# Temp Loss: 0.172187
#
# Epoch: 17, Train Loss Decreased!! (0.133688-->0.124221)
# Test Loss: 0.117343
#
# Temp Loss: 0.150829
#
# Epoch: 18, Train Loss Decreased!! (0.124221-->0.121142)
# Test Loss: 0.128589
#
# Temp Loss: 0.158393
#
# Epoch: 19, Train Loss Decreased!! (0.121142-->0.113230)
# Test Loss: 0.108468
#
# Temp Loss: 0.143289
#
# Epoch: 20, Train Loss Decreased!! (0.113230-->0.111674)
# Test Loss: 0.121824
#
# Temp Loss: 0.153635
#
# Epoch: 21, Train Loss Decreased!! (0.111674-->0.107130)
# Test Loss: 0.103363
#
# Temp Loss: 0.139958
#
# Epoch: 22, Train Loss Decreased!! (0.107130-->0.104710)
# Test Loss: 0.111987
#
# Temp Loss: 0.145719
#
# Epoch: 23, Train Loss Decreased!! (0.104710-->0.100163)
# Test Loss: 0.095993
#
# Temp Loss: 0.135327
#
# Epoch: 24, Train Loss Decreased!! (0.100163-->0.099151)
# Test Loss: 0.107706
#
# Temp Loss: 0.143878
#
# Epoch: 25, Train Loss Decreased!! (0.099151-->0.093028)
# Test Loss: 0.088520
#
# Temp Loss: 0.128025
#
# Epoch: 26, Train Loss Decreased!! (0.093028-->0.089906)
# Test Loss: 0.097353
#
# Temp Loss: 0.134044
#
# Epoch: 27, Train Loss Decreased!! (0.089906-->0.084900)
# Test Loss: 0.081302
#
# Temp Loss: 0.119394
#
# Epoch: 28, Train Loss Decreased!! (0.084900-->0.082090)
# Test Loss: 0.088528
#
# Temp Loss: 0.124845
#
# Epoch: 29, Train Loss Decreased!! (0.082090-->0.076554)
# Test Loss: 0.073714
#
# Temp Loss: 0.115126
#
# Epoch: 30, Train Loss Decreased!! (0.076554-->0.076097)
# Test Loss: 0.085226
#
# Temp Loss: 0.123113
#
# Epoch: 31, Train Loss Decreased!! (0.076097-->0.071727)
# Test Loss: 0.069214
#
# Temp Loss: 0.110064
#
# Test Loss: 0.081638
#
# Temp Loss: 0.118103
#
# Epoch: 33, Train Loss Decreased!! (0.071727-->0.067685)
# Test Loss: 0.063939
#
# Temp Loss: 0.103587
#
# Test Loss: 0.078856
#
# Temp Loss: 0.114233
#
# Epoch: 35, Train Loss Decreased!! (0.067685-->0.062610)
# Test Loss: 0.059030
#
# Temp Loss: 0.097353
#
# Test Loss: 0.074001
#
# Temp Loss: 0.108608
#
# Epoch: 37, Train Loss Decreased!! (0.062610-->0.057915)
# Test Loss: 0.053676
#
# Temp Loss: 0.091876
#
# Epoch: 38, Train Loss Decreased!! (0.057915-->0.057241)
# Test Loss: 0.066093
#
# Temp Loss: 0.100747
#
# Epoch: 39, Train Loss Decreased!! (0.057241-->0.052759)
# Test Loss: 0.049151
#
# Temp Loss: 0.088265
#
# Epoch: 40, Train Loss Decreased!! (0.052759-->0.052730)
# Test Loss: 0.061600
#
# Temp Loss: 0.096955
#
# Epoch: 41, Train Loss Decreased!! (0.052730-->0.048636)
# Test Loss: 0.045283
#
# Temp Loss: 0.085869
#
# Test Loss: 0.057105
#
# Temp Loss: 0.094673
#
# Epoch: 43, Train Loss Decreased!! (0.048636-->0.045436)
# Test Loss: 0.043024
#
# Temp Loss: 0.084995
#
# Test Loss: 0.054312
#
# Temp Loss: 0.093403
#
# Epoch: 45, Train Loss Decreased!! (0.045436-->0.043443)
# Test Loss: 0.041369
#
# Temp Loss: 0.084358
#
# Test Loss: 0.049902
#
# Temp Loss: 0.090200
#
# Epoch: 47, Train Loss Decreased!! (0.043443-->0.040965)
# Test Loss: 0.039087
#
# Temp Loss: 0.082136
#
# Test Loss: 0.048890
#
# Temp Loss: 0.090242
#
# Epoch: 49, Train Loss Decreased!! (0.040965-->0.038521)
# Test Loss: 0.035706
#
# Temp Loss: 0.079929
#
# Test Loss: 0.046776
#
# Temp Loss: 0.089480
#
# Epoch: 51, Train Loss Decreased!! (0.038521-->0.034686)
# Test Loss: 0.031289
#
# Temp Loss: 0.079002
#
# Test Loss: 0.043719
#
# Temp Loss: 0.090648
#
# Epoch: 53, Train Loss Decreased!! (0.034686-->0.030422)
# Test Loss: 0.027240
#
# Temp Loss: 0.076814
#
# Test Loss: 0.041340
#
# Temp Loss: 0.089704
#
# Epoch: 55, Train Loss Decreased!! (0.030422-->0.027060)
# Test Loss: 0.024323
#
# Temp Loss: 0.075179
#
# Test Loss: 0.040756
#
# Temp Loss: 0.088731
#
# Epoch: 57, Train Loss Decreased!! (0.027060-->0.025223)
# Test Loss: 0.022178
#
# Temp Loss: 0.075271
#
# Test Loss: 0.040074
#
# Temp Loss: 0.088895
#
# Epoch: 59, Train Loss Decreased!! (0.025223-->0.023376)
# Test Loss: 0.020388
#
# Temp Loss: 0.074732
#
# Test Loss: 0.038850
#
# Temp Loss: 0.088183
#
# Epoch: 61, Train Loss Decreased!! (0.023376-->0.021799)
# Test Loss: 0.019284
#
# Temp Loss: 0.074602
#
# Test Loss: 0.039333
#
# Temp Loss: 0.087888
#
# Epoch: 63, Train Loss Decreased!! (0.021799-->0.021221)
# Test Loss: 0.018025
#
# Temp Loss: 0.074093
#
# Test Loss: 0.037989
#
# Temp Loss: 0.086724
#
# Epoch: 65, Train Loss Decreased!! (0.021221-->0.020056)
# Test Loss: 0.017164
#
# Temp Loss: 0.073561
#
# Test Loss: 0.036896
#
# Temp Loss: 0.085304
#
# Epoch: 67, Train Loss Decreased!! (0.020056-->0.018952)
# Test Loss: 0.016375
#
# Temp Loss: 0.074577
#
# Test Loss: 0.035500
#
# Temp Loss: 0.084161
#
# Epoch: 69, Train Loss Decreased!! (0.018952-->0.018105)
# Test Loss: 0.015503
#
# Temp Loss: 0.074921
#
# Test Loss: 0.035016
#
# Temp Loss: 0.084471
#
# Epoch: 71, Train Loss Decreased!! (0.018105-->0.017161)
# Test Loss: 0.014665
#
# Temp Loss: 0.075142
#
# Test Loss: 0.034970
#
# Temp Loss: 0.085008
#
# Epoch: 73, Train Loss Decreased!! (0.017161-->0.016646)
# Test Loss: 0.014047
#
# Temp Loss: 0.074939
#
# Test Loss: 0.034428
#
# Temp Loss: 0.084929
#
# Epoch: 75, Train Loss Decreased!! (0.016646-->0.016180)
# Test Loss: 0.013383
#
# Temp Loss: 0.075239
#
# Test Loss: 0.033080
#
# Temp Loss: 0.084319
#
# Epoch: 77, Train Loss Decreased!! (0.016180-->0.015506)
# Test Loss: 0.012931
#
# Temp Loss: 0.074857
#
# Test Loss: 0.032981
#
# Temp Loss: 0.084310
#
# Epoch: 79, Train Loss Decreased!! (0.015506-->0.015119)
# Test Loss: 0.012428
#
# Temp Loss: 0.075026
#
# Test Loss: 0.031249
#
# Temp Loss: 0.083731
#
# Epoch: 81, Train Loss Decreased!! (0.015119-->0.014586)
# Test Loss: 0.011935
#
# Temp Loss: 0.075488
#
# Test Loss: 0.032120
#
# Temp Loss: 0.084774
#
# Epoch: 83, Train Loss Decreased!! (0.014586-->0.014023)
# Test Loss: 0.011373
#
# Temp Loss: 0.075578
#
# Test Loss: 0.031179
#
# Temp Loss: 0.084620
#
# Epoch: 85, Train Loss Decreased!! (0.014023-->0.013660)
# Test Loss: 0.011284
#
# Temp Loss: 0.076521
#
# Test Loss: 0.029935
#
# Temp Loss: 0.084488
#
# Epoch: 87, Train Loss Decreased!! (0.013660-->0.013239)
# Test Loss: 0.010757
#
# Temp Loss: 0.076950
#
# Test Loss: 0.028799
#
# Temp Loss: 0.085161
#
# Epoch: 89, Train Loss Decreased!! (0.013239-->0.012691)
# Test Loss: 0.010298
#
# Temp Loss: 0.077054
#
# Test Loss: 0.029401
#
# Temp Loss: 0.085574
#
# Epoch: 91, Train Loss Decreased!! (0.012691-->0.012000)
# Test Loss: 0.009714
#
# Temp Loss: 0.078984
#
# Test Loss: 0.027126
#
# Temp Loss: 0.086299
#
# Epoch: 93, Train Loss Decreased!! (0.012000-->0.011168)
# Test Loss: 0.008992
#
# Temp Loss: 0.080407
#
# Test Loss: 0.026202
#
# Temp Loss: 0.087118
#
# Epoch: 95, Train Loss Decreased!! (0.011168-->0.010810)
# Test Loss: 0.008362
#
# Temp Loss: 0.081850
#
# Test Loss: 0.026242
#
# Temp Loss: 0.089404
#
# Epoch: 97, Train Loss Decreased!! (0.010810-->0.010165)
# Test Loss: 0.007840
#
# Temp Loss: 0.083703
#
# Test Loss: 0.024074
#
# Temp Loss: 0.089857
#
# Epoch: 99, Train Loss Decreased!! (0.010165-->0.009277)
# Test Loss: 0.007218
#
# Temp Loss: 0.084388
#  40%|████      | 2/5 [04:30<06:46, 135.41s/it]
# Test Loss: 0.023376
#
# Temp Loss: 0.090534
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.294470)
# Test Loss: 0.253026
#
# Temp Loss: 0.252969
#
# Epoch: 2, Train Loss Decreased!! (0.294470-->0.252394)
# Test Loss: 0.252645
#
# Temp Loss: 0.252563
#
# Epoch: 3, Train Loss Decreased!! (0.252394-->0.248349)
# Test Loss: 0.238188
#
# Temp Loss: 0.238183
#
# Epoch: 4, Train Loss Decreased!! (0.248349-->0.237767)
# Test Loss: 0.238462
#
# Temp Loss: 0.238280
#
# Epoch: 5, Train Loss Decreased!! (0.237767-->0.224042)
# Test Loss: 0.213274
#
# Temp Loss: 0.214354
#
# Epoch: 6, Train Loss Decreased!! (0.224042-->0.213920)
# Test Loss: 0.216267
#
# Temp Loss: 0.216970
#
# Epoch: 7, Train Loss Decreased!! (0.213920-->0.206781)
# Test Loss: 0.196881
#
# Temp Loss: 0.203800
#
# Epoch: 8, Train Loss Decreased!! (0.206781-->0.197637)
# Test Loss: 0.201340
#
# Temp Loss: 0.208118
#
# Epoch: 9, Train Loss Decreased!! (0.197637-->0.184226)
# Test Loss: 0.172429
#
# Temp Loss: 0.197434
#
# Epoch: 10, Train Loss Decreased!! (0.184226-->0.173322)
# Test Loss: 0.176896
#
# Temp Loss: 0.200848
#
# Epoch: 11, Train Loss Decreased!! (0.173322-->0.166298)
# Test Loss: 0.158732
#
# Temp Loss: 0.188632
#
# Epoch: 12, Train Loss Decreased!! (0.166298-->0.159134)
# Test Loss: 0.164701
#
# Temp Loss: 0.193855
#
# Epoch: 13, Train Loss Decreased!! (0.159134-->0.152250)
# Test Loss: 0.145508
#
# Temp Loss: 0.175222
#
# Epoch: 14, Train Loss Decreased!! (0.152250-->0.147785)
# Test Loss: 0.156640
#
# Temp Loss: 0.185047
#
# Epoch: 15, Train Loss Decreased!! (0.147785-->0.141192)
# Test Loss: 0.138363
#
# Temp Loss: 0.169134
#
# Epoch: 16, Train Loss Decreased!! (0.141192-->0.139687)
# Test Loss: 0.148934
#
# Temp Loss: 0.178690
#
# Epoch: 17, Train Loss Decreased!! (0.139687-->0.134268)
# Test Loss: 0.127093
#
# Temp Loss: 0.157853
#
# Epoch: 18, Train Loss Decreased!! (0.134268-->0.129036)
# Test Loss: 0.136413
#
# Temp Loss: 0.165551
#
# Epoch: 19, Train Loss Decreased!! (0.129036-->0.123609)
# Test Loss: 0.120446
#
# Temp Loss: 0.152413
#
# Epoch: 20, Train Loss Decreased!! (0.123609-->0.121610)
# Test Loss: 0.128446
#
# Temp Loss: 0.158986
#
# Epoch: 21, Train Loss Decreased!! (0.121610-->0.115035)
# Test Loss: 0.107902
#
# Temp Loss: 0.139995
#
# Epoch: 22, Train Loss Decreased!! (0.115035-->0.110689)
# Test Loss: 0.118764
#
# Temp Loss: 0.148711
#
# Epoch: 23, Train Loss Decreased!! (0.110689-->0.102176)
# Test Loss: 0.096529
#
# Temp Loss: 0.129886
#
# Epoch: 24, Train Loss Decreased!! (0.102176-->0.099564)
# Test Loss: 0.109642
#
# Temp Loss: 0.140730
#
# Epoch: 25, Train Loss Decreased!! (0.099564-->0.090626)
# Test Loss: 0.082567
#
# Temp Loss: 0.116240
#
# Epoch: 26, Train Loss Decreased!! (0.090626-->0.086490)
# Test Loss: 0.094675
#
# Temp Loss: 0.126558
#
# Epoch: 27, Train Loss Decreased!! (0.086490-->0.081706)
# Test Loss: 0.077821
#
# Temp Loss: 0.111688
#
# Epoch: 28, Train Loss Decreased!! (0.081706-->0.080577)
# Test Loss: 0.086035
#
# Temp Loss: 0.118951
#
# Epoch: 29, Train Loss Decreased!! (0.080577-->0.077333)
# Test Loss: 0.073403
#
# Temp Loss: 0.108766
#
# Epoch: 30, Train Loss Decreased!! (0.077333-->0.075500)
# Test Loss: 0.079794
#
# Temp Loss: 0.113835
#
# Epoch: 31, Train Loss Decreased!! (0.075500-->0.072101)
# Test Loss: 0.068501
#
# Temp Loss: 0.104790
#
# Epoch: 32, Train Loss Decreased!! (0.072101-->0.070108)
# Test Loss: 0.073658
#
# Temp Loss: 0.109576
#
# Epoch: 33, Train Loss Decreased!! (0.070108-->0.067131)
# Test Loss: 0.063942
#
# Temp Loss: 0.100356
#
# Epoch: 34, Train Loss Decreased!! (0.067131-->0.065924)
# Test Loss: 0.070406
#
# Temp Loss: 0.106018
#
# Epoch: 35, Train Loss Decreased!! (0.065924-->0.062987)
# Test Loss: 0.060618
#
# Temp Loss: 0.097532
#
# Epoch: 36, Train Loss Decreased!! (0.062987-->0.062770)
# Test Loss: 0.068044
#
# Temp Loss: 0.103727
#
# Epoch: 37, Train Loss Decreased!! (0.062770-->0.060547)
# Test Loss: 0.057933
#
# Temp Loss: 0.096204
#
# Epoch: 38, Train Loss Decreased!! (0.060547-->0.060508)
# Test Loss: 0.066159
#
# Temp Loss: 0.102737
#
# Epoch: 39, Train Loss Decreased!! (0.060508-->0.057819)
# Test Loss: 0.055088
#
# Temp Loss: 0.093905
#
# Epoch: 40, Train Loss Decreased!! (0.057819-->0.057443)
# Test Loss: 0.063255
#
# Temp Loss: 0.100594
#
# Epoch: 41, Train Loss Decreased!! (0.057443-->0.053789)
# Test Loss: 0.049994
#
# Temp Loss: 0.089882
#
# Epoch: 42, Train Loss Decreased!! (0.053789-->0.052811)
# Test Loss: 0.058467
#
# Temp Loss: 0.096602
#
# Epoch: 43, Train Loss Decreased!! (0.052811-->0.048732)
# Test Loss: 0.045336
#
# Temp Loss: 0.086733
#
# Epoch: 44, Train Loss Decreased!! (0.048732-->0.048191)
# Test Loss: 0.053396
#
# Temp Loss: 0.092425
#
# Epoch: 45, Train Loss Decreased!! (0.048191-->0.044497)
# Test Loss: 0.042080
#
# Temp Loss: 0.085209
#
# Test Loss: 0.050995
#
# Temp Loss: 0.091051
#
# Epoch: 47, Train Loss Decreased!! (0.044497-->0.040893)
# Test Loss: 0.037981
#
# Temp Loss: 0.084223
#
# Test Loss: 0.047727
#
# Temp Loss: 0.090162
#
# Epoch: 49, Train Loss Decreased!! (0.040893-->0.036949)
# Test Loss: 0.033377
#
# Temp Loss: 0.081596
#
# Epoch: 50, Train Loss Decreased!! (0.036949-->0.035600)
# Test Loss: 0.042264
#
# Temp Loss: 0.085879
#
# Epoch: 51, Train Loss Decreased!! (0.035600-->0.032094)
# Test Loss: 0.029209
#
# Temp Loss: 0.079971
#
# Test Loss: 0.041218
#
# Temp Loss: 0.086356
#
# Epoch: 53, Train Loss Decreased!! (0.032094-->0.028439)
# Test Loss: 0.025413
#
# Temp Loss: 0.079368
#
# Test Loss: 0.038755
#
# Temp Loss: 0.085488
#
# Epoch: 55, Train Loss Decreased!! (0.028439-->0.025559)
# Test Loss: 0.022891
#
# Temp Loss: 0.079827
#
# Test Loss: 0.040449
#
# Temp Loss: 0.088546
#
# Epoch: 57, Train Loss Decreased!! (0.025559-->0.023929)
# Test Loss: 0.020750
#
# Temp Loss: 0.079556
#
# Test Loss: 0.038177
#
# Temp Loss: 0.087325
#
# Epoch: 59, Train Loss Decreased!! (0.023929-->0.021917)
# Test Loss: 0.018838
#
# Temp Loss: 0.080015
#
# Test Loss: 0.036253
#
# Temp Loss: 0.088164
#
# Epoch: 61, Train Loss Decreased!! (0.021917-->0.019747)
# Test Loss: 0.016484
#
# Temp Loss: 0.079945
#
# Test Loss: 0.034624
#
# Temp Loss: 0.089118
#
# Epoch: 63, Train Loss Decreased!! (0.019747-->0.017852)
# Test Loss: 0.014950
#
# Temp Loss: 0.081045
#
# Test Loss: 0.030354
#
# Temp Loss: 0.088005
#
# Epoch: 65, Train Loss Decreased!! (0.017852-->0.016234)
# Test Loss: 0.013400
#
# Temp Loss: 0.080960
#
# Test Loss: 0.029517
#
# Temp Loss: 0.088646
#
# Epoch: 67, Train Loss Decreased!! (0.016234-->0.015235)
# Test Loss: 0.012617
#
# Temp Loss: 0.081740
#
# Test Loss: 0.026899
#
# Temp Loss: 0.088270
#
# Epoch: 69, Train Loss Decreased!! (0.015235-->0.014479)
# Test Loss: 0.011939
#
# Temp Loss: 0.081687
#
# Test Loss: 0.025721
#
# Temp Loss: 0.087838
#
# Epoch: 71, Train Loss Decreased!! (0.014479-->0.013713)
# Test Loss: 0.011562
#
# Temp Loss: 0.082159
#
# Test Loss: 0.026146
#
# Temp Loss: 0.089184
#
# Epoch: 73, Train Loss Decreased!! (0.013713-->0.013311)
# Test Loss: 0.010885
#
# Temp Loss: 0.081286
#
# Test Loss: 0.023802
#
# Temp Loss: 0.087609
#
# Epoch: 75, Train Loss Decreased!! (0.013311-->0.012663)
# Test Loss: 0.010639
#
# Temp Loss: 0.081247
#
# Test Loss: 0.023273
#
# Temp Loss: 0.087259
#
# Epoch: 77, Train Loss Decreased!! (0.012663-->0.012237)
# Test Loss: 0.010069
#
# Temp Loss: 0.081243
#
# Test Loss: 0.022587
#
# Temp Loss: 0.087211
#
# Epoch: 79, Train Loss Decreased!! (0.012237-->0.011842)
# Test Loss: 0.009751
#
# Temp Loss: 0.082050
#
# Test Loss: 0.022138
#
# Temp Loss: 0.087823
#
# Epoch: 81, Train Loss Decreased!! (0.011842-->0.011285)
# Test Loss: 0.009415
#
# Temp Loss: 0.081728
#
# Test Loss: 0.021325
#
# Temp Loss: 0.087552
#
# Epoch: 83, Train Loss Decreased!! (0.011285-->0.011123)
# Test Loss: 0.009031
#
# Temp Loss: 0.081181
#
# Test Loss: 0.020696
#
# Temp Loss: 0.086541
#
# Epoch: 85, Train Loss Decreased!! (0.011123-->0.010532)
# Test Loss: 0.008725
#
# Temp Loss: 0.081504
#
# Test Loss: 0.020365
#
# Temp Loss: 0.087140
#
# Epoch: 87, Train Loss Decreased!! (0.010532-->0.010345)
# Test Loss: 0.008467
#
# Temp Loss: 0.081712
#
# Test Loss: 0.020155
#
# Temp Loss: 0.087244
#
# Epoch: 89, Train Loss Decreased!! (0.010345-->0.010093)
# Test Loss: 0.008345
#
# Temp Loss: 0.081064
#
# Test Loss: 0.020384
#
# Temp Loss: 0.086531
#
# Epoch: 91, Train Loss Decreased!! (0.010093-->0.010055)
# Test Loss: 0.008129
#
# Temp Loss: 0.081298
#
# Test Loss: 0.019646
#
# Temp Loss: 0.086777
#
# Epoch: 93, Train Loss Decreased!! (0.010055-->0.009978)
# Test Loss: 0.007976
#
# Temp Loss: 0.080905
#
# Test Loss: 0.018343
#
# Temp Loss: 0.085806
#
# Epoch: 95, Train Loss Decreased!! (0.009978-->0.009517)
# Test Loss: 0.007846
#
# Temp Loss: 0.080987
#
# Test Loss: 0.018913
#
# Temp Loss: 0.086169
#
# Epoch: 97, Train Loss Decreased!! (0.009517-->0.009350)
# Test Loss: 0.007534
#
# Temp Loss: 0.081226
#
# Test Loss: 0.018567
#
# Temp Loss: 0.086421
#
# Epoch: 99, Train Loss Decreased!! (0.009350-->0.009162)
# Test Loss: 0.007527
#
# Temp Loss: 0.081146
#  60%|██████    | 3/5 [06:45<04:30, 135.40s/it]
# Test Loss: 0.017941
#
# Temp Loss: 0.085700
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.293819)
# Test Loss: 0.254180
#
# Temp Loss: 0.254153
#
# Epoch: 2, Train Loss Decreased!! (0.293819-->0.252941)
# Test Loss: 0.253438
#
# Temp Loss: 0.253785
#
# Epoch: 3, Train Loss Decreased!! (0.252941-->0.249283)
# Test Loss: 0.239297
#
# Temp Loss: 0.238917
#
# Epoch: 4, Train Loss Decreased!! (0.249283-->0.238515)
# Test Loss: 0.239913
#
# Temp Loss: 0.239780
#
# Epoch: 5, Train Loss Decreased!! (0.238515-->0.224276)
# Test Loss: 0.213876
#
# Temp Loss: 0.213935
#
# Epoch: 6, Train Loss Decreased!! (0.224276-->0.214401)
# Test Loss: 0.216532
#
# Temp Loss: 0.216950
#
# Epoch: 7, Train Loss Decreased!! (0.214401-->0.209188)
# Test Loss: 0.204400
#
# Temp Loss: 0.205849
#
# Epoch: 8, Train Loss Decreased!! (0.209188-->0.204208)
# Test Loss: 0.206154
#
# Temp Loss: 0.207566
#
# Epoch: 9, Train Loss Decreased!! (0.204208-->0.191025)
# Test Loss: 0.179261
#
# Temp Loss: 0.187797
#
# Epoch: 10, Train Loss Decreased!! (0.191025-->0.180231)
# Test Loss: 0.183828
#
# Temp Loss: 0.192478
#
# Epoch: 11, Train Loss Decreased!! (0.180231-->0.173312)
# Test Loss: 0.167333
#
# Temp Loss: 0.193401
#
# Epoch: 12, Train Loss Decreased!! (0.173312-->0.168559)
# Test Loss: 0.172063
#
# Temp Loss: 0.197496
#
# Epoch: 13, Train Loss Decreased!! (0.168559-->0.163394)
# Test Loss: 0.155924
#
# Temp Loss: 0.185234
#
# Epoch: 14, Train Loss Decreased!! (0.163394-->0.159085)
# Test Loss: 0.165097
#
# Temp Loss: 0.193453
#
# Epoch: 15, Train Loss Decreased!! (0.159085-->0.150089)
# Test Loss: 0.141288
#
# Temp Loss: 0.171545
#
# Epoch: 16, Train Loss Decreased!! (0.150089-->0.142499)
# Test Loss: 0.146556
#
# Temp Loss: 0.176732
#
# Epoch: 17, Train Loss Decreased!! (0.142499-->0.132862)
# Test Loss: 0.124387
#
# Temp Loss: 0.156189
#
# Epoch: 18, Train Loss Decreased!! (0.132862-->0.126306)
# Test Loss: 0.132373
#
# Temp Loss: 0.164763
#
# Epoch: 19, Train Loss Decreased!! (0.126306-->0.121011)
# Test Loss: 0.115745
#
# Temp Loss: 0.149189
#
# Epoch: 20, Train Loss Decreased!! (0.121011-->0.120444)
# Test Loss: 0.130507
#
# Temp Loss: 0.161525
#
# Epoch: 21, Train Loss Decreased!! (0.120444-->0.111891)
# Test Loss: 0.103895
#
# Temp Loss: 0.137998
#
# Epoch: 22, Train Loss Decreased!! (0.111891-->0.110253)
# Test Loss: 0.123599
#
# Temp Loss: 0.155498
#
# Epoch: 23, Train Loss Decreased!! (0.110253-->0.102105)
# Test Loss: 0.097086
#
# Temp Loss: 0.131023
#
# Epoch: 24, Train Loss Decreased!! (0.102105-->0.100263)
# Test Loss: 0.109773
#
# Temp Loss: 0.142521
#
# Epoch: 25, Train Loss Decreased!! (0.100263-->0.096047)
# Test Loss: 0.093193
#
# Temp Loss: 0.126102
#
# Epoch: 26, Train Loss Decreased!! (0.096047-->0.094395)
# Test Loss: 0.100631
#
# Temp Loss: 0.132862
#
# Epoch: 27, Train Loss Decreased!! (0.094395-->0.091725)
# Test Loss: 0.090097
#
# Temp Loss: 0.123375
#
# Epoch: 28, Train Loss Decreased!! (0.091725-->0.091326)
# Test Loss: 0.096715
#
# Temp Loss: 0.129847
#
# Epoch: 29, Train Loss Decreased!! (0.091326-->0.088494)
# Test Loss: 0.086395
#
# Temp Loss: 0.121771
#
# Epoch: 30, Train Loss Decreased!! (0.088494-->0.088143)
# Test Loss: 0.093839
#
# Temp Loss: 0.128247
#
# Epoch: 31, Train Loss Decreased!! (0.088143-->0.084993)
# Test Loss: 0.082698
#
# Temp Loss: 0.121880
#
# Epoch: 32, Train Loss Decreased!! (0.084993-->0.083776)
# Test Loss: 0.089479
#
# Temp Loss: 0.127347
#
# Epoch: 33, Train Loss Decreased!! (0.083776-->0.080611)
# Test Loss: 0.077367
#
# Temp Loss: 0.117510
#
# Epoch: 34, Train Loss Decreased!! (0.080611-->0.080211)
# Test Loss: 0.088231
#
# Temp Loss: 0.126388
#
# Epoch: 35, Train Loss Decreased!! (0.080211-->0.074882)
# Test Loss: 0.072373
#
# Temp Loss: 0.113356
#
# Test Loss: 0.084875
#
# Temp Loss: 0.123780
#
# Epoch: 37, Train Loss Decreased!! (0.074882-->0.071275)
# Test Loss: 0.069265
#
# Temp Loss: 0.111110
#
# Test Loss: 0.081766
#
# Temp Loss: 0.121567
#
# Epoch: 39, Train Loss Decreased!! (0.071275-->0.069297)
# Test Loss: 0.066637
#
# Temp Loss: 0.108452
#
# Epoch: 40, Train Loss Decreased!! (0.069297-->0.068971)
# Test Loss: 0.076714
#
# Temp Loss: 0.116079
#
# Epoch: 41, Train Loss Decreased!! (0.068971-->0.066019)
# Test Loss: 0.063016
#
# Temp Loss: 0.104014
#
# Epoch: 42, Train Loss Decreased!! (0.066019-->0.065426)
# Test Loss: 0.072022
#
# Temp Loss: 0.110782
#
# Epoch: 43, Train Loss Decreased!! (0.065426-->0.060852)
# Test Loss: 0.056012
#
# Temp Loss: 0.099149
#
# Epoch: 44, Train Loss Decreased!! (0.060852-->0.060777)
# Test Loss: 0.069426
#
# Temp Loss: 0.108493
#
# Epoch: 45, Train Loss Decreased!! (0.060777-->0.055881)
# Test Loss: 0.052215
#
# Temp Loss: 0.100383
#
# Test Loss: 0.064336
#
# Temp Loss: 0.108305
#
# Epoch: 47, Train Loss Decreased!! (0.055881-->0.052696)
# Test Loss: 0.049670
#
# Temp Loss: 0.100098
#
# Epoch: 48, Train Loss Decreased!! (0.052696-->0.052270)
# Test Loss: 0.058094
#
# Temp Loss: 0.105639
#
# Epoch: 49, Train Loss Decreased!! (0.052270-->0.049363)
# Test Loss: 0.047236
#
# Temp Loss: 0.100660
#
# Epoch: 50, Train Loss Decreased!! (0.049363-->0.049270)
# Test Loss: 0.054802
#
# Temp Loss: 0.106302
#
# Epoch: 51, Train Loss Decreased!! (0.049270-->0.046983)
# Test Loss: 0.044972
#
# Temp Loss: 0.101244
#
# Test Loss: 0.052980
#
# Temp Loss: 0.108002
#
# Epoch: 53, Train Loss Decreased!! (0.046983-->0.045204)
# Test Loss: 0.043603
#
# Temp Loss: 0.103416
#
# Test Loss: 0.051454
#
# Temp Loss: 0.110118
#
# Epoch: 55, Train Loss Decreased!! (0.045204-->0.043588)
# Test Loss: 0.041558
#
# Temp Loss: 0.102946
#
# Test Loss: 0.048945
#
# Temp Loss: 0.108963
#
# Epoch: 57, Train Loss Decreased!! (0.043588-->0.041409)
# Test Loss: 0.038745
#
# Temp Loss: 0.101759
#
# Test Loss: 0.047582
#
# Temp Loss: 0.107843
#
# Epoch: 59, Train Loss Decreased!! (0.041409-->0.037640)
# Test Loss: 0.034396
#
# Temp Loss: 0.099073
#
# Test Loss: 0.046302
#
# Temp Loss: 0.105444
#
# Epoch: 61, Train Loss Decreased!! (0.037640-->0.034089)
# Test Loss: 0.031837
#
# Temp Loss: 0.098416
#
# Test Loss: 0.048603
#
# Temp Loss: 0.106656
#
# Epoch: 63, Train Loss Decreased!! (0.034089-->0.032856)
# Test Loss: 0.030141
#
# Temp Loss: 0.097046
#
# Test Loss: 0.048623
#
# Temp Loss: 0.105555
#
# Epoch: 65, Train Loss Decreased!! (0.032856-->0.031845)
# Test Loss: 0.029121
#
# Temp Loss: 0.097004
#
# Test Loss: 0.048854
#
# Temp Loss: 0.106436
#
# Epoch: 67, Train Loss Decreased!! (0.031845-->0.031261)
# Test Loss: 0.027955
#
# Temp Loss: 0.095728
#
# Test Loss: 0.049983
#
# Temp Loss: 0.106444
#
# Epoch: 69, Train Loss Decreased!! (0.031261-->0.029755)
# Test Loss: 0.026432
#
# Temp Loss: 0.094645
#
# Test Loss: 0.045958
#
# Temp Loss: 0.103155
#
# Epoch: 71, Train Loss Decreased!! (0.029755-->0.026739)
# Test Loss: 0.022580
#
# Temp Loss: 0.087879
#
# Test Loss: 0.042373
#
# Temp Loss: 0.096073
#
# Epoch: 73, Train Loss Decreased!! (0.026739-->0.022571)
# Test Loss: 0.019069
#
# Temp Loss: 0.086895
#
# Test Loss: 0.041031
#
# Temp Loss: 0.095836
#
# Epoch: 75, Train Loss Decreased!! (0.022571-->0.020239)
# Test Loss: 0.016860
#
# Temp Loss: 0.086986
#
# Test Loss: 0.037666
#
# Temp Loss: 0.096236
#
# Epoch: 77, Train Loss Decreased!! (0.020239-->0.018208)
# Test Loss: 0.015269
#
# Temp Loss: 0.086458
#
# Test Loss: 0.036999
#
# Temp Loss: 0.096488
#
# Epoch: 79, Train Loss Decreased!! (0.018208-->0.017603)
# Test Loss: 0.014506
#
# Temp Loss: 0.086811
#
# Test Loss: 0.035553
#
# Temp Loss: 0.096378
#
# Epoch: 81, Train Loss Decreased!! (0.017603-->0.016232)
# Test Loss: 0.013503
#
# Temp Loss: 0.086736
#
# Test Loss: 0.035443
#
# Temp Loss: 0.096496
#
# Epoch: 83, Train Loss Decreased!! (0.016232-->0.015524)
# Test Loss: 0.012775
#
# Temp Loss: 0.086645
#
# Test Loss: 0.034273
#
# Temp Loss: 0.095911
#
# Epoch: 85, Train Loss Decreased!! (0.015524-->0.014593)
# Test Loss: 0.011882
#
# Temp Loss: 0.086559
#
# Test Loss: 0.034892
#
# Temp Loss: 0.097192
#
# Epoch: 87, Train Loss Decreased!! (0.014593-->0.014172)
# Test Loss: 0.011098
#
# Temp Loss: 0.086462
#
# Test Loss: 0.033965
#
# Temp Loss: 0.097663
#
# Epoch: 89, Train Loss Decreased!! (0.014172-->0.013302)
# Test Loss: 0.010166
#
# Temp Loss: 0.086631
#
# Test Loss: 0.033731
#
# Temp Loss: 0.098090
#
# Epoch: 91, Train Loss Decreased!! (0.013302-->0.012573)
# Test Loss: 0.009535
#
# Temp Loss: 0.086116
#
# Test Loss: 0.031092
#
# Temp Loss: 0.097027
#
# Epoch: 93, Train Loss Decreased!! (0.012573-->0.011769)
# Test Loss: 0.009122
#
# Temp Loss: 0.085922
#
# Test Loss: 0.029817
#
# Temp Loss: 0.096680
#
# Epoch: 95, Train Loss Decreased!! (0.011769-->0.011135)
# Test Loss: 0.008607
#
# Temp Loss: 0.085648
#
# Test Loss: 0.030562
#
# Temp Loss: 0.097493
#
# Epoch: 97, Train Loss Decreased!! (0.011135-->0.010808)
# Test Loss: 0.008211
#
# Temp Loss: 0.085976
#
# Test Loss: 0.031248
#
# Temp Loss: 0.098062
#
# Test Loss: 0.008079
#
# Temp Loss: 0.085957
#  80%|████████  | 4/5 [09:01<02:15, 135.28s/it]
# Test Loss: 0.026926
#
# Temp Loss: 0.095536
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.286548)
# Test Loss: 0.252143
#
# Temp Loss: 0.252109
#
# Epoch: 2, Train Loss Decreased!! (0.286548-->0.251685)
# Test Loss: 0.251732
#
# Temp Loss: 0.251870
#
# Epoch: 3, Train Loss Decreased!! (0.251685-->0.247488)
# Test Loss: 0.238167
#
# Temp Loss: 0.238004
#
# Epoch: 4, Train Loss Decreased!! (0.247488-->0.239183)
# Test Loss: 0.238800
#
# Temp Loss: 0.238728
#
# Epoch: 5, Train Loss Decreased!! (0.239183-->0.227473)
# Test Loss: 0.214849
#
# Temp Loss: 0.215850
#
# Epoch: 6, Train Loss Decreased!! (0.227473-->0.217834)
# Test Loss: 0.219919
#
# Temp Loss: 0.220765
#
# Epoch: 7, Train Loss Decreased!! (0.217834-->0.210221)
# Test Loss: 0.200613
#
# Temp Loss: 0.208407
#
# Epoch: 8, Train Loss Decreased!! (0.210221-->0.203344)
# Test Loss: 0.205691
#
# Temp Loss: 0.212463
#
# Epoch: 9, Train Loss Decreased!! (0.203344-->0.190528)
# Test Loss: 0.179876
#
# Temp Loss: 0.205987
#
# Epoch: 10, Train Loss Decreased!! (0.190528-->0.180770)
# Test Loss: 0.184278
#
# Temp Loss: 0.208034
#
# Epoch: 11, Train Loss Decreased!! (0.180770-->0.172099)
# Test Loss: 0.165704
#
# Temp Loss: 0.195117
#
# Epoch: 12, Train Loss Decreased!! (0.172099-->0.166378)
# Test Loss: 0.168999
#
# Temp Loss: 0.195852
#
# Epoch: 13, Train Loss Decreased!! (0.166378-->0.159675)
# Test Loss: 0.153365
#
# Temp Loss: 0.185434
#
# Epoch: 14, Train Loss Decreased!! (0.159675-->0.154911)
# Test Loss: 0.159934
#
# Temp Loss: 0.188378
#
# Epoch: 15, Train Loss Decreased!! (0.154911-->0.146100)
# Test Loss: 0.139613
#
# Temp Loss: 0.172630
#
# Epoch: 16, Train Loss Decreased!! (0.146100-->0.141262)
# Test Loss: 0.148198
#
# Temp Loss: 0.178277
#
# Epoch: 17, Train Loss Decreased!! (0.141262-->0.135513)
# Test Loss: 0.129096
#
# Temp Loss: 0.161795
#
# Epoch: 18, Train Loss Decreased!! (0.135513-->0.130216)
# Test Loss: 0.136636
#
# Temp Loss: 0.166239
#
# Epoch: 19, Train Loss Decreased!! (0.130216-->0.123625)
# Test Loss: 0.120649
#
# Temp Loss: 0.155503
#
# Epoch: 20, Train Loss Decreased!! (0.123625-->0.120470)
# Test Loss: 0.126590
#
# Temp Loss: 0.159170
#
# Epoch: 21, Train Loss Decreased!! (0.120470-->0.116668)
# Test Loss: 0.112868
#
# Temp Loss: 0.151143
#
# Epoch: 22, Train Loss Decreased!! (0.116668-->0.114194)
# Test Loss: 0.120902
#
# Temp Loss: 0.156342
#
# Epoch: 23, Train Loss Decreased!! (0.114194-->0.106897)
# Test Loss: 0.100496
#
# Temp Loss: 0.139798
#
# Epoch: 24, Train Loss Decreased!! (0.106897-->0.103941)
# Test Loss: 0.111969
#
# Temp Loss: 0.148653
#
# Epoch: 25, Train Loss Decreased!! (0.103941-->0.095252)
# Test Loss: 0.087140
#
# Temp Loss: 0.127382
#
# Epoch: 26, Train Loss Decreased!! (0.095252-->0.093607)
# Test Loss: 0.103491
#
# Temp Loss: 0.139837
#
# Epoch: 27, Train Loss Decreased!! (0.093607-->0.086494)
# Test Loss: 0.081586
#
# Temp Loss: 0.121933
#
# Test Loss: 0.095545
#
# Temp Loss: 0.132355
#
# Epoch: 29, Train Loss Decreased!! (0.086494-->0.081268)
# Test Loss: 0.075236
#
# Temp Loss: 0.114755
#
# Epoch: 30, Train Loss Decreased!! (0.081268-->0.079842)
# Test Loss: 0.087900
#
# Temp Loss: 0.125007
#
# Epoch: 31, Train Loss Decreased!! (0.079842-->0.072533)
# Test Loss: 0.064719
#
# Temp Loss: 0.103132
#
# Epoch: 32, Train Loss Decreased!! (0.072533-->0.070464)
# Test Loss: 0.079594
#
# Temp Loss: 0.116821
#
# Epoch: 33, Train Loss Decreased!! (0.070464-->0.064912)
# Test Loss: 0.060349
#
# Temp Loss: 0.099680
#
# Test Loss: 0.073256
#
# Temp Loss: 0.110757
#
# Epoch: 35, Train Loss Decreased!! (0.064912-->0.060669)
# Test Loss: 0.056352
#
# Temp Loss: 0.097309
#
# Epoch: 36, Train Loss Decreased!! (0.060669-->0.059733)
# Test Loss: 0.066023
#
# Temp Loss: 0.105872
#
# Epoch: 37, Train Loss Decreased!! (0.059733-->0.056008)
# Test Loss: 0.051451
#
# Temp Loss: 0.093484
#
# Epoch: 38, Train Loss Decreased!! (0.056008-->0.055175)
# Test Loss: 0.061148
#
# Temp Loss: 0.102455
#
# Epoch: 39, Train Loss Decreased!! (0.055175-->0.050972)
# Test Loss: 0.046078
#
# Temp Loss: 0.089707
#
# Epoch: 40, Train Loss Decreased!! (0.050972-->0.049818)
# Test Loss: 0.056212
#
# Temp Loss: 0.098759
#
# Epoch: 41, Train Loss Decreased!! (0.049818-->0.046419)
# Test Loss: 0.042662
#
# Temp Loss: 0.088472
#
# Test Loss: 0.054003
#
# Temp Loss: 0.098676
#
# Epoch: 43, Train Loss Decreased!! (0.046419-->0.043252)
# Test Loss: 0.039952
#
# Temp Loss: 0.088752
#
# Test Loss: 0.049496
#
# Temp Loss: 0.096623
#
# Epoch: 45, Train Loss Decreased!! (0.043252-->0.040163)
# Test Loss: 0.037088
#
# Temp Loss: 0.088039
#
# Test Loss: 0.046860
#
# Temp Loss: 0.096151
#
# Epoch: 47, Train Loss Decreased!! (0.040163-->0.037593)
# Test Loss: 0.034617
#
# Temp Loss: 0.088774
#
# Test Loss: 0.046129
#
# Temp Loss: 0.097688
#
# Epoch: 49, Train Loss Decreased!! (0.037593-->0.035960)
# Test Loss: 0.032457
#
# Temp Loss: 0.090136
#
# Test Loss: 0.043738
#
# Temp Loss: 0.097788
#
# Epoch: 51, Train Loss Decreased!! (0.035960-->0.033803)
# Test Loss: 0.030842
#
# Temp Loss: 0.091207
#
# Test Loss: 0.043871
#
# Temp Loss: 0.100650
#
# Epoch: 53, Train Loss Decreased!! (0.033803-->0.032915)
# Test Loss: 0.029716
#
# Temp Loss: 0.090980
#
# Test Loss: 0.042062
#
# Temp Loss: 0.099969
#
# Epoch: 55, Train Loss Decreased!! (0.032915-->0.031531)
# Test Loss: 0.028422
#
# Temp Loss: 0.090910
#
# Test Loss: 0.042734
#
# Temp Loss: 0.101810
#
# Epoch: 57, Train Loss Decreased!! (0.031531-->0.030366)
# Test Loss: 0.026923
#
# Temp Loss: 0.090640
#
# Test Loss: 0.043976
#
# Temp Loss: 0.104039
#
# Epoch: 59, Train Loss Decreased!! (0.030366-->0.029563)
# Test Loss: 0.026442
#
# Temp Loss: 0.090146
#
# Test Loss: 0.041881
#
# Temp Loss: 0.102214
#
# Epoch: 61, Train Loss Decreased!! (0.029563-->0.028719)
# Test Loss: 0.025288
#
# Temp Loss: 0.091507
#
# Test Loss: 0.041661
#
# Temp Loss: 0.101143
#
# Epoch: 63, Train Loss Decreased!! (0.028719-->0.027860)
# Test Loss: 0.024514
#
# Temp Loss: 0.090551
#
# Test Loss: 0.041938
#
# Temp Loss: 0.100947
#
# Epoch: 65, Train Loss Decreased!! (0.027860-->0.026310)
# Test Loss: 0.022822
#
# Temp Loss: 0.089811
#
# Test Loss: 0.039882
#
# Temp Loss: 0.099571
#
# Epoch: 67, Train Loss Decreased!! (0.026310-->0.024549)
# Test Loss: 0.020683
#
# Temp Loss: 0.088444
#
# Test Loss: 0.038935
#
# Temp Loss: 0.099115
#
# Epoch: 69, Train Loss Decreased!! (0.024549-->0.021901)
# Test Loss: 0.017283
#
# Temp Loss: 0.085316
#
# Test Loss: 0.036911
#
# Temp Loss: 0.098074
#
# Epoch: 71, Train Loss Decreased!! (0.021901-->0.018987)
# Test Loss: 0.014461
#
# Temp Loss: 0.083430
#
# Test Loss: 0.036036
#
# Temp Loss: 0.096829
#
# Epoch: 73, Train Loss Decreased!! (0.018987-->0.016615)
# Test Loss: 0.012168
#
# Temp Loss: 0.083301
#
# Test Loss: 0.035085
#
# Temp Loss: 0.097139
#
# Epoch: 75, Train Loss Decreased!! (0.016615-->0.015148)
# Test Loss: 0.010850
#
# Temp Loss: 0.083071
#
# Test Loss: 0.034361
#
# Temp Loss: 0.096792
#
# Epoch: 77, Train Loss Decreased!! (0.015148-->0.013837)
# Test Loss: 0.009796
#
# Temp Loss: 0.083357
#
# Test Loss: 0.032821
#
# Temp Loss: 0.096191
#
# Epoch: 79, Train Loss Decreased!! (0.013837-->0.013077)
# Test Loss: 0.009055
#
# Temp Loss: 0.083213
#
# Test Loss: 0.029999
#
# Temp Loss: 0.093090
#
# Epoch: 81, Train Loss Decreased!! (0.013077-->0.011819)
# Test Loss: 0.008258
#
# Temp Loss: 0.084027
#
# Test Loss: 0.030131
#
# Temp Loss: 0.094552
#
# Epoch: 83, Train Loss Decreased!! (0.011819-->0.011461)
# Test Loss: 0.007923
#
# Temp Loss: 0.083413
#
# Test Loss: 0.028238
#
# Temp Loss: 0.092340
#
# Epoch: 85, Train Loss Decreased!! (0.011461-->0.010819)
# Test Loss: 0.007414
#
# Temp Loss: 0.083695
#
# Test Loss: 0.027022
#
# Temp Loss: 0.091468
#
# Epoch: 87, Train Loss Decreased!! (0.010819-->0.010153)
# Test Loss: 0.007061
#
# Temp Loss: 0.083821
#
# Test Loss: 0.026635
#
# Temp Loss: 0.091757
#
# Epoch: 89, Train Loss Decreased!! (0.010153-->0.009748)
# Test Loss: 0.006702
#
# Temp Loss: 0.084053
#
# Test Loss: 0.025591
#
# Temp Loss: 0.091295
#
# Epoch: 91, Train Loss Decreased!! (0.009748-->0.009586)
# Test Loss: 0.006573
#
# Temp Loss: 0.083950
#
# Test Loss: 0.024985
#
# Temp Loss: 0.090596
#
# Epoch: 93, Train Loss Decreased!! (0.009586-->0.009024)
# Test Loss: 0.006091
#
# Temp Loss: 0.083712
#
# Test Loss: 0.024191
#
# Temp Loss: 0.090054
#
# Epoch: 95, Train Loss Decreased!! (0.009024-->0.008677)
# Test Loss: 0.005846
#
# Temp Loss: 0.084190
#
# Test Loss: 0.024880
#
# Temp Loss: 0.091512
#
# Epoch: 97, Train Loss Decreased!! (0.008677-->0.008648)
# Test Loss: 0.005607
#
# Temp Loss: 0.083676
#
# Test Loss: 0.023303
#
# Temp Loss: 0.089888
#
# Epoch: 99, Train Loss Decreased!! (0.008648-->0.008204)
# Test Loss: 0.005423
#
# Temp Loss: 0.084115
# 100%|██████████| 5/5 [11:16<00:00, 135.21s/it]
# Test Loss: 0.022495
#
# Temp Loss: 0.089879
#
# ----------------------------------------------------

# %%
train_losses_mat = np.zeros((nRuns,n_epochs+1))
test_losses_mat = np.zeros((nRuns,n_epochs+1))
temp_losses_mat = np.zeros((nRuns,n_epochs+1))

train_expected_losses_mat = np.zeros((nRuns,n_epochs+1))

test_expected_losses_mat = np.zeros((nRuns,n_epochs+1))
test_surprise_losses_mat = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    train_losses_mat[cntr] = train_losses[cntr]
    test_losses_mat[cntr] = test_losses[cntr]
    temp_losses_mat[cntr] = temp_losses[cntr]
    
    train_expected_losses_mat[cntr] = train_expected_rec_losses[cntr]
    
    test_expected_losses_mat[cntr] = test_expected_rec_losses[cntr]
    test_surprise_losses_mat[cntr] = test_surprise_rec_losses[cntr]

# %%
train_losses_mean = np.mean(train_losses_mat,axis=0)
test_losses_mean = np.mean(test_losses_mat,axis=0)
temp_losses_mean = np.mean(temp_losses_mat,axis=0)

train_expected_losses_mean = np.mean(train_expected_losses_mat,axis=0)

test_expected_losses_mean = np.mean(test_expected_losses_mat,axis=0)
test_surprise_losses_mean = np.mean(test_surprise_losses_mat,axis=0)

# %%
train_losses_std = np.std(train_losses_mat,axis=0)
test_losses_std = np.std(test_losses_mat,axis=0)
temp_losses_std = np.std(test_losses_mat,axis=0)

train_expected_losses_std = np.std(train_expected_losses_mat,axis=0)

test_expected_losses_std = np.std(test_expected_losses_mat,axis=0)
test_surprise_losses_std = np.std(test_surprise_losses_mat,axis=0)

# %%
train_expected_losses_mean[0] = train_losses_mean[0]

# %%
f = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.errorbar(np.arange(n_epochs+1),train_losses_mean,yerr=train_losses_std)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,2)
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.subplot(2,2,3)
plt.errorbar(np.arange(n_epochs+1),test_losses_mean,yerr=test_losses_std)
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,4)
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
# kk=4
# a = np.unique(allStatesTest[kk][:,0])
# b = np.unique(allStatesTrain[kk][:,0])
# len(np.intersect1d(a,b))

# %% [markdown]
# ### Representational Analyses

# %% [markdown]
# #### RNN Names

# %%
rnn_names = ['L4','L23','L56','H4','H23','H56']

# %% [markdown]
# #### Analyses train loader

# %%
analyses_train_loader = {}

# %%
for cntr in range(nRuns):
    analyses_train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=False)

# %% [markdown]
# #### Pass data and store activations

# %%
def pass_data_store_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        activations_hidden_L23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_L4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_L56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_hidden_H23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_H4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_H56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_out_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
        for e in tqdm(range(n_epochs+1)):

            cnt = 0

            ## Load model
            model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr])
            model[cntr].to(device)
            model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
            model[cntr].eval()

            ## Pass clean samples
            for data, f_target, lastEvent, surpriseBinary in loader[cntr]:

                if train_on_gpu:
                    data, f_targetC = data.float().cuda(), f_target.float().cuda()
                else: data, f_targetC = data.float(), f_target.float()

                target = f_target

                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                ## Collect activations  
                act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                for i in range(batch_size):
                    if i < len(data):
                        label = target.data[i]

                        activations_hidden_L23_np[cntr][e,cnt] = act_hidden_L23[i]
                        activations_hidden_L4_np[cntr][e,cnt] = act_hidden_L4[i]
                        activations_hidden_L56_np[cntr][e,cnt] = act_hidden_L56[i]

                        activations_hidden_H23_np[cntr][e,cnt] = act_hidden_H23[i]
                        activations_hidden_H4_np[cntr][e,cnt] = act_hidden_H4[i]
                        activations_hidden_H56_np[cntr][e,cnt] = act_hidden_H56[i]

                        activations_out_np[cntr][e,cnt] = output_pred[i]

                        cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
(L23_train,L4_train,L56_train,
 H23_train,H4_train,H56_train,), out_train = pass_data_store_activations(analyses_train_loader, nTrain)
# Out:
# 100%|██████████| 101/101 [01:15<00:00,  1.33it/s]
# 100%|██████████| 101/101 [01:15<00:00,  1.33it/s]
# 100%|██████████| 101/101 [01:15<00:00,  1.34it/s]
# 100%|██████████| 101/101 [01:15<00:00,  1.33it/s]
# 100%|██████████| 101/101 [01:16<00:00,  1.33it/s]

# %%
(L23_test,L4_test,L56_test,
 H23_test,H4_test,H56_test,), out_test = pass_data_store_activations(test_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:20<00:00,  4.99it/s]
# 100%|██████████| 101/101 [00:20<00:00,  5.02it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.91it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.97it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.99it/s]

# %%
(L23_temp,L4_temp,L56_temp,
 H23_temp,H4_temp,H56_temp,), out_temp = pass_data_store_activations(test_temp_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:20<00:00,  4.95it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.96it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.97it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.99it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.96it/s]

# %% [markdown]
# #### PCA for RNNs

# %%
def repsPCA(rnnActs):
    nEpochs, nSeqs, nRolls, nNeurons = rnnActs.shape
    pca_dict = {}
    nSamps = nSeqs*nRolls
    dimPCA = min(nNeurons,nSamps)
    repsR_transformed = np.zeros((nEpochs,nSamps,dimPCA))
    
    for ep in tqdm(range(nEpochs)):
        
        reps = rnnActs[ep]
        
        ## reshape
        repsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        for ii in range(nSeqs):
            for jj in range(nRolls):
                repsR[cnt] = reps[ii,jj]
                cnt += 1
        ## PCA
        rnnPCA = PCA()
        repsR_transformed[ep] = rnnPCA.fit_transform(repsR)
        pca_dict[str(ep)] = rnnPCA
        
    return repsR_transformed, pca_dict

# %%
L23pca_train = {}
L4pca_train = {}
L56pca_train = {}

H23pca_train = {}
H4pca_train = {}
H56pca_train = {}

L23pca_test = {}
L4pca_test = {}
L56pca_test = {}

H23pca_test = {}
H4pca_test = {}
H56pca_test = {}

L23pca_temp = {}
L4pca_temp = {}
L56pca_temp = {}

H23pca_temp = {}
H4pca_temp = {}
H56pca_temp = {}

# %%
for cntr in range(nRuns):
    L23pca_train[cntr], _ = repsPCA(L23_train[cntr])
    L4pca_train[cntr], _ = repsPCA(L4_train[cntr])
    L56pca_train[cntr], _ = repsPCA(L56_train[cntr])

    H23pca_train[cntr], _ = repsPCA(H23_train[cntr])
    H4pca_train[cntr], _ = repsPCA(H4_train[cntr])
    H56pca_train[cntr], _ = repsPCA(H56_train[cntr])
# Out:
# 100%|██████████| 101/101 [00:06<00:00, 16.77it/s]
# 100%|██████████| 101/101 [00:03<00:00, 32.86it/s]
# 100%|██████████| 101/101 [00:05<00:00, 19.50it/s]
# 100%|██████████| 101/101 [00:06<00:00, 16.49it/s]
# 100%|██████████| 101/101 [00:03<00:00, 33.19it/s]
# 100%|██████████| 101/101 [00:05<00:00, 19.41it/s]
# 100%|██████████| 101/101 [00:06<00:00, 16.57it/s]
# 100%|██████████| 101/101 [00:03<00:00, 32.35it/s]
# 100%|██████████| 101/101 [00:05<00:00, 19.56it/s]
# 100%|██████████| 101/101 [00:06<00:00, 16.47it/s]
# 100%|██████████| 101/101 [00:03<00:00, 32.82it/s]
# 100%|██████████| 101/101 [00:05<00:00, 19.67it/s]
# 100%|██████████| 101/101 [00:06<00:00, 16.51it/s]
# 100%|██████████| 101/101 [00:03<00:00, 32.38it/s]
# 100%|██████████| 101/101 [00:05<00:00, 19.20it/s]
# 100%|██████████| 101/101 [00:06<00:00, 16.68it/s]
# 100%|██████████| 101/101 [00:03<00:00, 32.71it/s]
# 100%|██████████| 101/101 [00:05<00:00, 19.41it/s]
# 100%|██████████| 101/101 [00:06<00:00, 16.54it/s]
# 100%|██████████| 101/101 [00:03<00:00, 32.54it/s]
# 100%|██████████| 101/101 [00:05<00:00, 19.33it/s]
# 100%|██████████| 101/101 [00:06<00:00, 16.63it/s]
# 100%|██████████| 101/101 [00:03<00:00, 32.04it/s]
# 100%|██████████| 101/101 [00:05<00:00, 19.38it/s]
# 100%|██████████| 101/101 [00:06<00:00, 16.44it/s]
# 100%|██████████| 101/101 [00:03<00:00, 32.39it/s]
# 100%|██████████| 101/101 [00:05<00:00, 19.45it/s]
# 100%|██████████| 101/101 [00:06<00:00, 16.60it/s]
# 100%|██████████| 101/101 [00:03<00:00, 33.04it/s]
# 100%|██████████| 101/101 [00:05<00:00, 19.33it/s]

# %%
for cntr in range(nRuns):
    L23pca_test[cntr], _ = repsPCA(L23_test[cntr])
    L4pca_test[cntr], _ = repsPCA(L4_test[cntr])
    L56pca_test[cntr], _ = repsPCA(L56_test[cntr])

    H23pca_test[cntr], _ = repsPCA(H23_test[cntr])
    H4pca_test[cntr], _ = repsPCA(H4_test[cntr])
    H56pca_test[cntr], _ = repsPCA(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 64.81it/s]
# 100%|██████████| 101/101 [00:00<00:00, 123.47it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.63it/s]
# 100%|██████████| 101/101 [00:01<00:00, 61.80it/s]
# 100%|██████████| 101/101 [00:00<00:00, 122.41it/s]
# 100%|██████████| 101/101 [00:01<00:00, 76.81it/s]
# 100%|██████████| 101/101 [00:01<00:00, 59.39it/s]
# 100%|██████████| 101/101 [00:00<00:00, 123.80it/s]
# 100%|██████████| 101/101 [00:01<00:00, 74.86it/s]
# 100%|██████████| 101/101 [00:01<00:00, 61.08it/s]
# 100%|██████████| 101/101 [00:00<00:00, 127.02it/s]
# 100%|██████████| 101/101 [00:01<00:00, 76.28it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.37it/s]
# 100%|██████████| 101/101 [00:00<00:00, 122.74it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.12it/s]
# 100%|██████████| 101/101 [00:01<00:00, 61.37it/s]
# 100%|██████████| 101/101 [00:00<00:00, 121.43it/s]
# 100%|██████████| 101/101 [00:01<00:00, 77.96it/s]
# 100%|██████████| 101/101 [00:01<00:00, 62.12it/s]
# 100%|██████████| 101/101 [00:00<00:00, 123.20it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.14it/s]
# 100%|██████████| 101/101 [00:01<00:00, 61.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 128.84it/s]
# 100%|██████████| 101/101 [00:01<00:00, 77.22it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.11it/s]
# 100%|██████████| 101/101 [00:00<00:00, 123.64it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.32it/s]
# 100%|██████████| 101/101 [00:01<00:00, 62.35it/s]
# 100%|██████████| 101/101 [00:00<00:00, 125.94it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.55it/s]

# %%
for cntr in range(nRuns):
    L23pca_temp[cntr], _ = repsPCA(L23_temp[cntr])
    L4pca_temp[cntr], _ = repsPCA(L4_temp[cntr])
    L56pca_temp[cntr], _ = repsPCA(L56_temp[cntr])

    H23pca_temp[cntr], _ = repsPCA(H23_temp[cntr])
    H4pca_temp[cntr], _ = repsPCA(H4_temp[cntr])
    H56pca_temp[cntr], _ = repsPCA(H56_temp[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 61.22it/s]
# 100%|██████████| 101/101 [00:00<00:00, 133.25it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.32it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.57it/s]
# 100%|██████████| 101/101 [00:00<00:00, 121.14it/s]
# 100%|██████████| 101/101 [00:01<00:00, 77.50it/s]
# 100%|██████████| 101/101 [00:01<00:00, 58.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 118.27it/s]
# 100%|██████████| 101/101 [00:01<00:00, 81.27it/s]
# 100%|██████████| 101/101 [00:01<00:00, 65.27it/s]
# 100%|██████████| 101/101 [00:00<00:00, 124.49it/s]
# 100%|██████████| 101/101 [00:01<00:00, 82.32it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.72it/s]
# 100%|██████████| 101/101 [00:00<00:00, 123.05it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.36it/s]
# 100%|██████████| 101/101 [00:01<00:00, 70.13it/s]
# 100%|██████████| 101/101 [00:00<00:00, 133.25it/s]
# 100%|██████████| 101/101 [00:01<00:00, 86.33it/s]
# 100%|██████████| 101/101 [00:01<00:00, 69.89it/s]
# 100%|██████████| 101/101 [00:00<00:00, 136.64it/s]
# 100%|██████████| 101/101 [00:01<00:00, 69.32it/s]
# 100%|██████████| 101/101 [00:02<00:00, 39.40it/s]
# 100%|██████████| 101/101 [00:00<00:00, 122.31it/s]
# 100%|██████████| 101/101 [00:01<00:00, 74.21it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.09it/s]
# 100%|██████████| 101/101 [00:00<00:00, 120.27it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.77it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.65it/s]
# 100%|██████████| 101/101 [00:00<00:00, 127.54it/s]
# 100%|██████████| 101/101 [00:01<00:00, 82.03it/s]

# %%
idxs0_train = np.array([6*x for x in range(nTrain)])
idxs1_train = idxs0_train + 1
idxs2_train = idxs0_train + 2
idxs3_train = idxs0_train + 3
idxs4_train = idxs0_train + 4
idxs5_train = idxs0_train + 5

# %%
idxs0_test = np.array([6*x for x in range(nTest)])
idxs1_test = idxs0_test + 1
idxs2_test = idxs0_test + 2
idxs3_test = idxs0_test + 3
idxs4_test = idxs0_test + 4
idxs5_test = idxs0_test + 5

# %%
# cnt = 4
# ep = -1
# ix = idxs5_train
# c = allStatesTrain[cnt][:,0]/numM
# s = 20*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_train[cnt][ep,ix,0],L4pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_train[cnt][ep,ix,0],L23pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_train[cnt][ep,ix,0],L56pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_train[cnt][ep,ix,0],H4pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_train[cnt][ep,ix,0],H23pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_train[cnt][ep,ix,0],H56pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H5/6')

# %%
# cnt = 4
# ep = -1
# ix = idxs4_test
# c = allStatesTest[cnt][:,0]/numM
# s = 20*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H5/6')

# %% [markdown]
# #### Subset indices, etc.

# %%
idxs00_train = np.hstack((idxs0_train.reshape(-1,1),idxs1_train.reshape(-1,1)))
idxs11_train = np.hstack((idxs2_train.reshape(-1,1),idxs3_train.reshape(-1,1)))
idxs22_train = np.hstack((idxs4_train.reshape(-1,1),idxs5_train.reshape(-1,1)))

# %%
idxs00_test = np.hstack((idxs0_test.reshape(-1,1),idxs1_test.reshape(-1,1))).ravel()
idxs11_test = np.hstack((idxs2_test.reshape(-1,1),idxs3_test.reshape(-1,1))).ravel()
idxs22_test = np.hstack((idxs4_test.reshape(-1,1),idxs5_test.reshape(-1,1))).ravel()

# %%
cleanPCs = {}
surpPCs = {}

contextPCs_sub = {}

# %%
for cntr in range(nRuns):
    cleanPCs[cntr] = (L4pca_test[cntr],L23pca_test[cntr],L56pca_test[cntr],
                      H4pca_test[cntr],H23pca_test[cntr],H56pca_test[cntr])
    surpPCs[cntr] = (L4pca_temp[cntr],L23pca_temp[cntr],L56pca_temp[cntr],
                     H4pca_temp[cntr],H23pca_temp[cntr],H56pca_temp[cntr])
    
    for rnnNo in range(len(rnn_names)):
        contextPCs_sub[cntr,rnnNo] = np.hstack((cleanPCs[cntr][rnnNo][:,idxs22_test,:],surpPCs[cntr][rnnNo][:,idxs22_test,:]))

# %%
context_sub_surp = np.array([0]*nRepeats*nTest + [1]*nRepeats*nTest)

# %%
context_sub_imgIDs = {}
for cntr in range(nRuns):
    context_sub_imgIDs[cntr] = np.hstack((np.repeat(labelsTest[cntr][:,2:3],nRepeats),
                                          np.repeat(labelsTestTemp[cntr][:,2:3],nRepeats)))

# %%
# print(len(np.unique(context_sub_imgIDs[4])))

# %% [markdown]
# #### Supervised Decoding

# %%
sub_Eps = np.array([0,1,50])
ds_im = 100

# %%
def repsDecodeSupervisedContext(rnnActs,labels,decodeType='surprise',clf='logistic',sub=True,ds=ds_im):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'surprise':
        nClasses = 2
    elif decodeType == 'imageID':
        if sub:
            rnnActs = rnnActs[:,::ds,:]
            nEpochs, nSamps, nNeurons = rnnActs.shape
            labels = labels[::ds]
            nClasses = len(np.unique(labels))
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression(multi_class='ovr').fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)    
        
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
dims23 = np.array([1,2,4,8,16,32,64,80])
dims4 = np.array([1,2,4,8,16,32])
dims56 = np.array([1,2,4,8,16,32,64])

# %%
L23surpPC = {}
L4surpPC = {}
L56surpPC = {}

H23surpPC = {}
H4surpPC = {}
H56surpPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        
    for d in dims4:
        L4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
    
    for d in dims56:
        L56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  1.72it/s]

# %%
L23imgPC = {}
L4imgPC = {}
L56imgPC = {}

H23imgPC = {}
H4imgPC = {}
H56imgPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        
    for d in dims4:
        L4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][sub_Eps,:,:d],
                                                          context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][sub_Eps,:,:d],
                                                          context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
    
    for d in dims56:
        L56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
# Out:
# 100%|██████████| 5/5 [00:17<00:00,  3.56s/it]

# %% [markdown]
# #### Generate plots

# %%
preds_L23imgPC = {}
preds_L4imgPC = {}
preds_L56imgPC = {}

preds_H23imgPC = {}
preds_H4imgPC = {}
preds_H56imgPC = {}

preds_L23surpPC = {}
preds_L4surpPC = {}
preds_L56surpPC = {}

preds_H23surpPC = {}
preds_H4surpPC = {}
preds_H56surpPC = {}

# %%
accs_L23imgPC = {}
accs_L4imgPC = {}
accs_L56imgPC = {}

accs_H23imgPC = {}
accs_H4imgPC = {}
accs_H56imgPC = {}

accs_L23surpPC = {}
accs_L4surpPC = {}
accs_L56surpPC = {}

accs_H23surpPC = {}
accs_H4surpPC = {}
accs_H56surpPC = {}

# %%
for cntr in range(nRuns):
    for ep in range(len(sub_Eps)):
        
        for d in dims23:
            preds_L23imgPC[cntr,d,ep] = np.argmax(L23imgPC[cntr,d][ep],axis=-1)
            preds_H23imgPC[cntr,d,ep] = np.argmax(H23imgPC[cntr,d][ep],axis=-1)
            
            preds_L23surpPC[cntr,d,ep] = np.argmax(L23surpPC[cntr,d][ep],axis=-1)
            preds_H23surpPC[cntr,d,ep] = np.argmax(H23surpPC[cntr,d][ep],axis=-1)
            
            accs_L23imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L23imgPC[cntr,d,ep])
            accs_H23imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H23imgPC[cntr,d,ep])
            
            accs_L23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L23surpPC[cntr,d,ep])
            accs_H23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H23surpPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4imgPC[cntr,d,ep] = np.argmax(L4imgPC[cntr,d][ep],axis=-1)
            preds_H4imgPC[cntr,d,ep] = np.argmax(H4imgPC[cntr,d][ep],axis=-1)
            
            preds_L4surpPC[cntr,d,ep] = np.argmax(L4surpPC[cntr,d][ep],axis=-1)
            preds_H4surpPC[cntr,d,ep] = np.argmax(H4surpPC[cntr,d][ep],axis=-1)
            
            accs_L4imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L4imgPC[cntr,d,ep])
            accs_H4imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H4imgPC[cntr,d,ep])
            
            accs_L4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L4surpPC[cntr,d,ep])
            accs_H4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H4surpPC[cntr,d,ep])
                
        for d in dims56:        
            preds_L56imgPC[cntr,d,ep] = np.argmax(L56imgPC[cntr,d][ep],axis=-1)
            preds_H56imgPC[cntr,d,ep] = np.argmax(H56imgPC[cntr,d][ep],axis=-1)
            
            preds_L56surpPC[cntr,d,ep] = np.argmax(L56surpPC[cntr,d][ep],axis=-1)
            preds_H56surpPC[cntr,d,ep] = np.argmax(H56surpPC[cntr,d][ep],axis=-1)
            
            accs_L56imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L56imgPC[cntr,d,ep])
            accs_H56imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H56imgPC[cntr,d,ep])
            
            accs_L56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L56surpPC[cntr,d,ep])
            accs_H56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H56surpPC[cntr,d,ep])

# %%
tensor_accs_L23imgPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4imgPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56imgPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23imgPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4imgPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56imgPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_L23surpPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4surpPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56surpPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23surpPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4surpPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56surpPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

# %%
for ii in range(nRuns):
    for kk in range(len(sub_Eps)):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23imgPC[ii,jj,kk] = accs_L23imgPC[ii,d,kk]
            tensor_accs_H23imgPC[ii,jj,kk] = accs_H23imgPC[ii,d,kk]
            
            tensor_accs_L23surpPC[ii,jj,kk] = accs_L23surpPC[ii,d,kk]
            tensor_accs_H23surpPC[ii,jj,kk] = accs_H23surpPC[ii,d,kk]
            
        
        for jj,d in enumerate(dims4):
            tensor_accs_L4imgPC[ii,jj,kk] = accs_L4imgPC[ii,d,kk]
            tensor_accs_H4imgPC[ii,jj,kk] = accs_H4imgPC[ii,d,kk]
            
            tensor_accs_L4surpPC[ii,jj,kk] = accs_L4surpPC[ii,d,kk]
            tensor_accs_H4surpPC[ii,jj,kk] = accs_H4surpPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56imgPC[ii,jj,kk] = accs_L56imgPC[ii,d,kk]
            tensor_accs_H56imgPC[ii,jj,kk] = accs_H56imgPC[ii,d,kk]

            tensor_accs_L56surpPC[ii,jj,kk] = accs_L56surpPC[ii,d,kk]
            tensor_accs_H56surpPC[ii,jj,kk] = accs_H56surpPC[ii,d,kk]

# %%
mean_accs_L4imgPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23imgPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56imgPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4imgPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23imgPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56imgPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_L4surpPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23surpPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56surpPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4surpPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23surpPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56surpPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4imgPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23imgPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56imgPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4imgPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23imgPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56imgPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4surpPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23surpPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56surpPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4surpPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23surpPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56surpPC = np.zeros((len(dims56),len(sub_Eps)))

# %%
for ep in range(len(sub_Eps)):
    
    for dd, dims in enumerate(dims23):
        mean_accs_L23imgPC[dd,ep] = np.mean(tensor_accs_L23imgPC[:,dd,ep])
        mean_accs_H23imgPC[dd,ep] = np.mean(tensor_accs_H23imgPC[:,dd,ep])
        
        std_accs_L23imgPC[dd,ep] = np.var(tensor_accs_L23imgPC[:,dd,ep])
        std_accs_H23imgPC[dd,ep] = np.var(tensor_accs_H23imgPC[:,dd,ep])
        
        mean_accs_L23surpPC[dd,ep] = np.mean(tensor_accs_L23surpPC[:,dd,ep])
        mean_accs_H23surpPC[dd,ep] = np.mean(tensor_accs_H23surpPC[:,dd,ep])
        
        std_accs_L23surpPC[dd,ep] = np.var(tensor_accs_L23surpPC[:,dd,ep])
        std_accs_H23surpPC[dd,ep] = np.var(tensor_accs_H23surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims4):
        mean_accs_L4imgPC[dd,ep] = np.mean(tensor_accs_L4imgPC[:,dd,ep])
        mean_accs_H4imgPC[dd,ep] = np.mean(tensor_accs_H4imgPC[:,dd,ep])
        
        std_accs_L4imgPC[dd,ep] = np.var(tensor_accs_L4imgPC[:,dd,ep])
        std_accs_H4imgPC[dd,ep] = np.var(tensor_accs_H4imgPC[:,dd,ep])
        
        mean_accs_L4surpPC[dd,ep] = np.mean(tensor_accs_L4surpPC[:,dd,ep])
        mean_accs_H4surpPC[dd,ep] = np.mean(tensor_accs_H4surpPC[:,dd,ep])
        
        std_accs_L4surpPC[dd,ep] = np.var(tensor_accs_L4surpPC[:,dd,ep])
        std_accs_H4surpPC[dd,ep] = np.var(tensor_accs_H4surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims56):
        mean_accs_L56imgPC[dd,ep] = np.mean(tensor_accs_L56imgPC[:,dd,ep])        
        mean_accs_H56imgPC[dd,ep] = np.mean(tensor_accs_H56imgPC[:,dd,ep])
        
        std_accs_L56imgPC[dd,ep] = np.var(tensor_accs_L56imgPC[:,dd,ep])
        std_accs_H56imgPC[dd,ep] = np.var(tensor_accs_H56imgPC[:,dd,ep])
        
        mean_accs_L56surpPC[dd,ep] = np.mean(tensor_accs_L56surpPC[:,dd,ep])
        mean_accs_H56surpPC[dd,ep] = np.mean(tensor_accs_H56surpPC[:,dd,ep])
        
        std_accs_L56surpPC[dd,ep] = np.var(tensor_accs_L56surpPC[:,dd,ep])        
        std_accs_H56surpPC[dd,ep] = np.var(tensor_accs_H56surpPC[:,dd,ep])

# %%
ffsurp_dim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Surprise ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,0],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,0],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,0],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,0],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,0],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,0],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(132)
plt.title('Surprise ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,1],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,1],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,1],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,1],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,1],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,1],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(133)
plt.title('Surprise ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,-1],yerr=std_accs_L4surpPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,-1],yerr=std_accs_L23surpPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,-1],yerr=std_accs_L56surpPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,-1],yerr=std_accs_H4surpPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,-1],yerr=std_accs_H23surpPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,-1],yerr=std_accs_H56surpPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
ffdim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Image ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,0],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,0],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,0],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,0],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,0],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,0],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Image ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,1],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,1],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,1],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,1],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,1],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,1],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Image ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,-1],yerr=std_accs_L4imgPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,-1],yerr=std_accs_L23imgPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,-1],yerr=std_accs_L56imgPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,-1],yerr=std_accs_H4imgPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,-1],yerr=std_accs_H23imgPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,-1],yerr=std_accs_H56imgPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# #### Position

# %%
step_labels = np.array([x%nSteps for x in range(nTest*nSteps)])

# %%
def repsDecodeSupervisedPosition(rnnActs,labels,clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    nClasses = 6
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
L4posPC = {}
L23posPC = {}
L56posPC = {}
H4posPC = {}
H23posPC = {}
H56posPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][1][sub_Eps,:,:d],step_labels)
        H23posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][4][sub_Eps,:,:d],step_labels)
    
    for d in dims4:
        L4posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][0][sub_Eps,:,:d],step_labels)
        H4posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][3][sub_Eps,:,:d],step_labels)
        
    for d in dims56:
        ## Position
        L56posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][2][sub_Eps,:,:d],step_labels)      
        H56posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][5][sub_Eps,:,:d],step_labels)
# Out:
# 100%|██████████| 5/5 [00:26<00:00,  5.29s/it]

# %%
preds_L23posPC = {}
preds_L4posPC = {}
preds_L56posPC = {}

preds_H23posPC = {}
preds_H4posPC = {}
preds_H56posPC = {}

# %%
accs_L23posPC = {}
accs_L4posPC = {}
accs_L56posPC = {}

accs_H23posPC = {}
accs_H4posPC = {}
accs_H56posPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(len(sub_Eps)):
        
        for d in dims23:
            preds_L23posPC[cntr,d,ep] = np.argmax(L23posPC[cntr,d][ep],axis=-1)
            preds_H23posPC[cntr,d,ep] = np.argmax(H23posPC[cntr,d][ep],axis=-1)
            
            accs_L23posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L23posPC[cntr,d,ep])
            accs_H23posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H23posPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4posPC[cntr,d,ep] = np.argmax(L4posPC[cntr,d][ep],axis=-1)
            preds_H4posPC[cntr,d,ep] = np.argmax(H4posPC[cntr,d][ep],axis=-1)
            
            accs_L4posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L4posPC[cntr,d,ep])
            accs_H4posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H4posPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56posPC[cntr,d,ep] = np.argmax(L56posPC[cntr,d][ep],axis=-1)
            preds_H56posPC[cntr,d,ep] = np.argmax(H56posPC[cntr,d][ep],axis=-1)
            
            accs_L56posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L56posPC[cntr,d,ep])
            accs_H56posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H56posPC[cntr,d,ep])

# %%
tensor_accs_L23posPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4posPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56posPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23posPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4posPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56posPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

# %%
for ii in range(nRuns):
    
    for kk in range(len(sub_Eps)):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23posPC[ii,jj,kk] = accs_L23posPC[ii,d,kk]
            tensor_accs_H23posPC[ii,jj,kk] = accs_H23posPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4posPC[ii,jj,kk] = accs_L4posPC[ii,d,kk]
            tensor_accs_H4posPC[ii,jj,kk] = accs_H4posPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56posPC[ii,jj,kk] = accs_L56posPC[ii,d,kk]            
            tensor_accs_H56posPC[ii,jj,kk] = accs_H56posPC[ii,d,kk]

# %%
mean_accs_L4posPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23posPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56posPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4posPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23posPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56posPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4posPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23posPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56posPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4posPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23posPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56posPC = np.zeros((len(dims56),len(sub_Eps)))

# %%
for ep in range(len(sub_Eps)):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23posPC[dd,ep] = np.mean(tensor_accs_L23posPC[:,dd,ep])
        mean_accs_H23posPC[dd,ep] = np.mean(tensor_accs_H23posPC[:,dd,ep])
        
        std_accs_L23posPC[dd,ep] = np.var(tensor_accs_L23posPC[:,dd,ep])
        std_accs_H23posPC[dd,ep] = np.var(tensor_accs_H23posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4posPC[dd,ep] = np.mean(tensor_accs_L4posPC[:,dd,ep])
        mean_accs_H4posPC[dd,ep] = np.mean(tensor_accs_H4posPC[:,dd,ep])
        
        std_accs_L4posPC[dd,ep] = np.var(tensor_accs_L4posPC[:,dd,ep])
        std_accs_H4posPC[dd,ep] = np.var(tensor_accs_H4posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56posPC[dd,ep] = np.mean(tensor_accs_L56posPC[:,dd,ep])
        mean_accs_H56posPC[dd,ep] = np.mean(tensor_accs_H56posPC[:,dd,ep])
        
        std_accs_L56posPC[dd,ep] = np.var(tensor_accs_L56posPC[:,dd,ep])
        std_accs_H56posPC[dd,ep] = np.var(tensor_accs_H56posPC[:,dd,ep])

# %%
ffpos = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Position Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,0],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,0],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,0],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,0],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,0],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,0],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Position Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,1],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,1],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,1],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,1],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,1],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,1],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Position Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,-1],yerr=std_accs_L4posPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,-1],yerr=std_accs_L23posPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,-1],yerr=std_accs_L56posPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,-1],yerr=std_accs_H4posPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,-1],yerr=std_accs_H23posPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,-1],yerr=std_accs_H56posPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
np.save(pp+'preds_img_temp_L4-corticalRNN-binary',preds_L4imgPC)
np.save(pp+'preds_img_temp_L23-corticalRNN-binary',preds_L23imgPC)
np.save(pp+'preds_img_temp_L56-corticalRNN-binary',preds_L56imgPC)
np.save(pp+'preds_img_temp_H4-corticalRNN-binary',preds_H4imgPC)
np.save(pp+'preds_img_temp_H23-corticalRNN-binary',preds_H23imgPC)
np.save(pp+'preds_img_temp_H56-corticalRNN-binary',preds_H56imgPC)

np.save(pp+'accs_img_temp_L4-corticalRNN-binary',accs_L4imgPC)
np.save(pp+'accs_img_temp_L23-corticalRNN-binary',accs_L23imgPC)
np.save(pp+'accs_img_temp_L56-corticalRNN-binary',accs_L56imgPC)
np.save(pp+'accs_img_temp_H4-corticalRNN-binary',accs_H4imgPC)
np.save(pp+'accs_img_temp_H23-corticalRNN-binary',accs_H23imgPC)
np.save(pp+'accs_img_temp_H56-corticalRNN-binary',accs_H56imgPC)

# %%
np.save(pp+'preds_pos_temp_L4-corticalRNN-binary',preds_L4posPC)
np.save(pp+'preds_pos_temp_L23-corticalRNN-binary',preds_L23posPC)
np.save(pp+'preds_pos_temp_L56-corticalRNN-binary',preds_L56posPC)
np.save(pp+'preds_pos_temp_H4-corticalRNN-binary',preds_H4posPC)
np.save(pp+'preds_pos_temp_H23-corticalRNN-binary',preds_H23posPC)
np.save(pp+'preds_pos_temp_H56-corticalRNN-binary',preds_H56posPC)

np.save(pp+'accs_pos_temp_L4-corticalRNN-binary',accs_L4posPC)
np.save(pp+'accs_pos_temp_L23-corticalRNN-binary',accs_L23posPC)
np.save(pp+'accs_pos_temp_L56-corticalRNN-binary',accs_L56posPC)
np.save(pp+'accs_pos_temp_H4-corticalRNN-binary',accs_H4posPC)
np.save(pp+'accs_pos_temp_H23-corticalRNN-binary',accs_H23posPC)
np.save(pp+'accs_pos_temp_H56-corticalRNN-binary',accs_H56posPC)

# %%
np.save(pp+'preds_surp_temp_L4-corticalRNN',preds_L4surpPC)
np.save(pp+'preds_surp_temp_L23-corticalRNN',preds_L23surpPC)
np.save(pp+'preds_surp_temp_L56-corticalRNN',preds_L56surpPC)
np.save(pp+'preds_surp_temp_H4-corticalRNN',preds_H4surpPC)
np.save(pp+'preds_surp_temp_H23-corticalRNN',preds_H23surpPC)
np.save(pp+'preds_surp_temp_H56-corticalRNN',preds_H56surpPC)

np.save(pp+'accs_surp_temp_L4-corticalRNN',accs_L4surpPC)
np.save(pp+'accs_surp_temp_L23-corticalRNN',accs_L23surpPC)
np.save(pp+'accs_surp_temp_L56-corticalRNN',accs_L56surpPC)
np.save(pp+'accs_surp_temp_H4-corticalRNN',accs_H4surpPC)
np.save(pp+'accs_surp_temp_H23-corticalRNN',accs_H23surpPC)
np.save(pp+'accs_surp_temp_H56-corticalRNN',accs_H56surpPC)

# %% [markdown]
# #### Temporal accuracies

# %%
preds_train = {}
preds_test = {}
preds_temp = {}

accs_train = np.zeros((nRuns,n_epochs+1))
accs_test = np.zeros((nRuns,n_epochs+1))
accs_temp = np.zeros((nRuns,n_epochs+1))

for cntr in range(nRuns):
    preds_train[cntr] = np.abs(np.round_(out_train[cntr]*(out_train[cntr]>0)))
    preds_test[cntr] = np.abs(np.round_(out_test[cntr]*(out_test[cntr]>0)))
    preds_temp[cntr] = np.abs(np.round_(out_test[cntr]*(out_temp[cntr]>0)))
    
    accs_train[cntr] = np.sum(np.sum(np.sum(((yRepsTrain[cntr] - preds_train[cntr])==0)*1,-1),-1),-1)/np.prod(yRepsTrain[cntr].shape)
    accs_test[cntr] = np.sum(np.sum(np.sum(((yRepsTest[cntr] - preds_test[cntr])==0)*1,-1),-1),-1)/np.prod(yRepsTest[cntr].shape)
    accs_temp[cntr] = np.sum(np.sum(np.sum(((yRepsTestTemp[cntr] - preds_temp[cntr])==0)*1,-1),-1),-1)/np.prod(yRepsTestTemp[cntr].shape)

# %%
ff_final_temp_noise = plt.figure()
# plt.errorbar(np.arange(n_epochs+1),np.mean(accs_train,0),yerr=np.var(accs_train,0),fmt='-',label='Train')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_test,0),yerr=np.var(accs_test,0),fmt='-',label='Test - Clean')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_temp,0),yerr=np.var(accs_temp,0),fmt='-',label='Test - Surprise')
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend()
plt.title('Prediction accuracy in presence of temporal violation')
plt.show()

# %%
np.save(pp+'corticalRNN-no-violations-accs-binary',accs_test)
np.save(pp+'corticalRNN-temporal-violations-accs-binary',accs_temp)

# %%
ff_final_temp_noise.savefig('temporal-violation-final-acc-repeated-runs-corticalRNN-bianry.png',dpi=300,bbox_inches='tight')
ff_final_temp_noise.savefig('temporal-violation-final-acc-repeated-runs-corticalRNN-binary.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# #### Dimensionality (Linear)

# %%
def rnnLinDim(acts):
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    eig_mat = np.zeros((nEpochs,nNeurons))
        
    for ep in tqdm(range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        cov = actsScaled.T@actsScaled
        eig_mat[ep] = eigvals(cov)
        num = np.sum(eig_mat,1)**2
        den = np.sum(eig_mat**2,1) + 1e-17
        PR = num/den
    return PR

# %%
L23LinDim = np.zeros((nRuns,n_epochs+1))
L4LinDim = np.zeros((nRuns,n_epochs+1))
L56LinDim = np.zeros((nRuns,n_epochs+1))

H23LinDim = np.zeros((nRuns,n_epochs+1))
H4LinDim = np.zeros((nRuns,n_epochs+1))
H56LinDim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23LinDim[cntr] = rnnLinDim(L23_test[cntr])
    L4LinDim[cntr] = rnnLinDim(L4_test[cntr])
    L56LinDim[cntr] = rnnLinDim(L56_test[cntr])

    H23LinDim[cntr] = rnnLinDim(H23_test[cntr])
    H4LinDim[cntr] = rnnLinDim(H4_test[cntr])
    H56LinDim[cntr] = rnnLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 97.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 161.52it/s]
# 100%|██████████| 101/101 [00:00<00:00, 115.87it/s]
# 100%|██████████| 101/101 [00:01<00:00, 99.09it/s]
# 100%|██████████| 101/101 [00:00<00:00, 166.29it/s]
# 100%|██████████| 101/101 [00:00<00:00, 120.42it/s]
# 100%|██████████| 101/101 [00:00<00:00, 103.18it/s]
# 100%|██████████| 101/101 [00:00<00:00, 168.78it/s]
# 100%|██████████| 101/101 [00:00<00:00, 120.41it/s]
# 100%|██████████| 101/101 [00:01<00:00, 100.57it/s]
# 100%|██████████| 101/101 [00:00<00:00, 174.91it/s]
# 100%|██████████| 101/101 [00:00<00:00, 119.00it/s]
# 100%|██████████| 101/101 [00:00<00:00, 102.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 171.77it/s]
# 100%|██████████| 101/101 [00:00<00:00, 119.14it/s]
# 100%|██████████| 101/101 [00:00<00:00, 103.55it/s]
# 100%|██████████| 101/101 [00:00<00:00, 175.82it/s]
# 100%|██████████| 101/101 [00:00<00:00, 124.11it/s]
# 100%|██████████| 101/101 [00:01<00:00, 100.17it/s]
# 100%|██████████| 101/101 [00:00<00:00, 171.06it/s]
# 100%|██████████| 101/101 [00:00<00:00, 120.99it/s]
# 100%|██████████| 101/101 [00:00<00:00, 103.13it/s]
# 100%|██████████| 101/101 [00:00<00:00, 177.05it/s]
# 100%|██████████| 101/101 [00:00<00:00, 123.50it/s]
# 100%|██████████| 101/101 [00:01<00:00, 100.56it/s]
# 100%|██████████| 101/101 [00:00<00:00, 175.81it/s]
# 100%|██████████| 101/101 [00:00<00:00, 112.15it/s]
# 100%|██████████| 101/101 [00:01<00:00, 93.16it/s]
# 100%|██████████| 101/101 [00:00<00:00, 161.00it/s]
# 100%|██████████| 101/101 [00:00<00:00, 115.08it/s]

# %% [markdown]
# #### Dimensionality (Non-linear)

# %%
def rnnNonLinDim(acts,nTypes=2,subsample=True,ds=100):
    
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    dims_mat = np.zeros((nEpochs,nTypes))
        
    for ep in (range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        
        if subsample:
            actsScaled = actsScaled[::ds]
        
        dims_mat[ep,0] = MiND_ML().fit(actsScaled).dimension_
#         print(dims_mat[ep,0])
        dims_mat[ep,1] = CorrInt().fit(actsScaled).dimension_
#         print(dims_mat[ep,1])
#         dims_mat[ep,2] = MLE().fit(actsScaled).dimension_
#         print(dims_mat[ep,2])
#         dims_mat[ep,3] = DANCo().fit(actsScaled).dimension_
        
    return np.mean(dims_mat,-1),dims_mat

# %%
L23NonLinDim = np.zeros((nRuns,n_epochs+1))
L4NonLinDim = np.zeros((nRuns,n_epochs+1))
L56NonLinDim = np.zeros((nRuns,n_epochs+1))

H23NonLinDim = np.zeros((nRuns,n_epochs+1))
H4NonLinDim = np.zeros((nRuns,n_epochs+1))
H56NonLinDim = np.zeros((nRuns,n_epochs+1))

# %%
L23_ND_mat = {}
L4_ND_mat = {}
L56_ND_mat = {}
H23_ND_mat = {}
H4_ND_mat = {}
H56_ND_mat = {}

# %%
for cntr in tqdm(range(nRuns)):
    L23NonLinDim[cntr], L23_ND_mat[cntr] = rnnNonLinDim(L23_test[cntr])
    L4NonLinDim[cntr], L4_ND_mat[cntr] = rnnNonLinDim(L4_test[cntr])
    L56NonLinDim[cntr], L56_ND_mat[cntr] = rnnNonLinDim(L56_test[cntr])

    H23NonLinDim[cntr], H23_ND_mat[cntr] = rnnNonLinDim(H23_test[cntr])
    H4NonLinDim[cntr], H4_ND_mat[cntr] = rnnNonLinDim(H4_test[cntr])
    H56NonLinDim[cntr], H56_ND_mat[cntr] = rnnNonLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 5/5 [02:16<00:00, 27.22s/it]

# %%
L23_NonLineDim_mean = np.mean(L23NonLinDim,0)
L4_NonLineDim_mean = np.mean(L4NonLinDim,0)
L56_NonLineDim_mean = np.mean(L56NonLinDim,0)

H23_NonLineDim_mean = np.mean(H23NonLinDim,0)
H4_NonLineDim_mean = np.mean(H4NonLinDim,0)
H56_NonLineDim_mean = np.mean(H56NonLinDim,0)

L23_NonLineDim_std = np.var(L23NonLinDim,0)
L4_NonLineDim_std = np.var(L4NonLinDim,0)
L56_NonLineDim_std = np.var(L56NonLinDim,0)

H23_NonLineDim_std = np.var(H23NonLinDim,0)
H4_NonLineDim_std = np.var(H4NonLinDim,0)
H56_NonLineDim_std = np.var(H56NonLinDim,0)

# %%
L23_dim = np.zeros((nRuns,n_epochs+1))
L4_dim = np.zeros((nRuns,n_epochs+1))
L56_dim = np.zeros((nRuns,n_epochs+1))

H23_dim = np.zeros((nRuns,n_epochs+1))
H4_dim = np.zeros((nRuns,n_epochs+1))
H56_dim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23_dim[cntr] = L23LinDim[cntr]/L23NonLinDim[cntr]
    L4_dim[cntr] = L4LinDim[cntr]/L4NonLinDim[cntr]
    L56_dim[cntr] = L56LinDim[cntr]/L56NonLinDim[cntr]
    H23_dim[cntr] = H23LinDim[cntr]/H23NonLinDim[cntr]
    H4_dim[cntr] = H4LinDim[cntr]/H4NonLinDim[cntr]
    H56_dim[cntr] = H56LinDim[cntr]/H56NonLinDim[cntr]

# %%
np.save(pp+'L23DG_corticalRNN_binary',L23_dim)
np.save(pp+'L4DG_corticalRNN_binary',L4_dim)
np.save(pp+'L56DG_corticalRNN_binary',L56_dim)
np.save(pp+'H23DG_corticalRNN_binary',H23_dim)
np.save(pp+'H4DG_corticalRNN_binary',H4_dim)
np.save(pp+'H56DG_corticalRNN_binary',H56_dim)

# %%
ffTotDim = plt.figure(figsize=(5,5))

plt.subplot(111)

plt.plot(np.arange(n_epochs+1),np.mean(L4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(L4_dim,0)-np.var(L4_dim,0),np.mean(L4_dim,0)+np.var(L4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(L23_dim,0)-np.var(L23_dim,0),np.mean(L23_dim,0)+np.var(L23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(L56_dim,0)-np.var(L56_dim,0),np.mean(L56_dim,0)+np.var(L56_dim,0),alpha=0.5)

plt.plot(np.arange(n_epochs+1),np.mean(H4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(H4_dim,0)-np.var(H4_dim,0),np.mean(H4_dim,0)+np.var(H4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(H23_dim,0)-np.var(H23_dim,0),np.mean(H23_dim,0)+np.var(H23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(H56_dim,0)-np.var(H56_dim,0),np.mean(H56_dim,0)+np.var(H56_dim,0),alpha=0.5)

plt.xlabel('Epochs')
plt.ylabel('Dimensionality Gain')
# plt.ylim(0.9,2.2)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Canonical Microcircuit')
plt.show()

# %%
ffTotDim.savefig('Dimensionality-gain-corticalRNN-across-learning-binary.png',dpi=300,bbox_inches='tight')
ffTotDim.savefig('Dimensionality-gain-corticalRNN-across-learning-binary.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# #### Spatial violations

# %%
dim = 16

# %%
from numpy.random import normal

# %%
noise_stds = np.linspace(0,5,6)

# %%
noiseSeqs = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noiseSeqs[cntr,nn] = repsTest[cntr] + normal(0,noise,repsTest[cntr].shape)

# %%
noisy_loader_analyses = {}

for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noisy_loader_analyses[cntr,nn] = makeTensorLoaders((noiseSeqs[cntr,nn],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)

# %%
L23_noisy = {}
L4_noisy = {}
L56_noisy = {}

H23_noisy = {}
H4_noisy = {}
H56_noisy = {}

out_noisy = {}

# %%
def pass_data_store_noisy_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        for nn in range(len(noise_stds)):
            activations_hidden_L23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_L4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_L56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_hidden_H23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_H4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_H56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_out_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,dim))

            for e in tqdm(range(n_epochs+1)):

                cnt = 0

                ## Load model
                model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr])
                model[cntr].to(device)
                model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
                model[cntr].eval()

                ## Pass clean samples
                for data, f_target, lastEvent, surpriseBinary in loader[cntr,nn]:

                    if train_on_gpu:
                        data, f_targetC = data.float().cuda(), f_target.float().cuda()
                    else: data, f_targetC = data.float(), f_target.float()

                    target = f_target

                    output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                    ## Collect activations  
                    act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                    act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                    act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                    act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                    act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                    act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                    output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                    for i in range(batch_size):
                        if i < len(data):
                            label = target.data[i]

                            activations_hidden_L23_np[cntr,nn][e,cnt] = act_hidden_L23[i]
                            activations_hidden_L4_np[cntr,nn][e,cnt] = act_hidden_L4[i]
                            activations_hidden_L56_np[cntr,nn][e,cnt] = act_hidden_L56[i]

                            activations_hidden_H23_np[cntr,nn][e,cnt] = act_hidden_H23[i]
                            activations_hidden_H4_np[cntr,nn][e,cnt] = act_hidden_H4[i]
                            activations_hidden_H56_np[cntr,nn][e,cnt] = act_hidden_H56[i]

                            activations_out_np[cntr,nn][e,cnt] = output_pred[i]

                            cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
(L23_noisy,L4_noisy,L56_noisy,
 H23_noisy,H4_noisy,H56_noisy,), out_noisy = pass_data_store_noisy_activations(noisy_loader_analyses, nTest)
# Out:
# 100%|██████████| 101/101 [00:19<00:00,  5.26it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.28it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.28it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.28it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.25it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.19it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.97it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.18it/s]
# 100%|██████████| 101/101 [00:20<00:00,  5.03it/s]
# 100%|██████████| 101/101 [00:21<00:00,  4.71it/s]
# 100%|██████████| 101/101 [00:23<00:00,  4.36it/s]
# 100%|██████████| 101/101 [00:20<00:00,  5.02it/s]
# 100%|██████████| 101/101 [00:24<00:00,  4.05it/s]
# 100%|██████████| 101/101 [00:21<00:00,  4.78it/s]
# 100%|██████████| 101/101 [00:24<00:00,  4.16it/s]
# 100%|██████████| 101/101 [00:22<00:00,  4.50it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.95it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.95it/s]
# 100%|██████████| 101/101 [00:25<00:00,  3.92it/s]
# 100%|██████████| 101/101 [00:21<00:00,  4.79it/s]
# 100%|██████████| 101/101 [00:21<00:00,  4.73it/s]
# 100%|██████████| 101/101 [00:21<00:00,  4.75it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.85it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.05it/s]
# 100%|██████████| 101/101 [00:25<00:00,  4.03it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.07it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.09it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.10it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.09it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.94it/s]

# %%
predsN = {}
accsN = np.zeros((nRuns,len(noise_stds),n_epochs+1))

# %%
for cntr in range(nRuns):
    for nn in range(len(noise_stds)):
        predsN[cntr,nn] = np.abs(np.round_(out_noisy[cntr,nn]*(out_noisy[cntr,nn]>0)))
        accsN[cntr,nn] = np.sum(np.sum(np.sum(((yRepsTest[cntr] - predsN[cntr,nn])==0)*1,-1),-1),-1)/np.prod(yRepsTest[cntr].shape)

# %%
name = "Dark2_r"
cmap = get_cmap(name)  # type: matplotlib.colors.ListedColormap
colors = cmap.colors  # type: list

# %%
fpredspat = plt.figure()
for nn, noise in enumerate(noise_stds):
    plt.errorbar(np.arange(n_epochs+1),np.mean(accsN[:,nn],0),yerr=np.var(accsN[:,nn],0),fmt='-',label=np.round(noise,2),
                 c=colors[nn])
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
# plt.ylim(0,1)
plt.legend(title="Noise sigma",bbox_to_anchor=(1,0.5))
plt.title('Prediction accuracy with spatial noise - Canonical Microcircuit')
plt.show()

# %%
np.save(pp+'corticalRNN-spatial-noisy-accs-binary',accsN)
