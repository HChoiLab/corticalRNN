# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

from numpy.random import choice
from numpy.linalg import norm

from math import factorial

from itertools import permutations

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap

from tqdm import tqdm
import os

# %%
from numpy.linalg import svd, eigvals
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, homogeneity_completeness_v_measure, confusion_matrix, ConfusionMatrixDisplay, homogeneity_score

# %%
from skdim.id import *

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import get_cmap

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.style.use('seaborn-whitegrid')
# plt.style.use('default')

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

# %%
from generate_data import generate_binary_rep_data, makeTensorLoaders

# %% [markdown]
# #### Test for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('No GPU, training on CPU')
    device = torch.device('cpu')
else:
    print('GPU found, training on GPU')
    device = torch.device('cuda')
# Out:
# GPU found, training on GPU

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Number of runs

# %%
nRuns = 5

# %% [markdown]
# #### Generate data for runs

# %%
dim = 16
nTot = 5000

fracTrain = 0.8
fracTest = np.round(1-fracTrain,2)

nTrain = int(nTot*fracTrain)
nTest = nTot - nTrain

lenSeq = 4
nRepeats = 2

# %%
numM = 2**dim-1

# %%
repsTrain = {}
yRepsTrain = {}
eTrain = {}
pTrain = {}
surpTrain = {}
allStatesTrain = {}

# %%
repsTest = {}
yRepsTest = {}
eTest = {}
pTest = {}
surpTest = {}
allStatesTest = {}

# %%
repsTestTemp = {}
yRepsTestTemp = {}
eTestTemp = {}
pTestTemp = {}
surpTestTemp = {}
allStatesTestTemp = {}

# %%
labelsTrain = {}
labelsTest = {}
labelsTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]) = generate_binary_rep_data(nTot,fracTrain,dim,lenSeq)

# %%
for cntr in range(nRuns):
    labelsTrain[cntr] = np.repeat(allStatesTrain[cntr][:,:-1],2).reshape(nTrain,-1)
    labelsTest[cntr] = np.repeat(allStatesTest[cntr][:,1:],2).reshape(nTest,-1)
    labelsTestTemp[cntr] = np.repeat(allStatesTestTemp[cntr][:,1:],2).reshape(nTest,-1)

# %% [markdown]
# #### Create directories to save data and representations

# %%
pp = ## specify path

# %%
npp = {}
pp_npy = {}
pp_pts = {}

# %%
for cntr in range(nRuns):
    
    npp[cntr] = 'binary-same-pop-'+str(cntr)+'/'
    pp_npy[cntr] = pp+npp[cntr]+'npys-'+str(cntr)+'/'
    pp_pts[cntr] = pp+npp[cntr]+'pts-'+str(cntr)+'/'

    ## uncomment the following lines to create the folders. comment out if already created
    
    # os.mkdir(os.path.join(pp,npp[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_pts[cntr]))

    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr],'Dataset/'))

# %% [markdown]
# #### Save seeds and dataset

# %%
seeds = np.random.randint(1000, size=nRuns)
np.save(pp_npy[cntr]+'seeds',seeds)

# %%
for cntr in range(nRuns):

    ## Train Data
    np.save(pp_npy[cntr]+'Dataset/repsTrain',repsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTrain',yRepsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTrain',eTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTrain',surpTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTrain',allStatesTrain[cntr])

    ## Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTest',repsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTest',yRepsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTest',eTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTest',surpTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTest',allStatesTest[cntr])
    
    ## Temporally violated Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTestTemp',repsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTestTemp',yRepsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTestTemp',eTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTestTemp',surpTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTestTemp',allStatesTestTemp[cntr])

# %% [markdown]
# #### Load seeds

# %%
seeds = np.load(pp_npy[cntr]+'seeds.npy')

# %% [markdown]
# #### Convert data into tensors, etc.

# %%
batch_size = 100 ##100

# %%
pos_seq_idx = np.array([0,0,1,1,2,2])

# %%
train_loader = {}
test_loader = {}
test_temp_loader = {}

# %%
for cntr in range(nRuns):
    train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=True)
    test_loader[cntr] = makeTensorLoaders((repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)
    test_temp_loader[cntr] = makeTensorLoaders((repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),
                                          batch_size,shuffle=False)

# %%
# kk = 3
# print(np.min(allStatesTestTemp[kk]))
# ix = np.where(allStatesTestTemp[kk]==np.min(allStatesTestTemp[kk]))[0]
# print(repsTestTemp[kk][ix])
# print(yRepsTestTemp[kk][ix])

# %% [markdown]
# #### Load architectures, models, etc.

# %%
n_latent = 16 ## make sure it is the same in the architecture file as well
pop_list = [3,3,3] ## make sure it is the same in the architecture file as well

# %%
from architecture_same_pop import microcircuit

# %%
model = {}
optimizer_rec = {}
optimizer_pc = {}

# %%
#specify loss function
reconLoss = nn.MSELoss()

#optimizer learning rate
eta_rec = 0.001
eta_pc = 0.0001

# %%
for cntr in range(nRuns):
    model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,pop_list=pop_list,bsize=batch_size,
                               manual_seed=seeds[cntr])
    model[cntr].to(device)
    optimizer_rec[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_rec)
    optimizer_pc[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_pc)

# %% [markdown]
# #### Train and collect activations

# %%
for data, f_target, lastEvent, surpriseBinary in train_loader[0]:
    if train_on_gpu:
        data, f_target = data.float().cuda(), f_target.float().cuda()
    else: data, f_target = data.float(), f_target.float()

# %%
output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[0](data)

# %%
nSteps = data.shape[1]

# %%
n_epochs = 100 ## number of epochs
div = n_epochs//n_epochs ## try ensuring that number used to divide by is a factor of n_epochs

# %%
feedback = True

# %%
def findMSE(output):
    errSq = output**2
    MSE_mat_samples_seq = errSq/np.prod(errSq.shape)
    MSE_samples = torch.mean(MSE_mat_samples_seq,1)
    return MSE_samples

# %%
train_losses = {}
test_losses = {}
temp_losses = {}

train_expected_rec_losses = {}
train_expected_fb_losses = {}

test_expected_rec_losses = {}
test_expected_fb_losses = {}

test_surprise_rec_losses = {}
test_surprise_fb_losses = {}

MSE_mat_full_test = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    train_losses[cntr] = np.zeros(n_epochs+1)
    test_losses[cntr] = np.zeros(n_epochs+1)
    temp_losses[cntr] = np.zeros(n_epochs+1)

    train_loss_min = np.Inf
    best_epoch = 0

    train_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    train_expected_fb_losses[cntr] = np.zeros(n_epochs+1)

    test_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_fb_losses[cntr] = np.zeros(n_epochs+1)
    
    test_surprise_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_surprise_fb_losses[cntr] = np.zeros(n_epochs+1)

    MSE_mat_full_test[cntr] = np.zeros(n_epochs+1)

    for epoch in (range(1,n_epochs+1)):

        train_loss = 0.0

        train_expected_rec_loss = 0.0
        train_expected_fb_loss = 0.0
        
        test_expected_rec_loss = 0.0
        test_expected_fb_loss = 0.0

        temp_rec_loss = 0.0
        temp_fb_loss = 0.0
        
        test_loss = 0.0
        temp_loss = 0.0

        cnt = 0
        
        ## Save model without training
        if epoch == 1:
            
            model[cntr].eval()
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_0.pt') ## Save model before any training
            
            ## Losses at 0th epoch
            for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
                if train_on_gpu:
                    data, f_target = data.float().cuda(), f_target.float().cuda()
                else:
                    data, f_target = data.float(), f_target.float()

                ##define all-sequence targets
                target = f_target

                optimizer_rec[cntr].zero_grad() #clears older gradients
                optimizer_pc[cntr].zero_grad() #clears older gradients
                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

                err_rec = torch.linalg.norm((output_pred-target),dim=2)
                err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
                MSE_samples_rec = findMSE(err_rec)
                MSE_samples_fb = findMSE(err_fb)

                loss = reconLoss(output_pred,target) #calculate the loss for the batch
                train_loss += loss.item()*data.size(0) #update training loss

                train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
                train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
                                    
            ## calculate average loss
            train_loss = train_loss/len(train_loader[cntr].dataset)
            
            ## Training loss at initialization
            train_losses[cntr][0] = train_loss
            train_expected_rec_losses[cntr][0] = train_expected_rec_loss
            train_expected_fb_losses[cntr][0] = train_expected_fb_loss
            
            ## Test losses at initialization
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test

                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)
                
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                # calculate the batch loss
                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
#             print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][0] = test_loss

            test_expected_rec_losses[cntr][0] = test_expected_rec_loss
            test_expected_fb_losses[cntr][0] = test_expected_fb_loss
        
        ## Test temp losses at initialization
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                    
                ##define all-sequence targets
                target_temp = f_target_temp

                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)
                loss_temp = reconLoss(output_pred_temp,target_temp)
                err_temp_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                # calculate the batch loss
                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_temp.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
#             print('Temp Loss: {:.6f}\n'.format(test_loss))

            temp_losses[cntr][0] = temp_loss

            test_surprise_rec_losses[cntr][0] = temp_rec_loss
            test_surprise_fb_losses[cntr][0] = temp_fb_loss

        #train model
        model[cntr].train()
        for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
            if train_on_gpu:
                data, f_target = data.float().cuda(), f_target.float().cuda()
            else:
                data, f_target = data.float(), f_target.float()

            ##define all-sequence targets
            target = f_target

            output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

            err_rec = torch.linalg.norm((output_pred-target),dim=2)
            err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
            MSE_samples_rec = findMSE(err_rec)
            MSE_samples_fb = findMSE(err_fb)
            
            loss = reconLoss(output_pred,target) #calculate the loss for the batch
            train_loss += loss.item()*data.size(0) #update training loss
            fbloss = torch.mean(MSE_samples_fb)

            optimizer_rec[cntr].zero_grad() #clears older gradients
            optimizer_pc[cntr].zero_grad() #clears older gradients
            ######## feedback error updates only higher-cortical area
            if (feedback)&(epoch%2==0):
                for name, param in model[cntr].named_parameters():
                    if ('FF' in name) or ('L23' in name) or ('L4' in name) or ('L56' in name):
                        param.require_grad = False
                fbloss.backward()
                optimizer_pc[cntr].step()
                for name, param in model[cntr].named_parameters():
                    param.require_grad = True
            else:
                loss.backward() #backprop
                optimizer_rec[cntr].step() #update parameters in direction of the -ve gradient  

            train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
            train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
        
        #calculate average loss
        train_loss = train_loss/len(train_loader[cntr].dataset)

        #training/validation stats
        train_losses[cntr][epoch] = train_loss
        train_expected_rec_losses[cntr][epoch] = train_expected_rec_loss
        train_expected_fb_losses[cntr][epoch] = train_expected_fb_loss

        #save model if the training loss decreased
        if train_loss <= train_loss_min:
            print('Epoch: {}, Train Loss Decreased!! ({:.6f}-->{:.6f})'.format(epoch,train_loss_min,train_loss))
            torch.save(model[cntr].state_dict(),pp_pts[cntr]+'predRNN.pt')
            train_loss_min = train_loss
            best_epoch = epoch

        if epoch%div == 0:
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_'+str(epoch)+'.pt')
            
            model[cntr].eval()
            
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test
                
                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)

                # calculate the batch loss
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
            print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][epoch] = test_loss

            test_expected_rec_losses[cntr][epoch] = test_expected_rec_loss
            test_expected_fb_losses[cntr][epoch] = test_expected_fb_loss
            
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                
                ##define all-sequence targets
                target_temp = f_target_temp
                
                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)

                # calculate the batch loss
                err_temp_rec = torch.linalg.norm((output_pred_temp-target_temp),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_temp[0],dim=2)+torch.linalg.norm(feedbackDiffs_temp[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_test.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
            print('Temp Loss: {:.6f}\n'.format(temp_loss))

            temp_losses[cntr][epoch] = temp_loss

            test_surprise_rec_losses[cntr][epoch] = temp_rec_loss
            test_surprise_fb_losses[cntr][epoch] = temp_fb_loss
            
    print('----------------------------------------------------')
            
    outF = open(pp+npp[cntr]+"training-details.txt", "w")
    outF.write('# epochs = ' + str(n_epochs))
    outF.write('\n')
    outF.write('Best epoch = '+str(best_epoch))
    outF.write('\n')
    outF.write('Minimum training loss = ' + str(train_loss_min))
    outF.write('\n')
    outF.write('Total number of samples = ' + str(nTot))
    outF.write('\n')
    outF.write('Number of training samples = ' + str(nTrain))
    outF.write('\n')
    outF.write('Number of testing samples = ' + str(nTest))
    outF.write('\n')
    outF.write('Dimensionality of representations = ' + str(dim))
    outF.write('\n')
    outF.write('Length of sequences = ' + str(lenSeq))
    outF.write('\n')
    outF.close()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1, Train Loss Decreased!! (inf-->0.296140)
# Test Loss: 0.252805
#
# Temp Loss: 0.252460
#
# Epoch: 2, Train Loss Decreased!! (0.296140-->0.251857)
# Test Loss: 0.252362
#
# Temp Loss: 0.252152
#
# Epoch: 3, Train Loss Decreased!! (0.251857-->0.250247)
# Test Loss: 0.244718
#
# Temp Loss: 0.245190
#
# Epoch: 4, Train Loss Decreased!! (0.250247-->0.245220)
# Test Loss: 0.245214
#
# Temp Loss: 0.245481
#
# Epoch: 5, Train Loss Decreased!! (0.245220-->0.236566)
# Test Loss: 0.228003
#
# Temp Loss: 0.228266
#
# Epoch: 6, Train Loss Decreased!! (0.236566-->0.228384)
# Test Loss: 0.227650
#
# Temp Loss: 0.227694
#
# Epoch: 7, Train Loss Decreased!! (0.228384-->0.222617)
# Test Loss: 0.213377
#
# Temp Loss: 0.216348
#
# Epoch: 8, Train Loss Decreased!! (0.222617-->0.214540)
# Test Loss: 0.214483
#
# Temp Loss: 0.217549
#
# Epoch: 9, Train Loss Decreased!! (0.214540-->0.206127)
# Test Loss: 0.198200
#
# Temp Loss: 0.219564
#
# Epoch: 10, Train Loss Decreased!! (0.206127-->0.198483)
# Test Loss: 0.199083
#
# Temp Loss: 0.219950
#
# Epoch: 11, Train Loss Decreased!! (0.198483-->0.191061)
# Test Loss: 0.182321
#
# Temp Loss: 0.212771
#
# Epoch: 12, Train Loss Decreased!! (0.191061-->0.185211)
# Test Loss: 0.187656
#
# Temp Loss: 0.218024
#
# Epoch: 13, Train Loss Decreased!! (0.185211-->0.178005)
# Test Loss: 0.170008
#
# Temp Loss: 0.201243
#
# Epoch: 14, Train Loss Decreased!! (0.178005-->0.171661)
# Test Loss: 0.174091
#
# Temp Loss: 0.204604
#
# Epoch: 15, Train Loss Decreased!! (0.171661-->0.166405)
# Test Loss: 0.160003
#
# Temp Loss: 0.191408
#
# Epoch: 16, Train Loss Decreased!! (0.166405-->0.160883)
# Test Loss: 0.163789
#
# Temp Loss: 0.194687
#
# Epoch: 17, Train Loss Decreased!! (0.160883-->0.156461)
# Test Loss: 0.152699
#
# Temp Loss: 0.185122
#
# Epoch: 18, Train Loss Decreased!! (0.156461-->0.153344)
# Test Loss: 0.156125
#
# Temp Loss: 0.187953
#
# Epoch: 19, Train Loss Decreased!! (0.153344-->0.149320)
# Test Loss: 0.143876
#
# Temp Loss: 0.178442
#
# Epoch: 20, Train Loss Decreased!! (0.149320-->0.144440)
# Test Loss: 0.146638
#
# Temp Loss: 0.180737
#
# Epoch: 21, Train Loss Decreased!! (0.144440-->0.135943)
# Test Loss: 0.127477
#
# Temp Loss: 0.160253
#
# Epoch: 22, Train Loss Decreased!! (0.135943-->0.130094)
# Test Loss: 0.132799
#
# Temp Loss: 0.164762
#
# Epoch: 23, Train Loss Decreased!! (0.130094-->0.126005)
# Test Loss: 0.121841
#
# Temp Loss: 0.154262
#
# Epoch: 24, Train Loss Decreased!! (0.126005-->0.124243)
# Test Loss: 0.127127
#
# Temp Loss: 0.158369
#
# Epoch: 25, Train Loss Decreased!! (0.124243-->0.121537)
# Test Loss: 0.117939
#
# Temp Loss: 0.151578
#
# Epoch: 26, Train Loss Decreased!! (0.121537-->0.120004)
# Test Loss: 0.122976
#
# Temp Loss: 0.154839
#
# Epoch: 27, Train Loss Decreased!! (0.120004-->0.116572)
# Test Loss: 0.112719
#
# Temp Loss: 0.151927
#
# Epoch: 28, Train Loss Decreased!! (0.116572-->0.114591)
# Test Loss: 0.117935
#
# Temp Loss: 0.155323
#
# Epoch: 29, Train Loss Decreased!! (0.114591-->0.110231)
# Test Loss: 0.104765
#
# Temp Loss: 0.144373
#
# Epoch: 30, Train Loss Decreased!! (0.110231-->0.107301)
# Test Loss: 0.112919
#
# Temp Loss: 0.148974
#
# Epoch: 31, Train Loss Decreased!! (0.107301-->0.098638)
# Test Loss: 0.090822
#
# Temp Loss: 0.129422
#
# Epoch: 32, Train Loss Decreased!! (0.098638-->0.093509)
# Test Loss: 0.099330
#
# Temp Loss: 0.135718
#
# Epoch: 33, Train Loss Decreased!! (0.093509-->0.086705)
# Test Loss: 0.080778
#
# Temp Loss: 0.117170
#
# Epoch: 34, Train Loss Decreased!! (0.086705-->0.083194)
# Test Loss: 0.088973
#
# Temp Loss: 0.124591
#
# Epoch: 35, Train Loss Decreased!! (0.083194-->0.078545)
# Test Loss: 0.075031
#
# Temp Loss: 0.111665
#
# Epoch: 36, Train Loss Decreased!! (0.078545-->0.076870)
# Test Loss: 0.081482
#
# Temp Loss: 0.117481
#
# Epoch: 37, Train Loss Decreased!! (0.076870-->0.073740)
# Test Loss: 0.071767
#
# Temp Loss: 0.109588
#
# Epoch: 38, Train Loss Decreased!! (0.073740-->0.073393)
# Test Loss: 0.078459
#
# Temp Loss: 0.115132
#
# Epoch: 39, Train Loss Decreased!! (0.073393-->0.071144)
# Test Loss: 0.069156
#
# Temp Loss: 0.108283
#
# Test Loss: 0.078625
#
# Temp Loss: 0.116237
#
# Epoch: 41, Train Loss Decreased!! (0.071144-->0.069060)
# Test Loss: 0.067359
#
# Temp Loss: 0.108016
#
# Test Loss: 0.078113
#
# Temp Loss: 0.117171
#
# Epoch: 43, Train Loss Decreased!! (0.069060-->0.067556)
# Test Loss: 0.066338
#
# Temp Loss: 0.108024
#
# Test Loss: 0.077298
#
# Temp Loss: 0.116477
#
# Epoch: 45, Train Loss Decreased!! (0.067556-->0.066706)
# Test Loss: 0.064836
#
# Temp Loss: 0.106278
#
# Test Loss: 0.075224
#
# Temp Loss: 0.114699
#
# Epoch: 47, Train Loss Decreased!! (0.066706-->0.064870)
# Test Loss: 0.063139
#
# Temp Loss: 0.105016
#
# Test Loss: 0.071947
#
# Temp Loss: 0.112339
#
# Epoch: 49, Train Loss Decreased!! (0.064870-->0.062435)
# Test Loss: 0.060403
#
# Temp Loss: 0.104438
#
# Test Loss: 0.069023
#
# Temp Loss: 0.111682
#
# Epoch: 51, Train Loss Decreased!! (0.062435-->0.059207)
# Test Loss: 0.055517
#
# Temp Loss: 0.101397
#
# Epoch: 52, Train Loss Decreased!! (0.059207-->0.058312)
# Test Loss: 0.065251
#
# Temp Loss: 0.109422
#
# Epoch: 53, Train Loss Decreased!! (0.058312-->0.053265)
# Test Loss: 0.049789
#
# Temp Loss: 0.096352
#
# Epoch: 54, Train Loss Decreased!! (0.053265-->0.052202)
# Test Loss: 0.059025
#
# Temp Loss: 0.104244
#
# Epoch: 55, Train Loss Decreased!! (0.052202-->0.048670)
# Test Loss: 0.045541
#
# Temp Loss: 0.093950
#
# Test Loss: 0.056447
#
# Temp Loss: 0.102762
#
# Epoch: 57, Train Loss Decreased!! (0.048670-->0.045550)
# Test Loss: 0.043001
#
# Temp Loss: 0.090337
#
# Test Loss: 0.053176
#
# Temp Loss: 0.098668
#
# Epoch: 59, Train Loss Decreased!! (0.045550-->0.043010)
# Test Loss: 0.040576
#
# Temp Loss: 0.088643
#
# Test Loss: 0.051044
#
# Temp Loss: 0.097196
#
# Epoch: 61, Train Loss Decreased!! (0.043010-->0.040610)
# Test Loss: 0.037755
#
# Temp Loss: 0.087801
#
# Test Loss: 0.048343
#
# Temp Loss: 0.095969
#
# Epoch: 63, Train Loss Decreased!! (0.040610-->0.038309)
# Test Loss: 0.035902
#
# Temp Loss: 0.088739
#
# Test Loss: 0.045085
#
# Temp Loss: 0.095179
#
# Epoch: 65, Train Loss Decreased!! (0.038309-->0.036512)
# Test Loss: 0.034864
#
# Temp Loss: 0.089244
#
# Test Loss: 0.042669
#
# Temp Loss: 0.093681
#
# Epoch: 67, Train Loss Decreased!! (0.036512-->0.035181)
# Test Loss: 0.033959
#
# Temp Loss: 0.089004
#
# Test Loss: 0.042250
#
# Temp Loss: 0.093660
#
# Epoch: 69, Train Loss Decreased!! (0.035181-->0.034409)
# Test Loss: 0.033069
#
# Temp Loss: 0.088920
#
# Test Loss: 0.041126
#
# Temp Loss: 0.093470
#
# Epoch: 71, Train Loss Decreased!! (0.034409-->0.033826)
# Test Loss: 0.032208
#
# Temp Loss: 0.088284
#
# Test Loss: 0.041092
#
# Temp Loss: 0.092907
#
# Epoch: 73, Train Loss Decreased!! (0.033826-->0.033160)
# Test Loss: 0.031674
#
# Temp Loss: 0.088013
#
# Test Loss: 0.040194
#
# Temp Loss: 0.091962
#
# Epoch: 75, Train Loss Decreased!! (0.033160-->0.032419)
# Test Loss: 0.031170
#
# Temp Loss: 0.087224
#
# Test Loss: 0.040490
#
# Temp Loss: 0.091330
#
# Epoch: 77, Train Loss Decreased!! (0.032419-->0.031823)
# Test Loss: 0.030133
#
# Temp Loss: 0.086960
#
# Test Loss: 0.041421
#
# Temp Loss: 0.092212
#
# Epoch: 79, Train Loss Decreased!! (0.031823-->0.031088)
# Test Loss: 0.028936
#
# Temp Loss: 0.086189
#
# Test Loss: 0.040974
#
# Temp Loss: 0.091826
#
# Epoch: 81, Train Loss Decreased!! (0.031088-->0.029896)
# Test Loss: 0.027165
#
# Temp Loss: 0.084015
#
# Test Loss: 0.041588
#
# Temp Loss: 0.091713
#
# Epoch: 83, Train Loss Decreased!! (0.029896-->0.027537)
# Test Loss: 0.024061
#
# Temp Loss: 0.084036
#
# Test Loss: 0.041781
#
# Temp Loss: 0.095551
#
# Epoch: 85, Train Loss Decreased!! (0.027537-->0.025111)
# Test Loss: 0.021531
#
# Temp Loss: 0.081779
#
# Test Loss: 0.037514
#
# Temp Loss: 0.092556
#
# Epoch: 87, Train Loss Decreased!! (0.025111-->0.022556)
# Test Loss: 0.019315
#
# Temp Loss: 0.081824
#
# Test Loss: 0.036236
#
# Temp Loss: 0.093921
#
# Epoch: 89, Train Loss Decreased!! (0.022556-->0.021216)
# Test Loss: 0.018111
#
# Temp Loss: 0.080983
#
# Test Loss: 0.032868
#
# Temp Loss: 0.090824
#
# Epoch: 91, Train Loss Decreased!! (0.021216-->0.019919)
# Test Loss: 0.017650
#
# Temp Loss: 0.080822
#
# Test Loss: 0.031177
#
# Temp Loss: 0.090140
#
# Epoch: 93, Train Loss Decreased!! (0.019919-->0.019082)
# Test Loss: 0.016453
#
# Temp Loss: 0.080837
#
# Test Loss: 0.030685
#
# Temp Loss: 0.090169
#
# Epoch: 95, Train Loss Decreased!! (0.019082-->0.018467)
# Test Loss: 0.016008
#
# Temp Loss: 0.080504
#
# Test Loss: 0.028657
#
# Temp Loss: 0.088613
#
# Epoch: 97, Train Loss Decreased!! (0.018467-->0.017669)
# Test Loss: 0.015483
#
# Temp Loss: 0.080477
#
# Test Loss: 0.028138
#
# Temp Loss: 0.088630
#
# Epoch: 99, Train Loss Decreased!! (0.017669-->0.017024)
# Test Loss: 0.014853
#
# Temp Loss: 0.080762
#  20%|██        | 1/5 [01:57<07:49, 117.34s/it]
# Test Loss: 0.027595
#
# Temp Loss: 0.089016
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.306983)
# Test Loss: 0.253568
#
# Temp Loss: 0.253303
#
# Epoch: 2, Train Loss Decreased!! (0.306983-->0.252916)
# Test Loss: 0.252662
#
# Temp Loss: 0.252605
#
# Epoch: 3, Train Loss Decreased!! (0.252916-->0.251579)
# Test Loss: 0.250224
#
# Temp Loss: 0.250274
#
# Epoch: 4, Train Loss Decreased!! (0.251579-->0.250304)
# Test Loss: 0.250871
#
# Temp Loss: 0.250718
#
# Epoch: 5, Train Loss Decreased!! (0.250304-->0.244050)
# Test Loss: 0.238655
#
# Temp Loss: 0.239985
#
# Epoch: 6, Train Loss Decreased!! (0.244050-->0.238478)
# Test Loss: 0.240630
#
# Temp Loss: 0.241610
#
# Epoch: 7, Train Loss Decreased!! (0.238478-->0.229198)
# Test Loss: 0.216538
#
# Temp Loss: 0.223116
#
# Epoch: 8, Train Loss Decreased!! (0.229198-->0.216872)
# Test Loss: 0.219076
#
# Temp Loss: 0.225850
#
# Epoch: 9, Train Loss Decreased!! (0.216872-->0.206130)
# Test Loss: 0.197009
#
# Temp Loss: 0.220370
#
# Epoch: 10, Train Loss Decreased!! (0.206130-->0.196893)
# Test Loss: 0.198969
#
# Temp Loss: 0.221530
#
# Epoch: 11, Train Loss Decreased!! (0.196893-->0.187910)
# Test Loss: 0.182758
#
# Temp Loss: 0.212732
#
# Epoch: 12, Train Loss Decreased!! (0.187910-->0.181585)
# Test Loss: 0.185496
#
# Temp Loss: 0.213927
#
# Epoch: 13, Train Loss Decreased!! (0.181585-->0.175838)
# Test Loss: 0.172661
#
# Temp Loss: 0.205856
#
# Epoch: 14, Train Loss Decreased!! (0.175838-->0.174487)
# Test Loss: 0.182839
#
# Temp Loss: 0.212463
#
# Epoch: 15, Train Loss Decreased!! (0.174487-->0.168577)
# Test Loss: 0.163873
#
# Temp Loss: 0.195255
#
# Epoch: 16, Train Loss Decreased!! (0.168577-->0.163627)
# Test Loss: 0.170424
#
# Temp Loss: 0.199869
#
# Epoch: 17, Train Loss Decreased!! (0.163627-->0.157047)
# Test Loss: 0.154003
#
# Temp Loss: 0.186056
#
# Epoch: 18, Train Loss Decreased!! (0.157047-->0.154720)
# Test Loss: 0.161879
#
# Temp Loss: 0.192303
#
# Epoch: 19, Train Loss Decreased!! (0.154720-->0.148926)
# Test Loss: 0.144313
#
# Temp Loss: 0.177434
#
# Epoch: 20, Train Loss Decreased!! (0.148926-->0.145282)
# Test Loss: 0.154195
#
# Temp Loss: 0.184522
#
# Epoch: 21, Train Loss Decreased!! (0.145282-->0.138490)
# Test Loss: 0.134950
#
# Temp Loss: 0.170674
#
# Epoch: 22, Train Loss Decreased!! (0.138490-->0.135946)
# Test Loss: 0.145365
#
# Temp Loss: 0.178210
#
# Epoch: 23, Train Loss Decreased!! (0.135946-->0.129751)
# Test Loss: 0.125854
#
# Temp Loss: 0.161344
#
# Epoch: 24, Train Loss Decreased!! (0.129751-->0.127479)
# Test Loss: 0.135598
#
# Temp Loss: 0.168569
#
# Epoch: 25, Train Loss Decreased!! (0.127479-->0.121878)
# Test Loss: 0.117374
#
# Temp Loss: 0.151152
#
# Epoch: 26, Train Loss Decreased!! (0.121878-->0.118425)
# Test Loss: 0.125995
#
# Temp Loss: 0.157983
#
# Epoch: 27, Train Loss Decreased!! (0.118425-->0.111380)
# Test Loss: 0.107833
#
# Temp Loss: 0.142298
#
# Epoch: 28, Train Loss Decreased!! (0.111380-->0.110121)
# Test Loss: 0.118594
#
# Temp Loss: 0.150811
#
# Epoch: 29, Train Loss Decreased!! (0.110121-->0.106349)
# Test Loss: 0.104232
#
# Temp Loss: 0.140530
#
# Epoch: 30, Train Loss Decreased!! (0.106349-->0.105663)
# Test Loss: 0.113536
#
# Temp Loss: 0.147364
#
# Epoch: 31, Train Loss Decreased!! (0.105663-->0.102359)
# Test Loss: 0.100420
#
# Temp Loss: 0.139195
#
# Epoch: 32, Train Loss Decreased!! (0.102359-->0.101464)
# Test Loss: 0.109916
#
# Temp Loss: 0.145205
#
# Epoch: 33, Train Loss Decreased!! (0.101464-->0.097484)
# Test Loss: 0.094051
#
# Temp Loss: 0.135016
#
# Epoch: 34, Train Loss Decreased!! (0.097484-->0.097011)
# Test Loss: 0.106822
#
# Temp Loss: 0.142584
#
# Epoch: 35, Train Loss Decreased!! (0.097011-->0.090438)
# Test Loss: 0.085179
#
# Temp Loss: 0.128017
#
# Epoch: 36, Train Loss Decreased!! (0.090438-->0.090340)
# Test Loss: 0.101225
#
# Temp Loss: 0.138207
#
# Epoch: 37, Train Loss Decreased!! (0.090340-->0.083318)
# Test Loss: 0.077765
#
# Temp Loss: 0.117780
#
# Test Loss: 0.095385
#
# Temp Loss: 0.131420
#
# Epoch: 39, Train Loss Decreased!! (0.083318-->0.077052)
# Test Loss: 0.072124
#
# Temp Loss: 0.111506
#
# Epoch: 40, Train Loss Decreased!! (0.077052-->0.076741)
# Test Loss: 0.086551
#
# Temp Loss: 0.123125
#
# Epoch: 41, Train Loss Decreased!! (0.076741-->0.071480)
# Test Loss: 0.068434
#
# Temp Loss: 0.108897
#
# Test Loss: 0.080631
#
# Temp Loss: 0.118951
#
# Epoch: 43, Train Loss Decreased!! (0.071480-->0.068314)
# Test Loss: 0.066030
#
# Temp Loss: 0.108792
#
# Test Loss: 0.077009
#
# Temp Loss: 0.117302
#
# Epoch: 45, Train Loss Decreased!! (0.068314-->0.066038)
# Test Loss: 0.063274
#
# Temp Loss: 0.107367
#
# Test Loss: 0.074426
#
# Temp Loss: 0.116146
#
# Epoch: 47, Train Loss Decreased!! (0.066038-->0.062726)
# Test Loss: 0.058280
#
# Temp Loss: 0.103489
#
# Epoch: 48, Train Loss Decreased!! (0.062726-->0.062702)
# Test Loss: 0.072267
#
# Temp Loss: 0.115033
#
# Epoch: 49, Train Loss Decreased!! (0.062702-->0.056966)
# Test Loss: 0.052773
#
# Temp Loss: 0.100125
#
# Test Loss: 0.066870
#
# Temp Loss: 0.112203
#
# Epoch: 51, Train Loss Decreased!! (0.056966-->0.051715)
# Test Loss: 0.047299
#
# Temp Loss: 0.097581
#
# Epoch: 52, Train Loss Decreased!! (0.051715-->0.051149)
# Test Loss: 0.059906
#
# Temp Loss: 0.108806
#
# Epoch: 53, Train Loss Decreased!! (0.051149-->0.046313)
# Test Loss: 0.042588
#
# Temp Loss: 0.093612
#
# Test Loss: 0.055620
#
# Temp Loss: 0.106723
#
# Epoch: 55, Train Loss Decreased!! (0.046313-->0.042029)
# Test Loss: 0.038550
#
# Temp Loss: 0.093010
#
# Test Loss: 0.050788
#
# Temp Loss: 0.104663
#
# Epoch: 57, Train Loss Decreased!! (0.042029-->0.038532)
# Test Loss: 0.035647
#
# Temp Loss: 0.092993
#
# Test Loss: 0.046861
#
# Temp Loss: 0.102823
#
# Epoch: 59, Train Loss Decreased!! (0.038532-->0.035851)
# Test Loss: 0.032922
#
# Temp Loss: 0.091154
#
# Test Loss: 0.044547
#
# Temp Loss: 0.101438
#
# Epoch: 61, Train Loss Decreased!! (0.035851-->0.033996)
# Test Loss: 0.031194
#
# Temp Loss: 0.090817
#
# Test Loss: 0.042759
#
# Temp Loss: 0.100637
#
# Epoch: 63, Train Loss Decreased!! (0.033996-->0.032110)
# Test Loss: 0.029464
#
# Temp Loss: 0.090417
#
# Test Loss: 0.043409
#
# Temp Loss: 0.102600
#
# Epoch: 65, Train Loss Decreased!! (0.032110-->0.030439)
# Test Loss: 0.027225
#
# Temp Loss: 0.088806
#
# Test Loss: 0.041461
#
# Temp Loss: 0.099151
#
# Epoch: 67, Train Loss Decreased!! (0.030439-->0.028133)
# Test Loss: 0.024789
#
# Temp Loss: 0.086363
#
# Test Loss: 0.041458
#
# Temp Loss: 0.098670
#
# Epoch: 69, Train Loss Decreased!! (0.028133-->0.026217)
# Test Loss: 0.022334
#
# Temp Loss: 0.085054
#
# Test Loss: 0.040999
#
# Temp Loss: 0.098677
#
# Epoch: 71, Train Loss Decreased!! (0.026217-->0.024085)
# Test Loss: 0.020041
#
# Temp Loss: 0.085185
#
# Test Loss: 0.040472
#
# Temp Loss: 0.099168
#
# Epoch: 73, Train Loss Decreased!! (0.024085-->0.022155)
# Test Loss: 0.018489
#
# Temp Loss: 0.084421
#
# Test Loss: 0.038292
#
# Temp Loss: 0.098148
#
# Epoch: 75, Train Loss Decreased!! (0.022155-->0.020895)
# Test Loss: 0.017053
#
# Temp Loss: 0.085198
#
# Test Loss: 0.036977
#
# Temp Loss: 0.097990
#
# Epoch: 77, Train Loss Decreased!! (0.020895-->0.019102)
# Test Loss: 0.015066
#
# Temp Loss: 0.085418
#
# Test Loss: 0.035488
#
# Temp Loss: 0.097789
#
# Epoch: 79, Train Loss Decreased!! (0.019102-->0.017308)
# Test Loss: 0.013702
#
# Temp Loss: 0.085297
#
# Test Loss: 0.032569
#
# Temp Loss: 0.096922
#
# Epoch: 81, Train Loss Decreased!! (0.017308-->0.015825)
# Test Loss: 0.012129
#
# Temp Loss: 0.084713
#
# Test Loss: 0.030230
#
# Temp Loss: 0.095915
#
# Epoch: 83, Train Loss Decreased!! (0.015825-->0.013876)
# Test Loss: 0.010721
#
# Temp Loss: 0.084388
#
# Test Loss: 0.028204
#
# Temp Loss: 0.094816
#
# Epoch: 85, Train Loss Decreased!! (0.013876-->0.012742)
# Test Loss: 0.009605
#
# Temp Loss: 0.085122
#
# Test Loss: 0.026226
#
# Temp Loss: 0.094155
#
# Epoch: 87, Train Loss Decreased!! (0.012742-->0.011795)
# Test Loss: 0.008852
#
# Temp Loss: 0.085202
#
# Test Loss: 0.025662
#
# Temp Loss: 0.094472
#
# Epoch: 89, Train Loss Decreased!! (0.011795-->0.011052)
# Test Loss: 0.008331
#
# Temp Loss: 0.085735
#
# Test Loss: 0.023837
#
# Temp Loss: 0.093270
#
# Epoch: 91, Train Loss Decreased!! (0.011052-->0.010475)
# Test Loss: 0.008002
#
# Temp Loss: 0.086507
#
# Test Loss: 0.023748
#
# Temp Loss: 0.094175
#
# Epoch: 93, Train Loss Decreased!! (0.010475-->0.009924)
# Test Loss: 0.007487
#
# Temp Loss: 0.086384
#
# Test Loss: 0.023542
#
# Temp Loss: 0.093725
#
# Epoch: 95, Train Loss Decreased!! (0.009924-->0.009724)
# Test Loss: 0.007256
#
# Temp Loss: 0.086768
#
# Test Loss: 0.022444
#
# Temp Loss: 0.093080
#
# Epoch: 97, Train Loss Decreased!! (0.009724-->0.009411)
# Test Loss: 0.007054
#
# Temp Loss: 0.086877
#
# Test Loss: 0.021807
#
# Temp Loss: 0.093010
#
# Epoch: 99, Train Loss Decreased!! (0.009411-->0.008923)
# Test Loss: 0.006651
#
# Temp Loss: 0.086478
#  40%|████      | 2/5 [03:50<05:44, 114.73s/it]
# Test Loss: 0.022443
#
# Temp Loss: 0.093540
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.320856)
# Test Loss: 0.254111
#
# Temp Loss: 0.253967
#
# Epoch: 2, Train Loss Decreased!! (0.320856-->0.253249)
# Test Loss: 0.253819
#
# Temp Loss: 0.253541
#
# Epoch: 3, Train Loss Decreased!! (0.253249-->0.251955)
# Test Loss: 0.250973
#
# Temp Loss: 0.250899
#
# Epoch: 4, Train Loss Decreased!! (0.251955-->0.250898)
# Test Loss: 0.251271
#
# Temp Loss: 0.251025
#
# Epoch: 5, Train Loss Decreased!! (0.250898-->0.244324)
# Test Loss: 0.233198
#
# Temp Loss: 0.233061
#
# Epoch: 6, Train Loss Decreased!! (0.244324-->0.233492)
# Test Loss: 0.234855
#
# Temp Loss: 0.235213
#
# Epoch: 7, Train Loss Decreased!! (0.233492-->0.227716)
# Test Loss: 0.223997
#
# Temp Loss: 0.224335
#
# Epoch: 8, Train Loss Decreased!! (0.227716-->0.223310)
# Test Loss: 0.224713
#
# Temp Loss: 0.224692
#
# Epoch: 9, Train Loss Decreased!! (0.223310-->0.219094)
# Test Loss: 0.211626
#
# Temp Loss: 0.213101
#
# Epoch: 10, Train Loss Decreased!! (0.219094-->0.210735)
# Test Loss: 0.212445
#
# Temp Loss: 0.214062
#
# Epoch: 11, Train Loss Decreased!! (0.210735-->0.201426)
# Test Loss: 0.191342
#
# Temp Loss: 0.200209
#
# Epoch: 12, Train Loss Decreased!! (0.201426-->0.192087)
# Test Loss: 0.193920
#
# Temp Loss: 0.201921
#
# Epoch: 13, Train Loss Decreased!! (0.192087-->0.183084)
# Test Loss: 0.174220
#
# Temp Loss: 0.200555
#
# Epoch: 14, Train Loss Decreased!! (0.183084-->0.173978)
# Test Loss: 0.175922
#
# Temp Loss: 0.200414
#
# Epoch: 15, Train Loss Decreased!! (0.173978-->0.170364)
# Test Loss: 0.167909
#
# Temp Loss: 0.197556
#
# Epoch: 16, Train Loss Decreased!! (0.170364-->0.168132)
# Test Loss: 0.171557
#
# Temp Loss: 0.198589
#
# Epoch: 17, Train Loss Decreased!! (0.168132-->0.165628)
# Test Loss: 0.161673
#
# Temp Loss: 0.191291
#
# Epoch: 18, Train Loss Decreased!! (0.165628-->0.162325)
# Test Loss: 0.165326
#
# Temp Loss: 0.191667
#
# Epoch: 19, Train Loss Decreased!! (0.162325-->0.153764)
# Test Loss: 0.145811
#
# Temp Loss: 0.174858
#
# Epoch: 20, Train Loss Decreased!! (0.153764-->0.147235)
# Test Loss: 0.152384
#
# Temp Loss: 0.179540
#
# Epoch: 21, Train Loss Decreased!! (0.147235-->0.141623)
# Test Loss: 0.137535
#
# Temp Loss: 0.168810
#
# Epoch: 22, Train Loss Decreased!! (0.141623-->0.139371)
# Test Loss: 0.145280
#
# Temp Loss: 0.174381
#
# Epoch: 23, Train Loss Decreased!! (0.139371-->0.132494)
# Test Loss: 0.125721
#
# Temp Loss: 0.157514
#
# Epoch: 24, Train Loss Decreased!! (0.132494-->0.126670)
# Test Loss: 0.130882
#
# Temp Loss: 0.161360
#
# Epoch: 25, Train Loss Decreased!! (0.126670-->0.123102)
# Test Loss: 0.120277
#
# Temp Loss: 0.151045
#
# Epoch: 26, Train Loss Decreased!! (0.123102-->0.120253)
# Test Loss: 0.123809
#
# Temp Loss: 0.154023
#
# Epoch: 27, Train Loss Decreased!! (0.120253-->0.114915)
# Test Loss: 0.110264
#
# Temp Loss: 0.142004
#
# Epoch: 28, Train Loss Decreased!! (0.114915-->0.110908)
# Test Loss: 0.113663
#
# Temp Loss: 0.144376
#
# Epoch: 29, Train Loss Decreased!! (0.110908-->0.108461)
# Test Loss: 0.106695
#
# Temp Loss: 0.137700
#
# Epoch: 30, Train Loss Decreased!! (0.108461-->0.107288)
# Test Loss: 0.109931
#
# Temp Loss: 0.139855
#
# Epoch: 31, Train Loss Decreased!! (0.107288-->0.105996)
# Test Loss: 0.104962
#
# Temp Loss: 0.136545
#
# Epoch: 32, Train Loss Decreased!! (0.105996-->0.105717)
# Test Loss: 0.108353
#
# Temp Loss: 0.138904
#
# Epoch: 33, Train Loss Decreased!! (0.105717-->0.104577)
# Test Loss: 0.103905
#
# Temp Loss: 0.135846
#
# Epoch: 34, Train Loss Decreased!! (0.104577-->0.104237)
# Test Loss: 0.106646
#
# Temp Loss: 0.137902
#
# Epoch: 35, Train Loss Decreased!! (0.104237-->0.103211)
# Test Loss: 0.102425
#
# Temp Loss: 0.134691
#
# Epoch: 36, Train Loss Decreased!! (0.103211-->0.102555)
# Test Loss: 0.105478
#
# Temp Loss: 0.136933
#
# Epoch: 37, Train Loss Decreased!! (0.102555-->0.099121)
# Test Loss: 0.095179
#
# Temp Loss: 0.130709
#
# Epoch: 38, Train Loss Decreased!! (0.099121-->0.095310)
# Test Loss: 0.098421
#
# Temp Loss: 0.132623
#
# Epoch: 39, Train Loss Decreased!! (0.095310-->0.092346)
# Test Loss: 0.088662
#
# Temp Loss: 0.123253
#
# Epoch: 40, Train Loss Decreased!! (0.092346-->0.090367)
# Test Loss: 0.094943
#
# Temp Loss: 0.127496
#
# Epoch: 41, Train Loss Decreased!! (0.090367-->0.085017)
# Test Loss: 0.079092
#
# Temp Loss: 0.112896
#
# Test Loss: 0.093252
#
# Temp Loss: 0.124544
#
# Epoch: 43, Train Loss Decreased!! (0.085017-->0.077202)
# Test Loss: 0.072771
#
# Temp Loss: 0.107492
#
# Epoch: 44, Train Loss Decreased!! (0.077202-->0.075178)
# Test Loss: 0.080870
#
# Temp Loss: 0.113879
#
# Epoch: 45, Train Loss Decreased!! (0.075178-->0.071030)
# Test Loss: 0.066891
#
# Temp Loss: 0.104334
#
# Epoch: 46, Train Loss Decreased!! (0.071030-->0.069484)
# Test Loss: 0.075562
#
# Temp Loss: 0.111613
#
# Epoch: 47, Train Loss Decreased!! (0.069484-->0.064755)
# Test Loss: 0.060254
#
# Temp Loss: 0.098938
#
# Epoch: 48, Train Loss Decreased!! (0.064755-->0.064160)
# Test Loss: 0.071644
#
# Temp Loss: 0.108556
#
# Epoch: 49, Train Loss Decreased!! (0.064160-->0.059109)
# Test Loss: 0.054878
#
# Temp Loss: 0.097307
#
# Epoch: 50, Train Loss Decreased!! (0.059109-->0.057661)
# Test Loss: 0.063553
#
# Temp Loss: 0.103911
#
# Epoch: 51, Train Loss Decreased!! (0.057661-->0.053943)
# Test Loss: 0.050962
#
# Temp Loss: 0.095823
#
# Test Loss: 0.059554
#
# Temp Loss: 0.102485
#
# Epoch: 53, Train Loss Decreased!! (0.053943-->0.050639)
# Test Loss: 0.047576
#
# Temp Loss: 0.093939
#
# Test Loss: 0.056669
#
# Temp Loss: 0.100018
#
# Epoch: 55, Train Loss Decreased!! (0.050639-->0.048148)
# Test Loss: 0.045448
#
# Temp Loss: 0.090329
#
# Epoch: 56, Train Loss Decreased!! (0.048148-->0.047501)
# Test Loss: 0.051775
#
# Temp Loss: 0.094456
#
# Epoch: 57, Train Loss Decreased!! (0.047501-->0.045541)
# Test Loss: 0.043724
#
# Temp Loss: 0.088944
#
# Test Loss: 0.049523
#
# Temp Loss: 0.092623
#
# Epoch: 59, Train Loss Decreased!! (0.045541-->0.043397)
# Test Loss: 0.040787
#
# Temp Loss: 0.089026
#
# Epoch: 60, Train Loss Decreased!! (0.043397-->0.042631)
# Test Loss: 0.045992
#
# Temp Loss: 0.091427
#
# Epoch: 61, Train Loss Decreased!! (0.042631-->0.040052)
# Test Loss: 0.036921
#
# Temp Loss: 0.087977
#
# Epoch: 62, Train Loss Decreased!! (0.040052-->0.039021)
# Test Loss: 0.042653
#
# Temp Loss: 0.090844
#
# Epoch: 63, Train Loss Decreased!! (0.039021-->0.035913)
# Test Loss: 0.032944
#
# Temp Loss: 0.088971
#
# Epoch: 64, Train Loss Decreased!! (0.035913-->0.034713)
# Test Loss: 0.038367
#
# Temp Loss: 0.090719
#
# Epoch: 65, Train Loss Decreased!! (0.034713-->0.032269)
# Test Loss: 0.029348
#
# Temp Loss: 0.089195
#
# Epoch: 66, Train Loss Decreased!! (0.032269-->0.031404)
# Test Loss: 0.035182
#
# Temp Loss: 0.091236
#
# Epoch: 67, Train Loss Decreased!! (0.031404-->0.028695)
# Test Loss: 0.025601
#
# Temp Loss: 0.086389
#
# Epoch: 68, Train Loss Decreased!! (0.028695-->0.028119)
# Test Loss: 0.032620
#
# Temp Loss: 0.089489
#
# Epoch: 69, Train Loss Decreased!! (0.028119-->0.024972)
# Test Loss: 0.022057
#
# Temp Loss: 0.086057
#
# Test Loss: 0.031228
#
# Temp Loss: 0.090737
#
# Epoch: 71, Train Loss Decreased!! (0.024972-->0.022252)
# Test Loss: 0.019459
#
# Temp Loss: 0.085868
#
# Test Loss: 0.030234
#
# Temp Loss: 0.091525
#
# Epoch: 73, Train Loss Decreased!! (0.022252-->0.019918)
# Test Loss: 0.017255
#
# Temp Loss: 0.084828
#
# Test Loss: 0.029894
#
# Temp Loss: 0.091930
#
# Epoch: 75, Train Loss Decreased!! (0.019918-->0.018279)
# Test Loss: 0.015602
#
# Temp Loss: 0.084386
#
# Test Loss: 0.029650
#
# Temp Loss: 0.092408
#
# Epoch: 77, Train Loss Decreased!! (0.018279-->0.016967)
# Test Loss: 0.014212
#
# Temp Loss: 0.084195
#
# Test Loss: 0.029013
#
# Temp Loss: 0.091200
#
# Epoch: 79, Train Loss Decreased!! (0.016967-->0.016147)
# Test Loss: 0.013269
#
# Temp Loss: 0.084104
#
# Test Loss: 0.028410
#
# Temp Loss: 0.090618
#
# Epoch: 81, Train Loss Decreased!! (0.016147-->0.015355)
# Test Loss: 0.012465
#
# Temp Loss: 0.084002
#
# Test Loss: 0.028119
#
# Temp Loss: 0.090148
#
# Epoch: 83, Train Loss Decreased!! (0.015355-->0.014625)
# Test Loss: 0.011931
#
# Temp Loss: 0.084301
#
# Test Loss: 0.028171
#
# Temp Loss: 0.090211
#
# Epoch: 85, Train Loss Decreased!! (0.014625-->0.013823)
# Test Loss: 0.011350
#
# Temp Loss: 0.084514
#
# Test Loss: 0.026926
#
# Temp Loss: 0.089538
#
# Epoch: 87, Train Loss Decreased!! (0.013823-->0.013347)
# Test Loss: 0.010932
#
# Temp Loss: 0.083885
#
# Test Loss: 0.027285
#
# Temp Loss: 0.089482
#
# Epoch: 89, Train Loss Decreased!! (0.013347-->0.012797)
# Test Loss: 0.010386
#
# Temp Loss: 0.084605
#
# Test Loss: 0.027957
#
# Temp Loss: 0.090505
#
# Epoch: 91, Train Loss Decreased!! (0.012797-->0.012614)
# Test Loss: 0.009886
#
# Temp Loss: 0.084434
#
# Test Loss: 0.026180
#
# Temp Loss: 0.089308
#
# Epoch: 93, Train Loss Decreased!! (0.012614-->0.012121)
# Test Loss: 0.009522
#
# Temp Loss: 0.084414
#
# Test Loss: 0.026733
#
# Temp Loss: 0.089737
#
# Epoch: 95, Train Loss Decreased!! (0.012121-->0.011900)
# Test Loss: 0.009159
#
# Temp Loss: 0.084385
#
# Test Loss: 0.026393
#
# Temp Loss: 0.089843
#
# Epoch: 97, Train Loss Decreased!! (0.011900-->0.011563)
# Test Loss: 0.008839
#
# Temp Loss: 0.084005
#
# Test Loss: 0.026236
#
# Temp Loss: 0.089599
#
# Epoch: 99, Train Loss Decreased!! (0.011563-->0.011399)
# Test Loss: 0.008720
#
# Temp Loss: 0.084327
#  60%|██████    | 3/5 [05:43<03:48, 114.01s/it]
# Test Loss: 0.025125
#
# Temp Loss: 0.089274
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.331691)
# Test Loss: 0.254868
#
# Temp Loss: 0.254870
#
# Epoch: 2, Train Loss Decreased!! (0.331691-->0.254227)
# Test Loss: 0.254123
#
# Temp Loss: 0.254114
#
# Epoch: 3, Train Loss Decreased!! (0.254227-->0.252035)
# Test Loss: 0.248593
#
# Temp Loss: 0.248802
#
# Epoch: 4, Train Loss Decreased!! (0.252035-->0.249235)
# Test Loss: 0.249694
#
# Temp Loss: 0.249707
#
# Epoch: 5, Train Loss Decreased!! (0.249235-->0.240424)
# Test Loss: 0.230179
#
# Temp Loss: 0.231038
#
# Epoch: 6, Train Loss Decreased!! (0.240424-->0.230245)
# Test Loss: 0.230320
#
# Temp Loss: 0.231035
#
# Epoch: 7, Train Loss Decreased!! (0.230245-->0.222309)
# Test Loss: 0.213375
#
# Temp Loss: 0.214715
#
# Epoch: 8, Train Loss Decreased!! (0.222309-->0.213201)
# Test Loss: 0.213304
#
# Temp Loss: 0.214997
#
# Epoch: 9, Train Loss Decreased!! (0.213201-->0.208722)
# Test Loss: 0.204687
#
# Temp Loss: 0.208939
#
# Epoch: 10, Train Loss Decreased!! (0.208722-->0.205042)
# Test Loss: 0.205697
#
# Temp Loss: 0.209734
#
# Epoch: 11, Train Loss Decreased!! (0.205042-->0.199744)
# Test Loss: 0.187540
#
# Temp Loss: 0.204021
#
# Epoch: 12, Train Loss Decreased!! (0.199744-->0.188507)
# Test Loss: 0.189040
#
# Temp Loss: 0.204847
#
# Epoch: 13, Train Loss Decreased!! (0.188507-->0.177201)
# Test Loss: 0.168080
#
# Temp Loss: 0.196468
#
# Epoch: 14, Train Loss Decreased!! (0.177201-->0.169523)
# Test Loss: 0.171194
#
# Temp Loss: 0.197412
#
# Epoch: 15, Train Loss Decreased!! (0.169523-->0.161964)
# Test Loss: 0.155527
#
# Temp Loss: 0.186444
#
# Epoch: 16, Train Loss Decreased!! (0.161964-->0.157265)
# Test Loss: 0.159415
#
# Temp Loss: 0.188091
#
# Epoch: 17, Train Loss Decreased!! (0.157265-->0.153980)
# Test Loss: 0.151378
#
# Temp Loss: 0.182803
#
# Epoch: 18, Train Loss Decreased!! (0.153980-->0.152433)
# Test Loss: 0.154774
#
# Temp Loss: 0.183668
#
# Epoch: 19, Train Loss Decreased!! (0.152433-->0.150827)
# Test Loss: 0.148077
#
# Temp Loss: 0.179830
#
# Epoch: 20, Train Loss Decreased!! (0.150827-->0.149274)
# Test Loss: 0.151645
#
# Temp Loss: 0.180087
#
# Epoch: 21, Train Loss Decreased!! (0.149274-->0.144583)
# Test Loss: 0.137280
#
# Temp Loss: 0.168653
#
# Epoch: 22, Train Loss Decreased!! (0.144583-->0.138587)
# Test Loss: 0.139277
#
# Temp Loss: 0.168766
#
# Epoch: 23, Train Loss Decreased!! (0.138587-->0.133862)
# Test Loss: 0.126819
#
# Temp Loss: 0.159737
#
# Epoch: 24, Train Loss Decreased!! (0.133862-->0.129451)
# Test Loss: 0.131275
#
# Temp Loss: 0.162137
#
# Epoch: 25, Train Loss Decreased!! (0.129451-->0.122373)
# Test Loss: 0.117142
#
# Temp Loss: 0.152119
#
# Epoch: 26, Train Loss Decreased!! (0.122373-->0.120468)
# Test Loss: 0.127222
#
# Temp Loss: 0.159805
#
# Epoch: 27, Train Loss Decreased!! (0.120468-->0.114720)
# Test Loss: 0.109083
#
# Temp Loss: 0.144884
#
# Epoch: 28, Train Loss Decreased!! (0.114720-->0.111199)
# Test Loss: 0.116415
#
# Temp Loss: 0.150293
#
# Epoch: 29, Train Loss Decreased!! (0.111199-->0.106399)
# Test Loss: 0.103039
#
# Temp Loss: 0.139537
#
# Epoch: 30, Train Loss Decreased!! (0.106399-->0.104255)
# Test Loss: 0.109899
#
# Temp Loss: 0.144618
#
# Epoch: 31, Train Loss Decreased!! (0.104255-->0.100337)
# Test Loss: 0.097164
#
# Temp Loss: 0.137148
#
# Epoch: 32, Train Loss Decreased!! (0.100337-->0.098454)
# Test Loss: 0.104334
#
# Temp Loss: 0.142578
#
# Epoch: 33, Train Loss Decreased!! (0.098454-->0.093700)
# Test Loss: 0.090805
#
# Temp Loss: 0.132691
#
# Epoch: 34, Train Loss Decreased!! (0.093700-->0.092697)
# Test Loss: 0.099004
#
# Temp Loss: 0.138993
#
# Epoch: 35, Train Loss Decreased!! (0.092697-->0.088175)
# Test Loss: 0.085481
#
# Temp Loss: 0.128275
#
# Epoch: 36, Train Loss Decreased!! (0.088175-->0.086094)
# Test Loss: 0.091418
#
# Temp Loss: 0.132489
#
# Epoch: 37, Train Loss Decreased!! (0.086094-->0.083006)
# Test Loss: 0.080278
#
# Temp Loss: 0.122191
#
# Epoch: 38, Train Loss Decreased!! (0.083006-->0.081351)
# Test Loss: 0.086978
#
# Temp Loss: 0.126511
#
# Epoch: 39, Train Loss Decreased!! (0.081351-->0.077574)
# Test Loss: 0.074581
#
# Temp Loss: 0.116638
#
# Epoch: 40, Train Loss Decreased!! (0.077574-->0.075665)
# Test Loss: 0.081271
#
# Temp Loss: 0.120717
#
# Epoch: 41, Train Loss Decreased!! (0.075665-->0.072841)
# Test Loss: 0.071532
#
# Temp Loss: 0.114398
#
# Epoch: 42, Train Loss Decreased!! (0.072841-->0.072635)
# Test Loss: 0.078185
#
# Temp Loss: 0.117854
#
# Epoch: 43, Train Loss Decreased!! (0.072635-->0.070727)
# Test Loss: 0.069112
#
# Temp Loss: 0.111542
#
# Epoch: 44, Train Loss Decreased!! (0.070727-->0.070379)
# Test Loss: 0.075333
#
# Temp Loss: 0.114907
#
# Epoch: 45, Train Loss Decreased!! (0.070379-->0.068261)
# Test Loss: 0.066688
#
# Temp Loss: 0.109019
#
# Epoch: 46, Train Loss Decreased!! (0.068261-->0.067903)
# Test Loss: 0.072941
#
# Temp Loss: 0.112537
#
# Epoch: 47, Train Loss Decreased!! (0.067903-->0.064787)
# Test Loss: 0.061231
#
# Temp Loss: 0.102604
#
# Epoch: 48, Train Loss Decreased!! (0.064787-->0.062657)
# Test Loss: 0.067148
#
# Temp Loss: 0.106024
#
# Epoch: 49, Train Loss Decreased!! (0.062657-->0.058802)
# Test Loss: 0.054315
#
# Temp Loss: 0.095629
#
# Epoch: 50, Train Loss Decreased!! (0.058802-->0.056868)
# Test Loss: 0.061821
#
# Temp Loss: 0.100505
#
# Epoch: 51, Train Loss Decreased!! (0.056868-->0.051960)
# Test Loss: 0.048150
#
# Temp Loss: 0.090357
#
# Epoch: 52, Train Loss Decreased!! (0.051960-->0.051386)
# Test Loss: 0.057556
#
# Temp Loss: 0.096118
#
# Epoch: 53, Train Loss Decreased!! (0.051386-->0.048184)
# Test Loss: 0.045491
#
# Temp Loss: 0.088124
#
# Test Loss: 0.056010
#
# Temp Loss: 0.094224
#
# Epoch: 55, Train Loss Decreased!! (0.048184-->0.046186)
# Test Loss: 0.043252
#
# Temp Loss: 0.086599
#
# Test Loss: 0.054925
#
# Temp Loss: 0.093270
#
# Epoch: 57, Train Loss Decreased!! (0.046186-->0.044282)
# Test Loss: 0.041681
#
# Temp Loss: 0.086066
#
# Test Loss: 0.053450
#
# Temp Loss: 0.092381
#
# Epoch: 59, Train Loss Decreased!! (0.044282-->0.042843)
# Test Loss: 0.040278
#
# Temp Loss: 0.084831
#
# Test Loss: 0.052107
#
# Temp Loss: 0.091395
#
# Epoch: 61, Train Loss Decreased!! (0.042843-->0.041178)
# Test Loss: 0.038354
#
# Temp Loss: 0.083483
#
# Test Loss: 0.051282
#
# Temp Loss: 0.091720
#
# Epoch: 63, Train Loss Decreased!! (0.041178-->0.039383)
# Test Loss: 0.036257
#
# Temp Loss: 0.082480
#
# Test Loss: 0.049666
#
# Temp Loss: 0.090563
#
# Epoch: 65, Train Loss Decreased!! (0.039383-->0.036956)
# Test Loss: 0.032855
#
# Temp Loss: 0.081471
#
# Test Loss: 0.047114
#
# Temp Loss: 0.090767
#
# Epoch: 67, Train Loss Decreased!! (0.036956-->0.033493)
# Test Loss: 0.029321
#
# Temp Loss: 0.081610
#
# Test Loss: 0.044625
#
# Temp Loss: 0.091706
#
# Epoch: 69, Train Loss Decreased!! (0.033493-->0.029859)
# Test Loss: 0.025997
#
# Temp Loss: 0.082616
#
# Test Loss: 0.042760
#
# Temp Loss: 0.092657
#
# Epoch: 71, Train Loss Decreased!! (0.029859-->0.027203)
# Test Loss: 0.023212
#
# Temp Loss: 0.081056
#
# Test Loss: 0.040870
#
# Temp Loss: 0.091712
#
# Epoch: 73, Train Loss Decreased!! (0.027203-->0.025043)
# Test Loss: 0.021310
#
# Temp Loss: 0.080859
#
# Test Loss: 0.040128
#
# Temp Loss: 0.091335
#
# Epoch: 75, Train Loss Decreased!! (0.025043-->0.023192)
# Test Loss: 0.019608
#
# Temp Loss: 0.080238
#
# Test Loss: 0.039150
#
# Temp Loss: 0.090754
#
# Epoch: 77, Train Loss Decreased!! (0.023192-->0.021904)
# Test Loss: 0.018287
#
# Temp Loss: 0.079976
#
# Test Loss: 0.036821
#
# Temp Loss: 0.089388
#
# Epoch: 79, Train Loss Decreased!! (0.021904-->0.020335)
# Test Loss: 0.017378
#
# Temp Loss: 0.080311
#
# Test Loss: 0.033671
#
# Temp Loss: 0.087021
#
# Epoch: 81, Train Loss Decreased!! (0.020335-->0.019191)
# Test Loss: 0.016018
#
# Temp Loss: 0.080108
#
# Test Loss: 0.032990
#
# Temp Loss: 0.087316
#
# Epoch: 83, Train Loss Decreased!! (0.019191-->0.018258)
# Test Loss: 0.014908
#
# Temp Loss: 0.080536
#
# Test Loss: 0.033024
#
# Temp Loss: 0.088261
#
# Epoch: 85, Train Loss Decreased!! (0.018258-->0.017227)
# Test Loss: 0.013901
#
# Temp Loss: 0.079972
#
# Test Loss: 0.031143
#
# Temp Loss: 0.087210
#
# Epoch: 87, Train Loss Decreased!! (0.017227-->0.016068)
# Test Loss: 0.012910
#
# Temp Loss: 0.080233
#
# Test Loss: 0.030678
#
# Temp Loss: 0.087623
#
# Epoch: 89, Train Loss Decreased!! (0.016068-->0.015499)
# Test Loss: 0.012220
#
# Temp Loss: 0.080931
#
# Test Loss: 0.029266
#
# Temp Loss: 0.087406
#
# Epoch: 91, Train Loss Decreased!! (0.015499-->0.014532)
# Test Loss: 0.011558
#
# Temp Loss: 0.080734
#
# Test Loss: 0.028947
#
# Temp Loss: 0.087527
#
# Epoch: 93, Train Loss Decreased!! (0.014532-->0.013878)
# Test Loss: 0.011046
#
# Temp Loss: 0.081680
#
# Test Loss: 0.028281
#
# Temp Loss: 0.088718
#
# Epoch: 95, Train Loss Decreased!! (0.013878-->0.013432)
# Test Loss: 0.010611
#
# Temp Loss: 0.081896
#
# Test Loss: 0.027032
#
# Temp Loss: 0.088734
#
# Epoch: 97, Train Loss Decreased!! (0.013432-->0.012792)
# Test Loss: 0.010005
#
# Temp Loss: 0.082223
#
# Test Loss: 0.026130
#
# Temp Loss: 0.088433
#
# Epoch: 99, Train Loss Decreased!! (0.012792-->0.012338)
# Test Loss: 0.009515
#
# Temp Loss: 0.082609
#
# Test Loss: 0.026527
#
# Temp Loss: 0.089295
#  80%|████████  | 4/5 [07:36<01:53, 113.65s/it]
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.297395)
# Test Loss: 0.254116
#
# Temp Loss: 0.254297
#
# Epoch: 2, Train Loss Decreased!! (0.297395-->0.253425)
# Test Loss: 0.253803
#
# Temp Loss: 0.253739
#
# Epoch: 3, Train Loss Decreased!! (0.253425-->0.251091)
# Test Loss: 0.247712
#
# Temp Loss: 0.247481
#
# Epoch: 4, Train Loss Decreased!! (0.251091-->0.247341)
# Test Loss: 0.248077
#
# Temp Loss: 0.247967
#
# Epoch: 5, Train Loss Decreased!! (0.247341-->0.237408)
# Test Loss: 0.223532
#
# Temp Loss: 0.223257
#
# Epoch: 6, Train Loss Decreased!! (0.237408-->0.222446)
# Test Loss: 0.223517
#
# Temp Loss: 0.223626
#
# Epoch: 7, Train Loss Decreased!! (0.222446-->0.214381)
# Test Loss: 0.208860
#
# Temp Loss: 0.212286
#
# Epoch: 8, Train Loss Decreased!! (0.214381-->0.208165)
# Test Loss: 0.209461
#
# Temp Loss: 0.212690
#
# Epoch: 9, Train Loss Decreased!! (0.208165-->0.202627)
# Test Loss: 0.194645
#
# Temp Loss: 0.212568
#
# Epoch: 10, Train Loss Decreased!! (0.202627-->0.194421)
# Test Loss: 0.196551
#
# Temp Loss: 0.214106
#
# Epoch: 11, Train Loss Decreased!! (0.194421-->0.186638)
# Test Loss: 0.181779
#
# Temp Loss: 0.212546
#
# Epoch: 12, Train Loss Decreased!! (0.186638-->0.182505)
# Test Loss: 0.186268
#
# Temp Loss: 0.215573
#
# Epoch: 13, Train Loss Decreased!! (0.182505-->0.172525)
# Test Loss: 0.160174
#
# Temp Loss: 0.190315
#
# Epoch: 14, Train Loss Decreased!! (0.172525-->0.161628)
# Test Loss: 0.165120
#
# Temp Loss: 0.194481
#
# Epoch: 15, Train Loss Decreased!! (0.161628-->0.154118)
# Test Loss: 0.147161
#
# Temp Loss: 0.177347
#
# Epoch: 16, Train Loss Decreased!! (0.154118-->0.151788)
# Test Loss: 0.158678
#
# Temp Loss: 0.189240
#
# Epoch: 17, Train Loss Decreased!! (0.151788-->0.144443)
# Test Loss: 0.140758
#
# Temp Loss: 0.172753
#
# Epoch: 18, Train Loss Decreased!! (0.144443-->0.143668)
# Test Loss: 0.152365
#
# Temp Loss: 0.182753
#
# Epoch: 19, Train Loss Decreased!! (0.143668-->0.140059)
# Test Loss: 0.138381
#
# Temp Loss: 0.170537
#
# Epoch: 20, Train Loss Decreased!! (0.140059-->0.139909)
# Test Loss: 0.147546
#
# Temp Loss: 0.178466
#
# Epoch: 21, Train Loss Decreased!! (0.139909-->0.137075)
# Test Loss: 0.136092
#
# Temp Loss: 0.168114
#
# Epoch: 22, Train Loss Decreased!! (0.137075-->0.136016)
# Test Loss: 0.142215
#
# Temp Loss: 0.172533
#
# Epoch: 23, Train Loss Decreased!! (0.136016-->0.130971)
# Test Loss: 0.127358
#
# Temp Loss: 0.159412
#
# Epoch: 24, Train Loss Decreased!! (0.130971-->0.127053)
# Test Loss: 0.133569
#
# Temp Loss: 0.165502
#
# Epoch: 25, Train Loss Decreased!! (0.127053-->0.119652)
# Test Loss: 0.113596
#
# Temp Loss: 0.145689
#
# Epoch: 26, Train Loss Decreased!! (0.119652-->0.114726)
# Test Loss: 0.121729
#
# Temp Loss: 0.153752
#
# Epoch: 27, Train Loss Decreased!! (0.114726-->0.110514)
# Test Loss: 0.108627
#
# Temp Loss: 0.140624
#
# Epoch: 28, Train Loss Decreased!! (0.110514-->0.109235)
# Test Loss: 0.115788
#
# Temp Loss: 0.147069
#
# Epoch: 29, Train Loss Decreased!! (0.109235-->0.106821)
# Test Loss: 0.105690
#
# Temp Loss: 0.138392
#
# Epoch: 30, Train Loss Decreased!! (0.106821-->0.106055)
# Test Loss: 0.111577
#
# Temp Loss: 0.143631
#
# Epoch: 31, Train Loss Decreased!! (0.106055-->0.103510)
# Test Loss: 0.101879
#
# Temp Loss: 0.136927
#
# Epoch: 32, Train Loss Decreased!! (0.103510-->0.102300)
# Test Loss: 0.108008
#
# Temp Loss: 0.141807
#
# Epoch: 33, Train Loss Decreased!! (0.102300-->0.098218)
# Test Loss: 0.095311
#
# Temp Loss: 0.133745
#
# Epoch: 34, Train Loss Decreased!! (0.098218-->0.095965)
# Test Loss: 0.101709
#
# Temp Loss: 0.138514
#
# Epoch: 35, Train Loss Decreased!! (0.095965-->0.090232)
# Test Loss: 0.085413
#
# Temp Loss: 0.120896
#
# Epoch: 36, Train Loss Decreased!! (0.090232-->0.085629)
# Test Loss: 0.091795
#
# Temp Loss: 0.125911
#
# Epoch: 37, Train Loss Decreased!! (0.085629-->0.080249)
# Test Loss: 0.077199
#
# Temp Loss: 0.111792
#
# Epoch: 38, Train Loss Decreased!! (0.080249-->0.077762)
# Test Loss: 0.084087
#
# Temp Loss: 0.117507
#
# Epoch: 39, Train Loss Decreased!! (0.077762-->0.074545)
# Test Loss: 0.071866
#
# Temp Loss: 0.108900
#
# Epoch: 40, Train Loss Decreased!! (0.074545-->0.072384)
# Test Loss: 0.077804
#
# Temp Loss: 0.113210
#
# Epoch: 41, Train Loss Decreased!! (0.072384-->0.067841)
# Test Loss: 0.064183
#
# Temp Loss: 0.103273
#
# Epoch: 42, Train Loss Decreased!! (0.067841-->0.065074)
# Test Loss: 0.071849
#
# Temp Loss: 0.109654
#
# Epoch: 43, Train Loss Decreased!! (0.065074-->0.059733)
# Test Loss: 0.055740
#
# Temp Loss: 0.095109
#
# Epoch: 44, Train Loss Decreased!! (0.059733-->0.056740)
# Test Loss: 0.063774
#
# Temp Loss: 0.101876
#
# Epoch: 45, Train Loss Decreased!! (0.056740-->0.052264)
# Test Loss: 0.049597
#
# Temp Loss: 0.090863
#
# Epoch: 46, Train Loss Decreased!! (0.052264-->0.052147)
# Test Loss: 0.060997
#
# Temp Loss: 0.100154
#
# Epoch: 47, Train Loss Decreased!! (0.052147-->0.048309)
# Test Loss: 0.046680
#
# Temp Loss: 0.088934
#
# Test Loss: 0.056763
#
# Temp Loss: 0.096991
#
# Epoch: 49, Train Loss Decreased!! (0.048309-->0.046149)
# Test Loss: 0.044945
#
# Temp Loss: 0.088238
#
# Test Loss: 0.053457
#
# Temp Loss: 0.094800
#
# Epoch: 51, Train Loss Decreased!! (0.046149-->0.044200)
# Test Loss: 0.043496
#
# Temp Loss: 0.087333
#
# Test Loss: 0.051366
#
# Temp Loss: 0.093524
#
# Epoch: 53, Train Loss Decreased!! (0.044200-->0.042586)
# Test Loss: 0.042434
#
# Temp Loss: 0.087714
#
# Test Loss: 0.049662
#
# Temp Loss: 0.093624
#
# Epoch: 55, Train Loss Decreased!! (0.042586-->0.040876)
# Test Loss: 0.040108
#
# Temp Loss: 0.087819
#
# Test Loss: 0.047680
#
# Temp Loss: 0.093105
#
# Epoch: 57, Train Loss Decreased!! (0.040876-->0.038735)
# Test Loss: 0.038079
#
# Temp Loss: 0.088708
#
# Test Loss: 0.046195
#
# Temp Loss: 0.094981
#
# Epoch: 59, Train Loss Decreased!! (0.038735-->0.036488)
# Test Loss: 0.035335
#
# Temp Loss: 0.088515
#
# Test Loss: 0.044284
#
# Temp Loss: 0.095392
#
# Epoch: 61, Train Loss Decreased!! (0.036488-->0.034316)
# Test Loss: 0.033471
#
# Temp Loss: 0.089403
#
# Test Loss: 0.043985
#
# Temp Loss: 0.097819
#
# Epoch: 63, Train Loss Decreased!! (0.034316-->0.032610)
# Test Loss: 0.031673
#
# Temp Loss: 0.090156
#
# Test Loss: 0.042862
#
# Temp Loss: 0.098633
#
# Epoch: 65, Train Loss Decreased!! (0.032610-->0.031231)
# Test Loss: 0.030247
#
# Temp Loss: 0.091373
#
# Test Loss: 0.042116
#
# Temp Loss: 0.099756
#
# Epoch: 67, Train Loss Decreased!! (0.031231-->0.030268)
# Test Loss: 0.029266
#
# Temp Loss: 0.091867
#
# Test Loss: 0.041924
#
# Temp Loss: 0.100744
#
# Epoch: 69, Train Loss Decreased!! (0.030268-->0.029161)
# Test Loss: 0.028021
#
# Temp Loss: 0.092062
#
# Test Loss: 0.041659
#
# Temp Loss: 0.102278
#
# Epoch: 71, Train Loss Decreased!! (0.029161-->0.027915)
# Test Loss: 0.026847
#
# Temp Loss: 0.091401
#
# Test Loss: 0.042467
#
# Temp Loss: 0.103616
#
# Epoch: 73, Train Loss Decreased!! (0.027915-->0.027002)
# Test Loss: 0.025554
#
# Temp Loss: 0.091228
#
# Test Loss: 0.042043
#
# Temp Loss: 0.105107
#
# Epoch: 75, Train Loss Decreased!! (0.027002-->0.025655)
# Test Loss: 0.023504
#
# Temp Loss: 0.090322
#
# Test Loss: 0.040283
#
# Temp Loss: 0.103179
#
# Epoch: 77, Train Loss Decreased!! (0.025655-->0.023836)
# Test Loss: 0.021155
#
# Temp Loss: 0.089149
#
# Test Loss: 0.037392
#
# Temp Loss: 0.101551
#
# Epoch: 79, Train Loss Decreased!! (0.023836-->0.020704)
# Test Loss: 0.018160
#
# Temp Loss: 0.087022
#
# Test Loss: 0.035096
#
# Temp Loss: 0.100174
#
# Epoch: 81, Train Loss Decreased!! (0.020704-->0.017945)
# Test Loss: 0.015403
#
# Temp Loss: 0.085088
#
# Test Loss: 0.032559
#
# Temp Loss: 0.097924
#
# Epoch: 83, Train Loss Decreased!! (0.017945-->0.015530)
# Test Loss: 0.013096
#
# Temp Loss: 0.084156
#
# Test Loss: 0.029996
#
# Temp Loss: 0.096827
#
# Epoch: 85, Train Loss Decreased!! (0.015530-->0.013596)
# Test Loss: 0.011513
#
# Temp Loss: 0.084056
#
# Test Loss: 0.029553
#
# Temp Loss: 0.096503
#
# Epoch: 87, Train Loss Decreased!! (0.013596-->0.012512)
# Test Loss: 0.010360
#
# Temp Loss: 0.084150
#
# Test Loss: 0.029574
#
# Temp Loss: 0.096725
#
# Epoch: 89, Train Loss Decreased!! (0.012512-->0.011957)
# Test Loss: 0.009743
#
# Temp Loss: 0.084446
#
# Test Loss: 0.027305
#
# Temp Loss: 0.095705
#
# Epoch: 91, Train Loss Decreased!! (0.011957-->0.010755)
# Test Loss: 0.008871
#
# Temp Loss: 0.084104
#
# Test Loss: 0.026377
#
# Temp Loss: 0.095473
#
# Epoch: 93, Train Loss Decreased!! (0.010755-->0.010200)
# Test Loss: 0.008380
#
# Temp Loss: 0.084237
#
# Test Loss: 0.025431
#
# Temp Loss: 0.095154
#
# Epoch: 95, Train Loss Decreased!! (0.010200-->0.009621)
# Test Loss: 0.007883
#
# Temp Loss: 0.084137
#
# Test Loss: 0.024862
#
# Temp Loss: 0.095066
#
# Epoch: 97, Train Loss Decreased!! (0.009621-->0.009020)
# Test Loss: 0.007447
#
# Temp Loss: 0.084217
#
# Test Loss: 0.024173
#
# Temp Loss: 0.095162
#
# Epoch: 99, Train Loss Decreased!! (0.009020-->0.008684)
# Test Loss: 0.007160
#
# Temp Loss: 0.084714
# 100%|██████████| 5/5 [09:29<00:00, 113.91s/it]
# Test Loss: 0.023578
#
# Temp Loss: 0.095137
#
# ----------------------------------------------------

# %%
train_losses_mat = np.zeros((nRuns,n_epochs+1))
test_losses_mat = np.zeros((nRuns,n_epochs+1))
temp_losses_mat = np.zeros((nRuns,n_epochs+1))

train_expected_losses_mat = np.zeros((nRuns,n_epochs+1))

test_expected_losses_mat = np.zeros((nRuns,n_epochs+1))
test_surprise_losses_mat = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    train_losses_mat[cntr] = train_losses[cntr]
    test_losses_mat[cntr] = test_losses[cntr]
    temp_losses_mat[cntr] = temp_losses[cntr]
    
    train_expected_losses_mat[cntr] = train_expected_rec_losses[cntr]
    
    test_expected_losses_mat[cntr] = test_expected_rec_losses[cntr]
    test_surprise_losses_mat[cntr] = test_surprise_rec_losses[cntr]

# %%
train_losses_mean = np.mean(train_losses_mat,axis=0)
test_losses_mean = np.mean(test_losses_mat,axis=0)
temp_losses_mean = np.mean(temp_losses_mat,axis=0)

train_expected_losses_mean = np.mean(train_expected_losses_mat,axis=0)

test_expected_losses_mean = np.mean(test_expected_losses_mat,axis=0)
test_surprise_losses_mean = np.mean(test_surprise_losses_mat,axis=0)

# %%
train_losses_std = np.std(train_losses_mat,axis=0)
test_losses_std = np.std(test_losses_mat,axis=0)
temp_losses_std = np.std(test_losses_mat,axis=0)

train_expected_losses_std = np.std(train_expected_losses_mat,axis=0)

test_expected_losses_std = np.std(test_expected_losses_mat,axis=0)
test_surprise_losses_std = np.std(test_surprise_losses_mat,axis=0)

# %%
train_expected_losses_mean[0] = train_losses_mean[0]

# %%
f = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.errorbar(np.arange(n_epochs+1),train_losses_mean,yerr=train_losses_std)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,2)
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.subplot(2,2,3)
plt.errorbar(np.arange(n_epochs+1),test_losses_mean,yerr=test_losses_std)
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,4)
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
# kk=4
# a = np.unique(allStatesTest[kk][:,0])
# b = np.unique(allStatesTrain[kk][:,0])
# len(np.intersect1d(a,b))

# %% [markdown]
# ### Representational Analyses

# %% [markdown]
# #### RNN Names

# %%
rnn_names = ['L4','L23','L56','H4','H23','H56']

# %% [markdown]
# #### Analyses train loader

# %%
analyses_train_loader = {}

# %%
for cntr in range(nRuns):
    analyses_train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=False)

# %% [markdown]
# #### Pass data and store activations

# %%
def pass_data_store_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        activations_hidden_L23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_L4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_L56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_hidden_H23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_H4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_H56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_out_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
        for e in tqdm(range(n_epochs+1)):

            cnt = 0

            ## Load model
            model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr])
            model[cntr].to(device)
            model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
            model[cntr].eval()

            ## Pass clean samples
            for data, f_target, lastEvent, surpriseBinary in loader[cntr]:

                if train_on_gpu:
                    data, f_targetC = data.float().cuda(), f_target.float().cuda()
                else: data, f_targetC = data.float(), f_target.float()

                target = f_target

                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                ## Collect activations  
                act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                for i in range(batch_size):
                    if i < len(data):
                        label = target.data[i]

                        activations_hidden_L23_np[cntr][e,cnt] = act_hidden_L23[i]
                        activations_hidden_L4_np[cntr][e,cnt] = act_hidden_L4[i]
                        activations_hidden_L56_np[cntr][e,cnt] = act_hidden_L56[i]

                        activations_hidden_H23_np[cntr][e,cnt] = act_hidden_H23[i]
                        activations_hidden_H4_np[cntr][e,cnt] = act_hidden_H4[i]
                        activations_hidden_H56_np[cntr][e,cnt] = act_hidden_H56[i]

                        activations_out_np[cntr][e,cnt] = output_pred[i]

                        cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# (L23_train,L4_train,L56_train,
#  H23_train,H4_train,H56_train,), out_train = pass_data_store_activations(analyses_train_loader, nTrain)

# %%
(L23_test,L4_test,L56_test,
 H23_test,H4_test,H56_test,), out_test = pass_data_store_activations(test_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:18<00:00,  5.33it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.38it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.35it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.41it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.42it/s]

# %%
(L23_temp,L4_temp,L56_temp,
 H23_temp,H4_temp,H56_temp,), out_temp = pass_data_store_activations(test_temp_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:18<00:00,  5.39it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.39it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.42it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.42it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.41it/s]

# %% [markdown]
# #### PCA for RNNs

# %%
def repsPCA(rnnActs):
    nEpochs, nSeqs, nRolls, nNeurons = rnnActs.shape
    pca_dict = {}
    nSamps = nSeqs*nRolls
    dimPCA = min(nNeurons,nSamps)
    repsR_transformed = np.zeros((nEpochs,nSamps,dimPCA))
    
    for ep in tqdm(range(nEpochs)):
        
        reps = rnnActs[ep]
        
        ## reshape
        repsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        for ii in range(nSeqs):
            for jj in range(nRolls):
                repsR[cnt] = reps[ii,jj]
                cnt += 1
        ## PCA
        rnnPCA = PCA()
        repsR_transformed[ep] = rnnPCA.fit_transform(repsR)
        pca_dict[str(ep)] = rnnPCA
        
    return repsR_transformed, pca_dict

# %%
# L23pca_train = {}
# L4pca_train = {}
# L56pca_train = {}

# H23pca_train = {}
# H4pca_train = {}
# H56pca_train = {}

L23pca_test = {}
L4pca_test = {}
L56pca_test = {}

H23pca_test = {}
H4pca_test = {}
H56pca_test = {}

L23pca_temp = {}
L4pca_temp = {}
L56pca_temp = {}

H23pca_temp = {}
H4pca_temp = {}
H56pca_temp = {}

# %%
# for cntr in range(nRuns):
#     L23pca_train[cntr], _ = repsPCA(L23_train[cntr])
#     L4pca_train[cntr], _ = repsPCA(L4_train[cntr])
#     L56pca_train[cntr], _ = repsPCA(L56_train[cntr])

#     H23pca_train[cntr], _ = repsPCA(H23_train[cntr])
#     H4pca_train[cntr], _ = repsPCA(H4_train[cntr])
#     H56pca_train[cntr], _ = repsPCA(H56_train[cntr])

# %%
for cntr in range(nRuns):
    L23pca_test[cntr], _ = repsPCA(L23_test[cntr])
    L4pca_test[cntr], _ = repsPCA(L4_test[cntr])
    L56pca_test[cntr], _ = repsPCA(L56_test[cntr])

    H23pca_test[cntr], _ = repsPCA(H23_test[cntr])
    H4pca_test[cntr], _ = repsPCA(H4_test[cntr])
    H56pca_test[cntr], _ = repsPCA(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 102.81it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.38it/s]
# 100%|██████████| 101/101 [00:00<00:00, 104.29it/s]
# 100%|██████████| 101/101 [00:00<00:00, 107.73it/s]
# 100%|██████████| 101/101 [00:00<00:00, 105.91it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.15it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.38it/s]
# 100%|██████████| 101/101 [00:00<00:00, 105.49it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.37it/s]
# 100%|██████████| 101/101 [00:00<00:00, 107.05it/s]
# 100%|██████████| 101/101 [00:00<00:00, 103.55it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.65it/s]
# 100%|██████████| 101/101 [00:00<00:00, 108.42it/s]
# 100%|██████████| 101/101 [00:00<00:00, 107.16it/s]
# 100%|██████████| 101/101 [00:00<00:00, 105.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 108.04it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.94it/s]
# 100%|██████████| 101/101 [00:00<00:00, 103.87it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.60it/s]
# 100%|██████████| 101/101 [00:00<00:00, 109.60it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.71it/s]
# 100%|██████████| 101/101 [00:00<00:00, 104.38it/s]
# 100%|██████████| 101/101 [00:00<00:00, 108.89it/s]
# 100%|██████████| 101/101 [00:00<00:00, 104.72it/s]
# 100%|██████████| 101/101 [00:00<00:00, 108.25it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.04it/s]
# 100%|██████████| 101/101 [00:00<00:00, 108.31it/s]
# 100%|██████████| 101/101 [00:00<00:00, 103.32it/s]
# 100%|██████████| 101/101 [00:00<00:00, 107.96it/s]

# %%
for cntr in range(nRuns):
    L23pca_temp[cntr], _ = repsPCA(L23_temp[cntr])
    L4pca_temp[cntr], _ = repsPCA(L4_temp[cntr])
    L56pca_temp[cntr], _ = repsPCA(L56_temp[cntr])

    H23pca_temp[cntr], _ = repsPCA(H23_temp[cntr])
    H4pca_temp[cntr], _ = repsPCA(H4_temp[cntr])
    H56pca_temp[cntr], _ = repsPCA(H56_temp[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 106.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 109.01it/s]
# 100%|██████████| 101/101 [00:00<00:00, 105.71it/s]
# 100%|██████████| 101/101 [00:00<00:00, 107.84it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.88it/s]
# 100%|██████████| 101/101 [00:00<00:00, 103.76it/s]
# 100%|██████████| 101/101 [00:00<00:00, 103.76it/s]
# 100%|██████████| 101/101 [00:00<00:00, 107.05it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.93it/s]
# 100%|██████████| 101/101 [00:00<00:00, 110.92it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.99it/s]
# 100%|██████████| 101/101 [00:00<00:00, 103.00it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.82it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.60it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.49it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.72it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.15it/s]
# 100%|██████████| 101/101 [00:00<00:00, 107.10it/s]
# 100%|██████████| 101/101 [00:00<00:00, 103.87it/s]
# 100%|██████████| 101/101 [00:00<00:00, 105.93it/s]
# 100%|██████████| 101/101 [00:00<00:00, 109.40it/s]
# 100%|██████████| 101/101 [00:00<00:00, 107.96it/s]
# 100%|██████████| 101/101 [00:00<00:00, 108.54it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.15it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.49it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.60it/s]
# 100%|██████████| 101/101 [00:00<00:00, 106.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 107.22it/s]
# 100%|██████████| 101/101 [00:00<00:00, 112.52it/s]
# 100%|██████████| 101/101 [00:00<00:00, 107.16it/s]

# %%
idxs0_train = np.array([6*x for x in range(nTrain)])
idxs1_train = idxs0_train + 1
idxs2_train = idxs0_train + 2
idxs3_train = idxs0_train + 3
idxs4_train = idxs0_train + 4
idxs5_train = idxs0_train + 5

# %%
idxs0_test = np.array([6*x for x in range(nTest)])
idxs1_test = idxs0_test + 1
idxs2_test = idxs0_test + 2
idxs3_test = idxs0_test + 3
idxs4_test = idxs0_test + 4
idxs5_test = idxs0_test + 5

# %%
# cnt = 4
# ep = -1
# ix = idxs5_train
# c = allStatesTrain[cnt][:,0]/numM
# s = 20*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_train[cnt][ep,ix,0],L4pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_train[cnt][ep,ix,0],L23pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_train[cnt][ep,ix,0],L56pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_train[cnt][ep,ix,0],H4pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_train[cnt][ep,ix,0],H23pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_train[cnt][ep,ix,0],H56pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H5/6')

# %%
# cnt = 4
# ep = 50
# ix = idxs4_test
# c = allStatesTest[cnt][:,0]/numM
# s = 20*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H5/6')

# %% [markdown]
# #### Subset indices, etc.

# %%
idxs00_train = np.hstack((idxs0_train.reshape(-1,1),idxs1_train.reshape(-1,1)))
idxs11_train = np.hstack((idxs2_train.reshape(-1,1),idxs3_train.reshape(-1,1)))
idxs22_train = np.hstack((idxs4_train.reshape(-1,1),idxs5_train.reshape(-1,1)))

# %%
idxs00_test = np.hstack((idxs0_test.reshape(-1,1),idxs1_test.reshape(-1,1))).ravel()
idxs11_test = np.hstack((idxs2_test.reshape(-1,1),idxs3_test.reshape(-1,1))).ravel()
idxs22_test = np.hstack((idxs4_test.reshape(-1,1),idxs5_test.reshape(-1,1))).ravel()

# %%
cleanPCs = {}
surpPCs = {}

contextPCs_sub = {}

# %%
for cntr in range(nRuns):
    cleanPCs[cntr] = (L4pca_test[cntr],L23pca_test[cntr],L56pca_test[cntr],
                      H4pca_test[cntr],H23pca_test[cntr],H56pca_test[cntr])
    surpPCs[cntr] = (L4pca_temp[cntr],L23pca_temp[cntr],L56pca_temp[cntr],
                     H4pca_temp[cntr],H23pca_temp[cntr],H56pca_temp[cntr])
    
    for rnnNo in range(len(rnn_names)):
        contextPCs_sub[cntr,rnnNo] = np.hstack((cleanPCs[cntr][rnnNo][:,idxs22_test,:],surpPCs[cntr][rnnNo][:,idxs22_test,:]))

# %%
context_sub_surp = np.array([0]*nRepeats*nTest + [1]*nRepeats*nTest)

# %%
context_sub_imgIDs = {}
for cntr in range(nRuns):
    context_sub_imgIDs[cntr] = np.hstack((np.repeat(labelsTest[cntr][:,2:3],nRepeats),
                                          np.repeat(labelsTestTemp[cntr][:,2:3],nRepeats)))

# %% [markdown]
# #### Supervised Decoding

# %%
sub_Eps = np.array([0,1,50])
ds_im = 100

# %%
def repsDecodeSupervisedContext(rnnActs,labels,decodeType='surprise',clf='logistic',sub=True,ds=ds_im):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'surprise':
        nClasses = 2
    elif decodeType == 'imageID':
        if sub:
            rnnActs = rnnActs[:,::ds,:]
            nEpochs, nSamps, nNeurons = rnnActs.shape
            labels = labels[::ds]
            nClasses = len(np.unique(labels))
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression(multi_class='ovr').fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)    
        
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
dims23 = np.array([1,2,4,8,16,32,64,80])
dims4 = np.array([1,2,4,8,16,32])
dims56 = np.array([1,2,4,8,16,32,64])

# %%
L23surpPC = {}
L4surpPC = {}
L56surpPC = {}

H23surpPC = {}
H4surpPC = {}
H56surpPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        
    for d in dims4:
        L4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
    
    for d in dims56:
        L56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  1.99it/s]

# %%
L23imgPC = {}
L4imgPC = {}
L56imgPC = {}

H23imgPC = {}
H4imgPC = {}
H56imgPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        
    for d in dims4:
        L4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][sub_Eps,:,:d],
                                                          context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][sub_Eps,:,:d],
                                                          context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
    
    for d in dims56:
        L56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
# Out:
# 100%|██████████| 5/5 [00:16<00:00,  3.33s/it]

# %% [markdown]
# #### Generate plots

# %%
preds_L23imgPC = {}
preds_L4imgPC = {}
preds_L56imgPC = {}

preds_H23imgPC = {}
preds_H4imgPC = {}
preds_H56imgPC = {}

preds_L23surpPC = {}
preds_L4surpPC = {}
preds_L56surpPC = {}

preds_H23surpPC = {}
preds_H4surpPC = {}
preds_H56surpPC = {}

# %%
accs_L23imgPC = {}
accs_L4imgPC = {}
accs_L56imgPC = {}

accs_H23imgPC = {}
accs_H4imgPC = {}
accs_H56imgPC = {}

accs_L23surpPC = {}
accs_L4surpPC = {}
accs_L56surpPC = {}

accs_H23surpPC = {}
accs_H4surpPC = {}
accs_H56surpPC = {}

# %%
for cntr in range(nRuns):
    for ep in range(len(sub_Eps)):
        
        for d in dims23:
            preds_L23imgPC[cntr,d,ep] = np.argmax(L23imgPC[cntr,d][ep],axis=-1)
            preds_H23imgPC[cntr,d,ep] = np.argmax(H23imgPC[cntr,d][ep],axis=-1)
            
            preds_L23surpPC[cntr,d,ep] = np.argmax(L23surpPC[cntr,d][ep],axis=-1)
            preds_H23surpPC[cntr,d,ep] = np.argmax(H23surpPC[cntr,d][ep],axis=-1)
            
            accs_L23imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L23imgPC[cntr,d,ep])
            accs_H23imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H23imgPC[cntr,d,ep])
            
            accs_L23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L23surpPC[cntr,d,ep])
            accs_H23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H23surpPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4imgPC[cntr,d,ep] = np.argmax(L4imgPC[cntr,d][ep],axis=-1)
            preds_H4imgPC[cntr,d,ep] = np.argmax(H4imgPC[cntr,d][ep],axis=-1)
            
            preds_L4surpPC[cntr,d,ep] = np.argmax(L4surpPC[cntr,d][ep],axis=-1)
            preds_H4surpPC[cntr,d,ep] = np.argmax(H4surpPC[cntr,d][ep],axis=-1)
            
            accs_L4imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L4imgPC[cntr,d,ep])
            accs_H4imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H4imgPC[cntr,d,ep])
            
            accs_L4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L4surpPC[cntr,d,ep])
            accs_H4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H4surpPC[cntr,d,ep])
                
        for d in dims56:        
            preds_L56imgPC[cntr,d,ep] = np.argmax(L56imgPC[cntr,d][ep],axis=-1)
            preds_H56imgPC[cntr,d,ep] = np.argmax(H56imgPC[cntr,d][ep],axis=-1)
            
            preds_L56surpPC[cntr,d,ep] = np.argmax(L56surpPC[cntr,d][ep],axis=-1)
            preds_H56surpPC[cntr,d,ep] = np.argmax(H56surpPC[cntr,d][ep],axis=-1)
            
            accs_L56imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L56imgPC[cntr,d,ep])
            accs_H56imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H56imgPC[cntr,d,ep])
            
            accs_L56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L56surpPC[cntr,d,ep])
            accs_H56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H56surpPC[cntr,d,ep])

# %%
tensor_accs_L23imgPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4imgPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56imgPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23imgPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4imgPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56imgPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_L23surpPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4surpPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56surpPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23surpPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4surpPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56surpPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

# %%
for ii in range(nRuns):
    for kk in range(len(sub_Eps)):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23imgPC[ii,jj,kk] = accs_L23imgPC[ii,d,kk]
            tensor_accs_H23imgPC[ii,jj,kk] = accs_H23imgPC[ii,d,kk]
            
            tensor_accs_L23surpPC[ii,jj,kk] = accs_L23surpPC[ii,d,kk]
            tensor_accs_H23surpPC[ii,jj,kk] = accs_H23surpPC[ii,d,kk]
            
        
        for jj,d in enumerate(dims4):
            tensor_accs_L4imgPC[ii,jj,kk] = accs_L4imgPC[ii,d,kk]
            tensor_accs_H4imgPC[ii,jj,kk] = accs_H4imgPC[ii,d,kk]
            
            tensor_accs_L4surpPC[ii,jj,kk] = accs_L4surpPC[ii,d,kk]
            tensor_accs_H4surpPC[ii,jj,kk] = accs_H4surpPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56imgPC[ii,jj,kk] = accs_L56imgPC[ii,d,kk]
            tensor_accs_H56imgPC[ii,jj,kk] = accs_H56imgPC[ii,d,kk]

            tensor_accs_L56surpPC[ii,jj,kk] = accs_L56surpPC[ii,d,kk]
            tensor_accs_H56surpPC[ii,jj,kk] = accs_H56surpPC[ii,d,kk]

# %%
mean_accs_L4imgPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23imgPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56imgPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4imgPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23imgPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56imgPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_L4surpPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23surpPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56surpPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4surpPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23surpPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56surpPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4imgPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23imgPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56imgPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4imgPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23imgPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56imgPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4surpPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23surpPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56surpPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4surpPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23surpPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56surpPC = np.zeros((len(dims56),len(sub_Eps)))

# %%
for ep in range(len(sub_Eps)):
    
    for dd, dims in enumerate(dims23):
        mean_accs_L23imgPC[dd,ep] = np.mean(tensor_accs_L23imgPC[:,dd,ep])
        mean_accs_H23imgPC[dd,ep] = np.mean(tensor_accs_H23imgPC[:,dd,ep])
        
        std_accs_L23imgPC[dd,ep] = np.var(tensor_accs_L23imgPC[:,dd,ep])
        std_accs_H23imgPC[dd,ep] = np.var(tensor_accs_H23imgPC[:,dd,ep])
        
        mean_accs_L23surpPC[dd,ep] = np.mean(tensor_accs_L23surpPC[:,dd,ep])
        mean_accs_H23surpPC[dd,ep] = np.mean(tensor_accs_H23surpPC[:,dd,ep])
        
        std_accs_L23surpPC[dd,ep] = np.var(tensor_accs_L23surpPC[:,dd,ep])
        std_accs_H23surpPC[dd,ep] = np.var(tensor_accs_H23surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims4):
        mean_accs_L4imgPC[dd,ep] = np.mean(tensor_accs_L4imgPC[:,dd,ep])
        mean_accs_H4imgPC[dd,ep] = np.mean(tensor_accs_H4imgPC[:,dd,ep])
        
        std_accs_L4imgPC[dd,ep] = np.var(tensor_accs_L4imgPC[:,dd,ep])
        std_accs_H4imgPC[dd,ep] = np.var(tensor_accs_H4imgPC[:,dd,ep])
        
        mean_accs_L4surpPC[dd,ep] = np.mean(tensor_accs_L4surpPC[:,dd,ep])
        mean_accs_H4surpPC[dd,ep] = np.mean(tensor_accs_H4surpPC[:,dd,ep])
        
        std_accs_L4surpPC[dd,ep] = np.var(tensor_accs_L4surpPC[:,dd,ep])
        std_accs_H4surpPC[dd,ep] = np.var(tensor_accs_H4surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims56):
        mean_accs_L56imgPC[dd,ep] = np.mean(tensor_accs_L56imgPC[:,dd,ep])        
        mean_accs_H56imgPC[dd,ep] = np.mean(tensor_accs_H56imgPC[:,dd,ep])
        
        std_accs_L56imgPC[dd,ep] = np.var(tensor_accs_L56imgPC[:,dd,ep])
        std_accs_H56imgPC[dd,ep] = np.var(tensor_accs_H56imgPC[:,dd,ep])
        
        mean_accs_L56surpPC[dd,ep] = np.mean(tensor_accs_L56surpPC[:,dd,ep])
        mean_accs_H56surpPC[dd,ep] = np.mean(tensor_accs_H56surpPC[:,dd,ep])
        
        std_accs_L56surpPC[dd,ep] = np.var(tensor_accs_L56surpPC[:,dd,ep])        
        std_accs_H56surpPC[dd,ep] = np.var(tensor_accs_H56surpPC[:,dd,ep])

# %%
ffsurp_dim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Surprise ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,0],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,0],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,0],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,0],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,0],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,0],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(132)
plt.title('Surprise ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,1],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,1],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,1],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,1],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,1],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,1],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(133)
plt.title('Surprise ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,-1],yerr=std_accs_L4surpPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,-1],yerr=std_accs_L23surpPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,-1],yerr=std_accs_L56surpPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,-1],yerr=std_accs_H4surpPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,-1],yerr=std_accs_H23surpPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,-1],yerr=std_accs_H56surpPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
ffdim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Image ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,0],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,0],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,0],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,0],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,0],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,0],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Image ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,1],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,1],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,1],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,1],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,1],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,1],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Image ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,-1],yerr=std_accs_L4imgPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,-1],yerr=std_accs_L23imgPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,-1],yerr=std_accs_L56imgPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,-1],yerr=std_accs_H4imgPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,-1],yerr=std_accs_H23imgPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,-1],yerr=std_accs_H56imgPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# #### Position

# %%
step_labels = np.array([x%nSteps for x in range(nTest*nSteps)])

# %%
def repsDecodeSupervisedPosition(rnnActs,labels,clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    nClasses = 6
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
L4posPC = {}
L23posPC = {}
L56posPC = {}
H4posPC = {}
H23posPC = {}
H56posPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][1][sub_Eps,:,:d],step_labels)
        H23posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][4][sub_Eps,:,:d],step_labels)
    
    for d in dims4:
        L4posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][0][sub_Eps,:,:d],step_labels)
        H4posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][3][sub_Eps,:,:d],step_labels)
        
    for d in dims56:
        ## Position
        L56posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][2][sub_Eps,:,:d],step_labels)      
        H56posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][5][sub_Eps,:,:d],step_labels)
# Out:
# 100%|██████████| 5/5 [00:27<00:00,  5.44s/it]

# %%
preds_L23posPC = {}
preds_L4posPC = {}
preds_L56posPC = {}

preds_H23posPC = {}
preds_H4posPC = {}
preds_H56posPC = {}

# %%
accs_L23posPC = {}
accs_L4posPC = {}
accs_L56posPC = {}

accs_H23posPC = {}
accs_H4posPC = {}
accs_H56posPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(len(sub_Eps)):
        
        for d in dims23:
            preds_L23posPC[cntr,d,ep] = np.argmax(L23posPC[cntr,d][ep],axis=-1)
            preds_H23posPC[cntr,d,ep] = np.argmax(H23posPC[cntr,d][ep],axis=-1)
            
            accs_L23posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L23posPC[cntr,d,ep])
            accs_H23posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H23posPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4posPC[cntr,d,ep] = np.argmax(L4posPC[cntr,d][ep],axis=-1)
            preds_H4posPC[cntr,d,ep] = np.argmax(H4posPC[cntr,d][ep],axis=-1)
            
            accs_L4posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L4posPC[cntr,d,ep])
            accs_H4posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H4posPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56posPC[cntr,d,ep] = np.argmax(L56posPC[cntr,d][ep],axis=-1)
            preds_H56posPC[cntr,d,ep] = np.argmax(H56posPC[cntr,d][ep],axis=-1)
            
            accs_L56posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L56posPC[cntr,d,ep])
            accs_H56posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H56posPC[cntr,d,ep])

# %%
tensor_accs_L23posPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4posPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56posPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23posPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4posPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56posPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

# %%
for ii in range(nRuns):
    
    for kk in range(len(sub_Eps)):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23posPC[ii,jj,kk] = accs_L23posPC[ii,d,kk]
            tensor_accs_H23posPC[ii,jj,kk] = accs_H23posPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4posPC[ii,jj,kk] = accs_L4posPC[ii,d,kk]
            tensor_accs_H4posPC[ii,jj,kk] = accs_H4posPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56posPC[ii,jj,kk] = accs_L56posPC[ii,d,kk]            
            tensor_accs_H56posPC[ii,jj,kk] = accs_H56posPC[ii,d,kk]

# %%
mean_accs_L4posPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23posPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56posPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4posPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23posPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56posPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4posPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23posPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56posPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4posPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23posPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56posPC = np.zeros((len(dims56),len(sub_Eps)))

# %%
for ep in range(len(sub_Eps)):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23posPC[dd,ep] = np.mean(tensor_accs_L23posPC[:,dd,ep])
        mean_accs_H23posPC[dd,ep] = np.mean(tensor_accs_H23posPC[:,dd,ep])
        
        std_accs_L23posPC[dd,ep] = np.var(tensor_accs_L23posPC[:,dd,ep])
        std_accs_H23posPC[dd,ep] = np.var(tensor_accs_H23posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4posPC[dd,ep] = np.mean(tensor_accs_L4posPC[:,dd,ep])
        mean_accs_H4posPC[dd,ep] = np.mean(tensor_accs_H4posPC[:,dd,ep])
        
        std_accs_L4posPC[dd,ep] = np.var(tensor_accs_L4posPC[:,dd,ep])
        std_accs_H4posPC[dd,ep] = np.var(tensor_accs_H4posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56posPC[dd,ep] = np.mean(tensor_accs_L56posPC[:,dd,ep])
        mean_accs_H56posPC[dd,ep] = np.mean(tensor_accs_H56posPC[:,dd,ep])
        
        std_accs_L56posPC[dd,ep] = np.var(tensor_accs_L56posPC[:,dd,ep])
        std_accs_H56posPC[dd,ep] = np.var(tensor_accs_H56posPC[:,dd,ep])

# %%
ffpos = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Position Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,0],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,0],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,0],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,0],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,0],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,0],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Position Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,1],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,1],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,1],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,1],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,1],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,1],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Position Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,-1],yerr=std_accs_L4posPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,-1],yerr=std_accs_L23posPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,-1],yerr=std_accs_L56posPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,-1],yerr=std_accs_H4posPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,-1],yerr=std_accs_H23posPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,-1],yerr=std_accs_H56posPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
np.save(pp+'preds_img_temp_L4-same-pop-binary',preds_L4imgPC)
np.save(pp+'preds_img_temp_L23-same-pop-binary',preds_L23imgPC)
np.save(pp+'preds_img_temp_L56-same-pop-binary',preds_L56imgPC)
np.save(pp+'preds_img_temp_H4-same-pop-binary',preds_H4imgPC)
np.save(pp+'preds_img_temp_H23-same-pop-binary',preds_H23imgPC)
np.save(pp+'preds_img_temp_H56-same-pop-binary',preds_H56imgPC)

np.save(pp+'accs_img_temp_L4-same-pop-binary',accs_L4imgPC)
np.save(pp+'accs_img_temp_L23-same-pop-binary',accs_L23imgPC)
np.save(pp+'accs_img_temp_L56-same-pop-binary',accs_L56imgPC)
np.save(pp+'accs_img_temp_H4-same-pop-binary',accs_H4imgPC)
np.save(pp+'accs_img_temp_H23-same-pop-binary',accs_H23imgPC)
np.save(pp+'accs_img_temp_H56-same-pop-binary',accs_H56imgPC)

# %%
np.save(pp+'preds_pos_temp_L4-same-pop-binary',preds_L4posPC)
np.save(pp+'preds_pos_temp_L23-same-pop-binary',preds_L23posPC)
np.save(pp+'preds_pos_temp_L56-same-pop-binary',preds_L56posPC)
np.save(pp+'preds_pos_temp_H4-same-pop-binary',preds_H4posPC)
np.save(pp+'preds_pos_temp_H23-same-pop-binary',preds_H23posPC)
np.save(pp+'preds_pos_temp_H56-same-pop-binary',preds_H56posPC)

np.save(pp+'accs_pos_temp_L4-same-pop-binary',accs_L4posPC)
np.save(pp+'accs_pos_temp_L23-same-pop-binary',accs_L23posPC)
np.save(pp+'accs_pos_temp_L56-same-pop-binary',accs_L56posPC)
np.save(pp+'accs_pos_temp_H4-same-pop-binary',accs_H4posPC)
np.save(pp+'accs_pos_temp_H23-same-pop-binary',accs_H23posPC)
np.save(pp+'accs_pos_temp_H56-same-pop-binary',accs_H56posPC)

# %%
np.save(pp+'preds_surp_temp_L4-same-pop-binary',preds_L4surpPC)
np.save(pp+'preds_surp_temp_L23-same-pop-binary',preds_L23surpPC)
np.save(pp+'preds_surp_temp_L56-same-pop-binary',preds_L56surpPC)
np.save(pp+'preds_surp_temp_H4-same-pop-binary',preds_H4surpPC)
np.save(pp+'preds_surp_temp_H23-same-pop-binary',preds_H23surpPC)
np.save(pp+'preds_surp_temp_H56-same-pop-binary',preds_H56surpPC)

np.save(pp+'accs_surp_temp_L4-same-pop-binary',accs_L4surpPC)
np.save(pp+'accs_surp_temp_L23-same-pop-binary',accs_L23surpPC)
np.save(pp+'accs_surp_temp_L56-same-pop-binary',accs_L56surpPC)
np.save(pp+'accs_surp_temp_H4-same-pop-binary',accs_H4surpPC)
np.save(pp+'accs_surp_temp_H23-same-pop-binary',accs_H23surpPC)
np.save(pp+'accs_surp_temp_H56-same-pop-binary',accs_H56surpPC)

# %% [markdown]
# #### Temporal accuracies

# %%
preds_test = {}
preds_temp = {}

accs_test = np.zeros((nRuns,n_epochs+1))
accs_temp = np.zeros((nRuns,n_epochs+1))

for cntr in range(nRuns):
    preds_test[cntr] = np.abs(np.round_(out_test[cntr]*(out_test[cntr]>0)))
    preds_temp[cntr] = np.abs(np.round_(out_test[cntr]*(out_temp[cntr]>0)))
    
    accs_test[cntr] = np.sum(np.sum(np.sum(((yRepsTest[cntr] - preds_test[cntr])==0)*1,-1),-1),-1)/np.prod(yRepsTest[cntr].shape)
    accs_temp[cntr] = np.sum(np.sum(np.sum(((yRepsTestTemp[cntr] - preds_temp[cntr])==0)*1,-1),-1),-1)/np.prod(yRepsTestTemp[cntr].shape)

# %%
ff_final_temp_noise = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_test,0),yerr=np.var(accs_test,0),fmt='-',label='Test - Clean')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_temp,0),yerr=np.var(accs_temp,0),fmt='-',label='Test - Surprise')
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend()
plt.title('Prediction accuracy in presence of temporal violation')
plt.show()

# %%
np.save(pp+'same-pop-no-violations-accs-binary',accs_test)
np.save(pp+'same-pop-temporal-violations-accs-binary',accs_temp)

# %%
ff_final_temp_noise.savefig('temporal-violation-final-acc-repeated-runs-same-pop-bianry.png',dpi=300,bbox_inches='tight')
ff_final_temp_noise.savefig('temporal-violation-final-acc-repeated-runs-same-pop-binary.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# #### Spatial violations

# %%
dim = 16

# %%
from numpy.random import normal

# %%
noise_stds = np.linspace(0,5,6)

# %%
noiseSeqs = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noiseSeqs[cntr,nn] = repsTest[cntr] + normal(0,noise,repsTest[cntr].shape)

# %%
noisy_loader_analyses = {}

for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noisy_loader_analyses[cntr,nn] = makeTensorLoaders((noiseSeqs[cntr,nn],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)

# %%
def pass_data_store_noisy_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        for nn in range(len(noise_stds)):
            activations_hidden_L23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_L4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_L56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_hidden_H23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_H4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_H56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_out_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,dim))

            for e in tqdm(range(n_epochs+1)):

                cnt = 0

                ## Load model
                model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr])
                model[cntr].to(device)
                model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
                model[cntr].eval()

                ## Pass clean samples
                for data, f_target, lastEvent, surpriseBinary in loader[cntr,nn]:

                    if train_on_gpu:
                        data, f_targetC = data.float().cuda(), f_target.float().cuda()
                    else: data, f_targetC = data.float(), f_target.float()

                    target = f_target

                    output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                    ## Collect activations  
                    act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                    act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                    act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                    act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                    act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                    act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                    output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                    for i in range(batch_size):
                        if i < len(data):
                            label = target.data[i]

                            activations_hidden_L23_np[cntr,nn][e,cnt] = act_hidden_L23[i]
                            activations_hidden_L4_np[cntr,nn][e,cnt] = act_hidden_L4[i]
                            activations_hidden_L56_np[cntr,nn][e,cnt] = act_hidden_L56[i]

                            activations_hidden_H23_np[cntr,nn][e,cnt] = act_hidden_H23[i]
                            activations_hidden_H4_np[cntr,nn][e,cnt] = act_hidden_H4[i]
                            activations_hidden_H56_np[cntr,nn][e,cnt] = act_hidden_H56[i]

                            activations_out_np[cntr,nn][e,cnt] = output_pred[i]

                            cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
(L23_noisy,L4_noisy,L56_noisy,
 H23_noisy,H4_noisy,H56_noisy,), out_noisy = pass_data_store_noisy_activations(noisy_loader_analyses, nTest)
# Out:
# 100%|██████████| 101/101 [00:19<00:00,  5.23it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.31it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.31it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.34it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.34it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.31it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.29it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.33it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.35it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.34it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.35it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.34it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.32it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.36it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.35it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.39it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.38it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.34it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.32it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.35it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.34it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.37it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.35it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.36it/s]
# 100%|██████████| 101/101 [00:19<00:00,  5.31it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.36it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.38it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.36it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.35it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.35it/s]

# %%
predsN = {}
accsN = np.zeros((nRuns,len(noise_stds),n_epochs+1))

# %%
for cntr in range(nRuns):
    for nn in range(len(noise_stds)):
        predsN[cntr,nn] = np.abs(np.round_(out_noisy[cntr,nn]*(out_noisy[cntr,nn]>0)))
        accsN[cntr,nn] = np.sum(np.sum(np.sum(((yRepsTest[cntr] - predsN[cntr,nn])==0)*1,-1),-1),-1)/np.prod(yRepsTest[cntr].shape)

# %%
name = "Dark2_r"
cmap = get_cmap(name)  # type: matplotlib.colors.ListedColormap
colors = cmap.colors  # type: list

# %%
fpredspat = plt.figure()
for nn, noise in enumerate(noise_stds):
    plt.errorbar(np.arange(n_epochs+1),np.mean(accsN[:,nn],0),yerr=np.var(accsN[:,nn],0),fmt='-',label=np.round(noise,2),
                 c=colors[nn])
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
# plt.ylim(0,1)
plt.legend(title="Noise sigma",bbox_to_anchor=(1,0.5))
plt.title('Prediction accuracy with spatial noise - Same Pop')
plt.show()

# %%
np.save(pp+'same-pop-spatial-noisy-accs-binary',accsN)

# %% [markdown]
# #### Dimesionality (linear)

# %%
def rnnLinDim(acts):
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    eig_mat = np.zeros((nEpochs,nNeurons))
        
    for ep in tqdm(range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        cov = actsScaled.T@actsScaled
        eig_mat[ep] = eigvals(cov)
        num = np.sum(eig_mat,1)**2
        den = np.sum(eig_mat**2,1) + 1e-17
        PR = num/den
    return PR

# %%
L23LinDim = np.zeros((nRuns,n_epochs+1))
L4LinDim = np.zeros((nRuns,n_epochs+1))
L56LinDim = np.zeros((nRuns,n_epochs+1))

H23LinDim = np.zeros((nRuns,n_epochs+1))
H4LinDim = np.zeros((nRuns,n_epochs+1))
H56LinDim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23LinDim[cntr] = rnnLinDim(L23_test[cntr])
    L4LinDim[cntr] = rnnLinDim(L4_test[cntr])
    L56LinDim[cntr] = rnnLinDim(L56_test[cntr])

    H23LinDim[cntr] = rnnLinDim(H23_test[cntr])
    H4LinDim[cntr] = rnnLinDim(H4_test[cntr])
    H56LinDim[cntr] = rnnLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:00<00:00, 142.83it/s]
# 100%|██████████| 101/101 [00:00<00:00, 146.23it/s]
# 100%|██████████| 101/101 [00:00<00:00, 142.63it/s]
# 100%|██████████| 101/101 [00:00<00:00, 141.24it/s]
# 100%|██████████| 101/101 [00:00<00:00, 142.03it/s]
# 100%|██████████| 101/101 [00:00<00:00, 150.36it/s]
# 100%|██████████| 101/101 [00:00<00:00, 149.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 141.83it/s]
# 100%|██████████| 101/101 [00:00<00:00, 148.82it/s]
# 100%|██████████| 101/101 [00:00<00:00, 144.98it/s]
# 100%|██████████| 101/101 [00:00<00:00, 147.41it/s]
# 100%|██████████| 101/101 [00:00<00:00, 147.62it/s]
# 100%|██████████| 101/101 [00:00<00:00, 147.62it/s]
# 100%|██████████| 101/101 [00:00<00:00, 147.19it/s]
# 100%|██████████| 101/101 [00:00<00:00, 154.13it/s]
# 100%|██████████| 101/101 [00:00<00:00, 142.63it/s]
# 100%|██████████| 101/101 [00:00<00:00, 143.54it/s]
# 100%|██████████| 101/101 [00:00<00:00, 148.71it/s]
# 100%|██████████| 101/101 [00:00<00:00, 146.98it/s]
# 100%|██████████| 101/101 [00:00<00:00, 143.04it/s]
# 100%|██████████| 101/101 [00:00<00:00, 140.65it/s]
# 100%|██████████| 101/101 [00:00<00:00, 149.81it/s]
# 100%|██████████| 101/101 [00:00<00:00, 145.29it/s]
# 100%|██████████| 101/101 [00:00<00:00, 146.03it/s]
# 100%|██████████| 101/101 [00:00<00:00, 152.51it/s]
# 100%|██████████| 101/101 [00:00<00:00, 143.04it/s]
# 100%|██████████| 101/101 [00:00<00:00, 144.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 150.48it/s]
# 100%|██████████| 101/101 [00:00<00:00, 144.26it/s]
# 100%|██████████| 101/101 [00:00<00:00, 144.46it/s]

# %% [markdown]
# #### Dimensionality (non-linear)

# %%
def rnnNonLinDim(acts,nTypes=2,subsample=True,ds=100):
    
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    dims_mat = np.zeros((nEpochs,nTypes))
        
    for ep in (range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        
        if subsample:
            actsScaled = actsScaled[::ds]
        
        dims_mat[ep,0] = MiND_ML().fit(actsScaled).dimension_
#         print(dims_mat[ep,0])
        dims_mat[ep,1] = CorrInt().fit(actsScaled).dimension_
#         print(dims_mat[ep,1])
#         dims_mat[ep,2] = MLE().fit(actsScaled).dimension_
#         print(dims_mat[ep,2])
#         dims_mat[ep,3] = DANCo().fit(actsScaled).dimension_
        
    return np.mean(dims_mat,-1),dims_mat

# %%
L23NonLinDim = np.zeros((nRuns,n_epochs+1))
L4NonLinDim = np.zeros((nRuns,n_epochs+1))
L56NonLinDim = np.zeros((nRuns,n_epochs+1))

H23NonLinDim = np.zeros((nRuns,n_epochs+1))
H4NonLinDim = np.zeros((nRuns,n_epochs+1))
H56NonLinDim = np.zeros((nRuns,n_epochs+1))

# %%
L23_ND_mat = {}
L4_ND_mat = {}
L56_ND_mat = {}
H23_ND_mat = {}
H4_ND_mat = {}
H56_ND_mat = {}

# %%
for cntr in tqdm(range(nRuns)):
    L23NonLinDim[cntr], L23_ND_mat[cntr] = rnnNonLinDim(L23_test[cntr])
    L4NonLinDim[cntr], L4_ND_mat[cntr] = rnnNonLinDim(L4_test[cntr])
    L56NonLinDim[cntr], L56_ND_mat[cntr] = rnnNonLinDim(L56_test[cntr])

    H23NonLinDim[cntr], H23_ND_mat[cntr] = rnnNonLinDim(H23_test[cntr])
    H4NonLinDim[cntr], H4_ND_mat[cntr] = rnnNonLinDim(H4_test[cntr])
    H56NonLinDim[cntr], H56_ND_mat[cntr] = rnnNonLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 5/5 [02:13<00:00, 26.62s/it]

# %%
L23_NonLineDim_mean = np.mean(L23NonLinDim,0)
L4_NonLineDim_mean = np.mean(L4NonLinDim,0)
L56_NonLineDim_mean = np.mean(L56NonLinDim,0)

H23_NonLineDim_mean = np.mean(H23NonLinDim,0)
H4_NonLineDim_mean = np.mean(H4NonLinDim,0)
H56_NonLineDim_mean = np.mean(H56NonLinDim,0)

L23_NonLineDim_std = np.var(L23NonLinDim,0)
L4_NonLineDim_std = np.var(L4NonLinDim,0)
L56_NonLineDim_std = np.var(L56NonLinDim,0)

H23_NonLineDim_std = np.var(H23NonLinDim,0)
H4_NonLineDim_std = np.var(H4NonLinDim,0)
H56_NonLineDim_std = np.var(H56NonLinDim,0)

# %%
L23_dim = np.zeros((nRuns,n_epochs+1))
L4_dim = np.zeros((nRuns,n_epochs+1))
L56_dim = np.zeros((nRuns,n_epochs+1))

H23_dim = np.zeros((nRuns,n_epochs+1))
H4_dim = np.zeros((nRuns,n_epochs+1))
H56_dim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23_dim[cntr] = L23LinDim[cntr]/L23NonLinDim[cntr]
    L4_dim[cntr] = L4LinDim[cntr]/L4NonLinDim[cntr]
    L56_dim[cntr] = L56LinDim[cntr]/L56NonLinDim[cntr]
    H23_dim[cntr] = H23LinDim[cntr]/H23NonLinDim[cntr]
    H4_dim[cntr] = H4LinDim[cntr]/H4NonLinDim[cntr]
    H56_dim[cntr] = H56LinDim[cntr]/H56NonLinDim[cntr]

# %%
np.save(pp+'L23DG_same-pop_binary',L23_dim)
np.save(pp+'L4DG_same-pop_binary',L4_dim)
np.save(pp+'L56DG_same-pop_binary',L56_dim)
np.save(pp+'H23DG_same-pop_binary',H23_dim)
np.save(pp+'H4DG_same-pop_binary',H4_dim)
np.save(pp+'H56DG_same-pop_binary',H56_dim)

# %%
ffTotDim = plt.figure(figsize=(5,5))

plt.subplot(111)

plt.plot(np.arange(n_epochs+1),np.mean(L4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(L4_dim,0)-np.var(L4_dim,0),np.mean(L4_dim,0)+np.var(L4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(L23_dim,0)-np.var(L23_dim,0),np.mean(L23_dim,0)+np.var(L23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(L56_dim,0)-np.var(L56_dim,0),np.mean(L56_dim,0)+np.var(L56_dim,0),alpha=0.5)

plt.plot(np.arange(n_epochs+1),np.mean(H4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(H4_dim,0)-np.var(H4_dim,0),np.mean(H4_dim,0)+np.var(H4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(H23_dim,0)-np.var(H23_dim,0),np.mean(H23_dim,0)+np.var(H23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(H56_dim,0)-np.var(H56_dim,0),np.mean(H56_dim,0)+np.var(H56_dim,0),alpha=0.5)

plt.xlabel('Epochs')
plt.ylabel('Dimensionality Gain')
# plt.ylim(0.9,2.2)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Same-Pop Microcircuit')
plt.show()

# %%
ffTotDim.savefig('Dimensionality-gain-same-pop-across-learning-binary.png',dpi=300,bbox_inches='tight')
ffTotDim.savefig('Dimensionality-gain-same-pop-across-learning-binary.svg',dpi=300,bbox_inches='tight')
