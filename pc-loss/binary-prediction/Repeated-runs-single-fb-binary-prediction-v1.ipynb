# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

from numpy.random import choice
from numpy.linalg import norm

from math import factorial

from itertools import permutations

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap

from tqdm import tqdm
import os

# %%
from numpy.linalg import svd, eigvals
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, homogeneity_completeness_v_measure, confusion_matrix, ConfusionMatrixDisplay, homogeneity_score

# %%
from skdim.id import *

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import get_cmap

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
plt.style.use('seaborn-whitegrid')
# plt.style.use('default')

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

# %%
from generate_data import generate_binary_rep_data, makeTensorLoaders

# %% [markdown]
# #### Test for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('No GPU, training on CPU')
    device = torch.device('cpu')
else:
    print('GPU found, training on GPU')
    device = torch.device('cuda')
# Out:
# GPU found, training on GPU

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Number of runs

# %%
nRuns = 5

# %% [markdown]
# #### Generate data for runs

# %%
dim = 16
nTot = 5000

fracTrain = 0.8
fracTest = np.round(1-fracTrain,2)

nTrain = int(nTot*fracTrain)
nTest = nTot - nTrain

lenSeq = 4
nRepeats = 2

# %%
numM = 2**dim-1

# %%
repsTrain = {}
yRepsTrain = {}
eTrain = {}
pTrain = {}
surpTrain = {}
allStatesTrain = {}

# %%
repsTest = {}
yRepsTest = {}
eTest = {}
pTest = {}
surpTest = {}
allStatesTest = {}

# %%
repsTestTemp = {}
yRepsTestTemp = {}
eTestTemp = {}
pTestTemp = {}
surpTestTemp = {}
allStatesTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]) = generate_binary_rep_data(nTot,fracTrain,dim,lenSeq)

# %%
labelsTrain = {}
labelsTest = {}
labelsTestTemp = {}

# %%
for cntr in range(nRuns):
    (repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),\
    (repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),\
    (repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),\
    (allStatesTrain[cntr],allStatesTest[cntr],allStatesTestTemp[cntr]) = generate_binary_rep_data(nTot,fracTrain,dim,lenSeq)

# %%
for cntr in range(nRuns):
    labelsTrain[cntr] = np.repeat(allStatesTrain[cntr][:,:-1],2).reshape(nTrain,-1)
    labelsTest[cntr] = np.repeat(allStatesTest[cntr][:,1:],2).reshape(nTest,-1)
    labelsTestTemp[cntr] = np.repeat(allStatesTestTemp[cntr][:,1:],2).reshape(nTest,-1)

# %% [markdown]
# #### Create directories to save data and representations

# %%
pp = ##specify path

# %%
npp = {}
pp_npy = {}
pp_pts = {}

# %%
for cntr in range(nRuns):
    
    npp[cntr] = 'binary-unidirectional-fb-'+str(cntr)+'/'
    pp_npy[cntr] = pp+npp[cntr]+'npys-'+str(cntr)+'/'
    pp_pts[cntr] = pp+npp[cntr]+'pts-'+str(cntr)+'/'
    
## uncomment the following lines to create the folders. comment out if already created
    
    # os.mkdir(os.path.join(pp,npp[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr]))
    # os.mkdir(os.path.join(pp,npp[cntr],pp_pts[cntr]))

    # os.mkdir(os.path.join(pp,npp[cntr],pp_npy[cntr],'Dataset/'))

# %% [markdown]
# #### Save seeds and dataset

# %%
seeds = np.random.randint(1000, size=nRuns)
np.save(pp_npy[cntr]+'seeds',seeds)

# %%
for cntr in range(nRuns):

    ## Train Data
    np.save(pp_npy[cntr]+'Dataset/repsTrain',repsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTrain',yRepsTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTrain',eTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTrain',surpTrain[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTrain',allStatesTrain[cntr])

    ## Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTest',repsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTest',yRepsTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTest',eTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTest',surpTest[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTest',allStatesTest[cntr])
    
    ## Temporally violated Test Data
    np.save(pp_npy[cntr]+'Dataset/repsTestTemp',repsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/yRepsTestTemp',yRepsTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/eTestTemp',eTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/surpTestTemp',surpTestTemp[cntr])
    np.save(pp_npy[cntr]+'Dataset/allStatesTestTemp',allStatesTestTemp[cntr])

# %% [markdown]
# #### Load seeds

# %%
seeds = np.load(pp_npy[cntr]+'seeds.npy')

# %% [markdown]
# #### Convert data into tensors, etc.

# %%
batch_size = 100 ##100

# %%
pos_seq_idx = np.array([0,0,1,1,2,2])

# %%
train_loader = {}
test_loader = {}
test_temp_loader = {}

# %%
for cntr in range(nRuns):
    train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=True)
    test_loader[cntr] = makeTensorLoaders((repsTest[cntr],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)
    test_temp_loader[cntr] = makeTensorLoaders((repsTestTemp[cntr],yRepsTestTemp[cntr],eTestTemp[cntr],surpTestTemp[cntr]),
                                          batch_size,shuffle=False)

# %%
# kk = 3
# print(np.min(allStatesTestTemp[kk]))
# ix = np.where(allStatesTestTemp[kk]==np.min(allStatesTestTemp[kk]))[0]
# print(repsTestTemp[kk][ix])
# print(yRepsTestTemp[kk][ix])

# %% [markdown]
# #### Load architectures, models, etc.

# %%
n_latent = 16 ## make sure it is the same in the architecture file as well
pop_list = [2,5,4] ## make sure it is the same in the architecture file as well

# %%
from architecture_single_feedback import microcircuit

# %%
model = {}
optimizer_rec = {}
optimizer_pc = {}

# %%
#specify loss function
reconLoss = nn.MSELoss()

#optimizer learning rate
eta_rec = 0.001
eta_pc = 0.0001

# %%
for cntr in range(nRuns):
    model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,pop_list=pop_list,bsize=batch_size,
                               manual_seed=seeds[cntr])
    model[cntr].to(device)
    optimizer_rec[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_rec)
    optimizer_pc[cntr] = torch.optim.Adam(model[cntr].parameters(), lr=eta_pc)

# %% [markdown]
# #### Train and collect activations

# %%
for data, f_target, lastEvent, surpriseBinary in train_loader[0]:
    if train_on_gpu:
        data, f_target = data.float().cuda(), f_target.float().cuda()
    else: data, f_target = data.float(), f_target.float()

# %%
output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[0](data)

# %%
nSteps = data.shape[1]

# %%
n_epochs = 100 ## number of epochs
div = n_epochs//n_epochs ## try ensuring that number used to divide by is a factor of n_epochs

# %%
feedback = True

# %%
def findMSE(output):
    errSq = output**2
    MSE_mat_samples_seq = errSq/np.prod(errSq.shape)
    MSE_samples = torch.mean(MSE_mat_samples_seq,1)
    return MSE_samples

# %%
train_losses = {}
test_losses = {}
temp_losses = {}

train_expected_rec_losses = {}
train_expected_fb_losses = {}

test_expected_rec_losses = {}
test_expected_fb_losses = {}

test_surprise_rec_losses = {}
test_surprise_fb_losses = {}

MSE_mat_full_test = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    train_losses[cntr] = np.zeros(n_epochs+1)
    test_losses[cntr] = np.zeros(n_epochs+1)
    temp_losses[cntr] = np.zeros(n_epochs+1)

    train_loss_min = np.Inf
    best_epoch = 0

    train_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    train_expected_fb_losses[cntr] = np.zeros(n_epochs+1)

    test_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_expected_fb_losses[cntr] = np.zeros(n_epochs+1)
    
    test_surprise_rec_losses[cntr] = np.zeros(n_epochs+1)
    test_surprise_fb_losses[cntr] = np.zeros(n_epochs+1)

    MSE_mat_full_test[cntr] = np.zeros(n_epochs+1)

    for epoch in (range(1,n_epochs+1)):

        train_loss = 0.0

        train_expected_rec_loss = 0.0
        train_expected_fb_loss = 0.0
        
        test_expected_rec_loss = 0.0
        test_expected_fb_loss = 0.0

        temp_rec_loss = 0.0
        temp_fb_loss = 0.0
        
        test_loss = 0.0
        temp_loss = 0.0

        cnt = 0
        
        ## Save model without training
        if epoch == 1:
            
            model[cntr].eval()
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_0.pt') ## Save model before any training
            
            ## Losses at 0th epoch
            for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
                if train_on_gpu:
                    data, f_target = data.float().cuda(), f_target.float().cuda()
                else:
                    data, f_target = data.float(), f_target.float()

                ##define all-sequence targets
                target = f_target

                optimizer_rec[cntr].zero_grad() #clears older gradients
                optimizer_pc[cntr].zero_grad() #clears older gradients
                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

                err_rec = torch.linalg.norm((output_pred-target),dim=2)
                err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
                MSE_samples_rec = findMSE(err_rec)
                MSE_samples_fb = findMSE(err_fb)

                loss = reconLoss(output_pred,target) #calculate the loss for the batch
                train_loss += loss.item()*data.size(0) #update training loss

                train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
                train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
                                    
            ## calculate average loss
            train_loss = train_loss/len(train_loader[cntr].dataset)
            
            ## Training loss at initialization
            train_losses[cntr][0] = train_loss
            train_expected_rec_losses[cntr][0] = train_expected_rec_loss
            train_expected_fb_losses[cntr][0] = train_expected_fb_loss
            
            ## Test losses at initialization
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test

                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)
                
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                # calculate the batch loss
                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
#             print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][0] = test_loss

            test_expected_rec_losses[cntr][0] = test_expected_rec_loss
            test_expected_fb_losses[cntr][0] = test_expected_fb_loss
        
        ## Test temp losses at initialization
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                    
                ##define all-sequence targets
                target_temp = f_target_temp

                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)
                loss_temp = reconLoss(output_pred_temp,target_temp)
                err_temp_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                # calculate the batch loss
                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_temp.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
#             print('Temp Loss: {:.6f}\n'.format(test_loss))

            temp_losses[cntr][0] = temp_loss

            test_surprise_rec_losses[cntr][0] = temp_rec_loss
            test_surprise_fb_losses[cntr][0] = temp_fb_loss

        #train model
        model[cntr].train()
        for data, f_target, lastEvent, surpriseBinary in train_loader[cntr]:
            if train_on_gpu:
                data, f_target = data.float().cuda(), f_target.float().cuda()
            else:
                data, f_target = data.float(), f_target.float()

            ##define all-sequence targets
            target = f_target

            output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data) #forward pass

            err_rec = torch.linalg.norm((output_pred-target),dim=2)
            err_fb = (torch.linalg.norm(feedbackDiffs[0],dim=2)+torch.linalg.norm(feedbackDiffs[1],dim=2))/2
            MSE_samples_rec = findMSE(err_rec)
            MSE_samples_fb = findMSE(err_fb)
            
            loss = reconLoss(output_pred,target) #calculate the loss for the batch
            train_loss += loss.item()*data.size(0) #update training loss
            fbloss = torch.mean(MSE_samples_fb)

            optimizer_rec[cntr].zero_grad() #clears older gradients
            optimizer_pc[cntr].zero_grad() #clears older gradients
            ######## feedback error updates only higher-cortical area
            if (feedback)&(epoch%2==0):
                for name, param in model[cntr].named_parameters():
                    if ('FF' in name) or ('L23' in name) or ('L4' in name) or ('L56' in name):
                        param.require_grad = False
                fbloss.backward()
                optimizer_pc[cntr].step()
                for name, param in model[cntr].named_parameters():
                    param.require_grad = True
            else:
                loss.backward() #backprop
                optimizer_rec[cntr].step() #update parameters in direction of the -ve gradient  

            train_expected_rec_loss += torch.mean(MSE_samples_rec[torch.where(surpriseBinary==0)[0]])
            train_expected_fb_loss += torch.mean(MSE_samples_fb[torch.where(surpriseBinary==0)[0]])
        
        #calculate average loss
        train_loss = train_loss/len(train_loader[cntr].dataset)

        #training/validation stats
        train_losses[cntr][epoch] = train_loss
        train_expected_rec_losses[cntr][epoch] = train_expected_rec_loss
        train_expected_fb_losses[cntr][epoch] = train_expected_fb_loss

        #save model if the training loss decreased
        if train_loss <= train_loss_min:
            print('Epoch: {}, Train Loss Decreased!! ({:.6f}-->{:.6f})'.format(epoch,train_loss_min,train_loss))
            torch.save(model[cntr].state_dict(),pp_pts[cntr]+'predRNN.pt')
            train_loss_min = train_loss
            best_epoch = epoch

        if epoch%div == 0:
            torch.save(model[cntr].state_dict(), pp_pts[cntr]+'predRNN_epoch_'+str(epoch)+'.pt')
            
            model[cntr].eval()
            
            for data_test, f_target_test, le_test, sb_test in test_loader[cntr]:
                if train_on_gpu:
                    data_test, f_target_test = data_test.float().cuda(), f_target_test.float().cuda()
                else:
                    data_test, f_target_test = data_test.float(), f_target_test.float()
                
                ##define all-sequence targets
                target_test = f_target_test
                
                ## outputs
                output_pred_test, RNN_outputs_test, feedbackDiffs_test, projInterArea_test = model[cntr](data_test)

                # calculate the batch loss
                err_test_rec = torch.linalg.norm((output_pred_test-target_test),dim=2)
                err_test_fb = (torch.linalg.norm(feedbackDiffs_test[0],dim=2)+torch.linalg.norm(feedbackDiffs_test[1],dim=2))/2
                MSE_samples_rec_test = findMSE(err_test_rec)
                MSE_samples_fb_test = findMSE(err_test_fb)

                test_expected_rec_loss += torch.mean(MSE_samples_rec_test[torch.where(sb_test==0)[0]])
                test_expected_fb_loss += torch.mean(MSE_samples_fb_test[torch.where(sb_test==0)[0]])
                loss_test = reconLoss(output_pred_test,target_test)

                # update test loss 
                test_loss += loss_test.item()*data_test.size(0)

            # average test loss
            test_loss = test_loss/len(test_loader[cntr].dataset)
            print('Test Loss: {:.6f}\n'.format(test_loss))

            test_losses[cntr][epoch] = test_loss

            test_expected_rec_losses[cntr][epoch] = test_expected_rec_loss
            test_expected_fb_losses[cntr][epoch] = test_expected_fb_loss
            
            for data_temp, f_target_temp, le_temp, sb_temp in test_temp_loader[cntr]:
                if train_on_gpu:
                    data_temp, f_target_temp = data_temp.float().cuda(), f_target_temp.float().cuda()
                else:
                    data_temp, f_target_temp = data_temp.float(), f_target_temp.float()
                
                ##define all-sequence targets
                target_temp = f_target_temp
                
                ## outputs
                output_pred_temp, RNN_outputs_temp, feedbackDiffs_temp, projInterArea_temp = model[cntr](data_temp)

                # calculate the batch loss
                err_temp_rec = torch.linalg.norm((output_pred_temp-target_temp),dim=2)
                err_temp_fb = (torch.linalg.norm(feedbackDiffs_temp[0],dim=2)+torch.linalg.norm(feedbackDiffs_temp[1],dim=2))/2
                MSE_samples_rec_temp = findMSE(err_temp_rec)
                MSE_samples_fb_temp = findMSE(err_temp_fb)

                temp_rec_loss += torch.mean(MSE_samples_rec_temp[torch.where(sb_test==0)[0]])
                temp_fb_loss += torch.mean(MSE_samples_fb_temp[torch.where(sb_test==0)[0]])
                loss_temp = reconLoss(output_pred_temp,target_temp)

                # update test loss 
                temp_loss += loss_temp.item()*data_test.size(0)

            # average test loss
            temp_loss = temp_loss/len(test_temp_loader[cntr].dataset)
            print('Temp Loss: {:.6f}\n'.format(temp_loss))

            temp_losses[cntr][epoch] = temp_loss

            test_surprise_rec_losses[cntr][epoch] = temp_rec_loss
            test_surprise_fb_losses[cntr][epoch] = temp_fb_loss
            
    print('----------------------------------------------------')
            
    outF = open(pp+npp[cntr]+"training-details.txt", "w")
    outF.write('# epochs = ' + str(n_epochs))
    outF.write('\n')
    outF.write('Best epoch = '+str(best_epoch))
    outF.write('\n')
    outF.write('Minimum training loss = ' + str(train_loss_min))
    outF.write('\n')
    outF.write('Total number of samples = ' + str(nTot))
    outF.write('\n')
    outF.write('Number of training samples = ' + str(nTrain))
    outF.write('\n')
    outF.write('Number of testing samples = ' + str(nTest))
    outF.write('\n')
    outF.write('Dimensionality of representations = ' + str(dim))
    outF.write('\n')
    outF.write('Length of sequences = ' + str(lenSeq))
    outF.write('\n')
    outF.close()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1, Train Loss Decreased!! (inf-->0.295810)
# Test Loss: 0.253352
#
# Temp Loss: 0.253380
#
# Epoch: 2, Train Loss Decreased!! (0.295810-->0.252174)
# Test Loss: 0.253015
#
# Temp Loss: 0.252998
#
# Epoch: 3, Train Loss Decreased!! (0.252174-->0.248051)
# Test Loss: 0.241526
#
# Temp Loss: 0.242504
#
# Epoch: 4, Train Loss Decreased!! (0.248051-->0.241462)
# Test Loss: 0.242230
#
# Temp Loss: 0.243449
#
# Epoch: 5, Train Loss Decreased!! (0.241462-->0.233209)
# Test Loss: 0.225452
#
# Temp Loss: 0.226171
#
# Epoch: 6, Train Loss Decreased!! (0.233209-->0.226319)
# Test Loss: 0.229568
#
# Temp Loss: 0.230175
#
# Epoch: 7, Train Loss Decreased!! (0.226319-->0.215213)
# Test Loss: 0.208867
#
# Temp Loss: 0.211565
#
# Epoch: 8, Train Loss Decreased!! (0.215213-->0.208004)
# Test Loss: 0.212341
#
# Temp Loss: 0.215143
#
# Epoch: 9, Train Loss Decreased!! (0.208004-->0.197066)
# Test Loss: 0.187729
#
# Temp Loss: 0.203384
#
# Epoch: 10, Train Loss Decreased!! (0.197066-->0.187197)
# Test Loss: 0.192209
#
# Temp Loss: 0.206895
#
# Epoch: 11, Train Loss Decreased!! (0.187197-->0.175853)
# Test Loss: 0.163309
#
# Temp Loss: 0.192834
#
# Epoch: 12, Train Loss Decreased!! (0.175853-->0.165797)
# Test Loss: 0.172992
#
# Temp Loss: 0.199233
#
# Epoch: 13, Train Loss Decreased!! (0.165797-->0.157639)
# Test Loss: 0.153354
#
# Temp Loss: 0.184521
#
# Epoch: 14, Train Loss Decreased!! (0.157639-->0.153892)
# Test Loss: 0.159823
#
# Temp Loss: 0.188436
#
# Epoch: 15, Train Loss Decreased!! (0.153892-->0.148751)
# Test Loss: 0.143200
#
# Temp Loss: 0.173681
#
# Epoch: 16, Train Loss Decreased!! (0.148751-->0.144800)
# Test Loss: 0.151024
#
# Temp Loss: 0.179657
#
# Epoch: 17, Train Loss Decreased!! (0.144800-->0.136402)
# Test Loss: 0.127771
#
# Temp Loss: 0.158856
#
# Epoch: 18, Train Loss Decreased!! (0.136402-->0.131395)
# Test Loss: 0.139576
#
# Temp Loss: 0.168981
#
# Epoch: 19, Train Loss Decreased!! (0.131395-->0.125030)
# Test Loss: 0.120843
#
# Temp Loss: 0.152956
#
# Epoch: 20, Train Loss Decreased!! (0.125030-->0.122579)
# Test Loss: 0.129486
#
# Temp Loss: 0.159883
#
# Epoch: 21, Train Loss Decreased!! (0.122579-->0.116855)
# Test Loss: 0.111775
#
# Temp Loss: 0.147262
#
# Test Loss: 0.131900
#
# Temp Loss: 0.164616
#
# Epoch: 23, Train Loss Decreased!! (0.116855-->0.110509)
# Test Loss: 0.105517
#
# Temp Loss: 0.140882
#
# Epoch: 24, Train Loss Decreased!! (0.110509-->0.106841)
# Test Loss: 0.114391
#
# Temp Loss: 0.147715
#
# Epoch: 25, Train Loss Decreased!! (0.106841-->0.100814)
# Test Loss: 0.093514
#
# Temp Loss: 0.129645
#
# Epoch: 26, Train Loss Decreased!! (0.100814-->0.096206)
# Test Loss: 0.104272
#
# Temp Loss: 0.138220
#
# Epoch: 27, Train Loss Decreased!! (0.096206-->0.089073)
# Test Loss: 0.082865
#
# Temp Loss: 0.121019
#
# Epoch: 28, Train Loss Decreased!! (0.089073-->0.086891)
# Test Loss: 0.095916
#
# Temp Loss: 0.131047
#
# Epoch: 29, Train Loss Decreased!! (0.086891-->0.080107)
# Test Loss: 0.074162
#
# Temp Loss: 0.113280
#
# Epoch: 30, Train Loss Decreased!! (0.080107-->0.077664)
# Test Loss: 0.085154
#
# Temp Loss: 0.122213
#
# Epoch: 31, Train Loss Decreased!! (0.077664-->0.073923)
# Test Loss: 0.070709
#
# Temp Loss: 0.111545
#
# Epoch: 32, Train Loss Decreased!! (0.073923-->0.073363)
# Test Loss: 0.079250
#
# Temp Loss: 0.117359
#
# Epoch: 33, Train Loss Decreased!! (0.073363-->0.071042)
# Test Loss: 0.068431
#
# Temp Loss: 0.108340
#
# Epoch: 34, Train Loss Decreased!! (0.071042-->0.070782)
# Test Loss: 0.075672
#
# Temp Loss: 0.113393
#
# Epoch: 35, Train Loss Decreased!! (0.070782-->0.068344)
# Test Loss: 0.065234
#
# Temp Loss: 0.105601
#
# Epoch: 36, Train Loss Decreased!! (0.068344-->0.067515)
# Test Loss: 0.072137
#
# Temp Loss: 0.110498
#
# Epoch: 37, Train Loss Decreased!! (0.067515-->0.063229)
# Test Loss: 0.056978
#
# Temp Loss: 0.097817
#
# Epoch: 38, Train Loss Decreased!! (0.063229-->0.061605)
# Test Loss: 0.068250
#
# Temp Loss: 0.106567
#
# Epoch: 39, Train Loss Decreased!! (0.061605-->0.057515)
# Test Loss: 0.053971
#
# Temp Loss: 0.093798
#
# Epoch: 40, Train Loss Decreased!! (0.057515-->0.057304)
# Test Loss: 0.062728
#
# Temp Loss: 0.100224
#
# Epoch: 41, Train Loss Decreased!! (0.057304-->0.054983)
# Test Loss: 0.052628
#
# Temp Loss: 0.092790
#
# Test Loss: 0.059424
#
# Temp Loss: 0.097328
#
# Epoch: 43, Train Loss Decreased!! (0.054983-->0.053251)
# Test Loss: 0.051472
#
# Temp Loss: 0.091851
#
# Test Loss: 0.056965
#
# Temp Loss: 0.095481
#
# Epoch: 45, Train Loss Decreased!! (0.053251-->0.051941)
# Test Loss: 0.050299
#
# Temp Loss: 0.091845
#
# Test Loss: 0.056070
#
# Temp Loss: 0.095143
#
# Epoch: 47, Train Loss Decreased!! (0.051941-->0.050513)
# Test Loss: 0.048204
#
# Temp Loss: 0.089646
#
# Epoch: 48, Train Loss Decreased!! (0.050513-->0.050248)
# Test Loss: 0.053559
#
# Temp Loss: 0.093223
#
# Epoch: 49, Train Loss Decreased!! (0.050248-->0.047682)
# Test Loss: 0.044462
#
# Temp Loss: 0.086970
#
# Epoch: 50, Train Loss Decreased!! (0.047682-->0.046553)
# Test Loss: 0.050551
#
# Temp Loss: 0.091177
#
# Epoch: 51, Train Loss Decreased!! (0.046553-->0.043636)
# Test Loss: 0.040400
#
# Temp Loss: 0.084285
#
# Epoch: 52, Train Loss Decreased!! (0.043636-->0.042635)
# Test Loss: 0.047010
#
# Temp Loss: 0.089045
#
# Epoch: 53, Train Loss Decreased!! (0.042635-->0.039799)
# Test Loss: 0.036346
#
# Temp Loss: 0.081999
#
# Test Loss: 0.047932
#
# Temp Loss: 0.091745
#
# Epoch: 55, Train Loss Decreased!! (0.039799-->0.036851)
# Test Loss: 0.033261
#
# Temp Loss: 0.082033
#
# Test Loss: 0.048591
#
# Temp Loss: 0.094115
#
# Epoch: 57, Train Loss Decreased!! (0.036851-->0.034406)
# Test Loss: 0.030475
#
# Temp Loss: 0.082272
#
# Test Loss: 0.045506
#
# Temp Loss: 0.093712
#
# Epoch: 59, Train Loss Decreased!! (0.034406-->0.032182)
# Test Loss: 0.028526
#
# Temp Loss: 0.082180
#
# Test Loss: 0.044547
#
# Temp Loss: 0.094107
#
# Epoch: 61, Train Loss Decreased!! (0.032182-->0.030006)
# Test Loss: 0.025840
#
# Temp Loss: 0.082466
#
# Test Loss: 0.041378
#
# Temp Loss: 0.093760
#
# Epoch: 63, Train Loss Decreased!! (0.030006-->0.026867)
# Test Loss: 0.022594
#
# Temp Loss: 0.083133
#
# Test Loss: 0.040934
#
# Temp Loss: 0.096311
#
# Epoch: 65, Train Loss Decreased!! (0.026867-->0.023529)
# Test Loss: 0.018980
#
# Temp Loss: 0.083159
#
# Test Loss: 0.033856
#
# Temp Loss: 0.092516
#
# Epoch: 67, Train Loss Decreased!! (0.023529-->0.019874)
# Test Loss: 0.016180
#
# Temp Loss: 0.083198
#
# Test Loss: 0.033372
#
# Temp Loss: 0.094052
#
# Epoch: 69, Train Loss Decreased!! (0.019874-->0.017812)
# Test Loss: 0.014138
#
# Temp Loss: 0.083809
#
# Test Loss: 0.030151
#
# Temp Loss: 0.092764
#
# Epoch: 71, Train Loss Decreased!! (0.017812-->0.016419)
# Test Loss: 0.012727
#
# Temp Loss: 0.084020
#
# Test Loss: 0.028175
#
# Temp Loss: 0.092426
#
# Epoch: 73, Train Loss Decreased!! (0.016419-->0.014960)
# Test Loss: 0.011599
#
# Temp Loss: 0.084248
#
# Test Loss: 0.026414
#
# Temp Loss: 0.091477
#
# Epoch: 75, Train Loss Decreased!! (0.014960-->0.013783)
# Test Loss: 0.010953
#
# Temp Loss: 0.084544
#
# Test Loss: 0.025372
#
# Temp Loss: 0.091995
#
# Epoch: 77, Train Loss Decreased!! (0.013783-->0.013102)
# Test Loss: 0.010258
#
# Temp Loss: 0.084802
#
# Test Loss: 0.026728
#
# Temp Loss: 0.093415
#
# Epoch: 79, Train Loss Decreased!! (0.013102-->0.012685)
# Test Loss: 0.009662
#
# Temp Loss: 0.084602
#
# Test Loss: 0.023333
#
# Temp Loss: 0.091149
#
# Epoch: 81, Train Loss Decreased!! (0.012685-->0.011456)
# Test Loss: 0.008711
#
# Temp Loss: 0.084506
#
# Test Loss: 0.023812
#
# Temp Loss: 0.092449
#
# Epoch: 83, Train Loss Decreased!! (0.011456-->0.011023)
# Test Loss: 0.008133
#
# Temp Loss: 0.084874
#
# Test Loss: 0.024285
#
# Temp Loss: 0.093380
#
# Epoch: 85, Train Loss Decreased!! (0.011023-->0.010469)
# Test Loss: 0.007838
#
# Temp Loss: 0.085191
#
# Test Loss: 0.024421
#
# Temp Loss: 0.093902
#
# Test Loss: 0.007375
#
# Temp Loss: 0.084667
#
# Test Loss: 0.022076
#
# Temp Loss: 0.092625
#
# Epoch: 89, Train Loss Decreased!! (0.010469-->0.009993)
# Test Loss: 0.007129
#
# Temp Loss: 0.085239
#
# Test Loss: 0.021879
#
# Temp Loss: 0.093179
#
# Epoch: 91, Train Loss Decreased!! (0.009993-->0.009626)
# Test Loss: 0.006682
#
# Temp Loss: 0.085395
#
# Test Loss: 0.020457
#
# Temp Loss: 0.092218
#
# Epoch: 93, Train Loss Decreased!! (0.009626-->0.009080)
# Test Loss: 0.006420
#
# Temp Loss: 0.085335
#
# Test Loss: 0.021104
#
# Temp Loss: 0.092605
#
# Epoch: 95, Train Loss Decreased!! (0.009080-->0.009023)
# Test Loss: 0.006201
#
# Temp Loss: 0.085046
#
# Test Loss: 0.021266
#
# Temp Loss: 0.092673
#
# Epoch: 97, Train Loss Decreased!! (0.009023-->0.008816)
# Test Loss: 0.005981
#
# Temp Loss: 0.084958
#
# Test Loss: 0.020245
#
# Temp Loss: 0.092217
#
# Epoch: 99, Train Loss Decreased!! (0.008816-->0.008454)
# Test Loss: 0.005810
#
# Temp Loss: 0.085147
#  20%|██        | 1/5 [02:00<08:03, 120.98s/it]
# Test Loss: 0.019660
#
# Temp Loss: 0.092617
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.288387)
# Test Loss: 0.252394
#
# Temp Loss: 0.252426
#
# Epoch: 2, Train Loss Decreased!! (0.288387-->0.251735)
# Test Loss: 0.251827
#
# Temp Loss: 0.251813
#
# Epoch: 3, Train Loss Decreased!! (0.251735-->0.244941)
# Test Loss: 0.234023
#
# Temp Loss: 0.234040
#
# Epoch: 4, Train Loss Decreased!! (0.244941-->0.234742)
# Test Loss: 0.235952
#
# Temp Loss: 0.236367
#
# Epoch: 5, Train Loss Decreased!! (0.234742-->0.227529)
# Test Loss: 0.221113
#
# Temp Loss: 0.221681
#
# Epoch: 6, Train Loss Decreased!! (0.227529-->0.221825)
# Test Loss: 0.223705
#
# Temp Loss: 0.224778
#
# Epoch: 7, Train Loss Decreased!! (0.221825-->0.209339)
# Test Loss: 0.195847
#
# Temp Loss: 0.200278
#
# Epoch: 8, Train Loss Decreased!! (0.209339-->0.194043)
# Test Loss: 0.196587
#
# Temp Loss: 0.200782
#
# Epoch: 9, Train Loss Decreased!! (0.194043-->0.179853)
# Test Loss: 0.166407
#
# Temp Loss: 0.187263
#
# Epoch: 10, Train Loss Decreased!! (0.179853-->0.166611)
# Test Loss: 0.171188
#
# Temp Loss: 0.190592
#
# Epoch: 11, Train Loss Decreased!! (0.166611-->0.155679)
# Test Loss: 0.147723
#
# Temp Loss: 0.176268
#
# Epoch: 12, Train Loss Decreased!! (0.155679-->0.149296)
# Test Loss: 0.155990
#
# Temp Loss: 0.183094
#
# Epoch: 13, Train Loss Decreased!! (0.149296-->0.142121)
# Test Loss: 0.140816
#
# Temp Loss: 0.171456
#
# Epoch: 14, Train Loss Decreased!! (0.142121-->0.139097)
# Test Loss: 0.144890
#
# Temp Loss: 0.175249
#
# Epoch: 15, Train Loss Decreased!! (0.139097-->0.136617)
# Test Loss: 0.137250
#
# Temp Loss: 0.169106
#
# Epoch: 16, Train Loss Decreased!! (0.136617-->0.134919)
# Test Loss: 0.140331
#
# Temp Loss: 0.170876
#
# Epoch: 17, Train Loss Decreased!! (0.134919-->0.133314)
# Test Loss: 0.132841
#
# Temp Loss: 0.165807
#
# Epoch: 18, Train Loss Decreased!! (0.133314-->0.131394)
# Test Loss: 0.136943
#
# Temp Loss: 0.168297
#
# Epoch: 19, Train Loss Decreased!! (0.131394-->0.124470)
# Test Loss: 0.119521
#
# Temp Loss: 0.152777
#
# Epoch: 20, Train Loss Decreased!! (0.124470-->0.118146)
# Test Loss: 0.123040
#
# Temp Loss: 0.155588
#
# Epoch: 21, Train Loss Decreased!! (0.118146-->0.110477)
# Test Loss: 0.103998
#
# Temp Loss: 0.138184
#
# Epoch: 22, Train Loss Decreased!! (0.110477-->0.105216)
# Test Loss: 0.112730
#
# Temp Loss: 0.145146
#
# Epoch: 23, Train Loss Decreased!! (0.105216-->0.097771)
# Test Loss: 0.093849
#
# Temp Loss: 0.128508
#
# Epoch: 24, Train Loss Decreased!! (0.097771-->0.095806)
# Test Loss: 0.105827
#
# Temp Loss: 0.139158
#
# Epoch: 25, Train Loss Decreased!! (0.095806-->0.090114)
# Test Loss: 0.086833
#
# Temp Loss: 0.123421
#
# Epoch: 26, Train Loss Decreased!! (0.090114-->0.087592)
# Test Loss: 0.095869
#
# Temp Loss: 0.131048
#
# Epoch: 27, Train Loss Decreased!! (0.087592-->0.083380)
# Test Loss: 0.081546
#
# Temp Loss: 0.119693
#
# Epoch: 28, Train Loss Decreased!! (0.083380-->0.081426)
# Test Loss: 0.088862
#
# Temp Loss: 0.125445
#
# Epoch: 29, Train Loss Decreased!! (0.081426-->0.076791)
# Test Loss: 0.073878
#
# Temp Loss: 0.110811
#
# Epoch: 30, Train Loss Decreased!! (0.076791-->0.073179)
# Test Loss: 0.081061
#
# Temp Loss: 0.116237
#
# Epoch: 31, Train Loss Decreased!! (0.073179-->0.069063)
# Test Loss: 0.068148
#
# Temp Loss: 0.104722
#
# Epoch: 32, Train Loss Decreased!! (0.069063-->0.067560)
# Test Loss: 0.074664
#
# Temp Loss: 0.110057
#
# Epoch: 33, Train Loss Decreased!! (0.067560-->0.064547)
# Test Loss: 0.063451
#
# Temp Loss: 0.100046
#
# Epoch: 34, Train Loss Decreased!! (0.064547-->0.062679)
# Test Loss: 0.068985
#
# Temp Loss: 0.104380
#
# Epoch: 35, Train Loss Decreased!! (0.062679-->0.058792)
# Test Loss: 0.056554
#
# Temp Loss: 0.095828
#
# Epoch: 36, Train Loss Decreased!! (0.058792-->0.055979)
# Test Loss: 0.062285
#
# Temp Loss: 0.100037
#
# Epoch: 37, Train Loss Decreased!! (0.055979-->0.051463)
# Test Loss: 0.049621
#
# Temp Loss: 0.089487
#
# Epoch: 38, Train Loss Decreased!! (0.051463-->0.049434)
# Test Loss: 0.056389
#
# Temp Loss: 0.094017
#
# Epoch: 39, Train Loss Decreased!! (0.049434-->0.046295)
# Test Loss: 0.045736
#
# Temp Loss: 0.087180
#
# Test Loss: 0.055395
#
# Temp Loss: 0.092516
#
# Epoch: 41, Train Loss Decreased!! (0.046295-->0.043562)
# Test Loss: 0.042934
#
# Temp Loss: 0.086221
#
# Test Loss: 0.054663
#
# Temp Loss: 0.092326
#
# Epoch: 43, Train Loss Decreased!! (0.043562-->0.041735)
# Test Loss: 0.041186
#
# Temp Loss: 0.084908
#
# Test Loss: 0.055003
#
# Temp Loss: 0.092602
#
# Epoch: 45, Train Loss Decreased!! (0.041735-->0.040726)
# Test Loss: 0.039609
#
# Temp Loss: 0.084770
#
# Test Loss: 0.055546
#
# Temp Loss: 0.094480
#
# Epoch: 47, Train Loss Decreased!! (0.040726-->0.039591)
# Test Loss: 0.037710
#
# Temp Loss: 0.083261
#
# Test Loss: 0.055452
#
# Temp Loss: 0.095505
#
# Epoch: 49, Train Loss Decreased!! (0.039591-->0.038042)
# Test Loss: 0.035504
#
# Temp Loss: 0.082507
#
# Test Loss: 0.056147
#
# Temp Loss: 0.097063
#
# Epoch: 51, Train Loss Decreased!! (0.038042-->0.035281)
# Test Loss: 0.030989
#
# Temp Loss: 0.081858
#
# Test Loss: 0.051136
#
# Temp Loss: 0.096374
#
# Epoch: 53, Train Loss Decreased!! (0.035281-->0.029116)
# Test Loss: 0.025446
#
# Temp Loss: 0.080197
#
# Test Loss: 0.046564
#
# Temp Loss: 0.093716
#
# Epoch: 55, Train Loss Decreased!! (0.029116-->0.025374)
# Test Loss: 0.022458
#
# Temp Loss: 0.079460
#
# Test Loss: 0.042449
#
# Temp Loss: 0.090716
#
# Epoch: 57, Train Loss Decreased!! (0.025374-->0.022592)
# Test Loss: 0.019951
#
# Temp Loss: 0.080242
#
# Test Loss: 0.040669
#
# Temp Loss: 0.091384
#
# Epoch: 59, Train Loss Decreased!! (0.022592-->0.020455)
# Test Loss: 0.018214
#
# Temp Loss: 0.081926
#
# Test Loss: 0.041640
#
# Temp Loss: 0.094321
#
# Epoch: 61, Train Loss Decreased!! (0.020455-->0.019392)
# Test Loss: 0.016954
#
# Temp Loss: 0.081939
#
# Test Loss: 0.039078
#
# Temp Loss: 0.092924
#
# Epoch: 63, Train Loss Decreased!! (0.019392-->0.018112)
# Test Loss: 0.015785
#
# Temp Loss: 0.082802
#
# Test Loss: 0.039178
#
# Temp Loss: 0.094209
#
# Epoch: 65, Train Loss Decreased!! (0.018112-->0.017395)
# Test Loss: 0.015003
#
# Temp Loss: 0.082495
#
# Test Loss: 0.037529
#
# Temp Loss: 0.093420
#
# Epoch: 67, Train Loss Decreased!! (0.017395-->0.016424)
# Test Loss: 0.014017
#
# Temp Loss: 0.082895
#
# Test Loss: 0.037790
#
# Temp Loss: 0.094709
#
# Epoch: 69, Train Loss Decreased!! (0.016424-->0.015373)
# Test Loss: 0.013013
#
# Temp Loss: 0.082809
#
# Test Loss: 0.035490
#
# Temp Loss: 0.093310
#
# Epoch: 71, Train Loss Decreased!! (0.015373-->0.014345)
# Test Loss: 0.012295
#
# Temp Loss: 0.083763
#
# Test Loss: 0.034845
#
# Temp Loss: 0.094343
#
# Epoch: 73, Train Loss Decreased!! (0.014345-->0.013594)
# Test Loss: 0.011778
#
# Temp Loss: 0.083610
#
# Test Loss: 0.033546
#
# Temp Loss: 0.093175
#
# Epoch: 75, Train Loss Decreased!! (0.013594-->0.013142)
# Test Loss: 0.011262
#
# Temp Loss: 0.083265
#
# Test Loss: 0.032023
#
# Temp Loss: 0.092162
#
# Epoch: 77, Train Loss Decreased!! (0.013142-->0.012592)
# Test Loss: 0.010801
#
# Temp Loss: 0.083559
#
# Test Loss: 0.031103
#
# Temp Loss: 0.091624
#
# Epoch: 79, Train Loss Decreased!! (0.012592-->0.012157)
# Test Loss: 0.010441
#
# Temp Loss: 0.083203
#
# Test Loss: 0.030174
#
# Temp Loss: 0.091190
#
# Epoch: 81, Train Loss Decreased!! (0.012157-->0.011740)
# Test Loss: 0.010138
#
# Temp Loss: 0.083294
#
# Test Loss: 0.029280
#
# Temp Loss: 0.090449
#
# Epoch: 83, Train Loss Decreased!! (0.011740-->0.011153)
# Test Loss: 0.009786
#
# Temp Loss: 0.082649
#
# Test Loss: 0.030616
#
# Temp Loss: 0.091278
#
# Test Loss: 0.009527
#
# Temp Loss: 0.082902
#
# Test Loss: 0.028877
#
# Temp Loss: 0.090116
#
# Epoch: 87, Train Loss Decreased!! (0.011153-->0.011076)
# Test Loss: 0.009406
#
# Temp Loss: 0.082800
#
# Test Loss: 0.027432
#
# Temp Loss: 0.089014
#
# Epoch: 89, Train Loss Decreased!! (0.011076-->0.010617)
# Test Loss: 0.009125
#
# Temp Loss: 0.082851
#
# Test Loss: 0.028179
#
# Temp Loss: 0.089938
#
# Epoch: 91, Train Loss Decreased!! (0.010617-->0.010306)
# Test Loss: 0.008923
#
# Temp Loss: 0.082875
#
# Test Loss: 0.028382
#
# Temp Loss: 0.090172
#
# Epoch: 93, Train Loss Decreased!! (0.010306-->0.010084)
# Test Loss: 0.008508
#
# Temp Loss: 0.082985
#
# Test Loss: 0.027104
#
# Temp Loss: 0.089108
#
# Epoch: 95, Train Loss Decreased!! (0.010084-->0.009948)
# Test Loss: 0.008514
#
# Temp Loss: 0.083376
#
# Test Loss: 0.027597
#
# Temp Loss: 0.090354
#
# Test Loss: 0.008283
#
# Temp Loss: 0.083413
#
# Test Loss: 0.026302
#
# Temp Loss: 0.089203
#
# Epoch: 99, Train Loss Decreased!! (0.009948-->0.009590)
# Test Loss: 0.008072
#
# Temp Loss: 0.082898
#  40%|████      | 2/5 [04:01<06:02, 120.82s/it]
# Test Loss: 0.026593
#
# Temp Loss: 0.088926
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.286476)
# Test Loss: 0.252348
#
# Temp Loss: 0.252573
#
# Epoch: 2, Train Loss Decreased!! (0.286476-->0.252287)
# Test Loss: 0.251997
#
# Temp Loss: 0.252019
#
# Epoch: 3, Train Loss Decreased!! (0.252287-->0.242321)
# Test Loss: 0.229966
#
# Temp Loss: 0.233738
#
# Epoch: 4, Train Loss Decreased!! (0.242321-->0.228966)
# Test Loss: 0.230741
#
# Temp Loss: 0.234080
#
# Epoch: 5, Train Loss Decreased!! (0.228966-->0.216156)
# Test Loss: 0.202137
#
# Temp Loss: 0.225995
#
# Epoch: 6, Train Loss Decreased!! (0.216156-->0.201630)
# Test Loss: 0.205207
#
# Temp Loss: 0.228252
#
# Epoch: 7, Train Loss Decreased!! (0.201630-->0.190136)
# Test Loss: 0.182087
#
# Temp Loss: 0.211979
#
# Epoch: 8, Train Loss Decreased!! (0.190136-->0.181726)
# Test Loss: 0.186260
#
# Temp Loss: 0.213773
#
# Epoch: 9, Train Loss Decreased!! (0.181726-->0.172401)
# Test Loss: 0.166211
#
# Temp Loss: 0.197544
#
# Epoch: 10, Train Loss Decreased!! (0.172401-->0.165912)
# Test Loss: 0.172248
#
# Temp Loss: 0.202618
#
# Epoch: 11, Train Loss Decreased!! (0.165912-->0.156256)
# Test Loss: 0.147892
#
# Temp Loss: 0.179820
#
# Epoch: 12, Train Loss Decreased!! (0.156256-->0.147182)
# Test Loss: 0.154658
#
# Temp Loss: 0.185734
#
# Epoch: 13, Train Loss Decreased!! (0.147182-->0.135477)
# Test Loss: 0.127941
#
# Temp Loss: 0.160013
#
# Epoch: 14, Train Loss Decreased!! (0.135477-->0.128932)
# Test Loss: 0.136911
#
# Temp Loss: 0.167878
#
# Epoch: 15, Train Loss Decreased!! (0.128932-->0.121442)
# Test Loss: 0.113865
#
# Temp Loss: 0.145245
#
# Epoch: 16, Train Loss Decreased!! (0.121442-->0.113784)
# Test Loss: 0.120241
#
# Temp Loss: 0.151245
#
# Epoch: 17, Train Loss Decreased!! (0.113784-->0.105420)
# Test Loss: 0.098822
#
# Temp Loss: 0.131139
#
# Epoch: 18, Train Loss Decreased!! (0.105420-->0.099303)
# Test Loss: 0.104971
#
# Temp Loss: 0.136841
#
# Epoch: 19, Train Loss Decreased!! (0.099303-->0.093806)
# Test Loss: 0.088691
#
# Temp Loss: 0.121317
#
# Epoch: 20, Train Loss Decreased!! (0.093806-->0.089239)
# Test Loss: 0.093770
#
# Temp Loss: 0.125865
#
# Epoch: 21, Train Loss Decreased!! (0.089239-->0.084694)
# Test Loss: 0.081725
#
# Temp Loss: 0.114845
#
# Epoch: 22, Train Loss Decreased!! (0.084694-->0.082131)
# Test Loss: 0.086218
#
# Temp Loss: 0.118881
#
# Epoch: 23, Train Loss Decreased!! (0.082131-->0.079800)
# Test Loss: 0.078183
#
# Temp Loss: 0.111043
#
# Epoch: 24, Train Loss Decreased!! (0.079800-->0.078080)
# Test Loss: 0.081557
#
# Temp Loss: 0.113545
#
# Epoch: 25, Train Loss Decreased!! (0.078080-->0.076362)
# Test Loss: 0.074763
#
# Temp Loss: 0.108006
#
# Epoch: 26, Train Loss Decreased!! (0.076362-->0.075027)
# Test Loss: 0.080311
#
# Temp Loss: 0.112325
#
# Epoch: 27, Train Loss Decreased!! (0.075027-->0.070739)
# Test Loss: 0.067737
#
# Temp Loss: 0.101670
#
# Test Loss: 0.084103
#
# Temp Loss: 0.118016
#
# Epoch: 29, Train Loss Decreased!! (0.070739-->0.067003)
# Test Loss: 0.064705
#
# Temp Loss: 0.098879
#
# Epoch: 30, Train Loss Decreased!! (0.067003-->0.065214)
# Test Loss: 0.072105
#
# Temp Loss: 0.105478
#
# Epoch: 31, Train Loss Decreased!! (0.065214-->0.063096)
# Test Loss: 0.062781
#
# Temp Loss: 0.098568
#
# Epoch: 32, Train Loss Decreased!! (0.063096-->0.062485)
# Test Loss: 0.067975
#
# Temp Loss: 0.103142
#
# Epoch: 33, Train Loss Decreased!! (0.062485-->0.061010)
# Test Loss: 0.061115
#
# Temp Loss: 0.097708
#
# Epoch: 34, Train Loss Decreased!! (0.061010-->0.060849)
# Test Loss: 0.066475
#
# Temp Loss: 0.102068
#
# Epoch: 35, Train Loss Decreased!! (0.060849-->0.059298)
# Test Loss: 0.059266
#
# Temp Loss: 0.096755
#
# Epoch: 36, Train Loss Decreased!! (0.059298-->0.058974)
# Test Loss: 0.063961
#
# Temp Loss: 0.100503
#
# Epoch: 37, Train Loss Decreased!! (0.058974-->0.057396)
# Test Loss: 0.056395
#
# Temp Loss: 0.094958
#
# Epoch: 38, Train Loss Decreased!! (0.057396-->0.057136)
# Test Loss: 0.062832
#
# Temp Loss: 0.099762
#
# Epoch: 39, Train Loss Decreased!! (0.057136-->0.054648)
# Test Loss: 0.052895
#
# Temp Loss: 0.093070
#
# Epoch: 40, Train Loss Decreased!! (0.054648-->0.054323)
# Test Loss: 0.059956
#
# Temp Loss: 0.098132
#
# Epoch: 41, Train Loss Decreased!! (0.054323-->0.050748)
# Test Loss: 0.048501
#
# Temp Loss: 0.089960
#
# Epoch: 42, Train Loss Decreased!! (0.050748-->0.050056)
# Test Loss: 0.055698
#
# Temp Loss: 0.095699
#
# Epoch: 43, Train Loss Decreased!! (0.050056-->0.046673)
# Test Loss: 0.045196
#
# Temp Loss: 0.086591
#
# Test Loss: 0.052724
#
# Temp Loss: 0.091468
#
# Epoch: 45, Train Loss Decreased!! (0.046673-->0.044269)
# Test Loss: 0.043384
#
# Temp Loss: 0.085086
#
# Test Loss: 0.051367
#
# Temp Loss: 0.090388
#
# Epoch: 47, Train Loss Decreased!! (0.044269-->0.042342)
# Test Loss: 0.041470
#
# Temp Loss: 0.084528
#
# Test Loss: 0.049659
#
# Temp Loss: 0.089528
#
# Epoch: 49, Train Loss Decreased!! (0.042342-->0.040802)
# Test Loss: 0.039894
#
# Temp Loss: 0.083953
#
# Test Loss: 0.048789
#
# Temp Loss: 0.089580
#
# Epoch: 51, Train Loss Decreased!! (0.040802-->0.039240)
# Test Loss: 0.037716
#
# Temp Loss: 0.083014
#
# Test Loss: 0.047769
#
# Temp Loss: 0.089922
#
# Epoch: 53, Train Loss Decreased!! (0.039240-->0.037233)
# Test Loss: 0.035710
#
# Temp Loss: 0.082429
#
# Test Loss: 0.045773
#
# Temp Loss: 0.089342
#
# Epoch: 55, Train Loss Decreased!! (0.037233-->0.035125)
# Test Loss: 0.033323
#
# Temp Loss: 0.082797
#
# Test Loss: 0.044060
#
# Temp Loss: 0.089493
#
# Epoch: 57, Train Loss Decreased!! (0.035125-->0.033041)
# Test Loss: 0.030781
#
# Temp Loss: 0.082535
#
# Test Loss: 0.043121
#
# Temp Loss: 0.089747
#
# Epoch: 59, Train Loss Decreased!! (0.033041-->0.030750)
# Test Loss: 0.028093
#
# Temp Loss: 0.082884
#
# Test Loss: 0.041472
#
# Temp Loss: 0.089662
#
# Epoch: 61, Train Loss Decreased!! (0.030750-->0.027744)
# Test Loss: 0.023669
#
# Temp Loss: 0.079419
#
# Test Loss: 0.039579
#
# Temp Loss: 0.087881
#
# Epoch: 63, Train Loss Decreased!! (0.027744-->0.023810)
# Test Loss: 0.020140
#
# Temp Loss: 0.077931
#
# Test Loss: 0.036439
#
# Temp Loss: 0.087915
#
# Epoch: 65, Train Loss Decreased!! (0.023810-->0.021122)
# Test Loss: 0.018172
#
# Temp Loss: 0.077730
#
# Test Loss: 0.033276
#
# Temp Loss: 0.086743
#
# Epoch: 67, Train Loss Decreased!! (0.021122-->0.019548)
# Test Loss: 0.016706
#
# Temp Loss: 0.077768
#
# Test Loss: 0.031204
#
# Temp Loss: 0.086614
#
# Epoch: 69, Train Loss Decreased!! (0.019548-->0.017492)
# Test Loss: 0.014990
#
# Temp Loss: 0.078517
#
# Test Loss: 0.029344
#
# Temp Loss: 0.086059
#
# Epoch: 71, Train Loss Decreased!! (0.017492-->0.016448)
# Test Loss: 0.013790
#
# Temp Loss: 0.078564
#
# Test Loss: 0.030143
#
# Temp Loss: 0.087111
#
# Epoch: 73, Train Loss Decreased!! (0.016448-->0.015213)
# Test Loss: 0.012783
#
# Temp Loss: 0.079473
#
# Test Loss: 0.028551
#
# Temp Loss: 0.086154
#
# Epoch: 75, Train Loss Decreased!! (0.015213-->0.014283)
# Test Loss: 0.011689
#
# Temp Loss: 0.080398
#
# Test Loss: 0.027074
#
# Temp Loss: 0.085721
#
# Epoch: 77, Train Loss Decreased!! (0.014283-->0.013231)
# Test Loss: 0.010777
#
# Temp Loss: 0.081486
#
# Test Loss: 0.026700
#
# Temp Loss: 0.086355
#
# Epoch: 79, Train Loss Decreased!! (0.013231-->0.012558)
# Test Loss: 0.010064
#
# Temp Loss: 0.082475
#
# Test Loss: 0.025981
#
# Temp Loss: 0.086902
#
# Epoch: 81, Train Loss Decreased!! (0.012558-->0.011839)
# Test Loss: 0.009529
#
# Temp Loss: 0.082813
#
# Test Loss: 0.026576
#
# Temp Loss: 0.087717
#
# Epoch: 83, Train Loss Decreased!! (0.011839-->0.011648)
# Test Loss: 0.009086
#
# Temp Loss: 0.083663
#
# Test Loss: 0.026337
#
# Temp Loss: 0.088558
#
# Epoch: 85, Train Loss Decreased!! (0.011648-->0.011274)
# Test Loss: 0.008694
#
# Temp Loss: 0.083942
#
# Test Loss: 0.025843
#
# Temp Loss: 0.088420
#
# Epoch: 87, Train Loss Decreased!! (0.011274-->0.010670)
# Test Loss: 0.008071
#
# Temp Loss: 0.084181
#
# Test Loss: 0.023752
#
# Temp Loss: 0.087694
#
# Epoch: 89, Train Loss Decreased!! (0.010670-->0.009676)
# Test Loss: 0.007436
#
# Temp Loss: 0.084797
#
# Test Loss: 0.023483
#
# Temp Loss: 0.088991
#
# Epoch: 91, Train Loss Decreased!! (0.009676-->0.009098)
# Test Loss: 0.006748
#
# Temp Loss: 0.084814
#
# Test Loss: 0.022853
#
# Temp Loss: 0.089371
#
# Epoch: 93, Train Loss Decreased!! (0.009098-->0.008558)
# Test Loss: 0.006155
#
# Temp Loss: 0.084841
#
# Test Loss: 0.022266
#
# Temp Loss: 0.090193
#
# Epoch: 95, Train Loss Decreased!! (0.008558-->0.008219)
# Test Loss: 0.005762
#
# Temp Loss: 0.084644
#
# Test Loss: 0.021953
#
# Temp Loss: 0.090293
#
# Epoch: 97, Train Loss Decreased!! (0.008219-->0.007750)
# Test Loss: 0.005334
#
# Temp Loss: 0.084448
#
# Test Loss: 0.022883
#
# Temp Loss: 0.092151
#
# Epoch: 99, Train Loss Decreased!! (0.007750-->0.007659)
# Test Loss: 0.005086
#
# Temp Loss: 0.084454
#  60%|██████    | 3/5 [06:02<04:01, 120.72s/it]
# Test Loss: 0.021617
#
# Temp Loss: 0.091946
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.293954)
# Test Loss: 0.254739
#
# Temp Loss: 0.254313
#
# Epoch: 2, Train Loss Decreased!! (0.293954-->0.253525)
# Test Loss: 0.254150
#
# Temp Loss: 0.253991
#
# Epoch: 3, Train Loss Decreased!! (0.253525-->0.249159)
# Test Loss: 0.240111
#
# Temp Loss: 0.239801
#
# Epoch: 4, Train Loss Decreased!! (0.249159-->0.241129)
# Test Loss: 0.239736
#
# Temp Loss: 0.240128
#
# Epoch: 5, Train Loss Decreased!! (0.241129-->0.229805)
# Test Loss: 0.216424
#
# Temp Loss: 0.217283
#
# Epoch: 6, Train Loss Decreased!! (0.229805-->0.218201)
# Test Loss: 0.217911
#
# Temp Loss: 0.218910
#
# Epoch: 7, Train Loss Decreased!! (0.218201-->0.205825)
# Test Loss: 0.193894
#
# Temp Loss: 0.201446
#
# Epoch: 8, Train Loss Decreased!! (0.205825-->0.196259)
# Test Loss: 0.196710
#
# Temp Loss: 0.203681
#
# Epoch: 9, Train Loss Decreased!! (0.196259-->0.188302)
# Test Loss: 0.181257
#
# Temp Loss: 0.206858
#
# Epoch: 10, Train Loss Decreased!! (0.188302-->0.182623)
# Test Loss: 0.183522
#
# Temp Loss: 0.206224
#
# Epoch: 11, Train Loss Decreased!! (0.182623-->0.175537)
# Test Loss: 0.162039
#
# Temp Loss: 0.191282
#
# Epoch: 12, Train Loss Decreased!! (0.175537-->0.165117)
# Test Loss: 0.169361
#
# Temp Loss: 0.194308
#
# Epoch: 13, Train Loss Decreased!! (0.165117-->0.152933)
# Test Loss: 0.142584
#
# Temp Loss: 0.173537
#
# Epoch: 14, Train Loss Decreased!! (0.152933-->0.145656)
# Test Loss: 0.152445
#
# Temp Loss: 0.181054
#
# Epoch: 15, Train Loss Decreased!! (0.145656-->0.138459)
# Test Loss: 0.130973
#
# Temp Loss: 0.163369
#
# Epoch: 16, Train Loss Decreased!! (0.138459-->0.133422)
# Test Loss: 0.139495
#
# Temp Loss: 0.169157
#
# Epoch: 17, Train Loss Decreased!! (0.133422-->0.123792)
# Test Loss: 0.115570
#
# Temp Loss: 0.148146
#
# Epoch: 18, Train Loss Decreased!! (0.123792-->0.117326)
# Test Loss: 0.122894
#
# Temp Loss: 0.153937
#
# Epoch: 19, Train Loss Decreased!! (0.117326-->0.112889)
# Test Loss: 0.110216
#
# Temp Loss: 0.142261
#
# Epoch: 20, Train Loss Decreased!! (0.112889-->0.111071)
# Test Loss: 0.116026
#
# Temp Loss: 0.146654
#
# Epoch: 21, Train Loss Decreased!! (0.111071-->0.108493)
# Test Loss: 0.107201
#
# Temp Loss: 0.139155
#
# Epoch: 22, Train Loss Decreased!! (0.108493-->0.107409)
# Test Loss: 0.112208
#
# Temp Loss: 0.142193
#
# Epoch: 23, Train Loss Decreased!! (0.107409-->0.103144)
# Test Loss: 0.095864
#
# Temp Loss: 0.127550
#
# Test Loss: 0.118181
#
# Temp Loss: 0.147455
#
# Epoch: 25, Train Loss Decreased!! (0.103144-->0.094654)
# Test Loss: 0.087819
#
# Temp Loss: 0.120241
#
# Epoch: 26, Train Loss Decreased!! (0.094654-->0.091995)
# Test Loss: 0.101114
#
# Temp Loss: 0.132372
#
# Epoch: 27, Train Loss Decreased!! (0.091995-->0.085569)
# Test Loss: 0.080564
#
# Temp Loss: 0.113076
#
# Epoch: 28, Train Loss Decreased!! (0.085569-->0.085134)
# Test Loss: 0.095393
#
# Temp Loss: 0.126070
#
# Epoch: 29, Train Loss Decreased!! (0.085134-->0.081268)
# Test Loss: 0.078450
#
# Temp Loss: 0.110490
#
# Epoch: 30, Train Loss Decreased!! (0.081268-->0.080769)
# Test Loss: 0.087805
#
# Temp Loss: 0.118085
#
# Epoch: 31, Train Loss Decreased!! (0.080769-->0.078733)
# Test Loss: 0.076904
#
# Temp Loss: 0.108631
#
# Test Loss: 0.086512
#
# Temp Loss: 0.116629
#
# Epoch: 33, Train Loss Decreased!! (0.078733-->0.076513)
# Test Loss: 0.073501
#
# Temp Loss: 0.105520
#
# Test Loss: 0.088112
#
# Temp Loss: 0.117527
#
# Epoch: 35, Train Loss Decreased!! (0.076513-->0.072167)
# Test Loss: 0.067095
#
# Temp Loss: 0.099772
#
# Epoch: 36, Train Loss Decreased!! (0.072167-->0.071859)
# Test Loss: 0.082288
#
# Temp Loss: 0.112162
#
# Epoch: 37, Train Loss Decreased!! (0.071859-->0.067444)
# Test Loss: 0.062989
#
# Temp Loss: 0.097415
#
# Epoch: 38, Train Loss Decreased!! (0.067444-->0.067367)
# Test Loss: 0.075392
#
# Temp Loss: 0.107390
#
# Epoch: 39, Train Loss Decreased!! (0.067367-->0.064095)
# Test Loss: 0.060567
#
# Temp Loss: 0.095273
#
# Epoch: 40, Train Loss Decreased!! (0.064095-->0.063814)
# Test Loss: 0.070214
#
# Temp Loss: 0.102818
#
# Epoch: 41, Train Loss Decreased!! (0.063814-->0.061262)
# Test Loss: 0.057807
#
# Temp Loss: 0.093584
#
# Test Loss: 0.068120
#
# Temp Loss: 0.101744
#
# Epoch: 43, Train Loss Decreased!! (0.061262-->0.058524)
# Test Loss: 0.054425
#
# Temp Loss: 0.093450
#
# Epoch: 44, Train Loss Decreased!! (0.058524-->0.058345)
# Test Loss: 0.064534
#
# Temp Loss: 0.101361
#
# Epoch: 45, Train Loss Decreased!! (0.058345-->0.054915)
# Test Loss: 0.050526
#
# Temp Loss: 0.091469
#
# Test Loss: 0.062486
#
# Temp Loss: 0.100556
#
# Epoch: 47, Train Loss Decreased!! (0.054915-->0.049938)
# Test Loss: 0.045303
#
# Temp Loss: 0.087381
#
# Epoch: 48, Train Loss Decreased!! (0.049938-->0.049391)
# Test Loss: 0.057286
#
# Temp Loss: 0.095429
#
# Epoch: 49, Train Loss Decreased!! (0.049391-->0.045704)
# Test Loss: 0.041741
#
# Temp Loss: 0.084090
#
# Test Loss: 0.055354
#
# Temp Loss: 0.093564
#
# Epoch: 51, Train Loss Decreased!! (0.045704-->0.043222)
# Test Loss: 0.039083
#
# Temp Loss: 0.082903
#
# Test Loss: 0.052940
#
# Temp Loss: 0.092024
#
# Epoch: 53, Train Loss Decreased!! (0.043222-->0.040297)
# Test Loss: 0.036316
#
# Temp Loss: 0.082237
#
# Test Loss: 0.049396
#
# Temp Loss: 0.090853
#
# Epoch: 55, Train Loss Decreased!! (0.040297-->0.037115)
# Test Loss: 0.033455
#
# Temp Loss: 0.082422
#
# Test Loss: 0.048292
#
# Temp Loss: 0.092671
#
# Epoch: 57, Train Loss Decreased!! (0.037115-->0.035311)
# Test Loss: 0.031295
#
# Temp Loss: 0.082503
#
# Test Loss: 0.047395
#
# Temp Loss: 0.093798
#
# Epoch: 59, Train Loss Decreased!! (0.035311-->0.032577)
# Test Loss: 0.027908
#
# Temp Loss: 0.081503
#
# Test Loss: 0.046247
#
# Temp Loss: 0.094095
#
# Epoch: 61, Train Loss Decreased!! (0.032577-->0.029398)
# Test Loss: 0.023707
#
# Temp Loss: 0.079888
#
# Test Loss: 0.044526
#
# Temp Loss: 0.094889
#
# Epoch: 63, Train Loss Decreased!! (0.029398-->0.025737)
# Test Loss: 0.020268
#
# Temp Loss: 0.078683
#
# Test Loss: 0.042505
#
# Temp Loss: 0.094267
#
# Epoch: 65, Train Loss Decreased!! (0.025737-->0.023009)
# Test Loss: 0.018017
#
# Temp Loss: 0.077410
#
# Test Loss: 0.040399
#
# Temp Loss: 0.091766
#
# Epoch: 67, Train Loss Decreased!! (0.023009-->0.020849)
# Test Loss: 0.016378
#
# Temp Loss: 0.077619
#
# Test Loss: 0.039953
#
# Temp Loss: 0.091929
#
# Epoch: 69, Train Loss Decreased!! (0.020849-->0.019628)
# Test Loss: 0.015022
#
# Temp Loss: 0.078018
#
# Test Loss: 0.039382
#
# Temp Loss: 0.092342
#
# Epoch: 71, Train Loss Decreased!! (0.019628-->0.018436)
# Test Loss: 0.014000
#
# Temp Loss: 0.077699
#
# Test Loss: 0.037890
#
# Temp Loss: 0.091464
#
# Epoch: 73, Train Loss Decreased!! (0.018436-->0.017355)
# Test Loss: 0.012803
#
# Temp Loss: 0.076929
#
# Test Loss: 0.036027
#
# Temp Loss: 0.089491
#
# Epoch: 75, Train Loss Decreased!! (0.017355-->0.015681)
# Test Loss: 0.011156
#
# Temp Loss: 0.077912
#
# Test Loss: 0.034799
#
# Temp Loss: 0.089611
#
# Epoch: 77, Train Loss Decreased!! (0.015681-->0.014617)
# Test Loss: 0.010071
#
# Temp Loss: 0.077974
#
# Test Loss: 0.034683
#
# Temp Loss: 0.090164
#
# Epoch: 79, Train Loss Decreased!! (0.014617-->0.013306)
# Test Loss: 0.008939
#
# Temp Loss: 0.077788
#
# Test Loss: 0.032297
#
# Temp Loss: 0.089022
#
# Epoch: 81, Train Loss Decreased!! (0.013306-->0.012400)
# Test Loss: 0.008216
#
# Temp Loss: 0.078595
#
# Test Loss: 0.033421
#
# Temp Loss: 0.090884
#
# Epoch: 83, Train Loss Decreased!! (0.012400-->0.011777)
# Test Loss: 0.007440
#
# Temp Loss: 0.078427
#
# Test Loss: 0.031364
#
# Temp Loss: 0.089970
#
# Epoch: 85, Train Loss Decreased!! (0.011777-->0.010866)
# Test Loss: 0.007065
#
# Temp Loss: 0.078926
#
# Test Loss: 0.030139
#
# Temp Loss: 0.090020
#
# Epoch: 87, Train Loss Decreased!! (0.010866-->0.010659)
# Test Loss: 0.006416
#
# Temp Loss: 0.078945
#
# Test Loss: 0.029659
#
# Temp Loss: 0.089366
#
# Epoch: 89, Train Loss Decreased!! (0.010659-->0.010056)
# Test Loss: 0.006202
#
# Temp Loss: 0.079386
#
# Test Loss: 0.028503
#
# Temp Loss: 0.089232
#
# Epoch: 91, Train Loss Decreased!! (0.010056-->0.009762)
# Test Loss: 0.005871
#
# Temp Loss: 0.079636
#
# Test Loss: 0.029917
#
# Temp Loss: 0.090350
#
# Epoch: 93, Train Loss Decreased!! (0.009762-->0.009364)
# Test Loss: 0.005512
#
# Temp Loss: 0.079951
#
# Test Loss: 0.029827
#
# Temp Loss: 0.089631
#
# Epoch: 95, Train Loss Decreased!! (0.009364-->0.008932)
# Test Loss: 0.005186
#
# Temp Loss: 0.079889
#
# Test Loss: 0.027970
#
# Temp Loss: 0.088794
#
# Epoch: 97, Train Loss Decreased!! (0.008932-->0.008918)
# Test Loss: 0.005020
#
# Temp Loss: 0.080112
#
# Test Loss: 0.027379
#
# Temp Loss: 0.088857
#
# Epoch: 99, Train Loss Decreased!! (0.008918-->0.008182)
# Test Loss: 0.004690
#
# Temp Loss: 0.080178
#  80%|████████  | 4/5 [08:03<02:00, 120.96s/it]
# Test Loss: 0.026171
#
# Temp Loss: 0.088073
#
# ----------------------------------------------------
# Epoch: 1, Train Loss Decreased!! (inf-->0.287862)
# Test Loss: 0.252869
#
# Temp Loss: 0.252967
#
# Epoch: 2, Train Loss Decreased!! (0.287862-->0.252072)
# Test Loss: 0.252503
#
# Temp Loss: 0.252487
#
# Epoch: 3, Train Loss Decreased!! (0.252072-->0.245354)
# Test Loss: 0.235051
#
# Temp Loss: 0.235627
#
# Epoch: 4, Train Loss Decreased!! (0.245354-->0.235028)
# Test Loss: 0.237054
#
# Temp Loss: 0.237881
#
# Epoch: 5, Train Loss Decreased!! (0.235028-->0.221512)
# Test Loss: 0.212021
#
# Temp Loss: 0.214222
#
# Epoch: 6, Train Loss Decreased!! (0.221512-->0.210215)
# Test Loss: 0.212992
#
# Temp Loss: 0.214795
#
# Epoch: 7, Train Loss Decreased!! (0.210215-->0.198320)
# Test Loss: 0.189137
#
# Temp Loss: 0.205601
#
# Epoch: 8, Train Loss Decreased!! (0.198320-->0.187318)
# Test Loss: 0.193570
#
# Temp Loss: 0.210136
#
# Epoch: 9, Train Loss Decreased!! (0.187318-->0.175985)
# Test Loss: 0.172091
#
# Temp Loss: 0.199352
#
# Epoch: 10, Train Loss Decreased!! (0.175985-->0.169559)
# Test Loss: 0.175637
#
# Temp Loss: 0.201947
#
# Epoch: 11, Train Loss Decreased!! (0.169559-->0.161893)
# Test Loss: 0.156910
#
# Temp Loss: 0.187636
#
# Epoch: 12, Train Loss Decreased!! (0.161893-->0.154878)
# Test Loss: 0.162920
#
# Temp Loss: 0.192620
#
# Epoch: 13, Train Loss Decreased!! (0.154878-->0.145824)
# Test Loss: 0.142237
#
# Temp Loss: 0.172877
#
# Epoch: 14, Train Loss Decreased!! (0.145824-->0.140985)
# Test Loss: 0.149973
#
# Temp Loss: 0.179057
#
# Epoch: 15, Train Loss Decreased!! (0.140985-->0.136222)
# Test Loss: 0.133988
#
# Temp Loss: 0.165689
#
# Epoch: 16, Train Loss Decreased!! (0.136222-->0.133841)
# Test Loss: 0.143718
#
# Temp Loss: 0.173696
#
# Epoch: 17, Train Loss Decreased!! (0.133841-->0.127223)
# Test Loss: 0.125706
#
# Temp Loss: 0.157646
#
# Epoch: 18, Train Loss Decreased!! (0.127223-->0.125880)
# Test Loss: 0.135356
#
# Temp Loss: 0.166009
#
# Epoch: 19, Train Loss Decreased!! (0.125880-->0.121610)
# Test Loss: 0.119858
#
# Temp Loss: 0.152422
#
# Epoch: 20, Train Loss Decreased!! (0.121610-->0.119522)
# Test Loss: 0.127304
#
# Temp Loss: 0.158521
#
# Epoch: 21, Train Loss Decreased!! (0.119522-->0.111998)
# Test Loss: 0.107663
#
# Temp Loss: 0.140601
#
# Epoch: 22, Train Loss Decreased!! (0.111998-->0.108826)
# Test Loss: 0.118122
#
# Temp Loss: 0.150186
#
# Epoch: 23, Train Loss Decreased!! (0.108826-->0.100630)
# Test Loss: 0.097494
#
# Temp Loss: 0.131606
#
# Epoch: 24, Train Loss Decreased!! (0.100630-->0.098440)
# Test Loss: 0.108772
#
# Temp Loss: 0.140825
#
# Epoch: 25, Train Loss Decreased!! (0.098440-->0.091701)
# Test Loss: 0.086979
#
# Temp Loss: 0.120691
#
# Epoch: 26, Train Loss Decreased!! (0.091701-->0.088788)
# Test Loss: 0.097826
#
# Temp Loss: 0.130546
#
# Epoch: 27, Train Loss Decreased!! (0.088788-->0.083160)
# Test Loss: 0.081051
#
# Temp Loss: 0.114937
#
# Epoch: 28, Train Loss Decreased!! (0.083160-->0.081382)
# Test Loss: 0.088662
#
# Temp Loss: 0.121168
#
# Epoch: 29, Train Loss Decreased!! (0.081382-->0.078377)
# Test Loss: 0.076575
#
# Temp Loss: 0.111742
#
# Epoch: 30, Train Loss Decreased!! (0.078377-->0.076636)
# Test Loss: 0.083051
#
# Temp Loss: 0.116332
#
# Epoch: 31, Train Loss Decreased!! (0.076636-->0.072810)
# Test Loss: 0.070583
#
# Temp Loss: 0.110639
#
# Epoch: 32, Train Loss Decreased!! (0.072810-->0.072139)
# Test Loss: 0.080133
#
# Temp Loss: 0.116626
#
# Epoch: 33, Train Loss Decreased!! (0.072139-->0.066601)
# Test Loss: 0.063015
#
# Temp Loss: 0.104484
#
# Epoch: 34, Train Loss Decreased!! (0.066601-->0.063730)
# Test Loss: 0.071524
#
# Temp Loss: 0.109722
#
# Epoch: 35, Train Loss Decreased!! (0.063730-->0.059992)
# Test Loss: 0.057524
#
# Temp Loss: 0.099077
#
# Epoch: 36, Train Loss Decreased!! (0.059992-->0.059459)
# Test Loss: 0.066883
#
# Temp Loss: 0.105131
#
# Epoch: 37, Train Loss Decreased!! (0.059459-->0.055543)
# Test Loss: 0.052953
#
# Temp Loss: 0.094023
#
# Epoch: 38, Train Loss Decreased!! (0.055543-->0.055041)
# Test Loss: 0.063273
#
# Temp Loss: 0.100904
#
# Epoch: 39, Train Loss Decreased!! (0.055041-->0.049964)
# Test Loss: 0.046986
#
# Temp Loss: 0.089370
#
# Epoch: 40, Train Loss Decreased!! (0.049964-->0.049465)
# Test Loss: 0.057676
#
# Temp Loss: 0.096114
#
# Epoch: 41, Train Loss Decreased!! (0.049465-->0.044412)
# Test Loss: 0.041105
#
# Temp Loss: 0.087690
#
# Test Loss: 0.055575
#
# Temp Loss: 0.096376
#
# Epoch: 43, Train Loss Decreased!! (0.044412-->0.040264)
# Test Loss: 0.037150
#
# Temp Loss: 0.087909
#
# Test Loss: 0.053602
#
# Temp Loss: 0.096953
#
# Epoch: 45, Train Loss Decreased!! (0.040264-->0.037088)
# Test Loss: 0.033765
#
# Temp Loss: 0.087017
#
# Test Loss: 0.054195
#
# Temp Loss: 0.098818
#
# Epoch: 47, Train Loss Decreased!! (0.037088-->0.034461)
# Test Loss: 0.030591
#
# Temp Loss: 0.085230
#
# Test Loss: 0.052451
#
# Temp Loss: 0.098910
#
# Epoch: 49, Train Loss Decreased!! (0.034461-->0.031649)
# Test Loss: 0.027786
#
# Temp Loss: 0.082694
#
# Test Loss: 0.052082
#
# Temp Loss: 0.098488
#
# Epoch: 51, Train Loss Decreased!! (0.031649-->0.029514)
# Test Loss: 0.025825
#
# Temp Loss: 0.081451
#
# Test Loss: 0.048749
#
# Temp Loss: 0.096151
#
# Epoch: 53, Train Loss Decreased!! (0.029514-->0.027514)
# Test Loss: 0.023892
#
# Temp Loss: 0.081926
#
# Test Loss: 0.047798
#
# Temp Loss: 0.097218
#
# Epoch: 55, Train Loss Decreased!! (0.027514-->0.025760)
# Test Loss: 0.022400
#
# Temp Loss: 0.080477
#
# Test Loss: 0.046975
#
# Temp Loss: 0.096059
#
# Epoch: 57, Train Loss Decreased!! (0.025760-->0.023860)
# Test Loss: 0.020374
#
# Temp Loss: 0.079646
#
# Test Loss: 0.044747
#
# Temp Loss: 0.093879
#
# Epoch: 59, Train Loss Decreased!! (0.023860-->0.021925)
# Test Loss: 0.018562
#
# Temp Loss: 0.079757
#
# Test Loss: 0.045311
#
# Temp Loss: 0.095307
#
# Epoch: 61, Train Loss Decreased!! (0.021925-->0.021140)
# Test Loss: 0.017733
#
# Temp Loss: 0.078053
#
# Test Loss: 0.041783
#
# Temp Loss: 0.090553
#
# Epoch: 63, Train Loss Decreased!! (0.021140-->0.019268)
# Test Loss: 0.016256
#
# Temp Loss: 0.078717
#
# Test Loss: 0.040973
#
# Temp Loss: 0.091039
#
# Epoch: 65, Train Loss Decreased!! (0.019268-->0.018645)
# Test Loss: 0.015534
#
# Temp Loss: 0.079315
#
# Test Loss: 0.040911
#
# Temp Loss: 0.091862
#
# Epoch: 67, Train Loss Decreased!! (0.018645-->0.017785)
# Test Loss: 0.015016
#
# Temp Loss: 0.078492
#
# Test Loss: 0.038425
#
# Temp Loss: 0.089891
#
# Epoch: 69, Train Loss Decreased!! (0.017785-->0.016939)
# Test Loss: 0.014225
#
# Temp Loss: 0.078570
#
# Test Loss: 0.037718
#
# Temp Loss: 0.089602
#
# Epoch: 71, Train Loss Decreased!! (0.016939-->0.016104)
# Test Loss: 0.013609
#
# Temp Loss: 0.079545
#
# Test Loss: 0.035634
#
# Temp Loss: 0.089689
#
# Epoch: 73, Train Loss Decreased!! (0.016104-->0.015104)
# Test Loss: 0.012934
#
# Temp Loss: 0.079706
#
# Test Loss: 0.035792
#
# Temp Loss: 0.089995
#
# Epoch: 75, Train Loss Decreased!! (0.015104-->0.015003)
# Test Loss: 0.012589
#
# Temp Loss: 0.080022
#
# Test Loss: 0.033826
#
# Temp Loss: 0.089582
#
# Epoch: 77, Train Loss Decreased!! (0.015003-->0.014416)
# Test Loss: 0.012027
#
# Temp Loss: 0.080428
#
# Test Loss: 0.032281
#
# Temp Loss: 0.089017
#
# Epoch: 79, Train Loss Decreased!! (0.014416-->0.013746)
# Test Loss: 0.011684
#
# Temp Loss: 0.080759
#
# Test Loss: 0.031625
#
# Temp Loss: 0.089432
#
# Epoch: 81, Train Loss Decreased!! (0.013746-->0.013027)
# Test Loss: 0.010797
#
# Temp Loss: 0.080673
#
# Test Loss: 0.029948
#
# Temp Loss: 0.088678
#
# Epoch: 83, Train Loss Decreased!! (0.013027-->0.012183)
# Test Loss: 0.010350
#
# Temp Loss: 0.080732
#
# Test Loss: 0.029484
#
# Temp Loss: 0.088841
#
# Epoch: 85, Train Loss Decreased!! (0.012183-->0.011708)
# Test Loss: 0.009647
#
# Temp Loss: 0.081108
#
# Test Loss: 0.028472
#
# Temp Loss: 0.089090
#
# Epoch: 87, Train Loss Decreased!! (0.011708-->0.011087)
# Test Loss: 0.009072
#
# Temp Loss: 0.081661
#
# Test Loss: 0.027815
#
# Temp Loss: 0.089326
#
# Epoch: 89, Train Loss Decreased!! (0.011087-->0.010278)
# Test Loss: 0.008308
#
# Temp Loss: 0.081488
#
# Test Loss: 0.025770
#
# Temp Loss: 0.088640
#
# Epoch: 91, Train Loss Decreased!! (0.010278-->0.009676)
# Test Loss: 0.007938
#
# Temp Loss: 0.081838
#
# Test Loss: 0.026890
#
# Temp Loss: 0.089423
#
# Epoch: 93, Train Loss Decreased!! (0.009676-->0.009414)
# Test Loss: 0.007375
#
# Temp Loss: 0.081518
#
# Test Loss: 0.025245
#
# Temp Loss: 0.088751
#
# Epoch: 95, Train Loss Decreased!! (0.009414-->0.008960)
# Test Loss: 0.006868
#
# Temp Loss: 0.081599
#
# Test Loss: 0.024641
#
# Temp Loss: 0.088505
#
# Epoch: 97, Train Loss Decreased!! (0.008960-->0.008225)
# Test Loss: 0.006399
#
# Temp Loss: 0.081671
#
# Test Loss: 0.024658
#
# Temp Loss: 0.088932
#
# Epoch: 99, Train Loss Decreased!! (0.008225-->0.007944)
# Test Loss: 0.006110
#
# Temp Loss: 0.081779
# 100%|██████████| 5/5 [10:05<00:00, 121.14s/it]
# Test Loss: 0.024695
#
# Temp Loss: 0.089210
#
# ----------------------------------------------------

# %%
train_losses_mat = np.zeros((nRuns,n_epochs+1))
test_losses_mat = np.zeros((nRuns,n_epochs+1))
temp_losses_mat = np.zeros((nRuns,n_epochs+1))

train_expected_losses_mat = np.zeros((nRuns,n_epochs+1))

test_expected_losses_mat = np.zeros((nRuns,n_epochs+1))
test_surprise_losses_mat = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    train_losses_mat[cntr] = train_losses[cntr]
    test_losses_mat[cntr] = test_losses[cntr]
    temp_losses_mat[cntr] = temp_losses[cntr]
    
    train_expected_losses_mat[cntr] = train_expected_rec_losses[cntr]
    
    test_expected_losses_mat[cntr] = test_expected_rec_losses[cntr]
    test_surprise_losses_mat[cntr] = test_surprise_rec_losses[cntr]

# %%
train_losses_mean = np.mean(train_losses_mat,axis=0)
test_losses_mean = np.mean(test_losses_mat,axis=0)
temp_losses_mean = np.mean(temp_losses_mat,axis=0)

train_expected_losses_mean = np.mean(train_expected_losses_mat,axis=0)

test_expected_losses_mean = np.mean(test_expected_losses_mat,axis=0)
test_surprise_losses_mean = np.mean(test_surprise_losses_mat,axis=0)

# %%
train_losses_std = np.std(train_losses_mat,axis=0)
test_losses_std = np.std(test_losses_mat,axis=0)
temp_losses_std = np.std(test_losses_mat,axis=0)

train_expected_losses_std = np.std(train_expected_losses_mat,axis=0)

test_expected_losses_std = np.std(test_expected_losses_mat,axis=0)
test_surprise_losses_std = np.std(test_surprise_losses_mat,axis=0)

# %%
train_expected_losses_mean[0] = train_losses_mean[0]

# %%
f = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.errorbar(np.arange(n_epochs+1),train_losses_mean,yerr=train_losses_std)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,2)
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.subplot(2,2,3)
plt.errorbar(np.arange(n_epochs+1),test_losses_mean,yerr=test_losses_std)
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.subplot(2,2,4)
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.title('Test Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
plt.errorbar(np.arange(n_epochs+1),train_expected_losses_mean,yerr=train_expected_losses_std,label='Clean - Training')
plt.errorbar(np.arange(n_epochs+1),test_expected_losses_mean,yerr=test_expected_losses_std,label='Clean - Test')
plt.errorbar(np.arange(n_epochs+1),test_surprise_losses_mean,yerr=test_surprise_losses_std,label='Temporally violated - Test')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()

plt.show()

# %%
# kk=4
# a = np.unique(allStatesTest[kk][:,0])
# b = np.unique(allStatesTrain[kk][:,0])
# len(np.intersect1d(a,b))

# %% [markdown]
# ### Representational Analyses

# %% [markdown]
# #### RNN Names

# %%
rnn_names = ['L4','L23','L56','H4','H23','H56']

# %% [markdown]
# #### Analyses train loader

# %%
analyses_train_loader = {}

# %%
for cntr in range(nRuns):
    analyses_train_loader[cntr] = makeTensorLoaders((repsTrain[cntr],yRepsTrain[cntr],eTrain[cntr],surpTrain[cntr]),
                                           batch_size,shuffle=False)

# %% [markdown]
# #### Pass data and store activations

# %%
def pass_data_store_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        activations_hidden_L23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_L4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_L56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_hidden_H23_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
        activations_hidden_H4_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
        activations_hidden_H56_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

        activations_out_np[cntr] = np.zeros((n_epochs+1,nData,nSteps,dim))
        
        for e in tqdm(range(n_epochs+1)):

            cnt = 0

            ## Load model
            model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr])
            model[cntr].to(device)
            model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
            model[cntr].eval()

            ## Pass clean samples
            for data, f_target, lastEvent, surpriseBinary in loader[cntr]:

                if train_on_gpu:
                    data, f_targetC = data.float().cuda(), f_target.float().cuda()
                else: data, f_targetC = data.float(), f_target.float()

                target = f_target

                output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                ## Collect activations  
                act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                for i in range(batch_size):
                    if i < len(data):
                        label = target.data[i]

                        activations_hidden_L23_np[cntr][e,cnt] = act_hidden_L23[i]
                        activations_hidden_L4_np[cntr][e,cnt] = act_hidden_L4[i]
                        activations_hidden_L56_np[cntr][e,cnt] = act_hidden_L56[i]

                        activations_hidden_H23_np[cntr][e,cnt] = act_hidden_H23[i]
                        activations_hidden_H4_np[cntr][e,cnt] = act_hidden_H4[i]
                        activations_hidden_H56_np[cntr][e,cnt] = act_hidden_H56[i]

                        activations_out_np[cntr][e,cnt] = output_pred[i]

                        cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
# (L23_train,L4_train,L56_train,
#  H23_train,H4_train,H56_train,), out_train = pass_data_store_activations(analyses_train_loader, nTrain)

# %%
(L23_test,L4_test,L56_test,
 H23_test,H4_test,H56_test,), out_test = pass_data_store_activations(test_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:18<00:00,  5.58it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.56it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.56it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.57it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.56it/s]

# %%
(L23_temp,L4_temp,L56_temp,
 H23_temp,H4_temp,H56_temp,), out_temp = pass_data_store_activations(test_temp_loader, nTest)
# Out:
# 100%|██████████| 101/101 [00:18<00:00,  5.54it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.57it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.59it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.59it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.55it/s]

# %% [markdown]
# #### PCA for RNNs

# %%
def repsPCA(rnnActs):
    nEpochs, nSeqs, nRolls, nNeurons = rnnActs.shape
    pca_dict = {}
    nSamps = nSeqs*nRolls
    dimPCA = min(nNeurons,nSamps)
    repsR_transformed = np.zeros((nEpochs,nSamps,dimPCA))
    
    for ep in tqdm(range(nEpochs)):
        
        reps = rnnActs[ep]
        
        ## reshape
        repsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        for ii in range(nSeqs):
            for jj in range(nRolls):
                repsR[cnt] = reps[ii,jj]
                cnt += 1
        ## PCA
        rnnPCA = PCA()
        repsR_transformed[ep] = rnnPCA.fit_transform(repsR)
        pca_dict[str(ep)] = rnnPCA
        
    return repsR_transformed, pca_dict

# %%
# L23pca_train = {}
# L4pca_train = {}
# L56pca_train = {}

# H23pca_train = {}
# H4pca_train = {}
# H56pca_train = {}

L23pca_test = {}
L4pca_test = {}
L56pca_test = {}

H23pca_test = {}
H4pca_test = {}
H56pca_test = {}

L23pca_temp = {}
L4pca_temp = {}
L56pca_temp = {}

H23pca_temp = {}
H4pca_temp = {}
H56pca_temp = {}

# %%
# for cntr in range(nRuns):
#     L23pca_train[cntr], _ = repsPCA(L23_train[cntr])
#     L4pca_train[cntr], _ = repsPCA(L4_train[cntr])
#     L56pca_train[cntr], _ = repsPCA(L56_train[cntr])

#     H23pca_train[cntr], _ = repsPCA(H23_train[cntr])
#     H4pca_train[cntr], _ = repsPCA(H4_train[cntr])
#     H56pca_train[cntr], _ = repsPCA(H56_train[cntr])

# %%
for cntr in range(nRuns):
    L23pca_test[cntr], _ = repsPCA(L23_test[cntr])
    L4pca_test[cntr], _ = repsPCA(L4_test[cntr])
    L56pca_test[cntr], _ = repsPCA(L56_test[cntr])

    H23pca_test[cntr], _ = repsPCA(H23_test[cntr])
    H4pca_test[cntr], _ = repsPCA(H4_test[cntr])
    H56pca_test[cntr], _ = repsPCA(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 66.10it/s]
# 100%|██████████| 101/101 [00:00<00:00, 139.11it/s]
# 100%|██████████| 101/101 [00:01<00:00, 85.68it/s]
# 100%|██████████| 101/101 [00:01<00:00, 69.03it/s]
# 100%|██████████| 101/101 [00:00<00:00, 133.25it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.83it/s]
# 100%|██████████| 101/101 [00:01<00:00, 62.57it/s]
# 100%|██████████| 101/101 [00:00<00:00, 135.20it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.43it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.93it/s]
# 100%|██████████| 101/101 [00:00<00:00, 129.67it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.80it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.32it/s]
# 100%|██████████| 101/101 [00:00<00:00, 128.52it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.61it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.81it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.35it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.50it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.38it/s]
# 100%|██████████| 101/101 [00:00<00:00, 130.00it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.49it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.42it/s]
# 100%|██████████| 101/101 [00:00<00:00, 128.84it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.18it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.28it/s]
# 100%|██████████| 101/101 [00:00<00:00, 129.91it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.88it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.24it/s]
# 100%|██████████| 101/101 [00:00<00:00, 129.50it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.99it/s]

# %%
for cntr in range(nRuns):
    L23pca_temp[cntr], _ = repsPCA(L23_temp[cntr])
    L4pca_temp[cntr], _ = repsPCA(L4_temp[cntr])
    L56pca_temp[cntr], _ = repsPCA(L56_temp[cntr])

    H23pca_temp[cntr], _ = repsPCA(H23_temp[cntr])
    H4pca_temp[cntr], _ = repsPCA(H4_temp[cntr])
    H56pca_temp[cntr], _ = repsPCA(H56_temp[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 64.01it/s]
# 100%|██████████| 101/101 [00:00<00:00, 136.30it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.13it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.33it/s]
# 100%|██████████| 101/101 [00:00<00:00, 129.17it/s]
# 100%|██████████| 101/101 [00:01<00:00, 82.00it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 128.84it/s]
# 100%|██████████| 101/101 [00:01<00:00, 81.41it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.21it/s]
# 100%|██████████| 101/101 [00:00<00:00, 130.00it/s]
# 100%|██████████| 101/101 [00:01<00:00, 78.69it/s]
# 100%|██████████| 101/101 [00:01<00:00, 63.89it/s]
# 100%|██████████| 101/101 [00:00<00:00, 133.87it/s]
# 100%|██████████| 101/101 [00:01<00:00, 82.13it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.18it/s]
# 100%|██████████| 101/101 [00:00<00:00, 133.43it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.50it/s]
# 100%|██████████| 101/101 [00:01<00:00, 65.80it/s]
# 100%|██████████| 101/101 [00:00<00:00, 133.78it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.99it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.50it/s]
# 100%|██████████| 101/101 [00:00<00:00, 131.18it/s]
# 100%|██████████| 101/101 [00:01<00:00, 81.87it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.67it/s]
# 100%|██████████| 101/101 [00:00<00:00, 125.96it/s]
# 100%|██████████| 101/101 [00:01<00:00, 80.28it/s]
# 100%|██████████| 101/101 [00:01<00:00, 64.87it/s]
# 100%|██████████| 101/101 [00:00<00:00, 128.51it/s]
# 100%|██████████| 101/101 [00:01<00:00, 81.41it/s]

# %%
idxs0_train = np.array([6*x for x in range(nTrain)])
idxs1_train = idxs0_train + 1
idxs2_train = idxs0_train + 2
idxs3_train = idxs0_train + 3
idxs4_train = idxs0_train + 4
idxs5_train = idxs0_train + 5

# %%
idxs0_test = np.array([6*x for x in range(nTest)])
idxs1_test = idxs0_test + 1
idxs2_test = idxs0_test + 2
idxs3_test = idxs0_test + 3
idxs4_test = idxs0_test + 4
idxs5_test = idxs0_test + 5

# %%
# cnt = 4
# ep = -1
# ix = idxs5_train
# c = allStatesTrain[cnt][:,0]/numM
# s = 20*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_train[cnt][ep,ix,0],L4pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_train[cnt][ep,ix,0],L23pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_train[cnt][ep,ix,0],L56pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_train[cnt][ep,ix,0],H4pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_train[cnt][ep,ix,0],H23pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_train[cnt][ep,ix,0],H56pca_train[cnt][ep,ix,1],
#             c=allStatesTrain[cnt][:,0],s=s,cmap='Blues')
# plt.title('Layer H5/6')

# %%
# cnt = 4
# ep = 50
# ix = idxs4_test
# c = allStatesTest[cnt][:,0]/numM
# s = 20*c

# f = plt.figure(figsize=(16,10))

# plt.subplot(231)
# plt.scatter(L4pca_test[cnt][ep,ix,0],L4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L4pca_temp[cnt][ep,ix,0],L4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L4')

# plt.subplot(232)
# plt.scatter(L23pca_test[cnt][ep,ix,0],L23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L23pca_temp[cnt][ep,ix,0],L23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L2/3')

# plt.subplot(233)
# plt.scatter(L56pca_test[cnt][ep,ix,0],L56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(L56pca_temp[cnt][ep,ix,0],L56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer L5/6')

# plt.subplot(234)
# plt.scatter(H4pca_test[cnt][ep,ix,0],H4pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H4pca_temp[cnt][ep,ix,0],H4pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H4')

# plt.subplot(235)
# plt.scatter(H23pca_test[cnt][ep,ix,0],H23pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H23pca_temp[cnt][ep,ix,0],H23pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H2/3')

# plt.subplot(236)
# plt.scatter(H56pca_test[cnt][ep,ix,0],H56pca_test[cnt][ep,ix,1],
#             c=c,s=s,cmap='Greens')
# plt.scatter(H56pca_temp[cnt][ep,ix,0],H56pca_temp[cnt][ep,ix,1],
#             c=c,s=s,cmap='Purples')
# plt.title('Layer H5/6')

# %% [markdown]
# #### Subset indices, etc.

# %%
idxs00_train = np.hstack((idxs0_train.reshape(-1,1),idxs1_train.reshape(-1,1)))
idxs11_train = np.hstack((idxs2_train.reshape(-1,1),idxs3_train.reshape(-1,1)))
idxs22_train = np.hstack((idxs4_train.reshape(-1,1),idxs5_train.reshape(-1,1)))

# %%
idxs00_test = np.hstack((idxs0_test.reshape(-1,1),idxs1_test.reshape(-1,1))).ravel()
idxs11_test = np.hstack((idxs2_test.reshape(-1,1),idxs3_test.reshape(-1,1))).ravel()
idxs22_test = np.hstack((idxs4_test.reshape(-1,1),idxs5_test.reshape(-1,1))).ravel()

# %%
cleanPCs = {}
surpPCs = {}

contextPCs_sub = {}

# %%
for cntr in range(nRuns):
    cleanPCs[cntr] = (L4pca_test[cntr],L23pca_test[cntr],L56pca_test[cntr],
                      H4pca_test[cntr],H23pca_test[cntr],H56pca_test[cntr])
    surpPCs[cntr] = (L4pca_temp[cntr],L23pca_temp[cntr],L56pca_temp[cntr],
                     H4pca_temp[cntr],H23pca_temp[cntr],H56pca_temp[cntr])
    
    for rnnNo in range(len(rnn_names)):
        contextPCs_sub[cntr,rnnNo] = np.hstack((cleanPCs[cntr][rnnNo][:,idxs22_test,:],surpPCs[cntr][rnnNo][:,idxs22_test,:]))

# %%
context_sub_surp = np.array([0]*nRepeats*nTest + [1]*nRepeats*nTest)

# %%
context_sub_imgIDs = {}
for cntr in range(nRuns):
    context_sub_imgIDs[cntr] = np.hstack((np.repeat(labelsTest[cntr][:,2:3],nRepeats),
                                          np.repeat(labelsTestTemp[cntr][:,2:3],nRepeats)))

# %% [markdown]
# #### Supervised Decoding

# %%
sub_Eps = np.array([0,1,50])
ds_im = 100

# %%
def repsDecodeSupervisedContext(rnnActs,labels,decodeType='surprise',clf='logistic',sub=True,ds=ds_im):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    if decodeType == 'surprise':
        nClasses = 2
    elif decodeType == 'imageID':
        if sub:
            rnnActs = rnnActs[:,::ds,:]
            nEpochs, nSamps, nNeurons = rnnActs.shape
            labels = labels[::ds]
            nClasses = len(np.unique(labels))
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression(multi_class='ovr').fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)    
        
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
dims23 = np.array([1,2,4,8,16,32,64,80])
dims4 = np.array([1,2,4,8,16,32])
dims56 = np.array([1,2,4,8,16,32,64])

# %%
L23surpPC = {}
L4surpPC = {}
L56surpPC = {}

H23surpPC = {}
H4surpPC = {}
H56surpPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H23surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        
    for d in dims4:
        L4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H4surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
    
    for d in dims56:
        L56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
        H56surpPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][sub_Eps,:,:d],context_sub_surp,decodeType='surprise')
# Out:
# 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]

# %%
L23imgPC = {}
L4imgPC = {}
L56imgPC = {}

H23imgPC = {}
H4imgPC = {}
H56imgPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    for d in dims23:
        L23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,1][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H23imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,4][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        
    for d in dims4:
        L4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,0][sub_Eps,:,:d],
                                                          context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H4imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,3][sub_Eps,:,:d],
                                                          context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
    
    for d in dims56:
        L56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,2][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
        H56imgPC[cntr,d], _ = repsDecodeSupervisedContext(contextPCs_sub[cntr,5][sub_Eps,:,:d],
                                                           context_sub_imgIDs[cntr].ravel(),decodeType='imageID')
# Out:
# 100%|██████████| 5/5 [00:16<00:00,  3.38s/it]

# %% [markdown]
# #### Generate plots

# %%
preds_L23imgPC = {}
preds_L4imgPC = {}
preds_L56imgPC = {}

preds_H23imgPC = {}
preds_H4imgPC = {}
preds_H56imgPC = {}

preds_L23surpPC = {}
preds_L4surpPC = {}
preds_L56surpPC = {}

preds_H23surpPC = {}
preds_H4surpPC = {}
preds_H56surpPC = {}

# %%
accs_L23imgPC = {}
accs_L4imgPC = {}
accs_L56imgPC = {}

accs_H23imgPC = {}
accs_H4imgPC = {}
accs_H56imgPC = {}

accs_L23surpPC = {}
accs_L4surpPC = {}
accs_L56surpPC = {}

accs_H23surpPC = {}
accs_H4surpPC = {}
accs_H56surpPC = {}

# %%
for cntr in range(nRuns):
    for ep in range(len(sub_Eps)):
        
        for d in dims23:
            preds_L23imgPC[cntr,d,ep] = np.argmax(L23imgPC[cntr,d][ep],axis=-1)
            preds_H23imgPC[cntr,d,ep] = np.argmax(H23imgPC[cntr,d][ep],axis=-1)
            
            preds_L23surpPC[cntr,d,ep] = np.argmax(L23surpPC[cntr,d][ep],axis=-1)
            preds_H23surpPC[cntr,d,ep] = np.argmax(H23surpPC[cntr,d][ep],axis=-1)
            
            accs_L23imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L23imgPC[cntr,d,ep])
            accs_H23imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H23imgPC[cntr,d,ep])
            
            accs_L23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L23surpPC[cntr,d,ep])
            accs_H23surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H23surpPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4imgPC[cntr,d,ep] = np.argmax(L4imgPC[cntr,d][ep],axis=-1)
            preds_H4imgPC[cntr,d,ep] = np.argmax(H4imgPC[cntr,d][ep],axis=-1)
            
            preds_L4surpPC[cntr,d,ep] = np.argmax(L4surpPC[cntr,d][ep],axis=-1)
            preds_H4surpPC[cntr,d,ep] = np.argmax(H4surpPC[cntr,d][ep],axis=-1)
            
            accs_L4imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L4imgPC[cntr,d,ep])
            accs_H4imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H4imgPC[cntr,d,ep])
            
            accs_L4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L4surpPC[cntr,d,ep])
            accs_H4surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H4surpPC[cntr,d,ep])
                
        for d in dims56:        
            preds_L56imgPC[cntr,d,ep] = np.argmax(L56imgPC[cntr,d][ep],axis=-1)
            preds_H56imgPC[cntr,d,ep] = np.argmax(H56imgPC[cntr,d][ep],axis=-1)
            
            preds_L56surpPC[cntr,d,ep] = np.argmax(L56surpPC[cntr,d][ep],axis=-1)
            preds_H56surpPC[cntr,d,ep] = np.argmax(H56surpPC[cntr,d][ep],axis=-1)
            
            accs_L56imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_L56imgPC[cntr,d,ep])
            accs_H56imgPC[cntr,d,ep] = homogeneity_score(context_sub_imgIDs[cntr][::ds_im],preds_H56imgPC[cntr,d,ep])
            
            accs_L56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_L56surpPC[cntr,d,ep])
            accs_H56surpPC[cntr,d,ep] = accuracy_score(context_sub_surp,preds_H56surpPC[cntr,d,ep])

# %%
tensor_accs_L23imgPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4imgPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56imgPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23imgPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4imgPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56imgPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_L23surpPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4surpPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56surpPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23surpPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4surpPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56surpPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

# %%
for ii in range(nRuns):
    for kk in range(len(sub_Eps)):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23imgPC[ii,jj,kk] = accs_L23imgPC[ii,d,kk]
            tensor_accs_H23imgPC[ii,jj,kk] = accs_H23imgPC[ii,d,kk]
            
            tensor_accs_L23surpPC[ii,jj,kk] = accs_L23surpPC[ii,d,kk]
            tensor_accs_H23surpPC[ii,jj,kk] = accs_H23surpPC[ii,d,kk]
            
        
        for jj,d in enumerate(dims4):
            tensor_accs_L4imgPC[ii,jj,kk] = accs_L4imgPC[ii,d,kk]
            tensor_accs_H4imgPC[ii,jj,kk] = accs_H4imgPC[ii,d,kk]
            
            tensor_accs_L4surpPC[ii,jj,kk] = accs_L4surpPC[ii,d,kk]
            tensor_accs_H4surpPC[ii,jj,kk] = accs_H4surpPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56imgPC[ii,jj,kk] = accs_L56imgPC[ii,d,kk]
            tensor_accs_H56imgPC[ii,jj,kk] = accs_H56imgPC[ii,d,kk]

            tensor_accs_L56surpPC[ii,jj,kk] = accs_L56surpPC[ii,d,kk]
            tensor_accs_H56surpPC[ii,jj,kk] = accs_H56surpPC[ii,d,kk]

# %%
mean_accs_L4imgPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23imgPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56imgPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4imgPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23imgPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56imgPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_L4surpPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23surpPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56surpPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4surpPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23surpPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56surpPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4imgPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23imgPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56imgPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4imgPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23imgPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56imgPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4surpPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23surpPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56surpPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4surpPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23surpPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56surpPC = np.zeros((len(dims56),len(sub_Eps)))

# %%
for ep in range(len(sub_Eps)):
    
    for dd, dims in enumerate(dims23):
        mean_accs_L23imgPC[dd,ep] = np.mean(tensor_accs_L23imgPC[:,dd,ep])
        mean_accs_H23imgPC[dd,ep] = np.mean(tensor_accs_H23imgPC[:,dd,ep])
        
        std_accs_L23imgPC[dd,ep] = np.var(tensor_accs_L23imgPC[:,dd,ep])
        std_accs_H23imgPC[dd,ep] = np.var(tensor_accs_H23imgPC[:,dd,ep])
        
        mean_accs_L23surpPC[dd,ep] = np.mean(tensor_accs_L23surpPC[:,dd,ep])
        mean_accs_H23surpPC[dd,ep] = np.mean(tensor_accs_H23surpPC[:,dd,ep])
        
        std_accs_L23surpPC[dd,ep] = np.var(tensor_accs_L23surpPC[:,dd,ep])
        std_accs_H23surpPC[dd,ep] = np.var(tensor_accs_H23surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims4):
        mean_accs_L4imgPC[dd,ep] = np.mean(tensor_accs_L4imgPC[:,dd,ep])
        mean_accs_H4imgPC[dd,ep] = np.mean(tensor_accs_H4imgPC[:,dd,ep])
        
        std_accs_L4imgPC[dd,ep] = np.var(tensor_accs_L4imgPC[:,dd,ep])
        std_accs_H4imgPC[dd,ep] = np.var(tensor_accs_H4imgPC[:,dd,ep])
        
        mean_accs_L4surpPC[dd,ep] = np.mean(tensor_accs_L4surpPC[:,dd,ep])
        mean_accs_H4surpPC[dd,ep] = np.mean(tensor_accs_H4surpPC[:,dd,ep])
        
        std_accs_L4surpPC[dd,ep] = np.var(tensor_accs_L4surpPC[:,dd,ep])
        std_accs_H4surpPC[dd,ep] = np.var(tensor_accs_H4surpPC[:,dd,ep])
        
    for dd, dims in enumerate(dims56):
        mean_accs_L56imgPC[dd,ep] = np.mean(tensor_accs_L56imgPC[:,dd,ep])        
        mean_accs_H56imgPC[dd,ep] = np.mean(tensor_accs_H56imgPC[:,dd,ep])
        
        std_accs_L56imgPC[dd,ep] = np.var(tensor_accs_L56imgPC[:,dd,ep])
        std_accs_H56imgPC[dd,ep] = np.var(tensor_accs_H56imgPC[:,dd,ep])
        
        mean_accs_L56surpPC[dd,ep] = np.mean(tensor_accs_L56surpPC[:,dd,ep])
        mean_accs_H56surpPC[dd,ep] = np.mean(tensor_accs_H56surpPC[:,dd,ep])
        
        std_accs_L56surpPC[dd,ep] = np.var(tensor_accs_L56surpPC[:,dd,ep])        
        std_accs_H56surpPC[dd,ep] = np.var(tensor_accs_H56surpPC[:,dd,ep])

# %%
ffsurp_dim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Surprise ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,0],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,0],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,0],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,0],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,0],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,0],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(132)
plt.title('Surprise ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,1],yerr=std_accs_L4surpPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,1],yerr=std_accs_L23surpPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,1],yerr=std_accs_L56surpPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,1],yerr=std_accs_H4surpPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,1],yerr=std_accs_H23surpPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,1],yerr=std_accs_H56surpPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
# plt.legend()

plt.subplot(133)
plt.title('Surprise ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4surpPC[:,-1],yerr=std_accs_L4surpPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23surpPC[:,-1],yerr=std_accs_L23surpPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56surpPC[:,-1],yerr=std_accs_L56surpPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4surpPC[:,-1],yerr=std_accs_H4surpPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23surpPC[:,-1],yerr=std_accs_H23surpPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56surpPC[:,-1],yerr=std_accs_H56surpPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
ffdim = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Image ID Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,0],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,0],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,0],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,0],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,0],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,0],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Image ID Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,1],yerr=std_accs_L4imgPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,1],yerr=std_accs_L23imgPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,1],yerr=std_accs_L56imgPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,1],yerr=std_accs_H4imgPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,1],yerr=std_accs_H23imgPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,1],yerr=std_accs_H56imgPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Image ID Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4imgPC[:,-1],yerr=std_accs_L4imgPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23imgPC[:,-1],yerr=std_accs_L23imgPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56imgPC[:,-1],yerr=std_accs_L56imgPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4imgPC[:,-1],yerr=std_accs_H4imgPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23imgPC[:,-1],yerr=std_accs_H23imgPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56imgPC[:,-1],yerr=std_accs_H56imgPC[:,-1],label='Higer layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# #### Position

# %%
step_labels = np.array([x%nSteps for x in range(nTest*nSteps)])

# %%
def repsDecodeSupervisedPosition(rnnActs,labels,clf='logistic'):
    nEpochs, nSamps, nNeurons = rnnActs.shape
    decode_dict = {}
    
    nClasses = 6
    
    reps_preds_probs = np.zeros((nEpochs,nSamps,nClasses))
    
    for ep in (range(nEpochs)):
        repsR = rnnActs[ep]
        
        ## Decoding
        if clf=='svm':
            clfR = SVC(kernel='linear',probability=True).fit(repsR,labels)
        elif clf=='logistic':
            clfR = LogisticRegression().fit(repsR,labels)
        elif clf=='perceptron':
            clfR = Perceptron().fit(repsR,labels)
        
        reps_preds_probs[ep] = clfR.predict_proba(repsR)
        decode_dict[str(ep)] = clfR
        
    return reps_preds_probs, decode_dict

# %%
L4posPC = {}
L23posPC = {}
L56posPC = {}
H4posPC = {}
H23posPC = {}
H56posPC = {}

# %%
for cntr in tqdm(range(nRuns)):
    
    for d in dims23:
        L23posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][1][sub_Eps,:,:d],step_labels)
        H23posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][4][sub_Eps,:,:d],step_labels)
    
    for d in dims4:
        L4posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][0][sub_Eps,:,:d],step_labels)
        H4posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][3][sub_Eps,:,:d],step_labels)
        
    for d in dims56:
        ## Position
        L56posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][2][sub_Eps,:,:d],step_labels)      
        H56posPC[cntr,d], _ = repsDecodeSupervisedPosition(cleanPCs[cntr][5][sub_Eps,:,:d],step_labels)
# Out:
# 100%|██████████| 5/5 [00:25<00:00,  5.18s/it]

# %%
preds_L23posPC = {}
preds_L4posPC = {}
preds_L56posPC = {}

preds_H23posPC = {}
preds_H4posPC = {}
preds_H56posPC = {}

# %%
accs_L23posPC = {}
accs_L4posPC = {}
accs_L56posPC = {}

accs_H23posPC = {}
accs_H4posPC = {}
accs_H56posPC = {}

# %%
for cntr in range(nRuns):
    
    for ep in range(len(sub_Eps)):
        
        for d in dims23:
            preds_L23posPC[cntr,d,ep] = np.argmax(L23posPC[cntr,d][ep],axis=-1)
            preds_H23posPC[cntr,d,ep] = np.argmax(H23posPC[cntr,d][ep],axis=-1)
            
            accs_L23posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L23posPC[cntr,d,ep])
            accs_H23posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H23posPC[cntr,d,ep])
            
        for d in dims4:
            preds_L4posPC[cntr,d,ep] = np.argmax(L4posPC[cntr,d][ep],axis=-1)
            preds_H4posPC[cntr,d,ep] = np.argmax(H4posPC[cntr,d][ep],axis=-1)
            
            accs_L4posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L4posPC[cntr,d,ep])
            accs_H4posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H4posPC[cntr,d,ep])
            
        for d in dims56:
            preds_L56posPC[cntr,d,ep] = np.argmax(L56posPC[cntr,d][ep],axis=-1)
            preds_H56posPC[cntr,d,ep] = np.argmax(H56posPC[cntr,d][ep],axis=-1)
            
            accs_L56posPC[cntr,d,ep] = accuracy_score(step_labels,preds_L56posPC[cntr,d,ep])
            accs_H56posPC[cntr,d,ep] = accuracy_score(step_labels,preds_H56posPC[cntr,d,ep])

# %%
tensor_accs_L23posPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_L4posPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_L56posPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

tensor_accs_H23posPC = np.zeros((nRuns,len(dims23),len(sub_Eps)))
tensor_accs_H4posPC = np.zeros((nRuns,len(dims4),len(sub_Eps)))
tensor_accs_H56posPC = np.zeros((nRuns,len(dims56),len(sub_Eps)))

# %%
for ii in range(nRuns):
    
    for kk in range(len(sub_Eps)):
        
        for jj,d in enumerate(dims23):
            tensor_accs_L23posPC[ii,jj,kk] = accs_L23posPC[ii,d,kk]
            tensor_accs_H23posPC[ii,jj,kk] = accs_H23posPC[ii,d,kk]
            
        for jj,d in enumerate(dims4):
            tensor_accs_L4posPC[ii,jj,kk] = accs_L4posPC[ii,d,kk]
            tensor_accs_H4posPC[ii,jj,kk] = accs_H4posPC[ii,d,kk]
            
        for jj,d in enumerate(dims56):            
            tensor_accs_L56posPC[ii,jj,kk] = accs_L56posPC[ii,d,kk]            
            tensor_accs_H56posPC[ii,jj,kk] = accs_H56posPC[ii,d,kk]

# %%
mean_accs_L4posPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_L23posPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_L56posPC = np.zeros((len(dims56),len(sub_Eps)))

mean_accs_H4posPC = np.zeros((len(dims4),len(sub_Eps)))
mean_accs_H23posPC = np.zeros((len(dims23),len(sub_Eps)))
mean_accs_H56posPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_L4posPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_L23posPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_L56posPC = np.zeros((len(dims56),len(sub_Eps)))

std_accs_H4posPC = np.zeros((len(dims4),len(sub_Eps)))
std_accs_H23posPC = np.zeros((len(dims23),len(sub_Eps)))
std_accs_H56posPC = np.zeros((len(dims56),len(sub_Eps)))

# %%
for ep in range(len(sub_Eps)):
    
    for dd, dim in enumerate(dims23):
        mean_accs_L23posPC[dd,ep] = np.mean(tensor_accs_L23posPC[:,dd,ep])
        mean_accs_H23posPC[dd,ep] = np.mean(tensor_accs_H23posPC[:,dd,ep])
        
        std_accs_L23posPC[dd,ep] = np.var(tensor_accs_L23posPC[:,dd,ep])
        std_accs_H23posPC[dd,ep] = np.var(tensor_accs_H23posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims4):
        mean_accs_L4posPC[dd,ep] = np.mean(tensor_accs_L4posPC[:,dd,ep])
        mean_accs_H4posPC[dd,ep] = np.mean(tensor_accs_H4posPC[:,dd,ep])
        
        std_accs_L4posPC[dd,ep] = np.var(tensor_accs_L4posPC[:,dd,ep])
        std_accs_H4posPC[dd,ep] = np.var(tensor_accs_H4posPC[:,dd,ep])
        
    for dd, dim in enumerate(dims56):
        mean_accs_L56posPC[dd,ep] = np.mean(tensor_accs_L56posPC[:,dd,ep])
        mean_accs_H56posPC[dd,ep] = np.mean(tensor_accs_H56posPC[:,dd,ep])
        
        std_accs_L56posPC[dd,ep] = np.var(tensor_accs_L56posPC[:,dd,ep])
        std_accs_H56posPC[dd,ep] = np.var(tensor_accs_H56posPC[:,dd,ep])

# %%
ffpos = plt.figure(figsize=(15,5))

plt.subplot(131)
plt.title('Position Decoding - Initialization')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,0],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,0],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,0],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,0],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,0],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,0],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(132)
plt.title('Position Decoding - First Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,1],yerr=std_accs_L4posPC[:,1],label='L4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,1],yerr=std_accs_L23posPC[:,1],label='L23',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,1],yerr=std_accs_L56posPC[:,1],label='L56',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,1],yerr=std_accs_H4posPC[:,1],label='H4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,1],yerr=std_accs_H23posPC[:,1],label='H23',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,1],yerr=std_accs_H56posPC[:,1],label='H56',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend()

plt.subplot(133)
plt.title('Position Decoding - Last Epoch')
plt.errorbar(np.arange(len(dims4)),mean_accs_L4posPC[:,-1],yerr=std_accs_L4posPC[:,-1],label='Lower layer 4',fmt='--^')
plt.errorbar(np.arange(len(dims23)),mean_accs_L23posPC[:,-1],yerr=std_accs_L23posPC[:,-1],label='Lower layer 2/3',fmt='--o')
plt.errorbar(np.arange(len(dims56)),mean_accs_L56posPC[:,-1],yerr=std_accs_L56posPC[:,-1],label='Lower layer 5/6',fmt='--s')
plt.errorbar(np.arange(len(dims4)),mean_accs_H4posPC[:,-1],yerr=std_accs_H4posPC[:,-1],label='Higher layer 4',fmt='-^')
plt.errorbar(np.arange(len(dims23)),mean_accs_H23posPC[:,-1],yerr=std_accs_H23posPC[:,-1],label='Higher layer 2/3',fmt='-o')
plt.errorbar(np.arange(len(dims56)),mean_accs_H56posPC[:,-1],yerr=std_accs_H56posPC[:,-1],label='Higher layer 5/6',fmt='-s')
plt.xlabel('PC Dimensionality')
plt.ylim(0,1.1)
plt.xticks(np.arange(len(dims23)),dims23)
plt.legend(bbox_to_anchor=(1,1))

# %%
np.save(pp+'preds_img_temp_L4-unidirectional-fb-binary',preds_L4imgPC)
np.save(pp+'preds_img_temp_L23-unidirectional-fb-binary',preds_L23imgPC)
np.save(pp+'preds_img_temp_L56-unidirectional-fb-binary',preds_L56imgPC)
np.save(pp+'preds_img_temp_H4-unidirectional-fb-binary',preds_H4imgPC)
np.save(pp+'preds_img_temp_H23-unidirectional-fb-binary',preds_H23imgPC)
np.save(pp+'preds_img_temp_H56-unidirectional-fb-binary',preds_H56imgPC)

np.save(pp+'accs_img_temp_L4-unidirectional-fb-binary',accs_L4imgPC)
np.save(pp+'accs_img_temp_L23-unidirectional-fb-binary',accs_L23imgPC)
np.save(pp+'accs_img_temp_L56-unidirectional-fb-binary',accs_L56imgPC)
np.save(pp+'accs_img_temp_H4-unidirectional-fb-binary',accs_H4imgPC)
np.save(pp+'accs_img_temp_H23-unidirectional-fb-binary',accs_H23imgPC)
np.save(pp+'accs_img_temp_H56-unidirectional-fb-binary',accs_H56imgPC)

# %%
np.save(pp+'preds_pos_temp_L4-unidirectional-fb-binary',preds_L4posPC)
np.save(pp+'preds_pos_temp_L23-unidirectional-fb-binary',preds_L23posPC)
np.save(pp+'preds_pos_temp_L56-unidirectional-fb-binary',preds_L56posPC)
np.save(pp+'preds_pos_temp_H4-unidirectional-fb-binary',preds_H4posPC)
np.save(pp+'preds_pos_temp_H23-unidirectional-fb-binary',preds_H23posPC)
np.save(pp+'preds_pos_temp_H56-unidirectional-fb-binary',preds_H56posPC)

np.save(pp+'accs_pos_temp_L4-unidirectional-fb-binary',accs_L4posPC)
np.save(pp+'accs_pos_temp_L23-unidirectional-fb-binary',accs_L23posPC)
np.save(pp+'accs_pos_temp_L56-unidirectional-fb-binary',accs_L56posPC)
np.save(pp+'accs_pos_temp_H4-unidirectional-fb-binary',accs_H4posPC)
np.save(pp+'accs_pos_temp_H23-unidirectional-fb-binary',accs_H23posPC)
np.save(pp+'accs_pos_temp_H56-unidirectional-fb-binary',accs_H56posPC)

# %%
np.save(pp+'preds_surp_temp_L4-unidirectional-fb',preds_L4surpPC)
np.save(pp+'preds_surp_temp_L23-unidirectional-fb',preds_L23surpPC)
np.save(pp+'preds_surp_temp_L56-unidirectional-fb',preds_L56surpPC)
np.save(pp+'preds_surp_temp_H4-unidirectional-fb',preds_H4surpPC)
np.save(pp+'preds_surp_temp_H23-unidirectional-fb',preds_H23surpPC)
np.save(pp+'preds_surp_temp_H56-unidirectional-fb',preds_H56surpPC)

np.save(pp+'accs_surp_temp_L4-unidirectional-fb',accs_L4surpPC)
np.save(pp+'accs_surp_temp_L23-unidirectional-fb',accs_L23surpPC)
np.save(pp+'accs_surp_temp_L56-unidirectional-fb',accs_L56surpPC)
np.save(pp+'accs_surp_temp_H4-unidirectional-fb',accs_H4surpPC)
np.save(pp+'accs_surp_temp_H23-unidirectional-fb',accs_H23surpPC)
np.save(pp+'accs_surp_temp_H56-unidirectional-fb',accs_H56surpPC)

# %% [markdown]
# #### Temporal accuracies

# %%
preds_test = {}
preds_temp = {}

accs_test = np.zeros((nRuns,n_epochs+1))
accs_temp = np.zeros((nRuns,n_epochs+1))

for cntr in range(nRuns):
    preds_test[cntr] = np.abs(np.round_(out_test[cntr]*(out_test[cntr]>0)))
    preds_temp[cntr] = np.abs(np.round_(out_test[cntr]*(out_temp[cntr]>0)))
    
    accs_test[cntr] = np.sum(np.sum(np.sum(((yRepsTest[cntr] - preds_test[cntr])==0)*1,-1),-1),-1)/np.prod(yRepsTest[cntr].shape)
    accs_temp[cntr] = np.sum(np.sum(np.sum(((yRepsTestTemp[cntr] - preds_temp[cntr])==0)*1,-1),-1),-1)/np.prod(yRepsTestTemp[cntr].shape)

# %%
ff_final_temp_noise = plt.figure()
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_test,0),yerr=np.var(accs_test,0),fmt='-',label='Test - Clean')
plt.errorbar(np.arange(n_epochs+1),np.mean(accs_temp,0),yerr=np.var(accs_temp,0),fmt='-',label='Test - Surprise')
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
plt.legend()
plt.title('Prediction accuracy in presence of temporal violation')
plt.show()

# %%
np.save(pp+'unidirectional-fb-no-violations-accs-binary',accs_test)
np.save(pp+'unidirectional-fb-temporal-violations-accs-binary',accs_temp)

# %%
ff_final_temp_noise.savefig('temporal-violation-final-acc-repeated-runs-unidirectional-fb-bianry.png',dpi=300,bbox_inches='tight')
ff_final_temp_noise.savefig('temporal-violation-final-acc-repeated-runs-unidirectional-fb-binary.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# #### Spatial violations

# %%
dim = 16

# %%
from numpy.random import normal

# %%
noise_stds = np.linspace(0,5,6)

# %%
noiseSeqs = {}

# %%
for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noiseSeqs[cntr,nn] = repsTest[cntr] + normal(0,noise,repsTest[cntr].shape)

# %%
noisy_loader_analyses = {}

for cntr in range(nRuns):
    for nn, noise in enumerate(noise_stds):
        noisy_loader_analyses[cntr,nn] = makeTensorLoaders((noiseSeqs[cntr,nn],yRepsTest[cntr],eTest[cntr],surpTest[cntr]),
                                          batch_size,shuffle=False)

# %%
L23_noisy = {}
L4_noisy = {}
L56_noisy = {}

H23_noisy = {}
H4_noisy = {}
H56_noisy = {}

out_noisy = {}

# %%
def pass_data_store_noisy_activations(loader, nData, 
                                nRuns=nRuns, n_epochs=n_epochs, nSteps=nSteps, pop_list=pop_list, n_latent=n_latent,
                                batch_size = batch_size):
    
    model = {}
    
    activations_hidden_L23_np = {}
    activations_hidden_L4_np = {}
    activations_hidden_L56_np = {}

    activations_hidden_H23_np = {}
    activations_hidden_H4_np = {}
    activations_hidden_H56_np = {}

    activations_out_np = {}
    
    for cntr in range(nRuns):
        for nn in range(len(noise_stds)):
            activations_hidden_L23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_L4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_L56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_hidden_H23_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[1]*n_latent))
            activations_hidden_H4_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[0]*n_latent))
            activations_hidden_H56_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,pop_list[2]*n_latent))

            activations_out_np[cntr,nn] = np.zeros((n_epochs+1,nData,nSteps,dim))

            for e in tqdm(range(n_epochs+1)):

                cnt = 0

                ## Load model
                model[cntr] = microcircuit(n_features=dim,hidden_dim=n_latent,bsize=batch_size,manual_seed=seeds[cntr])
                model[cntr].to(device)
                model[cntr].load_state_dict(torch.load(pp_pts[cntr]+'predRNN_epoch_'+str(e)+'.pt'))
                model[cntr].eval()

                ## Pass clean samples
                for data, f_target, lastEvent, surpriseBinary in loader[cntr,nn]:

                    if train_on_gpu:
                        data, f_targetC = data.float().cuda(), f_target.float().cuda()
                    else: data, f_targetC = data.float(), f_target.float()

                    target = f_target

                    output_pred, RNN_outputs, feedbackDiffs, projInterArea = model[cntr](data)

                    ## Collect activations  
                    act_hidden_L23 = np.squeeze(RNN_outputs[0].detach().cpu().numpy())
                    act_hidden_L4 = np.squeeze(RNN_outputs[1].detach().cpu().numpy())
                    act_hidden_L56 = np.squeeze(RNN_outputs[2].detach().cpu().numpy())

                    act_hidden_H23 = np.squeeze(RNN_outputs[3].detach().cpu().numpy())
                    act_hidden_H4 = np.squeeze(RNN_outputs[4].detach().cpu().numpy())
                    act_hidden_H56 = np.squeeze(RNN_outputs[5].detach().cpu().numpy())

                    output_pred = np.squeeze(output_pred.detach().cpu().numpy())

                    for i in range(batch_size):
                        if i < len(data):
                            label = target.data[i]

                            activations_hidden_L23_np[cntr,nn][e,cnt] = act_hidden_L23[i]
                            activations_hidden_L4_np[cntr,nn][e,cnt] = act_hidden_L4[i]
                            activations_hidden_L56_np[cntr,nn][e,cnt] = act_hidden_L56[i]

                            activations_hidden_H23_np[cntr,nn][e,cnt] = act_hidden_H23[i]
                            activations_hidden_H4_np[cntr,nn][e,cnt] = act_hidden_H4[i]
                            activations_hidden_H56_np[cntr,nn][e,cnt] = act_hidden_H56[i]

                            activations_out_np[cntr,nn][e,cnt] = output_pred[i]

                            cnt += 1

    return (activations_hidden_L23_np,activations_hidden_L4_np,activations_hidden_L56_np,
            activations_hidden_H23_np,activations_hidden_H4_np,activations_hidden_H56_np), activations_out_np

# %%
(L23_noisy,L4_noisy,L56_noisy,
 H23_noisy,H4_noisy,H56_noisy,), out_noisy = pass_data_store_noisy_activations(noisy_loader_analyses, nTest)
# Out:
# 100%|██████████| 101/101 [00:21<00:00,  4.77it/s]
# 100%|██████████| 101/101 [00:24<00:00,  4.15it/s]
# 100%|██████████| 101/101 [00:23<00:00,  4.22it/s]
# 100%|██████████| 101/101 [00:24<00:00,  4.13it/s]
# 100%|██████████| 101/101 [00:20<00:00,  5.04it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.52it/s]
# 100%|██████████| 101/101 [00:24<00:00,  4.18it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.47it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.50it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.50it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.55it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.54it/s]
# 100%|██████████| 101/101 [00:24<00:00,  4.12it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.52it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.49it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.46it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.48it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.49it/s]
# 100%|██████████| 101/101 [00:23<00:00,  4.34it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.50it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.49it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.41it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.47it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.49it/s]
# 100%|██████████| 101/101 [00:22<00:00,  4.41it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.49it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.53it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.49it/s]
# 100%|██████████| 101/101 [00:18<00:00,  5.49it/s]
# 100%|██████████| 101/101 [00:20<00:00,  4.82it/s]

# %%
predsN = {}
accsN = np.zeros((nRuns,len(noise_stds),n_epochs+1))

# %%
for cntr in range(nRuns):
    for nn in range(len(noise_stds)):
        predsN[cntr,nn] = np.abs(np.round_(out_noisy[cntr,nn]*(out_noisy[cntr,nn]>0)))
        accsN[cntr,nn] = np.sum(np.sum(np.sum(((yRepsTest[cntr] - predsN[cntr,nn])==0)*1,-1),-1),-1)/np.prod(yRepsTest[cntr].shape)

# %%
name = "Dark2_r"
cmap = get_cmap(name)  # type: matplotlib.colors.ListedColormap
colors = cmap.colors  # type: list

# %%
fpredspat = plt.figure()
for nn, noise in enumerate(noise_stds):
    plt.errorbar(np.arange(n_epochs+1),np.mean(accsN[:,nn],0),yerr=np.var(accsN[:,nn],0),fmt='-',label=np.round(noise,2),
                 c=colors[nn])
plt.xlabel('Epochs')
plt.ylabel('Prediction Accuracy')
# plt.ylim(0,1)
plt.legend(title="Noise sigma",bbox_to_anchor=(1,0.5))
plt.title('Prediction accuracy with spatial noise - Unidirectional FB')
plt.show()

# %%
np.save(pp+'unidirectional-fb-spatial-noisy-accs-binary',accsN)

# %% [markdown]
# #### Dimensionality (Linear)

# %%
def rnnLinDim(acts):
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    eig_mat = np.zeros((nEpochs,nNeurons))
        
    for ep in tqdm(range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        cov = actsScaled.T@actsScaled
        eig_mat[ep] = eigvals(cov)
        num = np.sum(eig_mat,1)**2
        den = np.sum(eig_mat**2,1) + 1e-17
        PR = num/den
    return PR

# %%
L23LinDim = np.zeros((nRuns,n_epochs+1))
L4LinDim = np.zeros((nRuns,n_epochs+1))
L56LinDim = np.zeros((nRuns,n_epochs+1))

H23LinDim = np.zeros((nRuns,n_epochs+1))
H4LinDim = np.zeros((nRuns,n_epochs+1))
H56LinDim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23LinDim[cntr] = rnnLinDim(L23_test[cntr])
    L4LinDim[cntr] = rnnLinDim(L4_test[cntr])
    L56LinDim[cntr] = rnnLinDim(L56_test[cntr])

    H23LinDim[cntr] = rnnLinDim(H23_test[cntr])
    H4LinDim[cntr] = rnnLinDim(H4_test[cntr])
    H56LinDim[cntr] = rnnLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 101/101 [00:01<00:00, 52.04it/s]
# 100%|██████████| 101/101 [00:00<00:00, 138.73it/s]
# 100%|██████████| 101/101 [00:01<00:00, 83.63it/s]
# 100%|██████████| 101/101 [00:01<00:00, 60.68it/s]
# 100%|██████████| 101/101 [00:00<00:00, 121.86it/s]
# 100%|██████████| 101/101 [00:01<00:00, 72.65it/s]
# 100%|██████████| 101/101 [00:01<00:00, 60.14it/s]
# 100%|██████████| 101/101 [00:00<00:00, 107.96it/s]
# 100%|██████████| 101/101 [00:01<00:00, 72.08it/s]
# 100%|██████████| 101/101 [00:01<00:00, 60.64it/s]
# 100%|██████████| 101/101 [00:00<00:00, 104.62it/s]
# 100%|██████████| 101/101 [00:02<00:00, 45.66it/s]
# 100%|██████████| 101/101 [00:02<00:00, 48.95it/s]
# 100%|██████████| 101/101 [00:00<00:00, 161.52it/s]
# 100%|██████████| 101/101 [00:00<00:00, 110.92it/s]
# 100%|██████████| 101/101 [00:01<00:00, 74.19it/s]
# 100%|██████████| 101/101 [00:00<00:00, 144.05it/s]
# 100%|██████████| 101/101 [00:01<00:00, 79.55it/s]
# 100%|██████████| 101/101 [00:01<00:00, 99.47it/s]
# 100%|██████████| 101/101 [00:00<00:00, 140.65it/s]
# 100%|██████████| 101/101 [00:01<00:00, 84.74it/s]
# 100%|██████████| 101/101 [00:01<00:00, 93.65it/s]
# 100%|██████████| 101/101 [00:00<00:00, 168.90it/s]
# 100%|██████████| 101/101 [00:00<00:00, 110.80it/s]
# 100%|██████████| 101/101 [00:01<00:00, 94.55it/s]
# 100%|██████████| 101/101 [00:00<00:00, 162.28it/s]
# 100%|██████████| 101/101 [00:01<00:00, 87.37it/s]
# 100%|██████████| 101/101 [00:01<00:00, 71.22it/s]
# 100%|██████████| 101/101 [00:00<00:00, 139.88it/s]
# 100%|██████████| 101/101 [00:01<00:00, 91.40it/s]

# %% [markdown]
# #### Dimensionality (non-linear)

# %%
def rnnNonLinDim(acts,nTypes=2,subsample=True,ds=100):
    
    nEpochs,nSeqs, nRolls, nNeurons = acts.shape
    nSamps = nSeqs*nRolls
    
    dims_mat = np.zeros((nEpochs,nTypes))
        
    for ep in (range(nEpochs)):
        reps = acts[ep]
        
        ## reshape
        actsR = np.zeros((nSeqs*nRolls,nNeurons))
        cnt = 0
        
        for ii in range(nSeqs):
            for jj in range(nRolls):
                
                actsR[cnt] = reps[ii,jj]
                cnt += 1
        
        scaler = StandardScaler()
        actsScaled = scaler.fit_transform(actsR)
        
        if subsample:
            actsScaled = actsScaled[::ds]
        
        dims_mat[ep,0] = MiND_ML().fit(actsScaled).dimension_
#         print(dims_mat[ep,0])
        dims_mat[ep,1] = CorrInt().fit(actsScaled).dimension_
#         print(dims_mat[ep,1])
#         dims_mat[ep,2] = MLE().fit(actsScaled).dimension_
#         print(dims_mat[ep,2])
#         dims_mat[ep,3] = DANCo().fit(actsScaled).dimension_
        
    return np.mean(dims_mat,-1),dims_mat

# %%
L23NonLinDim = np.zeros((nRuns,n_epochs+1))
L4NonLinDim = np.zeros((nRuns,n_epochs+1))
L56NonLinDim = np.zeros((nRuns,n_epochs+1))

H23NonLinDim = np.zeros((nRuns,n_epochs+1))
H4NonLinDim = np.zeros((nRuns,n_epochs+1))
H56NonLinDim = np.zeros((nRuns,n_epochs+1))

# %%
L23_ND_mat = {}
L4_ND_mat = {}
L56_ND_mat = {}
H23_ND_mat = {}
H4_ND_mat = {}
H56_ND_mat = {}

# %%
for cntr in tqdm(range(nRuns)):
    L23NonLinDim[cntr], L23_ND_mat[cntr] = rnnNonLinDim(L23_test[cntr])
    L4NonLinDim[cntr], L4_ND_mat[cntr] = rnnNonLinDim(L4_test[cntr])
    L56NonLinDim[cntr], L56_ND_mat[cntr] = rnnNonLinDim(L56_test[cntr])

    H23NonLinDim[cntr], H23_ND_mat[cntr] = rnnNonLinDim(H23_test[cntr])
    H4NonLinDim[cntr], H4_ND_mat[cntr] = rnnNonLinDim(H4_test[cntr])
    H56NonLinDim[cntr], H56_ND_mat[cntr] = rnnNonLinDim(H56_test[cntr])
# Out:
# 100%|██████████| 5/5 [02:17<00:00, 27.41s/it]

# %%
L23_NonLineDim_mean = np.mean(L23NonLinDim,0)
L4_NonLineDim_mean = np.mean(L4NonLinDim,0)
L56_NonLineDim_mean = np.mean(L56NonLinDim,0)

H23_NonLineDim_mean = np.mean(H23NonLinDim,0)
H4_NonLineDim_mean = np.mean(H4NonLinDim,0)
H56_NonLineDim_mean = np.mean(H56NonLinDim,0)

L23_NonLineDim_std = np.var(L23NonLinDim,0)
L4_NonLineDim_std = np.var(L4NonLinDim,0)
L56_NonLineDim_std = np.var(L56NonLinDim,0)

H23_NonLineDim_std = np.var(H23NonLinDim,0)
H4_NonLineDim_std = np.var(H4NonLinDim,0)
H56_NonLineDim_std = np.var(H56NonLinDim,0)

# %%
L23_dim = np.zeros((nRuns,n_epochs+1))
L4_dim = np.zeros((nRuns,n_epochs+1))
L56_dim = np.zeros((nRuns,n_epochs+1))

H23_dim = np.zeros((nRuns,n_epochs+1))
H4_dim = np.zeros((nRuns,n_epochs+1))
H56_dim = np.zeros((nRuns,n_epochs+1))

# %%
for cntr in range(nRuns):
    L23_dim[cntr] = L23LinDim[cntr]/L23NonLinDim[cntr]
    L4_dim[cntr] = L4LinDim[cntr]/L4NonLinDim[cntr]
    L56_dim[cntr] = L56LinDim[cntr]/L56NonLinDim[cntr]
    H23_dim[cntr] = H23LinDim[cntr]/H23NonLinDim[cntr]
    H4_dim[cntr] = H4LinDim[cntr]/H4NonLinDim[cntr]
    H56_dim[cntr] = H56LinDim[cntr]/H56NonLinDim[cntr]

# %%
np.save(pp+'L23DG_unidirectional-fb_binary',L23_dim)
np.save(pp+'L4DG_unidirectional-fb_binary',L4_dim)
np.save(pp+'L56DG_unidirectional-fb_binary',L56_dim)
np.save(pp+'H23DG_unidirectional-fb_binary',H23_dim)
np.save(pp+'H4DG_unidirectional-fb_binary',H4_dim)
np.save(pp+'H56DG_unidirectional-fb_binary',H56_dim)

# %%
ffTotDim = plt.figure(figsize=(5,5))

plt.subplot(111)

plt.plot(np.arange(n_epochs+1),np.mean(L4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(L4_dim,0)-np.var(L4_dim,0),np.mean(L4_dim,0)+np.var(L4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(L23_dim,0)-np.var(L23_dim,0),np.mean(L23_dim,0)+np.var(L23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(L56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(L56_dim,0)-np.var(L56_dim,0),np.mean(L56_dim,0)+np.var(L56_dim,0),alpha=0.5)

plt.plot(np.arange(n_epochs+1),np.mean(H4_dim,0),label='Lower layer 4')
plt.fill_between(np.arange(n_epochs+1),np.mean(H4_dim,0)-np.var(H4_dim,0),np.mean(H4_dim,0)+np.var(H4_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H23_dim,0),label='Lower layer 2/3')
plt.fill_between(np.arange(n_epochs+1),np.mean(H23_dim,0)-np.var(H23_dim,0),np.mean(H23_dim,0)+np.var(H23_dim,0),alpha=0.5)
plt.plot(np.arange(n_epochs+1),np.mean(H56_dim,0),label='Lower layer 5/6')
plt.fill_between(np.arange(n_epochs+1),np.mean(H56_dim,0)-np.var(H56_dim,0),np.mean(H56_dim,0)+np.var(H56_dim,0),alpha=0.5)

plt.xlabel('Epochs')
plt.ylabel('Dimensionality Gain')
# plt.ylim(0.9,2.2)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Unidirectional-FB Microcircuit')
plt.show()

# %%
ffTotDim.savefig('Dimensionality-gain-unidirectional-fb-across-learning-binary.png',dpi=300,bbox_inches='tight')
ffTotDim.savefig('Dimensionality-gain-unidirectional-fb-across-learning-binary.svg',dpi=300,bbox_inches='tight')
